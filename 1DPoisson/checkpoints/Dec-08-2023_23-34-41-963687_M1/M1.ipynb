# %%
# # Switch to tensorflow 1.x
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time
import logging

import os.path
import shutil
from datetime import datetime
import pickle

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# %%
class PINN:
    def __init__(self, layers, X_u, Y_u, X_r, Y_r ,mode ,  sess):


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        self.mu_X, self.sigma_X = X_r.mean(0), X_r.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]

        # Normalize
        self.X_u = (X_u - self.mu_X) / self.sigma_X
        self.Y_u = Y_u
        self.X_r = (X_r - self.mu_X) / self.sigma_X
        self.Y_r = Y_r

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
            
        # Define the size of the Kernel
        self.kernel_size = X_u.shape[0]
        # Define Tensorflow session
        self.sess = sess# tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_bc_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.x_u_ntk_tf = tf.placeholder(tf.float32, shape=(self.kernel_size, 1))
        self.x_r_ntk_tf = tf.placeholder(tf.float32, shape=(self.kernel_size, 1))


        # Evaluate predictions
        self.u_bc_pred = self.net_u(self.x_bc_tf)

        self.u_pred = self.net_u(self.x_u_tf)
        self.r_pred = self.net_r(self.x_r_tf)
        
        self.u_ntk_pred = self.net_u(self.x_u_ntk_tf)
        self.r_ntk_pred = self.net_r(self.x_r_ntk_tf)
     
        # Boundary loss
        self.loss_bcs = tf.reduce_mean(tf.square(self.u_bc_pred - self.u_bc_tf))

        # Residual loss        
        self.loss_res =  tf.reduce_mean(tf.square(self.r_tf - self.r_pred))
        
        # Total loss
        self.loss = self.loss_res + self.loss_bcs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-5
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        # To compute NTK, it is better to use SGD optimizer
        # since the corresponding gradient flow is not exactly same.
        self.train_op = tf.train.GradientDescentOptimizer(starter_learning_rate).minimize(self.loss)
        # self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)


        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
        
        self.saver = tf.train.Saver()
        
        # Compute the Jacobian for weights and biases in each hidden layer  
        self.J_u = self.compute_jacobian(self.u_ntk_pred) 
        self.J_r = self.compute_jacobian(self.r_ntk_pred)
        
        # The empirical NTK = J J^T, compute NTK of PINNs 
        self.K_uu = self.compute_ntk(self.J_u, self.x_u_ntk_tf, self.J_u, self.x_u_ntk_tf)
        self.K_ur = self.compute_ntk(self.J_u, self.x_u_ntk_tf, self.J_r, self.x_r_ntk_tf)
        self.K_rr = self.compute_ntk(self.J_r, self.x_r_ntk_tf, self.J_r, self.x_r_ntk_tf)
        
        # Logger
        # Loss logger
        self.loss_bcs_log = []
        self.loss_res_log = []

        # NTK logger 
        self.K_uu_log = []
        self.K_rr_log = []
        self.K_ur_log = []
        
        # Weights logger 
        self.weights_log = []
        self.biases_log = []
       # Gradients Storage


        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bc_layers = self.generate_grad_dict()

        self.grad_res = []
        self.grad_bc = []

        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bc.append(tf.gradients(self.loss_bcs, self.weights[i])[0])



        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bcs] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        

###############################################################################################################

    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)
    
    # NTK initialization
    def NTK_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        std = 1. / np.sqrt(in_dim)
        return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * std,
                           dtype=tf.float32)

     # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.NTK_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.random.normal([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.nn.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Evaluates the PDE solution
    def net_u(self, x):
        u = self.forward_pass(x)
        return u

    # Forward pass for the residual
    def net_r(self, x):
        u = self.net_u(x)

        u_x = tf.gradients(u, x)[0] / self.sigma_x
        u_xx = tf.gradients(u_x, x)[0] / self.sigma_x

        res_u = u_xx
        return res_u
    
    # Compute Jacobian for each weights and biases in each layer and retrun a list 
    def compute_jacobian(self, f):
        J_list =[]
        L = len(self.weights)    
        for i in range(L):
            J_w = jacobian(f, self.weights[i])
            J_list.append(J_w)
     
        for i in range(L):
            J_b = jacobian(f, self.biases[i])
            J_list.append(J_b)
        return J_list
    
    # Compute the empirical NTK = J J^T
    def compute_ntk(self, J1_list, x1, J2_list, x2):
        D = x1.shape[0]
        N = len(J1_list)
        
        Ker = tf.zeros((D,D))
        for k in range(N):
            J1 = tf.reshape(J1_list[k], shape=(D,-1))
            J2 = tf.reshape(J2_list[k], shape=(D,-1))
            
            K = tf.matmul(J1, tf.transpose(J2))
            Ker = Ker + K
        return Ker
            
    # Trains the model by minimizing the MSE loss
    def trainmb(self, nIter=10000, batch_size=128, log_NTK=True, log_weights=True):


        itValues = [1,100,1000,39999]
        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_bc_tf: self.X_u, self.u_bc_tf: self.Y_u,
                       self.x_u_tf: self.X_u, self.x_r_tf: self.X_r,
                       self.r_tf: self.Y_r
                       }
        
            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            # self.print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value, loss_res_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)
                self.loss_bcs_log.append(loss_bcs_value)
                self.loss_res_log.append(loss_res_value)

                self.print('It: %d, Loss: %.3e, Loss_bcs: %.3e, Loss_res: %.3e ,Time: %.2f' %  (it, loss_value, loss_bcs_value, loss_res_value, elapsed))
                
            if log_NTK:
                # provide x, x' for NTK
                if it % 100 == 0:
                    self.print("Compute NTK...")
                    tf_dict2 = {self.x_u_ntk_tf: self.X_u, 
                               self.x_r_ntk_tf: self.X_r
                               }
                    K_uu_value, K_ur_value, K_rr_value = self.sess.run([self.K_uu,  self.K_ur,  self.K_rr], tf_dict2)
                    self.K_uu_log.append(K_uu_value)
                    self.K_ur_log.append(K_ur_value)
                    self.K_rr_log.append(K_rr_value)
            start_time = timeit.default_timer()

            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
            
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    # Evaluates predictions at test points
    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_r_tf: X_star}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
 ############################################################

    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values

  ############################################################
###################################################################################################################


    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc  = self.sess.run([ self.grad_res[i],self.grad_bc[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bc_layers['layer_' + str(i + 1)].append(grad_bc.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc = self.dict_gradients_bc_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=2)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")

    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M1.ipynb', os.path.join(dirname, 'M1.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger
    
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        #plt.show()
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)

        return self.dirname
    
    def plot_ntk(self):
        # Create empty lists for storing the eigenvalues of NTK
        lambda_K_log = []
        lambda_K_uu_log = []
        lambda_K_ur_log = []
        lambda_K_rr_log = []

        # Restore the NTK
        K_uu_list = self.K_uu_log
        K_ur_list = self.K_ur_log
        K_rr_list = self.K_rr_log
        K_list = []
            
        for k in range(len(K_uu_list)):
            K_uu = K_uu_list[k]
            K_ur = K_ur_list[k]
            K_rr = K_rr_list[k]
            
            K = np.concatenate([np.concatenate([K_uu, K_ur], axis = 1), np.concatenate([K_ur.T, K_rr], axis = 1)], axis = 0)
            K_list.append(K)

            # Compute eigenvalues
            lambda_K, _ = np.linalg.eig(K)
            lambda_K_uu, _ = np.linalg.eig(K_uu)
            lambda_K_rr, _ = np.linalg.eig(K_rr)
            
            # Sort in descresing order
            lambda_K = np.sort(np.real(lambda_K))[::-1]
            lambda_K_uu = np.sort(np.real(lambda_K_uu))[::-1]
            lambda_K_rr = np.sort(np.real(lambda_K_rr))[::-1]
            
            # Store eigenvalues
            lambda_K_log.append(lambda_K)
            lambda_K_uu_log.append(lambda_K_uu)
            lambda_K_rr_log.append(lambda_K_rr)
        fig = plt.figure(figsize=(18, 5))
        plt.subplot(1,3,1)
        for i in range(1, len(lambda_K_log), 10):
            plt.plot(lambda_K_log[i], '--')
        plt.xscale('log')
        plt.yscale('log')
        plt.title(r'Eigenvalues of ${K}$')
        plt.tight_layout()

        plt.subplot(1,3,2)
        for i in range(1, len(lambda_K_uu_log), 10):
            plt.plot(lambda_K_uu_log[i], '--')
        plt.xscale('log')
        plt.yscale('log')
        plt.title(r'Eigenvalues of ${K}_{uu}$')
        plt.tight_layout()

        plt.subplot(1,3,3)
        for i in range(1, len(lambda_K_log), 10):
            plt.plot(lambda_K_rr_log[i], '--')
        plt.xscale('log')
        plt.yscale('log')
        plt.title(r'Eigenvalues of ${K}_{rr}$')
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"ntk.png"))
        plt.close("all")

    def plt_prediction(self , X_star , u_star , u_pred):
        fig = plt.figure(figsize=(12, 5))
        plt.subplot(1,2,1)
        plt.plot(X_star, u_star, label='Exact')
        plt.plot(X_star, u_pred, '--', label='Predicted')
        plt.xlabel('$x$')
        plt.ylabel('$y$')
        plt.legend(loc='upper right')

        plt.subplot(1,2,2)
        plt.plot(X_star, np.abs(u_star - u_pred), label='Error')
        plt.yscale('log')
        plt.xlabel('$x$')
        plt.ylabel('Point-wise error')
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"))
        plt.close("all")

# %%
# Define solution and its Laplace
a = 4

def u(x, a):
  return np.sin(np.pi * a * x)

def u_xx(x, a):
  return -(np.pi * a)**2 * np.sin(np.pi * a * x)

# %%
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  X_u, Y_u, X_r, Y_r , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size , mode):


    gpu_options = tf.GPUOptions(visible_device_list="0")
    tf.reset_default_graph()
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, X_u, Y_u, X_r, Y_r , mode , sess)    

        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        r_pred = model.predict_r(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(r_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_r: {:.2e}'.format(error_r))


    return [elapsed, error_u , error_r ]

# %%
# Define computional domain
bc1_coords = np.array([[0.0], [0.0]])
bc2_coords = np.array([[1.0], [1.0]])
dom_coords = np.array([[0.0], [1.0]])

# Training data on u(x) -- Dirichlet boundary conditions

nn  = 100

X_bc1 = dom_coords[0, 0] * np.ones((nn // 2, 1))
X_bc2 = dom_coords[1, 0] * np.ones((nn // 2, 1))
X_u = np.vstack([X_bc1, X_bc2])
Y_u = u(X_u, a)

X_r = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
Y_r = u_xx(X_r, a)

nn = 1000
X_star = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
u_star = u(X_star, a)
r_star = u_xx(X_star, a)

nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 128



# Define model
mode = 'M1'
layers = [1, 500, 1]



iterations = 1
methods = [ "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler
        gpu_options = tf.GPUOptions(visible_device_list="0")
        tf.reset_default_graph()
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            model = PINN(layers, X_u, Y_u, X_r, Y_r , mode , sess)    

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions
            model.save_NN()
            model.plot_ntk()
 

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(r_star, 2)

            print('elapsed: {:.2e}'.format(elapsed))

            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_r: {:.2e}'.format(error_r))


            print('elapsed: {:.2e}'.format(elapsed))
            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_v: {:.2e}'.format(error_r))

            model.plt_prediction( X_star , u_star , u_pred)
            sess.close()  
            
        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_v_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list ,error_r_list ]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_model"+mode+"_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(bcbatch_size)+"_n"+str(iterations)+"_nIter"+str(nIter)+".mat" , result_dict))
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_22810/683443582.py:52: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22810/683443582.py:53: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22810/683443582.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22810/683443582.py:54: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22810/3040281818.py:29: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22810/3040281818.py:63: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22810/3040281818.py:69: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# 2023-12-08 20:23:26.890157: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-08 20:23:26.909994: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-08 20:23:26.910483: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55772b4071a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-08 20:23:26.910500: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-08 20:23:26.911018: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_22810/3040281818.py:73: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22810/3040281818.py:76: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# mini_batch method is used
# It: 0, Loss: 1.196e+04, Loss_bcs: 2.614e+00, Loss_res: 1.195e+04 ,Time: 0.35
# Compute NTK...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 1.176e+04, Loss_bcs: 2.652e+00, Loss_res: 1.176e+04 ,Time: 0.00
# Compute NTK...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 1.157e+04, Loss_bcs: 2.713e+00, Loss_res: 1.156e+04 ,Time: 0.00
# Compute NTK...
# It: 300, Loss: 1.138e+04, Loss_bcs: 2.800e+00, Loss_res: 1.138e+04 ,Time: 0.00
# Compute NTK...
# It: 400, Loss: 1.120e+04, Loss_bcs: 2.908e+00, Loss_res: 1.119e+04 ,Time: 0.00
# Compute NTK...
# It: 500, Loss: 1.102e+04, Loss_bcs: 3.038e+00, Loss_res: 1.101e+04 ,Time: 0.00
# Compute NTK...
# It: 600, Loss: 1.084e+04, Loss_bcs: 3.188e+00, Loss_res: 1.084e+04 ,Time: 0.00
# Compute NTK...
# It: 700, Loss: 1.067e+04, Loss_bcs: 3.357e+00, Loss_res: 1.067e+04 ,Time: 0.00
# Compute NTK...
# It: 800, Loss: 1.050e+04, Loss_bcs: 3.545e+00, Loss_res: 1.050e+04 ,Time: 0.00
# Compute NTK...
# It: 900, Loss: 1.034e+04, Loss_bcs: 3.751e+00, Loss_res: 1.033e+04 ,Time: 0.00
# Compute NTK...
# It: 1000, Loss: 1.018e+04, Loss_bcs: 3.975e+00, Loss_res: 1.017e+04 ,Time: 0.00
# Compute NTK...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 1.002e+04, Loss_bcs: 4.216e+00, Loss_res: 1.001e+04 ,Time: 0.00
# Compute NTK...
# It: 1200, Loss: 9.862e+03, Loss_bcs: 4.474e+00, Loss_res: 9.858e+03 ,Time: 0.00
# Compute NTK...
# It: 1300, Loss: 9.710e+03, Loss_bcs: 4.748e+00, Loss_res: 9.705e+03 ,Time: 0.00
# Compute NTK...
# It: 1400, Loss: 9.560e+03, Loss_bcs: 5.038e+00, Loss_res: 9.555e+03 ,Time: 0.00
# Compute NTK...
# It: 1500, Loss: 9.414e+03, Loss_bcs: 5.344e+00, Loss_res: 9.408e+03 ,Time: 0.00
# Compute NTK...
# It: 1600, Loss: 9.270e+03, Loss_bcs: 5.663e+00, Loss_res: 9.264e+03 ,Time: 0.00
# Compute NTK...
# It: 1700, Loss: 9.128e+03, Loss_bcs: 5.998e+00, Loss_res: 9.122e+03 ,Time: 0.00
# Compute NTK...
# It: 1800, Loss: 8.989e+03, Loss_bcs: 6.345e+00, Loss_res: 8.983e+03 ,Time: 0.00
# Compute NTK...
# It: 1900, Loss: 8.853e+03, Loss_bcs: 6.706e+00, Loss_res: 8.846e+03 ,Time: 0.00
# Compute NTK...
# It: 2000, Loss: 8.719e+03, Loss_bcs: 7.080e+00, Loss_res: 8.712e+03 ,Time: 0.00
# Compute NTK...
# It: 2100, Loss: 8.587e+03, Loss_bcs: 7.465e+00, Loss_res: 8.580e+03 ,Time: 0.00
# Compute NTK...
# It: 2200, Loss: 8.458e+03, Loss_bcs: 7.863e+00, Loss_res: 8.450e+03 ,Time: 0.00
# Compute NTK...
# It: 2300, Loss: 8.331e+03, Loss_bcs: 8.272e+00, Loss_res: 8.322e+03 ,Time: 0.00
# Compute NTK...
# It: 2400, Loss: 8.206e+03, Loss_bcs: 8.693e+00, Loss_res: 8.197e+03 ,Time: 0.00
# Compute NTK...
# It: 2500, Loss: 8.083e+03, Loss_bcs: 9.124e+00, Loss_res: 8.074e+03 ,Time: 0.00
# Compute NTK...
# It: 2600, Loss: 7.962e+03, Loss_bcs: 9.566e+00, Loss_res: 7.952e+03 ,Time: 0.00
# Compute NTK...
# It: 2700, Loss: 7.843e+03, Loss_bcs: 1.002e+01, Loss_res: 7.833e+03 ,Time: 0.00
# Compute NTK...
# It: 2800, Loss: 7.727e+03, Loss_bcs: 1.048e+01, Loss_res: 7.716e+03 ,Time: 0.00
# Compute NTK...
# It: 2900, Loss: 7.612e+03, Loss_bcs: 1.095e+01, Loss_res: 7.601e+03 ,Time: 0.01
# Compute NTK...
# It: 3000, Loss: 7.499e+03, Loss_bcs: 1.143e+01, Loss_res: 7.488e+03 ,Time: 0.00
# Compute NTK...
# It: 3100, Loss: 7.388e+03, Loss_bcs: 1.192e+01, Loss_res: 7.376e+03 ,Time: 0.00
# Compute NTK...
# It: 3200, Loss: 7.279e+03, Loss_bcs: 1.242e+01, Loss_res: 7.267e+03 ,Time: 0.00
# Compute NTK...
# It: 3300, Loss: 7.172e+03, Loss_bcs: 1.292e+01, Loss_res: 7.159e+03 ,Time: 0.00
# Compute NTK...
# It: 3400, Loss: 7.066e+03, Loss_bcs: 1.343e+01, Loss_res: 7.053e+03 ,Time: 0.00
# Compute NTK...
# It: 3500, Loss: 6.963e+03, Loss_bcs: 1.395e+01, Loss_res: 6.949e+03 ,Time: 0.00
# Compute NTK...
# It: 3600, Loss: 6.861e+03, Loss_bcs: 1.448e+01, Loss_res: 6.846e+03 ,Time: 0.00
# Compute NTK...
# It: 3700, Loss: 6.761e+03, Loss_bcs: 1.501e+01, Loss_res: 6.746e+03 ,Time: 0.00
# Compute NTK...
# It: 3800, Loss: 6.662e+03, Loss_bcs: 1.555e+01, Loss_res: 6.646e+03 ,Time: 0.00
# Compute NTK...
# It: 3900, Loss: 6.565e+03, Loss_bcs: 1.610e+01, Loss_res: 6.549e+03 ,Time: 0.00
# Compute NTK...
# It: 4000, Loss: 6.470e+03, Loss_bcs: 1.665e+01, Loss_res: 6.453e+03 ,Time: 0.00
# Compute NTK...
# It: 4100, Loss: 6.376e+03, Loss_bcs: 1.720e+01, Loss_res: 6.359e+03 ,Time: 0.00
# Compute NTK...
# It: 4200, Loss: 6.284e+03, Loss_bcs: 1.777e+01, Loss_res: 6.266e+03 ,Time: 0.00
# Compute NTK...
# It: 4300, Loss: 6.194e+03, Loss_bcs: 1.834e+01, Loss_res: 6.175e+03 ,Time: 0.00
# Compute NTK...
# It: 4400, Loss: 6.104e+03, Loss_bcs: 1.891e+01, Loss_res: 6.086e+03 ,Time: 0.00
# Compute NTK...
# It: 4500, Loss: 6.017e+03, Loss_bcs: 1.949e+01, Loss_res: 5.997e+03 ,Time: 0.00
# Compute NTK...
# It: 4600, Loss: 5.931e+03, Loss_bcs: 2.007e+01, Loss_res: 5.911e+03 ,Time: 0.00
# Compute NTK...
# It: 4700, Loss: 5.846e+03, Loss_bcs: 2.066e+01, Loss_res: 5.826e+03 ,Time: 0.00
# Compute NTK...
# It: 4800, Loss: 5.763e+03, Loss_bcs: 2.125e+01, Loss_res: 5.742e+03 ,Time: 0.00
# Compute NTK...
# It: 4900, Loss: 5.681e+03, Loss_bcs: 2.185e+01, Loss_res: 5.659e+03 ,Time: 0.00
# Compute NTK...
# It: 5000, Loss: 5.601e+03, Loss_bcs: 2.244e+01, Loss_res: 5.578e+03 ,Time: 0.00
# Compute NTK...
# It: 5100, Loss: 5.522e+03, Loss_bcs: 2.304e+01, Loss_res: 5.499e+03 ,Time: 0.00
# Compute NTK...
# It: 5200, Loss: 5.444e+03, Loss_bcs: 2.365e+01, Loss_res: 5.420e+03 ,Time: 0.00
# Compute NTK...
# It: 5300, Loss: 5.367e+03, Loss_bcs: 2.425e+01, Loss_res: 5.343e+03 ,Time: 0.00
# Compute NTK...
# It: 5400, Loss: 5.292e+03, Loss_bcs: 2.486e+01, Loss_res: 5.267e+03 ,Time: 0.00
# Compute NTK...
# It: 5500, Loss: 5.218e+03, Loss_bcs: 2.547e+01, Loss_res: 5.193e+03 ,Time: 0.00
# Compute NTK...
# It: 5600, Loss: 5.146e+03, Loss_bcs: 2.608e+01, Loss_res: 5.120e+03 ,Time: 0.00
# Compute NTK...
# It: 5700, Loss: 5.074e+03, Loss_bcs: 2.669e+01, Loss_res: 5.047e+03 ,Time: 0.00
# Compute NTK...
# It: 5800, Loss: 5.004e+03, Loss_bcs: 2.730e+01, Loss_res: 4.977e+03 ,Time: 0.00
# Compute NTK...
# It: 5900, Loss: 4.935e+03, Loss_bcs: 2.791e+01, Loss_res: 4.907e+03 ,Time: 0.00
# Compute NTK...
# It: 6000, Loss: 4.867e+03, Loss_bcs: 2.853e+01, Loss_res: 4.839e+03 ,Time: 0.00
# Compute NTK...
# It: 6100, Loss: 4.800e+03, Loss_bcs: 2.914e+01, Loss_res: 4.771e+03 ,Time: 0.00
# Compute NTK...
# It: 6200, Loss: 4.735e+03, Loss_bcs: 2.976e+01, Loss_res: 4.705e+03 ,Time: 0.00
# Compute NTK...
# It: 6300, Loss: 4.671e+03, Loss_bcs: 3.037e+01, Loss_res: 4.640e+03 ,Time: 0.00
# Compute NTK...
# It: 6400, Loss: 4.607e+03, Loss_bcs: 3.099e+01, Loss_res: 4.576e+03 ,Time: 0.00
# Compute NTK...
# It: 6500, Loss: 4.545e+03, Loss_bcs: 3.160e+01, Loss_res: 4.513e+03 ,Time: 0.00
# Compute NTK...
# It: 6600, Loss: 4.484e+03, Loss_bcs: 3.221e+01, Loss_res: 4.452e+03 ,Time: 0.00
# Compute NTK...
# It: 6700, Loss: 4.424e+03, Loss_bcs: 3.282e+01, Loss_res: 4.391e+03 ,Time: 0.00
# Compute NTK...
# It: 6800, Loss: 4.365e+03, Loss_bcs: 3.344e+01, Loss_res: 4.331e+03 ,Time: 0.00
# Compute NTK...
# It: 6900, Loss: 4.307e+03, Loss_bcs: 3.405e+01, Loss_res: 4.273e+03 ,Time: 0.00
# Compute NTK...
# It: 7000, Loss: 4.250e+03, Loss_bcs: 3.465e+01, Loss_res: 4.215e+03 ,Time: 0.00
# Compute NTK...
# It: 7100, Loss: 4.194e+03, Loss_bcs: 3.526e+01, Loss_res: 4.158e+03 ,Time: 0.00
# Compute NTK...
# It: 7200, Loss: 4.138e+03, Loss_bcs: 3.586e+01, Loss_res: 4.103e+03 ,Time: 0.00
# Compute NTK...
# It: 7300, Loss: 4.084e+03, Loss_bcs: 3.647e+01, Loss_res: 4.048e+03 ,Time: 0.00
# Compute NTK...
# It: 7400, Loss: 4.031e+03, Loss_bcs: 3.707e+01, Loss_res: 3.994e+03 ,Time: 0.00
# Compute NTK...
# It: 7500, Loss: 3.979e+03, Loss_bcs: 3.766e+01, Loss_res: 3.941e+03 ,Time: 0.00
# Compute NTK...
# It: 7600, Loss: 3.927e+03, Loss_bcs: 3.826e+01, Loss_res: 3.889e+03 ,Time: 0.00
# Compute NTK...
# It: 7700, Loss: 3.877e+03, Loss_bcs: 3.885e+01, Loss_res: 3.838e+03 ,Time: 0.00
# Compute NTK...
# It: 7800, Loss: 3.827e+03, Loss_bcs: 3.944e+01, Loss_res: 3.788e+03 ,Time: 0.00
# Compute NTK...
# It: 7900, Loss: 3.779e+03, Loss_bcs: 4.002e+01, Loss_res: 3.739e+03 ,Time: 0.00
# Compute NTK...
# It: 8000, Loss: 3.731e+03, Loss_bcs: 4.060e+01, Loss_res: 3.690e+03 ,Time: 0.00
# Compute NTK...
# It: 8100, Loss: 3.684e+03, Loss_bcs: 4.118e+01, Loss_res: 3.643e+03 ,Time: 0.00
# Compute NTK...
# It: 8200, Loss: 3.638e+03, Loss_bcs: 4.175e+01, Loss_res: 3.596e+03 ,Time: 0.00
# Compute NTK...
# It: 8300, Loss: 3.592e+03, Loss_bcs: 4.232e+01, Loss_res: 3.550e+03 ,Time: 0.00
# Compute NTK...
# It: 8400, Loss: 3.547e+03, Loss_bcs: 4.289e+01, Loss_res: 3.505e+03 ,Time: 0.00
# Compute NTK...
# It: 8500, Loss: 3.504e+03, Loss_bcs: 4.345e+01, Loss_res: 3.460e+03 ,Time: 0.00
# Compute NTK...
# It: 8600, Loss: 3.460e+03, Loss_bcs: 4.401e+01, Loss_res: 3.416e+03 ,Time: 0.00
# Compute NTK...
# It: 8700, Loss: 3.418e+03, Loss_bcs: 4.456e+01, Loss_res: 3.374e+03 ,Time: 0.00
# Compute NTK...
# It: 8800, Loss: 3.377e+03, Loss_bcs: 4.511e+01, Loss_res: 3.331e+03 ,Time: 0.01
# Compute NTK...
# It: 8900, Loss: 3.336e+03, Loss_bcs: 4.565e+01, Loss_res: 3.290e+03 ,Time: 0.00
# Compute NTK...
# It: 9000, Loss: 3.296e+03, Loss_bcs: 4.620e+01, Loss_res: 3.249e+03 ,Time: 0.00
# Compute NTK...
# It: 9100, Loss: 3.256e+03, Loss_bcs: 4.673e+01, Loss_res: 3.209e+03 ,Time: 0.00
# Compute NTK...
# It: 9200, Loss: 3.217e+03, Loss_bcs: 4.727e+01, Loss_res: 3.170e+03 ,Time: 0.00
# Compute NTK...
# It: 9300, Loss: 3.179e+03, Loss_bcs: 4.780e+01, Loss_res: 3.131e+03 ,Time: 0.00
# Compute NTK...
# It: 9400, Loss: 3.142e+03, Loss_bcs: 4.832e+01, Loss_res: 3.093e+03 ,Time: 0.00
# Compute NTK...
# It: 9500, Loss: 3.105e+03, Loss_bcs: 4.884e+01, Loss_res: 3.056e+03 ,Time: 0.00
# Compute NTK...
# It: 9600, Loss: 3.069e+03, Loss_bcs: 4.936e+01, Loss_res: 3.019e+03 ,Time: 0.00
# Compute NTK...
# It: 9700, Loss: 3.033e+03, Loss_bcs: 4.987e+01, Loss_res: 2.983e+03 ,Time: 0.00
# Compute NTK...
# It: 9800, Loss: 2.998e+03, Loss_bcs: 5.038e+01, Loss_res: 2.948e+03 ,Time: 0.00
# Compute NTK...
# It: 9900, Loss: 2.964e+03, Loss_bcs: 5.089e+01, Loss_res: 2.913e+03 ,Time: 0.00
# Compute NTK...
# It: 10000, Loss: 2.931e+03, Loss_bcs: 5.139e+01, Loss_res: 2.879e+03 ,Time: 0.00
# Compute NTK...
# It: 10100, Loss: 2.897e+03, Loss_bcs: 5.189e+01, Loss_res: 2.846e+03 ,Time: 0.00
# Compute NTK...
# It: 10200, Loss: 2.865e+03, Loss_bcs: 5.238e+01, Loss_res: 2.813e+03 ,Time: 0.00
# Compute NTK...
# It: 10300, Loss: 2.833e+03, Loss_bcs: 5.287e+01, Loss_res: 2.780e+03 ,Time: 0.00
# Compute NTK...
# It: 10400, Loss: 2.802e+03, Loss_bcs: 5.335e+01, Loss_res: 2.748e+03 ,Time: 0.00
# Compute NTK...
# It: 10500, Loss: 2.771e+03, Loss_bcs: 5.383e+01, Loss_res: 2.717e+03 ,Time: 0.00
# Compute NTK...
# It: 10600, Loss: 2.740e+03, Loss_bcs: 5.431e+01, Loss_res: 2.686e+03 ,Time: 0.00
# Compute NTK...
# It: 10700, Loss: 2.711e+03, Loss_bcs: 5.478e+01, Loss_res: 2.656e+03 ,Time: 0.00
# Compute NTK...
# It: 10800, Loss: 2.681e+03, Loss_bcs: 5.524e+01, Loss_res: 2.626e+03 ,Time: 0.00
# Compute NTK...
# It: 10900, Loss: 2.653e+03, Loss_bcs: 5.571e+01, Loss_res: 2.597e+03 ,Time: 0.00
# Compute NTK...
# It: 11000, Loss: 2.624e+03, Loss_bcs: 5.617e+01, Loss_res: 2.568e+03 ,Time: 0.00
# Compute NTK...
# It: 11100, Loss: 2.597e+03, Loss_bcs: 5.662e+01, Loss_res: 2.540e+03 ,Time: 0.00
# Compute NTK...
# It: 11200, Loss: 2.569e+03, Loss_bcs: 5.707e+01, Loss_res: 2.512e+03 ,Time: 0.00
# Compute NTK...
# It: 11300, Loss: 2.543e+03, Loss_bcs: 5.752e+01, Loss_res: 2.485e+03 ,Time: 0.00
# Compute NTK...
# It: 11400, Loss: 2.516e+03, Loss_bcs: 5.796e+01, Loss_res: 2.458e+03 ,Time: 0.00
# Compute NTK...
# It: 11500, Loss: 2.490e+03, Loss_bcs: 5.840e+01, Loss_res: 2.432e+03 ,Time: 0.00
# Compute NTK...
# It: 11600, Loss: 2.465e+03, Loss_bcs: 5.883e+01, Loss_res: 2.406e+03 ,Time: 0.00
# Compute NTK...
# It: 11700, Loss: 2.440e+03, Loss_bcs: 5.926e+01, Loss_res: 2.381e+03 ,Time: 0.00
# Compute NTK...
# It: 11800, Loss: 2.415e+03, Loss_bcs: 5.969e+01, Loss_res: 2.356e+03 ,Time: 0.00
# Compute NTK...
# It: 11900, Loss: 2.391e+03, Loss_bcs: 6.011e+01, Loss_res: 2.331e+03 ,Time: 0.00
# Compute NTK...
# It: 12000, Loss: 2.367e+03, Loss_bcs: 6.053e+01, Loss_res: 2.307e+03 ,Time: 0.00
# Compute NTK...
# It: 12100, Loss: 2.344e+03, Loss_bcs: 6.095e+01, Loss_res: 2.283e+03 ,Time: 0.00
# Compute NTK...
# It: 12200, Loss: 2.321e+03, Loss_bcs: 6.136e+01, Loss_res: 2.260e+03 ,Time: 0.00
# Compute NTK...
# It: 12300, Loss: 2.299e+03, Loss_bcs: 6.177e+01, Loss_res: 2.237e+03 ,Time: 0.00
# Compute NTK...
# It: 12400, Loss: 2.277e+03, Loss_bcs: 6.217e+01, Loss_res: 2.214e+03 ,Time: 0.00
# Compute NTK...
# It: 12500, Loss: 2.255e+03, Loss_bcs: 6.257e+01, Loss_res: 2.192e+03 ,Time: 0.00
# Compute NTK...
# It: 12600, Loss: 2.234e+03, Loss_bcs: 6.297e+01, Loss_res: 2.171e+03 ,Time: 0.00
# Compute NTK...
# It: 12700, Loss: 2.213e+03, Loss_bcs: 6.336e+01, Loss_res: 2.149e+03 ,Time: 0.00
# Compute NTK...
# It: 12800, Loss: 2.192e+03, Loss_bcs: 6.375e+01, Loss_res: 2.128e+03 ,Time: 0.00
# Compute NTK...
# It: 12900, Loss: 2.172e+03, Loss_bcs: 6.414e+01, Loss_res: 2.108e+03 ,Time: 0.00
# Compute NTK...
# It: 13000, Loss: 2.152e+03, Loss_bcs: 6.452e+01, Loss_res: 2.087e+03 ,Time: 0.00
# Compute NTK...
# It: 13100, Loss: 2.132e+03, Loss_bcs: 6.489e+01, Loss_res: 2.067e+03 ,Time: 0.00
# Compute NTK...
# It: 13200, Loss: 2.113e+03, Loss_bcs: 6.527e+01, Loss_res: 2.048e+03 ,Time: 0.00
# Compute NTK...
# It: 13300, Loss: 2.094e+03, Loss_bcs: 6.564e+01, Loss_res: 2.028e+03 ,Time: 0.00
# Compute NTK...
# It: 13400, Loss: 2.075e+03, Loss_bcs: 6.600e+01, Loss_res: 2.009e+03 ,Time: 0.00
# Compute NTK...
# It: 13500, Loss: 2.057e+03, Loss_bcs: 6.636e+01, Loss_res: 1.991e+03 ,Time: 0.00
# Compute NTK...
# It: 13600, Loss: 2.039e+03, Loss_bcs: 6.672e+01, Loss_res: 1.972e+03 ,Time: 0.00
# Compute NTK...
# It: 13700, Loss: 2.022e+03, Loss_bcs: 6.708e+01, Loss_res: 1.954e+03 ,Time: 0.00
# Compute NTK...
# It: 13800, Loss: 2.004e+03, Loss_bcs: 6.743e+01, Loss_res: 1.937e+03 ,Time: 0.00
# Compute NTK...
# It: 13900, Loss: 1.987e+03, Loss_bcs: 6.777e+01, Loss_res: 1.919e+03 ,Time: 0.00
# Compute NTK...
# It: 14000, Loss: 1.970e+03, Loss_bcs: 6.812e+01, Loss_res: 1.902e+03 ,Time: 0.00
# Compute NTK...
# It: 14100, Loss: 1.954e+03, Loss_bcs: 6.846e+01, Loss_res: 1.886e+03 ,Time: 0.00
# Compute NTK...
# It: 14200, Loss: 1.938e+03, Loss_bcs: 6.879e+01, Loss_res: 1.869e+03 ,Time: 0.00
# Compute NTK...
# It: 14300, Loss: 1.922e+03, Loss_bcs: 6.912e+01, Loss_res: 1.853e+03 ,Time: 0.00
# Compute NTK...
# It: 14400, Loss: 1.906e+03, Loss_bcs: 6.945e+01, Loss_res: 1.837e+03 ,Time: 0.00
# Compute NTK...
# It: 14500, Loss: 1.891e+03, Loss_bcs: 6.978e+01, Loss_res: 1.821e+03 ,Time: 0.00
# Compute NTK...
# It: 14600, Loss: 1.876e+03, Loss_bcs: 7.010e+01, Loss_res: 1.806e+03 ,Time: 0.00
# Compute NTK...
# It: 14700, Loss: 1.861e+03, Loss_bcs: 7.041e+01, Loss_res: 1.791e+03 ,Time: 0.00
# Compute NTK...
# It: 14800, Loss: 1.846e+03, Loss_bcs: 7.073e+01, Loss_res: 1.776e+03 ,Time: 0.00
# Compute NTK...
# It: 14900, Loss: 1.832e+03, Loss_bcs: 7.104e+01, Loss_res: 1.761e+03 ,Time: 0.00
# Compute NTK...
# It: 15000, Loss: 1.818e+03, Loss_bcs: 7.135e+01, Loss_res: 1.747e+03 ,Time: 0.00
# Compute NTK...
# It: 15100, Loss: 1.804e+03, Loss_bcs: 7.165e+01, Loss_res: 1.733e+03 ,Time: 0.00
# Compute NTK...
# It: 15200, Loss: 1.791e+03, Loss_bcs: 7.195e+01, Loss_res: 1.719e+03 ,Time: 0.00
# Compute NTK...
# It: 15300, Loss: 1.777e+03, Loss_bcs: 7.224e+01, Loss_res: 1.705e+03 ,Time: 0.00
# Compute NTK...
# It: 15400, Loss: 1.764e+03, Loss_bcs: 7.254e+01, Loss_res: 1.692e+03 ,Time: 0.00
# Compute NTK...
# It: 15500, Loss: 1.751e+03, Loss_bcs: 7.283e+01, Loss_res: 1.678e+03 ,Time: 0.00
# Compute NTK...
# It: 15600, Loss: 1.738e+03, Loss_bcs: 7.311e+01, Loss_res: 1.665e+03 ,Time: 0.00
# Compute NTK...
# It: 15700, Loss: 1.726e+03, Loss_bcs: 7.339e+01, Loss_res: 1.653e+03 ,Time: 0.00
# Compute NTK...
# It: 15800, Loss: 1.714e+03, Loss_bcs: 7.367e+01, Loss_res: 1.640e+03 ,Time: 0.00
# Compute NTK...
# It: 15900, Loss: 1.702e+03, Loss_bcs: 7.395e+01, Loss_res: 1.628e+03 ,Time: 0.00
# Compute NTK...
# It: 16000, Loss: 1.690e+03, Loss_bcs: 7.422e+01, Loss_res: 1.615e+03 ,Time: 0.00
# Compute NTK...
# It: 16100, Loss: 1.678e+03, Loss_bcs: 7.449e+01, Loss_res: 1.604e+03 ,Time: 0.00
# Compute NTK...
# It: 16200, Loss: 1.667e+03, Loss_bcs: 7.475e+01, Loss_res: 1.592e+03 ,Time: 0.00
# Compute NTK...
# It: 16300, Loss: 1.655e+03, Loss_bcs: 7.501e+01, Loss_res: 1.580e+03 ,Time: 0.00
# Compute NTK...
# It: 16400, Loss: 1.644e+03, Loss_bcs: 7.527e+01, Loss_res: 1.569e+03 ,Time: 0.00
# Compute NTK...
# It: 16500, Loss: 1.633e+03, Loss_bcs: 7.552e+01, Loss_res: 1.558e+03 ,Time: 0.00
# Compute NTK...
# It: 16600, Loss: 1.623e+03, Loss_bcs: 7.577e+01, Loss_res: 1.547e+03 ,Time: 0.00
# Compute NTK...
# It: 16700, Loss: 1.612e+03, Loss_bcs: 7.602e+01, Loss_res: 1.536e+03 ,Time: 0.00
# Compute NTK...
# It: 16800, Loss: 1.602e+03, Loss_bcs: 7.626e+01, Loss_res: 1.525e+03 ,Time: 0.01
# Compute NTK...
# It: 16900, Loss: 1.591e+03, Loss_bcs: 7.650e+01, Loss_res: 1.515e+03 ,Time: 0.00
# Compute NTK...
# It: 17000, Loss: 1.581e+03, Loss_bcs: 7.673e+01, Loss_res: 1.505e+03 ,Time: 0.00
# Compute NTK...
# It: 17100, Loss: 1.571e+03, Loss_bcs: 7.697e+01, Loss_res: 1.495e+03 ,Time: 0.00
# Compute NTK...
# It: 17200, Loss: 1.562e+03, Loss_bcs: 7.720e+01, Loss_res: 1.485e+03 ,Time: 0.00
# Compute NTK...
# It: 17300, Loss: 1.552e+03, Loss_bcs: 7.743e+01, Loss_res: 1.475e+03 ,Time: 0.00
# Compute NTK...
# It: 17400, Loss: 1.543e+03, Loss_bcs: 7.765e+01, Loss_res: 1.465e+03 ,Time: 0.00
# Compute NTK...
# It: 17500, Loss: 1.534e+03, Loss_bcs: 7.787e+01, Loss_res: 1.456e+03 ,Time: 0.00
# Compute NTK...
# It: 17600, Loss: 1.525e+03, Loss_bcs: 7.809e+01, Loss_res: 1.446e+03 ,Time: 0.00
# Compute NTK...
# It: 17700, Loss: 1.516e+03, Loss_bcs: 7.831e+01, Loss_res: 1.437e+03 ,Time: 0.00
# Compute NTK...
# It: 17800, Loss: 1.507e+03, Loss_bcs: 7.852e+01, Loss_res: 1.428e+03 ,Time: 0.00
# Compute NTK...
# It: 17900, Loss: 1.498e+03, Loss_bcs: 7.873e+01, Loss_res: 1.420e+03 ,Time: 0.00
# Compute NTK...
# It: 18000, Loss: 1.490e+03, Loss_bcs: 7.894e+01, Loss_res: 1.411e+03 ,Time: 0.00
# Compute NTK...
# It: 18100, Loss: 1.481e+03, Loss_bcs: 7.915e+01, Loss_res: 1.402e+03 ,Time: 0.00
# Compute NTK...
# It: 18200, Loss: 1.473e+03, Loss_bcs: 7.935e+01, Loss_res: 1.394e+03 ,Time: 0.00
# Compute NTK...
# It: 18300, Loss: 1.465e+03, Loss_bcs: 7.955e+01, Loss_res: 1.386e+03 ,Time: 0.00
# Compute NTK...
# It: 18400, Loss: 1.457e+03, Loss_bcs: 7.975e+01, Loss_res: 1.377e+03 ,Time: 0.00
# Compute NTK...
# It: 18500, Loss: 1.449e+03, Loss_bcs: 7.994e+01, Loss_res: 1.369e+03 ,Time: 0.00
# Compute NTK...
# It: 18600, Loss: 1.442e+03, Loss_bcs: 8.014e+01, Loss_res: 1.362e+03 ,Time: 0.00
# Compute NTK...
# It: 18700, Loss: 1.434e+03, Loss_bcs: 8.033e+01, Loss_res: 1.354e+03 ,Time: 0.00
# Compute NTK...
# It: 18800, Loss: 1.427e+03, Loss_bcs: 8.051e+01, Loss_res: 1.346e+03 ,Time: 0.00
# Compute NTK...
# It: 18900, Loss: 1.419e+03, Loss_bcs: 8.070e+01, Loss_res: 1.339e+03 ,Time: 0.00
# Compute NTK...
# It: 19000, Loss: 1.412e+03, Loss_bcs: 8.088e+01, Loss_res: 1.331e+03 ,Time: 0.00
# Compute NTK...
# It: 19100, Loss: 1.405e+03, Loss_bcs: 8.106e+01, Loss_res: 1.324e+03 ,Time: 0.00
# Compute NTK...
# It: 19200, Loss: 1.398e+03, Loss_bcs: 8.123e+01, Loss_res: 1.317e+03 ,Time: 0.00
# Compute NTK...
# It: 19300, Loss: 1.391e+03, Loss_bcs: 8.141e+01, Loss_res: 1.310e+03 ,Time: 0.00
# Compute NTK...
# It: 19400, Loss: 1.384e+03, Loss_bcs: 8.158e+01, Loss_res: 1.303e+03 ,Time: 0.00
# Compute NTK...
# It: 19500, Loss: 1.378e+03, Loss_bcs: 8.175e+01, Loss_res: 1.296e+03 ,Time: 0.00
# Compute NTK...
# It: 19600, Loss: 1.371e+03, Loss_bcs: 8.191e+01, Loss_res: 1.289e+03 ,Time: 0.00
# Compute NTK...
# It: 19700, Loss: 1.365e+03, Loss_bcs: 8.208e+01, Loss_res: 1.283e+03 ,Time: 0.00
# Compute NTK...
# It: 19800, Loss: 1.359e+03, Loss_bcs: 8.224e+01, Loss_res: 1.276e+03 ,Time: 0.00
# Compute NTK...
# It: 19900, Loss: 1.352e+03, Loss_bcs: 8.240e+01, Loss_res: 1.270e+03 ,Time: 0.00
# Compute NTK...
# It: 20000, Loss: 1.346e+03, Loss_bcs: 8.255e+01, Loss_res: 1.264e+03 ,Time: 0.00
# Compute NTK...
# It: 20100, Loss: 1.340e+03, Loss_bcs: 8.270e+01, Loss_res: 1.257e+03 ,Time: 0.00
# Compute NTK...
# It: 20200, Loss: 1.334e+03, Loss_bcs: 8.285e+01, Loss_res: 1.251e+03 ,Time: 0.00
# Compute NTK...
# It: 20300, Loss: 1.328e+03, Loss_bcs: 8.300e+01, Loss_res: 1.245e+03 ,Time: 0.00
# Compute NTK...
# It: 20400, Loss: 1.323e+03, Loss_bcs: 8.315e+01, Loss_res: 1.239e+03 ,Time: 0.00
# Compute NTK...
# It: 20500, Loss: 1.317e+03, Loss_bcs: 8.329e+01, Loss_res: 1.234e+03 ,Time: 0.00
# Compute NTK...
# It: 20600, Loss: 1.311e+03, Loss_bcs: 8.343e+01, Loss_res: 1.228e+03 ,Time: 0.00
# Compute NTK...
# It: 20700, Loss: 1.306e+03, Loss_bcs: 8.357e+01, Loss_res: 1.222e+03 ,Time: 0.00
# Compute NTK...
# It: 20800, Loss: 1.301e+03, Loss_bcs: 8.370e+01, Loss_res: 1.217e+03 ,Time: 0.00
# Compute NTK...
# It: 20900, Loss: 1.295e+03, Loss_bcs: 8.384e+01, Loss_res: 1.211e+03 ,Time: 0.00
# Compute NTK...
# It: 21000, Loss: 1.290e+03, Loss_bcs: 8.397e+01, Loss_res: 1.206e+03 ,Time: 0.00
# Compute NTK...
# It: 21100, Loss: 1.285e+03, Loss_bcs: 8.410e+01, Loss_res: 1.201e+03 ,Time: 0.00
# Compute NTK...
# It: 21200, Loss: 1.280e+03, Loss_bcs: 8.422e+01, Loss_res: 1.196e+03 ,Time: 0.00
# Compute NTK...
# It: 21300, Loss: 1.275e+03, Loss_bcs: 8.435e+01, Loss_res: 1.190e+03 ,Time: 0.00
# Compute NTK...
# It: 21400, Loss: 1.270e+03, Loss_bcs: 8.447e+01, Loss_res: 1.185e+03 ,Time: 0.00
# Compute NTK...
# It: 21500, Loss: 1.265e+03, Loss_bcs: 8.459e+01, Loss_res: 1.180e+03 ,Time: 0.00
# Compute NTK...
# It: 21600, Loss: 1.260e+03, Loss_bcs: 8.471e+01, Loss_res: 1.176e+03 ,Time: 0.00
# Compute NTK...
# It: 21700, Loss: 1.256e+03, Loss_bcs: 8.483e+01, Loss_res: 1.171e+03 ,Time: 0.00
# Compute NTK...
# It: 21800, Loss: 1.251e+03, Loss_bcs: 8.494e+01, Loss_res: 1.166e+03 ,Time: 0.00
# Compute NTK...
# It: 21900, Loss: 1.246e+03, Loss_bcs: 8.506e+01, Loss_res: 1.161e+03 ,Time: 0.00
# Compute NTK...
# It: 22000, Loss: 1.242e+03, Loss_bcs: 8.517e+01, Loss_res: 1.157e+03 ,Time: 0.00
# Compute NTK...
# It: 22100, Loss: 1.238e+03, Loss_bcs: 8.528e+01, Loss_res: 1.152e+03 ,Time: 0.00
# Compute NTK...
# It: 22200, Loss: 1.233e+03, Loss_bcs: 8.539e+01, Loss_res: 1.148e+03 ,Time: 0.00
# Compute NTK...
# It: 22300, Loss: 1.229e+03, Loss_bcs: 8.549e+01, Loss_res: 1.143e+03 ,Time: 0.00
# Compute NTK...
# It: 22400, Loss: 1.225e+03, Loss_bcs: 8.560e+01, Loss_res: 1.139e+03 ,Time: 0.00
# Compute NTK...
# It: 22500, Loss: 1.221e+03, Loss_bcs: 8.570e+01, Loss_res: 1.135e+03 ,Time: 0.00
# Compute NTK...
# It: 22600, Loss: 1.216e+03, Loss_bcs: 8.580e+01, Loss_res: 1.131e+03 ,Time: 0.00
# Compute NTK...
# It: 22700, Loss: 1.212e+03, Loss_bcs: 8.590e+01, Loss_res: 1.127e+03 ,Time: 0.00
# Compute NTK...
# It: 22800, Loss: 1.208e+03, Loss_bcs: 8.600e+01, Loss_res: 1.122e+03 ,Time: 0.00
# Compute NTK...
# It: 22900, Loss: 1.205e+03, Loss_bcs: 8.609e+01, Loss_res: 1.119e+03 ,Time: 0.00
# Compute NTK...
# It: 23000, Loss: 1.201e+03, Loss_bcs: 8.619e+01, Loss_res: 1.115e+03 ,Time: 0.00
# Compute NTK...
# It: 23100, Loss: 1.197e+03, Loss_bcs: 8.628e+01, Loss_res: 1.111e+03 ,Time: 0.00
# Compute NTK...
# It: 23200, Loss: 1.193e+03, Loss_bcs: 8.637e+01, Loss_res: 1.107e+03 ,Time: 0.00
# Compute NTK...
# It: 23300, Loss: 1.190e+03, Loss_bcs: 8.646e+01, Loss_res: 1.103e+03 ,Time: 0.00
# Compute NTK...
# It: 23400, Loss: 1.186e+03, Loss_bcs: 8.655e+01, Loss_res: 1.099e+03 ,Time: 0.00
# Compute NTK...
# It: 23500, Loss: 1.182e+03, Loss_bcs: 8.664e+01, Loss_res: 1.096e+03 ,Time: 0.00
# Compute NTK...
# It: 23600, Loss: 1.179e+03, Loss_bcs: 8.672e+01, Loss_res: 1.092e+03 ,Time: 0.00
# Compute NTK...
# It: 23700, Loss: 1.175e+03, Loss_bcs: 8.681e+01, Loss_res: 1.089e+03 ,Time: 0.00
# Compute NTK...
# It: 23800, Loss: 1.172e+03, Loss_bcs: 8.689e+01, Loss_res: 1.085e+03 ,Time: 0.00
# Compute NTK...
# It: 23900, Loss: 1.169e+03, Loss_bcs: 8.697e+01, Loss_res: 1.082e+03 ,Time: 0.00
# Compute NTK...
# It: 24000, Loss: 1.165e+03, Loss_bcs: 8.705e+01, Loss_res: 1.078e+03 ,Time: 0.00
# Compute NTK...
# It: 24100, Loss: 1.162e+03, Loss_bcs: 8.712e+01, Loss_res: 1.075e+03 ,Time: 0.00
# Compute NTK...
# It: 24200, Loss: 1.159e+03, Loss_bcs: 8.720e+01, Loss_res: 1.072e+03 ,Time: 0.00
# Compute NTK...
# It: 24300, Loss: 1.156e+03, Loss_bcs: 8.727e+01, Loss_res: 1.069e+03 ,Time: 0.00
# Compute NTK...
# It: 24400, Loss: 1.153e+03, Loss_bcs: 8.734e+01, Loss_res: 1.065e+03 ,Time: 0.00
# Compute NTK...
# It: 24500, Loss: 1.150e+03, Loss_bcs: 8.741e+01, Loss_res: 1.062e+03 ,Time: 0.00
# Compute NTK...
# It: 24600, Loss: 1.147e+03, Loss_bcs: 8.748e+01, Loss_res: 1.059e+03 ,Time: 0.00
# Compute NTK...
# It: 24700, Loss: 1.144e+03, Loss_bcs: 8.754e+01, Loss_res: 1.056e+03 ,Time: 0.00
# Compute NTK...
# It: 24800, Loss: 1.141e+03, Loss_bcs: 8.761e+01, Loss_res: 1.053e+03 ,Time: 0.00
# Compute NTK...
# It: 24900, Loss: 1.138e+03, Loss_bcs: 8.767e+01, Loss_res: 1.050e+03 ,Time: 0.00
# Compute NTK...
# It: 25000, Loss: 1.135e+03, Loss_bcs: 8.773e+01, Loss_res: 1.047e+03 ,Time: 0.00
# Compute NTK...
# It: 25100, Loss: 1.132e+03, Loss_bcs: 8.780e+01, Loss_res: 1.044e+03 ,Time: 0.00
# Compute NTK...
# It: 25200, Loss: 1.129e+03, Loss_bcs: 8.786e+01, Loss_res: 1.041e+03 ,Time: 0.00
# Compute NTK...
# It: 25300, Loss: 1.127e+03, Loss_bcs: 8.791e+01, Loss_res: 1.039e+03 ,Time: 0.00
# Compute NTK...
# It: 25400, Loss: 1.124e+03, Loss_bcs: 8.797e+01, Loss_res: 1.036e+03 ,Time: 0.00
# Compute NTK...
# It: 25500, Loss: 1.121e+03, Loss_bcs: 8.803e+01, Loss_res: 1.033e+03 ,Time: 0.00
# Compute NTK...
# It: 25600, Loss: 1.119e+03, Loss_bcs: 8.808e+01, Loss_res: 1.030e+03 ,Time: 0.00
# Compute NTK...
# It: 25700, Loss: 1.116e+03, Loss_bcs: 8.814e+01, Loss_res: 1.028e+03 ,Time: 0.00
# Compute NTK...
# It: 25800, Loss: 1.113e+03, Loss_bcs: 8.819e+01, Loss_res: 1.025e+03 ,Time: 0.00
# Compute NTK...
# It: 25900, Loss: 1.111e+03, Loss_bcs: 8.824e+01, Loss_res: 1.023e+03 ,Time: 0.00
# Compute NTK...
# It: 26000, Loss: 1.109e+03, Loss_bcs: 8.829e+01, Loss_res: 1.020e+03 ,Time: 0.00
# Compute NTK...
# It: 26100, Loss: 1.106e+03, Loss_bcs: 8.834e+01, Loss_res: 1.018e+03 ,Time: 0.00
# Compute NTK...
# It: 26200, Loss: 1.104e+03, Loss_bcs: 8.839e+01, Loss_res: 1.015e+03 ,Time: 0.00
# Compute NTK...
# It: 26300, Loss: 1.101e+03, Loss_bcs: 8.844e+01, Loss_res: 1.013e+03 ,Time: 0.00
# Compute NTK...
# It: 26400, Loss: 1.099e+03, Loss_bcs: 8.849e+01, Loss_res: 1.011e+03 ,Time: 0.00
# Compute NTK...
# It: 26500, Loss: 1.097e+03, Loss_bcs: 8.853e+01, Loss_res: 1.008e+03 ,Time: 0.00
# Compute NTK...
# It: 26600, Loss: 1.094e+03, Loss_bcs: 8.858e+01, Loss_res: 1.006e+03 ,Time: 0.00
# Compute NTK...
# It: 26700, Loss: 1.092e+03, Loss_bcs: 8.863e+01, Loss_res: 1.004e+03 ,Time: 0.00
# Compute NTK...
# It: 26800, Loss: 1.090e+03, Loss_bcs: 8.867e+01, Loss_res: 1.001e+03 ,Time: 0.00
# Compute NTK...
# It: 26900, Loss: 1.088e+03, Loss_bcs: 8.872e+01, Loss_res: 9.991e+02 ,Time: 0.00
# Compute NTK...
# It: 27000, Loss: 1.086e+03, Loss_bcs: 8.876e+01, Loss_res: 9.969e+02 ,Time: 0.00
# Compute NTK...
# It: 27100, Loss: 1.083e+03, Loss_bcs: 8.881e+01, Loss_res: 9.947e+02 ,Time: 0.00
# Compute NTK...
# It: 27200, Loss: 1.081e+03, Loss_bcs: 8.885e+01, Loss_res: 9.925e+02 ,Time: 0.00
# Compute NTK...
# It: 27300, Loss: 1.079e+03, Loss_bcs: 8.889e+01, Loss_res: 9.904e+02 ,Time: 0.00
# Compute NTK...
# It: 27400, Loss: 1.077e+03, Loss_bcs: 8.893e+01, Loss_res: 9.883e+02 ,Time: 0.00
# Compute NTK...
# It: 27500, Loss: 1.075e+03, Loss_bcs: 8.897e+01, Loss_res: 9.863e+02 ,Time: 0.00
# Compute NTK...
# It: 27600, Loss: 1.073e+03, Loss_bcs: 8.901e+01, Loss_res: 9.843e+02 ,Time: 0.00
# Compute NTK...
# It: 27700, Loss: 1.071e+03, Loss_bcs: 8.905e+01, Loss_res: 9.823e+02 ,Time: 0.00
# Compute NTK...
# It: 27800, Loss: 1.069e+03, Loss_bcs: 8.909e+01, Loss_res: 9.804e+02 ,Time: 0.00
# Compute NTK...
# It: 27900, Loss: 1.068e+03, Loss_bcs: 8.912e+01, Loss_res: 9.785e+02 ,Time: 0.00
# Compute NTK...
# It: 28000, Loss: 1.066e+03, Loss_bcs: 8.916e+01, Loss_res: 9.766e+02 ,Time: 0.00
# Compute NTK...
# It: 28100, Loss: 1.064e+03, Loss_bcs: 8.919e+01, Loss_res: 9.747e+02 ,Time: 0.00
# Compute NTK...
# It: 28200, Loss: 1.062e+03, Loss_bcs: 8.923e+01, Loss_res: 9.729e+02 ,Time: 0.00
# Compute NTK...
# It: 28300, Loss: 1.060e+03, Loss_bcs: 8.926e+01, Loss_res: 9.711e+02 ,Time: 0.00
# Compute NTK...
# It: 28400, Loss: 1.059e+03, Loss_bcs: 8.930e+01, Loss_res: 9.693e+02 ,Time: 0.00
# Compute NTK...
# It: 28500, Loss: 1.057e+03, Loss_bcs: 8.933e+01, Loss_res: 9.675e+02 ,Time: 0.00
# Compute NTK...
# It: 28600, Loss: 1.055e+03, Loss_bcs: 8.936e+01, Loss_res: 9.658e+02 ,Time: 0.00
# Compute NTK...
# It: 28700, Loss: 1.053e+03, Loss_bcs: 8.939e+01, Loss_res: 9.640e+02 ,Time: 0.00
# Compute NTK...
# It: 28800, Loss: 1.052e+03, Loss_bcs: 8.942e+01, Loss_res: 9.623e+02 ,Time: 0.00
# Compute NTK...
# It: 28900, Loss: 1.050e+03, Loss_bcs: 8.945e+01, Loss_res: 9.606e+02 ,Time: 0.00
# Compute NTK...
# It: 29000, Loss: 1.048e+03, Loss_bcs: 8.948e+01, Loss_res: 9.590e+02 ,Time: 0.00
# Compute NTK...
# It: 29100, Loss: 1.047e+03, Loss_bcs: 8.951e+01, Loss_res: 9.573e+02 ,Time: 0.00
# Compute NTK...
# It: 29200, Loss: 1.045e+03, Loss_bcs: 8.954e+01, Loss_res: 9.557e+02 ,Time: 0.00
# Compute NTK...
# It: 29300, Loss: 1.044e+03, Loss_bcs: 8.957e+01, Loss_res: 9.541e+02 ,Time: 0.00
# Compute NTK...
# It: 29400, Loss: 1.042e+03, Loss_bcs: 8.959e+01, Loss_res: 9.525e+02 ,Time: 0.00
# Compute NTK...
# It: 29500, Loss: 1.041e+03, Loss_bcs: 8.962e+01, Loss_res: 9.509e+02 ,Time: 0.00
# Compute NTK...
# It: 29600, Loss: 1.039e+03, Loss_bcs: 8.964e+01, Loss_res: 9.494e+02 ,Time: 0.00
# Compute NTK...
# It: 29700, Loss: 1.038e+03, Loss_bcs: 8.967e+01, Loss_res: 9.478e+02 ,Time: 0.00
# Compute NTK...
# It: 29800, Loss: 1.036e+03, Loss_bcs: 8.969e+01, Loss_res: 9.463e+02 ,Time: 0.00
# Compute NTK...
# It: 29900, Loss: 1.035e+03, Loss_bcs: 8.972e+01, Loss_res: 9.448e+02 ,Time: 0.00
# Compute NTK...
# It: 30000, Loss: 1.033e+03, Loss_bcs: 8.974e+01, Loss_res: 9.434e+02 ,Time: 0.00
# Compute NTK...
# It: 30100, Loss: 1.032e+03, Loss_bcs: 8.976e+01, Loss_res: 9.420e+02 ,Time: 0.00
# Compute NTK...
# It: 30200, Loss: 1.030e+03, Loss_bcs: 8.978e+01, Loss_res: 9.406e+02 ,Time: 0.00
# Compute NTK...
# It: 30300, Loss: 1.029e+03, Loss_bcs: 8.980e+01, Loss_res: 9.392e+02 ,Time: 0.00
# Compute NTK...
# It: 30400, Loss: 1.028e+03, Loss_bcs: 8.982e+01, Loss_res: 9.378e+02 ,Time: 0.00
# Compute NTK...
# It: 30500, Loss: 1.026e+03, Loss_bcs: 8.984e+01, Loss_res: 9.365e+02 ,Time: 0.00
# Compute NTK...
# It: 30600, Loss: 1.025e+03, Loss_bcs: 8.986e+01, Loss_res: 9.352e+02 ,Time: 0.00
# Compute NTK...
# It: 30700, Loss: 1.024e+03, Loss_bcs: 8.988e+01, Loss_res: 9.339e+02 ,Time: 0.00
# Compute NTK...
# It: 30800, Loss: 1.022e+03, Loss_bcs: 8.990e+01, Loss_res: 9.326e+02 ,Time: 0.00
# Compute NTK...
# It: 30900, Loss: 1.021e+03, Loss_bcs: 8.992e+01, Loss_res: 9.313e+02 ,Time: 0.00
# Compute NTK...
# It: 31000, Loss: 1.020e+03, Loss_bcs: 8.994e+01, Loss_res: 9.301e+02 ,Time: 0.00
# Compute NTK...
# It: 31100, Loss: 1.019e+03, Loss_bcs: 8.996e+01, Loss_res: 9.288e+02 ,Time: 0.00
# Compute NTK...
# It: 31200, Loss: 1.018e+03, Loss_bcs: 8.997e+01, Loss_res: 9.276e+02 ,Time: 0.00
# Compute NTK...
# It: 31300, Loss: 1.016e+03, Loss_bcs: 8.999e+01, Loss_res: 9.263e+02 ,Time: 0.00
# Compute NTK...
# It: 31400, Loss: 1.015e+03, Loss_bcs: 9.001e+01, Loss_res: 9.251e+02 ,Time: 0.00
# Compute NTK...
# It: 31500, Loss: 1.014e+03, Loss_bcs: 9.003e+01, Loss_res: 9.240e+02 ,Time: 0.00
# Compute NTK...
# It: 31600, Loss: 1.013e+03, Loss_bcs: 9.005e+01, Loss_res: 9.228e+02 ,Time: 0.00
# Compute NTK...
# It: 31700, Loss: 1.012e+03, Loss_bcs: 9.006e+01, Loss_res: 9.216e+02 ,Time: 0.00
# Compute NTK...
# It: 31800, Loss: 1.011e+03, Loss_bcs: 9.008e+01, Loss_res: 9.205e+02 ,Time: 0.00
# Compute NTK...
# It: 31900, Loss: 1.009e+03, Loss_bcs: 9.010e+01, Loss_res: 9.193e+02 ,Time: 0.00
# Compute NTK...
# It: 32000, Loss: 1.008e+03, Loss_bcs: 9.011e+01, Loss_res: 9.182e+02 ,Time: 0.00
# Compute NTK...
# It: 32100, Loss: 1.007e+03, Loss_bcs: 9.013e+01, Loss_res: 9.171e+02 ,Time: 0.00
# Compute NTK...
# It: 32200, Loss: 1.006e+03, Loss_bcs: 9.015e+01, Loss_res: 9.160e+02 ,Time: 0.00
# Compute NTK...
# It: 32300, Loss: 1.005e+03, Loss_bcs: 9.016e+01, Loss_res: 9.149e+02 ,Time: 0.00
# Compute NTK...
# It: 32400, Loss: 1.004e+03, Loss_bcs: 9.018e+01, Loss_res: 9.138e+02 ,Time: 0.00
# Compute NTK...
# It: 32500, Loss: 1.003e+03, Loss_bcs: 9.019e+01, Loss_res: 9.128e+02 ,Time: 0.00
# Compute NTK...
# It: 32600, Loss: 1.002e+03, Loss_bcs: 9.021e+01, Loss_res: 9.117e+02 ,Time: 0.00
# Compute NTK...
# It: 32700, Loss: 1.001e+03, Loss_bcs: 9.022e+01, Loss_res: 9.107e+02 ,Time: 0.00
# Compute NTK...
# It: 32800, Loss: 9.999e+02, Loss_bcs: 9.024e+01, Loss_res: 9.097e+02 ,Time: 0.00
# Compute NTK...
# It: 32900, Loss: 9.989e+02, Loss_bcs: 9.025e+01, Loss_res: 9.086e+02 ,Time: 0.00
# Compute NTK...
# It: 33000, Loss: 9.979e+02, Loss_bcs: 9.027e+01, Loss_res: 9.076e+02 ,Time: 0.00
# Compute NTK...
# It: 33100, Loss: 9.969e+02, Loss_bcs: 9.028e+01, Loss_res: 9.067e+02 ,Time: 0.00
# Compute NTK...
# It: 33200, Loss: 9.960e+02, Loss_bcs: 9.030e+01, Loss_res: 9.057e+02 ,Time: 0.00
# Compute NTK...
# It: 33300, Loss: 9.951e+02, Loss_bcs: 9.031e+01, Loss_res: 9.048e+02 ,Time: 0.00
# Compute NTK...
# It: 33400, Loss: 9.942e+02, Loss_bcs: 9.032e+01, Loss_res: 9.039e+02 ,Time: 0.00
# Compute NTK...
# It: 33500, Loss: 9.933e+02, Loss_bcs: 9.033e+01, Loss_res: 9.030e+02 ,Time: 0.00
# Compute NTK...
# It: 33600, Loss: 9.924e+02, Loss_bcs: 9.035e+01, Loss_res: 9.021e+02 ,Time: 0.00
# Compute NTK...
# It: 33700, Loss: 9.916e+02, Loss_bcs: 9.036e+01, Loss_res: 9.012e+02 ,Time: 0.00
# Compute NTK...
# It: 33800, Loss: 9.907e+02, Loss_bcs: 9.037e+01, Loss_res: 9.003e+02 ,Time: 0.00
# Compute NTK...
# It: 33900, Loss: 9.899e+02, Loss_bcs: 9.038e+01, Loss_res: 8.995e+02 ,Time: 0.00
# Compute NTK...
# It: 34000, Loss: 9.890e+02, Loss_bcs: 9.039e+01, Loss_res: 8.986e+02 ,Time: 0.00
# Compute NTK...
# It: 34100, Loss: 9.882e+02, Loss_bcs: 9.041e+01, Loss_res: 8.978e+02 ,Time: 0.00
# Compute NTK...
# It: 34200, Loss: 9.874e+02, Loss_bcs: 9.042e+01, Loss_res: 8.970e+02 ,Time: 0.00
# Compute NTK...
# It: 34300, Loss: 9.866e+02, Loss_bcs: 9.043e+01, Loss_res: 8.962e+02 ,Time: 0.00
# Compute NTK...
# It: 34400, Loss: 9.858e+02, Loss_bcs: 9.044e+01, Loss_res: 8.954e+02 ,Time: 0.00
# Compute NTK...
# It: 34500, Loss: 9.850e+02, Loss_bcs: 9.045e+01, Loss_res: 8.946e+02 ,Time: 0.00
# Compute NTK...
# It: 34600, Loss: 9.842e+02, Loss_bcs: 9.046e+01, Loss_res: 8.938e+02 ,Time: 0.00
# Compute NTK...
# It: 34700, Loss: 9.835e+02, Loss_bcs: 9.047e+01, Loss_res: 8.930e+02 ,Time: 0.00
# Compute NTK...
# It: 34800, Loss: 9.827e+02, Loss_bcs: 9.048e+01, Loss_res: 8.922e+02 ,Time: 0.00
# Compute NTK...
# It: 34900, Loss: 9.819e+02, Loss_bcs: 9.049e+01, Loss_res: 8.915e+02 ,Time: 0.00
# Compute NTK...
# It: 35000, Loss: 9.812e+02, Loss_bcs: 9.050e+01, Loss_res: 8.907e+02 ,Time: 0.00
# Compute NTK...
# It: 35100, Loss: 9.805e+02, Loss_bcs: 9.051e+01, Loss_res: 8.899e+02 ,Time: 0.00
# Compute NTK...
# It: 35200, Loss: 9.797e+02, Loss_bcs: 9.052e+01, Loss_res: 8.892e+02 ,Time: 0.00
# Compute NTK...
# It: 35300, Loss: 9.790e+02, Loss_bcs: 9.053e+01, Loss_res: 8.885e+02 ,Time: 0.00
# Compute NTK...
# It: 35400, Loss: 9.783e+02, Loss_bcs: 9.054e+01, Loss_res: 8.877e+02 ,Time: 0.00
# Compute NTK...
# It: 35500, Loss: 9.776e+02, Loss_bcs: 9.055e+01, Loss_res: 8.870e+02 ,Time: 0.00
# Compute NTK...
# It: 35600, Loss: 9.769e+02, Loss_bcs: 9.055e+01, Loss_res: 8.863e+02 ,Time: 0.00
# Compute NTK...
# It: 35700, Loss: 9.762e+02, Loss_bcs: 9.056e+01, Loss_res: 8.856e+02 ,Time: 0.00
# Compute NTK...
# It: 35800, Loss: 9.755e+02, Loss_bcs: 9.057e+01, Loss_res: 8.849e+02 ,Time: 0.00
# Compute NTK...
# It: 35900, Loss: 9.748e+02, Loss_bcs: 9.058e+01, Loss_res: 8.842e+02 ,Time: 0.00
# Compute NTK...
# It: 36000, Loss: 9.741e+02, Loss_bcs: 9.059e+01, Loss_res: 8.835e+02 ,Time: 0.00
# Compute NTK...
# It: 36100, Loss: 9.734e+02, Loss_bcs: 9.059e+01, Loss_res: 8.828e+02 ,Time: 0.00
# Compute NTK...
# It: 36200, Loss: 9.728e+02, Loss_bcs: 9.060e+01, Loss_res: 8.822e+02 ,Time: 0.00
# Compute NTK...
# It: 36300, Loss: 9.721e+02, Loss_bcs: 9.061e+01, Loss_res: 8.815e+02 ,Time: 0.00
# Compute NTK...
# It: 36400, Loss: 9.714e+02, Loss_bcs: 9.062e+01, Loss_res: 8.808e+02 ,Time: 0.00
# Compute NTK...
# It: 36500, Loss: 9.708e+02, Loss_bcs: 9.062e+01, Loss_res: 8.802e+02 ,Time: 0.00
# Compute NTK...
# It: 36600, Loss: 9.702e+02, Loss_bcs: 9.063e+01, Loss_res: 8.795e+02 ,Time: 0.00
# Compute NTK...
# It: 36700, Loss: 9.695e+02, Loss_bcs: 9.063e+01, Loss_res: 8.789e+02 ,Time: 0.00
# Compute NTK...
# It: 36800, Loss: 9.689e+02, Loss_bcs: 9.064e+01, Loss_res: 8.783e+02 ,Time: 0.00
# Compute NTK...
# It: 36900, Loss: 9.683e+02, Loss_bcs: 9.065e+01, Loss_res: 8.776e+02 ,Time: 0.00
# Compute NTK...
# It: 37000, Loss: 9.677e+02, Loss_bcs: 9.065e+01, Loss_res: 8.770e+02 ,Time: 0.00
# Compute NTK...
# It: 37100, Loss: 9.671e+02, Loss_bcs: 9.066e+01, Loss_res: 8.764e+02 ,Time: 0.00
# Compute NTK...
# It: 37200, Loss: 9.665e+02, Loss_bcs: 9.066e+01, Loss_res: 8.758e+02 ,Time: 0.00
# Compute NTK...
# It: 37300, Loss: 9.659e+02, Loss_bcs: 9.067e+01, Loss_res: 8.752e+02 ,Time: 0.00
# Compute NTK...
# It: 37400, Loss: 9.653e+02, Loss_bcs: 9.067e+01, Loss_res: 8.746e+02 ,Time: 0.00
# Compute NTK...
# It: 37500, Loss: 9.647e+02, Loss_bcs: 9.068e+01, Loss_res: 8.740e+02 ,Time: 0.00
# Compute NTK...
# It: 37600, Loss: 9.641e+02, Loss_bcs: 9.068e+01, Loss_res: 8.735e+02 ,Time: 0.00
# Compute NTK...
# It: 37700, Loss: 9.636e+02, Loss_bcs: 9.068e+01, Loss_res: 8.729e+02 ,Time: 0.00
# Compute NTK...
# It: 37800, Loss: 9.630e+02, Loss_bcs: 9.069e+01, Loss_res: 8.723e+02 ,Time: 0.00
# Compute NTK...
# It: 37900, Loss: 9.624e+02, Loss_bcs: 9.069e+01, Loss_res: 8.717e+02 ,Time: 0.00
# Compute NTK...
# It: 38000, Loss: 9.619e+02, Loss_bcs: 9.070e+01, Loss_res: 8.712e+02 ,Time: 0.00
# Compute NTK...
# It: 38100, Loss: 9.614e+02, Loss_bcs: 9.070e+01, Loss_res: 8.706e+02 ,Time: 0.00
# Compute NTK...
# It: 38200, Loss: 9.609e+02, Loss_bcs: 9.071e+01, Loss_res: 8.701e+02 ,Time: 0.00
# Compute NTK...
# It: 38300, Loss: 9.604e+02, Loss_bcs: 9.071e+01, Loss_res: 8.697e+02 ,Time: 0.00
# Compute NTK...
# It: 38400, Loss: 9.599e+02, Loss_bcs: 9.071e+01, Loss_res: 8.692e+02 ,Time: 0.00
# Compute NTK...
# It: 38500, Loss: 9.594e+02, Loss_bcs: 9.072e+01, Loss_res: 8.687e+02 ,Time: 0.00
# Compute NTK...
# It: 38600, Loss: 9.589e+02, Loss_bcs: 9.072e+01, Loss_res: 8.682e+02 ,Time: 0.00
# Compute NTK...
# It: 38700, Loss: 9.585e+02, Loss_bcs: 9.072e+01, Loss_res: 8.678e+02 ,Time: 0.00
# Compute NTK...
# It: 38800, Loss: 9.580e+02, Loss_bcs: 9.073e+01, Loss_res: 8.673e+02 ,Time: 0.00
# Compute NTK...
# It: 38900, Loss: 9.576e+02, Loss_bcs: 9.073e+01, Loss_res: 8.668e+02 ,Time: 0.00
# Compute NTK...
# It: 39000, Loss: 9.571e+02, Loss_bcs: 9.073e+01, Loss_res: 8.664e+02 ,Time: 0.00
# Compute NTK...
# It: 39100, Loss: 9.567e+02, Loss_bcs: 9.074e+01, Loss_res: 8.659e+02 ,Time: 0.00
# Compute NTK...
# It: 39200, Loss: 9.562e+02, Loss_bcs: 9.074e+01, Loss_res: 8.655e+02 ,Time: 0.00
# Compute NTK...
# It: 39300, Loss: 9.558e+02, Loss_bcs: 9.074e+01, Loss_res: 8.650e+02 ,Time: 0.00
# Compute NTK...
# It: 39400, Loss: 9.554e+02, Loss_bcs: 9.075e+01, Loss_res: 8.646e+02 ,Time: 0.00
# Compute NTK...
# It: 39500, Loss: 9.549e+02, Loss_bcs: 9.075e+01, Loss_res: 8.642e+02 ,Time: 0.00
# Compute NTK...
# It: 39600, Loss: 9.545e+02, Loss_bcs: 9.075e+01, Loss_res: 8.637e+02 ,Time: 0.00
# Compute NTK...
# It: 39700, Loss: 9.541e+02, Loss_bcs: 9.076e+01, Loss_res: 8.633e+02 ,Time: 0.00
# Compute NTK...
# It: 39800, Loss: 9.537e+02, Loss_bcs: 9.076e+01, Loss_res: 8.629e+02 ,Time: 0.00
# Compute NTK...
# It: 39900, Loss: 9.533e+02, Loss_bcs: 9.076e+01, Loss_res: 8.625e+02 ,Time: 0.00
# Compute NTK...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 9.528e+02, Loss_bcs: 9.076e+01, Loss_res: 8.621e+02 ,Time: 0.27
# Compute NTK...
# Save uv NN parameters successfully in %s ...checkpoints/Dec-08-2023_20-23-26-911266_M1
# Final loss total loss: 9.528492e+02
# Final loss loss_res: 8.620845e+02
# Final loss loss_bcs: 9.076469e+01
# elapsed: 7.55e+01
# Relative L2 error_u: 7.56e+00
# Relative L2 error_r: 2.54e-01
# elapsed: 7.55e+01
# Relative L2 error_u: 7.56e+00
# Relative L2 error_v: 2.54e-01
#
#
# Method:  mini_batch
#
# average of time_list: 75.49032640457153
# average of error_u_list: 7.556735152809954
# average of error_v_list: 0.25398174051305994

# %%
# Define model
layers = [1, 512, 1]  
# layers = [1, 512, 512, 512, 1]

# %%
loss_bcs = model.loss_bcs_log
loss_res = model.loss_res_log

fig = plt.figure(figsize=(6,5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{b}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
# Out:
# Relative L2 error_u: 3.05e-02
# Relative L2 error_r: 4.16e-03

# %% [markdown]
# **NTK Eigenvalues**

# %% [markdown]
# **Change of NTK**

# %%
# Change of the NTK
NTK_change_list = []
K0 = K_list[0]
for K in K_list:
    diff = np.linalg.norm(K - K0) / np.linalg.norm(K0) 
    NTK_change_list.append(diff)

# %%
fig = plt.figure(figsize=(6,5))
plt.plot(NTK_change_list)

# %% [markdown]
# **Change of NN Params**

# %%
# Change of the weights and biases
def compute_weights_diff(weights_1, weights_2):
    weights = []
    N = len(weights_1)
    for k in range(N):
        weight = weights_1[k] - weights_2[k]
        weights.append(weight)
    return weights

def compute_weights_norm(weights, biases):
    norm = 0
    for w in weights:
        norm = norm + np.sum(np.square(w))
    for b in biases:
        norm = norm + np.sum(np.square(b))
    norm = np.sqrt(norm)
    return norm

# Restore the list weights and biases
weights_log = model.weights_log
biases_log = model.biases_log

weights_0 = weights_log[0]
biases_0 = biases_log[0]

# Norm of the weights at initialization
weights_init_norm = compute_weights_norm(weights_0, biases_0)

weights_change_list = []

N = len(weights_log)
for k in range(N):
    weights_diff = compute_weights_diff(weights_log[k], weights_log[0])
    biases_diff = compute_weights_diff(biases_log[k], biases_log[0])
    
    weights_diff_norm = compute_weights_norm(weights_diff, biases_diff)
    weights_change = weights_diff_norm / weights_init_norm
    weights_change_list.append(weights_change)

# %%
fig = plt.figure(figsize=(6,5))
plt.plot(weights_change_list)
