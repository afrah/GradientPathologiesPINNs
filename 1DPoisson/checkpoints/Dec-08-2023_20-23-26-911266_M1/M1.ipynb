# %%
# # Switch to tensorflow 1.x
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time
import logging

import os.path
import shutil
from datetime import datetime
import pickle

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# %%
class PINN:
    def __init__(self, layers, X_u, Y_u, X_r, Y_r ,mode ,  sess):


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        self.mu_X, self.sigma_X = X_r.mean(0), X_r.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]

        # Normalize
        self.X_u = (X_u - self.mu_X) / self.sigma_X
        self.Y_u = Y_u
        self.X_r = (X_r - self.mu_X) / self.sigma_X
        self.Y_r = Y_r

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
            
        # Define the size of the Kernel
        self.kernel_size = X_u.shape[0]
        # Define Tensorflow session
        self.sess = sess# tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_bc_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.x_u_ntk_tf = tf.placeholder(tf.float32, shape=(self.kernel_size, 1))
        self.x_r_ntk_tf = tf.placeholder(tf.float32, shape=(self.kernel_size, 1))


        # Evaluate predictions
        self.u_bc_pred = self.net_u(self.x_bc_tf)

        self.u_pred = self.net_u(self.x_u_tf)
        self.r_pred = self.net_r(self.x_r_tf)
        
        self.u_ntk_pred = self.net_u(self.x_u_ntk_tf)
        self.r_ntk_pred = self.net_r(self.x_r_ntk_tf)
     
        # Boundary loss
        self.loss_bcs = tf.reduce_mean(tf.square(self.u_bc_pred - self.u_bc_tf))

        # Residual loss        
        self.loss_res =  tf.reduce_mean(tf.square(self.r_tf - self.r_pred))
        
        # Total loss
        self.loss = self.loss_res + self.loss_bcs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-5
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        # To compute NTK, it is better to use SGD optimizer
        # since the corresponding gradient flow is not exactly same.
        # self.train_op = tf.train.GradientDescentOptimizer(starter_learning_rate).minimize(self.loss)
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)


        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
        
        self.saver = tf.train.Saver()
        
        # Compute the Jacobian for weights and biases in each hidden layer  
        self.J_u = self.compute_jacobian(self.u_ntk_pred) 
        self.J_r = self.compute_jacobian(self.r_ntk_pred)
        
        # The empirical NTK = J J^T, compute NTK of PINNs 
        self.K_uu = self.compute_ntk(self.J_u, self.x_u_ntk_tf, self.J_u, self.x_u_ntk_tf)
        self.K_ur = self.compute_ntk(self.J_u, self.x_u_ntk_tf, self.J_r, self.x_r_ntk_tf)
        self.K_rr = self.compute_ntk(self.J_r, self.x_r_ntk_tf, self.J_r, self.x_r_ntk_tf)
        
        # Logger
        # Loss logger
        self.loss_bcs_log = []
        self.loss_res_log = []

        # NTK logger 
        self.K_uu_log = []
        self.K_rr_log = []
        self.K_ur_log = []
        
        # Weights logger 
        self.weights_log = []
        self.biases_log = []
       # Gradients Storage


        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bc_layers = self.generate_grad_dict()

        self.grad_res = []
        self.grad_bc = []

        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bc.append(tf.gradients(self.loss_bcs, self.weights[i])[0])



        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bcs] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        

###############################################################################################################

    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)
    
    # NTK initialization
    def NTK_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        std = 1. / np.sqrt(in_dim)
        return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * std,
                           dtype=tf.float32)

     # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.NTK_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.random.normal([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.nn.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Evaluates the PDE solution
    def net_u(self, x):
        u = self.forward_pass(x)
        return u

    # Forward pass for the residual
    def net_r(self, x):
        u = self.net_u(x)

        u_x = tf.gradients(u, x)[0] / self.sigma_x
        u_xx = tf.gradients(u_x, x)[0] / self.sigma_x

        res_u = u_xx
        return res_u
    
    # Compute Jacobian for each weights and biases in each layer and retrun a list 
    def compute_jacobian(self, f):
        J_list =[]
        L = len(self.weights)    
        for i in range(L):
            J_w = jacobian(f, self.weights[i])
            J_list.append(J_w)
     
        for i in range(L):
            J_b = jacobian(f, self.biases[i])
            J_list.append(J_b)
        return J_list
    
    # Compute the empirical NTK = J J^T
    def compute_ntk(self, J1_list, x1, J2_list, x2):
        D = x1.shape[0]
        N = len(J1_list)
        
        Ker = tf.zeros((D,D))
        for k in range(N):
            J1 = tf.reshape(J1_list[k], shape=(D,-1))
            J2 = tf.reshape(J2_list[k], shape=(D,-1))
            
            K = tf.matmul(J1, tf.transpose(J2))
            Ker = Ker + K
        return Ker
            
    # Trains the model by minimizing the MSE loss
    def trainmb(self, nIter=10000, batch_size=128, log_NTK=True, log_weights=True):


        itValues = [1,100,1000,39999]
        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_bc_tf: self.X_u, self.u_bc_tf: self.Y_u,
                       self.x_u_tf: self.X_u, self.x_r_tf: self.X_r,
                       self.r_tf: self.Y_r
                       }
        
            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            # self.print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value, loss_res_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)
                self.loss_bcs_log.append(loss_bcs_value)
                self.loss_res_log.append(loss_res_value)

                self.print('It: %d, Loss: %.3e, Loss_bcs: %.3e, Loss_res: %.3e ,Time: %.2f' %  (it, loss_value, loss_bcs_value, loss_res_value, elapsed))
                
            if log_NTK:
                # provide x, x' for NTK
                if it % 100 == 0:
                    self.print("Compute NTK...")
                    tf_dict2 = {self.x_u_ntk_tf: self.X_u, 
                               self.x_r_ntk_tf: self.X_r
                               }
                    K_uu_value, K_ur_value, K_rr_value = self.sess.run([self.K_uu,  self.K_ur,  self.K_rr], tf_dict2)
                    self.K_uu_log.append(K_uu_value)
                    self.K_ur_log.append(K_ur_value)
                    self.K_rr_log.append(K_rr_value)
            start_time = timeit.default_timer()

            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
            
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    # Evaluates predictions at test points
    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_r_tf: X_star}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
 ############################################################

    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values

  ############################################################
###################################################################################################################


    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc  = self.sess.run([ self.grad_res[i],self.grad_bc[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bc_layers['layer_' + str(i + 1)].append(grad_bc.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc = self.dict_gradients_bc_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=2)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")

    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M1.ipynb', os.path.join(dirname, 'M1.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger
    
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        #plt.show()
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)

        return self.dirname
    
    def plot_ntk(self):
        # Create empty lists for storing the eigenvalues of NTK
        lambda_K_log = []
        lambda_K_uu_log = []
        lambda_K_ur_log = []
        lambda_K_rr_log = []

        # Restore the NTK
        K_uu_list = self.K_uu_log
        K_ur_list = self.K_ur_log
        K_rr_list = self.K_rr_log
        K_list = []
            
        for k in range(len(K_uu_list)):
            K_uu = K_uu_list[k]
            K_ur = K_ur_list[k]
            K_rr = K_rr_list[k]
            
            K = np.concatenate([np.concatenate([K_uu, K_ur], axis = 1), np.concatenate([K_ur.T, K_rr], axis = 1)], axis = 0)
            K_list.append(K)

            # Compute eigenvalues
            lambda_K, _ = np.linalg.eig(K)
            lambda_K_uu, _ = np.linalg.eig(K_uu)
            lambda_K_rr, _ = np.linalg.eig(K_rr)
            
            # Sort in descresing order
            lambda_K = np.sort(np.real(lambda_K))[::-1]
            lambda_K_uu = np.sort(np.real(lambda_K_uu))[::-1]
            lambda_K_rr = np.sort(np.real(lambda_K_rr))[::-1]
            
            # Store eigenvalues
            lambda_K_log.append(lambda_K)
            lambda_K_uu_log.append(lambda_K_uu)
            lambda_K_rr_log.append(lambda_K_rr)
            fig = plt.figure(figsize=(18, 5))
            plt.subplot(1,3,1)
            for i in range(1, len(lambda_K_log), 10):
                plt.plot(lambda_K_log[i], '--')
            plt.xscale('log')
            plt.yscale('log')
            plt.title(r'Eigenvalues of ${K}$')
            plt.tight_layout()

            plt.subplot(1,3,2)
            for i in range(1, len(lambda_K_uu_log), 10):
                plt.plot(lambda_K_uu_log[i], '--')
            plt.xscale('log')
            plt.yscale('log')
            plt.title(r'Eigenvalues of ${K}_{uu}$')
            plt.tight_layout()

            plt.subplot(1,3,3)
            for i in range(1, len(lambda_K_log), 10):
                plt.plot(lambda_K_rr_log[i], '--')
            plt.xscale('log')
            plt.yscale('log')
            plt.title(r'Eigenvalues of ${K}_{rr}$')
            plt.tight_layout()
            plt.savefig(os.path.join(self.dirname,"ntk.png"))
            plt.close("all")

# %%
# Define solution and its Laplace
a = 4

def u(x, a):
  return np.sin(np.pi * a * x)

def u_xx(x, a):
  return -(np.pi * a)**2 * np.sin(np.pi * a * x)

# %%
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  X_u, Y_u, X_r, Y_r , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size , mode):


    gpu_options = tf.GPUOptions(visible_device_list="0")
    tf.reset_default_graph()
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, X_u, Y_u, X_r, Y_r , mode , sess)    

        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        r_pred = model.predict_r(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(r_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_r: {:.2e}'.format(error_r))


    return [elapsed, error_u , error_r ]

# %%
# Define computional domain
bc1_coords = np.array([[0.0], [0.0]])
bc2_coords = np.array([[1.0], [1.0]])
dom_coords = np.array([[0.0], [1.0]])

# Training data on u(x) -- Dirichlet boundary conditions

nn  = 100

X_bc1 = dom_coords[0, 0] * np.ones((nn // 2, 1))
X_bc2 = dom_coords[1, 0] * np.ones((nn // 2, 1))
X_u = np.vstack([X_bc1, X_bc2])
Y_u = u(X_u, a)

X_r = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
Y_r = u_xx(X_r, a)

nn = 1000
X_star = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
u_star = u(X_star, a)
r_star = u_xx(X_star, a)

nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 128



# Define model
mode = 'M1'
layers = [1, 500, 1]



iterations = 1
methods = [ "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler
        gpu_options = tf.GPUOptions(visible_device_list="0")
        tf.reset_default_graph()
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            model = PINN(layers, X_u, Y_u, X_r, Y_r , mode , sess)    

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions
            model.save_NN()
            model.plot_ntk()
            sess.close()   

        error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
        error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(r_star, 2)

        print('elapsed: {:.2e}'.format(elapsed))

        print('Relative L2 error_u: {:.2e}'.format(error_u))
        print('Relative L2 error_r: {:.2e}'.format(error_r))


        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))
        print('Relative L2 error_v: {:.2e}'.format(error_r))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_v_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list ,error_r_list ]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(model.dirname+"/"+mtd+"_model"+mode+"_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(bcbatch_size)+"_n"+str(iterations)+"_nIter"+str(nIter)+".mat" , result_dict)
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_22072/3619856961.py:52: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22072/3619856961.py:53: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22072/3619856961.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22072/3619856961.py:54: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22072/2503977835.py:29: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22072/2503977835.py:63: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22072/2503977835.py:68: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_22072/2503977835.py:73: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# 2023-12-08 19:55:00.219189: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-08 19:55:00.241945: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-08 19:55:00.242513: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55d8066a58e0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-08 19:55:00.242528: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-08 19:55:00.245502: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_22072/2503977835.py:76: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# mini_batch method is used
# It: 0, Loss: 9.714e+03, Loss_bcs: 2.520e+00, Loss_res: 9.711e+03 ,Time: 0.32
# Compute NTK...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 4.381e+02, Loss_bcs: 8.877e+01, Loss_res: 3.493e+02 ,Time: -1702026032.77
# Compute NTK...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 2.679e+02, Loss_bcs: 5.302e+01, Loss_res: 2.149e+02 ,Time: -1702026032.77
# Compute NTK...
# It: 300, Loss: 1.844e+02, Loss_bcs: 3.108e+01, Loss_res: 1.534e+02 ,Time: -1702026032.77
# Compute NTK...
# It: 400, Loss: 1.331e+02, Loss_bcs: 1.808e+01, Loss_res: 1.150e+02 ,Time: -1702026032.77
# Compute NTK...
# It: 500, Loss: 9.989e+01, Loss_bcs: 1.027e+01, Loss_res: 8.961e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 600, Loss: 7.798e+01, Loss_bcs: 5.639e+00, Loss_res: 7.234e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 700, Loss: 6.316e+01, Loss_bcs: 2.956e+00, Loss_res: 6.021e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 800, Loss: 5.286e+01, Loss_bcs: 1.463e+00, Loss_res: 5.140e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 900, Loss: 4.547e+01, Loss_bcs: 6.897e-01, Loss_res: 4.478e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1000, Loss: 4.000e+01, Loss_bcs: 3.426e-01, Loss_res: 3.966e+01 ,Time: -1702026032.77
# Compute NTK...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 3.584e+01, Loss_bcs: 2.405e-01, Loss_res: 3.559e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1200, Loss: 3.257e+01, Loss_bcs: 2.719e-01, Loss_res: 3.230e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1300, Loss: 2.995e+01, Loss_bcs: 3.689e-01, Loss_res: 2.958e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1400, Loss: 2.780e+01, Loss_bcs: 4.914e-01, Loss_res: 2.731e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1500, Loss: 2.601e+01, Loss_bcs: 6.162e-01, Loss_res: 2.539e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1600, Loss: 2.449e+01, Loss_bcs: 7.308e-01, Loss_res: 2.375e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1700, Loss: 2.317e+01, Loss_bcs: 8.294e-01, Loss_res: 2.234e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1800, Loss: 2.202e+01, Loss_bcs: 9.098e-01, Loss_res: 2.111e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 1900, Loss: 2.101e+01, Loss_bcs: 9.721e-01, Loss_res: 2.004e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2000, Loss: 2.010e+01, Loss_bcs: 1.018e+00, Loss_res: 1.909e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2100, Loss: 1.929e+01, Loss_bcs: 1.048e+00, Loss_res: 1.824e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2200, Loss: 1.855e+01, Loss_bcs: 1.066e+00, Loss_res: 1.748e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2300, Loss: 1.787e+01, Loss_bcs: 1.073e+00, Loss_res: 1.679e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2400, Loss: 1.724e+01, Loss_bcs: 1.071e+00, Loss_res: 1.617e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2500, Loss: 1.666e+01, Loss_bcs: 1.062e+00, Loss_res: 1.560e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2600, Loss: 1.612e+01, Loss_bcs: 1.047e+00, Loss_res: 1.507e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2700, Loss: 1.561e+01, Loss_bcs: 1.028e+00, Loss_res: 1.458e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2800, Loss: 1.514e+01, Loss_bcs: 1.005e+00, Loss_res: 1.413e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 2900, Loss: 1.469e+01, Loss_bcs: 9.802e-01, Loss_res: 1.371e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3000, Loss: 1.427e+01, Loss_bcs: 9.536e-01, Loss_res: 1.331e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3100, Loss: 1.386e+01, Loss_bcs: 9.258e-01, Loss_res: 1.294e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3200, Loss: 1.348e+01, Loss_bcs: 8.975e-01, Loss_res: 1.259e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3300, Loss: 1.312e+01, Loss_bcs: 8.691e-01, Loss_res: 1.225e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3400, Loss: 1.277e+01, Loss_bcs: 8.407e-01, Loss_res: 1.193e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3500, Loss: 1.244e+01, Loss_bcs: 8.126e-01, Loss_res: 1.163e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3600, Loss: 1.213e+01, Loss_bcs: 7.851e-01, Loss_res: 1.134e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3700, Loss: 1.183e+01, Loss_bcs: 7.582e-01, Loss_res: 1.107e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 3800, Loss: 1.154e+01, Loss_bcs: 7.321e-01, Loss_res: 1.080e+01 ,Time: -1702026032.76
# Compute NTK...
# It: 3900, Loss: 1.126e+01, Loss_bcs: 7.068e-01, Loss_res: 1.055e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 4000, Loss: 1.099e+01, Loss_bcs: 6.824e-01, Loss_res: 1.031e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 4100, Loss: 1.073e+01, Loss_bcs: 6.589e-01, Loss_res: 1.007e+01 ,Time: -1702026032.77
# Compute NTK...
# It: 4200, Loss: 1.049e+01, Loss_bcs: 6.362e-01, Loss_res: 9.849e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 4300, Loss: 1.025e+01, Loss_bcs: 6.145e-01, Loss_res: 9.633e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 4400, Loss: 1.002e+01, Loss_bcs: 5.936e-01, Loss_res: 9.424e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 4500, Loss: 9.795e+00, Loss_bcs: 5.736e-01, Loss_res: 9.222e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 4600, Loss: 9.581e+00, Loss_bcs: 5.544e-01, Loss_res: 9.027e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 4700, Loss: 9.375e+00, Loss_bcs: 5.360e-01, Loss_res: 8.839e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 4800, Loss: 9.175e+00, Loss_bcs: 5.184e-01, Loss_res: 8.656e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 4900, Loss: 8.982e+00, Loss_bcs: 5.015e-01, Loss_res: 8.480e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5000, Loss: 8.795e+00, Loss_bcs: 4.854e-01, Loss_res: 8.309e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5100, Loss: 8.614e+00, Loss_bcs: 4.699e-01, Loss_res: 8.144e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5200, Loss: 8.439e+00, Loss_bcs: 4.552e-01, Loss_res: 7.983e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5300, Loss: 8.269e+00, Loss_bcs: 4.410e-01, Loss_res: 7.828e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5400, Loss: 8.104e+00, Loss_bcs: 4.274e-01, Loss_res: 7.677e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5500, Loss: 7.945e+00, Loss_bcs: 4.144e-01, Loss_res: 7.530e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5600, Loss: 7.790e+00, Loss_bcs: 4.020e-01, Loss_res: 7.388e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5700, Loss: 7.640e+00, Loss_bcs: 3.900e-01, Loss_res: 7.250e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5800, Loss: 7.494e+00, Loss_bcs: 3.785e-01, Loss_res: 7.116e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 5900, Loss: 7.353e+00, Loss_bcs: 3.675e-01, Loss_res: 6.985e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6000, Loss: 7.215e+00, Loss_bcs: 3.570e-01, Loss_res: 6.858e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6100, Loss: 7.081e+00, Loss_bcs: 3.468e-01, Loss_res: 6.735e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6200, Loss: 6.952e+00, Loss_bcs: 3.371e-01, Loss_res: 6.614e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6300, Loss: 6.825e+00, Loss_bcs: 3.277e-01, Loss_res: 6.498e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6400, Loss: 6.702e+00, Loss_bcs: 3.187e-01, Loss_res: 6.384e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6500, Loss: 6.583e+00, Loss_bcs: 3.100e-01, Loss_res: 6.273e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6600, Loss: 6.467e+00, Loss_bcs: 3.017e-01, Loss_res: 6.165e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6700, Loss: 6.354e+00, Loss_bcs: 2.936e-01, Loss_res: 6.060e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6800, Loss: 6.243e+00, Loss_bcs: 2.859e-01, Loss_res: 5.957e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 6900, Loss: 6.136e+00, Loss_bcs: 2.784e-01, Loss_res: 5.858e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7000, Loss: 6.032e+00, Loss_bcs: 2.713e-01, Loss_res: 5.760e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7100, Loss: 5.930e+00, Loss_bcs: 2.643e-01, Loss_res: 5.665e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7200, Loss: 5.830e+00, Loss_bcs: 2.577e-01, Loss_res: 5.573e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7300, Loss: 5.734e+00, Loss_bcs: 2.512e-01, Loss_res: 5.482e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7400, Loss: 5.639e+00, Loss_bcs: 2.450e-01, Loss_res: 5.394e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7500, Loss: 5.547e+00, Loss_bcs: 2.390e-01, Loss_res: 5.308e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7600, Loss: 5.458e+00, Loss_bcs: 2.331e-01, Loss_res: 5.224e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7700, Loss: 5.370e+00, Loss_bcs: 2.275e-01, Loss_res: 5.143e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7800, Loss: 5.285e+00, Loss_bcs: 2.221e-01, Loss_res: 5.063e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 7900, Loss: 5.201e+00, Loss_bcs: 2.169e-01, Loss_res: 4.985e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8000, Loss: 5.120e+00, Loss_bcs: 2.118e-01, Loss_res: 4.908e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8100, Loss: 5.041e+00, Loss_bcs: 2.068e-01, Loss_res: 4.834e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8200, Loss: 4.963e+00, Loss_bcs: 2.021e-01, Loss_res: 4.761e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8300, Loss: 4.887e+00, Loss_bcs: 1.975e-01, Loss_res: 4.690e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8400, Loss: 4.814e+00, Loss_bcs: 1.930e-01, Loss_res: 4.621e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8500, Loss: 4.741e+00, Loss_bcs: 1.887e-01, Loss_res: 4.553e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8600, Loss: 4.671e+00, Loss_bcs: 1.845e-01, Loss_res: 4.486e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8700, Loss: 4.602e+00, Loss_bcs: 1.804e-01, Loss_res: 4.422e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8800, Loss: 4.535e+00, Loss_bcs: 1.765e-01, Loss_res: 4.358e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 8900, Loss: 4.469e+00, Loss_bcs: 1.726e-01, Loss_res: 4.296e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9000, Loss: 4.404e+00, Loss_bcs: 1.689e-01, Loss_res: 4.235e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9100, Loss: 4.342e+00, Loss_bcs: 1.653e-01, Loss_res: 4.176e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9200, Loss: 4.280e+00, Loss_bcs: 1.618e-01, Loss_res: 4.118e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9300, Loss: 4.220e+00, Loss_bcs: 1.584e-01, Loss_res: 4.062e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9400, Loss: 4.161e+00, Loss_bcs: 1.551e-01, Loss_res: 4.006e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9500, Loss: 4.104e+00, Loss_bcs: 1.519e-01, Loss_res: 3.952e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9600, Loss: 4.047e+00, Loss_bcs: 1.488e-01, Loss_res: 3.899e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9700, Loss: 3.992e+00, Loss_bcs: 1.457e-01, Loss_res: 3.847e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9800, Loss: 3.939e+00, Loss_bcs: 1.428e-01, Loss_res: 3.796e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 9900, Loss: 3.886e+00, Loss_bcs: 1.399e-01, Loss_res: 3.746e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10000, Loss: 3.834e+00, Loss_bcs: 1.371e-01, Loss_res: 3.697e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10100, Loss: 3.784e+00, Loss_bcs: 1.344e-01, Loss_res: 3.650e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10200, Loss: 3.735e+00, Loss_bcs: 1.317e-01, Loss_res: 3.603e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10300, Loss: 3.686e+00, Loss_bcs: 1.291e-01, Loss_res: 3.557e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10400, Loss: 3.639e+00, Loss_bcs: 1.266e-01, Loss_res: 3.512e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10500, Loss: 3.593e+00, Loss_bcs: 1.242e-01, Loss_res: 3.469e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10600, Loss: 3.547e+00, Loss_bcs: 1.218e-01, Loss_res: 3.426e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10700, Loss: 3.503e+00, Loss_bcs: 1.195e-01, Loss_res: 3.384e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10800, Loss: 3.460e+00, Loss_bcs: 1.172e-01, Loss_res: 3.342e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 10900, Loss: 3.417e+00, Loss_bcs: 1.150e-01, Loss_res: 3.302e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11000, Loss: 3.375e+00, Loss_bcs: 1.129e-01, Loss_res: 3.262e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11100, Loss: 3.334e+00, Loss_bcs: 1.108e-01, Loss_res: 3.224e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11200, Loss: 3.294e+00, Loss_bcs: 1.087e-01, Loss_res: 3.186e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11300, Loss: 3.255e+00, Loss_bcs: 1.067e-01, Loss_res: 3.149e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11400, Loss: 3.217e+00, Loss_bcs: 1.048e-01, Loss_res: 3.112e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11500, Loss: 3.179e+00, Loss_bcs: 1.028e-01, Loss_res: 3.076e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11600, Loss: 3.142e+00, Loss_bcs: 1.010e-01, Loss_res: 3.041e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11700, Loss: 3.106e+00, Loss_bcs: 9.918e-02, Loss_res: 3.007e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11800, Loss: 3.071e+00, Loss_bcs: 9.741e-02, Loss_res: 2.973e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 11900, Loss: 3.036e+00, Loss_bcs: 9.569e-02, Loss_res: 2.940e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12000, Loss: 3.002e+00, Loss_bcs: 9.400e-02, Loss_res: 2.908e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12100, Loss: 2.968e+00, Loss_bcs: 9.234e-02, Loss_res: 2.876e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12200, Loss: 2.936e+00, Loss_bcs: 9.072e-02, Loss_res: 2.845e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12300, Loss: 2.904e+00, Loss_bcs: 8.914e-02, Loss_res: 2.814e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12400, Loss: 2.872e+00, Loss_bcs: 8.759e-02, Loss_res: 2.784e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12500, Loss: 2.841e+00, Loss_bcs: 8.607e-02, Loss_res: 2.755e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12600, Loss: 2.811e+00, Loss_bcs: 8.460e-02, Loss_res: 2.726e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12700, Loss: 2.781e+00, Loss_bcs: 8.316e-02, Loss_res: 2.698e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12800, Loss: 2.752e+00, Loss_bcs: 8.174e-02, Loss_res: 2.670e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 12900, Loss: 2.723e+00, Loss_bcs: 8.036e-02, Loss_res: 2.643e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13000, Loss: 2.695e+00, Loss_bcs: 7.901e-02, Loss_res: 2.616e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13100, Loss: 2.668e+00, Loss_bcs: 7.770e-02, Loss_res: 2.590e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13200, Loss: 2.640e+00, Loss_bcs: 7.641e-02, Loss_res: 2.564e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13300, Loss: 2.614e+00, Loss_bcs: 7.514e-02, Loss_res: 2.539e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13400, Loss: 2.588e+00, Loss_bcs: 7.392e-02, Loss_res: 2.514e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13500, Loss: 2.562e+00, Loss_bcs: 7.271e-02, Loss_res: 2.490e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13600, Loss: 2.537e+00, Loss_bcs: 7.153e-02, Loss_res: 2.466e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13700, Loss: 2.512e+00, Loss_bcs: 7.035e-02, Loss_res: 2.442e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13800, Loss: 2.488e+00, Loss_bcs: 6.922e-02, Loss_res: 2.419e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 13900, Loss: 2.464e+00, Loss_bcs: 6.812e-02, Loss_res: 2.396e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14000, Loss: 2.441e+00, Loss_bcs: 6.704e-02, Loss_res: 2.374e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14100, Loss: 2.418e+00, Loss_bcs: 6.597e-02, Loss_res: 2.352e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14200, Loss: 2.395e+00, Loss_bcs: 6.491e-02, Loss_res: 2.330e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14300, Loss: 2.373e+00, Loss_bcs: 6.388e-02, Loss_res: 2.309e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14400, Loss: 2.351e+00, Loss_bcs: 6.287e-02, Loss_res: 2.288e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14500, Loss: 2.330e+00, Loss_bcs: 6.189e-02, Loss_res: 2.268e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14600, Loss: 2.309e+00, Loss_bcs: 6.093e-02, Loss_res: 2.248e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14700, Loss: 2.288e+00, Loss_bcs: 5.997e-02, Loss_res: 2.228e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14800, Loss: 2.268e+00, Loss_bcs: 5.904e-02, Loss_res: 2.208e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 14900, Loss: 2.247e+00, Loss_bcs: 5.813e-02, Loss_res: 2.189e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15000, Loss: 2.228e+00, Loss_bcs: 5.724e-02, Loss_res: 2.171e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15100, Loss: 2.208e+00, Loss_bcs: 5.637e-02, Loss_res: 2.152e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15200, Loss: 2.189e+00, Loss_bcs: 5.551e-02, Loss_res: 2.134e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15300, Loss: 2.171e+00, Loss_bcs: 5.468e-02, Loss_res: 2.116e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15400, Loss: 2.152e+00, Loss_bcs: 5.385e-02, Loss_res: 2.098e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15500, Loss: 2.134e+00, Loss_bcs: 5.304e-02, Loss_res: 2.081e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15600, Loss: 2.116e+00, Loss_bcs: 5.226e-02, Loss_res: 2.064e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15700, Loss: 2.099e+00, Loss_bcs: 5.149e-02, Loss_res: 2.047e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15800, Loss: 2.081e+00, Loss_bcs: 5.073e-02, Loss_res: 2.030e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 15900, Loss: 2.064e+00, Loss_bcs: 4.998e-02, Loss_res: 2.014e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16000, Loss: 2.047e+00, Loss_bcs: 4.926e-02, Loss_res: 1.998e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16100, Loss: 2.031e+00, Loss_bcs: 4.854e-02, Loss_res: 1.982e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16200, Loss: 2.015e+00, Loss_bcs: 4.783e-02, Loss_res: 1.967e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16300, Loss: 1.999e+00, Loss_bcs: 4.713e-02, Loss_res: 1.951e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16400, Loss: 1.983e+00, Loss_bcs: 4.644e-02, Loss_res: 1.936e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16500, Loss: 1.967e+00, Loss_bcs: 4.578e-02, Loss_res: 1.922e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16600, Loss: 1.952e+00, Loss_bcs: 4.514e-02, Loss_res: 1.907e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16700, Loss: 1.937e+00, Loss_bcs: 4.449e-02, Loss_res: 1.892e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16800, Loss: 1.922e+00, Loss_bcs: 4.384e-02, Loss_res: 1.878e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 16900, Loss: 1.908e+00, Loss_bcs: 4.323e-02, Loss_res: 1.864e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17000, Loss: 1.893e+00, Loss_bcs: 4.263e-02, Loss_res: 1.850e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17100, Loss: 1.879e+00, Loss_bcs: 4.203e-02, Loss_res: 1.837e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17200, Loss: 1.865e+00, Loss_bcs: 4.144e-02, Loss_res: 1.823e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17300, Loss: 1.851e+00, Loss_bcs: 4.086e-02, Loss_res: 1.810e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17400, Loss: 1.837e+00, Loss_bcs: 4.030e-02, Loss_res: 1.797e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17500, Loss: 1.824e+00, Loss_bcs: 3.975e-02, Loss_res: 1.784e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17600, Loss: 1.811e+00, Loss_bcs: 3.920e-02, Loss_res: 1.772e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17700, Loss: 1.798e+00, Loss_bcs: 3.866e-02, Loss_res: 1.759e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17800, Loss: 1.785e+00, Loss_bcs: 3.815e-02, Loss_res: 1.747e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 17900, Loss: 1.772e+00, Loss_bcs: 3.763e-02, Loss_res: 1.735e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18000, Loss: 1.760e+00, Loss_bcs: 3.712e-02, Loss_res: 1.723e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18100, Loss: 1.747e+00, Loss_bcs: 3.663e-02, Loss_res: 1.711e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18200, Loss: 1.735e+00, Loss_bcs: 3.614e-02, Loss_res: 1.699e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18300, Loss: 1.723e+00, Loss_bcs: 3.566e-02, Loss_res: 1.687e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18400, Loss: 1.711e+00, Loss_bcs: 3.519e-02, Loss_res: 1.676e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18500, Loss: 1.700e+00, Loss_bcs: 3.473e-02, Loss_res: 1.665e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18600, Loss: 1.688e+00, Loss_bcs: 3.427e-02, Loss_res: 1.654e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18700, Loss: 1.677e+00, Loss_bcs: 3.382e-02, Loss_res: 1.643e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18800, Loss: 1.665e+00, Loss_bcs: 3.338e-02, Loss_res: 1.632e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 18900, Loss: 1.654e+00, Loss_bcs: 3.295e-02, Loss_res: 1.621e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19000, Loss: 1.643e+00, Loss_bcs: 3.253e-02, Loss_res: 1.611e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19100, Loss: 1.632e+00, Loss_bcs: 3.211e-02, Loss_res: 1.600e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19200, Loss: 1.622e+00, Loss_bcs: 3.169e-02, Loss_res: 1.590e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19300, Loss: 1.611e+00, Loss_bcs: 3.129e-02, Loss_res: 1.580e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19400, Loss: 1.601e+00, Loss_bcs: 3.089e-02, Loss_res: 1.570e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19500, Loss: 1.590e+00, Loss_bcs: 3.050e-02, Loss_res: 1.560e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19600, Loss: 1.580e+00, Loss_bcs: 3.012e-02, Loss_res: 1.550e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19700, Loss: 1.570e+00, Loss_bcs: 2.974e-02, Loss_res: 1.540e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19800, Loss: 1.560e+00, Loss_bcs: 2.936e-02, Loss_res: 1.531e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 19900, Loss: 1.550e+00, Loss_bcs: 2.899e-02, Loss_res: 1.521e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20000, Loss: 1.540e+00, Loss_bcs: 2.864e-02, Loss_res: 1.512e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20100, Loss: 1.531e+00, Loss_bcs: 2.829e-02, Loss_res: 1.503e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20200, Loss: 1.521e+00, Loss_bcs: 2.794e-02, Loss_res: 1.493e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20300, Loss: 1.512e+00, Loss_bcs: 2.759e-02, Loss_res: 1.484e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20400, Loss: 1.503e+00, Loss_bcs: 2.726e-02, Loss_res: 1.475e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20500, Loss: 1.493e+00, Loss_bcs: 2.694e-02, Loss_res: 1.467e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20600, Loss: 1.484e+00, Loss_bcs: 2.662e-02, Loss_res: 1.458e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20700, Loss: 1.475e+00, Loss_bcs: 2.630e-02, Loss_res: 1.449e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20800, Loss: 1.467e+00, Loss_bcs: 2.598e-02, Loss_res: 1.441e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 20900, Loss: 1.458e+00, Loss_bcs: 2.568e-02, Loss_res: 1.432e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21000, Loss: 1.449e+00, Loss_bcs: 2.538e-02, Loss_res: 1.424e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21100, Loss: 1.441e+00, Loss_bcs: 2.508e-02, Loss_res: 1.415e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21200, Loss: 1.432e+00, Loss_bcs: 2.478e-02, Loss_res: 1.407e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21300, Loss: 1.424e+00, Loss_bcs: 2.449e-02, Loss_res: 1.399e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21400, Loss: 1.415e+00, Loss_bcs: 2.421e-02, Loss_res: 1.391e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21500, Loss: 1.407e+00, Loss_bcs: 2.393e-02, Loss_res: 1.383e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21600, Loss: 1.399e+00, Loss_bcs: 2.366e-02, Loss_res: 1.375e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21700, Loss: 1.391e+00, Loss_bcs: 2.338e-02, Loss_res: 1.367e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21800, Loss: 1.383e+00, Loss_bcs: 2.311e-02, Loss_res: 1.360e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 21900, Loss: 1.375e+00, Loss_bcs: 2.284e-02, Loss_res: 1.352e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22000, Loss: 1.367e+00, Loss_bcs: 2.258e-02, Loss_res: 1.345e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22100, Loss: 1.359e+00, Loss_bcs: 2.233e-02, Loss_res: 1.337e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22200, Loss: 1.352e+00, Loss_bcs: 2.209e-02, Loss_res: 1.330e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22300, Loss: 1.344e+00, Loss_bcs: 2.185e-02, Loss_res: 1.322e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22400, Loss: 1.337e+00, Loss_bcs: 2.160e-02, Loss_res: 1.315e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22500, Loss: 1.329e+00, Loss_bcs: 2.136e-02, Loss_res: 1.308e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22600, Loss: 1.322e+00, Loss_bcs: 2.112e-02, Loss_res: 1.301e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22700, Loss: 1.315e+00, Loss_bcs: 2.089e-02, Loss_res: 1.294e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22800, Loss: 1.307e+00, Loss_bcs: 2.066e-02, Loss_res: 1.287e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 22900, Loss: 1.300e+00, Loss_bcs: 2.044e-02, Loss_res: 1.280e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23000, Loss: 1.293e+00, Loss_bcs: 2.021e-02, Loss_res: 1.273e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23100, Loss: 1.286e+00, Loss_bcs: 1.999e-02, Loss_res: 1.266e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23200, Loss: 1.279e+00, Loss_bcs: 1.978e-02, Loss_res: 1.259e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23300, Loss: 1.272e+00, Loss_bcs: 1.956e-02, Loss_res: 1.253e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23400, Loss: 1.265e+00, Loss_bcs: 1.934e-02, Loss_res: 1.246e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23500, Loss: 1.259e+00, Loss_bcs: 1.913e-02, Loss_res: 1.239e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23600, Loss: 1.252e+00, Loss_bcs: 1.893e-02, Loss_res: 1.233e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23700, Loss: 1.245e+00, Loss_bcs: 1.873e-02, Loss_res: 1.227e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23800, Loss: 1.239e+00, Loss_bcs: 1.854e-02, Loss_res: 1.220e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 23900, Loss: 1.232e+00, Loss_bcs: 1.835e-02, Loss_res: 1.214e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24000, Loss: 1.226e+00, Loss_bcs: 1.817e-02, Loss_res: 1.208e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24100, Loss: 1.219e+00, Loss_bcs: 1.799e-02, Loss_res: 1.201e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24200, Loss: 1.213e+00, Loss_bcs: 1.780e-02, Loss_res: 1.195e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24300, Loss: 1.207e+00, Loss_bcs: 1.761e-02, Loss_res: 1.189e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24400, Loss: 1.200e+00, Loss_bcs: 1.743e-02, Loss_res: 1.183e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24500, Loss: 1.194e+00, Loss_bcs: 1.725e-02, Loss_res: 1.177e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24600, Loss: 1.188e+00, Loss_bcs: 1.708e-02, Loss_res: 1.171e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24700, Loss: 1.182e+00, Loss_bcs: 1.690e-02, Loss_res: 1.165e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24800, Loss: 1.176e+00, Loss_bcs: 1.673e-02, Loss_res: 1.159e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 24900, Loss: 1.170e+00, Loss_bcs: 1.656e-02, Loss_res: 1.153e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25000, Loss: 1.164e+00, Loss_bcs: 1.640e-02, Loss_res: 1.148e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25100, Loss: 1.158e+00, Loss_bcs: 1.624e-02, Loss_res: 1.142e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25200, Loss: 1.152e+00, Loss_bcs: 1.608e-02, Loss_res: 1.136e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25300, Loss: 1.147e+00, Loss_bcs: 1.592e-02, Loss_res: 1.131e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25400, Loss: 1.141e+00, Loss_bcs: 1.576e-02, Loss_res: 1.125e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25500, Loss: 1.135e+00, Loss_bcs: 1.561e-02, Loss_res: 1.120e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25600, Loss: 1.130e+00, Loss_bcs: 1.546e-02, Loss_res: 1.114e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25700, Loss: 1.124e+00, Loss_bcs: 1.531e-02, Loss_res: 1.109e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 25800, Loss: 1.118e+00, Loss_bcs: 1.516e-02, Loss_res: 1.103e+00 ,Time: -1702026032.76
# Compute NTK...
# It: 25900, Loss: 1.113e+00, Loss_bcs: 1.501e-02, Loss_res: 1.098e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26000, Loss: 1.108e+00, Loss_bcs: 1.487e-02, Loss_res: 1.093e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26100, Loss: 1.102e+00, Loss_bcs: 1.473e-02, Loss_res: 1.087e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26200, Loss: 1.097e+00, Loss_bcs: 1.459e-02, Loss_res: 1.082e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26300, Loss: 1.091e+00, Loss_bcs: 1.445e-02, Loss_res: 1.077e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26400, Loss: 1.086e+00, Loss_bcs: 1.431e-02, Loss_res: 1.072e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26500, Loss: 1.081e+00, Loss_bcs: 1.418e-02, Loss_res: 1.067e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26600, Loss: 1.076e+00, Loss_bcs: 1.405e-02, Loss_res: 1.062e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26700, Loss: 1.071e+00, Loss_bcs: 1.392e-02, Loss_res: 1.057e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26800, Loss: 1.065e+00, Loss_bcs: 1.379e-02, Loss_res: 1.052e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 26900, Loss: 1.060e+00, Loss_bcs: 1.366e-02, Loss_res: 1.047e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27000, Loss: 1.055e+00, Loss_bcs: 1.354e-02, Loss_res: 1.042e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27100, Loss: 1.050e+00, Loss_bcs: 1.341e-02, Loss_res: 1.037e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27200, Loss: 1.045e+00, Loss_bcs: 1.329e-02, Loss_res: 1.032e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27300, Loss: 1.040e+00, Loss_bcs: 1.318e-02, Loss_res: 1.027e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27400, Loss: 1.036e+00, Loss_bcs: 1.307e-02, Loss_res: 1.022e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27500, Loss: 1.031e+00, Loss_bcs: 1.295e-02, Loss_res: 1.018e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27600, Loss: 1.026e+00, Loss_bcs: 1.284e-02, Loss_res: 1.013e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27700, Loss: 1.021e+00, Loss_bcs: 1.271e-02, Loss_res: 1.008e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27800, Loss: 1.016e+00, Loss_bcs: 1.260e-02, Loss_res: 1.004e+00 ,Time: -1702026032.77
# Compute NTK...
# It: 27900, Loss: 1.012e+00, Loss_bcs: 1.248e-02, Loss_res: 9.992e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28000, Loss: 1.007e+00, Loss_bcs: 1.237e-02, Loss_res: 9.946e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28100, Loss: 1.002e+00, Loss_bcs: 1.227e-02, Loss_res: 9.900e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28200, Loss: 9.977e-01, Loss_bcs: 1.216e-02, Loss_res: 9.855e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28300, Loss: 9.931e-01, Loss_bcs: 1.206e-02, Loss_res: 9.810e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28400, Loss: 9.885e-01, Loss_bcs: 1.196e-02, Loss_res: 9.766e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28500, Loss: 9.840e-01, Loss_bcs: 1.186e-02, Loss_res: 9.721e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28600, Loss: 9.795e-01, Loss_bcs: 1.176e-02, Loss_res: 9.678e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28700, Loss: 9.751e-01, Loss_bcs: 1.165e-02, Loss_res: 9.635e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28800, Loss: 9.707e-01, Loss_bcs: 1.155e-02, Loss_res: 9.591e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 28900, Loss: 9.663e-01, Loss_bcs: 1.145e-02, Loss_res: 9.548e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29000, Loss: 9.619e-01, Loss_bcs: 1.135e-02, Loss_res: 9.506e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29100, Loss: 9.576e-01, Loss_bcs: 1.126e-02, Loss_res: 9.464e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29200, Loss: 9.533e-01, Loss_bcs: 1.116e-02, Loss_res: 9.422e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29300, Loss: 9.491e-01, Loss_bcs: 1.107e-02, Loss_res: 9.380e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29400, Loss: 9.448e-01, Loss_bcs: 1.098e-02, Loss_res: 9.339e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29500, Loss: 9.406e-01, Loss_bcs: 1.089e-02, Loss_res: 9.297e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29600, Loss: 9.364e-01, Loss_bcs: 1.080e-02, Loss_res: 9.256e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29700, Loss: 9.323e-01, Loss_bcs: 1.072e-02, Loss_res: 9.216e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29800, Loss: 9.282e-01, Loss_bcs: 1.063e-02, Loss_res: 9.175e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 29900, Loss: 9.241e-01, Loss_bcs: 1.055e-02, Loss_res: 9.135e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30000, Loss: 9.200e-01, Loss_bcs: 1.046e-02, Loss_res: 9.096e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30100, Loss: 9.160e-01, Loss_bcs: 1.038e-02, Loss_res: 9.056e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30200, Loss: 9.120e-01, Loss_bcs: 1.030e-02, Loss_res: 9.017e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30300, Loss: 9.080e-01, Loss_bcs: 1.022e-02, Loss_res: 8.978e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30400, Loss: 9.041e-01, Loss_bcs: 1.013e-02, Loss_res: 8.939e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30500, Loss: 9.001e-01, Loss_bcs: 1.005e-02, Loss_res: 8.901e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30600, Loss: 8.962e-01, Loss_bcs: 9.968e-03, Loss_res: 8.862e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30700, Loss: 8.923e-01, Loss_bcs: 9.888e-03, Loss_res: 8.824e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30800, Loss: 8.885e-01, Loss_bcs: 9.806e-03, Loss_res: 8.787e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 30900, Loss: 8.847e-01, Loss_bcs: 9.723e-03, Loss_res: 8.749e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31000, Loss: 8.809e-01, Loss_bcs: 9.642e-03, Loss_res: 8.712e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31100, Loss: 8.771e-01, Loss_bcs: 9.566e-03, Loss_res: 8.675e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31200, Loss: 8.734e-01, Loss_bcs: 9.493e-03, Loss_res: 8.639e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31300, Loss: 8.696e-01, Loss_bcs: 9.420e-03, Loss_res: 8.602e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31400, Loss: 8.659e-01, Loss_bcs: 9.349e-03, Loss_res: 8.566e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31500, Loss: 8.623e-01, Loss_bcs: 9.278e-03, Loss_res: 8.530e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31600, Loss: 8.586e-01, Loss_bcs: 9.211e-03, Loss_res: 8.494e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31700, Loss: 8.550e-01, Loss_bcs: 9.145e-03, Loss_res: 8.458e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31800, Loss: 8.513e-01, Loss_bcs: 9.081e-03, Loss_res: 8.423e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 31900, Loss: 8.477e-01, Loss_bcs: 9.019e-03, Loss_res: 8.387e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32000, Loss: 8.442e-01, Loss_bcs: 8.954e-03, Loss_res: 8.352e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32100, Loss: 8.406e-01, Loss_bcs: 8.887e-03, Loss_res: 8.318e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32200, Loss: 8.371e-01, Loss_bcs: 8.819e-03, Loss_res: 8.283e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32300, Loss: 8.337e-01, Loss_bcs: 8.752e-03, Loss_res: 8.249e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32400, Loss: 8.302e-01, Loss_bcs: 8.687e-03, Loss_res: 8.215e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32500, Loss: 8.267e-01, Loss_bcs: 8.622e-03, Loss_res: 8.181e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32600, Loss: 8.233e-01, Loss_bcs: 8.558e-03, Loss_res: 8.148e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32700, Loss: 8.199e-01, Loss_bcs: 8.495e-03, Loss_res: 8.114e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32800, Loss: 8.165e-01, Loss_bcs: 8.432e-03, Loss_res: 8.081e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 32900, Loss: 8.132e-01, Loss_bcs: 8.370e-03, Loss_res: 8.048e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33000, Loss: 8.098e-01, Loss_bcs: 8.310e-03, Loss_res: 8.015e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33100, Loss: 8.065e-01, Loss_bcs: 8.250e-03, Loss_res: 7.983e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33200, Loss: 8.032e-01, Loss_bcs: 8.191e-03, Loss_res: 7.950e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33300, Loss: 8.000e-01, Loss_bcs: 8.132e-03, Loss_res: 7.918e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33400, Loss: 7.967e-01, Loss_bcs: 8.072e-03, Loss_res: 7.886e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33500, Loss: 7.935e-01, Loss_bcs: 8.012e-03, Loss_res: 7.855e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33600, Loss: 7.903e-01, Loss_bcs: 7.954e-03, Loss_res: 7.823e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33700, Loss: 7.871e-01, Loss_bcs: 7.895e-03, Loss_res: 7.792e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33800, Loss: 7.839e-01, Loss_bcs: 7.841e-03, Loss_res: 7.761e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 33900, Loss: 7.807e-01, Loss_bcs: 7.789e-03, Loss_res: 7.729e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34000, Loss: 7.776e-01, Loss_bcs: 7.739e-03, Loss_res: 7.698e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34100, Loss: 7.745e-01, Loss_bcs: 7.689e-03, Loss_res: 7.668e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34200, Loss: 7.714e-01, Loss_bcs: 7.637e-03, Loss_res: 7.637e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34300, Loss: 7.683e-01, Loss_bcs: 7.582e-03, Loss_res: 7.607e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34400, Loss: 7.653e-01, Loss_bcs: 7.529e-03, Loss_res: 7.577e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34500, Loss: 7.622e-01, Loss_bcs: 7.474e-03, Loss_res: 7.548e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34600, Loss: 7.592e-01, Loss_bcs: 7.420e-03, Loss_res: 7.518e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34700, Loss: 7.562e-01, Loss_bcs: 7.365e-03, Loss_res: 7.488e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34800, Loss: 7.532e-01, Loss_bcs: 7.310e-03, Loss_res: 7.459e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 34900, Loss: 7.503e-01, Loss_bcs: 7.256e-03, Loss_res: 7.430e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35000, Loss: 7.474e-01, Loss_bcs: 7.201e-03, Loss_res: 7.402e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35100, Loss: 7.444e-01, Loss_bcs: 7.148e-03, Loss_res: 7.373e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35200, Loss: 7.415e-01, Loss_bcs: 7.097e-03, Loss_res: 7.344e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35300, Loss: 7.386e-01, Loss_bcs: 7.046e-03, Loss_res: 7.316e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35400, Loss: 7.358e-01, Loss_bcs: 6.997e-03, Loss_res: 7.288e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35500, Loss: 7.329e-01, Loss_bcs: 6.950e-03, Loss_res: 7.260e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35600, Loss: 7.301e-01, Loss_bcs: 6.905e-03, Loss_res: 7.232e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35700, Loss: 7.272e-01, Loss_bcs: 6.862e-03, Loss_res: 7.204e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35800, Loss: 7.244e-01, Loss_bcs: 6.819e-03, Loss_res: 7.176e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 35900, Loss: 7.216e-01, Loss_bcs: 6.776e-03, Loss_res: 7.149e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36000, Loss: 7.189e-01, Loss_bcs: 6.734e-03, Loss_res: 7.121e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36100, Loss: 7.161e-01, Loss_bcs: 6.692e-03, Loss_res: 7.094e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36200, Loss: 7.134e-01, Loss_bcs: 6.651e-03, Loss_res: 7.067e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36300, Loss: 7.106e-01, Loss_bcs: 6.608e-03, Loss_res: 7.040e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36400, Loss: 7.079e-01, Loss_bcs: 6.565e-03, Loss_res: 7.013e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36500, Loss: 7.052e-01, Loss_bcs: 6.520e-03, Loss_res: 6.987e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36600, Loss: 7.025e-01, Loss_bcs: 6.476e-03, Loss_res: 6.960e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36700, Loss: 6.999e-01, Loss_bcs: 6.432e-03, Loss_res: 6.935e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36800, Loss: 6.973e-01, Loss_bcs: 6.387e-03, Loss_res: 6.909e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 36900, Loss: 6.946e-01, Loss_bcs: 6.342e-03, Loss_res: 6.883e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37000, Loss: 6.920e-01, Loss_bcs: 6.298e-03, Loss_res: 6.857e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37100, Loss: 6.895e-01, Loss_bcs: 6.256e-03, Loss_res: 6.832e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37200, Loss: 6.869e-01, Loss_bcs: 6.216e-03, Loss_res: 6.807e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37300, Loss: 6.843e-01, Loss_bcs: 6.178e-03, Loss_res: 6.782e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37400, Loss: 6.818e-01, Loss_bcs: 6.141e-03, Loss_res: 6.757e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37500, Loss: 6.793e-01, Loss_bcs: 6.107e-03, Loss_res: 6.732e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37600, Loss: 6.768e-01, Loss_bcs: 6.074e-03, Loss_res: 6.707e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37700, Loss: 6.743e-01, Loss_bcs: 6.041e-03, Loss_res: 6.682e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37800, Loss: 6.718e-01, Loss_bcs: 6.006e-03, Loss_res: 6.657e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 37900, Loss: 6.693e-01, Loss_bcs: 5.972e-03, Loss_res: 6.633e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38000, Loss: 6.668e-01, Loss_bcs: 5.939e-03, Loss_res: 6.609e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38100, Loss: 6.644e-01, Loss_bcs: 5.904e-03, Loss_res: 6.585e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38200, Loss: 6.619e-01, Loss_bcs: 5.869e-03, Loss_res: 6.561e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38300, Loss: 6.595e-01, Loss_bcs: 5.832e-03, Loss_res: 6.537e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38400, Loss: 6.571e-01, Loss_bcs: 5.796e-03, Loss_res: 6.513e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38500, Loss: 6.547e-01, Loss_bcs: 5.761e-03, Loss_res: 6.490e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38600, Loss: 6.524e-01, Loss_bcs: 5.723e-03, Loss_res: 6.466e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38700, Loss: 6.500e-01, Loss_bcs: 5.687e-03, Loss_res: 6.443e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38800, Loss: 6.477e-01, Loss_bcs: 5.651e-03, Loss_res: 6.420e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 38900, Loss: 6.453e-01, Loss_bcs: 5.617e-03, Loss_res: 6.397e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39000, Loss: 6.430e-01, Loss_bcs: 5.584e-03, Loss_res: 6.374e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39100, Loss: 6.407e-01, Loss_bcs: 5.552e-03, Loss_res: 6.352e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39200, Loss: 6.384e-01, Loss_bcs: 5.520e-03, Loss_res: 6.329e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39300, Loss: 6.361e-01, Loss_bcs: 5.489e-03, Loss_res: 6.306e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39400, Loss: 6.339e-01, Loss_bcs: 5.459e-03, Loss_res: 6.284e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39500, Loss: 6.316e-01, Loss_bcs: 5.427e-03, Loss_res: 6.262e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39600, Loss: 6.294e-01, Loss_bcs: 5.394e-03, Loss_res: 6.240e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39700, Loss: 6.272e-01, Loss_bcs: 5.362e-03, Loss_res: 6.218e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39800, Loss: 6.249e-01, Loss_bcs: 5.327e-03, Loss_res: 6.196e-01 ,Time: -1702026032.77
# Compute NTK...
# It: 39900, Loss: 6.227e-01, Loss_bcs: 5.291e-03, Loss_res: 6.175e-01 ,Time: -1702026032.77
# Compute NTK...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 6.206e-01, Loss_bcs: 5.256e-03, Loss_res: 6.153e-01 ,Time: -1702026032.51
# Compute NTK...
# Save uv NN parameters successfully in %s ...checkpoints/Dec-08-2023_19-55-00-245846_M1
# Final loss total loss: 6.205974e-01
# Final loss loss_res: 6.153408e-01
# Final loss loss_bcs: 5.256612e-03
# elapsed: 6.98e+01
# Relative L2 error_u: 5.96e-02
# Relative L2 error_r: 6.13e-03
# elapsed: 6.98e+01
# Relative L2 error_u: 5.96e-02
# Relative L2 error_v: 6.13e-03
#
#
# Method:  mini_batch
#
# average of time_list: 69.77083015441895
# average of error_u_list: 0.05958501274227404
# average of error_v_list: 0.006125716051913204
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat, mode)
#      38     try:
# ---> 39         return open(file_like, mode), True
#      40     except IOError as e:
#
# FileNotFoundError: [Errno 2] No such file or directory: './1DPoisson_model_dataset/mini_batch_modelM1_result_mb128_fb5000_bc500_n1_nIter40001.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_22072/3619856961.py in <module>
#     101     # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})
#     102
# --> 103     scipy.io.savemat("./1DPoisson_model_dataset/"+mtd+"_model"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(bcbatch_size)+"_n"+str(iterations)+"_nIter"+str(nIter)+".mat" , result_dict)
#     104
#     105
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/scipy/io/matlab/mio.py in savemat(file_name, mdict, appendmat, format, long_field_names, do_compression, oned_as)
#     283     >>> savemat("matlab_matrix.mat", mdic)
#     284     """
# --> 285     with _open_file_context(file_name, appendmat, 'wb') as file_stream:
#     286         if format == '4':
#     287             if long_field_names:
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/scipy/io/matlab/mio.py in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat, mode)
#      43             if appendmat and not file_like.endswith('.mat'):
#      44                 file_like += '.mat'
# ---> 45             return open(file_like, mode), True
#      46         else:
#      47             raise IOError(
#
# FileNotFoundError: [Errno 2] No such file or directory: './1DPoisson_model_dataset/mini_batch_modelM1_result_mb128_fb5000_bc500_n1_nIter40001.mat'

# %%
# Define model
layers = [1, 512, 1]  
# layers = [1, 512, 512, 512, 1]

# %%
loss_bcs = model.loss_bcs_log
loss_res = model.loss_res_log

fig = plt.figure(figsize=(6,5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{b}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
# Out:
# Relative L2 error_u: 3.05e-02
# Relative L2 error_r: 4.16e-03

# %%
fig = plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)
plt.plot(X_star, u_star, label='Exact')
plt.plot(X_star, u_pred, '--', label='Predicted')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(loc='upper right')

plt.subplot(1,2,2)
plt.plot(X_star, np.abs(u_star - u_pred), label='Error')
plt.yscale('log')
plt.xlabel('$x$')
plt.ylabel('Point-wise error')
plt.tight_layout()
plt.savefig(os.path.join(model.dirname,"prediction.png"))
plt.close("all")

# %% [markdown]
# **NTK Eigenvalues**

# %% [markdown]
# **Change of NTK**

# %%
# Change of the NTK
NTK_change_list = []
K0 = K_list[0]
for K in K_list:
    diff = np.linalg.norm(K - K0) / np.linalg.norm(K0) 
    NTK_change_list.append(diff)

# %%
fig = plt.figure(figsize=(6,5))
plt.plot(NTK_change_list)

# %% [markdown]
# **Change of NN Params**

# %%
# Change of the weights and biases
def compute_weights_diff(weights_1, weights_2):
    weights = []
    N = len(weights_1)
    for k in range(N):
        weight = weights_1[k] - weights_2[k]
        weights.append(weight)
    return weights

def compute_weights_norm(weights, biases):
    norm = 0
    for w in weights:
        norm = norm + np.sum(np.square(w))
    for b in biases:
        norm = norm + np.sum(np.square(b))
    norm = np.sqrt(norm)
    return norm

# Restore the list weights and biases
weights_log = model.weights_log
biases_log = model.biases_log

weights_0 = weights_log[0]
biases_0 = biases_log[0]

# Norm of the weights at initialization
weights_init_norm = compute_weights_norm(weights_0, biases_0)

weights_change_list = []

N = len(weights_log)
for k in range(N):
    weights_diff = compute_weights_diff(weights_log[k], weights_log[0])
    biases_diff = compute_weights_diff(biases_log[k], biases_log[0])
    
    weights_diff_norm = compute_weights_norm(weights_diff, biases_diff)
    weights_change = weights_diff_norm / weights_init_norm
    weights_change_list.append(weights_change)

# %%
fig = plt.figure(figsize=(6,5))
plt.plot(weights_change_list)
