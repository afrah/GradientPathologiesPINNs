# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import pandas as pd
# from NS_model_tf import Sampler, Navier_Stokes2D
import os
os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import scipy
import scipy.io
import time

import sys

import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle
def U_gamma_1(x):
    num = x.shape[0]
    return np.tile(np.array([1.0, 0.0]), (num, 1))


def U_gamma_2(x):
    num = x.shape[0]
    return np.zeros((num, 2))


def f(x):
    num = x.shape[0]
    return np.zeros((num, 2))

def operator(psi, p, x, y, Re, sigma_x=1.0, sigma_y=1.0):
    u = tf.gradients(psi, y)[0] / sigma_y
    v = - tf.gradients(psi, x)[0] / sigma_x

    u_x = tf.gradients(u, x)[0] / sigma_x
    u_y = tf.gradients(u, y)[0] / sigma_y

    v_x = tf.gradients(v, x)[0] / sigma_x
    v_y = tf.gradients(v, y)[0] / sigma_y

    p_x = tf.gradients(p, x)[0] / sigma_x
    p_y = tf.gradients(p, y)[0] / sigma_y

    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    u_yy = tf.gradients(u_y, y)[0] / sigma_y

    v_xx = tf.gradients(v_x, x)[0] / sigma_x
    v_yy = tf.gradients(v_y, y)[0] / sigma_y

    Ru_momentum = u * u_x + v * u_y + p_x - (u_xx + u_yy) / Re
    Rv_momentum = u * v_x + v * v_y + p_y - (v_xx + v_yy) / Re

    return Ru_momentum, Rv_momentum

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Navier_Stokes2D:
    def __init__(self, layers, operator, bcs_sampler, res_sampler, Re, mode , sess):


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]
        self.mu_y, self.sigma_y = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler


        # Navier Stokes constant
        self.Re = tf.constant(Re, dtype=tf.float32)

        # Adaptive re-weighting constant
        self.rate = 0.9
        self.rho = 0.9
        self.T = 0.9

        self.adaptive_constant_bcs_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)

        # Define Tensorflow session
        self.sess = sess

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)


        # Define placeholders and computational graph
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc1_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc2_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc3_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc4_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.adaptive_constant_bcs_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)

        # Evaluate predictions
        self.u_bc1_pred, self.v_bc1_pred = self.net_uv(self.x_bc1_tf, self.y_bc1_tf)
        self.u_bc2_pred, self.v_bc2_pred = self.net_uv(self.x_bc2_tf, self.y_bc2_tf)
        self.u_bc3_pred, self.v_bc3_pred = self.net_uv(self.x_bc3_tf, self.y_bc3_tf)
        self.u_bc4_pred, self.v_bc4_pred = self.net_uv(self.x_bc4_tf, self.y_bc4_tf)

        self.U_bc1_pred = tf.concat([self.u_bc1_pred, self.v_bc1_pred], axis=1)
        self.U_bc2_pred = tf.concat([self.u_bc2_pred, self.v_bc2_pred], axis=1)
        self.U_bc3_pred = tf.concat([self.u_bc3_pred, self.v_bc3_pred], axis=1)
        self.U_bc4_pred = tf.concat([self.u_bc4_pred, self.v_bc4_pred], axis=1)

        self.psi_pred, self.p_pred = self.net_psi_p(self.x_u_tf, self.y_u_tf)
        self.u_pred, self.v_pred = self.net_uv(self.x_u_tf, self.y_u_tf)
        self.u_momentum_pred, self.v_momentum_pred = self.net_r(self.x_r_tf, self.y_r_tf)

        # Residual loss
        self.loss_u_momentum = tf.reduce_mean(tf.square(self.u_momentum_pred))
        self.loss_v_momentum = tf.reduce_mean(tf.square(self.v_momentum_pred))

        self.loss_res = self.loss_u_momentum + self.loss_v_momentum
        
        # Boundary loss
        self.loss_bc1 = tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.U_bc2_pred))
        self.loss_bc3 = tf.reduce_mean(tf.square(self.U_bc3_pred))
        self.loss_bc4 = tf.reduce_mean(tf.square(self.U_bc4_pred))
        
        self.loss_bcs =  tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf) +tf.square(self.U_bc2_pred) + tf.square(self.U_bc3_pred) + tf.square(self.U_bc4_pred))
        
        # Total loss
        self.loss = self.adaptive_constant_res_tf * self.loss_res +  self.adaptive_constant_bcs_tf * tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf) + tf.square(self.U_bc2_pred) + tf.square(self.U_bc3_pred) + tf.square(self.U_bc4_pred))

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step, 1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_tensor_list = [self.loss ,  self.loss_res ,  self.loss_bcs,  self.loss_bc1 , self.loss_bc2 , self.loss_bc3, self.loss_bc4] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs" , "loss_bc1", "loss_bc2", "loss_bc3", "loss_bc4"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
       
        # self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_bcs = []
        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])

        self.adpative_constant_bcs_list = []
        self.adpative_constant_res_list = []
        
        self.adpative_constant_bcs_log = []
        self.adpative_constant_res_log = []

        self.mean_constant_bcs_log = []
        self.mean_constant_res_log = []

        for i in range(len(self.layers) - 1):
            self.adpative_constant_res_list.append( tf.reduce_mean(tf.abs(self.grad_res[i])))
            self.adpative_constant_bcs_list.append(  tf.reduce_mean(tf.abs(self.grad_bcs[i])))

        self.mean_constant_bcs = tf.reduce_mean(tf.stack(self.adpative_constant_bcs_list))
        self.mean_constant_res =  tf.reduce_mean(tf.stack(self.adpative_constant_res_list))

        self.prev_lam_bcs = 1
        self.prev_lam_res = 1
        self.index =1

        self.mean_grad_res_log  = []
        self.mean_grad_bcs_log  = []
        self.mean_grad_ics_log  = []
    

        init = tf.global_variables_initializer()
        self.sess.run(init)
        

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev, dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H


    # Forward pass for stream-pressure formulation
    def net_psi_p(self, x, y):
        psi_p = self.forward_pass(tf.concat([x, y], 1))
        psi = psi_p[:, 0:1]
        p = psi_p[:, 1:2]
        return psi, p

    # Forward pass for velocities
    def net_uv(self, x, y):
        psi, p = self.net_psi_p(x, y)
        u = tf.gradients(psi, y)[0] / self.sigma_y
        v = - tf.gradients(psi, x)[0] / self.sigma_x
        return u, v

    # Forward pass for residual
    def net_r(self, x, y):
        psi, p = self.net_psi_p(x, y)
        u_momentum_pred, v_momentum_pred = self.operator(psi, p, x, y,  self.Re,  self.sigma_x, self.sigma_y)

        return u_momentum_pred, v_momentum_pred

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
    def train(self, nIter ,  bcbatch_size , ubatch_size):

        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size)
        X_bc3_batch, _ = self.fetch_minibatch(self.bcs_sampler[2], bcbatch_size)
        X_bc4_batch, _ = self.fetch_minibatch(self.bcs_sampler[3], bcbatch_size)

        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                    self.U_bc1_tf: u_bc1_batch,
                    self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                    self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                    self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                    self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val,
                    self.adaptive_constant_res_tf: self.adaptive_constant_res_val
                    }
        
        for it in range( 1, nIter):

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)
                self.print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' % (it, loss_value, loss_u_value, loss_r_value, elapsed))

            if it % 100 == 0:

                # Compute the adaptive constant
                # adaptive_constant_bcs_val = self.sess.run(self.adaptive_constant_bcs, tf_dict)

                self.adaptive_constant_bcs_val = self.relobralo( "loss_bcs"  ,self.prev_lam_bcs)  
                self.adaptive_constant_res_val = self.relobralo( "loss_res"  ,self.prev_lam_res )  

                self.adpative_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                self.adpative_constant_res_log.append(self.adaptive_constant_res_val)

                self.mean_grad_bcs_log.append(self.mean_constant_bcs)
                self.mean_grad_res_log.append(self.mean_constant_res)


                self.print("adaptive_constant_bcs_val: {:.3f}".format(self.adaptive_constant_bcs_val))
                self.print("adaptive_constant_res_val: {:.3f}".format(self.adaptive_constant_res_val))


                mean_constant_bcs , mean_constant_res = self.sess.run([self.mean_constant_bcs ,self.mean_constant_res], tf_dict)

                self.mean_constant_bcs_log.append(mean_constant_bcs)
                self.mean_constant_res_log.append(mean_constant_res)
            
                self.prev_lam_bcs = self.adaptive_constant_bcs_val
                self.prev_lam_res = self.adaptive_constant_res_val
                self.index =it
  
            sys.stdout.flush()

            start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")



######################################################################################################################################
                

    def lambda_balance(self ,term , index):
        loss_list = ["loss_res" , "loss_bcs" ] 
        m= len(loss_list)
        num = np.exp(self.loss_history[term][-1] /(self.T * self.loss_history[term][index]))
        denum = 0 

        for  key in loss_list:
            denum +=  np.exp(self.loss_history[key][-1] /(self.T * self.loss_history[key][index]))
        return m * (num / denum)
     
    def relobralo( self, term ,prev_lamda ):

        lambda_hist = self.rho  * prev_lamda + (1.0 - self.rho) *  self.lambda_balance( term , 1)
        lambda_i = self.rate  * lambda_hist + (1.0 - self.rate) *  self.lambda_balance( term , self.index)

        return lambda_i
    

   # Trains the model by minimizing the MSE loss
    def trainmb(self, nIter, batch_size):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range( 1, nIter):
            # Fetch boundary mini-batches
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, _ = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, _ = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                       self.U_bc1_tf: u_bc1_batch,
                       self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                       self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                       self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                       self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                       self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val,
                       self.adaptive_constant_res_tf: self.adaptive_constant_res_val
                       }

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)
                self.print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' % (it, loss_value, loss_u_value, loss_r_value, elapsed))

            if it % 100 == 0:

                # Compute the adaptive constant
                # adaptive_constant_bcs_val = self.sess.run(self.adaptive_constant_bcs, tf_dict)

                self.adaptive_constant_bcs_val = self.relobralo( "loss_bcs"  ,self.prev_lam_bcs)  
                self.adaptive_constant_res_val = self.relobralo( "loss_res"  ,self.prev_lam_res )  

                self.adpative_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                self.adpative_constant_res_log.append(self.adaptive_constant_res_val)

                self.mean_grad_bcs_log.append(self.mean_constant_bcs)
                self.mean_grad_res_log.append(self.mean_constant_res)


                self.print("adaptive_constant_bcs_val: {:.3f}".format(self.adaptive_constant_bcs_val))
                self.print("adaptive_constant_res_val: {:.3f}".format(self.adaptive_constant_res_val))


                mean_constant_bcs , mean_constant_res = self.sess.run([self.mean_constant_bcs ,self.mean_constant_res], tf_dict)

                self.mean_constant_bcs_log.append(mean_constant_bcs)
                self.mean_constant_res_log.append(mean_constant_res)
            
                self.prev_lam_bcs = self.adaptive_constant_bcs_val
                self.prev_lam_res = self.adaptive_constant_res_val
                self.index =it
  
            sys.stdout.flush()

            start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

 

    # Evaluates predictions at test points
    def predict_psi_p(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2]}
        psi_star = self.sess.run(self.psi_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)
        return psi_star, p_star

    def predict_uv(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        return u_star, v_star



 ############################################################

    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values

    def plot_loss_history(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.show()
    ############################################################
  
  # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1    = self.sess.run([ self.grad_res[i],self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=3)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('relobralo.ipynb', os.path.join(dirname, 'relobralo.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        loss_list = ["total loss" , "loss_res"  , "loss_bc1", "loss_bc2", "loss_bc3", "loss_bc4"] 

        for key in loss_list:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        plt.close("all" , )
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
        from mpl_toolkits.axes_grid1 import ImageGrid

        ### Plot ###

        # Exact solution & Predicted solution
        # Exact soluton
        U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
        F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

        # Predicted solution
        U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
        F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

        titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $v(x)$' , 'Predicted $v(x)$' , 'Absolute error']
        data = [U_star.T , U_pred ,  np.abs(U_star.T - U_pred) , F_star.T , F_pred ,  np.abs(F_star.T - F_pred) ]

        fig_1 = plt.figure(1, figsize=(13, 5))
        grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                        label_mode="1", axes_pad=1.7, share_all=False, 
                        cbar_mode="each", cbar_location="right", 
                        cbar_size="5%", cbar_pad=0.0)
    # CREATE ARGUMENTS DICT FOR CONTOURPLOTS
        minmax_list = []
        for d in data:
            # if(local):
            #     minmax_list.append([np.min(d), np.max(d)])
            # else:
            minmax_list.append([np.min(d), np.max(d)])

            # kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60), cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

        for ax, z, minmax, title in zip(grid, data, minmax_list, titles):
        #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
            #pcfsets.append(pcf)
            # if (timeStp == 0):
            pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
            cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
            ax.cax.tick_params(labelsize=14.5)
            ax.set_title(title, fontsize=14.5, pad=7)
            ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
            ax.set_xlabel("x", fontsize=14.5)
            ax.tick_params(labelsize=14.5)
            ax.set_xlim(x1.min(), x1.max())
            ax.set_ylim(x2.min(), x2.max())
            ax.set_aspect("equal")

        fig_1.set_size_inches(15, 10, True)
        fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
        plt.close("all" , )


    def plot_lambda(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adpative_constant_bcs_log, label=r'$\lambda_{bc}$')
        ax.semilogy(self.adpative_constant_res_log, label=r'$\lambda_{res}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\lambda$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'lambda_history.png')
        plt.savefig(path)
        plt.close("all" , )



    def plot_grad(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.mean_constant_bcs_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc}}}$')
        ax.semilogy(self.mean_constant_res_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{res}}}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\bar{\nabla_\theta \mathcal{L}}$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)
        plt.close("all" , )

# %%
#        [elapsed, error_u , error_v ,  error_p] = test_method(mtd , layers, operator, bcs_sampler, res_sampler ,Re , stiff_ratio ,  X_star , X , Y)

def test_method(method , layers, operator, bcs_sampler, res_sampler, Re ,  mode , X_star , X , Y , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):


    model = Navier_Stokes2D(layers, operator, bcs_sampler, res_sampler, Re, mode)

    # Train model
    start_time = time.time()

    if method =="full_batch":
        model.train(nIter  , bcbatch_size , ubatch_size  )
    elif method =="mini_batch":
        model.trainmb(nIter, mbbatch_size)
    else:
        print("unknown method!")
    elapsed = time.time() - start_time

    # Predictions
    _, p_pred = model.predict_psi_p(X_star)
    u_pred, v_pred = model.predict_uv(X_star)

    # psi_star = griddata(X_star, psi_pred.flatten(), (X, Y), method='cubic')
    p_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
    # u_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
    # v_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')

    # velocity = np.sqrt(u_pred**2 + v_pred**2)
    # velocity_star = griddata(X_star, velocity.flatten(), (X, Y), method='cubic')

    # Reference
    u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
    v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
    # velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

    u_pred = u_pred.reshape(100,100)
    v_pred = v_pred.reshape(100,100)
    p_pred = p_pred.reshape(100,100)

    # Relative error
    error_u = np.linalg.norm(u_ref - u_pred.T, 2) / np.linalg.norm(u_ref, 2)
    print('l2 error: {:.2e}'.format(error_u))
    error_v = np.linalg.norm(v_ref - v_pred.T, 2) / np.linalg.norm(v_ref, 2)
    print('l2 error: {:.2e}'.format(error_v))
    error_p = np.linalg.norm(p_pred - p_star.T, 2) / np.linalg.norm(p_star, 2)
    print('l2 error: {:.2e}'.format(error_p))

    return [elapsed, error_u , error_v ,error_p ]

# %%
nIter =40001
bcbatch_size = 350
ubatch_size = 5000
mbbatch_size = 128

# Parameters of equations
Re = 100.0

# Domain boundaries
bc1_coords = np.array([[0.0, 1.0], [1.0, 1.0]])
bc2_coords = np.array([[0.0, 0.0], [0.0, 1.0]])
bc3_coords = np.array([[1.0, 0.0], [1.0, 1.0]])
bc4_coords = np.array([[0.0, 0.0], [1.0, 0.0]])
dom_coords = np.array([[0.0, 0.0], [1.0, 1.0]])

# Define model
model = 'relobralo'
layers = [2, 50, 50, 50, 50 , 50 , 2]

stiff_ratio = False  # Log the eigenvalues of Hessian of losses


# Test Data
nx = 100
ny = 100  # change to 100
x = np.linspace(0.0, 1.0, nx)
y = np.linspace(0.0, 1.0, ny)
X, Y = np.meshgrid(x, y)


X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))


iterations = 1
methods = ["full_batch" ]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_v_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create boundary conditions samplers
        bc1 = Sampler(2, bc1_coords, lambda x: U_gamma_1(x), name='Dirichlet BC1')
        bc2 = Sampler(2, bc2_coords, lambda x: U_gamma_2(x), name='Dirichlet BC2')
        bc3 = Sampler(2, bc3_coords, lambda x: U_gamma_2(x), name='Dirichlet BC3')
        bc4 = Sampler(2, bc4_coords, lambda x: U_gamma_2(x), name='Dirichlet BC4')
        bcs_sampler = [bc1, bc2, bc3, bc4]

        # Create residual sampler
        res_sampler = Sampler(2, dom_coords, lambda x: f(x), name='Forcing')

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            mode = Navier_Stokes2D(layers, operator, bcs_sampler, res_sampler, Re, model , sess)

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                mode.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                mode.trainmb(nIter, mbbatch_size)
            else:
                mode.print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            _, p_pred = mode.predict_psi_p(X_star)
            u_pred, v_pred = mode.predict_uv(X_star)

            # Reference
            u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
            v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
            # velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

            u_pred = u_pred.reshape(100,100)
            v_pred = v_pred.reshape(100,100)

            # Relative error
            error_u = np.linalg.norm(u_ref - u_pred.T, 2) / np.linalg.norm(u_ref, 2)
            error_v = np.linalg.norm(v_ref - v_pred.T, 2) / np.linalg.norm(v_ref, 2)

            mode.print('l2 error: {:.2e}'.format(error_u))
            mode.print('l2 error: {:.2e}'.format(error_v))

       
            mode.print("average lambda_bc: " , np.average(mode.adpative_constant_bcs_log))
            mode.print("average lambda_res: " , str(1.0))
            # sess.close
            mode.plot_lambda()

            mode.plot_grad()
            mode.save_NN()
            mode.plt_prediction( X , Y , X_star , u_ref , u_pred , v_ref , v_pred)


        mode.print('elapsed: {:.2e}'.format(elapsed))
        mode.print('Relative L2 error_u: {:.2e}'.format(error_u))
        mode.print('Relative L2 error_v: {:.2e}'.format(error_v))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_v_list.append(error_v)

    mode.print("\n\nMethod: ", mtd)
    mode.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    mode.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    mode.print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )

    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(mode.dirname,""+mtd+"_Lid-driven-Cavity_"+model+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)
# Out:
# Method:  full_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_7302/3589439032.py:59: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_7302/3589439032.py:60: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_7302/3589439032.py:61: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_7302/3589439032.py:61: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-17 13:47:08.555822: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-17 13:47:08.587453: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-17 13:47:08.588129: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557e0f8200a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-17 13:47:08.588164: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-17 13:47:08.588788: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_7302/2753309777.py:172: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_7302/2753309777.py:55: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_7302/2753309777.py:115: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_7302/2753309777.py:117: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_7302/2753309777.py:163: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 1.082e-01, Loss_u: 1.004e-01, Loss_r: 7.817e-03, Time: 0.42
# adaptive_constant_bcs_val: 1.023
# adaptive_constant_res_val: 0.977
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 8.687e-02, Loss_u: 7.925e-02, Loss_r: 7.619e-03, Time: 0.42
# adaptive_constant_bcs_val: 1.017
# adaptive_constant_res_val: 0.983
# It: 300, Loss: 6.927e-02, Loss_u: 6.303e-02, Loss_r: 6.245e-03, Time: 0.44
# adaptive_constant_bcs_val: 1.019
# adaptive_constant_res_val: 0.981
# It: 400, Loss: 5.251e-02, Loss_u: 4.724e-02, Loss_r: 5.266e-03, Time: 0.44
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 500, Loss: 4.278e-02, Loss_u: 3.827e-02, Loss_r: 4.506e-03, Time: 0.43
# adaptive_constant_bcs_val: 0.998
# adaptive_constant_res_val: 1.002
# It: 600, Loss: 3.973e-02, Loss_u: 3.574e-02, Loss_r: 3.987e-03, Time: 0.40
# adaptive_constant_bcs_val: 1.011
# adaptive_constant_res_val: 0.989
# It: 700, Loss: 3.823e-02, Loss_u: 3.457e-02, Loss_r: 3.669e-03, Time: 0.41
# adaptive_constant_bcs_val: 1.014
# adaptive_constant_res_val: 0.986
# It: 800, Loss: 3.740e-02, Loss_u: 3.411e-02, Loss_r: 3.296e-03, Time: 0.37
# adaptive_constant_bcs_val: 1.016
# adaptive_constant_res_val: 0.984
# It: 900, Loss: 3.940e-02, Loss_u: 3.221e-02, Loss_r: 7.195e-03, Time: 0.38
# adaptive_constant_bcs_val: 1.024
# adaptive_constant_res_val: 0.976
# It: 1000, Loss: 3.671e-02, Loss_u: 3.261e-02, Loss_r: 4.098e-03, Time: 0.36
# adaptive_constant_bcs_val: 1.062
# adaptive_constant_res_val: 0.938
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 3.664e-02, Loss_u: 3.424e-02, Loss_r: 2.404e-03, Time: 0.42
# adaptive_constant_bcs_val: 1.038
# adaptive_constant_res_val: 0.962
# It: 1200, Loss: 3.759e-02, Loss_u: 3.137e-02, Loss_r: 6.226e-03, Time: 0.38
# adaptive_constant_bcs_val: 1.027
# adaptive_constant_res_val: 0.973
# It: 1300, Loss: 3.506e-02, Loss_u: 3.247e-02, Loss_r: 2.584e-03, Time: 0.80
# adaptive_constant_bcs_val: 1.051
# adaptive_constant_res_val: 0.949
# It: 1400, Loss: 3.661e-02, Loss_u: 3.143e-02, Loss_r: 5.178e-03, Time: 0.41
# adaptive_constant_bcs_val: 1.050
# adaptive_constant_res_val: 0.950
# It: 1500, Loss: 3.523e-02, Loss_u: 3.031e-02, Loss_r: 4.921e-03, Time: 0.40
# adaptive_constant_bcs_val: 1.075
# adaptive_constant_res_val: 0.925
# It: 1600, Loss: 3.341e-02, Loss_u: 3.074e-02, Loss_r: 2.674e-03, Time: 0.40
# adaptive_constant_bcs_val: 1.080
# adaptive_constant_res_val: 0.920
# It: 1700, Loss: 3.267e-02, Loss_u: 2.958e-02, Loss_r: 3.085e-03, Time: 0.40
# adaptive_constant_bcs_val: 1.059
# adaptive_constant_res_val: 0.941
# It: 1800, Loss: 3.219e-02, Loss_u: 2.918e-02, Loss_r: 3.009e-03, Time: 0.60
# adaptive_constant_bcs_val: 1.041
# adaptive_constant_res_val: 0.959
# It: 1900, Loss: 3.822e-02, Loss_u: 2.850e-02, Loss_r: 9.725e-03, Time: 0.41
# adaptive_constant_bcs_val: 1.015
# adaptive_constant_res_val: 0.985
# It: 2000, Loss: 3.372e-02, Loss_u: 2.780e-02, Loss_r: 5.921e-03, Time: 0.38
# adaptive_constant_bcs_val: 1.053
# adaptive_constant_res_val: 0.947
# It: 2100, Loss: 3.148e-02, Loss_u: 2.782e-02, Loss_r: 3.658e-03, Time: 0.55
# adaptive_constant_bcs_val: 1.071
# adaptive_constant_res_val: 0.929
# It: 2200, Loss: 3.150e-02, Loss_u: 2.680e-02, Loss_r: 4.692e-03, Time: 0.37
# adaptive_constant_bcs_val: 1.068
# adaptive_constant_res_val: 0.932
# It: 2300, Loss: 3.051e-02, Loss_u: 2.718e-02, Loss_r: 3.324e-03, Time: 0.49
# adaptive_constant_bcs_val: 1.067
# adaptive_constant_res_val: 0.933
# It: 2400, Loss: 3.029e-02, Loss_u: 2.706e-02, Loss_r: 3.232e-03, Time: 0.42
# adaptive_constant_bcs_val: 1.037
# adaptive_constant_res_val: 0.963
# It: 2500, Loss: 3.005e-02, Loss_u: 2.676e-02, Loss_r: 3.295e-03, Time: 0.44
# adaptive_constant_bcs_val: 1.015
# adaptive_constant_res_val: 0.985
# It: 2600, Loss: 2.969e-02, Loss_u: 2.609e-02, Loss_r: 3.599e-03, Time: 0.38
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 2700, Loss: 3.011e-02, Loss_u: 2.685e-02, Loss_r: 3.262e-03, Time: 0.38
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 2800, Loss: 3.391e-02, Loss_u: 2.691e-02, Loss_r: 7.003e-03, Time: 0.32
# adaptive_constant_bcs_val: 0.992
# adaptive_constant_res_val: 1.008
# It: 2900, Loss: 2.948e-02, Loss_u: 2.526e-02, Loss_r: 4.212e-03, Time: 0.36
# adaptive_constant_bcs_val: 1.022
# adaptive_constant_res_val: 0.978
# It: 3000, Loss: 2.892e-02, Loss_u: 2.508e-02, Loss_r: 3.847e-03, Time: 0.35
# adaptive_constant_bcs_val: 1.029
# adaptive_constant_res_val: 0.971
# It: 3100, Loss: 2.894e-02, Loss_u: 2.548e-02, Loss_r: 3.465e-03, Time: 0.34
# adaptive_constant_bcs_val: 1.029
# adaptive_constant_res_val: 0.971
# It: 3200, Loss: 3.156e-02, Loss_u: 2.567e-02, Loss_r: 5.894e-03, Time: 0.41
# adaptive_constant_bcs_val: 1.020
# adaptive_constant_res_val: 0.980
# It: 3300, Loss: 2.850e-02, Loss_u: 2.515e-02, Loss_r: 3.359e-03, Time: 0.35
# adaptive_constant_bcs_val: 1.032
# adaptive_constant_res_val: 0.968
# It: 3400, Loss: 2.833e-02, Loss_u: 2.481e-02, Loss_r: 3.520e-03, Time: 0.36
# adaptive_constant_bcs_val: 1.013
# adaptive_constant_res_val: 0.987
# It: 3500, Loss: 2.795e-02, Loss_u: 2.440e-02, Loss_r: 3.549e-03, Time: 0.37
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 3600, Loss: 2.798e-02, Loss_u: 2.459e-02, Loss_r: 3.396e-03, Time: 0.37
# adaptive_constant_bcs_val: 0.991
# adaptive_constant_res_val: 1.009
# It: 3700, Loss: 2.769e-02, Loss_u: 2.367e-02, Loss_r: 4.022e-03, Time: 0.41
# adaptive_constant_bcs_val: 0.995
# adaptive_constant_res_val: 1.005
# It: 3800, Loss: 2.776e-02, Loss_u: 2.342e-02, Loss_r: 4.347e-03, Time: 0.35
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 3900, Loss: 2.735e-02, Loss_u: 2.402e-02, Loss_r: 3.332e-03, Time: 0.41
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 4000, Loss: 2.735e-02, Loss_u: 2.402e-02, Loss_r: 3.324e-03, Time: 0.59
# adaptive_constant_bcs_val: 0.981
# adaptive_constant_res_val: 1.019
# It: 4100, Loss: 2.682e-02, Loss_u: 2.318e-02, Loss_r: 3.639e-03, Time: 0.46
# adaptive_constant_bcs_val: 0.982
# adaptive_constant_res_val: 1.018
# It: 4200, Loss: 2.689e-02, Loss_u: 2.330e-02, Loss_r: 3.583e-03, Time: 0.54
# adaptive_constant_bcs_val: 0.989
# adaptive_constant_res_val: 1.011
# It: 4300, Loss: 2.654e-02, Loss_u: 2.240e-02, Loss_r: 4.137e-03, Time: 0.37
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 4400, Loss: 2.628e-02, Loss_u: 2.239e-02, Loss_r: 3.890e-03, Time: 0.34
# adaptive_constant_bcs_val: 1.014
# adaptive_constant_res_val: 0.986
# It: 4500, Loss: 2.689e-02, Loss_u: 2.293e-02, Loss_r: 3.953e-03, Time: 0.38
# adaptive_constant_bcs_val: 1.023
# adaptive_constant_res_val: 0.977
# It: 4600, Loss: 2.581e-02, Loss_u: 2.265e-02, Loss_r: 3.161e-03, Time: 0.33
# adaptive_constant_bcs_val: 1.022
# adaptive_constant_res_val: 0.978
# It: 4700, Loss: 2.594e-02, Loss_u: 2.277e-02, Loss_r: 3.171e-03, Time: 0.30
# adaptive_constant_bcs_val: 0.992
# adaptive_constant_res_val: 1.008
# It: 4800, Loss: 2.519e-02, Loss_u: 2.183e-02, Loss_r: 3.357e-03, Time: 0.29
# adaptive_constant_bcs_val: 0.992
# adaptive_constant_res_val: 1.008
# It: 4900, Loss: 2.504e-02, Loss_u: 2.182e-02, Loss_r: 3.226e-03, Time: 0.30
# adaptive_constant_bcs_val: 0.993
# adaptive_constant_res_val: 1.007
# It: 5000, Loss: 2.654e-02, Loss_u: 2.356e-02, Loss_r: 2.975e-03, Time: 0.38
# adaptive_constant_bcs_val: 0.993
# adaptive_constant_res_val: 1.007
# It: 5100, Loss: 2.441e-02, Loss_u: 2.138e-02, Loss_r: 3.032e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 5200, Loss: 2.432e-02, Loss_u: 2.129e-02, Loss_r: 3.026e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.976
# adaptive_constant_res_val: 1.024
# It: 5300, Loss: 2.410e-02, Loss_u: 2.102e-02, Loss_r: 3.080e-03, Time: 0.31
# adaptive_constant_bcs_val: 0.978
# adaptive_constant_res_val: 1.022
# It: 5400, Loss: 2.357e-02, Loss_u: 2.072e-02, Loss_r: 2.853e-03, Time: 0.30
# adaptive_constant_bcs_val: 0.978
# adaptive_constant_res_val: 1.022
# It: 5500, Loss: 2.322e-02, Loss_u: 2.034e-02, Loss_r: 2.879e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.977
# adaptive_constant_res_val: 1.023
# It: 5600, Loss: 2.277e-02, Loss_u: 1.964e-02, Loss_r: 3.123e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.981
# adaptive_constant_res_val: 1.019
# It: 5700, Loss: 2.237e-02, Loss_u: 1.939e-02, Loss_r: 2.980e-03, Time: 0.34
# adaptive_constant_bcs_val: 0.991
# adaptive_constant_res_val: 1.009
# It: 5800, Loss: 2.278e-02, Loss_u: 1.988e-02, Loss_r: 2.901e-03, Time: 0.31
# adaptive_constant_bcs_val: 0.986
# adaptive_constant_res_val: 1.014
# It: 5900, Loss: 2.136e-02, Loss_u: 1.822e-02, Loss_r: 3.140e-03, Time: 0.30
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 6000, Loss: 2.087e-02, Loss_u: 1.846e-02, Loss_r: 2.404e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 6100, Loss: 2.121e-02, Loss_u: 1.845e-02, Loss_r: 2.752e-03, Time: 0.31
# adaptive_constant_bcs_val: 0.937
# adaptive_constant_res_val: 1.063
# It: 6200, Loss: 1.914e-02, Loss_u: 1.695e-02, Loss_r: 2.195e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.945
# adaptive_constant_res_val: 1.055
# It: 6300, Loss: 1.856e-02, Loss_u: 1.639e-02, Loss_r: 2.173e-03, Time: 0.31
# adaptive_constant_bcs_val: 0.936
# adaptive_constant_res_val: 1.064
# It: 6400, Loss: 1.793e-02, Loss_u: 1.587e-02, Loss_r: 2.062e-03, Time: 0.34
# adaptive_constant_bcs_val: 0.925
# adaptive_constant_res_val: 1.075
# It: 6500, Loss: 1.832e-02, Loss_u: 1.524e-02, Loss_r: 3.084e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.932
# adaptive_constant_res_val: 1.068
# It: 6600, Loss: 1.697e-02, Loss_u: 1.490e-02, Loss_r: 2.065e-03, Time: 0.36
# adaptive_constant_bcs_val: 0.955
# adaptive_constant_res_val: 1.045
# It: 6700, Loss: 1.624e-02, Loss_u: 1.431e-02, Loss_r: 1.938e-03, Time: 0.34
# adaptive_constant_bcs_val: 0.958
# adaptive_constant_res_val: 1.042
# It: 6800, Loss: 1.572e-02, Loss_u: 1.376e-02, Loss_r: 1.963e-03, Time: 0.34
# adaptive_constant_bcs_val: 0.968
# adaptive_constant_res_val: 1.032
# It: 6900, Loss: 1.528e-02, Loss_u: 1.335e-02, Loss_r: 1.929e-03, Time: 0.35
# adaptive_constant_bcs_val: 0.980
# adaptive_constant_res_val: 1.020
# It: 7000, Loss: 1.531e-02, Loss_u: 1.289e-02, Loss_r: 2.418e-03, Time: 0.38
# adaptive_constant_bcs_val: 0.989
# adaptive_constant_res_val: 1.011
# It: 7100, Loss: 1.459e-02, Loss_u: 1.295e-02, Loss_r: 1.641e-03, Time: 0.31
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 7200, Loss: 1.453e-02, Loss_u: 1.289e-02, Loss_r: 1.639e-03, Time: 0.36
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 7300, Loss: 1.482e-02, Loss_u: 1.241e-02, Loss_r: 2.416e-03, Time: 0.36
# adaptive_constant_bcs_val: 0.995
# adaptive_constant_res_val: 1.005
# It: 7400, Loss: 1.366e-02, Loss_u: 1.219e-02, Loss_r: 1.473e-03, Time: 0.34
# adaptive_constant_bcs_val: 1.016
# adaptive_constant_res_val: 0.984
# It: 7500, Loss: 1.333e-02, Loss_u: 1.191e-02, Loss_r: 1.422e-03, Time: 0.36
# adaptive_constant_bcs_val: 1.012
# adaptive_constant_res_val: 0.988
# It: 7600, Loss: 1.426e-02, Loss_u: 1.240e-02, Loss_r: 1.856e-03, Time: 0.31
# adaptive_constant_bcs_val: 0.975
# adaptive_constant_res_val: 1.025
# It: 7700, Loss: 1.296e-02, Loss_u: 1.164e-02, Loss_r: 1.318e-03, Time: 0.35
# adaptive_constant_bcs_val: 0.982
# adaptive_constant_res_val: 1.018
# It: 7800, Loss: 1.302e-02, Loss_u: 1.118e-02, Loss_r: 1.841e-03, Time: 0.35
# adaptive_constant_bcs_val: 0.983
# adaptive_constant_res_val: 1.017
# It: 7900, Loss: 1.251e-02, Loss_u: 1.124e-02, Loss_r: 1.271e-03, Time: 0.38
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 8000, Loss: 1.254e-02, Loss_u: 1.116e-02, Loss_r: 1.383e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.989
# adaptive_constant_res_val: 1.011
# It: 8100, Loss: 1.219e-02, Loss_u: 1.060e-02, Loss_r: 1.591e-03, Time: 0.34
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 8200, Loss: 1.173e-02, Loss_u: 1.053e-02, Loss_r: 1.193e-03, Time: 0.33
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 8300, Loss: 1.336e-02, Loss_u: 1.053e-02, Loss_r: 2.827e-03, Time: 0.34
# adaptive_constant_bcs_val: 0.944
# adaptive_constant_res_val: 1.056
# It: 8400, Loss: 1.191e-02, Loss_u: 1.048e-02, Loss_r: 1.430e-03, Time: 0.35
# adaptive_constant_bcs_val: 0.976
# adaptive_constant_res_val: 1.024
# It: 8500, Loss: 1.197e-02, Loss_u: 1.041e-02, Loss_r: 1.554e-03, Time: 0.32
# adaptive_constant_bcs_val: 0.963
# adaptive_constant_res_val: 1.037
# It: 8600, Loss: 1.107e-02, Loss_u: 9.698e-03, Loss_r: 1.367e-03, Time: 0.34
# adaptive_constant_bcs_val: 0.983
# adaptive_constant_res_val: 1.017
# It: 8700, Loss: 1.132e-02, Loss_u: 9.993e-03, Loss_r: 1.324e-03, Time: 0.35
# adaptive_constant_bcs_val: 0.953
# adaptive_constant_res_val: 1.047
# It: 8800, Loss: 1.091e-02, Loss_u: 9.433e-03, Loss_r: 1.476e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.966
# adaptive_constant_res_val: 1.034
# It: 8900, Loss: 1.045e-02, Loss_u: 9.350e-03, Loss_r: 1.104e-03, Time: 0.33
# adaptive_constant_bcs_val: 0.989
# adaptive_constant_res_val: 1.011
# It: 9000, Loss: 1.053e-02, Loss_u: 9.403e-03, Loss_r: 1.128e-03, Time: 0.38
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 9100, Loss: 1.027e-02, Loss_u: 9.225e-03, Loss_r: 1.042e-03, Time: 0.25
# adaptive_constant_bcs_val: 0.985
# adaptive_constant_res_val: 1.015
# It: 9200, Loss: 1.021e-02, Loss_u: 9.104e-03, Loss_r: 1.109e-03, Time: 0.24
# adaptive_constant_bcs_val: 0.978
# adaptive_constant_res_val: 1.022
# It: 9300, Loss: 1.040e-02, Loss_u: 9.092e-03, Loss_r: 1.307e-03, Time: 0.24
# adaptive_constant_bcs_val: 0.983
# adaptive_constant_res_val: 1.017
# It: 9400, Loss: 9.887e-03, Loss_u: 8.863e-03, Loss_r: 1.024e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.995
# adaptive_constant_res_val: 1.005
# It: 9500, Loss: 1.043e-02, Loss_u: 9.092e-03, Loss_r: 1.333e-03, Time: 0.24
# adaptive_constant_bcs_val: 0.963
# adaptive_constant_res_val: 1.037
# It: 9600, Loss: 9.786e-03, Loss_u: 8.620e-03, Loss_r: 1.165e-03, Time: 0.25
# adaptive_constant_bcs_val: 0.980
# adaptive_constant_res_val: 1.020
# It: 9700, Loss: 1.047e-02, Loss_u: 8.867e-03, Loss_r: 1.600e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.933
# adaptive_constant_res_val: 1.067
# It: 9800, Loss: 1.051e-02, Loss_u: 8.971e-03, Loss_r: 1.539e-03, Time: 0.27
# adaptive_constant_bcs_val: 0.946
# adaptive_constant_res_val: 1.054
# It: 9900, Loss: 9.630e-03, Loss_u: 8.495e-03, Loss_r: 1.135e-03, Time: 0.24
# adaptive_constant_bcs_val: 0.956
# adaptive_constant_res_val: 1.044
# It: 10000, Loss: 9.434e-03, Loss_u: 8.422e-03, Loss_r: 1.012e-03, Time: 0.24
# adaptive_constant_bcs_val: 0.956
# adaptive_constant_res_val: 1.044
# It: 10100, Loss: 9.909e-03, Loss_u: 8.462e-03, Loss_r: 1.447e-03, Time: 0.25
# adaptive_constant_bcs_val: 0.935
# adaptive_constant_res_val: 1.065
# It: 10200, Loss: 9.490e-03, Loss_u: 8.248e-03, Loss_r: 1.242e-03, Time: 0.26
# adaptive_constant_bcs_val: 0.957
# adaptive_constant_res_val: 1.043
# It: 10300, Loss: 9.768e-03, Loss_u: 8.371e-03, Loss_r: 1.396e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.958
# adaptive_constant_res_val: 1.042
# It: 10400, Loss: 1.052e-02, Loss_u: 8.685e-03, Loss_r: 1.836e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.961
# adaptive_constant_res_val: 1.039
# It: 10500, Loss: 9.675e-03, Loss_u: 8.321e-03, Loss_r: 1.354e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.982
# adaptive_constant_res_val: 1.018
# It: 10600, Loss: 8.968e-03, Loss_u: 7.897e-03, Loss_r: 1.071e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 10700, Loss: 9.670e-03, Loss_u: 8.097e-03, Loss_r: 1.572e-03, Time: 0.22
# adaptive_constant_bcs_val: 0.969
# adaptive_constant_res_val: 1.031
# It: 10800, Loss: 9.309e-03, Loss_u: 7.945e-03, Loss_r: 1.364e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.975
# adaptive_constant_res_val: 1.025
# It: 10900, Loss: 9.273e-03, Loss_u: 7.725e-03, Loss_r: 1.548e-03, Time: 0.22
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 11000, Loss: 9.484e-03, Loss_u: 7.950e-03, Loss_r: 1.535e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.988
# adaptive_constant_res_val: 1.012
# It: 11100, Loss: 8.699e-03, Loss_u: 7.658e-03, Loss_r: 1.041e-03, Time: 0.22
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 11200, Loss: 8.615e-03, Loss_u: 7.622e-03, Loss_r: 9.934e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 11300, Loss: 8.715e-03, Loss_u: 7.426e-03, Loss_r: 1.289e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.994
# adaptive_constant_res_val: 1.006
# It: 11400, Loss: 8.427e-03, Loss_u: 7.446e-03, Loss_r: 9.811e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 11500, Loss: 8.527e-03, Loss_u: 7.437e-03, Loss_r: 1.089e-03, Time: 0.21
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 11600, Loss: 8.455e-03, Loss_u: 7.385e-03, Loss_r: 1.070e-03, Time: 0.21
# adaptive_constant_bcs_val: 1.006
# adaptive_constant_res_val: 0.994
# It: 11700, Loss: 8.420e-03, Loss_u: 7.366e-03, Loss_r: 1.054e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 11800, Loss: 8.187e-03, Loss_u: 7.213e-03, Loss_r: 9.745e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 11900, Loss: 8.329e-03, Loss_u: 7.131e-03, Loss_r: 1.198e-03, Time: 0.22
# adaptive_constant_bcs_val: 0.995
# adaptive_constant_res_val: 1.005
# It: 12000, Loss: 8.450e-03, Loss_u: 7.289e-03, Loss_r: 1.161e-03, Time: 0.25
# adaptive_constant_bcs_val: 1.005
# adaptive_constant_res_val: 0.995
# It: 12100, Loss: 8.970e-03, Loss_u: 7.229e-03, Loss_r: 1.741e-03, Time: 0.25
# adaptive_constant_bcs_val: 0.976
# adaptive_constant_res_val: 1.024
# It: 12200, Loss: 8.204e-03, Loss_u: 6.998e-03, Loss_r: 1.207e-03, Time: 0.21
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 12300, Loss: 8.117e-03, Loss_u: 7.083e-03, Loss_r: 1.034e-03, Time: 0.20
# adaptive_constant_bcs_val: 1.014
# adaptive_constant_res_val: 0.986
# It: 12400, Loss: 7.881e-03, Loss_u: 6.958e-03, Loss_r: 9.235e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.015
# adaptive_constant_res_val: 0.985
# It: 12500, Loss: 7.931e-03, Loss_u: 6.951e-03, Loss_r: 9.802e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 12600, Loss: 7.945e-03, Loss_u: 6.937e-03, Loss_r: 1.008e-03, Time: 0.23
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 12700, Loss: 7.834e-03, Loss_u: 6.796e-03, Loss_r: 1.037e-03, Time: 0.21
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 12800, Loss: 7.754e-03, Loss_u: 6.802e-03, Loss_r: 9.514e-04, Time: 0.29
# adaptive_constant_bcs_val: 1.007
# adaptive_constant_res_val: 0.993
# It: 12900, Loss: 7.728e-03, Loss_u: 6.781e-03, Loss_r: 9.471e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 13000, Loss: 7.892e-03, Loss_u: 6.820e-03, Loss_r: 1.072e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.989
# adaptive_constant_res_val: 1.011
# It: 13100, Loss: 7.604e-03, Loss_u: 6.693e-03, Loss_r: 9.110e-04, Time: 0.21
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 13200, Loss: 7.795e-03, Loss_u: 6.764e-03, Loss_r: 1.031e-03, Time: 0.22
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 13300, Loss: 7.584e-03, Loss_u: 6.636e-03, Loss_r: 9.482e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.987
# adaptive_constant_res_val: 1.013
# It: 13400, Loss: 7.539e-03, Loss_u: 6.569e-03, Loss_r: 9.701e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.990
# adaptive_constant_res_val: 1.010
# It: 13500, Loss: 7.387e-03, Loss_u: 6.533e-03, Loss_r: 8.540e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.993
# adaptive_constant_res_val: 1.007
# It: 13600, Loss: 7.337e-03, Loss_u: 6.455e-03, Loss_r: 8.827e-04, Time: 0.21
# adaptive_constant_bcs_val: 0.993
# adaptive_constant_res_val: 1.007
# It: 13700, Loss: 7.554e-03, Loss_u: 6.547e-03, Loss_r: 1.007e-03, Time: 0.22
# adaptive_constant_bcs_val: 0.974
# adaptive_constant_res_val: 1.026
# It: 13800, Loss: 7.437e-03, Loss_u: 6.481e-03, Loss_r: 9.558e-04, Time: 0.20
# adaptive_constant_bcs_val: 0.970
# adaptive_constant_res_val: 1.030
# It: 13900, Loss: 7.398e-03, Loss_u: 6.355e-03, Loss_r: 1.043e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.976
# adaptive_constant_res_val: 1.024
# It: 14000, Loss: 7.365e-03, Loss_u: 6.452e-03, Loss_r: 9.130e-04, Time: 0.21
# adaptive_constant_bcs_val: 0.976
# adaptive_constant_res_val: 1.024
# It: 14100, Loss: 7.147e-03, Loss_u: 6.299e-03, Loss_r: 8.480e-04, Time: 0.21
# adaptive_constant_bcs_val: 0.982
# adaptive_constant_res_val: 1.018
# It: 14200, Loss: 8.946e-03, Loss_u: 6.865e-03, Loss_r: 2.081e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.909
# adaptive_constant_res_val: 1.091
# It: 14300, Loss: 7.246e-03, Loss_u: 6.293e-03, Loss_r: 9.523e-04, Time: 0.24
# adaptive_constant_bcs_val: 0.950
# adaptive_constant_res_val: 1.050
# It: 14400, Loss: 7.358e-03, Loss_u: 6.269e-03, Loss_r: 1.089e-03, Time: 0.22
# adaptive_constant_bcs_val: 0.954
# adaptive_constant_res_val: 1.046
# It: 14500, Loss: 8.158e-03, Loss_u: 6.130e-03, Loss_r: 2.027e-03, Time: 0.27
# adaptive_constant_bcs_val: 0.933
# adaptive_constant_res_val: 1.067
# It: 14600, Loss: 7.005e-03, Loss_u: 6.130e-03, Loss_r: 8.751e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.977
# adaptive_constant_res_val: 1.023
# It: 14700, Loss: 6.974e-03, Loss_u: 6.074e-03, Loss_r: 9.003e-04, Time: 0.23
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 14800, Loss: 6.925e-03, Loss_u: 6.083e-03, Loss_r: 8.415e-04, Time: 0.27
# adaptive_constant_bcs_val: 0.989
# adaptive_constant_res_val: 1.011
# It: 14900, Loss: 8.079e-03, Loss_u: 6.056e-03, Loss_r: 2.023e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.930
# adaptive_constant_res_val: 1.070
# It: 15000, Loss: 6.948e-03, Loss_u: 6.024e-03, Loss_r: 9.241e-04, Time: 0.23
# adaptive_constant_bcs_val: 0.974
# adaptive_constant_res_val: 1.026
# It: 15100, Loss: 6.809e-03, Loss_u: 5.977e-03, Loss_r: 8.322e-04, Time: 0.24
# adaptive_constant_bcs_val: 0.985
# adaptive_constant_res_val: 1.015
# It: 15200, Loss: 7.073e-03, Loss_u: 5.967e-03, Loss_r: 1.106e-03, Time: 0.22
# adaptive_constant_bcs_val: 0.979
# adaptive_constant_res_val: 1.021
# It: 15300, Loss: 7.412e-03, Loss_u: 6.096e-03, Loss_r: 1.317e-03, Time: 0.24
# adaptive_constant_bcs_val: 0.971
# adaptive_constant_res_val: 1.029
# It: 15400, Loss: 6.994e-03, Loss_u: 5.953e-03, Loss_r: 1.040e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.987
# adaptive_constant_res_val: 1.013
# It: 15500, Loss: 6.754e-03, Loss_u: 5.876e-03, Loss_r: 8.777e-04, Time: 0.21
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 15600, Loss: 6.667e-03, Loss_u: 5.840e-03, Loss_r: 8.277e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 15700, Loss: 6.700e-03, Loss_u: 5.827e-03, Loss_r: 8.731e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 15800, Loss: 6.812e-03, Loss_u: 5.866e-03, Loss_r: 9.459e-04, Time: 0.21
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 15900, Loss: 6.676e-03, Loss_u: 5.785e-03, Loss_r: 8.912e-04, Time: 0.29
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 16000, Loss: 6.768e-03, Loss_u: 5.870e-03, Loss_r: 8.980e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.007
# adaptive_constant_res_val: 0.993
# It: 16100, Loss: 6.517e-03, Loss_u: 5.717e-03, Loss_r: 8.003e-04, Time: 0.33
# adaptive_constant_bcs_val: 1.011
# adaptive_constant_res_val: 0.989
# It: 16200, Loss: 6.516e-03, Loss_u: 5.707e-03, Loss_r: 8.083e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 16300, Loss: 6.474e-03, Loss_u: 5.679e-03, Loss_r: 7.953e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 16400, Loss: 6.452e-03, Loss_u: 5.663e-03, Loss_r: 7.892e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.005
# adaptive_constant_res_val: 0.995
# It: 16500, Loss: 6.411e-03, Loss_u: 5.626e-03, Loss_r: 7.852e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.005
# adaptive_constant_res_val: 0.995
# It: 16600, Loss: 6.393e-03, Loss_u: 5.611e-03, Loss_r: 7.820e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 16700, Loss: 6.384e-03, Loss_u: 5.601e-03, Loss_r: 7.825e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 16800, Loss: 6.350e-03, Loss_u: 5.578e-03, Loss_r: 7.719e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 16900, Loss: 6.703e-03, Loss_u: 5.534e-03, Loss_r: 1.169e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 17000, Loss: 6.318e-03, Loss_u: 5.523e-03, Loss_r: 7.955e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.005
# adaptive_constant_res_val: 0.995
# It: 17100, Loss: 6.300e-03, Loss_u: 5.501e-03, Loss_r: 7.990e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.007
# adaptive_constant_res_val: 0.993
# It: 17200, Loss: 6.429e-03, Loss_u: 5.448e-03, Loss_r: 9.806e-04, Time: 0.27
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 17300, Loss: 6.488e-03, Loss_u: 5.430e-03, Loss_r: 1.058e-03, Time: 0.22
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 17400, Loss: 6.214e-03, Loss_u: 5.426e-03, Loss_r: 7.888e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.019
# adaptive_constant_res_val: 0.981
# It: 17500, Loss: 6.197e-03, Loss_u: 5.403e-03, Loss_r: 7.939e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.017
# adaptive_constant_res_val: 0.983
# It: 17600, Loss: 6.259e-03, Loss_u: 5.398e-03, Loss_r: 8.609e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.010
# adaptive_constant_res_val: 0.990
# It: 17700, Loss: 6.149e-03, Loss_u: 5.377e-03, Loss_r: 7.720e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.014
# adaptive_constant_res_val: 0.986
# It: 17800, Loss: 6.128e-03, Loss_u: 5.367e-03, Loss_r: 7.619e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.011
# adaptive_constant_res_val: 0.989
# It: 17900, Loss: 6.354e-03, Loss_u: 5.445e-03, Loss_r: 9.094e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 18000, Loss: 6.095e-03, Loss_u: 5.338e-03, Loss_r: 7.574e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.007
# adaptive_constant_res_val: 0.993
# It: 18100, Loss: 6.200e-03, Loss_u: 5.285e-03, Loss_r: 9.144e-04, Time: 0.23
# adaptive_constant_bcs_val: 0.995
# adaptive_constant_res_val: 1.005
# It: 18200, Loss: 6.059e-03, Loss_u: 5.268e-03, Loss_r: 7.908e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.006
# adaptive_constant_res_val: 0.994
# It: 18300, Loss: 6.255e-03, Loss_u: 5.252e-03, Loss_r: 1.003e-03, Time: 0.23
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 18400, Loss: 6.391e-03, Loss_u: 5.253e-03, Loss_r: 1.138e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 18500, Loss: 6.011e-03, Loss_u: 5.221e-03, Loss_r: 7.896e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.015
# adaptive_constant_res_val: 0.985
# It: 18600, Loss: 6.063e-03, Loss_u: 5.253e-03, Loss_r: 8.098e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.007
# adaptive_constant_res_val: 0.993
# It: 18700, Loss: 5.935e-03, Loss_u: 5.188e-03, Loss_r: 7.472e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.010
# adaptive_constant_res_val: 0.990
# It: 18800, Loss: 5.947e-03, Loss_u: 5.191e-03, Loss_r: 7.562e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.006
# adaptive_constant_res_val: 0.994
# It: 18900, Loss: 6.022e-03, Loss_u: 5.206e-03, Loss_r: 8.157e-04, Time: 0.24
# adaptive_constant_bcs_val: 0.998
# adaptive_constant_res_val: 1.002
# It: 19000, Loss: 6.044e-03, Loss_u: 5.207e-03, Loss_r: 8.376e-04, Time: 0.23
# adaptive_constant_bcs_val: 0.985
# adaptive_constant_res_val: 1.015
# It: 19100, Loss: 5.873e-03, Loss_u: 5.134e-03, Loss_r: 7.390e-04, Time: 0.24
# adaptive_constant_bcs_val: 0.993
# adaptive_constant_res_val: 1.007
# It: 19200, Loss: 5.883e-03, Loss_u: 5.132e-03, Loss_r: 7.508e-04, Time: 0.20
# adaptive_constant_bcs_val: 0.994
# adaptive_constant_res_val: 1.006
# It: 19300, Loss: 5.842e-03, Loss_u: 5.081e-03, Loss_r: 7.617e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 19400, Loss: 5.815e-03, Loss_u: 5.080e-03, Loss_r: 7.354e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 19500, Loss: 5.804e-03, Loss_u: 5.075e-03, Loss_r: 7.296e-04, Time: 0.26
# adaptive_constant_bcs_val: 0.998
# adaptive_constant_res_val: 1.002
# It: 19600, Loss: 5.770e-03, Loss_u: 5.042e-03, Loss_r: 7.288e-04, Time: 0.20
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 19700, Loss: 5.762e-03, Loss_u: 5.018e-03, Loss_r: 7.446e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 19800, Loss: 5.764e-03, Loss_u: 4.995e-03, Loss_r: 7.685e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 19900, Loss: 6.259e-03, Loss_u: 5.142e-03, Loss_r: 1.118e-03, Time: 0.25
# adaptive_constant_bcs_val: 0.982
# adaptive_constant_res_val: 1.018
# It: 20000, Loss: 5.730e-03, Loss_u: 4.986e-03, Loss_r: 7.438e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 20100, Loss: 5.733e-03, Loss_u: 4.999e-03, Loss_r: 7.340e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 20200, Loss: 5.674e-03, Loss_u: 4.958e-03, Loss_r: 7.158e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.998
# adaptive_constant_res_val: 1.002
# It: 20300, Loss: 5.677e-03, Loss_u: 4.948e-03, Loss_r: 7.292e-04, Time: 0.21
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 20400, Loss: 5.648e-03, Loss_u: 4.934e-03, Loss_r: 7.139e-04, Time: 0.20
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 20500, Loss: 5.628e-03, Loss_u: 4.906e-03, Loss_r: 7.218e-04, Time: 0.25
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 20600, Loss: 5.605e-03, Loss_u: 4.892e-03, Loss_r: 7.132e-04, Time: 0.20
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 20700, Loss: 5.632e-03, Loss_u: 4.868e-03, Loss_r: 7.645e-04, Time: 0.23
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 20800, Loss: 5.625e-03, Loss_u: 4.866e-03, Loss_r: 7.587e-04, Time: 0.22
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 20900, Loss: 5.758e-03, Loss_u: 4.871e-03, Loss_r: 8.876e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 21000, Loss: 5.540e-03, Loss_u: 4.841e-03, Loss_r: 6.994e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.011
# adaptive_constant_res_val: 0.989
# It: 21100, Loss: 5.846e-03, Loss_u: 4.920e-03, Loss_r: 9.257e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 21200, Loss: 6.171e-03, Loss_u: 4.786e-03, Loss_r: 1.385e-03, Time: 0.21
# adaptive_constant_bcs_val: 0.975
# adaptive_constant_res_val: 1.025
# It: 21300, Loss: 5.621e-03, Loss_u: 4.834e-03, Loss_r: 7.873e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 21400, Loss: 5.598e-03, Loss_u: 4.762e-03, Loss_r: 8.360e-04, Time: 0.21
# adaptive_constant_bcs_val: 1.006
# adaptive_constant_res_val: 0.994
# It: 21500, Loss: 5.467e-03, Loss_u: 4.774e-03, Loss_r: 6.935e-04, Time: 0.29
# adaptive_constant_bcs_val: 1.016
# adaptive_constant_res_val: 0.984
# It: 21600, Loss: 5.623e-03, Loss_u: 4.750e-03, Loss_r: 8.729e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.994
# adaptive_constant_res_val: 1.006
# It: 21700, Loss: 5.729e-03, Loss_u: 4.809e-03, Loss_r: 9.197e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 21800, Loss: 5.422e-03, Loss_u: 4.734e-03, Loss_r: 6.877e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.013
# adaptive_constant_res_val: 0.987
# It: 21900, Loss: 5.423e-03, Loss_u: 4.736e-03, Loss_r: 6.872e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.009
# adaptive_constant_res_val: 0.991
# It: 22000, Loss: 5.398e-03, Loss_u: 4.709e-03, Loss_r: 6.884e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.008
# adaptive_constant_res_val: 0.992
# It: 22100, Loss: 5.381e-03, Loss_u: 4.701e-03, Loss_r: 6.801e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.007
# adaptive_constant_res_val: 0.993
# It: 22200, Loss: 5.434e-03, Loss_u: 4.695e-03, Loss_r: 7.386e-04, Time: 0.21
# ...
# It: 32600, Loss: 4.259e-03, Loss_u: 3.762e-03, Loss_r: 4.969e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 32700, Loss: 4.254e-03, Loss_u: 3.751e-03, Loss_r: 5.028e-04, Time: 0.27
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 32800, Loss: 4.242e-03, Loss_u: 3.747e-03, Loss_r: 4.946e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 32900, Loss: 4.234e-03, Loss_u: 3.741e-03, Loss_r: 4.931e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 33000, Loss: 4.227e-03, Loss_u: 3.736e-03, Loss_r: 4.912e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 33100, Loss: 4.258e-03, Loss_u: 3.737e-03, Loss_r: 5.202e-04, Time: 0.27
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 33200, Loss: 4.216e-03, Loss_u: 3.717e-03, Loss_r: 4.992e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 33300, Loss: 4.214e-03, Loss_u: 3.722e-03, Loss_r: 4.922e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 33400, Loss: 4.193e-03, Loss_u: 3.707e-03, Loss_r: 4.858e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 33500, Loss: 4.185e-03, Loss_u: 3.701e-03, Loss_r: 4.834e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 33600, Loss: 4.176e-03, Loss_u: 3.694e-03, Loss_r: 4.825e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 33700, Loss: 4.172e-03, Loss_u: 3.691e-03, Loss_r: 4.807e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 33800, Loss: 4.198e-03, Loss_u: 3.691e-03, Loss_r: 5.073e-04, Time: 0.27
# adaptive_constant_bcs_val: 0.998
# adaptive_constant_res_val: 1.002
# It: 33900, Loss: 4.153e-03, Loss_u: 3.674e-03, Loss_r: 4.785e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 34000, Loss: 4.145e-03, Loss_u: 3.668e-03, Loss_r: 4.776e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 34100, Loss: 4.137e-03, Loss_u: 3.662e-03, Loss_r: 4.756e-04, Time: 0.28
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 34200, Loss: 4.130e-03, Loss_u: 3.654e-03, Loss_r: 4.764e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 34300, Loss: 4.122e-03, Loss_u: 3.649e-03, Loss_r: 4.731e-04, Time: 0.30
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 34400, Loss: 4.231e-03, Loss_u: 3.649e-03, Loss_r: 5.819e-04, Time: 0.27
# adaptive_constant_bcs_val: 0.991
# adaptive_constant_res_val: 1.009
# It: 34500, Loss: 4.106e-03, Loss_u: 3.637e-03, Loss_r: 4.696e-04, Time: 0.30
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 34600, Loss: 4.099e-03, Loss_u: 3.629e-03, Loss_r: 4.691e-04, Time: 0.32
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 34700, Loss: 4.110e-03, Loss_u: 3.618e-03, Loss_r: 4.919e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 34800, Loss: 4.087e-03, Loss_u: 3.619e-03, Loss_r: 4.679e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 34900, Loss: 4.145e-03, Loss_u: 3.626e-03, Loss_r: 5.195e-04, Time: 0.26
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 35000, Loss: 4.068e-03, Loss_u: 3.604e-03, Loss_r: 4.638e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 35100, Loss: 4.064e-03, Loss_u: 3.597e-03, Loss_r: 4.672e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 35200, Loss: 4.058e-03, Loss_u: 3.595e-03, Loss_r: 4.637e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 35300, Loss: 4.093e-03, Loss_u: 3.601e-03, Loss_r: 4.921e-04, Time: 0.26
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 35400, Loss: 4.044e-03, Loss_u: 3.584e-03, Loss_r: 4.598e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 35500, Loss: 4.031e-03, Loss_u: 3.574e-03, Loss_r: 4.570e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 35600, Loss: 4.023e-03, Loss_u: 3.567e-03, Loss_r: 4.560e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 35700, Loss: 4.017e-03, Loss_u: 3.561e-03, Loss_r: 4.561e-04, Time: 0.28
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 35800, Loss: 4.009e-03, Loss_u: 3.555e-03, Loss_r: 4.542e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 35900, Loss: 4.002e-03, Loss_u: 3.549e-03, Loss_r: 4.524e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 36000, Loss: 3.994e-03, Loss_u: 3.544e-03, Loss_r: 4.508e-04, Time: 0.33
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 36100, Loss: 3.996e-03, Loss_u: 3.535e-03, Loss_r: 4.606e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 36200, Loss: 3.980e-03, Loss_u: 3.532e-03, Loss_r: 4.487e-04, Time: 0.27
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 36300, Loss: 3.975e-03, Loss_u: 3.527e-03, Loss_r: 4.479e-04, Time: 0.27
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 36400, Loss: 3.970e-03, Loss_u: 3.520e-03, Loss_r: 4.505e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 36500, Loss: 3.959e-03, Loss_u: 3.514e-03, Loss_r: 4.450e-04, Time: 0.30
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 36600, Loss: 3.952e-03, Loss_u: 3.508e-03, Loss_r: 4.439e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 36700, Loss: 3.986e-03, Loss_u: 3.512e-03, Loss_r: 4.740e-04, Time: 0.22
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 36800, Loss: 3.938e-03, Loss_u: 3.497e-03, Loss_r: 4.409e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 36900, Loss: 3.931e-03, Loss_u: 3.491e-03, Loss_r: 4.402e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 37000, Loss: 3.924e-03, Loss_u: 3.486e-03, Loss_r: 4.382e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 37100, Loss: 3.917e-03, Loss_u: 3.479e-03, Loss_r: 4.378e-04, Time: 0.28
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 37200, Loss: 3.911e-03, Loss_u: 3.475e-03, Loss_r: 4.365e-04, Time: 0.28
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 37300, Loss: 3.904e-03, Loss_u: 3.469e-03, Loss_r: 4.349e-04, Time: 0.32
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 37400, Loss: 3.897e-03, Loss_u: 3.462e-03, Loss_r: 4.342e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 37500, Loss: 3.901e-03, Loss_u: 3.460e-03, Loss_r: 4.410e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 37600, Loss: 3.883e-03, Loss_u: 3.452e-03, Loss_r: 4.315e-04, Time: 0.31
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 37700, Loss: 3.877e-03, Loss_u: 3.446e-03, Loss_r: 4.304e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 37800, Loss: 3.870e-03, Loss_u: 3.440e-03, Loss_r: 4.298e-04, Time: 0.29
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 37900, Loss: 3.863e-03, Loss_u: 3.435e-03, Loss_r: 4.285e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 38000, Loss: 3.857e-03, Loss_u: 3.429e-03, Loss_r: 4.276e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 38100, Loss: 3.850e-03, Loss_u: 3.424e-03, Loss_r: 4.263e-04, Time: 0.27
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 38200, Loss: 3.844e-03, Loss_u: 3.418e-03, Loss_r: 4.255e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 38300, Loss: 3.907e-03, Loss_u: 3.409e-03, Loss_r: 4.973e-04, Time: 0.23
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 38400, Loss: 3.831e-03, Loss_u: 3.408e-03, Loss_r: 4.231e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.005
# adaptive_constant_res_val: 0.995
# It: 38500, Loss: 3.825e-03, Loss_u: 3.401e-03, Loss_r: 4.239e-04, Time: 0.27
# adaptive_constant_bcs_val: 1.005
# adaptive_constant_res_val: 0.995
# It: 38600, Loss: 3.818e-03, Loss_u: 3.398e-03, Loss_r: 4.205e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 38700, Loss: 3.812e-03, Loss_u: 3.393e-03, Loss_r: 4.191e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 38800, Loss: 3.805e-03, Loss_u: 3.387e-03, Loss_r: 4.187e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 38900, Loss: 3.802e-03, Loss_u: 3.384e-03, Loss_r: 4.183e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 39000, Loss: 3.793e-03, Loss_u: 3.376e-03, Loss_r: 4.168e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 39100, Loss: 3.787e-03, Loss_u: 3.372e-03, Loss_r: 4.150e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 39200, Loss: 3.780e-03, Loss_u: 3.366e-03, Loss_r: 4.142e-04, Time: 0.27
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 39300, Loss: 3.778e-03, Loss_u: 3.365e-03, Loss_r: 4.139e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 39400, Loss: 3.769e-03, Loss_u: 3.355e-03, Loss_r: 4.142e-04, Time: 0.23
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 39500, Loss: 3.766e-03, Loss_u: 3.354e-03, Loss_r: 4.124e-04, Time: 0.26
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 39600, Loss: 3.759e-03, Loss_u: 3.344e-03, Loss_r: 4.149e-04, Time: 0.25
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 39700, Loss: 3.752e-03, Loss_u: 3.339e-03, Loss_r: 4.120e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 39800, Loss: 3.750e-03, Loss_u: 3.334e-03, Loss_r: 4.154e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 39900, Loss: 3.747e-03, Loss_u: 3.328e-03, Loss_r: 4.194e-04, Time: 0.24
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 3.737e-03, Loss_u: 3.328e-03, Loss_r: 4.083e-04, Time: 4.98
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# l2 error: 3.62e-02
# l2 error: 6.88e-02
# average lambda_bc: 9.9827e-01
# average lambda_res: 1.0
# Save uv NN parameters successfully in %s ...checkpoints/Dec-17-2023_13-47-08-589081_relobralo
# Final loss total loss: 3.735901e-03
# Final loss loss_res: 4.116905e-04
# Final loss loss_bc1: 1.196025e-03
# Final loss loss_bc2: 7.903015e-04
# Final loss loss_bc3: 1.327136e-03
# Final loss loss_bc4: 1.074830e-05
# elapsed: 1.14e+04
# Relative L2 error_u: 3.62e-02
# Relative L2 error_v: 6.88e-02
#
#
# Method: full_batch
#
# average of time_list:1.1377e+04
# average of error_u_list:3.6234e-02
# average of error_v_list:6.8754e-02

# %%
mode.print('elapsed: {:.2e}'.format(elapsed))
mode.print('Relative L2 error_u: {:.2e}'.format(error_u))
mode.print('Relative L2 error_v: {:.2e}'.format(error_v))
# Out:
# elapsed: 1.66e+02
# Relative L2 error_u: 3.04e-01
# Relative L2 error_v: 9.55e-01

# %%
# sess.close
mode.plot_lambda()

# mode.plot_grad()
mode.save_NN()
mode.plt_prediction( X , Y , X_star , u_ref , u_pred , v_ref , v_pred)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_18261/34445444.py in <module>
#       3
#       4 # mode.plot_grad()
# ----> 5 mode.save_NN()
#       6 mode.plt_prediction( X , Y , X_star , u_ref , u_pred , v_ref , v_pred)
#
# /tmp/ipykernel_18261/2555440992.py in save_NN(self)
#     519     def save_NN(self):
#     520
# --> 521         uv_weights = self.sess.run(self.weights)
#     522         uv_biases = self.sess.run(self.biases)
#     523
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1101     # Check session.
#    1102     if self._closed:
# -> 1103       raise RuntimeError('Attempted to use a closed Session.')
#    1104     if self.graph.version == 0:
#    1105       raise RuntimeError('The Session graph is empty.  Add operations to the '
#
# RuntimeError: Attempted to use a closed Session.

# %%
def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
    from mpl_toolkits.axes_grid1 import ImageGrid

    ### Plot ###

    # Exact solution & Predicted solution
    # Exact soluton
    U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

    # Predicted solution
    U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
    F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

    titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $v(x)$' , 'Predicted $v(x)$' , 'Absolute error']
    data = [U_star.T , U_pred ,  np.abs(U_star.T - U_pred) , F_star.T , F_pred ,  np.abs(F_star.T - F_pred) ]

    fig_1 = plt.figure(1, figsize=(13, 5))
    grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                    label_mode="1", axes_pad=1.7, share_all=False, 
                    cbar_mode="each", cbar_location="right", 
                    cbar_size="5%", cbar_pad=0.0)
# CREATE ARGUMENTS DICT FOR CONTOURPLOTS
    minmax_list = []
    for d in data:
        # if(local):
        #     minmax_list.append([np.min(d), np.max(d)])
        # else:
        minmax_list.append([np.min(d), np.max(d)])

        # kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60), cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

    for ax, z, minmax, title in zip(grid, data, minmax_list, titles):
    #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
        #pcfsets.append(pcf)
        # if (timeStp == 0):
        pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
        cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
        ax.cax.tick_params(labelsize=14.5)
        ax.set_title(title, fontsize=14.5, pad=7)
        ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
        ax.set_xlabel("x", fontsize=14.5)
        ax.tick_params(labelsize=14.5)
        ax.set_xlim(x1.min(), x1.max())
        ax.set_ylim(x2.min(), x2.max())
        ax.set_aspect("equal")

    fig_1.set_size_inches(15, 10, True)
    fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
    plt.tight_layout()
    plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
    plt.close("all" , )

# %%
u_ref.flatten()[:,None].shape
# Out:
# (10000, 1)

# %%
# Out:
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)

# %%
v_pred.shape
# Out:
# (100, 100)

# %%
import scipy.io

mode = 'M2'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = [1831.07 , ]
error_u_list = [0.2112 , 0.]
error_v_list = [0.3271 , 0.]
error_p_list = [0.094 , 0.]

for mtd in methods:
    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ,  error_p_list]


##Full Batch
time_list = [8048.86 , ]
error_u_list = [ 0.0367 ,0. ]
error_v_list = [0.0706 , 0.]
error_p_list = [0.465 , 0.]

for mtd in methods:
    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ,  error_p_list]


scipy.io.savemat("./dataset/NS_model_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
### Plot ###
###########

# %%
# Test Data
nx = 100
ny = 100  # change to 100
x = np.linspace(0.0, 1.0, nx)
y = np.linspace(0.0, 1.0, ny)
X, Y = np.meshgrid(x, y)

X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))

# Predictions
psi_pred, p_pred = mode.predict_psi_p(X_star)
u_pred, v_pred = mode.predict_uv(X_star)

psi_star = griddata(X_star, psi_pred.flatten(), (X, Y), method='cubic')
p_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
u_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
v_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')

velocity = np.sqrt(u_pred**2 + v_pred**2)
velocity_star = griddata(X_star, velocity.flatten(), (X, Y), method='cubic')

# Reference
u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

# Relative error
error = np.linalg.norm(u_star - u_pred.T, 2) / np.linalg.norm(u_star, 2)
print('l2 error: {:.2e}'.format(error))
error = np.linalg.norm(v_star - v_pred.T, 2) / np.linalg.norm(v_star, 2)
print('l2 error: {:.2e}'.format(error))
error = np.linalg.norm(p_pred - p_star.T, 2) / np.linalg.norm(p_star, 2)
print('l2 error: {:.2e}'.format(error))

### Plot ###
###########

# %%
# Reference solution & Prediceted solution
fig_1 = plt.figure(1, figsize=(18, 5))
fig_1.add_subplot(1, 3, 1)
plt.pcolor(X.T, Y.T, velocity_ref, cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Reference Velocity')

fig_1.add_subplot(1, 3, 2)
plt.pcolor(x, Y, velocity_star, cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Predicted Velocity')
plt.tight_layout()

fig_1.add_subplot(1, 3, 3)
plt.pcolor(X, Y, np.abs(velocity_star - velocity_ref.T), cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Absolute Error')
plt.show()

# %%
    ## Loss ##
loss_res = mode.loss_res_log
loss_bcs = mode.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
## Adaptive Constant
adaptive_constant = mode.adpative_constant_bcs_log
    
fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# %%
## Gradients #
data_gradients_res = mode.dict_gradients_res_layers
data_gradients_bcs = mode.dict_gradients_bcs_layers

num_hidden_layers = len(layers) -1
cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_{u_b}$')

    # ax.get_legend().remove()
    ax.set_xlim([-1.0, 1.0])
    ax.set_ylim([0, 100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()

fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()
