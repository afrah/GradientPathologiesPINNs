# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import pandas as pd
# from NS_model_tf import Sampler, Navier_Stokes2D
import os
os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import scipy
import scipy.io
import time

import sys

import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle
def U_gamma_1(x):
    num = x.shape[0]
    return np.tile(np.array([1.0, 0.0]), (num, 1))


def U_gamma_2(x):
    num = x.shape[0]
    return np.zeros((num, 2))


def f(x):
    num = x.shape[0]
    return np.zeros((num, 2))

def operator(psi, p, x, y, Re, sigma_x=1.0, sigma_y=1.0):
    u = tf.gradients(psi, y)[0] / sigma_y
    v = - tf.gradients(psi, x)[0] / sigma_x

    u_x = tf.gradients(u, x)[0] / sigma_x
    u_y = tf.gradients(u, y)[0] / sigma_y

    v_x = tf.gradients(v, x)[0] / sigma_x
    v_y = tf.gradients(v, y)[0] / sigma_y

    p_x = tf.gradients(p, x)[0] / sigma_x
    p_y = tf.gradients(p, y)[0] / sigma_y

    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    u_yy = tf.gradients(u_y, y)[0] / sigma_y

    v_xx = tf.gradients(v_x, x)[0] / sigma_x
    v_yy = tf.gradients(v_y, y)[0] / sigma_y

    Ru_momentum = u * u_x + v * u_y + p_x - (u_xx + u_yy) / Re
    Rv_momentum = u * v_x + v * v_y + p_y - (v_xx + v_yy) / Re

    return Ru_momentum, Rv_momentum

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Navier_Stokes2D:
    def __init__(self, layers, operator, bcs_sampler, res_sampler, Re, mode , sess):


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]
        self.mu_y, self.sigma_y = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler


        # Navier Stokes constant
        self.Re = tf.constant(Re, dtype=tf.float32)

        # Adaptive re-weighting constant
        self.beta = 0.9
        self.adaptive_constant_bcs_val = np.array(1.0)

        # Define Tensorflow session
        self.sess = sess

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)


        # Define placeholders and computational graph
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc1_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc2_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc3_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc4_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.adaptive_constant_bcs_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs_val.shape)

        # Evaluate predictions
        self.u_bc1_pred, self.v_bc1_pred = self.net_uv(self.x_bc1_tf, self.y_bc1_tf)
        self.u_bc2_pred, self.v_bc2_pred = self.net_uv(self.x_bc2_tf, self.y_bc2_tf)
        self.u_bc3_pred, self.v_bc3_pred = self.net_uv(self.x_bc3_tf, self.y_bc3_tf)
        self.u_bc4_pred, self.v_bc4_pred = self.net_uv(self.x_bc4_tf, self.y_bc4_tf)

        self.U_bc1_pred = tf.concat([self.u_bc1_pred, self.v_bc1_pred], axis=1)
        self.U_bc2_pred = tf.concat([self.u_bc2_pred, self.v_bc2_pred], axis=1)
        self.U_bc3_pred = tf.concat([self.u_bc3_pred, self.v_bc3_pred], axis=1)
        self.U_bc4_pred = tf.concat([self.u_bc4_pred, self.v_bc4_pred], axis=1)

        self.psi_pred, self.p_pred = self.net_psi_p(self.x_u_tf, self.y_u_tf)
        self.u_pred, self.v_pred = self.net_uv(self.x_u_tf, self.y_u_tf)
        self.u_momentum_pred, self.v_momentum_pred = self.net_r(self.x_r_tf, self.y_r_tf)

        # Residual loss
        self.loss_u_momentum = tf.reduce_mean(tf.square(self.u_momentum_pred))
        self.loss_v_momentum = tf.reduce_mean(tf.square(self.v_momentum_pred))

        self.loss_res = self.loss_u_momentum + self.loss_v_momentum
        
        # Boundary loss
        self.loss_bc1 = tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.U_bc2_pred))
        self.loss_bc3 = tf.reduce_mean(tf.square(self.U_bc3_pred))
        self.loss_bc4 = tf.reduce_mean(tf.square(self.U_bc4_pred))
        
        self.loss_bcs = self.adaptive_constant_bcs_tf * tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf) +tf.square(self.U_bc2_pred) + tf.square(self.U_bc3_pred) + tf.square(self.U_bc4_pred))
        
        # Total loss
        self.loss = self.loss_res + self.loss_bcs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bc1 , self.loss_bc2 , self.loss_bc3, self.loss_bc4] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bc1", "loss_bc2", "loss_bc3", "loss_bc4"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_res_log = []
        self.loss_bcs_log = []
        # self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_bcs = []
        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])

        self.adpative_constant_bcs_list = []
        self.adpative_constant_res_list = []
        self.adpative_constant_bcs_log = []

        for i in range(len(self.layers) - 1):
            self.adpative_constant_res_list.append( tf.reduce_max(tf.abs(self.grad_res[i])))
            self.adpative_constant_bcs_list.append(  tf.reduce_mean(tf.abs(self.grad_bcs[i])))

        self.adaptive_constant_bcs = tf.reduce_max(tf.stack(self.adpative_constant_res_list))/  tf.reduce_mean(tf.stack(self.adpative_constant_bcs_list))




        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bc1 ,  self.loss_bc2 ,  self.loss_bc3  ,  self.loss_bc4] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs1" , "loss_bcs2", "loss_bcs3" ,  "loss_bcs4"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)

        init = tf.global_variables_initializer()
        self.sess.run(init)
        

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev, dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H


    # Forward pass for stream-pressure formulation
    def net_psi_p(self, x, y):
        psi_p = self.forward_pass(tf.concat([x, y], 1))
        psi = psi_p[:, 0:1]
        p = psi_p[:, 1:2]
        return psi, p

    # Forward pass for velocities
    def net_uv(self, x, y):
        psi, p = self.net_psi_p(x, y)
        u = tf.gradients(psi, y)[0] / self.sigma_y
        v = - tf.gradients(psi, x)[0] / self.sigma_x
        return u, v

    # Forward pass for residual
    def net_r(self, x, y):
        psi, p = self.net_psi_p(x, y)
        u_momentum_pred, v_momentum_pred = self.operator(psi, p, x, y,
                                                         self.Re,
                                                         self.sigma_x, self.sigma_y)

        return u_momentum_pred, v_momentum_pred

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
    def train(self, nIter ,  bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        batch_size = bcbatch_size
        X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
        X_bc3_batch, _ = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
        X_bc4_batch, _ = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

        # Fetch residual mini-batch
        batch_size = ubatch_size

        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                    self.U_bc1_tf: u_bc1_batch,
                    self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                    self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                    self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                    self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val
                    }
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)

                # Compute the adaptive constant
                adaptive_constant_bcs_val = self.sess.run(self.adaptive_constant_bcs, tf_dict)

                self.adaptive_constant_bcs_val = adaptive_constant_bcs_val *  (1.0 - self.beta) + self.beta * self.adaptive_constant_bcs_val

                # self.adpative_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                # self.loss_bcs_log.append(loss_u_value)
                # self.loss_res_log.append(loss_r_value)

                print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' % (it, loss_value, loss_u_value, loss_r_value, elapsed))

                print("constant_bcs_val: {:.3f}".format(self.adaptive_constant_bcs_val))
                start_time = timeit.default_timer()

            sys.stdout.flush()
            start_time = timeit.default_timer()

            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
            # # Store gradients
            # if it % 10000 == 0:
            #     self.save_gradients(tf_dict)
            #     print("Gradients information stored ...")

   # Trains the model by minimizing the MSE loss
    def trainmb(self, nIter, batch_size):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, _ = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, _ = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                       self.U_bc1_tf: u_bc1_batch,
                       self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                       self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                       self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                       self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                       self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val
                       }

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)
                self.print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' % (it, loss_value, loss_u_value, loss_r_value, elapsed))

                if it % 10 == 0:

                    # Compute the adaptive constant
                    adaptive_constant_bcs_val = self.sess.run(self.adaptive_constant_bcs, tf_dict)

                    self.adaptive_constant_bcs_val = adaptive_constant_bcs_val *  (1.0 - self.beta) + self.beta * self.adaptive_constant_bcs_val

                    self.adpative_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                    # self.loss_bcs_log.append(loss_u_value)
                    # self.loss_res_log.append(loss_r_value)


                    self.print("constant_bcs_val: {:.3f}".format(self.adaptive_constant_bcs_val))

  
            sys.stdout.flush()

            start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])


    # Evaluates predictions at test points
    def predict_psi_p(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2]}
        psi_star = self.sess.run(self.psi_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)
        return psi_star, p_star

    def predict_uv(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        return u_star, v_star



 ############################################################

    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values

    def plot_loss_history(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.show()
    ############################################################
  
  # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1    = self.sess.run([ self.grad_res[i],self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=3)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        plt.close("all" , )
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
        from mpl_toolkits.axes_grid1 import ImageGrid

        ### Plot ###

        # Exact solution & Predicted solution
        # Exact soluton
        U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
        F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

        # Predicted solution
        U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
        F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

        titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $v(x)$' , 'Predicted $v(x)$' , 'Absolute error']
        data = [U_star.T , U_pred ,  np.abs(U_star.T - U_pred) , F_star.T , F_pred ,  np.abs(F_star.T - F_pred) ]

        fig_1 = plt.figure(1, figsize=(13, 5))
        grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                        label_mode="1", axes_pad=1.7, share_all=False, 
                        cbar_mode="each", cbar_location="right", 
                        cbar_size="5%", cbar_pad=0.0)
    # CREATE ARGUMENTS DICT FOR CONTOURPLOTS
        minmax_list = []
        for d in data:
            # if(local):
            #     minmax_list.append([np.min(d), np.max(d)])
            # else:
            minmax_list.append([np.min(d), np.max(d)])

            # kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60), cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

        for ax, z, minmax, title in zip(grid, data, minmax_list, titles):
        #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
            #pcfsets.append(pcf)
            # if (timeStp == 0):
            pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
            cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
            ax.cax.tick_params(labelsize=14.5)
            ax.set_title(title, fontsize=14.5, pad=7)
            ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
            ax.set_xlabel("x", fontsize=14.5)
            ax.tick_params(labelsize=14.5)
            ax.set_xlim(x1.min(), x1.max())
            ax.set_ylim(x2.min(), x2.max())
            ax.set_aspect("equal")

        fig_1.set_size_inches(15, 10, True)
        fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
        plt.close("all" , )


    def plot_grad(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adpative_constant_bcs_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc}}}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)
        plt.close("all" , )

# %%
#        [elapsed, error_u , error_v ,  error_p] = test_method(mtd , layers, operator, bcs_sampler, res_sampler ,Re , stiff_ratio ,  X_star , X , Y)

def test_method(method , layers, operator, bcs_sampler, res_sampler, Re ,  mode , X_star , X , Y , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):


    model = Navier_Stokes2D(layers, operator, bcs_sampler, res_sampler, Re, mode)

    # Train model
    start_time = time.time()

    if method =="full_batch":
        model.train(nIter  , bcbatch_size , ubatch_size  )
    elif method =="mini_batch":
        model.trainmb(nIter, mbbatch_size)
    else:
        print("unknown method!")
    elapsed = time.time() - start_time

    # Predictions
    _, p_pred = model.predict_psi_p(X_star)
    u_pred, v_pred = model.predict_uv(X_star)

    # psi_star = griddata(X_star, psi_pred.flatten(), (X, Y), method='cubic')
    p_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
    # u_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
    # v_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')

    # velocity = np.sqrt(u_pred**2 + v_pred**2)
    # velocity_star = griddata(X_star, velocity.flatten(), (X, Y), method='cubic')

    # Reference
    u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
    v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
    # velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

    u_pred = u_pred.reshape(100,100)
    v_pred = v_pred.reshape(100,100)
    p_pred = p_pred.reshape(100,100)

    # Relative error
    error_u = np.linalg.norm(u_ref - u_pred.T, 2) / np.linalg.norm(u_ref, 2)
    print('l2 error: {:.2e}'.format(error_u))
    error_v = np.linalg.norm(v_ref - v_pred.T, 2) / np.linalg.norm(v_ref, 2)
    print('l2 error: {:.2e}'.format(error_v))
    error_p = np.linalg.norm(p_pred - p_star.T, 2) / np.linalg.norm(p_star, 2)
    print('l2 error: {:.2e}'.format(error_p))

    return [elapsed, error_u , error_v ,error_p ]

# %%
nIter =40001
bcbatch_size = 350
ubatch_size = 5000
mbbatch_size = 128

# Parameters of equations
Re = 100.0

# Domain boundaries
bc1_coords = np.array([[0.0, 1.0], [1.0, 1.0]])
bc2_coords = np.array([[0.0, 0.0], [0.0, 1.0]])
bc3_coords = np.array([[1.0, 0.0], [1.0, 1.0]])
bc4_coords = np.array([[0.0, 0.0], [1.0, 0.0]])
dom_coords = np.array([[0.0, 0.0], [1.0, 1.0]])

# Define model
model = 'M2'
layers = [2, 50, 50, 50, 50 , 50 , 2]

stiff_ratio = False  # Log the eigenvalues of Hessian of losses


# Test Data
nx = 100
ny = 100  # change to 100
x = np.linspace(0.0, 1.0, nx)
y = np.linspace(0.0, 1.0, ny)
X, Y = np.meshgrid(x, y)


X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))


iterations = 1
methods = ["mini_batch" ]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_v_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create boundary conditions samplers
        bc1 = Sampler(2, bc1_coords, lambda x: U_gamma_1(x), name='Dirichlet BC1')
        bc2 = Sampler(2, bc2_coords, lambda x: U_gamma_2(x), name='Dirichlet BC2')
        bc3 = Sampler(2, bc3_coords, lambda x: U_gamma_2(x), name='Dirichlet BC3')
        bc4 = Sampler(2, bc4_coords, lambda x: U_gamma_2(x), name='Dirichlet BC4')
        bcs_sampler = [bc1, bc2, bc3, bc4]

        # Create residual sampler
        res_sampler = Sampler(2, dom_coords, lambda x: f(x), name='Forcing')

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            mode = Navier_Stokes2D(layers, operator, bcs_sampler, res_sampler, Re, model , sess)

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                mode.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                mode.trainmb(nIter, mbbatch_size)
            else:
                mode.print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            _, p_pred = mode.predict_psi_p(X_star)
            u_pred, v_pred = mode.predict_uv(X_star)

            # Reference
            u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
            v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
            # velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

            u_pred = u_pred.reshape(100,100)
            v_pred = v_pred.reshape(100,100)

            # Relative error
            error_u = np.linalg.norm(u_ref - u_pred.T, 2) / np.linalg.norm(u_ref, 2)
            error_v = np.linalg.norm(v_ref - v_pred.T, 2) / np.linalg.norm(v_ref, 2)

            mode.print('l2 error: {:.2e}'.format(error_u))
            mode.print('l2 error: {:.2e}'.format(error_v))

       
            mode.print("average lambda_bc" , np.average(mode.adpative_constant_bcs_log))
            mode.print("average lambda_res" , str(1.0))
            # sess.close
            mode.plot_grad()
            mode.save_NN()
            mode.plt_prediction( X , Y , X_star , u_ref , u_pred , v_ref , v_pred)


        mode.print('elapsed: {:.2e}'.format(elapsed))
        mode.print('Relative L2 error_u: {:.2e}'.format(error_u))
        mode.print('Relative L2 error_v: {:.2e}'.format(error_v))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_v_list.append(error_v)

    mode.print("\n\nMethod: ", mtd)
    mode.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    mode.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    mode.print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )

    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(mode.dirname,""+mtd+"_Lid-driven-Cavity_"+model+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_57234/2070537285.py:59: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_57234/2070537285.py:60: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_57234/2070537285.py:61: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_57234/2070537285.py:61: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-12 22:33:06.224006: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-12 22:33:06.253457: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-12 22:33:06.253919: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f7cfdcd910 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-12 22:33:06.253937: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-12 22:33:06.254976: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_57234/2922420956.py:164: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_57234/2922420956.py:51: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_57234/2922420956.py:110: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_57234/2922420956.py:113: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_57234/2922420956.py:155: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# It: 0, Loss: 6.692e-01, Loss_u: 4.577e-01, Loss_r: 2.115e-01, Time: 69.97
# constant_bcs_val: 2.509
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 10, Loss: 9.088e-01, Loss_u: 8.261e-01, Loss_r: 8.271e-02, Time: 0.06
# constant_bcs_val: 2.819
# It: 20, Loss: 6.716e-01, Loss_u: 6.204e-01, Loss_r: 5.126e-02, Time: 0.04
# constant_bcs_val: 3.207
# It: 30, Loss: 4.652e-01, Loss_u: 4.210e-01, Loss_r: 4.421e-02, Time: 0.05
# constant_bcs_val: 3.823
# It: 40, Loss: 5.372e-01, Loss_u: 4.798e-01, Loss_r: 5.744e-02, Time: 0.05
# constant_bcs_val: 4.066
# It: 50, Loss: 4.870e-01, Loss_u: 4.679e-01, Loss_r: 1.911e-02, Time: 0.07
# constant_bcs_val: 3.973
# It: 60, Loss: 3.781e-01, Loss_u: 3.541e-01, Loss_r: 2.393e-02, Time: 0.05
# constant_bcs_val: 3.888
# It: 70, Loss: 3.805e-01, Loss_u: 3.553e-01, Loss_r: 2.523e-02, Time: 0.06
# constant_bcs_val: 4.351
# It: 80, Loss: 4.432e-01, Loss_u: 4.127e-01, Loss_r: 3.047e-02, Time: 0.07
# constant_bcs_val: 4.567
# It: 90, Loss: 3.953e-01, Loss_u: 3.752e-01, Loss_r: 2.013e-02, Time: 0.04
# constant_bcs_val: 4.259
# It: 100, Loss: 3.309e-01, Loss_u: 3.088e-01, Loss_r: 2.211e-02, Time: 0.05
# constant_bcs_val: 4.552
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 110, Loss: 3.091e-01, Loss_u: 2.894e-01, Loss_r: 1.963e-02, Time: 0.04
# constant_bcs_val: 4.622
# It: 120, Loss: 3.247e-01, Loss_u: 3.076e-01, Loss_r: 1.714e-02, Time: 0.05
# constant_bcs_val: 4.368
# It: 130, Loss: 2.917e-01, Loss_u: 2.761e-01, Loss_r: 1.561e-02, Time: 0.04
# constant_bcs_val: 4.566
# It: 140, Loss: 3.272e-01, Loss_u: 3.047e-01, Loss_r: 2.256e-02, Time: 0.05
# constant_bcs_val: 4.584
# It: 150, Loss: 2.657e-01, Loss_u: 2.488e-01, Loss_r: 1.693e-02, Time: 0.06
# constant_bcs_val: 4.653
# It: 160, Loss: 3.091e-01, Loss_u: 2.945e-01, Loss_r: 1.460e-02, Time: 0.05
# constant_bcs_val: 4.522
# It: 170, Loss: 2.493e-01, Loss_u: 2.307e-01, Loss_r: 1.855e-02, Time: 0.04
# constant_bcs_val: 4.753
# It: 180, Loss: 2.364e-01, Loss_u: 2.128e-01, Loss_r: 2.355e-02, Time: 0.05
# constant_bcs_val: 4.919
# It: 190, Loss: 1.471e-01, Loss_u: 1.246e-01, Loss_r: 2.255e-02, Time: 0.05
# constant_bcs_val: 4.800
# It: 200, Loss: 1.949e-01, Loss_u: 1.752e-01, Loss_r: 1.963e-02, Time: 0.04
# constant_bcs_val: 4.494
# It: 210, Loss: 1.404e-01, Loss_u: 1.198e-01, Loss_r: 2.059e-02, Time: 0.05
# constant_bcs_val: 4.807
# It: 220, Loss: 2.040e-01, Loss_u: 1.875e-01, Loss_r: 1.657e-02, Time: 0.05
# constant_bcs_val: 4.404
# It: 230, Loss: 1.849e-01, Loss_u: 1.652e-01, Loss_r: 1.973e-02, Time: 0.05
# constant_bcs_val: 4.234
# It: 240, Loss: 1.308e-01, Loss_u: 1.095e-01, Loss_r: 2.128e-02, Time: 0.05
# constant_bcs_val: 4.441
# It: 250, Loss: 1.955e-01, Loss_u: 1.821e-01, Loss_r: 1.332e-02, Time: 0.04
# constant_bcs_val: 4.195
# It: 260, Loss: 1.791e-01, Loss_u: 1.585e-01, Loss_r: 2.054e-02, Time: 0.05
# constant_bcs_val: 4.115
# It: 270, Loss: 1.424e-01, Loss_u: 1.213e-01, Loss_r: 2.113e-02, Time: 0.05
# constant_bcs_val: 4.335
# It: 280, Loss: 1.617e-01, Loss_u: 1.433e-01, Loss_r: 1.845e-02, Time: 0.04
# constant_bcs_val: 4.662
# It: 290, Loss: 1.366e-01, Loss_u: 1.129e-01, Loss_r: 2.369e-02, Time: 0.04
# constant_bcs_val: 4.969
# It: 300, Loss: 1.758e-01, Loss_u: 1.555e-01, Loss_r: 2.028e-02, Time: 0.05
# constant_bcs_val: 5.371
# It: 310, Loss: 1.808e-01, Loss_u: 1.536e-01, Loss_r: 2.718e-02, Time: 0.05
# constant_bcs_val: 5.852
# It: 320, Loss: 1.523e-01, Loss_u: 1.357e-01, Loss_r: 1.654e-02, Time: 0.05
# constant_bcs_val: 5.922
# It: 330, Loss: 1.758e-01, Loss_u: 1.650e-01, Loss_r: 1.085e-02, Time: 0.08
# constant_bcs_val: 5.465
# It: 340, Loss: 1.304e-01, Loss_u: 1.085e-01, Loss_r: 2.197e-02, Time: 0.04
# constant_bcs_val: 5.834
# It: 350, Loss: 1.971e-01, Loss_u: 1.795e-01, Loss_r: 1.758e-02, Time: 0.04
# constant_bcs_val: 5.441
# It: 360, Loss: 1.400e-01, Loss_u: 1.209e-01, Loss_r: 1.909e-02, Time: 0.04
# constant_bcs_val: 5.205
# It: 370, Loss: 1.860e-01, Loss_u: 1.713e-01, Loss_r: 1.470e-02, Time: 0.07
# constant_bcs_val: 4.893
# It: 380, Loss: 1.566e-01, Loss_u: 1.419e-01, Loss_r: 1.472e-02, Time: 0.07
# constant_bcs_val: 4.775
# It: 390, Loss: 1.131e-01, Loss_u: 9.881e-02, Loss_r: 1.425e-02, Time: 0.10
# constant_bcs_val: 4.599
# It: 400, Loss: 1.425e-01, Loss_u: 1.294e-01, Loss_r: 1.304e-02, Time: 0.06
# constant_bcs_val: 4.301
# It: 410, Loss: 1.434e-01, Loss_u: 1.334e-01, Loss_r: 9.993e-03, Time: 0.05
# constant_bcs_val: 4.347
# It: 420, Loss: 7.946e-02, Loss_u: 6.524e-02, Loss_r: 1.422e-02, Time: 0.07
# constant_bcs_val: 4.494
# It: 430, Loss: 1.445e-01, Loss_u: 1.303e-01, Loss_r: 1.425e-02, Time: 0.08
# constant_bcs_val: 4.756
# It: 440, Loss: 1.457e-01, Loss_u: 1.351e-01, Loss_r: 1.060e-02, Time: 0.08
# constant_bcs_val: 4.601
# It: 450, Loss: 1.399e-01, Loss_u: 1.268e-01, Loss_r: 1.314e-02, Time: 0.08
# constant_bcs_val: 4.395
# It: 460, Loss: 1.410e-01, Loss_u: 1.271e-01, Loss_r: 1.389e-02, Time: 0.08
# constant_bcs_val: 4.116
# It: 470, Loss: 1.648e-01, Loss_u: 1.547e-01, Loss_r: 1.015e-02, Time: 0.08
# constant_bcs_val: 4.016
# It: 480, Loss: 1.418e-01, Loss_u: 1.180e-01, Loss_r: 2.377e-02, Time: 0.09
# constant_bcs_val: 5.147
# It: 490, Loss: 1.777e-01, Loss_u: 1.467e-01, Loss_r: 3.101e-02, Time: 0.09
# constant_bcs_val: 5.186
# It: 500, Loss: 1.980e-01, Loss_u: 1.719e-01, Loss_r: 2.607e-02, Time: 0.05
# constant_bcs_val: 5.382
# It: 510, Loss: 1.767e-01, Loss_u: 1.586e-01, Loss_r: 1.805e-02, Time: 0.07
# constant_bcs_val: 5.309
# It: 520, Loss: 1.094e-01, Loss_u: 9.414e-02, Loss_r: 1.529e-02, Time: 0.06
# constant_bcs_val: 5.157
# It: 530, Loss: 1.830e-01, Loss_u: 1.634e-01, Loss_r: 1.960e-02, Time: 0.07
# constant_bcs_val: 5.877
# It: 540, Loss: 1.366e-01, Loss_u: 1.212e-01, Loss_r: 1.533e-02, Time: 0.10
# constant_bcs_val: 5.720
# It: 550, Loss: 1.699e-01, Loss_u: 1.551e-01, Loss_r: 1.482e-02, Time: 0.07
# constant_bcs_val: 5.567
# It: 560, Loss: 1.529e-01, Loss_u: 1.314e-01, Loss_r: 2.148e-02, Time: 0.08
# constant_bcs_val: 5.676
# It: 570, Loss: 1.242e-01, Loss_u: 1.090e-01, Loss_r: 1.517e-02, Time: 0.08
# constant_bcs_val: 5.602
# It: 580, Loss: 1.571e-01, Loss_u: 1.433e-01, Loss_r: 1.377e-02, Time: 0.07
# constant_bcs_val: 5.468
# It: 590, Loss: 1.905e-01, Loss_u: 1.748e-01, Loss_r: 1.571e-02, Time: 0.09
# constant_bcs_val: 5.096
# It: 600, Loss: 1.351e-01, Loss_u: 1.167e-01, Loss_r: 1.842e-02, Time: 0.09
# constant_bcs_val: 5.653
# It: 610, Loss: 3.174e-01, Loss_u: 3.056e-01, Loss_r: 1.181e-02, Time: 0.06
# constant_bcs_val: 5.165
# It: 620, Loss: 1.842e-01, Loss_u: 1.672e-01, Loss_r: 1.708e-02, Time: 0.08
# constant_bcs_val: 4.875
# It: 630, Loss: 1.331e-01, Loss_u: 1.139e-01, Loss_r: 1.928e-02, Time: 0.08
# constant_bcs_val: 5.662
# It: 640, Loss: 1.701e-01, Loss_u: 1.473e-01, Loss_r: 2.283e-02, Time: 0.09
# constant_bcs_val: 5.723
# It: 650, Loss: 1.853e-01, Loss_u: 1.697e-01, Loss_r: 1.563e-02, Time: 0.08
# constant_bcs_val: 5.520
# It: 660, Loss: 2.196e-01, Loss_u: 2.110e-01, Loss_r: 8.573e-03, Time: 0.07
# constant_bcs_val: 5.037
# It: 670, Loss: 1.358e-01, Loss_u: 1.242e-01, Loss_r: 1.168e-02, Time: 0.08
# constant_bcs_val: 4.929
# It: 680, Loss: 1.638e-01, Loss_u: 1.501e-01, Loss_r: 1.367e-02, Time: 0.07
# constant_bcs_val: 4.729
# It: 690, Loss: 1.496e-01, Loss_u: 1.343e-01, Loss_r: 1.530e-02, Time: 0.07
# constant_bcs_val: 4.695
# It: 700, Loss: 1.328e-01, Loss_u: 1.146e-01, Loss_r: 1.826e-02, Time: 0.11
# constant_bcs_val: 5.997
# It: 710, Loss: 1.530e-01, Loss_u: 1.298e-01, Loss_r: 2.317e-02, Time: 0.07
# constant_bcs_val: 7.924
# It: 720, Loss: 2.234e-01, Loss_u: 2.088e-01, Loss_r: 1.460e-02, Time: 0.08
# constant_bcs_val: 7.391
# It: 730, Loss: 2.109e-01, Loss_u: 1.872e-01, Loss_r: 2.366e-02, Time: 0.07
# constant_bcs_val: 6.913
# It: 740, Loss: 1.878e-01, Loss_u: 1.683e-01, Loss_r: 1.946e-02, Time: 0.07
# constant_bcs_val: 6.504
# It: 750, Loss: 1.689e-01, Loss_u: 1.511e-01, Loss_r: 1.777e-02, Time: 0.13
# constant_bcs_val: 6.186
# It: 760, Loss: 1.988e-01, Loss_u: 1.799e-01, Loss_r: 1.895e-02, Time: 0.08
# constant_bcs_val: 5.725
# It: 770, Loss: 1.538e-01, Loss_u: 1.425e-01, Loss_r: 1.137e-02, Time: 0.08
# constant_bcs_val: 5.286
# It: 780, Loss: 1.290e-01, Loss_u: 1.147e-01, Loss_r: 1.423e-02, Time: 0.10
# constant_bcs_val: 5.073
# It: 790, Loss: 1.163e-01, Loss_u: 1.003e-01, Loss_r: 1.604e-02, Time: 0.10
# constant_bcs_val: 4.938
# It: 800, Loss: 6.547e-02, Loss_u: 5.768e-02, Loss_r: 7.786e-03, Time: 0.14
# constant_bcs_val: 4.786
# It: 810, Loss: 1.515e-01, Loss_u: 1.394e-01, Loss_r: 1.209e-02, Time: 0.07
# constant_bcs_val: 5.036
# It: 820, Loss: 1.446e-01, Loss_u: 1.236e-01, Loss_r: 2.094e-02, Time: 0.08
# constant_bcs_val: 4.863
# It: 830, Loss: 1.330e-01, Loss_u: 1.180e-01, Loss_r: 1.502e-02, Time: 0.10
# constant_bcs_val: 4.764
# It: 840, Loss: 1.562e-01, Loss_u: 1.402e-01, Loss_r: 1.599e-02, Time: 0.12
# constant_bcs_val: 5.448
# It: 850, Loss: 1.307e-01, Loss_u: 1.091e-01, Loss_r: 2.157e-02, Time: 0.08
# constant_bcs_val: 6.255
# It: 860, Loss: 1.603e-01, Loss_u: 1.443e-01, Loss_r: 1.593e-02, Time: 0.08
# constant_bcs_val: 6.256
# It: 870, Loss: 1.415e-01, Loss_u: 1.202e-01, Loss_r: 2.130e-02, Time: 0.08
# constant_bcs_val: 5.897
# It: 880, Loss: 1.831e-01, Loss_u: 1.709e-01, Loss_r: 1.219e-02, Time: 0.08
# constant_bcs_val: 5.455
# It: 890, Loss: 1.478e-01, Loss_u: 1.266e-01, Loss_r: 2.119e-02, Time: 0.08
# constant_bcs_val: 5.367
# It: 900, Loss: 1.042e-01, Loss_u: 8.282e-02, Loss_r: 2.141e-02, Time: 0.08
# constant_bcs_val: 5.982
# It: 910, Loss: 1.710e-01, Loss_u: 1.538e-01, Loss_r: 1.719e-02, Time: 0.07
# constant_bcs_val: 6.273
# It: 920, Loss: 1.530e-01, Loss_u: 1.303e-01, Loss_r: 2.270e-02, Time: 0.08
# constant_bcs_val: 7.595
# It: 930, Loss: 2.067e-01, Loss_u: 1.763e-01, Loss_r: 3.045e-02, Time: 0.07
# constant_bcs_val: 7.401
# It: 940, Loss: 2.257e-01, Loss_u: 1.889e-01, Loss_r: 3.682e-02, Time: 0.07
# constant_bcs_val: 6.975
# It: 950, Loss: 1.761e-01, Loss_u: 1.668e-01, Loss_r: 9.285e-03, Time: 0.11
# constant_bcs_val: 6.338
# It: 960, Loss: 1.404e-01, Loss_u: 1.247e-01, Loss_r: 1.573e-02, Time: 0.07
# constant_bcs_val: 5.891
# It: 970, Loss: 1.920e-01, Loss_u: 1.784e-01, Loss_r: 1.358e-02, Time: 0.08
# constant_bcs_val: 5.434
# It: 980, Loss: 1.451e-01, Loss_u: 1.265e-01, Loss_r: 1.866e-02, Time: 0.07
# constant_bcs_val: 5.625
# It: 990, Loss: 1.223e-01, Loss_u: 1.055e-01, Loss_r: 1.685e-02, Time: 0.08
# constant_bcs_val: 6.374
# It: 1000, Loss: 1.279e-01, Loss_u: 1.176e-01, Loss_r: 1.028e-02, Time: 0.07
# constant_bcs_val: 5.988
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1010, Loss: 1.434e-01, Loss_u: 1.216e-01, Loss_r: 2.173e-02, Time: 0.07
# constant_bcs_val: 5.855
# It: 1020, Loss: 1.010e-01, Loss_u: 7.577e-02, Loss_r: 2.518e-02, Time: 0.08
# constant_bcs_val: 6.993
# It: 1030, Loss: 1.681e-01, Loss_u: 1.453e-01, Loss_r: 2.284e-02, Time: 0.10
# constant_bcs_val: 6.991
# It: 1040, Loss: 1.400e-01, Loss_u: 1.243e-01, Loss_r: 1.570e-02, Time: 0.08
# constant_bcs_val: 7.105
# It: 1050, Loss: 1.704e-01, Loss_u: 1.531e-01, Loss_r: 1.724e-02, Time: 0.10
# constant_bcs_val: 7.421
# It: 1060, Loss: 2.430e-01, Loss_u: 2.301e-01, Loss_r: 1.293e-02, Time: 0.08
# constant_bcs_val: 6.856
# It: 1070, Loss: 1.979e-01, Loss_u: 1.817e-01, Loss_r: 1.624e-02, Time: 0.08
# constant_bcs_val: 6.319
# It: 1080, Loss: 1.562e-01, Loss_u: 1.398e-01, Loss_r: 1.647e-02, Time: 0.07
# constant_bcs_val: 5.995
# It: 1090, Loss: 1.611e-01, Loss_u: 1.326e-01, Loss_r: 2.849e-02, Time: 0.07
# constant_bcs_val: 7.723
# It: 1100, Loss: 1.535e-01, Loss_u: 1.303e-01, Loss_r: 2.322e-02, Time: 0.07
# constant_bcs_val: 7.763
# It: 1110, Loss: 1.791e-01, Loss_u: 1.672e-01, Loss_r: 1.193e-02, Time: 0.10
# constant_bcs_val: 7.218
# It: 1120, Loss: 1.744e-01, Loss_u: 1.534e-01, Loss_r: 2.106e-02, Time: 0.09
# constant_bcs_val: 7.216
# It: 1130, Loss: 1.260e-01, Loss_u: 1.023e-01, Loss_r: 2.368e-02, Time: 0.07
# constant_bcs_val: 6.825
# It: 1140, Loss: 2.014e-01, Loss_u: 1.710e-01, Loss_r: 3.036e-02, Time: 0.08
# constant_bcs_val: 7.417
# It: 1150, Loss: 2.020e-01, Loss_u: 1.629e-01, Loss_r: 3.900e-02, Time: 0.07
# constant_bcs_val: 7.880
# It: 1160, Loss: 2.006e-01, Loss_u: 1.748e-01, Loss_r: 2.583e-02, Time: 0.08
# constant_bcs_val: 7.294
# It: 1170, Loss: 1.298e-01, Loss_u: 9.448e-02, Loss_r: 3.531e-02, Time: 0.08
# constant_bcs_val: 7.118
# It: 1180, Loss: 1.619e-01, Loss_u: 1.478e-01, Loss_r: 1.412e-02, Time: 0.12
# constant_bcs_val: 6.627
# It: 1190, Loss: 1.409e-01, Loss_u: 1.247e-01, Loss_r: 1.622e-02, Time: 0.08
# constant_bcs_val: 6.390
# It: 1200, Loss: 1.881e-01, Loss_u: 1.708e-01, Loss_r: 1.722e-02, Time: 0.08
# constant_bcs_val: 6.119
# It: 1210, Loss: 1.506e-01, Loss_u: 1.410e-01, Loss_r: 9.653e-03, Time: 0.08
# constant_bcs_val: 5.608
# It: 1220, Loss: 1.355e-01, Loss_u: 1.261e-01, Loss_r: 9.372e-03, Time: 0.07
# constant_bcs_val: 5.401
# It: 1230, Loss: 1.383e-01, Loss_u: 1.135e-01, Loss_r: 2.482e-02, Time: 0.08
# constant_bcs_val: 5.370
# It: 1240, Loss: 1.235e-01, Loss_u: 1.056e-01, Loss_r: 1.791e-02, Time: 0.09
# constant_bcs_val: 5.302
# It: 1250, Loss: 1.314e-01, Loss_u: 9.237e-02, Loss_r: 3.900e-02, Time: 0.08
# constant_bcs_val: 5.843
# It: 1260, Loss: 1.259e-01, Loss_u: 1.025e-01, Loss_r: 2.343e-02, Time: 0.08
# constant_bcs_val: 5.764
# It: 1270, Loss: 1.266e-01, Loss_u: 1.084e-01, Loss_r: 1.819e-02, Time: 0.07
# constant_bcs_val: 5.802
# It: 1280, Loss: 1.243e-01, Loss_u: 1.015e-01, Loss_r: 2.276e-02, Time: 0.08
# constant_bcs_val: 6.943
# It: 1290, Loss: 1.777e-01, Loss_u: 1.597e-01, Loss_r: 1.803e-02, Time: 0.09
# constant_bcs_val: 6.422
# It: 1300, Loss: 1.055e-01, Loss_u: 8.437e-02, Loss_r: 2.117e-02, Time: 0.08
# constant_bcs_val: 6.277
# It: 1310, Loss: 1.651e-01, Loss_u: 1.511e-01, Loss_r: 1.405e-02, Time: 0.08
# constant_bcs_val: 5.827
# It: 1320, Loss: 1.140e-01, Loss_u: 9.830e-02, Loss_r: 1.570e-02, Time: 0.07
# constant_bcs_val: 5.668
# It: 1330, Loss: 8.702e-02, Loss_u: 6.827e-02, Loss_r: 1.874e-02, Time: 0.07
# constant_bcs_val: 5.831
# It: 1340, Loss: 1.709e-01, Loss_u: 1.526e-01, Loss_r: 1.831e-02, Time: 0.08
# constant_bcs_val: 5.391
# It: 1350, Loss: 1.397e-01, Loss_u: 1.281e-01, Loss_r: 1.160e-02, Time: 0.10
# constant_bcs_val: 5.040
# It: 1360, Loss: 1.138e-01, Loss_u: 8.892e-02, Loss_r: 2.486e-02, Time: 0.09
# constant_bcs_val: 5.802
# It: 1370, Loss: 1.563e-01, Loss_u: 1.320e-01, Loss_r: 2.425e-02, Time: 0.07
# constant_bcs_val: 5.860
# It: 1380, Loss: 1.758e-01, Loss_u: 1.611e-01, Loss_r: 1.466e-02, Time: 0.10
# constant_bcs_val: 5.585
# It: 1390, Loss: 1.272e-01, Loss_u: 1.116e-01, Loss_r: 1.557e-02, Time: 0.08
# constant_bcs_val: 5.399
# It: 1400, Loss: 1.104e-01, Loss_u: 9.149e-02, Loss_r: 1.887e-02, Time: 0.07
# constant_bcs_val: 5.679
# It: 1410, Loss: 1.275e-01, Loss_u: 1.095e-01, Loss_r: 1.805e-02, Time: 0.11
# constant_bcs_val: 5.701
# It: 1420, Loss: 1.148e-01, Loss_u: 9.450e-02, Loss_r: 2.035e-02, Time: 0.11
# constant_bcs_val: 5.639
# It: 1430, Loss: 1.401e-01, Loss_u: 1.283e-01, Loss_r: 1.184e-02, Time: 0.08
# constant_bcs_val: 5.286
# It: 1440, Loss: 1.220e-01, Loss_u: 1.074e-01, Loss_r: 1.454e-02, Time: 0.07
# constant_bcs_val: 5.103
# It: 1450, Loss: 1.613e-01, Loss_u: 1.427e-01, Loss_r: 1.860e-02, Time: 0.12
# constant_bcs_val: 4.872
# It: 1460, Loss: 1.446e-01, Loss_u: 1.239e-01, Loss_r: 2.071e-02, Time: 0.10
# constant_bcs_val: 4.881
# It: 1470, Loss: 1.434e-01, Loss_u: 1.142e-01, Loss_r: 2.914e-02, Time: 0.09
# constant_bcs_val: 5.151
# It: 1480, Loss: 1.626e-01, Loss_u: 1.457e-01, Loss_r: 1.691e-02, Time: 0.07
# constant_bcs_val: 4.873
# It: 1490, Loss: 1.308e-01, Loss_u: 1.053e-01, Loss_r: 2.546e-02, Time: 0.08
# constant_bcs_val: 5.399
# It: 1500, Loss: 9.821e-02, Loss_u: 7.157e-02, Loss_r: 2.664e-02, Time: 0.13
# constant_bcs_val: 7.921
# It: 1510, Loss: 2.255e-01, Loss_u: 2.043e-01, Loss_r: 2.120e-02, Time: 0.08
# constant_bcs_val: 7.382
# It: 1520, Loss: 1.914e-01, Loss_u: 1.788e-01, Loss_r: 1.263e-02, Time: 0.07
# constant_bcs_val: 6.992
# It: 1530, Loss: 1.080e-01, Loss_u: 8.970e-02, Loss_r: 1.831e-02, Time: 0.07
# constant_bcs_val: 6.914
# It: 1540, Loss: 1.661e-01, Loss_u: 1.350e-01, Loss_r: 3.107e-02, Time: 0.08
# constant_bcs_val: 6.642
# It: 1550, Loss: 1.584e-01, Loss_u: 1.251e-01, Loss_r: 3.327e-02, Time: 0.10
# constant_bcs_val: 7.588
# It: 1560, Loss: 1.759e-01, Loss_u: 1.623e-01, Loss_r: 1.360e-02, Time: 0.08
# constant_bcs_val: 7.021
# It: 1570, Loss: 2.045e-01, Loss_u: 1.863e-01, Loss_r: 1.826e-02, Time: 0.11
# constant_bcs_val: 6.382
# It: 1580, Loss: 1.368e-01, Loss_u: 1.221e-01, Loss_r: 1.462e-02, Time: 0.09
# constant_bcs_val: 6.226
# It: 1590, Loss: 1.994e-01, Loss_u: 1.818e-01, Loss_r: 1.760e-02, Time: 0.07
# constant_bcs_val: 5.780
# It: 1600, Loss: 1.472e-01, Loss_u: 1.227e-01, Loss_r: 2.454e-02, Time: 0.07
# constant_bcs_val: 5.919
# It: 1610, Loss: 1.348e-01, Loss_u: 1.058e-01, Loss_r: 2.903e-02, Time: 0.13
# constant_bcs_val: 6.604
# It: 1620, Loss: 1.148e-01, Loss_u: 8.480e-02, Loss_r: 2.997e-02, Time: 0.08
# constant_bcs_val: 6.598
# It: 1630, Loss: 1.319e-01, Loss_u: 1.117e-01, Loss_r: 2.016e-02, Time: 0.07
# constant_bcs_val: 6.097
# It: 1640, Loss: 1.922e-01, Loss_u: 1.719e-01, Loss_r: 2.031e-02, Time: 0.08
# constant_bcs_val: 5.709
# It: 1650, Loss: 1.409e-01, Loss_u: 1.269e-01, Loss_r: 1.397e-02, Time: 0.09
# constant_bcs_val: 5.382
# It: 1660, Loss: 1.429e-01, Loss_u: 1.199e-01, Loss_r: 2.302e-02, Time: 0.10
# constant_bcs_val: 5.272
# It: 1670, Loss: 1.527e-01, Loss_u: 1.365e-01, Loss_r: 1.620e-02, Time: 0.08
# constant_bcs_val: 4.983
# It: 1680, Loss: 1.197e-01, Loss_u: 1.027e-01, Loss_r: 1.690e-02, Time: 0.09
# constant_bcs_val: 4.741
# It: 1690, Loss: 1.127e-01, Loss_u: 1.007e-01, Loss_r: 1.196e-02, Time: 0.08
# constant_bcs_val: 4.807
# It: 1700, Loss: 1.070e-01, Loss_u: 9.628e-02, Loss_r: 1.068e-02, Time: 0.11
# constant_bcs_val: 4.991
# It: 1710, Loss: 1.112e-01, Loss_u: 9.196e-02, Loss_r: 1.920e-02, Time: 0.07
# constant_bcs_val: 5.540
# It: 1720, Loss: 1.602e-01, Loss_u: 1.378e-01, Loss_r: 2.238e-02, Time: 0.10
# constant_bcs_val: 5.620
# It: 1730, Loss: 1.117e-01, Loss_u: 9.851e-02, Loss_r: 1.318e-02, Time: 0.07
# constant_bcs_val: 5.240
# It: 1740, Loss: 1.473e-01, Loss_u: 1.055e-01, Loss_r: 4.182e-02, Time: 0.07
# constant_bcs_val: 5.900
# It: 1750, Loss: 1.632e-01, Loss_u: 1.385e-01, Loss_r: 2.478e-02, Time: 0.10
# constant_bcs_val: 6.001
# It: 1760, Loss: 1.373e-01, Loss_u: 1.055e-01, Loss_r: 3.178e-02, Time: 0.08
# constant_bcs_val: 6.638
# It: 1770, Loss: 1.220e-01, Loss_u: 1.030e-01, Loss_r: 1.908e-02, Time: 0.08
# constant_bcs_val: 7.112
# It: 1780, Loss: 1.248e-01, Loss_u: 1.023e-01, Loss_r: 2.256e-02, Time: 0.08
# constant_bcs_val: 6.667
# It: 1790, Loss: 1.416e-01, Loss_u: 1.122e-01, Loss_r: 2.940e-02, Time: 0.07
# constant_bcs_val: 6.952
# It: 1800, Loss: 1.544e-01, Loss_u: 1.437e-01, Loss_r: 1.071e-02, Time: 0.07
# constant_bcs_val: 6.452
# It: 1810, Loss: 1.289e-01, Loss_u: 1.130e-01, Loss_r: 1.589e-02, Time: 0.08
# constant_bcs_val: 6.163
# It: 1820, Loss: 1.085e-01, Loss_u: 8.766e-02, Loss_r: 2.088e-02, Time: 0.08
# constant_bcs_val: 6.112
# It: 1830, Loss: 1.238e-01, Loss_u: 1.120e-01, Loss_r: 1.176e-02, Time: 0.08
# constant_bcs_val: 5.754
# It: 1840, Loss: 1.498e-01, Loss_u: 1.307e-01, Loss_r: 1.917e-02, Time: 0.08
# constant_bcs_val: 5.980
# It: 1850, Loss: 1.726e-01, Loss_u: 1.547e-01, Loss_r: 1.785e-02, Time: 0.09
# constant_bcs_val: 5.543
# It: 1860, Loss: 1.315e-01, Loss_u: 1.038e-01, Loss_r: 2.770e-02, Time: 0.08
# constant_bcs_val: 5.697
# It: 1870, Loss: 1.352e-01, Loss_u: 1.214e-01, Loss_r: 1.380e-02, Time: 0.09
# constant_bcs_val: 5.219
# It: 1880, Loss: 1.059e-01, Loss_u: 8.614e-02, Loss_r: 1.978e-02, Time: 0.08
# constant_bcs_val: 5.209
# It: 1890, Loss: 1.059e-01, Loss_u: 9.295e-02, Loss_r: 1.300e-02, Time: 0.09
# constant_bcs_val: 5.210
# It: 1900, Loss: 1.144e-01, Loss_u: 9.519e-02, Loss_r: 1.917e-02, Time: 0.07
# constant_bcs_val: 5.705
# It: 1910, Loss: 1.447e-01, Loss_u: 1.247e-01, Loss_r: 2.003e-02, Time: 0.10
# constant_bcs_val: 5.782
# It: 1920, Loss: 1.188e-01, Loss_u: 9.293e-02, Loss_r: 2.589e-02, Time: 0.09
# constant_bcs_val: 6.607
# It: 1930, Loss: 1.132e-01, Loss_u: 9.529e-02, Loss_r: 1.794e-02, Time: 0.08
# constant_bcs_val: 6.419
# It: 1940, Loss: 1.497e-01, Loss_u: 1.342e-01, Loss_r: 1.551e-02, Time: 0.07
# constant_bcs_val: 6.196
# It: 1950, Loss: 1.425e-01, Loss_u: 1.261e-01, Loss_r: 1.637e-02, Time: 0.08
# constant_bcs_val: 5.810
# It: 1960, Loss: 1.096e-01, Loss_u: 9.327e-02, Loss_r: 1.637e-02, Time: 0.07
# constant_bcs_val: 5.471
# It: 1970, Loss: 1.070e-01, Loss_u: 9.334e-02, Loss_r: 1.370e-02, Time: 0.14
# constant_bcs_val: 5.510
# It: 1980, Loss: 1.194e-01, Loss_u: 1.044e-01, Loss_r: 1.507e-02, Time: 0.07
# constant_bcs_val: 5.305
# It: 1990, Loss: 8.479e-02, Loss_u: 6.187e-02, Loss_r: 2.293e-02, Time: 0.10
# constant_bcs_val: 5.546
# It: 2000, Loss: 1.092e-01, Loss_u: 9.187e-02, Loss_r: 1.737e-02, Time: 0.08
# constant_bcs_val: 5.950
# It: 2010, Loss: 8.513e-02, Loss_u: 6.602e-02, Loss_r: 1.911e-02, Time: 0.07
# constant_bcs_val: 5.814
# It: 2020, Loss: 1.344e-01, Loss_u: 1.175e-01, Loss_r: 1.688e-02, Time: 0.09
# constant_bcs_val: 5.690
# It: 2030, Loss: 1.554e-01, Loss_u: 1.405e-01, Loss_r: 1.495e-02, Time: 0.10
# constant_bcs_val: 5.931
# It: 2040, Loss: 1.186e-01, Loss_u: 1.041e-01, Loss_r: 1.449e-02, Time: 0.08
# constant_bcs_val: 5.587
# It: 2050, Loss: 1.067e-01, Loss_u: 8.802e-02, Loss_r: 1.866e-02, Time: 0.07
# constant_bcs_val: 5.268
# It: 2060, Loss: 1.408e-01, Loss_u: 1.132e-01, Loss_r: 2.767e-02, Time: 0.07
# constant_bcs_val: 6.371
# It: 2070, Loss: 1.405e-01, Loss_u: 1.266e-01, Loss_r: 1.383e-02, Time: 0.10
# constant_bcs_val: 6.297
# It: 2080, Loss: 1.549e-01, Loss_u: 1.448e-01, Loss_r: 1.018e-02, Time: 0.10
# constant_bcs_val: 5.824
# It: 2090, Loss: 9.861e-02, Loss_u: 7.988e-02, Loss_r: 1.873e-02, Time: 0.08
# constant_bcs_val: 6.174
# It: 2100, Loss: 1.020e-01, Loss_u: 7.943e-02, Loss_r: 2.259e-02, Time: 0.08
# constant_bcs_val: 6.143
# It: 2110, Loss: 9.921e-02, Loss_u: 8.078e-02, Loss_r: 1.843e-02, Time: 0.08
# constant_bcs_val: 6.425
# It: 2120, Loss: 1.389e-01, Loss_u: 1.245e-01, Loss_r: 1.438e-02, Time: 0.11
# constant_bcs_val: 6.024
# It: 2130, Loss: 1.128e-01, Loss_u: 9.656e-02, Loss_r: 1.625e-02, Time: 0.20
# constant_bcs_val: 5.832
# It: 2140, Loss: 1.337e-01, Loss_u: 1.076e-01, Loss_r: 2.611e-02, Time: 0.15
# constant_bcs_val: 5.998
# It: 2150, Loss: 1.031e-01, Loss_u: 8.693e-02, Loss_r: 1.612e-02, Time: 0.17
# constant_bcs_val: 5.842
# It: 2160, Loss: 1.120e-01, Loss_u: 8.835e-02, Loss_r: 2.362e-02, Time: 0.10
# constant_bcs_val: 5.718
# It: 2170, Loss: 1.348e-01, Loss_u: 1.236e-01, Loss_r: 1.120e-02, Time: 0.13
# constant_bcs_val: 5.353
# It: 2180, Loss: 9.810e-02, Loss_u: 8.552e-02, Loss_r: 1.258e-02, Time: 0.22
# constant_bcs_val: 5.250
# It: 2190, Loss: 9.118e-02, Loss_u: 7.099e-02, Loss_r: 2.019e-02, Time: 0.13
# constant_bcs_val: 5.181
# It: 2200, Loss: 1.076e-01, Loss_u: 9.762e-02, Loss_r: 9.989e-03, Time: 0.10
# constant_bcs_val: 4.900
# It: 2210, Loss: 1.454e-01, Loss_u: 1.154e-01, Loss_r: 3.001e-02, Time: 0.15
# constant_bcs_val: 4.780
# It: 2220, Loss: 1.323e-01, Loss_u: 1.106e-01, Loss_r: 2.173e-02, Time: 0.09
# constant_bcs_val: 4.641
# It: 2230, Loss: 1.062e-01, Loss_u: 8.873e-02, Loss_r: 1.748e-02, Time: 0.12
# constant_bcs_val: 5.280
# It: 2240, Loss: 1.249e-01, Loss_u: 1.086e-01, Loss_r: 1.629e-02, Time: 0.13
# constant_bcs_val: 5.657
# It: 2250, Loss: 1.538e-01, Loss_u: 1.369e-01, Loss_r: 1.693e-02, Time: 0.13
# constant_bcs_val: 5.394
# It: 2260, Loss: 1.668e-01, Loss_u: 1.339e-01, Loss_r: 3.295e-02, Time: 0.23
# constant_bcs_val: 5.509
# It: 2270, Loss: 1.096e-01, Loss_u: 8.823e-02, Loss_r: 2.140e-02, Time: 0.11
# constant_bcs_val: 5.471
# It: 2280, Loss: 1.732e-01, Loss_u: 1.524e-01, Loss_r: 2.077e-02, Time: 0.18
# constant_bcs_val: 5.708
# It: 2290, Loss: 1.294e-01, Loss_u: 1.141e-01, Loss_r: 1.531e-02, Time: 0.12
# constant_bcs_val: 5.279
# It: 2300, Loss: 1.375e-01, Loss_u: 1.202e-01, Loss_r: 1.732e-02, Time: 0.15
# constant_bcs_val: 5.413
# It: 2310, Loss: 1.705e-01, Loss_u: 1.476e-01, Loss_r: 2.297e-02, Time: 0.11
# constant_bcs_val: 5.304
# It: 2320, Loss: 1.007e-01, Loss_u: 8.216e-02, Loss_r: 1.857e-02, Time: 0.13
# constant_bcs_val: 5.167
# It: 2330, Loss: 1.362e-01, Loss_u: 1.228e-01, Loss_r: 1.341e-02, Time: 0.13
# constant_bcs_val: 4.829
# It: 2340, Loss: 8.895e-02, Loss_u: 7.868e-02, Loss_r: 1.027e-02, Time: 0.18
# constant_bcs_val: 4.458
# It: 2350, Loss: 1.238e-01, Loss_u: 1.084e-01, Loss_r: 1.543e-02, Time: 0.25
# constant_bcs_val: 4.248
# It: 2360, Loss: 1.087e-01, Loss_u: 9.295e-02, Loss_r: 1.573e-02, Time: 0.15
# constant_bcs_val: 4.318
# It: 2370, Loss: 9.327e-02, Loss_u: 7.634e-02, Loss_r: 1.692e-02, Time: 0.16
# constant_bcs_val: 4.604
# It: 2380, Loss: 9.096e-02, Loss_u: 7.436e-02, Loss_r: 1.660e-02, Time: 0.25
# constant_bcs_val: 4.443
# It: 2390, Loss: 8.778e-02, Loss_u: 7.253e-02, Loss_r: 1.525e-02, Time: 0.13
# constant_bcs_val: 4.604
# It: 2400, Loss: 1.139e-01, Loss_u: 9.084e-02, Loss_r: 2.305e-02, Time: 0.19
# constant_bcs_val: 5.716
# It: 2410, Loss: 1.154e-01, Loss_u: 9.914e-02, Loss_r: 1.628e-02, Time: 0.12
# constant_bcs_val: 5.619
# It: 2420, Loss: 1.547e-01, Loss_u: 1.333e-01, Loss_r: 2.134e-02, Time: 0.14
# constant_bcs_val: 6.216
# It: 2430, Loss: 2.082e-01, Loss_u: 1.968e-01, Loss_r: 1.140e-02, Time: 0.15
# constant_bcs_val: 5.665
# It: 2440, Loss: 1.212e-01, Loss_u: 9.415e-02, Loss_r: 2.709e-02, Time: 0.11
# constant_bcs_val: 5.502
# It: 2450, Loss: 1.232e-01, Loss_u: 1.060e-01, Loss_r: 1.722e-02, Time: 0.12
# constant_bcs_val: 5.493
# It: 2460, Loss: 1.023e-01, Loss_u: 8.213e-02, Loss_r: 2.018e-02, Time: 0.09
# constant_bcs_val: 5.495
# It: 2470, Loss: 1.319e-01, Loss_u: 1.102e-01, Loss_r: 2.169e-02, Time: 0.15
# constant_bcs_val: 5.681
# It: 2480, Loss: 1.105e-01, Loss_u: 9.709e-02, Loss_r: 1.344e-02, Time: 0.11
# constant_bcs_val: 5.706
# It: 2490, Loss: 1.115e-01, Loss_u: 9.386e-02, Loss_r: 1.768e-02, Time: 0.13
# constant_bcs_val: 5.723
# It: 2500, Loss: 1.209e-01, Loss_u: 9.749e-02, Loss_r: 2.337e-02, Time: 0.12
# constant_bcs_val: 6.511
# It: 2510, Loss: 1.520e-01, Loss_u: 1.294e-01, Loss_r: 2.260e-02, Time: 0.13
# constant_bcs_val: 6.036
# It: 2520, Loss: 1.291e-01, Loss_u: 1.022e-01, Loss_r: 2.687e-02, Time: 0.11
# constant_bcs_val: 5.608
# It: 2530, Loss: 1.091e-01, Loss_u: 9.063e-02, Loss_r: 1.846e-02, Time: 0.11
# constant_bcs_val: 5.669
# It: 2540, Loss: 9.946e-02, Loss_u: 7.629e-02, Loss_r: 2.317e-02, Time: 0.11
# constant_bcs_val: 5.398
# It: 2550, Loss: 1.844e-01, Loss_u: 1.556e-01, Loss_r: 2.875e-02, Time: 0.09
# constant_bcs_val: 5.150
# It: 2560, Loss: 1.218e-01, Loss_u: 1.015e-01, Loss_r: 2.032e-02, Time: 0.09
# constant_bcs_val: 4.840
# It: 2570, Loss: 1.019e-01, Loss_u: 8.271e-02, Loss_r: 1.917e-02, Time: 0.09
# constant_bcs_val: 4.921
# It: 2580, Loss: 1.138e-01, Loss_u: 8.747e-02, Loss_r: 2.638e-02, Time: 0.11
# constant_bcs_val: 8.046
# It: 2590, Loss: 1.389e-01, Loss_u: 1.183e-01, Loss_r: 2.061e-02, Time: 0.12
# constant_bcs_val: 7.946
# It: 2600, Loss: 1.324e-01, Loss_u: 1.140e-01, Loss_r: 1.841e-02, Time: 0.34
# constant_bcs_val: 7.678
# It: 2610, Loss: 1.906e-01, Loss_u: 1.658e-01, Loss_r: 2.485e-02, Time: 0.14
# constant_bcs_val: 8.022
# It: 2620, Loss: 2.174e-01, Loss_u: 1.968e-01, Loss_r: 2.059e-02, Time: 0.17
# constant_bcs_val: 7.335
# It: 2630, Loss: 1.802e-01, Loss_u: 1.693e-01, Loss_r: 1.094e-02, Time: 0.19
# constant_bcs_val: 6.685
# It: 2640, Loss: 1.670e-01, Loss_u: 1.540e-01, Loss_r: 1.304e-02, Time: 0.14
# constant_bcs_val: 6.208
# It: 2650, Loss: 1.302e-01, Loss_u: 1.042e-01, Loss_r: 2.597e-02, Time: 0.11
# constant_bcs_val: 6.420
# It: 2660, Loss: 1.632e-01, Loss_u: 1.497e-01, Loss_r: 1.345e-02, Time: 0.11
# constant_bcs_val: 5.917
# It: 2670, Loss: 1.346e-01, Loss_u: 1.168e-01, Loss_r: 1.783e-02, Time: 0.12
# constant_bcs_val: 5.690
# It: 2680, Loss: 1.448e-01, Loss_u: 1.249e-01, Loss_r: 1.997e-02, Time: 0.11
# constant_bcs_val: 5.694
# It: 2690, Loss: 1.058e-01, Loss_u: 9.040e-02, Loss_r: 1.538e-02, Time: 0.14
# constant_bcs_val: 5.716
# It: 2700, Loss: 1.208e-01, Loss_u: 1.005e-01, Loss_r: 2.037e-02, Time: 0.11
# constant_bcs_val: 5.437
# It: 2710, Loss: 8.557e-02, Loss_u: 7.434e-02, Loss_r: 1.123e-02, Time: 0.14
# constant_bcs_val: 5.100
# It: 2720, Loss: 1.323e-01, Loss_u: 1.122e-01, Loss_r: 2.011e-02, Time: 0.12
# constant_bcs_val: 6.429
# It: 2730, Loss: 1.245e-01, Loss_u: 1.114e-01, Loss_r: 1.308e-02, Time: 0.12
# constant_bcs_val: 6.129
# It: 2740, Loss: 1.395e-01, Loss_u: 1.206e-01, Loss_r: 1.895e-02, Time: 0.13
# constant_bcs_val: 6.017
# It: 2750, Loss: 1.408e-01, Loss_u: 1.269e-01, Loss_r: 1.390e-02, Time: 0.15
# constant_bcs_val: 5.746
# It: 2760, Loss: 1.390e-01, Loss_u: 1.140e-01, Loss_r: 2.499e-02, Time: 0.16
# constant_bcs_val: 6.246
# It: 2770, Loss: 1.245e-01, Loss_u: 1.097e-01, Loss_r: 1.477e-02, Time: 0.12
# constant_bcs_val: 5.737
# It: 2780, Loss: 1.173e-01, Loss_u: 1.042e-01, Loss_r: 1.313e-02, Time: 0.14
# constant_bcs_val: 5.456
# It: 2790, Loss: 1.240e-01, Loss_u: 9.672e-02, Loss_r: 2.732e-02, Time: 0.14
# constant_bcs_val: 5.715
# It: 2800, Loss: 1.534e-01, Loss_u: 1.221e-01, Loss_r: 3.136e-02, Time: 0.11
# constant_bcs_val: 6.105
# It: 2810, Loss: 1.335e-01, Loss_u: 1.145e-01, Loss_r: 1.897e-02, Time: 0.12
# constant_bcs_val: 6.624
# It: 2820, Loss: 1.906e-01, Loss_u: 1.734e-01, Loss_r: 1.719e-02, Time: 0.14
# constant_bcs_val: 6.267
# It: 2830, Loss: 9.744e-02, Loss_u: 7.564e-02, Loss_r: 2.180e-02, Time: 0.13
# constant_bcs_val: 6.539
# It: 2840, Loss: 1.390e-01, Loss_u: 1.100e-01, Loss_r: 2.902e-02, Time: 0.14
# constant_bcs_val: 6.873
# It: 2850, Loss: 2.169e-01, Loss_u: 1.925e-01, Loss_r: 2.446e-02, Time: 0.35
# constant_bcs_val: 7.084
# It: 2860, Loss: 1.418e-01, Loss_u: 1.230e-01, Loss_r: 1.878e-02, Time: 0.12
# constant_bcs_val: 6.915
# It: 2870, Loss: 9.249e-02, Loss_u: 7.049e-02, Loss_r: 2.200e-02, Time: 0.12
# constant_bcs_val: 6.479
# It: 2880, Loss: 1.288e-01, Loss_u: 1.077e-01, Loss_r: 2.105e-02, Time: 0.12
# constant_bcs_val: 6.444
# It: 2890, Loss: 1.399e-01, Loss_u: 1.252e-01, Loss_r: 1.473e-02, Time: 0.12
# constant_bcs_val: 6.069
# It: 2900, Loss: 1.116e-01, Loss_u: 9.630e-02, Loss_r: 1.529e-02, Time: 0.13
# constant_bcs_val: 5.743
# It: 2910, Loss: 1.200e-01, Loss_u: 9.566e-02, Loss_r: 2.437e-02, Time: 0.12
# constant_bcs_val: 5.932
# It: 2920, Loss: 1.222e-01, Loss_u: 9.869e-02, Loss_r: 2.349e-02, Time: 0.39
# constant_bcs_val: 6.589
# It: 2930, Loss: 1.610e-01, Loss_u: 1.365e-01, Loss_r: 2.445e-02, Time: 0.10
# constant_bcs_val: 6.913
# It: 2940, Loss: 1.836e-01, Loss_u: 1.568e-01, Loss_r: 2.672e-02, Time: 0.07
# constant_bcs_val: 6.472
# It: 2950, Loss: 1.615e-01, Loss_u: 1.394e-01, Loss_r: 2.213e-02, Time: 0.11
# constant_bcs_val: 6.729
# It: 2960, Loss: 1.288e-01, Loss_u: 9.967e-02, Loss_r: 2.912e-02, Time: 0.08
# constant_bcs_val: 6.583
# It: 2970, Loss: 1.046e-01, Loss_u: 8.713e-02, Loss_r: 1.751e-02, Time: 0.13
# constant_bcs_val: 6.203
# It: 2980, Loss: 9.790e-02, Loss_u: 7.061e-02, Loss_r: 2.729e-02, Time: 0.14
# constant_bcs_val: 6.421
# It: 2990, Loss: 1.279e-01, Loss_u: 1.153e-01, Loss_r: 1.259e-02, Time: 0.08
# constant_bcs_val: 6.049
# It: 3000, Loss: 1.272e-01, Loss_u: 1.046e-01, Loss_r: 2.259e-02, Time: 0.14
# constant_bcs_val: 5.664
# It: 3010, Loss: 1.192e-01, Loss_u: 8.823e-02, Loss_r: 3.097e-02, Time: 0.12
# constant_bcs_val: 6.202
# It: 3020, Loss: 1.380e-01, Loss_u: 1.196e-01, Loss_r: 1.847e-02, Time: 0.12
# constant_bcs_val: 6.029
# It: 3030, Loss: 1.129e-01, Loss_u: 9.252e-02, Loss_r: 2.042e-02, Time: 0.13
# constant_bcs_val: 6.102
# It: 3040, Loss: 1.186e-01, Loss_u: 1.012e-01, Loss_r: 1.741e-02, Time: 0.18
# constant_bcs_val: 6.667
# It: 3050, Loss: 9.404e-02, Loss_u: 8.114e-02, Loss_r: 1.290e-02, Time: 0.14
# constant_bcs_val: 6.091
# It: 3060, Loss: 1.355e-01, Loss_u: 1.066e-01, Loss_r: 2.892e-02, Time: 0.15
# constant_bcs_val: 5.990
# It: 3070, Loss: 1.034e-01, Loss_u: 8.827e-02, Loss_r: 1.516e-02, Time: 0.15
# constant_bcs_val: 5.674
# It: 3080, Loss: 1.019e-01, Loss_u: 8.465e-02, Loss_r: 1.730e-02, Time: 0.08
# constant_bcs_val: 5.610
# It: 3090, Loss: 1.252e-01, Loss_u: 1.126e-01, Loss_r: 1.255e-02, Time: 0.13
# constant_bcs_val: 5.187
# It: 3100, Loss: 1.606e-01, Loss_u: 1.391e-01, Loss_r: 2.145e-02, Time: 0.18
# constant_bcs_val: 4.879
# It: 3110, Loss: 9.006e-02, Loss_u: 7.295e-02, Loss_r: 1.712e-02, Time: 0.13
# constant_bcs_val: 4.743
# It: 3120, Loss: 9.053e-02, Loss_u: 7.875e-02, Loss_r: 1.178e-02, Time: 0.14
# constant_bcs_val: 4.576
# It: 3130, Loss: 9.074e-02, Loss_u: 7.498e-02, Loss_r: 1.577e-02, Time: 0.11
# constant_bcs_val: 4.285
# It: 3140, Loss: 1.084e-01, Loss_u: 9.024e-02, Loss_r: 1.819e-02, Time: 0.23
# constant_bcs_val: 4.206
# It: 3150, Loss: 1.334e-01, Loss_u: 1.115e-01, Loss_r: 2.189e-02, Time: 0.13
# constant_bcs_val: 4.204
# It: 3160, Loss: 9.656e-02, Loss_u: 8.694e-02, Loss_r: 9.617e-03, Time: 0.12
# ...
# constant_bcs_val: 14.699
# It: 38960, Loss: 7.175e-02, Loss_u: 6.795e-02, Loss_r: 3.809e-03, Time: 0.16
# constant_bcs_val: 13.509
# It: 38970, Loss: 8.351e-02, Loss_u: 7.631e-02, Loss_r: 7.205e-03, Time: 0.12
# constant_bcs_val: 13.806
# It: 38980, Loss: 6.020e-02, Loss_u: 5.467e-02, Loss_r: 5.524e-03, Time: 0.10
# constant_bcs_val: 12.852
# It: 38990, Loss: 9.187e-02, Loss_u: 6.783e-02, Loss_r: 2.404e-02, Time: 0.10
# constant_bcs_val: 14.189
# It: 39000, Loss: 1.454e-01, Loss_u: 1.055e-01, Loss_r: 3.989e-02, Time: 0.14
# constant_bcs_val: 21.854
# It: 39010, Loss: 1.382e-01, Loss_u: 1.303e-01, Loss_r: 7.889e-03, Time: 0.15
# constant_bcs_val: 20.328
# It: 39020, Loss: 7.395e-02, Loss_u: 6.996e-02, Loss_r: 3.990e-03, Time: 0.12
# constant_bcs_val: 18.465
# It: 39030, Loss: 8.343e-02, Loss_u: 7.567e-02, Loss_r: 7.762e-03, Time: 0.13
# constant_bcs_val: 16.847
# It: 39040, Loss: 9.971e-02, Loss_u: 9.559e-02, Loss_r: 4.120e-03, Time: 0.14
# constant_bcs_val: 15.228
# It: 39050, Loss: 7.586e-02, Loss_u: 6.935e-02, Loss_r: 6.513e-03, Time: 0.12
# constant_bcs_val: 14.115
# It: 39060, Loss: 4.846e-02, Loss_u: 4.419e-02, Loss_r: 4.272e-03, Time: 0.09
# constant_bcs_val: 16.442
# It: 39070, Loss: 7.944e-02, Loss_u: 6.934e-02, Loss_r: 1.010e-02, Time: 0.17
# constant_bcs_val: 15.244
# It: 39080, Loss: 5.474e-02, Loss_u: 4.358e-02, Loss_r: 1.117e-02, Time: 0.10
# constant_bcs_val: 15.324
# It: 39090, Loss: 9.536e-02, Loss_u: 8.593e-02, Loss_r: 9.426e-03, Time: 0.09
# constant_bcs_val: 17.769
# It: 39100, Loss: 8.747e-02, Loss_u: 7.017e-02, Loss_r: 1.730e-02, Time: 0.18
# constant_bcs_val: 21.521
# It: 39110, Loss: 1.839e-01, Loss_u: 1.561e-01, Loss_r: 2.775e-02, Time: 0.10
# constant_bcs_val: 20.516
# It: 39120, Loss: 1.776e-01, Loss_u: 1.696e-01, Loss_r: 8.065e-03, Time: 0.10
# constant_bcs_val: 18.759
# It: 39130, Loss: 1.702e-01, Loss_u: 1.634e-01, Loss_r: 6.775e-03, Time: 0.10
# constant_bcs_val: 17.266
# It: 39140, Loss: 8.398e-02, Loss_u: 6.883e-02, Loss_r: 1.515e-02, Time: 0.16
# constant_bcs_val: 18.036
# It: 39150, Loss: 1.378e-01, Loss_u: 1.302e-01, Loss_r: 7.610e-03, Time: 0.11
# constant_bcs_val: 16.792
# It: 39160, Loss: 6.846e-02, Loss_u: 6.181e-02, Loss_r: 6.654e-03, Time: 0.10
# constant_bcs_val: 15.846
# It: 39170, Loss: 7.786e-02, Loss_u: 6.188e-02, Loss_r: 1.597e-02, Time: 0.17
# constant_bcs_val: 15.081
# It: 39180, Loss: 1.166e-01, Loss_u: 8.947e-02, Loss_r: 2.710e-02, Time: 0.17
# constant_bcs_val: 24.081
# It: 39190, Loss: 1.627e-01, Loss_u: 1.545e-01, Loss_r: 8.129e-03, Time: 0.12
# constant_bcs_val: 22.096
# It: 39200, Loss: 1.324e-01, Loss_u: 1.094e-01, Loss_r: 2.307e-02, Time: 0.10
# constant_bcs_val: 20.400
# It: 39210, Loss: 1.310e-01, Loss_u: 1.192e-01, Loss_r: 1.185e-02, Time: 0.11
# constant_bcs_val: 20.184
# It: 39220, Loss: 1.347e-01, Loss_u: 1.099e-01, Loss_r: 2.483e-02, Time: 0.10
# constant_bcs_val: 22.031
# It: 39230, Loss: 1.019e-01, Loss_u: 9.368e-02, Loss_r: 8.227e-03, Time: 0.10
# constant_bcs_val: 20.040
# It: 39240, Loss: 1.583e-01, Loss_u: 1.523e-01, Loss_r: 6.032e-03, Time: 0.10
# constant_bcs_val: 18.554
# It: 39250, Loss: 7.699e-02, Loss_u: 7.240e-02, Loss_r: 4.595e-03, Time: 0.14
# constant_bcs_val: 16.821
# It: 39260, Loss: 1.132e-01, Loss_u: 1.054e-01, Loss_r: 7.732e-03, Time: 0.11
# constant_bcs_val: 15.885
# It: 39270, Loss: 8.856e-02, Loss_u: 8.125e-02, Loss_r: 7.310e-03, Time: 0.10
# constant_bcs_val: 14.610
# It: 39280, Loss: 9.503e-02, Loss_u: 6.862e-02, Loss_r: 2.641e-02, Time: 0.12
# constant_bcs_val: 21.513
# It: 39290, Loss: 1.339e-01, Loss_u: 1.281e-01, Loss_r: 5.721e-03, Time: 0.14
# constant_bcs_val: 19.787
# It: 39300, Loss: 2.270e-01, Loss_u: 2.095e-01, Loss_r: 1.746e-02, Time: 0.12
# constant_bcs_val: 18.846
# It: 39310, Loss: 1.665e-01, Loss_u: 1.493e-01, Loss_r: 1.721e-02, Time: 0.10
# constant_bcs_val: 17.627
# It: 39320, Loss: 1.092e-01, Loss_u: 1.022e-01, Loss_r: 7.066e-03, Time: 0.17
# constant_bcs_val: 16.184
# It: 39330, Loss: 1.000e-01, Loss_u: 7.903e-02, Loss_r: 2.098e-02, Time: 0.15
# constant_bcs_val: 18.852
# It: 39340, Loss: 1.380e-01, Loss_u: 1.310e-01, Loss_r: 7.026e-03, Time: 0.20
# constant_bcs_val: 17.496
# It: 39350, Loss: 1.322e-01, Loss_u: 1.269e-01, Loss_r: 5.312e-03, Time: 0.14
# constant_bcs_val: 15.807
# It: 39360, Loss: 1.041e-01, Loss_u: 9.064e-02, Loss_r: 1.347e-02, Time: 0.12
# constant_bcs_val: 14.807
# It: 39370, Loss: 1.328e-01, Loss_u: 1.281e-01, Loss_r: 4.786e-03, Time: 0.15
# constant_bcs_val: 14.392
# It: 39380, Loss: 7.072e-02, Loss_u: 6.337e-02, Loss_r: 7.356e-03, Time: 0.18
# constant_bcs_val: 13.649
# It: 39390, Loss: 9.826e-02, Loss_u: 9.352e-02, Loss_r: 4.741e-03, Time: 0.13
# constant_bcs_val: 12.783
# It: 39400, Loss: 5.422e-02, Loss_u: 4.722e-02, Loss_r: 7.000e-03, Time: 0.13
# constant_bcs_val: 12.255
# It: 39410, Loss: 6.067e-02, Loss_u: 4.346e-02, Loss_r: 1.722e-02, Time: 0.17
# constant_bcs_val: 12.349
# It: 39420, Loss: 6.886e-02, Loss_u: 6.545e-02, Loss_r: 3.401e-03, Time: 0.17
# constant_bcs_val: 11.212
# It: 39430, Loss: 1.003e-01, Loss_u: 8.402e-02, Loss_r: 1.631e-02, Time: 0.15
# constant_bcs_val: 11.373
# It: 39440, Loss: 3.999e-02, Loss_u: 3.443e-02, Loss_r: 5.556e-03, Time: 0.19
# constant_bcs_val: 10.806
# It: 39450, Loss: 7.337e-02, Loss_u: 6.727e-02, Loss_r: 6.108e-03, Time: 0.11
# constant_bcs_val: 9.851
# It: 39460, Loss: 8.734e-02, Loss_u: 7.984e-02, Loss_r: 7.502e-03, Time: 0.15
# constant_bcs_val: 9.344
# It: 39470, Loss: 4.598e-02, Loss_u: 3.921e-02, Loss_r: 6.775e-03, Time: 0.12
# constant_bcs_val: 15.150
# It: 39480, Loss: 6.451e-02, Loss_u: 5.328e-02, Loss_r: 1.123e-02, Time: 0.11
# constant_bcs_val: 26.046
# It: 39490, Loss: 1.349e-01, Loss_u: 1.295e-01, Loss_r: 5.373e-03, Time: 0.13
# constant_bcs_val: 24.020
# It: 39500, Loss: 1.108e-01, Loss_u: 1.042e-01, Loss_r: 6.560e-03, Time: 0.13
# constant_bcs_val: 21.934
# It: 39510, Loss: 1.536e-01, Loss_u: 1.486e-01, Loss_r: 4.960e-03, Time: 0.10
# constant_bcs_val: 20.002
# It: 39520, Loss: 1.687e-01, Loss_u: 1.498e-01, Loss_r: 1.896e-02, Time: 0.15
# constant_bcs_val: 18.267
# It: 39530, Loss: 6.976e-02, Loss_u: 6.376e-02, Loss_r: 5.996e-03, Time: 0.12
# constant_bcs_val: 16.711
# It: 39540, Loss: 6.963e-02, Loss_u: 5.745e-02, Loss_r: 1.218e-02, Time: 0.17
# constant_bcs_val: 15.803
# It: 39550, Loss: 6.986e-02, Loss_u: 5.140e-02, Loss_r: 1.846e-02, Time: 0.18
# constant_bcs_val: 16.889
# It: 39560, Loss: 6.035e-02, Loss_u: 5.411e-02, Loss_r: 6.236e-03, Time: 0.16
# constant_bcs_val: 16.002
# It: 39570, Loss: 8.339e-02, Loss_u: 7.734e-02, Loss_r: 6.049e-03, Time: 0.31
# constant_bcs_val: 14.923
# It: 39580, Loss: 4.188e-02, Loss_u: 3.791e-02, Loss_r: 3.970e-03, Time: 0.11
# constant_bcs_val: 13.690
# It: 39590, Loss: 4.747e-02, Loss_u: 4.215e-02, Loss_r: 5.315e-03, Time: 0.13
# constant_bcs_val: 12.946
# It: 39600, Loss: 1.051e-01, Loss_u: 9.742e-02, Loss_r: 7.728e-03, Time: 0.19
# constant_bcs_val: 13.147
# It: 39610, Loss: 7.729e-02, Loss_u: 7.100e-02, Loss_r: 6.287e-03, Time: 0.14
# constant_bcs_val: 12.371
# It: 39620, Loss: 4.451e-02, Loss_u: 3.666e-02, Loss_r: 7.851e-03, Time: 0.16
# constant_bcs_val: 11.639
# It: 39630, Loss: 7.507e-02, Loss_u: 6.467e-02, Loss_r: 1.039e-02, Time: 0.22
# constant_bcs_val: 11.245
# It: 39640, Loss: 3.965e-02, Loss_u: 3.414e-02, Loss_r: 5.517e-03, Time: 0.11
# constant_bcs_val: 10.690
# It: 39650, Loss: 5.161e-02, Loss_u: 4.054e-02, Loss_r: 1.107e-02, Time: 0.17
# constant_bcs_val: 10.881
# It: 39660, Loss: 8.435e-02, Loss_u: 7.117e-02, Loss_r: 1.318e-02, Time: 0.23
# constant_bcs_val: 14.765
# It: 39670, Loss: 5.077e-02, Loss_u: 4.637e-02, Loss_r: 4.397e-03, Time: 0.10
# constant_bcs_val: 13.533
# It: 39680, Loss: 8.599e-02, Loss_u: 7.666e-02, Loss_r: 9.323e-03, Time: 0.15
# constant_bcs_val: 13.555
# It: 39690, Loss: 9.438e-02, Loss_u: 8.980e-02, Loss_r: 4.574e-03, Time: 0.17
# constant_bcs_val: 12.797
# It: 39700, Loss: 7.050e-02, Loss_u: 6.295e-02, Loss_r: 7.545e-03, Time: 0.12
# constant_bcs_val: 12.762
# It: 39710, Loss: 8.755e-02, Loss_u: 7.833e-02, Loss_r: 9.224e-03, Time: 0.10
# constant_bcs_val: 13.351
# It: 39720, Loss: 3.798e-02, Loss_u: 3.302e-02, Loss_r: 4.964e-03, Time: 0.11
# constant_bcs_val: 12.614
# It: 39730, Loss: 3.659e-02, Loss_u: 3.046e-02, Loss_r: 6.126e-03, Time: 0.12
# constant_bcs_val: 13.704
# It: 39740, Loss: 8.222e-02, Loss_u: 6.998e-02, Loss_r: 1.224e-02, Time: 0.21
# constant_bcs_val: 14.245
# It: 39750, Loss: 1.363e-01, Loss_u: 9.457e-02, Loss_r: 4.176e-02, Time: 0.27
# constant_bcs_val: 18.450
# It: 39760, Loss: 8.708e-02, Loss_u: 8.285e-02, Loss_r: 4.229e-03, Time: 0.11
# constant_bcs_val: 16.888
# It: 39770, Loss: 9.625e-02, Loss_u: 9.107e-02, Loss_r: 5.180e-03, Time: 0.22
# constant_bcs_val: 15.732
# It: 39780, Loss: 6.893e-02, Loss_u: 5.680e-02, Loss_r: 1.214e-02, Time: 0.12
# constant_bcs_val: 15.683
# It: 39790, Loss: 1.008e-01, Loss_u: 8.458e-02, Loss_r: 1.626e-02, Time: 0.19
# constant_bcs_val: 16.901
# It: 39800, Loss: 7.684e-02, Loss_u: 6.650e-02, Loss_r: 1.034e-02, Time: 0.10
# constant_bcs_val: 18.508
# It: 39810, Loss: 1.045e-01, Loss_u: 9.764e-02, Loss_r: 6.890e-03, Time: 0.18
# constant_bcs_val: 17.294
# It: 39820, Loss: 1.125e-01, Loss_u: 1.096e-01, Loss_r: 2.913e-03, Time: 0.12
# constant_bcs_val: 15.744
# It: 39830, Loss: 1.300e-01, Loss_u: 1.267e-01, Loss_r: 3.345e-03, Time: 0.12
# constant_bcs_val: 14.292
# It: 39840, Loss: 8.053e-02, Loss_u: 7.538e-02, Loss_r: 5.151e-03, Time: 0.19
# constant_bcs_val: 13.752
# It: 39850, Loss: 5.794e-02, Loss_u: 4.275e-02, Loss_r: 1.519e-02, Time: 0.09
# constant_bcs_val: 21.769
# It: 39860, Loss: 1.300e-01, Loss_u: 1.042e-01, Loss_r: 2.581e-02, Time: 0.10
# constant_bcs_val: 22.306
# It: 39870, Loss: 1.704e-01, Loss_u: 1.603e-01, Loss_r: 1.007e-02, Time: 0.18
# constant_bcs_val: 21.237
# It: 39880, Loss: 1.150e-01, Loss_u: 1.114e-01, Loss_r: 3.630e-03, Time: 0.11
# constant_bcs_val: 19.179
# It: 39890, Loss: 1.253e-01, Loss_u: 1.142e-01, Loss_r: 1.103e-02, Time: 0.10
# constant_bcs_val: 18.697
# It: 39900, Loss: 9.745e-02, Loss_u: 9.196e-02, Loss_r: 5.488e-03, Time: 0.09
# constant_bcs_val: 17.118
# It: 39910, Loss: 1.296e-01, Loss_u: 1.237e-01, Loss_r: 5.862e-03, Time: 0.09
# constant_bcs_val: 15.931
# It: 39920, Loss: 1.918e-01, Loss_u: 1.800e-01, Loss_r: 1.186e-02, Time: 0.09
# constant_bcs_val: 15.261
# It: 39930, Loss: 8.739e-02, Loss_u: 6.410e-02, Loss_r: 2.329e-02, Time: 0.17
# constant_bcs_val: 19.132
# It: 39940, Loss: 8.876e-02, Loss_u: 4.777e-02, Loss_r: 4.100e-02, Time: 0.19
# constant_bcs_val: 24.117
# It: 39950, Loss: 1.585e-01, Loss_u: 1.510e-01, Loss_r: 7.411e-03, Time: 0.10
# constant_bcs_val: 22.697
# It: 39960, Loss: 1.068e-01, Loss_u: 1.031e-01, Loss_r: 3.654e-03, Time: 0.15
# constant_bcs_val: 20.687
# It: 39970, Loss: 9.080e-02, Loss_u: 7.942e-02, Loss_r: 1.138e-02, Time: 0.10
# constant_bcs_val: 18.918
# It: 39980, Loss: 1.271e-01, Loss_u: 1.191e-01, Loss_r: 7.974e-03, Time: 0.12
# constant_bcs_val: 17.235
# It: 39990, Loss: 5.779e-02, Loss_u: 4.568e-02, Loss_r: 1.211e-02, Time: 0.10
# constant_bcs_val: 20.514
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 4.862e-02, Loss_u: 3.578e-02, Loss_r: 1.284e-02, Time: 4.57
# constant_bcs_val: 20.681
# l2 error: 1.80e-01
# l2 error: 2.92e-01
# average lambda_bc1.1164e+01
# average lambda_res1.0
# Save uv NN parameters successfully in %s ...checkpoints/Dec-12-2023_22-33-06-255267_M2
# Final loss total loss: 4.830931e-02
# Final loss loss_res: 1.225996e-02
# Final loss loss_bcs1: 4.970780e-04
# Final loss loss_bcs2: 2.279480e-04
# Final loss loss_bcs3: 1.029317e-03
# Final loss loss_bcs4: 2.919789e-06
# elapsed: 7.68e+03
# Relative L2 error_u: 1.80e-01
# Relative L2 error_v: 2.92e-01
#
#
# Method: mini_batch
#
# average of time_list:7.6789e+03
# average of error_u_list:1.7975e-01
# average of error_v_list:2.9160e-01

# %%
mode.plot_grad()

# %%
def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
    from mpl_toolkits.axes_grid1 import ImageGrid

    ### Plot ###

    # Exact solution & Predicted solution
    # Exact soluton
    U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

    # Predicted solution
    U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
    F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

    titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $v(x)$' , 'Predicted $v(x)$' , 'Absolute error']
    data = [U_star.T , U_pred ,  np.abs(U_star.T - U_pred) , F_star.T , F_pred ,  np.abs(F_star.T - F_pred) ]

    fig_1 = plt.figure(1, figsize=(13, 5))
    grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                    label_mode="1", axes_pad=1.7, share_all=False, 
                    cbar_mode="each", cbar_location="right", 
                    cbar_size="5%", cbar_pad=0.0)
# CREATE ARGUMENTS DICT FOR CONTOURPLOTS
    minmax_list = []
    for d in data:
        # if(local):
        #     minmax_list.append([np.min(d), np.max(d)])
        # else:
        minmax_list.append([np.min(d), np.max(d)])

        # kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60), cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

    for ax, z, minmax, title in zip(grid, data, minmax_list, titles):
    #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
        #pcfsets.append(pcf)
        # if (timeStp == 0):
        pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
        cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
        ax.cax.tick_params(labelsize=14.5)
        ax.set_title(title, fontsize=14.5, pad=7)
        ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
        ax.set_xlabel("x", fontsize=14.5)
        ax.tick_params(labelsize=14.5)
        ax.set_xlim(x1.min(), x1.max())
        ax.set_ylim(x2.min(), x2.max())
        ax.set_aspect("equal")

    fig_1.set_size_inches(15, 10, True)
    fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
    plt.tight_layout()
    plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
    plt.close("all" , )

# %%
u_ref.flatten()[:,None].shape
# Out:
# (10000, 1)

# %%
# Out:
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)

# %%
v_pred.shape
# Out:
# (100, 100)

# %%
import scipy.io

mode = 'M2'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = [1831.07 , ]
error_u_list = [0.2112 , 0.]
error_v_list = [0.3271 , 0.]
error_p_list = [0.094 , 0.]

for mtd in methods:
    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ,  error_p_list]


##Full Batch
time_list = [8048.86 , ]
error_u_list = [ 0.0367 ,0. ]
error_v_list = [0.0706 , 0.]
error_p_list = [0.465 , 0.]

for mtd in methods:
    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ,  error_p_list]


scipy.io.savemat("./dataset/NS_model_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
### Plot ###
###########

# %%
# Test Data
nx = 100
ny = 100  # change to 100
x = np.linspace(0.0, 1.0, nx)
y = np.linspace(0.0, 1.0, ny)
X, Y = np.meshgrid(x, y)

X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))

# Predictions
psi_pred, p_pred = mode.predict_psi_p(X_star)
u_pred, v_pred = mode.predict_uv(X_star)

psi_star = griddata(X_star, psi_pred.flatten(), (X, Y), method='cubic')
p_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
u_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
v_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')

velocity = np.sqrt(u_pred**2 + v_pred**2)
velocity_star = griddata(X_star, velocity.flatten(), (X, Y), method='cubic')

# Reference
u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

# Relative error
error = np.linalg.norm(u_star - u_pred.T, 2) / np.linalg.norm(u_star, 2)
print('l2 error: {:.2e}'.format(error))
error = np.linalg.norm(v_star - v_pred.T, 2) / np.linalg.norm(v_star, 2)
print('l2 error: {:.2e}'.format(error))
error = np.linalg.norm(p_pred - p_star.T, 2) / np.linalg.norm(p_star, 2)
print('l2 error: {:.2e}'.format(error))

### Plot ###
###########

# %%
# Reference solution & Prediceted solution
fig_1 = plt.figure(1, figsize=(18, 5))
fig_1.add_subplot(1, 3, 1)
plt.pcolor(X.T, Y.T, velocity_ref, cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Reference Velocity')

fig_1.add_subplot(1, 3, 2)
plt.pcolor(x, Y, velocity_star, cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Predicted Velocity')
plt.tight_layout()

fig_1.add_subplot(1, 3, 3)
plt.pcolor(X, Y, np.abs(velocity_star - velocity_ref.T), cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Absolute Error')
plt.show()

# %%
    ## Loss ##
loss_res = mode.loss_res_log
loss_bcs = mode.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
## Adaptive Constant
adaptive_constant = mode.adpative_constant_bcs_log
    
fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# %%
## Gradients #
data_gradients_res = mode.dict_gradients_res_layers
data_gradients_bcs = mode.dict_gradients_bcs_layers

num_hidden_layers = len(layers) -1
cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_{u_b}$')

    # ax.get_legend().remove()
    ax.set_xlim([-1.0, 1.0])
    ax.set_ylim([0, 100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()

fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()
