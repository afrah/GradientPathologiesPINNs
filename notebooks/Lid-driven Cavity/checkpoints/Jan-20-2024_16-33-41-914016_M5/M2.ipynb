# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import pandas as pd
# from NS_model_tf import Sampler, Navier_Stokes2D
import os
os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import scipy
import scipy.io
import time

import sys

import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle
def U_gamma_1(x):
    num = x.shape[0]
    return np.tile(np.array([1.0, 0.0]), (num, 1))


def U_gamma_2(x):
    num = x.shape[0]
    return np.zeros((num, 2))


def f(x):
    num = x.shape[0]
    return np.zeros((num, 2))

def operator(psi, p, x, y, Re, sigma_x=1.0, sigma_y=1.0):
    u = tf.gradients(psi, y)[0] / sigma_y
    v = - tf.gradients(psi, x)[0] / sigma_x

    u_x = tf.gradients(u, x)[0] / sigma_x
    u_y = tf.gradients(u, y)[0] / sigma_y

    v_x = tf.gradients(v, x)[0] / sigma_x
    v_y = tf.gradients(v, y)[0] / sigma_y

    p_x = tf.gradients(p, x)[0] / sigma_x
    p_y = tf.gradients(p, y)[0] / sigma_y

    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    u_yy = tf.gradients(u_y, y)[0] / sigma_y

    v_xx = tf.gradients(v_x, x)[0] / sigma_x
    v_yy = tf.gradients(v_y, y)[0] / sigma_y

    Ru_momentum = u * u_x + v * u_y + p_x - (u_xx + u_yy) / Re
    Rv_momentum = u * v_x + v * v_y + p_y - (v_xx + v_yy) / Re

    return Ru_momentum, Rv_momentum

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Navier_Stokes2D:
    def __init__(self, layers, operator, bcs_sampler, res_sampler, Re, mode , sess):


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]
        self.mu_y, self.sigma_y = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler


        # Navier Stokes constant
        self.Re = tf.constant(Re, dtype=tf.float32)

        # Adaptive re-weighting constant
        self.beta = 0.9
        self.adaptive_constant_bcs_val = np.array(1.0)

        # Define Tensorflow session
        self.sess = sess

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)


        # Define placeholders and computational graph
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc1_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc2_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc3_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc4_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.adaptive_constant_bcs_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs_val.shape)

        # Evaluate predictions
        self.u_bc1_pred, self.v_bc1_pred = self.net_uv(self.x_bc1_tf, self.y_bc1_tf)
        self.u_bc2_pred, self.v_bc2_pred = self.net_uv(self.x_bc2_tf, self.y_bc2_tf)
        self.u_bc3_pred, self.v_bc3_pred = self.net_uv(self.x_bc3_tf, self.y_bc3_tf)
        self.u_bc4_pred, self.v_bc4_pred = self.net_uv(self.x_bc4_tf, self.y_bc4_tf)

        self.U_bc1_pred = tf.concat([self.u_bc1_pred, self.v_bc1_pred], axis=1)
        self.U_bc2_pred = tf.concat([self.u_bc2_pred, self.v_bc2_pred], axis=1)
        self.U_bc3_pred = tf.concat([self.u_bc3_pred, self.v_bc3_pred], axis=1)
        self.U_bc4_pred = tf.concat([self.u_bc4_pred, self.v_bc4_pred], axis=1)

        self.psi_pred, self.p_pred = self.net_psi_p(self.x_u_tf, self.y_u_tf)
        self.u_pred, self.v_pred = self.net_uv(self.x_u_tf, self.y_u_tf)
        self.u_momentum_pred, self.v_momentum_pred = self.net_r(self.x_r_tf, self.y_r_tf)

        # Residual loss
        self.loss_u_momentum = tf.reduce_mean(tf.square(self.u_momentum_pred))
        self.loss_v_momentum = tf.reduce_mean(tf.square(self.v_momentum_pred))

        self.loss_res = self.loss_u_momentum + self.loss_v_momentum
        
        # Boundary loss
        self.loss_bc1 = tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.U_bc2_pred))
        self.loss_bc3 = tf.reduce_mean(tf.square(self.U_bc3_pred))
        self.loss_bc4 = tf.reduce_mean(tf.square(self.U_bc4_pred))
        
        self.loss_bcs = self.adaptive_constant_bcs_tf * tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf) +tf.square(self.U_bc2_pred) + tf.square(self.U_bc3_pred) + tf.square(self.U_bc4_pred))
        
        # Total loss
        self.loss = self.loss_res + self.loss_bcs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bc1 , self.loss_bc2 , self.loss_bc3, self.loss_bc4] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bc1", "loss_bc2", "loss_bc3", "loss_bc4"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_res_log = []
        self.loss_bcs_log = []
        # self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_bcs = []
        for i in range(1 , len(self.layers) - 2):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])

        self.adpative_constant_bcs_list = []
        self.adpative_constant_res_list = []
        self.adpative_constant_bcs_log = []
        self.mean_constant_res_log = []
        self.mean_constant_bcs_log = []

        for i in range(len(self.layers) - 1):
            self.adpative_constant_res_list.append( tf.reduce_mean(tf.abs(self.grad_res[i])))
            self.adpative_constant_bcs_list.append(  tf.reduce_mean(tf.abs(self.grad_bcs[i])))

        self.adaptive_constant_res = tf.reduce_mean(tf.stack(self.adpative_constant_res_list))
        self.adaptive_constant_bcs =  tf.reduce_mean(tf.stack(self.adpative_constant_bcs_list))




        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bc1 ,  self.loss_bc2 ,  self.loss_bc3  ,  self.loss_bc4] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs1" , "loss_bcs2", "loss_bcs3" ,  "loss_bcs4"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)

        init = tf.global_variables_initializer()
        self.sess.run(init)
        
#############################################################################################################################################
        


    def lambda_balance(self  , term  ):
                histoy_mean =  np.mean(self.loss_history[term])
                m = 3.0 #len(self.loss_list)
                num = np.exp( np.mean(self.loss_history[term][-99::]) )#/(self.T * histoy_mean)) np.exp( )
                denum = 0 
                loss_list = [ "loss_res"   , "loss_bcs" ,"loss_ics_u_t"  ]
                for  key in loss_list:
                    denum +=  np.exp(  np.mean(self.loss_history[key][-99::]) + 1e-12 )# /(self.T * histoy_mean))  np.exp(self.loss_history[key][-1] )

                return m * (num / denum)
    

    def trainmb(self, nIter, batch_size):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, _ = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, _ = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                       self.U_bc1_tf: u_bc1_batch,
                       self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                       self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                       self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                       self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                       self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val
                       }

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            if it % 100 == 0:

                adaptive_constant_res ,  adaptive_constant_bcs = self.sess.run([self.adaptive_constant_res , self.adaptive_constant_bcs], tf_dict)
                self.mean_constant_res_log.append(adaptive_constant_res)
                self.mean_constant_bcs_log.append(adaptive_constant_bcs)
                self.print("adaptive_constant_res: {:.3f}".format(adaptive_constant_res))
                self.print("adaptive_constant_bcs: {:.3f}".format(adaptive_constant_bcs))

            # Print
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)
                self.print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' % (it, loss_value, loss_u_value, loss_r_value, elapsed))


                if it % 1000 == 0:

                    # Compute the adaptive constant
                    adaptive_constant_bcs_val = self.sess.run(self.adaptive_constant_bcs, tf_dict)

                    self.adaptive_constant_bcs_val = 5 #* adaptive_constant_bcs_val *  (1.0 - self.beta) + self.beta * self.adaptive_constant_bcs_val

                    self.adpative_constant_bcs_log.append(adaptive_constant_res/adaptive_constant_bcs_val)
                    # self.loss_bcs_log.append(loss_u_value)
                    # self.loss_res_log.append(loss_r_value)


                    self.print("constant_bcs_val: {:.3f}".format(adaptive_constant_res/adaptive_constant_bcs_val))


            sys.stdout.flush()

            start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])


###############################################################################################        
    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev, dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H


    # Forward pass for stream-pressure formulation
    def net_psi_p(self, x, y):
        psi_p = self.forward_pass(tf.concat([x, y], 1))
        psi = psi_p[:, 0:1]
        p = psi_p[:, 1:2]
        return psi, p

    # Forward pass for velocities
    def net_uv(self, x, y):
        psi, p = self.net_psi_p(x, y)
        u = tf.gradients(psi, y)[0] / self.sigma_y
        v = - tf.gradients(psi, x)[0] / self.sigma_x
        return u, v

    # Forward pass for residual
    def net_r(self, x, y):
        psi, p = self.net_psi_p(x, y)
        u_momentum_pred, v_momentum_pred = self.operator(psi, p, x, y,
                                                         self.Re,
                                                         self.sigma_x, self.sigma_y)

        return u_momentum_pred, v_momentum_pred

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
    def train(self, nIter ,  bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        batch_size = bcbatch_size
        X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
        X_bc3_batch, _ = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
        X_bc4_batch, _ = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

        # Fetch residual mini-batch
        batch_size = ubatch_size

        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                    self.U_bc1_tf: u_bc1_batch,
                    self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                    self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                    self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                    self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val
                    }
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)

                # Compute the adaptive constant
                adaptive_constant_bcs_val = self.sess.run(self.adaptive_constant_bcs, tf_dict)

                self.adaptive_constant_bcs_val = adaptive_constant_bcs_val *  (1.0 - self.beta) + self.beta * self.adaptive_constant_bcs_val

                # self.adpative_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                # self.loss_bcs_log.append(loss_u_value)
                # self.loss_res_log.append(loss_r_value)

                print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' % (it, loss_value, loss_u_value, loss_r_value, elapsed))

                print("constant_bcs_val: {:.3f}".format(self.adaptive_constant_bcs_val))
                start_time = timeit.default_timer()

            sys.stdout.flush()
            start_time = timeit.default_timer()

            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
            # # Store gradients
            # if it % 10000 == 0:
            #     self.save_gradients(tf_dict)
            #     print("Gradients information stored ...")

   # Trains the model by minimizing the MSE loss


    # Evaluates predictions at test points
    def predict_psi_p(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2]}
        psi_star = self.sess.run(self.psi_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)
        return psi_star, p_star

    def predict_uv(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        return u_star, v_star



 ############################################################

    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values

    def plot_loss_history(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.show()
    ############################################################
  
  # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1    = self.sess.run([ self.grad_res[i],self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=3)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        plt.close("all" , )
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
        from mpl_toolkits.axes_grid1 import ImageGrid

        ### Plot ###

        # Exact solution & Predicted solution
        # Exact soluton
        U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
        F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

        # Predicted solution
        U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
        F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

        titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $v(x)$' , 'Predicted $v(x)$' , 'Absolute error']
        data = [U_star.T , U_pred ,  np.abs(U_star.T - U_pred) , F_star.T , F_pred ,  np.abs(F_star.T - F_pred) ]

        fig_1 = plt.figure(1, figsize=(13, 5))
        grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                        label_mode="1", axes_pad=1.7, share_all=False, 
                        cbar_mode="each", cbar_location="right", 
                        cbar_size="5%", cbar_pad=0.0)
    # CREATE ARGUMENTS DICT FOR CONTOURPLOTS
        minmax_list = []
        for d in data:
            # if(local):
            #     minmax_list.append([np.min(d), np.max(d)])
            # else:
            minmax_list.append([np.min(d), np.max(d)])

            # kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60), cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

        for ax, z, minmax, title in zip(grid, data, minmax_list, titles):
        #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
            #pcfsets.append(pcf)
            # if (timeStp == 0):
            pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
            cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
            ax.cax.tick_params(labelsize=14.5)
            ax.set_title(title, fontsize=14.5, pad=7)
            ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
            ax.set_xlabel("x", fontsize=14.5)
            ax.tick_params(labelsize=14.5)
            ax.set_xlim(x1.min(), x1.max())
            ax.set_ylim(x2.min(), x2.max())
            ax.set_aspect("equal")

        fig_1.set_size_inches(15, 10, True)
        fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
        plt.close("all" , )


    def plot_grad(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adpative_constant_bcs_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc}}}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)
        plt.close("all" , )


    
    def plot_lambda(self ):

        fontsize = 17
        fig, ax = plt.subplots()
        fig.set_size_inches([16,8])
        ax.semilogy(self.mean_constant_res_log, label=r'$\bar{\nabla_\theta {u_{res}}}$' , color = 'tab:green')
        ax.semilogy(self.mean_constant_bcs_log, label=r'$\bar{\nabla_\theta {u_{bc}}}$' , color = 'tab:blue')
        ax.set_xlabel("epochs", fontsize=fontsize)
        ax.set_ylabel(r'$\bar{\nabla_\theta {u}}$', fontsize=fontsize)
        ax.tick_params(labelsize=fontsize)
        ax.legend(loc='center left', bbox_to_anchor=(-0.25, 0.5))

        ax2 = ax.twinx() 

        # fig, ax = plt.subplots()
        # fig.set_size_inches([15,8])
    
        ax2.semilogy(self.adpative_constant_bcs_log, label=r'$\bar{\lambda_{bc}}$'  ,  linestyle='dashed' , color = 'tab:green') 
        ax2.set_xlabel("epochs", fontsize=fontsize)
        ax2.set_ylabel(r'$\bar{\lambda}$', fontsize=fontsize)
        ax2.tick_params(labelsize=fontsize)
        ax2.legend(loc='center right', bbox_to_anchor=(1.2, 0.5))

        plt.tight_layout()

        path = os.path.join(self.dirname,'lambda_history.png')
        plt.savefig(path)

# %%
#        [elapsed, error_u , error_v ,  error_p] = test_method(mtd , layers, operator, bcs_sampler, res_sampler ,Re , stiff_ratio ,  X_star , X , Y)

def test_method(method , layers, operator, bcs_sampler, res_sampler, Re ,  mode , X_star , X , Y , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):


    model = Navier_Stokes2D(layers, operator, bcs_sampler, res_sampler, Re, mode)

    # Train model
    start_time = time.time()

    if method =="full_batch":
        model.train(nIter  , bcbatch_size , ubatch_size  )
    elif method =="mini_batch":
        model.trainmb(nIter, mbbatch_size)
    else:
        print("unknown method!")
    elapsed = time.time() - start_time

    # Predictions
    _, p_pred = model.predict_psi_p(X_star)
    u_pred, v_pred = model.predict_uv(X_star)

    # psi_star = griddata(X_star, psi_pred.flatten(), (X, Y), method='cubic')
    p_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
    # u_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
    # v_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')

    # velocity = np.sqrt(u_pred**2 + v_pred**2)
    # velocity_star = griddata(X_star, velocity.flatten(), (X, Y), method='cubic')

    # Reference
    u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
    v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
    # velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

    u_pred = u_pred.reshape(100,100)
    v_pred = v_pred.reshape(100,100)
    p_pred = p_pred.reshape(100,100)

    # Relative error
    error_u = np.linalg.norm(u_ref - u_pred.T, 2) / np.linalg.norm(u_ref, 2)
    print('l2 error: {:.2e}'.format(error_u))
    error_v = np.linalg.norm(v_ref - v_pred.T, 2) / np.linalg.norm(v_ref, 2)
    print('l2 error: {:.2e}'.format(error_v))
    error_p = np.linalg.norm(p_pred - p_star.T, 2) / np.linalg.norm(p_star, 2)
    print('l2 error: {:.2e}'.format(error_p))

    return [elapsed, error_u , error_v ,error_p ]

# %%
nIter =40001
bcbatch_size = 350
ubatch_size = 5000
mbbatch_size = 128

# Parameters of equations
Re = 100.0

# Domain boundaries
bc1_coords = np.array([[0.0, 1.0], [1.0, 1.0]])
bc2_coords = np.array([[0.0, 0.0], [0.0, 1.0]])
bc3_coords = np.array([[1.0, 0.0], [1.0, 1.0]])
bc4_coords = np.array([[0.0, 0.0], [1.0, 0.0]])
dom_coords = np.array([[0.0, 0.0], [1.0, 1.0]])

# Define model
model = 'M2'
layers = [2, 50, 50, 50, 50 , 50 , 2]

stiff_ratio = False  # Log the eigenvalues of Hessian of losses


# Test Data
nx = 100
ny = 100  # change to 100
x = np.linspace(0.0, 1.0, nx)
y = np.linspace(0.0, 1.0, ny)
X, Y = np.meshgrid(x, y)


X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))


iterations = 1
methods = ["mini_batch" ]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_v_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create boundary conditions samplers
        bc1 = Sampler(2, bc1_coords, lambda x: U_gamma_1(x), name='Dirichlet BC1')
        bc2 = Sampler(2, bc2_coords, lambda x: U_gamma_2(x), name='Dirichlet BC2')
        bc3 = Sampler(2, bc3_coords, lambda x: U_gamma_2(x), name='Dirichlet BC3')
        bc4 = Sampler(2, bc4_coords, lambda x: U_gamma_2(x), name='Dirichlet BC4')
        bcs_sampler = [bc1, bc2, bc3, bc4]

        # Create residual sampler
        res_sampler = Sampler(2, dom_coords, lambda x: f(x), name='Forcing')

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            mode = Navier_Stokes2D(layers, operator, bcs_sampler, res_sampler, Re, model , sess)

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                mode.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                mode.trainmb(nIter, mbbatch_size)
            else:
                mode.print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            _, p_pred = mode.predict_psi_p(X_star)
            u_pred, v_pred = mode.predict_uv(X_star)

            # Reference
            u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
            v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
            # velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

            u_pred = u_pred.reshape(100,100)
            v_pred = v_pred.reshape(100,100)

            # Relative error
            error_u = np.linalg.norm(u_ref - u_pred.T, 2) / np.linalg.norm(u_ref, 2)
            error_v = np.linalg.norm(v_ref - v_pred.T, 2) / np.linalg.norm(v_ref, 2)

            mode.print('l2 error: {:.2e}'.format(error_u))
            mode.print('l2 error: {:.2e}'.format(error_v))

       
            mode.print("average lambda_bc" , np.average(mode.adpative_constant_bcs_log))
            mode.print("average lambda_res" , str(1.0))
            # sess.close
            mode.plot_lambda()
            mode.plot_grad()
            mode.save_NN()
            mode.plt_prediction( X , Y , X_star , u_ref , u_pred , v_ref , v_pred)


        mode.print('elapsed: {:.2e}'.format(elapsed))
        mode.print('Relative L2 error_u: {:.2e}'.format(error_u))
        mode.print('Relative L2 error_v: {:.2e}'.format(error_v))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_v_list.append(error_v)

    mode.print("\n\nMethod: ", mtd)
    mode.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    mode.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    mode.print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )

    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(mode.dirname,""+mtd+"_Lid-driven-Cavity_"+model+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_17917/4242647522.py:59: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17917/4242647522.py:60: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17917/4242647522.py:61: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17917/4242647522.py:61: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-23 22:33:49.244351: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-23 22:33:49.277221: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-23 22:33:49.277726: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558e0c87fc50 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-23 22:33:49.277739: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-23 22:33:49.278905: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_17917/300164131.py:167: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17917/300164131.py:51: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17917/300164131.py:110: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17917/300164131.py:113: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17917/300164131.py:158: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# adaptive_constant_res: 0.080
# adaptive_constant_bcs: 0.028
# It: 0, Loss: 5.869e-01, Loss_u: 4.582e-01, Loss_r: 1.287e-01, Time: 65.99
# constant_bcs_val: 2.858
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.047
# It: 100, Loss: 3.641e-01, Loss_u: 3.410e-01, Loss_r: 2.311e-02, Time: 0.22
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# adaptive_constant_res: 0.017
# adaptive_constant_bcs: 0.044
# It: 200, Loss: 1.670e-01, Loss_u: 1.514e-01, Loss_r: 1.562e-02, Time: 0.31
# adaptive_constant_res: 0.043
# adaptive_constant_bcs: 0.113
# It: 300, Loss: 1.805e-01, Loss_u: 1.602e-01, Loss_r: 2.030e-02, Time: 0.22
# adaptive_constant_res: 0.006
# adaptive_constant_bcs: 0.113
# It: 400, Loss: 1.453e-01, Loss_u: 1.354e-01, Loss_r: 9.850e-03, Time: 0.20
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.060
# It: 500, Loss: 1.693e-01, Loss_u: 1.591e-01, Loss_r: 1.022e-02, Time: 0.21
# adaptive_constant_res: 0.033
# adaptive_constant_bcs: 0.214
# It: 600, Loss: 2.201e-01, Loss_u: 2.020e-01, Loss_r: 1.807e-02, Time: 0.22
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.061
# It: 700, Loss: 1.131e-01, Loss_u: 1.020e-01, Loss_r: 1.109e-02, Time: 0.25
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.136
# It: 800, Loss: 1.793e-01, Loss_u: 1.700e-01, Loss_r: 9.251e-03, Time: 0.22
# adaptive_constant_res: 0.040
# adaptive_constant_bcs: 0.068
# It: 900, Loss: 1.481e-01, Loss_u: 1.244e-01, Loss_r: 2.368e-02, Time: 0.21
# adaptive_constant_res: 0.025
# adaptive_constant_bcs: 0.091
# It: 1000, Loss: 1.291e-01, Loss_u: 1.144e-01, Loss_r: 1.469e-02, Time: 0.23
# constant_bcs_val: 0.278
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.075
# It: 1100, Loss: 1.519e-01, Loss_u: 1.416e-01, Loss_r: 1.039e-02, Time: 0.21
# adaptive_constant_res: 0.029
# adaptive_constant_bcs: 0.048
# It: 1200, Loss: 1.131e-01, Loss_u: 9.250e-02, Loss_r: 2.056e-02, Time: 0.22
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.111
# It: 1300, Loss: 8.908e-02, Loss_u: 8.030e-02, Loss_r: 8.772e-03, Time: 0.21
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.055
# It: 1400, Loss: 1.380e-01, Loss_u: 1.280e-01, Loss_r: 1.002e-02, Time: 0.21
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.075
# It: 1500, Loss: 1.172e-01, Loss_u: 1.070e-01, Loss_r: 1.016e-02, Time: 0.50
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.064
# It: 1600, Loss: 9.186e-02, Loss_u: 7.920e-02, Loss_r: 1.266e-02, Time: 0.22
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.200
# It: 1700, Loss: 1.310e-01, Loss_u: 1.213e-01, Loss_r: 9.711e-03, Time: 0.23
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.117
# It: 1800, Loss: 1.140e-01, Loss_u: 1.029e-01, Loss_r: 1.108e-02, Time: 0.21
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.070
# It: 1900, Loss: 1.324e-01, Loss_u: 1.227e-01, Loss_r: 9.633e-03, Time: 0.24
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.064
# It: 2000, Loss: 6.993e-02, Loss_u: 5.758e-02, Loss_r: 1.236e-02, Time: 0.25
# constant_bcs_val: 0.241
# adaptive_constant_res: 0.035
# adaptive_constant_bcs: 0.060
# It: 2100, Loss: 1.052e-01, Loss_u: 8.248e-02, Loss_r: 2.270e-02, Time: 0.22
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.051
# It: 2200, Loss: 7.843e-02, Loss_u: 6.724e-02, Loss_r: 1.120e-02, Time: 0.22
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.038
# It: 2300, Loss: 1.272e-01, Loss_u: 1.195e-01, Loss_r: 7.681e-03, Time: 0.25
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.132
# It: 2400, Loss: 9.861e-02, Loss_u: 8.399e-02, Loss_r: 1.462e-02, Time: 0.22
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.053
# It: 2500, Loss: 9.994e-02, Loss_u: 8.531e-02, Loss_r: 1.463e-02, Time: 0.24
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.034
# It: 2600, Loss: 9.602e-02, Loss_u: 8.240e-02, Loss_r: 1.362e-02, Time: 0.22
# adaptive_constant_res: 0.011
# adaptive_constant_bcs: 0.157
# It: 2700, Loss: 1.244e-01, Loss_u: 1.083e-01, Loss_r: 1.612e-02, Time: 0.23
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.060
# It: 2800, Loss: 9.144e-02, Loss_u: 7.487e-02, Loss_r: 1.657e-02, Time: 0.23
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.059
# It: 2900, Loss: 1.056e-01, Loss_u: 9.550e-02, Loss_r: 1.015e-02, Time: 0.22
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.040
# It: 3000, Loss: 8.223e-02, Loss_u: 6.897e-02, Loss_r: 1.327e-02, Time: 0.23
# constant_bcs_val: 0.407
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.062
# It: 3100, Loss: 8.597e-02, Loss_u: 7.422e-02, Loss_r: 1.176e-02, Time: 0.23
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.090
# It: 3200, Loss: 1.015e-01, Loss_u: 9.260e-02, Loss_r: 8.867e-03, Time: 0.22
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.117
# It: 3300, Loss: 1.514e-01, Loss_u: 1.360e-01, Loss_r: 1.543e-02, Time: 0.23
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.097
# It: 3400, Loss: 1.372e-01, Loss_u: 1.213e-01, Loss_r: 1.585e-02, Time: 0.24
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.022
# It: 3500, Loss: 7.849e-02, Loss_u: 6.195e-02, Loss_r: 1.654e-02, Time: 0.30
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.117
# It: 3600, Loss: 8.033e-02, Loss_u: 6.924e-02, Loss_r: 1.109e-02, Time: 0.44
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.071
# It: 3700, Loss: 1.131e-01, Loss_u: 9.486e-02, Loss_r: 1.829e-02, Time: 0.47
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.160
# It: 3800, Loss: 1.026e-01, Loss_u: 9.307e-02, Loss_r: 9.494e-03, Time: 0.22
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.053
# It: 3900, Loss: 1.196e-01, Loss_u: 1.050e-01, Loss_r: 1.465e-02, Time: 0.22
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.032
# It: 4000, Loss: 8.967e-02, Loss_u: 7.631e-02, Loss_r: 1.336e-02, Time: 0.46
# constant_bcs_val: 0.464
# adaptive_constant_res: 0.041
# adaptive_constant_bcs: 0.091
# It: 4100, Loss: 1.012e-01, Loss_u: 7.498e-02, Loss_r: 2.620e-02, Time: 0.43
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.029
# It: 4200, Loss: 6.096e-02, Loss_u: 4.929e-02, Loss_r: 1.167e-02, Time: 0.26
# adaptive_constant_res: 0.011
# adaptive_constant_bcs: 0.041
# It: 4300, Loss: 1.264e-01, Loss_u: 1.146e-01, Loss_r: 1.178e-02, Time: 0.24
# adaptive_constant_res: 0.030
# adaptive_constant_bcs: 0.051
# It: 4400, Loss: 8.535e-02, Loss_u: 6.530e-02, Loss_r: 2.006e-02, Time: 0.25
# adaptive_constant_res: 0.024
# adaptive_constant_bcs: 0.074
# It: 4500, Loss: 8.900e-02, Loss_u: 7.060e-02, Loss_r: 1.840e-02, Time: 0.24
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.075
# It: 4600, Loss: 8.758e-02, Loss_u: 6.888e-02, Loss_r: 1.870e-02, Time: 0.28
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.075
# It: 4700, Loss: 8.699e-02, Loss_u: 7.389e-02, Loss_r: 1.310e-02, Time: 0.26
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.033
# It: 4800, Loss: 9.584e-02, Loss_u: 7.968e-02, Loss_r: 1.616e-02, Time: 0.27
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.067
# It: 4900, Loss: 8.621e-02, Loss_u: 7.291e-02, Loss_r: 1.330e-02, Time: 0.24
# adaptive_constant_res: 0.025
# adaptive_constant_bcs: 0.056
# It: 5000, Loss: 7.705e-02, Loss_u: 6.151e-02, Loss_r: 1.555e-02, Time: 0.25
# constant_bcs_val: 0.443
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.074
# It: 5100, Loss: 9.859e-02, Loss_u: 8.614e-02, Loss_r: 1.245e-02, Time: 0.22
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.058
# It: 5200, Loss: 7.766e-02, Loss_u: 6.312e-02, Loss_r: 1.454e-02, Time: 0.22
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.034
# It: 5300, Loss: 9.987e-02, Loss_u: 8.614e-02, Loss_r: 1.373e-02, Time: 0.23
# adaptive_constant_res: 0.019
# adaptive_constant_bcs: 0.057
# It: 5400, Loss: 8.124e-02, Loss_u: 6.542e-02, Loss_r: 1.582e-02, Time: 0.24
# adaptive_constant_res: 0.026
# adaptive_constant_bcs: 0.050
# It: 5500, Loss: 1.142e-01, Loss_u: 9.641e-02, Loss_r: 1.775e-02, Time: 0.23
# adaptive_constant_res: 0.032
# adaptive_constant_bcs: 0.072
# It: 5600, Loss: 8.753e-02, Loss_u: 6.792e-02, Loss_r: 1.961e-02, Time: 0.26
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.083
# It: 5700, Loss: 1.073e-01, Loss_u: 9.271e-02, Loss_r: 1.460e-02, Time: 0.38
# adaptive_constant_res: 0.039
# adaptive_constant_bcs: 0.041
# It: 5800, Loss: 9.779e-02, Loss_u: 6.494e-02, Loss_r: 3.284e-02, Time: 0.23
# adaptive_constant_res: 0.009
# adaptive_constant_bcs: 0.052
# It: 5900, Loss: 1.053e-01, Loss_u: 9.647e-02, Loss_r: 8.785e-03, Time: 0.25
# adaptive_constant_res: 0.017
# adaptive_constant_bcs: 0.046
# It: 6000, Loss: 1.183e-01, Loss_u: 1.071e-01, Loss_r: 1.122e-02, Time: 0.24
# constant_bcs_val: 0.363
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.032
# It: 6100, Loss: 5.490e-02, Loss_u: 4.644e-02, Loss_r: 8.459e-03, Time: 0.25
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.052
# It: 6200, Loss: 9.378e-02, Loss_u: 7.953e-02, Loss_r: 1.426e-02, Time: 0.25
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.019
# It: 6300, Loss: 6.857e-02, Loss_u: 5.647e-02, Loss_r: 1.210e-02, Time: 0.24
# adaptive_constant_res: 0.011
# adaptive_constant_bcs: 0.050
# It: 6400, Loss: 6.615e-02, Loss_u: 5.865e-02, Loss_r: 7.499e-03, Time: 0.25
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.033
# It: 6500, Loss: 9.118e-02, Loss_u: 7.564e-02, Loss_r: 1.554e-02, Time: 0.23
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.092
# It: 6600, Loss: 6.764e-02, Loss_u: 6.098e-02, Loss_r: 6.661e-03, Time: 0.22
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.025
# It: 6700, Loss: 5.187e-02, Loss_u: 4.025e-02, Loss_r: 1.162e-02, Time: 0.24
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.101
# It: 6800, Loss: 8.405e-02, Loss_u: 7.937e-02, Loss_r: 4.673e-03, Time: 0.24
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.045
# It: 6900, Loss: 6.784e-02, Loss_u: 5.767e-02, Loss_r: 1.018e-02, Time: 0.23
# adaptive_constant_res: 0.009
# adaptive_constant_bcs: 0.079
# It: 7000, Loss: 8.369e-02, Loss_u: 7.818e-02, Loss_r: 5.507e-03, Time: 0.20
# constant_bcs_val: 0.114
# adaptive_constant_res: 0.025
# adaptive_constant_bcs: 0.057
# It: 7100, Loss: 7.993e-02, Loss_u: 6.963e-02, Loss_r: 1.030e-02, Time: 0.23
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.028
# It: 7200, Loss: 7.256e-02, Loss_u: 6.331e-02, Loss_r: 9.248e-03, Time: 0.25
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.062
# It: 7300, Loss: 7.949e-02, Loss_u: 7.200e-02, Loss_r: 7.491e-03, Time: 0.27
# adaptive_constant_res: 0.023
# adaptive_constant_bcs: 0.059
# It: 7400, Loss: 8.183e-02, Loss_u: 6.868e-02, Loss_r: 1.316e-02, Time: 0.27
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.101
# It: 7500, Loss: 8.059e-02, Loss_u: 7.138e-02, Loss_r: 9.211e-03, Time: 0.24
# adaptive_constant_res: 0.019
# adaptive_constant_bcs: 0.080
# It: 7600, Loss: 7.594e-02, Loss_u: 6.726e-02, Loss_r: 8.677e-03, Time: 0.28
# adaptive_constant_res: 0.032
# adaptive_constant_bcs: 0.025
# It: 7700, Loss: 4.649e-02, Loss_u: 3.447e-02, Loss_r: 1.202e-02, Time: 0.47
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.107
# It: 7800, Loss: 6.343e-02, Loss_u: 5.618e-02, Loss_r: 7.246e-03, Time: 0.24
# adaptive_constant_res: 0.027
# adaptive_constant_bcs: 0.104
# It: 7900, Loss: 8.515e-02, Loss_u: 7.515e-02, Loss_r: 9.993e-03, Time: 0.51
# adaptive_constant_res: 0.019
# adaptive_constant_bcs: 0.039
# It: 8000, Loss: 5.326e-02, Loss_u: 4.656e-02, Loss_r: 6.704e-03, Time: 0.25
# constant_bcs_val: 0.479
# adaptive_constant_res: 0.033
# adaptive_constant_bcs: 0.029
# It: 8100, Loss: 6.311e-02, Loss_u: 5.257e-02, Loss_r: 1.053e-02, Time: 0.58
# adaptive_constant_res: 0.040
# adaptive_constant_bcs: 0.027
# It: 8200, Loss: 9.343e-02, Loss_u: 7.282e-02, Loss_r: 2.061e-02, Time: 0.24
# adaptive_constant_res: 0.032
# adaptive_constant_bcs: 0.092
# It: 8300, Loss: 6.851e-02, Loss_u: 5.542e-02, Loss_r: 1.309e-02, Time: 0.32
# adaptive_constant_res: 0.028
# adaptive_constant_bcs: 0.077
# It: 8400, Loss: 5.540e-02, Loss_u: 4.624e-02, Loss_r: 9.158e-03, Time: 0.24
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.063
# It: 8500, Loss: 6.758e-02, Loss_u: 5.691e-02, Loss_r: 1.067e-02, Time: 0.22
# adaptive_constant_res: 0.019
# adaptive_constant_bcs: 0.033
# It: 8600, Loss: 6.592e-02, Loss_u: 5.716e-02, Loss_r: 8.765e-03, Time: 0.24
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.028
# It: 8700, Loss: 3.485e-02, Loss_u: 2.696e-02, Loss_r: 7.892e-03, Time: 0.23
# adaptive_constant_res: 0.069
# adaptive_constant_bcs: 0.092
# It: 8800, Loss: 7.630e-02, Loss_u: 6.057e-02, Loss_r: 1.573e-02, Time: 0.23
# adaptive_constant_res: 0.073
# adaptive_constant_bcs: 0.041
# It: 8900, Loss: 6.340e-02, Loss_u: 4.339e-02, Loss_r: 2.001e-02, Time: 0.28
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.048
# It: 9000, Loss: 6.009e-02, Loss_u: 5.199e-02, Loss_r: 8.094e-03, Time: 0.26
# constant_bcs_val: 0.313
# adaptive_constant_res: 0.030
# adaptive_constant_bcs: 0.048
# It: 9100, Loss: 6.324e-02, Loss_u: 5.159e-02, Loss_r: 1.165e-02, Time: 0.23
# adaptive_constant_res: 0.024
# adaptive_constant_bcs: 0.036
# It: 9200, Loss: 3.869e-02, Loss_u: 2.869e-02, Loss_r: 9.998e-03, Time: 0.23
# adaptive_constant_res: 0.026
# adaptive_constant_bcs: 0.019
# It: 9300, Loss: 3.969e-02, Loss_u: 3.251e-02, Loss_r: 7.180e-03, Time: 0.23
# adaptive_constant_res: 0.058
# adaptive_constant_bcs: 0.045
# It: 9400, Loss: 1.039e-01, Loss_u: 8.806e-02, Loss_r: 1.581e-02, Time: 0.24
# adaptive_constant_res: 0.025
# adaptive_constant_bcs: 0.052
# It: 9500, Loss: 7.026e-02, Loss_u: 5.991e-02, Loss_r: 1.034e-02, Time: 0.21
# adaptive_constant_res: 0.030
# adaptive_constant_bcs: 0.060
# It: 9600, Loss: 7.146e-02, Loss_u: 6.289e-02, Loss_r: 8.564e-03, Time: 0.21
# adaptive_constant_res: 0.027
# adaptive_constant_bcs: 0.074
# It: 9700, Loss: 5.801e-02, Loss_u: 4.961e-02, Loss_r: 8.395e-03, Time: 0.24
# adaptive_constant_res: 0.019
# adaptive_constant_bcs: 0.091
# It: 9800, Loss: 7.215e-02, Loss_u: 6.642e-02, Loss_r: 5.731e-03, Time: 0.23
# adaptive_constant_res: 0.023
# adaptive_constant_bcs: 0.070
# It: 9900, Loss: 6.997e-02, Loss_u: 6.192e-02, Loss_r: 8.041e-03, Time: 0.26
# adaptive_constant_res: 0.009
# adaptive_constant_bcs: 0.085
# It: 10000, Loss: 9.522e-02, Loss_u: 8.940e-02, Loss_r: 5.816e-03, Time: 0.24
# constant_bcs_val: 0.112
# adaptive_constant_res: 0.030
# adaptive_constant_bcs: 0.034
# It: 10100, Loss: 6.812e-02, Loss_u: 5.943e-02, Loss_r: 8.690e-03, Time: 0.24
# adaptive_constant_res: 0.036
# adaptive_constant_bcs: 0.104
# It: 10200, Loss: 7.615e-02, Loss_u: 6.840e-02, Loss_r: 7.752e-03, Time: 0.25
# adaptive_constant_res: 0.027
# adaptive_constant_bcs: 0.029
# It: 10300, Loss: 6.993e-02, Loss_u: 5.994e-02, Loss_r: 9.989e-03, Time: 0.24
# adaptive_constant_res: 0.034
# adaptive_constant_bcs: 0.044
# It: 10400, Loss: 4.186e-02, Loss_u: 3.303e-02, Loss_r: 8.833e-03, Time: 0.26
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.014
# It: 10500, Loss: 3.517e-02, Loss_u: 2.476e-02, Loss_r: 1.041e-02, Time: 0.27
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.037
# It: 10600, Loss: 4.664e-02, Loss_u: 3.715e-02, Loss_r: 9.489e-03, Time: 0.25
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.064
# It: 10700, Loss: 6.360e-02, Loss_u: 5.667e-02, Loss_r: 6.930e-03, Time: 0.27
# adaptive_constant_res: 0.048
# adaptive_constant_bcs: 0.052
# It: 10800, Loss: 5.386e-02, Loss_u: 4.141e-02, Loss_r: 1.246e-02, Time: 0.25
# adaptive_constant_res: 0.031
# adaptive_constant_bcs: 0.031
# It: 10900, Loss: 7.282e-02, Loss_u: 6.279e-02, Loss_r: 1.004e-02, Time: 0.24
# adaptive_constant_res: 0.009
# adaptive_constant_bcs: 0.046
# It: 11000, Loss: 4.719e-02, Loss_u: 4.309e-02, Loss_r: 4.099e-03, Time: 0.25
# constant_bcs_val: 0.186
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.012
# It: 11100, Loss: 5.740e-02, Loss_u: 5.259e-02, Loss_r: 4.806e-03, Time: 0.54
# adaptive_constant_res: 0.049
# adaptive_constant_bcs: 0.074
# It: 11200, Loss: 8.433e-02, Loss_u: 7.191e-02, Loss_r: 1.242e-02, Time: 0.55
# adaptive_constant_res: 0.028
# adaptive_constant_bcs: 0.118
# It: 11300, Loss: 7.626e-02, Loss_u: 6.770e-02, Loss_r: 8.564e-03, Time: 0.23
# adaptive_constant_res: 0.009
# adaptive_constant_bcs: 0.054
# It: 11400, Loss: 5.965e-02, Loss_u: 5.520e-02, Loss_r: 4.455e-03, Time: 0.45
# adaptive_constant_res: 0.024
# adaptive_constant_bcs: 0.061
# It: 11500, Loss: 4.622e-02, Loss_u: 3.650e-02, Loss_r: 9.722e-03, Time: 0.25
# adaptive_constant_res: 0.034
# adaptive_constant_bcs: 0.033
# It: 11600, Loss: 5.938e-02, Loss_u: 5.000e-02, Loss_r: 9.378e-03, Time: 0.25
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.038
# It: 11700, Loss: 5.639e-02, Loss_u: 5.317e-02, Loss_r: 3.223e-03, Time: 0.30
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.106
# It: 11800, Loss: 8.585e-02, Loss_u: 7.744e-02, Loss_r: 8.405e-03, Time: 0.47
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.060
# It: 11900, Loss: 6.867e-02, Loss_u: 6.242e-02, Loss_r: 6.241e-03, Time: 0.22
# adaptive_constant_res: 0.063
# adaptive_constant_bcs: 0.046
# It: 12000, Loss: 6.228e-02, Loss_u: 4.625e-02, Loss_r: 1.603e-02, Time: 0.31
# constant_bcs_val: 1.365
# adaptive_constant_res: 0.045
# adaptive_constant_bcs: 0.040
# It: 12100, Loss: 6.565e-02, Loss_u: 5.216e-02, Loss_r: 1.349e-02, Time: 0.22
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.140
# It: 12200, Loss: 6.093e-02, Loss_u: 5.256e-02, Loss_r: 8.369e-03, Time: 0.21
# adaptive_constant_res: 0.037
# adaptive_constant_bcs: 0.111
# It: 12300, Loss: 4.779e-02, Loss_u: 3.628e-02, Loss_r: 1.151e-02, Time: 0.21
# adaptive_constant_res: 0.054
# adaptive_constant_bcs: 0.086
# It: 12400, Loss: 7.255e-02, Loss_u: 6.046e-02, Loss_r: 1.209e-02, Time: 0.22
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.046
# It: 12500, Loss: 4.726e-02, Loss_u: 4.295e-02, Loss_r: 4.309e-03, Time: 0.20
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.065
# It: 12600, Loss: 3.198e-02, Loss_u: 2.842e-02, Loss_r: 3.562e-03, Time: 0.20
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.034
# It: 12700, Loss: 4.346e-02, Loss_u: 3.971e-02, Loss_r: 3.751e-03, Time: 0.22
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.073
# It: 12800, Loss: 3.184e-02, Loss_u: 2.880e-02, Loss_r: 3.038e-03, Time: 0.20
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.041
# It: 12900, Loss: 5.136e-02, Loss_u: 4.558e-02, Loss_r: 5.779e-03, Time: 0.21
# adaptive_constant_res: 0.024
# adaptive_constant_bcs: 0.044
# It: 13000, Loss: 5.293e-02, Loss_u: 4.494e-02, Loss_r: 7.984e-03, Time: 0.22
# constant_bcs_val: 0.549
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.057
# It: 13100, Loss: 6.865e-02, Loss_u: 6.006e-02, Loss_r: 8.594e-03, Time: 0.21
# adaptive_constant_res: 0.024
# adaptive_constant_bcs: 0.107
# It: 13200, Loss: 4.737e-02, Loss_u: 4.008e-02, Loss_r: 7.291e-03, Time: 0.19
# adaptive_constant_res: 0.029
# adaptive_constant_bcs: 0.071
# It: 13300, Loss: 6.365e-02, Loss_u: 5.001e-02, Loss_r: 1.364e-02, Time: 0.24
# adaptive_constant_res: 0.036
# adaptive_constant_bcs: 0.075
# It: 13400, Loss: 5.806e-02, Loss_u: 4.601e-02, Loss_r: 1.204e-02, Time: 0.21
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.056
# It: 13500, Loss: 5.903e-02, Loss_u: 5.373e-02, Loss_r: 5.297e-03, Time: 0.20
# adaptive_constant_res: 0.033
# adaptive_constant_bcs: 0.087
# It: 13600, Loss: 4.965e-02, Loss_u: 3.580e-02, Loss_r: 1.386e-02, Time: 0.20
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.050
# It: 13700, Loss: 7.101e-02, Loss_u: 6.591e-02, Loss_r: 5.104e-03, Time: 0.21
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.032
# It: 13800, Loss: 5.170e-02, Loss_u: 4.801e-02, Loss_r: 3.691e-03, Time: 0.22
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.027
# It: 13900, Loss: 3.424e-02, Loss_u: 2.968e-02, Loss_r: 4.560e-03, Time: 0.23
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.084
# It: 14000, Loss: 4.163e-02, Loss_u: 3.681e-02, Loss_r: 4.823e-03, Time: 0.20
# constant_bcs_val: 0.155
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.076
# It: 14100, Loss: 6.950e-02, Loss_u: 6.542e-02, Loss_r: 4.083e-03, Time: 0.21
# adaptive_constant_res: 0.037
# adaptive_constant_bcs: 0.048
# It: 14200, Loss: 6.521e-02, Loss_u: 5.369e-02, Loss_r: 1.152e-02, Time: 0.20
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.059
# It: 14300, Loss: 3.621e-02, Loss_u: 3.212e-02, Loss_r: 4.086e-03, Time: 0.20
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.074
# It: 14400, Loss: 5.696e-02, Loss_u: 4.935e-02, Loss_r: 7.615e-03, Time: 0.22
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.028
# It: 14500, Loss: 5.551e-02, Loss_u: 4.846e-02, Loss_r: 7.045e-03, Time: 0.20
# adaptive_constant_res: 0.027
# adaptive_constant_bcs: 0.082
# It: 14600, Loss: 6.313e-02, Loss_u: 5.692e-02, Loss_r: 6.219e-03, Time: 0.33
# adaptive_constant_res: 0.030
# adaptive_constant_bcs: 0.109
# It: 14700, Loss: 6.334e-02, Loss_u: 5.685e-02, Loss_r: 6.489e-03, Time: 0.24
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.041
# It: 14800, Loss: 4.999e-02, Loss_u: 4.530e-02, Loss_r: 4.695e-03, Time: 0.19
# adaptive_constant_res: 0.025
# adaptive_constant_bcs: 0.027
# It: 14900, Loss: 2.967e-02, Loss_u: 2.498e-02, Loss_r: 4.691e-03, Time: 0.31
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.033
# It: 15000, Loss: 4.094e-02, Loss_u: 3.496e-02, Loss_r: 5.979e-03, Time: 0.22
# constant_bcs_val: 0.586
# adaptive_constant_res: 0.032
# adaptive_constant_bcs: 0.069
# It: 15100, Loss: 4.307e-02, Loss_u: 3.707e-02, Loss_r: 5.995e-03, Time: 0.20
# adaptive_constant_res: 0.040
# adaptive_constant_bcs: 0.025
# It: 15200, Loss: 4.898e-02, Loss_u: 4.022e-02, Loss_r: 8.760e-03, Time: 0.20
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.062
# It: 15300, Loss: 4.928e-02, Loss_u: 4.358e-02, Loss_r: 5.691e-03, Time: 0.20
# adaptive_constant_res: 0.004
# adaptive_constant_bcs: 0.038
# It: 15400, Loss: 6.145e-02, Loss_u: 5.968e-02, Loss_r: 1.770e-03, Time: 0.24
# adaptive_constant_res: 0.004
# adaptive_constant_bcs: 0.039
# It: 15500, Loss: 7.680e-02, Loss_u: 7.470e-02, Loss_r: 2.092e-03, Time: 0.20
# adaptive_constant_res: 0.051
# adaptive_constant_bcs: 0.074
# It: 15600, Loss: 3.869e-02, Loss_u: 3.062e-02, Loss_r: 8.065e-03, Time: 0.20
# adaptive_constant_res: 0.032
# adaptive_constant_bcs: 0.062
# It: 15700, Loss: 5.276e-02, Loss_u: 4.672e-02, Loss_r: 6.043e-03, Time: 0.23
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.030
# It: 15800, Loss: 5.675e-02, Loss_u: 5.163e-02, Loss_r: 5.113e-03, Time: 0.22
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.079
# It: 15900, Loss: 7.106e-02, Loss_u: 6.532e-02, Loss_r: 5.741e-03, Time: 0.30
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.024
# It: 16000, Loss: 3.328e-02, Loss_u: 2.981e-02, Loss_r: 3.474e-03, Time: 0.24
# constant_bcs_val: 0.742
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.067
# It: 16100, Loss: 5.654e-02, Loss_u: 5.285e-02, Loss_r: 3.696e-03, Time: 0.21
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.032
# It: 16200, Loss: 5.327e-02, Loss_u: 4.920e-02, Loss_r: 4.074e-03, Time: 0.22
# adaptive_constant_res: 0.057
# adaptive_constant_bcs: 0.034
# It: 16300, Loss: 5.292e-02, Loss_u: 4.451e-02, Loss_r: 8.408e-03, Time: 0.21
# adaptive_constant_res: 0.040
# adaptive_constant_bcs: 0.031
# It: 16400, Loss: 4.105e-02, Loss_u: 3.301e-02, Loss_r: 8.034e-03, Time: 0.21
# adaptive_constant_res: 0.017
# adaptive_constant_bcs: 0.043
# It: 16500, Loss: 5.831e-02, Loss_u: 5.223e-02, Loss_r: 6.084e-03, Time: 0.21
# adaptive_constant_res: 0.056
# adaptive_constant_bcs: 0.049
# It: 16600, Loss: 5.390e-02, Loss_u: 3.845e-02, Loss_r: 1.544e-02, Time: 0.22
# adaptive_constant_res: 0.017
# adaptive_constant_bcs: 0.027
# It: 16700, Loss: 4.929e-02, Loss_u: 4.524e-02, Loss_r: 4.048e-03, Time: 0.22
# adaptive_constant_res: 0.003
# adaptive_constant_bcs: 0.036
# It: 16800, Loss: 3.161e-02, Loss_u: 2.942e-02, Loss_r: 2.184e-03, Time: 0.21
# adaptive_constant_res: 0.009
# adaptive_constant_bcs: 0.030
# It: 16900, Loss: 4.606e-02, Loss_u: 4.231e-02, Loss_r: 3.754e-03, Time: 0.24
# adaptive_constant_res: 0.064
# adaptive_constant_bcs: 0.029
# It: 17000, Loss: 4.340e-02, Loss_u: 3.234e-02, Loss_r: 1.106e-02, Time: 0.20
# constant_bcs_val: 2.186
# adaptive_constant_res: 0.039
# adaptive_constant_bcs: 0.104
# It: 17100, Loss: 4.688e-02, Loss_u: 3.868e-02, Loss_r: 8.205e-03, Time: 0.21
# adaptive_constant_res: 0.053
# adaptive_constant_bcs: 0.060
# It: 17200, Loss: 4.118e-02, Loss_u: 3.046e-02, Loss_r: 1.073e-02, Time: 0.21
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.044
# It: 17300, Loss: 3.297e-02, Loss_u: 2.918e-02, Loss_r: 3.784e-03, Time: 0.22
# adaptive_constant_res: 0.059
# adaptive_constant_bcs: 0.047
# It: 17400, Loss: 4.778e-02, Loss_u: 3.408e-02, Loss_r: 1.370e-02, Time: 0.24
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.025
# It: 17500, Loss: 3.676e-02, Loss_u: 3.283e-02, Loss_r: 3.931e-03, Time: 0.21
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.054
# It: 17600, Loss: 7.238e-02, Loss_u: 6.986e-02, Loss_r: 2.522e-03, Time: 0.21
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.050
# It: 17700, Loss: 4.357e-02, Loss_u: 3.983e-02, Loss_r: 3.739e-03, Time: 0.20
# adaptive_constant_res: 0.055
# adaptive_constant_bcs: 0.052
# It: 17800, Loss: 3.979e-02, Loss_u: 3.059e-02, Loss_r: 9.195e-03, Time: 0.22
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.019
# It: 17900, Loss: 2.898e-02, Loss_u: 2.587e-02, Loss_r: 3.116e-03, Time: 0.28
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.069
# It: 18000, Loss: 4.683e-02, Loss_u: 4.339e-02, Loss_r: 3.437e-03, Time: 0.24
# constant_bcs_val: 0.145
# adaptive_constant_res: 0.030
# adaptive_constant_bcs: 0.054
# It: 18100, Loss: 4.395e-02, Loss_u: 3.540e-02, Loss_r: 8.553e-03, Time: 0.22
# adaptive_constant_res: 0.011
# adaptive_constant_bcs: 0.033
# It: 18200, Loss: 3.417e-02, Loss_u: 2.983e-02, Loss_r: 4.336e-03, Time: 0.25
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.017
# It: 18300, Loss: 3.244e-02, Loss_u: 2.711e-02, Loss_r: 5.324e-03, Time: 0.23
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.078
# It: 18400, Loss: 5.843e-02, Loss_u: 5.397e-02, Loss_r: 4.463e-03, Time: 0.29
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.039
# It: 18500, Loss: 3.688e-02, Loss_u: 3.417e-02, Loss_r: 2.710e-03, Time: 0.25
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.098
# It: 18600, Loss: 5.035e-02, Loss_u: 4.713e-02, Loss_r: 3.226e-03, Time: 0.24
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.132
# It: 18700, Loss: 5.624e-02, Loss_u: 5.296e-02, Loss_r: 3.282e-03, Time: 0.24
# adaptive_constant_res: 0.011
# adaptive_constant_bcs: 0.032
# It: 18800, Loss: 3.884e-02, Loss_u: 3.475e-02, Loss_r: 4.095e-03, Time: 0.25
# adaptive_constant_res: 0.029
# adaptive_constant_bcs: 0.030
# It: 18900, Loss: 5.537e-02, Loss_u: 5.113e-02, Loss_r: 4.242e-03, Time: 0.24
# adaptive_constant_res: 0.066
# adaptive_constant_bcs: 0.028
# It: 19000, Loss: 6.957e-02, Loss_u: 5.346e-02, Loss_r: 1.612e-02, Time: 0.23
# constant_bcs_val: 2.355
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.047
# It: 19100, Loss: 5.357e-02, Loss_u: 4.779e-02, Loss_r: 5.781e-03, Time: 0.22
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.126
# It: 19200, Loss: 4.692e-02, Loss_u: 4.251e-02, Loss_r: 4.406e-03, Time: 0.27
# adaptive_constant_res: 0.016
# adaptive_constant_bcs: 0.061
# It: 19300, Loss: 5.062e-02, Loss_u: 4.713e-02, Loss_r: 3.491e-03, Time: 0.29
# adaptive_constant_res: 0.031
# adaptive_constant_bcs: 0.057
# It: 19400, Loss: 4.154e-02, Loss_u: 3.437e-02, Loss_r: 7.173e-03, Time: 0.33
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.067
# It: 19500, Loss: 5.049e-02, Loss_u: 4.674e-02, Loss_r: 3.753e-03, Time: 0.28
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.037
# It: 19600, Loss: 2.791e-02, Loss_u: 2.390e-02, Loss_r: 4.012e-03, Time: 0.24
# adaptive_constant_res: 0.053
# adaptive_constant_bcs: 0.033
# It: 19700, Loss: 5.771e-02, Loss_u: 4.705e-02, Loss_r: 1.066e-02, Time: 0.30
# adaptive_constant_res: 0.029
# adaptive_constant_bcs: 0.037
# It: 19800, Loss: 3.817e-02, Loss_u: 3.194e-02, Loss_r: 6.224e-03, Time: 0.23
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.035
# It: 19900, Loss: 4.397e-02, Loss_u: 4.058e-02, Loss_r: 3.388e-03, Time: 0.24
# adaptive_constant_res: 0.083
# adaptive_constant_bcs: 0.047
# It: 20000, Loss: 4.937e-02, Loss_u: 3.974e-02, Loss_r: 9.629e-03, Time: 0.23
# constant_bcs_val: 1.759
# adaptive_constant_res: 0.053
# adaptive_constant_bcs: 0.055
# It: 20100, Loss: 5.931e-02, Loss_u: 4.779e-02, Loss_r: 1.152e-02, Time: 0.24
# adaptive_constant_res: 0.046
# adaptive_constant_bcs: 0.060
# It: 20200, Loss: 4.480e-02, Loss_u: 3.741e-02, Loss_r: 7.388e-03, Time: 0.23
# adaptive_constant_res: 0.028
# adaptive_constant_bcs: 0.028
# It: 20300, Loss: 5.659e-02, Loss_u: 5.098e-02, Loss_r: 5.617e-03, Time: 0.24
# adaptive_constant_res: 0.031
# adaptive_constant_bcs: 0.032
# It: 20400, Loss: 3.170e-02, Loss_u: 2.543e-02, Loss_r: 6.274e-03, Time: 0.26
# adaptive_constant_res: 0.068
# adaptive_constant_bcs: 0.034
# It: 20500, Loss: 3.585e-02, Loss_u: 2.752e-02, Loss_r: 8.324e-03, Time: 0.25
# adaptive_constant_res: 0.017
# adaptive_constant_bcs: 0.044
# It: 20600, Loss: 3.232e-02, Loss_u: 2.895e-02, Loss_r: 3.371e-03, Time: 0.25
# adaptive_constant_res: 0.017
# adaptive_constant_bcs: 0.037
# It: 20700, Loss: 5.479e-02, Loss_u: 5.161e-02, Loss_r: 3.172e-03, Time: 0.24
# adaptive_constant_res: 0.006
# adaptive_constant_bcs: 0.029
# It: 20800, Loss: 3.466e-02, Loss_u: 3.199e-02, Loss_r: 2.674e-03, Time: 0.34
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.043
# It: 20900, Loss: 4.139e-02, Loss_u: 3.775e-02, Loss_r: 3.639e-03, Time: 0.26
# adaptive_constant_res: 0.033
# adaptive_constant_bcs: 0.047
# It: 21000, Loss: 4.538e-02, Loss_u: 4.054e-02, Loss_r: 4.833e-03, Time: 0.26
# constant_bcs_val: 0.711
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.039
# It: 21100, Loss: 6.237e-02, Loss_u: 5.968e-02, Loss_r: 2.691e-03, Time: 0.27
# adaptive_constant_res: 0.034
# adaptive_constant_bcs: 0.032
# It: 21200, Loss: 3.627e-02, Loss_u: 3.134e-02, Loss_r: 4.928e-03, Time: 0.28
# adaptive_constant_res: 0.009
# adaptive_constant_bcs: 0.040
# It: 21300, Loss: 3.637e-02, Loss_u: 3.267e-02, Loss_r: 3.697e-03, Time: 0.24
# adaptive_constant_res: 0.036
# adaptive_constant_bcs: 0.063
# It: 21400, Loss: 8.604e-02, Loss_u: 7.751e-02, Loss_r: 8.532e-03, Time: 0.48
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.042
# It: 21500, Loss: 3.673e-02, Loss_u: 3.398e-02, Loss_r: 2.751e-03, Time: 0.29
# adaptive_constant_res: 0.018
# adaptive_constant_bcs: 0.046
# It: 21600, Loss: 4.839e-02, Loss_u: 4.402e-02, Loss_r: 4.363e-03, Time: 0.21
# adaptive_constant_res: 0.027
# adaptive_constant_bcs: 0.027
# It: 21700, Loss: 4.411e-02, Loss_u: 3.514e-02, Loss_r: 8.970e-03, Time: 0.23
# adaptive_constant_res: 0.034
# adaptive_constant_bcs: 0.051
# It: 21800, Loss: 5.251e-02, Loss_u: 4.540e-02, Loss_r: 7.110e-03, Time: 0.23
# adaptive_constant_res: 0.033
# adaptive_constant_bcs: 0.077
# It: 21900, Loss: 5.694e-02, Loss_u: 5.254e-02, Loss_r: 4.403e-03, Time: 0.23
# adaptive_constant_res: 0.023
# adaptive_constant_bcs: 0.065
# It: 22000, Loss: 2.688e-02, Loss_u: 2.044e-02, Loss_r: 6.440e-03, Time: 0.21
# constant_bcs_val: 0.350
# adaptive_constant_res: 0.115
# adaptive_constant_bcs: 0.019
# It: 22100, Loss: 4.260e-02, Loss_u: 3.266e-02, Loss_r: 9.938e-03, Time: 0.21
# adaptive_constant_res: 0.053
# adaptive_constant_bcs: 0.053
# It: 22200, Loss: 4.414e-02, Loss_u: 3.639e-02, Loss_r: 7.751e-03, Time: 0.23
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.048
# It: 22300, Loss: 2.529e-02, Loss_u: 2.123e-02, Loss_r: 4.055e-03, Time: 0.18
# adaptive_constant_res: 0.055
# adaptive_constant_bcs: 0.046
# It: 22400, Loss: 3.079e-02, Loss_u: 2.119e-02, Loss_r: 9.598e-03, Time: 0.23
# adaptive_constant_res: 0.031
# adaptive_constant_bcs: 0.066
# It: 22500, Loss: 3.440e-02, Loss_u: 2.677e-02, Loss_r: 7.625e-03, Time: 0.26
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.035
# It: 22600, Loss: 4.106e-02, Loss_u: 3.705e-02, Loss_r: 4.009e-03, Time: 0.20
# adaptive_constant_res: 0.073
# adaptive_constant_bcs: 0.046
# It: 22700, Loss: 3.303e-02, Loss_u: 2.576e-02, Loss_r: 7.264e-03, Time: 0.23
# adaptive_constant_res: 0.105
# adaptive_constant_bcs: 0.037
# It: 22800, Loss: 5.641e-02, Loss_u: 3.926e-02, Loss_r: 1.715e-02, Time: 0.20
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.027
# It: 22900, Loss: 3.301e-02, Loss_u: 3.032e-02, Loss_r: 2.684e-03, Time: 0.22
# adaptive_constant_res: 0.044
# adaptive_constant_bcs: 0.064
# ...
# adaptive_constant_res: 0.025
# adaptive_constant_bcs: 0.051
# It: 32300, Loss: 5.003e-02, Loss_u: 4.703e-02, Loss_r: 3.000e-03, Time: 0.56
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.021
# It: 32400, Loss: 2.617e-02, Loss_u: 2.364e-02, Loss_r: 2.524e-03, Time: 0.56
# adaptive_constant_res: 0.034
# adaptive_constant_bcs: 0.046
# It: 32500, Loss: 4.243e-02, Loss_u: 3.821e-02, Loss_r: 4.216e-03, Time: 0.54
# adaptive_constant_res: 0.040
# adaptive_constant_bcs: 0.024
# It: 32600, Loss: 2.353e-02, Loss_u: 1.906e-02, Loss_r: 4.467e-03, Time: 0.48
# adaptive_constant_res: 0.025
# adaptive_constant_bcs: 0.032
# It: 32700, Loss: 2.758e-02, Loss_u: 2.398e-02, Loss_r: 3.597e-03, Time: 0.48
# adaptive_constant_res: 0.045
# adaptive_constant_bcs: 0.023
# It: 32800, Loss: 4.152e-02, Loss_u: 3.636e-02, Loss_r: 5.164e-03, Time: 0.43
# adaptive_constant_res: 0.079
# adaptive_constant_bcs: 0.038
# It: 32900, Loss: 4.966e-02, Loss_u: 3.980e-02, Loss_r: 9.860e-03, Time: 0.46
# adaptive_constant_res: 0.006
# adaptive_constant_bcs: 0.035
# It: 33000, Loss: 4.245e-02, Loss_u: 4.022e-02, Loss_r: 2.230e-03, Time: 0.46
# constant_bcs_val: 0.161
# adaptive_constant_res: 0.032
# adaptive_constant_bcs: 0.015
# It: 33100, Loss: 4.144e-02, Loss_u: 3.772e-02, Loss_r: 3.725e-03, Time: 0.46
# adaptive_constant_res: 0.037
# adaptive_constant_bcs: 0.036
# It: 33200, Loss: 2.367e-02, Loss_u: 1.690e-02, Loss_r: 6.772e-03, Time: 0.46
# adaptive_constant_res: 0.002
# adaptive_constant_bcs: 0.049
# It: 33300, Loss: 2.510e-02, Loss_u: 2.330e-02, Loss_r: 1.800e-03, Time: 0.48
# adaptive_constant_res: 0.015
# adaptive_constant_bcs: 0.044
# It: 33400, Loss: 3.474e-02, Loss_u: 3.231e-02, Loss_r: 2.430e-03, Time: 0.44
# adaptive_constant_res: 0.033
# adaptive_constant_bcs: 0.051
# It: 33500, Loss: 2.633e-02, Loss_u: 1.994e-02, Loss_r: 6.389e-03, Time: 0.46
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.032
# It: 33600, Loss: 3.005e-02, Loss_u: 2.831e-02, Loss_r: 1.742e-03, Time: 0.47
# adaptive_constant_res: 0.061
# adaptive_constant_bcs: 0.023
# It: 33700, Loss: 5.647e-02, Loss_u: 4.774e-02, Loss_r: 8.733e-03, Time: 0.47
# adaptive_constant_res: 0.030
# adaptive_constant_bcs: 0.022
# It: 33800, Loss: 4.385e-02, Loss_u: 3.923e-02, Loss_r: 4.623e-03, Time: 0.47
# adaptive_constant_res: 0.005
# adaptive_constant_bcs: 0.071
# It: 33900, Loss: 5.015e-02, Loss_u: 4.874e-02, Loss_r: 1.410e-03, Time: 0.46
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.037
# It: 34000, Loss: 4.407e-02, Loss_u: 4.193e-02, Loss_r: 2.138e-03, Time: 0.48
# constant_bcs_val: 0.217
# adaptive_constant_res: 0.030
# adaptive_constant_bcs: 0.032
# It: 34100, Loss: 3.362e-02, Loss_u: 2.996e-02, Loss_r: 3.664e-03, Time: 0.47
# adaptive_constant_res: 0.066
# adaptive_constant_bcs: 0.020
# It: 34200, Loss: 3.659e-02, Loss_u: 3.230e-02, Loss_r: 4.294e-03, Time: 0.52
# adaptive_constant_res: 0.024
# adaptive_constant_bcs: 0.053
# It: 34300, Loss: 3.276e-02, Loss_u: 2.943e-02, Loss_r: 3.333e-03, Time: 0.46
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.051
# It: 34400, Loss: 3.161e-02, Loss_u: 2.756e-02, Loss_r: 4.056e-03, Time: 0.52
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.043
# It: 34500, Loss: 3.891e-02, Loss_u: 3.529e-02, Loss_r: 3.618e-03, Time: 0.48
# adaptive_constant_res: 0.005
# adaptive_constant_bcs: 0.061
# It: 34600, Loss: 3.672e-02, Loss_u: 3.494e-02, Loss_r: 1.776e-03, Time: 0.51
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.070
# It: 34700, Loss: 4.027e-02, Loss_u: 3.725e-02, Loss_r: 3.015e-03, Time: 0.48
# adaptive_constant_res: 0.053
# adaptive_constant_bcs: 0.026
# It: 34800, Loss: 4.196e-02, Loss_u: 3.724e-02, Loss_r: 4.718e-03, Time: 0.54
# adaptive_constant_res: 0.040
# adaptive_constant_bcs: 0.047
# It: 34900, Loss: 2.335e-02, Loss_u: 2.103e-02, Loss_r: 2.314e-03, Time: 0.52
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.033
# It: 35000, Loss: 2.386e-02, Loss_u: 2.127e-02, Loss_r: 2.594e-03, Time: 0.50
# constant_bcs_val: 0.417
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.022
# It: 35100, Loss: 2.927e-02, Loss_u: 2.730e-02, Loss_r: 1.964e-03, Time: 0.49
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.053
# It: 35200, Loss: 4.388e-02, Loss_u: 4.144e-02, Loss_r: 2.444e-03, Time: 0.46
# adaptive_constant_res: 0.021
# adaptive_constant_bcs: 0.040
# It: 35300, Loss: 4.019e-02, Loss_u: 3.696e-02, Loss_r: 3.230e-03, Time: 0.52
# adaptive_constant_res: 0.074
# adaptive_constant_bcs: 0.016
# It: 35400, Loss: 5.416e-02, Loss_u: 4.216e-02, Loss_r: 1.199e-02, Time: 0.50
# adaptive_constant_res: 0.045
# adaptive_constant_bcs: 0.043
# It: 35500, Loss: 4.450e-02, Loss_u: 3.621e-02, Loss_r: 8.288e-03, Time: 0.54
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.022
# It: 35600, Loss: 2.012e-02, Loss_u: 1.722e-02, Loss_r: 2.898e-03, Time: 0.50
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.046
# It: 35700, Loss: 3.123e-02, Loss_u: 2.830e-02, Loss_r: 2.927e-03, Time: 0.46
# adaptive_constant_res: 0.004
# adaptive_constant_bcs: 0.018
# It: 35800, Loss: 4.037e-02, Loss_u: 3.822e-02, Loss_r: 2.147e-03, Time: 0.46
# adaptive_constant_res: 0.031
# adaptive_constant_bcs: 0.038
# It: 35900, Loss: 5.155e-02, Loss_u: 4.765e-02, Loss_r: 3.899e-03, Time: 0.50
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.021
# It: 36000, Loss: 5.206e-02, Loss_u: 5.019e-02, Loss_r: 1.871e-03, Time: 0.49
# constant_bcs_val: 0.638
# adaptive_constant_res: 0.019
# adaptive_constant_bcs: 0.032
# It: 36100, Loss: 2.639e-02, Loss_u: 2.360e-02, Loss_r: 2.794e-03, Time: 0.55
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.063
# It: 36200, Loss: 4.655e-02, Loss_u: 4.431e-02, Loss_r: 2.241e-03, Time: 0.50
# adaptive_constant_res: 0.035
# adaptive_constant_bcs: 0.019
# It: 36300, Loss: 4.716e-02, Loss_u: 4.099e-02, Loss_r: 6.163e-03, Time: 0.47
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.014
# It: 36400, Loss: 3.467e-02, Loss_u: 3.065e-02, Loss_r: 4.018e-03, Time: 0.49
# adaptive_constant_res: 0.122
# adaptive_constant_bcs: 0.019
# It: 36500, Loss: 3.580e-02, Loss_u: 2.719e-02, Loss_r: 8.606e-03, Time: 0.46
# adaptive_constant_res: 0.034
# adaptive_constant_bcs: 0.025
# It: 36600, Loss: 6.101e-02, Loss_u: 5.201e-02, Loss_r: 8.998e-03, Time: 0.45
# adaptive_constant_res: 0.065
# adaptive_constant_bcs: 0.028
# It: 36700, Loss: 3.355e-02, Loss_u: 2.805e-02, Loss_r: 5.504e-03, Time: 0.48
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.035
# It: 36800, Loss: 2.250e-02, Loss_u: 1.943e-02, Loss_r: 3.063e-03, Time: 0.46
# adaptive_constant_res: 0.005
# adaptive_constant_bcs: 0.037
# It: 36900, Loss: 2.669e-02, Loss_u: 2.480e-02, Loss_r: 1.884e-03, Time: 0.46
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.018
# It: 37000, Loss: 3.919e-02, Loss_u: 3.643e-02, Loss_r: 2.756e-03, Time: 0.47
# constant_bcs_val: 0.456
# adaptive_constant_res: 0.031
# adaptive_constant_bcs: 0.093
# It: 37100, Loss: 3.990e-02, Loss_u: 3.302e-02, Loss_r: 6.874e-03, Time: 0.46
# adaptive_constant_res: 0.005
# adaptive_constant_bcs: 0.040
# It: 37200, Loss: 5.161e-02, Loss_u: 4.974e-02, Loss_r: 1.866e-03, Time: 0.54
# adaptive_constant_res: 0.022
# adaptive_constant_bcs: 0.033
# It: 37300, Loss: 4.883e-02, Loss_u: 4.453e-02, Loss_r: 4.302e-03, Time: 0.58
# adaptive_constant_res: 0.035
# adaptive_constant_bcs: 0.059
# It: 37400, Loss: 2.709e-02, Loss_u: 2.132e-02, Loss_r: 5.764e-03, Time: 0.51
# adaptive_constant_res: 0.006
# adaptive_constant_bcs: 0.050
# It: 37500, Loss: 1.758e-02, Loss_u: 1.547e-02, Loss_r: 2.107e-03, Time: 0.51
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.054
# It: 37600, Loss: 3.175e-02, Loss_u: 2.955e-02, Loss_r: 2.209e-03, Time: 0.47
# adaptive_constant_res: 0.012
# adaptive_constant_bcs: 0.035
# It: 37700, Loss: 3.289e-02, Loss_u: 3.026e-02, Loss_r: 2.638e-03, Time: 0.47
# adaptive_constant_res: 0.106
# adaptive_constant_bcs: 0.072
# It: 37800, Loss: 5.982e-02, Loss_u: 4.706e-02, Loss_r: 1.275e-02, Time: 0.49
# adaptive_constant_res: 0.026
# adaptive_constant_bcs: 0.088
# It: 37900, Loss: 6.309e-02, Loss_u: 5.971e-02, Loss_r: 3.375e-03, Time: 0.53
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.044
# It: 38000, Loss: 3.171e-02, Loss_u: 2.955e-02, Loss_r: 2.154e-03, Time: 0.44
# constant_bcs_val: 0.320
# adaptive_constant_res: 0.010
# adaptive_constant_bcs: 0.021
# It: 38100, Loss: 5.001e-02, Loss_u: 4.748e-02, Loss_r: 2.525e-03, Time: 0.47
# adaptive_constant_res: 0.042
# adaptive_constant_bcs: 0.041
# It: 38200, Loss: 4.881e-02, Loss_u: 4.106e-02, Loss_r: 7.752e-03, Time: 0.51
# adaptive_constant_res: 0.040
# adaptive_constant_bcs: 0.024
# It: 38300, Loss: 5.000e-02, Loss_u: 3.889e-02, Loss_r: 1.111e-02, Time: 0.46
# adaptive_constant_res: 0.005
# adaptive_constant_bcs: 0.023
# It: 38400, Loss: 3.990e-02, Loss_u: 3.774e-02, Loss_r: 2.160e-03, Time: 0.50
# adaptive_constant_res: 0.050
# adaptive_constant_bcs: 0.040
# It: 38500, Loss: 3.393e-02, Loss_u: 2.842e-02, Loss_r: 5.509e-03, Time: 0.53
# adaptive_constant_res: 0.043
# adaptive_constant_bcs: 0.021
# It: 38600, Loss: 2.654e-02, Loss_u: 2.192e-02, Loss_r: 4.621e-03, Time: 0.53
# adaptive_constant_res: 0.034
# adaptive_constant_bcs: 0.045
# It: 38700, Loss: 4.707e-02, Loss_u: 4.200e-02, Loss_r: 5.070e-03, Time: 0.58
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.027
# It: 38800, Loss: 4.651e-02, Loss_u: 4.462e-02, Loss_r: 1.896e-03, Time: 0.63
# adaptive_constant_res: 0.005
# adaptive_constant_bcs: 0.055
# It: 38900, Loss: 1.783e-02, Loss_u: 1.616e-02, Loss_r: 1.672e-03, Time: 0.55
# adaptive_constant_res: 0.107
# adaptive_constant_bcs: 0.040
# It: 39000, Loss: 6.663e-02, Loss_u: 5.783e-02, Loss_r: 8.804e-03, Time: 0.57
# constant_bcs_val: 2.705
# adaptive_constant_res: 0.005
# adaptive_constant_bcs: 0.014
# It: 39100, Loss: 4.429e-02, Loss_u: 4.248e-02, Loss_r: 1.814e-03, Time: 0.54
# adaptive_constant_res: 0.055
# adaptive_constant_bcs: 0.019
# It: 39200, Loss: 2.978e-02, Loss_u: 2.226e-02, Loss_r: 7.516e-03, Time: 0.65
# adaptive_constant_res: 0.008
# adaptive_constant_bcs: 0.047
# It: 39300, Loss: 2.637e-02, Loss_u: 2.417e-02, Loss_r: 2.192e-03, Time: 0.52
# adaptive_constant_res: 0.013
# adaptive_constant_bcs: 0.043
# It: 39400, Loss: 2.014e-02, Loss_u: 1.838e-02, Loss_r: 1.757e-03, Time: 0.59
# adaptive_constant_res: 0.004
# adaptive_constant_bcs: 0.055
# It: 39500, Loss: 1.737e-02, Loss_u: 1.585e-02, Loss_r: 1.524e-03, Time: 0.74
# adaptive_constant_res: 0.014
# adaptive_constant_bcs: 0.018
# It: 39600, Loss: 2.651e-02, Loss_u: 2.432e-02, Loss_r: 2.196e-03, Time: 0.52
# adaptive_constant_res: 0.020
# adaptive_constant_bcs: 0.026
# It: 39700, Loss: 2.772e-02, Loss_u: 2.245e-02, Loss_r: 5.274e-03, Time: 0.56
# adaptive_constant_res: 0.007
# adaptive_constant_bcs: 0.057
# It: 39800, Loss: 4.058e-02, Loss_u: 3.879e-02, Loss_r: 1.792e-03, Time: 0.55
# adaptive_constant_res: 0.026
# adaptive_constant_bcs: 0.043
# It: 39900, Loss: 3.985e-02, Loss_u: 3.488e-02, Loss_r: 4.971e-03, Time: 0.53
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# adaptive_constant_res: 0.027
# adaptive_constant_bcs: 0.022
# It: 40000, Loss: 4.104e-02, Loss_u: 3.710e-02, Loss_r: 3.935e-03, Time: 4.93
# constant_bcs_val: 1.260
# l2 error: 1.30e-01
# l2 error: 2.45e-01
# average lambda_bc7.4653e-01
# average lambda_res1.0
# Save uv NN parameters successfully in %s ...checkpoints/Dec-23-2023_22-33-49-279150_M2
# Final loss total loss: 4.118663e-02
# Final loss loss_res: 4.030874e-03
# Final loss loss_bcs1: 2.280272e-03
# Final loss loss_bcs2: 2.034847e-03
# Final loss loss_bcs3: 3.106695e-03
# Final loss loss_bcs4: 9.337141e-06
# elapsed: 4.25e+03
# Relative L2 error_u: 1.30e-01
# Relative L2 error_v: 2.45e-01
#
#
# Method: mini_batch
#
# average of time_list:4.2462e+03
# average of error_u_list:1.2997e-01
# average of error_v_list:2.4511e-01

# %%
            mode.plot_lambda()

# %%
def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
    from mpl_toolkits.axes_grid1 import ImageGrid

    ### Plot ###

    # Exact solution & Predicted solution
    # Exact soluton
    U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

    # Predicted solution
    U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
    F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

    titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $v(x)$' , 'Predicted $v(x)$' , 'Absolute error']
    data = [U_star.T , U_pred ,  np.abs(U_star.T - U_pred) , F_star.T , F_pred ,  np.abs(F_star.T - F_pred) ]

    fig_1 = plt.figure(1, figsize=(13, 5))
    grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                    label_mode="1", axes_pad=1.7, share_all=False, 
                    cbar_mode="each", cbar_location="right", 
                    cbar_size="5%", cbar_pad=0.0)
# CREATE ARGUMENTS DICT FOR CONTOURPLOTS
    minmax_list = []
    for d in data:
        # if(local):
        #     minmax_list.append([np.min(d), np.max(d)])
        # else:
        minmax_list.append([np.min(d), np.max(d)])

        # kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60), cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

    for ax, z, minmax, title in zip(grid, data, minmax_list, titles):
    #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
        #pcfsets.append(pcf)
        # if (timeStp == 0):
        pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
        cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
        ax.cax.tick_params(labelsize=14.5)
        ax.set_title(title, fontsize=14.5, pad=7)
        ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
        ax.set_xlabel("x", fontsize=14.5)
        ax.tick_params(labelsize=14.5)
        ax.set_xlim(x1.min(), x1.max())
        ax.set_ylim(x2.min(), x2.max())
        ax.set_aspect("equal")

    fig_1.set_size_inches(15, 10, True)
    fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
    plt.tight_layout()
    plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
    plt.close("all" , )

# %%
u_ref.flatten()[:,None].shape
# Out:
# (10000, 1)

# %%
# Out:
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)

# %%
v_pred.shape
# Out:
# (100, 100)

# %%
import scipy.io

mode = 'M2'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = [1831.07 , ]
error_u_list = [0.2112 , 0.]
error_v_list = [0.3271 , 0.]
error_p_list = [0.094 , 0.]

for mtd in methods:
    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ,  error_p_list]


##Full Batch
time_list = [8048.86 , ]
error_u_list = [ 0.0367 ,0. ]
error_v_list = [0.0706 , 0.]
error_p_list = [0.465 , 0.]

for mtd in methods:
    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ,  error_p_list]


scipy.io.savemat("./dataset/NS_model_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
### Plot ###
###########

# %%
# Test Data
nx = 100
ny = 100  # change to 100
x = np.linspace(0.0, 1.0, nx)
y = np.linspace(0.0, 1.0, ny)
X, Y = np.meshgrid(x, y)

X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))

# Predictions
psi_pred, p_pred = mode.predict_psi_p(X_star)
u_pred, v_pred = mode.predict_uv(X_star)

psi_star = griddata(X_star, psi_pred.flatten(), (X, Y), method='cubic')
p_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
u_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
v_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')

velocity = np.sqrt(u_pred**2 + v_pred**2)
velocity_star = griddata(X_star, velocity.flatten(), (X, Y), method='cubic')

# Reference
u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

# Relative error
error = np.linalg.norm(u_star - u_pred.T, 2) / np.linalg.norm(u_star, 2)
print('l2 error: {:.2e}'.format(error))
error = np.linalg.norm(v_star - v_pred.T, 2) / np.linalg.norm(v_star, 2)
print('l2 error: {:.2e}'.format(error))
error = np.linalg.norm(p_pred - p_star.T, 2) / np.linalg.norm(p_star, 2)
print('l2 error: {:.2e}'.format(error))

### Plot ###
###########

# %%
# Reference solution & Prediceted solution
fig_1 = plt.figure(1, figsize=(18, 5))
fig_1.add_subplot(1, 3, 1)
plt.pcolor(X.T, Y.T, velocity_ref, cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Reference Velocity')

fig_1.add_subplot(1, 3, 2)
plt.pcolor(x, Y, velocity_star, cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Predicted Velocity')
plt.tight_layout()

fig_1.add_subplot(1, 3, 3)
plt.pcolor(X, Y, np.abs(velocity_star - velocity_ref.T), cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Absolute Error')
plt.show()

# %%
    ## Loss ##
loss_res = mode.loss_res_log
loss_bcs = mode.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
## Adaptive Constant
adaptive_constant = mode.adpative_constant_bcs_log
    
fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# %%
## Gradients #
data_gradients_res = mode.dict_gradients_res_layers
data_gradients_bcs = mode.dict_gradients_bcs_layers

num_hidden_layers = len(layers) -1
cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_{u_b}$')

    # ax.get_legend().remove()
    ax.set_xlim([-1.0, 1.0])
    ax.set_ylim([0, 100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()

fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()
