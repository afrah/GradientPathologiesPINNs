# %%
import tensorflow as tf
# from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 

import timeit

import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle

class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c , mode ,  sess):
        # Normalization 




        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        self.T = 1.0
        # weights
        self.adaptive_constant_bcs1_val = np.array(1.0)
        self.adaptive_constant_bcs2_val = np.array(1.0)
        self.adaptive_constant_ics_val = np.array(1.0)
        self.adaptive_constant_ics_t_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)
        self.rate = 0.9

        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        # self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.adaptive_constant_bcs1_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs1_val.shape)
        self.adaptive_constant_bcs2_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs2_val.shape)
        self.adaptive_constant_ics_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_ics_val.shape)
        self.adaptive_constant_ics_t_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_ics_t_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)
        

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        # self.loss_ics_us = self.loss_ics_u + self.loss_ics_u_t
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        # self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss =  self.adaptive_constant_res_tf * self.loss_res + self.adaptive_constant_bcs1_tf * self.loss_bc1 + self.adaptive_constant_bcs2_tf * self.loss_bc2 + self.adaptive_constant_ics_tf * ( self.loss_ics_u)+ self.adaptive_constant_ics_t_tf * ( self.loss_ics_u_t)

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step, 1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_tensor_list = [self.loss ,  self.loss_res, self.loss_bc1 , self.loss_bc2 , self.loss_ics_u, self.loss_ics_u_t] 
        self.loss_list = ["total loss" , "loss_res"  , "loss_bc1", "loss_bc2", "loss_ics_u", "loss_ics_u_t"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_u_log = []
        self.loss_r_log = []

        # self.saver = tf.train.Saver()

         # # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs1_layers = self.generate_grad_dict()
        self.dict_gradients_bcs2_layers = self.generate_grad_dict()
        self.dict_gradients_ics_layers = self.generate_grad_dict()
        
        # Gradients Storage
        self.grad_res = []
        self.grad_ics = []
        self.grad_ics_t = []
        self.grad_bcs1 = []
        self.grad_bcs2 = []

        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs1.append(tf.gradients(self.loss_bc1, self.weights[i])[0])
            self.grad_bcs2.append(tf.gradients(self.loss_bc2, self.weights[i])[0])
            self.grad_ics.append(tf.gradients(self.loss_ics_u, self.weights[i])[0])
            self.grad_ics_t.append(tf.gradients(self.loss_ics_u_t, self.weights[i])[0])
          
        self.max_grad_res_list = []
        self.mean_grad_bcs1_list = []
        self.mean_grad_bcs2_list = []
        self.mean_grad_ics_list = []
        self.mean_grad_ics_t_list = []

        self.adaptive_constant_bcs1_log = []
        self.adaptive_constant_bcs2_log = []
        self.adaptive_constant_ics_log = []
        self.adaptive_constant_ics_t_log = []
        self.adaptive_constant_res_log = []

        self.mean_adaptive_constant_res_log = []
        self.mean_adaptive_constant_bcs1_log = []
        self.mean_adaptive_constant_bcs2_log = []
        self.mean_adaptive_constant_ics_log = []
        self.mean_adaptive_constant_ics_t_log = []

        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.reduce_max(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs1_list.append(tf.reduce_max(tf.abs(self.grad_bcs1[i])))
            self.mean_grad_bcs2_list.append(tf.reduce_max(tf.abs(self.grad_bcs2[i])))
            self.mean_grad_ics_list.append(tf.reduce_max(tf.abs(self.grad_ics[i])))
            self.mean_grad_ics_t_list.append(tf.reduce_max(tf.abs(self.grad_ics_t[i])))
        
        self.max_grad_res = tf.reduce_max(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs1 = tf.reduce_max(tf.stack(self.mean_grad_bcs1_list))
        self.mean_grad_bcs2 = tf.reduce_max(tf.stack(self.mean_grad_bcs2_list))
        self.mean_grad_ics = tf.reduce_max(tf.stack(self.mean_grad_ics_list))
        self.mean_grad_ics_t = tf.reduce_max(tf.stack(self.mean_grad_ics_t_list))
        
        self.adaptive_constant_bcs1 = self.mean_grad_bcs1
        self.adaptive_constant_bcs2 = self.mean_grad_bcs2
        self.adaptive_constant_ics = self.mean_grad_ics
        self.adaptive_constant_ics_t = self.mean_grad_ics_t
        self.adaptive_constant_res = self.max_grad_res 

         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev, dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss


    def lambda_balance(self  , term  ):
                histoy_mean =  np.mean(self.loss_history[term])
                m = 5 #len(self.loss_list)
                num = np.exp( (self.loss_history[term][-1] -2 * self.loss_history[term][-2] +  self.loss_history[term][-3]) / np.mean(self.loss_history[term]) )#/(self.T * histoy_mean)) np.exp( )
                denum = 0 

                for  key in self.loss_list:
                    denum +=  np.exp(  (self.loss_history[key][-1] -2 * self.loss_history[key][-2] +  self.loss_history[key][-3])  /  np.mean(self.loss_history[key]) )# /(self.T * histoy_mean))  np.exp(self.loss_history[key][-1] )
                return m * (num / denum)
    
    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(1 , nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1],
                       self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1],
                        self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                       self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], 
                       self.x_r_tf: X_res_batch[:, 1:2],
                       self.adaptive_constant_bcs1_tf: self.adaptive_constant_bcs1_val,
                       self.adaptive_constant_bcs2_tf: self.adaptive_constant_bcs2_val,
                       self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                       self.adaptive_constant_ics_t_tf: self.adaptive_constant_ics_t_val,
                       self.adaptive_constant_res_tf: self.adaptive_constant_res_val
                       }#self.lam_r_val}

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)
            
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                # loss_value = self.sess.run(self.loss, tf_dict)
                # loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                # loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                # loss_res_value = self.sess.run(self.loss_res, tf_dict)
                [loss ,  loss_res,    loss_bc1 , loss_bc2 , loss_ics_u, loss_ics_u_t]  =  batch_losses 
                self.print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs1: %.3e,  Loss_bcs2: %.3e,  loss_ics_u: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss, loss_res, loss_bc1, loss_bc2, loss_ics_u ,  loss_ics_u_t, elapsed))
                
                # Compute and Print adaptive weights during training
                    # Compute the adaptive constant
                adaptive_constant_res_val, adaptive_constant_bcs1_val, adaptive_constant_bcs2_val, adaptive_constant_ics_val, adaptive_constant_ics_t_val = self.sess.run( [self.adaptive_constant_res,
                                                                                                                                               self.adaptive_constant_bcs1, 
                                                                                                                                               self.adaptive_constant_bcs2, 
                                                                                                                                               self.adaptive_constant_ics ,
                                                                                                                                               self.adaptive_constant_ics_t ,
                                                                                                                                                 ], tf_dict)
                # Print adaptive weights during training

                min_grad = np.min( [adaptive_constant_res_val, adaptive_constant_bcs1_val, adaptive_constant_bcs2_val, adaptive_constant_ics_val, adaptive_constant_ics_t_val])

                update_res = self.lambda_balance( "loss_res"  )
                update_ics_u = self.lambda_balance( "loss_ics_u"  )
                update_ics_u_t = self.lambda_balance( "loss_ics_u_t"  )
                update_bcs1 = self.lambda_balance( "loss_bc1"  )
                update_bcs2 = self.lambda_balance( "loss_bc2"  )
                
                self.adaptive_constant_res_val =  update_res / (min_grad + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_res_val
                self.adaptive_constant_ics_val =  update_ics_u  / (min_grad + 1e-12)#( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_ics_t_val =  update_ics_u_t  / (min_grad + 1e-12)#( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs1_val =  update_bcs1  / (min_grad + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val
                self.adaptive_constant_bcs2_val =  update_bcs2  / (min_grad + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val

                self.print('min_grad: {:.3e}'.format( min_grad))

                self.print('update_res: {:.3e}'.format( update_res))
                self.print('update_ics_ut: {:.3e}'.format( update_ics_u))
                self.print('update_ics_u_t: {:.3e}'.format( update_ics_u_t))
                self.print('update_bcs1: {:.3e}'.format( update_bcs1))
                self.print('update_bcs2: {:.3e}'.format( update_bcs2))
                
                self.print('adaptive_constant_res_val: {:.3e}'.format( self.adaptive_constant_res_val))
                self.print('adaptive_constant_ics_val: {:.3e}'.format( self.adaptive_constant_ics_val))
                self.print('adaptive_constant_ics_t_val: {:.3e}'.format( self.adaptive_constant_ics_t_val))
                self.print('adaptive_constant_bcs1_val: {:.3e}'.format( self.adaptive_constant_bcs1_val))
                self.print('adaptive_constant_bcs2_val: {:.3e}'.format( self.adaptive_constant_bcs2_val))
                
                self.adaptive_constant_res_log.append(self.adaptive_constant_res_val)
                self.adaptive_constant_bcs1_log.append(self.adaptive_constant_bcs1_val)
                self.adaptive_constant_bcs2_log.append(self.adaptive_constant_bcs2_val)
                self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)
                self.adaptive_constant_ics_t_log.append(self.adaptive_constant_ics_t_val)

                max_grad_res , mean_grad_bcs1, mean_grad_bcs2, mean_grad_ics, mean_grad_ics_t = self.sess.run( [ self.max_grad_res , self.mean_grad_bcs1, self.mean_grad_bcs2, self.mean_grad_ics, self.mean_grad_ics_t  ], tf_dict)

                self.mean_adaptive_constant_res_log.append( max_grad_res)
                self.mean_adaptive_constant_bcs1_log.append( mean_grad_bcs1)
                self.mean_adaptive_constant_bcs2_log.append( mean_grad_bcs2)
                self.mean_adaptive_constant_ics_log.append( mean_grad_ics)
                self.mean_adaptive_constant_ics_t_log.append( mean_grad_ics_t)


                sys.stdout.flush()
                start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()


    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size)
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1],
                    self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1],
                    self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                    self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1], 
                    self.x_r_tf: X_res_batch[:, 1:2],
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs1_val,
                    self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val
                    }#self.lam_r_val}
        
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 1000 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                # Compute and Print adaptive weights during training
                    # Compute the adaptive constant
                adaptive_constant_bcs_val, adaptive_constant_ics_val = self.sess.run( [self.adaptive_constant_bcs1, self.adaptive_constant_ics  ], tf_dict)
                # Print adaptive weights during training
                self.adaptive_constant_ics_val = adaptive_constant_ics_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs1_val = adaptive_constant_bcs_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs1_val


                print('lambda_u: {:.3e}'.format(self.adaptive_constant_bcs1_val))
                print('lambda_ut: {:.3e}'.format(self.adaptive_constant_ics_val))
                sys.stdout.flush()

                         
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   
     ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1  , grad_bc2 ,grad_ics  = self.sess.run([ self.grad_res[i],self.grad_bcs1[i],self.grad_bcs2[i],self.grad_ics[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs1_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())
            self.dict_gradients_bcs2_layers['layer_' + str(i + 1)].append(grad_bc2.flatten())
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs1_layers['layer_' + str(j + 1)][-1]
            gradients_bc2 = self.dict_gradients_bcs2_layers['layer_' + str(j + 1)][-1]
            gradients_ics = self.dict_gradients_ics_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')
            sns.distplot(gradients_bc2, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc2}}$')
            sns.distplot(gradients_ics, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{ics}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=4)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        #plt.show()
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , t , x , X_star , u_star , u_pred , r_star , r_pred):
        
        U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
        r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
        U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
        R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


        plt.figure(figsize=(18, 9))
        plt.subplot(2, 3, 1)
        plt.pcolor(t, x, U_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$x_1$')
        plt.ylabel('$x_2$')
        plt.title('Exact u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 2)
        plt.pcolor(t, x, U_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 3)
        plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()

        plt.subplot(2, 3, 4)
        plt.pcolor(t, x, r_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Exact r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 5)
        plt.pcolor(t, x, R_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 6)
        plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"))
        plt.close("all")

        
    
    def plot_lambda(self ):

        fontsize = 17
        fig, ax = plt.subplots()
        fig.set_size_inches([16,8])
        ax.semilogy(self.mean_adaptive_constant_bcs1_log, label=r'$\bar{\nabla_\theta {u_{bc1}}}$' , color = 'tab:green')
        ax.semilogy(self.mean_adaptive_constant_bcs2_log, label=r'$\bar{\nabla_\theta {u_{bc2}}}$' , color = 'tab:green')
        ax.semilogy(self.mean_adaptive_constant_ics_log, label=r'$\bar{\nabla_\theta {u_{ics}}}$' , color = 'tab:blue')
        ax.semilogy(self.mean_adaptive_constant_res_log, label=r'$Max{\nabla_\theta {u_{phy}}}$' , color = 'tab:red')
        ax.set_xlabel("epochs", fontsize=fontsize)
        ax.set_ylabel(r'$\bar{\nabla_\theta {u}}$', fontsize=fontsize)
        ax.tick_params(labelsize=fontsize)
        ax.legend(loc='center left', bbox_to_anchor=(-0.25, 0.5))

        ax2 = ax.twinx() 

        # fig, ax = plt.subplots()
        # fig.set_size_inches([15,8])
    
        ax2.semilogy(self.adaptive_constant_bcs1_log, label=r'$\bar{\lambda_{bc1}}$'  ,  linestyle='dashed' , color = 'tab:green') 
        ax2.semilogy(self.adaptive_constant_bcs2_log, label=r'$\bar{\lambda_{bc2}}$'  ,  linestyle='dashed' , color = 'tab:green') 
        ax2.semilogy(self.adaptive_constant_ics_log, label=r'$\bar{\lambda_{ics}}$' , linestyle='dashed'  , color = 'tab:blue')
        ax2.semilogy(self.adaptive_constant_res_log, label=r'$\bar{\lambda_{phy}}$' ,  linestyle='dashed' , color = 'tab:red')
        ax2.set_xlabel("epochs", fontsize=fontsize)
        ax2.set_ylabel(r'$\bar{\lambda}$', fontsize=fontsize)
        ax2.tick_params(labelsize=fontsize)
        ax2.legend(loc='center right', bbox_to_anchor=(1.2, 0.5))

        plt.tight_layout()

        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)

# %%
   #  
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        r_pred = model.predict_r(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))


    return [elapsed, error_u  ]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M2'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []

    for index in range(iterations):

        print("Epoch: ", str(index+1))

     # Create residual sampler

        # [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )
        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator ,  ics_sampler, bcs_sampler, res_sampler, c , mode , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

            model.print('elapsed: {:.2e}'.format(elapsed))

            model.print('Relative L2 error_u: {:.2e}'.format(error_u))
            model.print('Relative L2 error_r: {:.2e}'.format(error_r))
            model.plot_lambda()
            # model.plot_grad()
            model.save_NN()
            model.plt_prediction( t , x , X_star , u_star , u_pred , r_star , r_pred)
            model.print("average lambda_bc : " , np.average(model.adaptive_constant_bcs1_log))
            model.print("average lambda_ic : " , np.average(model.adaptive_constant_ics_log))
            model.print("average lambda_res : " , str(1.0))
            # sess.close()  

        # print('elapsed: {:.2e}'.format(elapsed))
        # print('Relative L2 error_u: {:.2e}'.format(error_u))
        # print('Relative L2 error_r: {:.2e}'.format(error_r))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    model.print("\n\nMethod: ", mtd)
    model.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    model.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    model.print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list,error_r_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_10599/4049125936.py:65: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10599/4049125936.py:66: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10599/4049125936.py:67: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10599/4049125936.py:67: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10599/4169585685.py:128: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-12-22 16:36:31.032664: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-22 16:36:31.057621: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-22 16:36:31.058385: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5597c194e5c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-22 16:36:31.058412: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-22 16:36:31.062187: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_10599/4169585685.py:179: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10599/4169585685.py:181: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10599/4169585685.py:252: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 5.084e-01, Loss_res: 6.697e-04,  Loss_bcs1: 5.680e-02,  Loss_bcs2: 1.792e-02,  loss_ics_u: 4.121e-01, Loss_ut_ics: 2.090e-02,, Time: 24.10
# min_grad: 1.467e-02
# update_res: 7.893e-01
# update_ics_ut: 1.071e+00
# update_ics_u_t: 7.909e-01
# update_bcs1: 6.827e-01
# update_bcs2: 7.634e-01
# adaptive_constant_res_val: 5.381e+01
# adaptive_constant_ics_val: 7.301e+01
# adaptive_constant_ics_t_val: 5.392e+01
# adaptive_constant_bcs1_val: 4.654e+01
# adaptive_constant_bcs2_val: 5.205e+01
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 2.400e+01, Loss_res: 9.377e-03,  Loss_bcs1: 1.098e-01,  Loss_bcs2: 5.018e-02,  loss_ics_u: 2.072e-01, Loss_ut_ics: 1.199e-02,, Time: 15.31
# min_grad: 5.493e-02
# update_res: 6.025e-01
# update_ics_ut: 7.069e-01
# update_ics_u_t: 6.921e-01
# update_bcs1: 1.197e+00
# update_bcs2: 8.700e-01
# adaptive_constant_res_val: 1.097e+01
# adaptive_constant_ics_val: 1.287e+01
# adaptive_constant_ics_t_val: 1.260e+01
# adaptive_constant_bcs1_val: 2.179e+01
# adaptive_constant_bcs2_val: 1.584e+01
# It: 300, Loss: 4.151e+00, Loss_res: 1.080e-02,  Loss_bcs1: 2.280e-02,  Loss_bcs2: 2.052e-02,  loss_ics_u: 2.478e-01, Loss_ut_ics: 1.793e-03,, Time: 7.55
# min_grad: 1.213e-01
# update_res: 8.518e-01
# update_ics_ut: 7.615e-01
# update_ics_u_t: 9.016e-01
# update_bcs1: 8.580e-01
# update_bcs2: 8.056e-01
# adaptive_constant_res_val: 7.025e+00
# adaptive_constant_ics_val: 6.280e+00
# adaptive_constant_ics_t_val: 7.436e+00
# adaptive_constant_bcs1_val: 7.076e+00
# adaptive_constant_bcs2_val: 6.644e+00
# It: 400, Loss: 2.017e+00, Loss_res: 1.236e-02,  Loss_bcs1: 2.613e-02,  Loss_bcs2: 1.630e-02,  loss_ics_u: 2.581e-01, Loss_ut_ics: 2.198e-03,, Time: 7.53
# min_grad: 3.183e-02
# update_res: 8.233e-01
# update_ics_ut: 8.569e-01
# update_ics_u_t: 8.677e-01
# update_bcs1: 9.403e-01
# update_bcs2: 6.642e-01
# adaptive_constant_res_val: 2.586e+01
# adaptive_constant_ics_val: 2.692e+01
# adaptive_constant_ics_t_val: 2.726e+01
# adaptive_constant_bcs1_val: 2.954e+01
# adaptive_constant_bcs2_val: 2.086e+01
# It: 500, Loss: 9.335e+00, Loss_res: 6.208e-03,  Loss_bcs1: 5.671e-02,  Loss_bcs2: 3.785e-02,  loss_ics_u: 2.435e-01, Loss_ut_ics: 5.672e-03,, Time: 7.53
# min_grad: 3.974e-02
# update_res: 9.675e-01
# update_ics_ut: 7.485e-01
# update_ics_u_t: 1.003e+00
# update_bcs1: 4.917e-01
# update_bcs2: 1.070e+00
# adaptive_constant_res_val: 2.434e+01
# adaptive_constant_ics_val: 1.883e+01
# adaptive_constant_ics_t_val: 2.524e+01
# adaptive_constant_bcs1_val: 1.237e+01
# adaptive_constant_bcs2_val: 2.693e+01
# It: 600, Loss: 6.213e+00, Loss_res: 4.008e-02,  Loss_bcs1: 8.187e-02,  Loss_bcs2: 1.741e-02,  loss_ics_u: 1.801e-01, Loss_ut_ics: 1.443e-02,, Time: 7.60
# min_grad: 2.688e-02
# update_res: 1.321e+00
# update_ics_ut: 5.566e-01
# update_ics_u_t: 6.906e-01
# update_bcs1: 7.855e-01
# update_bcs2: 9.813e-01
# adaptive_constant_res_val: 4.913e+01
# adaptive_constant_ics_val: 2.070e+01
# adaptive_constant_ics_t_val: 2.569e+01
# adaptive_constant_bcs1_val: 2.922e+01
# adaptive_constant_bcs2_val: 3.650e+01
# It: 700, Loss: 9.578e+00, Loss_res: 1.837e-03,  Loss_bcs1: 3.848e-02,  Loss_bcs2: 1.164e-02,  loss_ics_u: 3.782e-01, Loss_ut_ics: 4.270e-03,, Time: 7.83
# min_grad: 1.015e-01
# update_res: 8.316e-01
# update_ics_ut: 8.806e-01
# update_ics_u_t: 8.617e-01
# update_bcs1: 6.057e-01
# update_bcs2: 9.826e-01
# adaptive_constant_res_val: 8.196e+00
# adaptive_constant_ics_val: 8.679e+00
# adaptive_constant_ics_t_val: 8.494e+00
# adaptive_constant_bcs1_val: 5.970e+00
# adaptive_constant_bcs2_val: 9.685e+00
# It: 800, Loss: 2.516e+00, Loss_res: 8.094e-03,  Loss_bcs1: 7.209e-02,  Loss_bcs2: 2.509e-02,  loss_ics_u: 2.028e-01, Loss_ut_ics: 1.888e-03,, Time: 7.53
# min_grad: 6.832e-02
# update_res: 9.546e-01
# update_ics_ut: 6.807e-01
# update_ics_u_t: 8.939e-01
# update_bcs1: 8.079e-01
# update_bcs2: 8.453e-01
# adaptive_constant_res_val: 1.397e+01
# adaptive_constant_ics_val: 9.963e+00
# adaptive_constant_ics_t_val: 1.308e+01
# adaptive_constant_bcs1_val: 1.182e+01
# adaptive_constant_bcs2_val: 1.237e+01
# It: 900, Loss: 3.114e+00, Loss_res: 1.663e-02,  Loss_bcs1: 4.413e-02,  Loss_bcs2: 8.654e-03,  loss_ics_u: 2.125e-01, Loss_ut_ics: 1.035e-02,, Time: 7.56
# min_grad: 1.005e-01
# update_res: 8.587e-01
# update_ics_ut: 8.512e-01
# update_ics_u_t: 7.666e-01
# update_bcs1: 8.838e-01
# update_bcs2: 7.748e-01
# adaptive_constant_res_val: 8.542e+00
# adaptive_constant_ics_val: 8.467e+00
# adaptive_constant_ics_t_val: 7.625e+00
# adaptive_constant_bcs1_val: 8.791e+00
# adaptive_constant_bcs2_val: 7.707e+00
# It: 1000, Loss: 2.477e+00, Loss_res: 6.788e-02,  Loss_bcs1: 2.944e-02,  Loss_bcs2: 8.977e-03,  loss_ics_u: 1.765e-01, Loss_ut_ics: 9.820e-03,, Time: 7.43
# min_grad: 1.113e-01
# update_res: 4.127e-01
# update_ics_ut: 8.446e-01
# update_ics_u_t: 9.176e-01
# update_bcs1: 1.176e+00
# update_bcs2: 8.596e-01
# adaptive_constant_res_val: 3.709e+00
# adaptive_constant_ics_val: 7.590e+00
# adaptive_constant_ics_t_val: 8.246e+00
# adaptive_constant_bcs1_val: 1.057e+01
# adaptive_constant_bcs2_val: 7.725e+00
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 1.447e+00, Loss_res: 6.491e-03,  Loss_bcs1: 2.202e-02,  Loss_bcs2: 1.117e-02,  loss_ics_u: 1.417e-01, Loss_ut_ics: 3.482e-03,, Time: 15.29
# min_grad: 8.513e-02
# update_res: 8.014e-01
# update_ics_ut: 8.997e-01
# update_ics_u_t: 8.113e-01
# update_bcs1: 6.959e-01
# update_bcs2: 8.936e-01
# adaptive_constant_res_val: 9.413e+00
# adaptive_constant_ics_val: 1.057e+01
# adaptive_constant_ics_t_val: 9.530e+00
# adaptive_constant_bcs1_val: 8.174e+00
# adaptive_constant_bcs2_val: 1.050e+01
# It: 1200, Loss: 4.007e+00, Loss_res: 2.507e-03,  Loss_bcs1: 8.723e-02,  Loss_bcs2: 3.510e-02,  loss_ics_u: 2.650e-01, Loss_ut_ics: 1.060e-02,, Time: 9.76
# min_grad: 9.927e-02
# update_res: 7.232e-01
# update_ics_ut: 1.099e+00
# update_ics_u_t: 6.158e-01
# update_bcs1: 7.584e-01
# update_bcs2: 9.455e-01
# adaptive_constant_res_val: 7.285e+00
# adaptive_constant_ics_val: 1.107e+01
# adaptive_constant_ics_t_val: 6.203e+00
# adaptive_constant_bcs1_val: 7.640e+00
# adaptive_constant_bcs2_val: 9.525e+00
# It: 1300, Loss: 3.599e+00, Loss_res: 2.357e-03,  Loss_bcs1: 8.619e-02,  Loss_bcs2: 3.217e-02,  loss_ics_u: 2.321e-01, Loss_ut_ics: 7.798e-03,, Time: 10.42
# min_grad: 1.003e-01
# update_res: 8.448e-01
# update_ics_ut: 1.030e+00
# update_ics_u_t: 7.950e-01
# update_bcs1: 7.188e-01
# update_bcs2: 7.143e-01
# adaptive_constant_res_val: 8.421e+00
# adaptive_constant_ics_val: 1.027e+01
# adaptive_constant_ics_t_val: 7.925e+00
# adaptive_constant_bcs1_val: 7.166e+00
# adaptive_constant_bcs2_val: 7.120e+00
# It: 1400, Loss: 3.791e+00, Loss_res: 2.008e-03,  Loss_bcs1: 5.725e-02,  Loss_bcs2: 3.559e-02,  loss_ics_u: 3.010e-01, Loss_ut_ics: 2.382e-03,, Time: 7.06
# min_grad: 1.349e-01
# update_res: 7.286e-01
# update_ics_ut: 5.138e-01
# update_ics_u_t: 7.966e-01
# update_bcs1: 1.165e+00
# update_bcs2: 1.132e+00
# adaptive_constant_res_val: 5.402e+00
# adaptive_constant_ics_val: 3.809e+00
# adaptive_constant_ics_t_val: 5.905e+00
# adaptive_constant_bcs1_val: 8.636e+00
# adaptive_constant_bcs2_val: 8.394e+00
# It: 1500, Loss: 1.610e+00, Loss_res: 9.654e-04,  Loss_bcs1: 2.391e-02,  Loss_bcs2: 1.792e-02,  loss_ics_u: 3.251e-01, Loss_ut_ics: 1.637e-03,, Time: 7.14
# min_grad: 8.812e-02
# update_res: 8.371e-01
# update_ics_ut: 5.813e-01
# update_ics_u_t: 8.391e-01
# update_bcs1: 8.820e-01
# update_bcs2: 1.063e+00
# adaptive_constant_res_val: 9.499e+00
# adaptive_constant_ics_val: 6.597e+00
# adaptive_constant_ics_t_val: 9.522e+00
# adaptive_constant_bcs1_val: 1.001e+01
# adaptive_constant_bcs2_val: 1.206e+01
# It: 1600, Loss: 2.526e+00, Loss_res: 2.932e-03,  Loss_bcs1: 4.567e-02,  Loss_bcs2: 2.293e-02,  loss_ics_u: 2.667e-01, Loss_ut_ics: 5.239e-04,, Time: 7.25
# min_grad: 8.566e-02
# update_res: 7.358e-01
# update_ics_ut: 4.604e-01
# update_ics_u_t: 7.242e-01
# update_bcs1: 8.729e-01
# update_bcs2: 1.534e+00
# adaptive_constant_res_val: 8.590e+00
# adaptive_constant_ics_val: 5.375e+00
# adaptive_constant_ics_t_val: 8.454e+00
# adaptive_constant_bcs1_val: 1.019e+01
# adaptive_constant_bcs2_val: 1.791e+01
# It: 1700, Loss: 2.112e+00, Loss_res: 4.656e-03,  Loss_bcs1: 3.360e-02,  Loss_bcs2: 9.772e-03,  loss_ics_u: 2.871e-01, Loss_ut_ics: 1.363e-03,, Time: 7.11
# min_grad: 9.306e-02
# update_res: 8.670e-01
# update_ics_ut: 6.068e-01
# update_ics_u_t: 8.223e-01
# update_bcs1: 1.085e+00
# update_bcs2: 8.399e-01
# adaptive_constant_res_val: 9.316e+00
# adaptive_constant_ics_val: 6.520e+00
# adaptive_constant_ics_t_val: 8.837e+00
# adaptive_constant_bcs1_val: 1.166e+01
# adaptive_constant_bcs2_val: 9.026e+00
# It: 1800, Loss: 2.007e+00, Loss_res: 6.088e-03,  Loss_bcs1: 3.193e-02,  Loss_bcs2: 2.639e-02,  loss_ics_u: 1.994e-01, Loss_ut_ics: 4.495e-03,, Time: 7.20
# min_grad: 2.289e-01
# update_res: 7.350e-01
# update_ics_ut: 1.132e+00
# update_ics_u_t: 4.745e-01
# update_bcs1: 6.683e-01
# update_bcs2: 1.204e+00
# adaptive_constant_res_val: 3.211e+00
# adaptive_constant_ics_val: 4.947e+00
# adaptive_constant_ics_t_val: 2.073e+00
# adaptive_constant_bcs1_val: 2.920e+00
# adaptive_constant_bcs2_val: 5.258e+00
# It: 1900, Loss: 1.019e+00, Loss_res: 5.449e-03,  Loss_bcs1: 3.660e-02,  Loss_bcs2: 9.419e-03,  loss_ics_u: 1.667e-01, Loss_ut_ics: 9.992e-03,, Time: 8.67
# min_grad: 1.616e-01
# update_res: 8.174e-01
# update_ics_ut: 8.012e-01
# update_ics_u_t: 9.138e-01
# update_bcs1: 7.246e-01
# update_bcs2: 8.923e-01
# adaptive_constant_res_val: 5.056e+00
# adaptive_constant_ics_val: 4.957e+00
# adaptive_constant_ics_t_val: 5.653e+00
# adaptive_constant_bcs1_val: 4.482e+00
# adaptive_constant_bcs2_val: 5.520e+00
# It: 2000, Loss: 9.586e-01, Loss_res: 3.206e-03,  Loss_bcs1: 3.358e-02,  Loss_bcs2: 9.320e-03,  loss_ics_u: 1.460e-01, Loss_ut_ics: 2.958e-03,, Time: 7.08
# min_grad: 1.365e-01
# update_res: 7.840e-01
# update_ics_ut: 6.970e-01
# update_ics_u_t: 9.127e-01
# update_bcs1: 8.495e-01
# update_bcs2: 9.463e-01
# adaptive_constant_res_val: 5.742e+00
# adaptive_constant_ics_val: 5.105e+00
# adaptive_constant_ics_t_val: 6.685e+00
# adaptive_constant_bcs1_val: 6.222e+00
# adaptive_constant_bcs2_val: 6.931e+00
# It: 2100, Loss: 1.106e+00, Loss_res: 2.567e-03,  Loss_bcs1: 2.723e-02,  Loss_bcs2: 1.406e-02,  loss_ics_u: 1.589e-01, Loss_ut_ics: 1.882e-03,, Time: 7.10
# min_grad: 1.049e-01
# update_res: 7.536e-01
# update_ics_ut: 8.609e-01
# update_ics_u_t: 7.570e-01
# update_bcs1: 7.795e-01
# update_bcs2: 1.027e+00
# adaptive_constant_res_val: 7.181e+00
# adaptive_constant_ics_val: 8.203e+00
# adaptive_constant_ics_t_val: 7.214e+00
# adaptive_constant_bcs1_val: 7.427e+00
# adaptive_constant_bcs2_val: 9.781e+00
# It: 2200, Loss: 1.296e+00, Loss_res: 2.515e-03,  Loss_bcs1: 3.440e-02,  Loss_bcs2: 1.510e-02,  loss_ics_u: 1.045e-01, Loss_ut_ics: 2.464e-03,, Time: 7.41
# min_grad: 3.980e-02
# update_res: 7.418e-01
# update_ics_ut: 7.475e-01
# update_ics_u_t: 8.662e-01
# update_bcs1: 9.430e-01
# update_bcs2: 8.717e-01
# adaptive_constant_res_val: 1.864e+01
# adaptive_constant_ics_val: 1.878e+01
# adaptive_constant_ics_t_val: 2.177e+01
# adaptive_constant_bcs1_val: 2.370e+01
# adaptive_constant_bcs2_val: 2.190e+01
# It: 2300, Loss: 7.268e+00, Loss_res: 1.515e-03,  Loss_bcs1: 6.019e-02,  Loss_bcs2: 3.518e-02,  loss_ics_u: 2.661e-01, Loss_ut_ics: 2.027e-03,, Time: 8.01
# min_grad: 4.866e-02
# update_res: 7.016e-01
# update_ics_ut: 8.928e-01
# update_ics_u_t: 6.891e-01
# update_bcs1: 8.492e-01
# update_bcs2: 9.203e-01
# adaptive_constant_res_val: 1.442e+01
# adaptive_constant_ics_val: 1.835e+01
# adaptive_constant_ics_t_val: 1.416e+01
# adaptive_constant_bcs1_val: 1.745e+01
# adaptive_constant_bcs2_val: 1.891e+01
# It: 2400, Loss: 5.650e+00, Loss_res: 3.690e-03,  Loss_bcs1: 4.951e-02,  Loss_bcs2: 2.374e-02,  loss_ics_u: 2.325e-01, Loss_ut_ics: 1.346e-03,, Time: 7.21
# min_grad: 8.977e-02
# update_res: 8.044e-01
# update_ics_ut: 1.047e+00
# update_ics_u_t: 7.597e-01
# update_bcs1: 5.460e-01
# update_bcs2: 8.776e-01
# adaptive_constant_res_val: 8.961e+00
# adaptive_constant_ics_val: 1.166e+01
# adaptive_constant_ics_t_val: 8.463e+00
# adaptive_constant_bcs1_val: 6.082e+00
# adaptive_constant_bcs2_val: 9.776e+00
# It: 2500, Loss: 3.138e+00, Loss_res: 4.017e-03,  Loss_bcs1: 8.796e-02,  Loss_bcs2: 2.478e-02,  loss_ics_u: 1.981e-01, Loss_ut_ics: 1.590e-03,, Time: 8.91
# min_grad: 1.128e-01
# update_res: 9.067e-01
# update_ics_ut: 9.046e-01
# update_ics_u_t: 1.010e+00
# update_bcs1: 3.826e-01
# update_bcs2: 9.198e-01
# adaptive_constant_res_val: 8.036e+00
# adaptive_constant_ics_val: 8.017e+00
# adaptive_constant_ics_t_val: 8.951e+00
# adaptive_constant_bcs1_val: 3.391e+00
# adaptive_constant_bcs2_val: 8.152e+00
# It: 2600, Loss: 1.802e+00, Loss_res: 5.198e-03,  Loss_bcs1: 1.004e-01,  Loss_bcs2: 4.571e-03,  loss_ics_u: 1.695e-01, Loss_ut_ics: 2.595e-03,, Time: 7.09
# min_grad: 5.695e-02
# update_res: 6.349e-01
# update_ics_ut: 5.520e-01
# update_ics_u_t: 6.103e-01
# update_bcs1: 2.061e+00
# update_bcs2: 5.304e-01
# adaptive_constant_res_val: 1.115e+01
# adaptive_constant_ics_val: 9.692e+00
# adaptive_constant_ics_t_val: 1.072e+01
# adaptive_constant_bcs1_val: 3.619e+01
# adaptive_constant_bcs2_val: 9.313e+00
# It: 2700, Loss: 3.121e+00, Loss_res: 2.325e-02,  Loss_bcs1: 9.838e-03,  Loss_bcs2: 1.871e-02,  loss_ics_u: 2.230e-01, Loss_ut_ics: 1.591e-02,, Time: 7.50
# min_grad: 1.323e-01
# update_res: 5.996e-01
# update_ics_ut: 6.447e-01
# update_ics_u_t: 1.818e+00
# update_bcs1: 6.787e-01
# update_bcs2: 5.827e-01
# adaptive_constant_res_val: 4.533e+00
# adaptive_constant_ics_val: 4.875e+00
# adaptive_constant_ics_t_val: 1.375e+01
# adaptive_constant_bcs1_val: 5.132e+00
# adaptive_constant_bcs2_val: 4.406e+00
# It: 2800, Loss: 9.383e-01, Loss_res: 6.325e-03,  Loss_bcs1: 2.733e-02,  Loss_bcs2: 8.551e-03,  loss_ics_u: 1.476e-01, Loss_ut_ics: 9.006e-04,, Time: 7.14
# min_grad: 1.088e-01
# update_res: 4.502e-01
# update_ics_ut: 8.518e-01
# update_ics_u_t: 9.616e-01
# update_bcs1: 8.442e-01
# update_bcs2: 9.947e-01
# adaptive_constant_res_val: 4.140e+00
# adaptive_constant_ics_val: 7.833e+00
# adaptive_constant_ics_t_val: 8.842e+00
# adaptive_constant_bcs1_val: 7.762e+00
# adaptive_constant_bcs2_val: 9.146e+00
# It: 2900, Loss: 1.291e+00, Loss_res: 2.435e-02,  Loss_bcs1: 2.426e-02,  Loss_bcs2: 1.052e-02,  loss_ics_u: 1.151e-01, Loss_ut_ics: 4.411e-04,, Time: 7.45
# min_grad: 6.045e-02
# update_res: 4.638e-01
# update_ics_ut: 9.664e-01
# update_ics_u_t: 8.038e-01
# update_bcs1: 9.660e-01
# update_bcs2: 8.838e-01
# adaptive_constant_res_val: 7.671e+00
# adaptive_constant_ics_val: 1.599e+01
# adaptive_constant_ics_t_val: 1.330e+01
# adaptive_constant_bcs1_val: 1.598e+01
# adaptive_constant_bcs2_val: 1.462e+01
# It: 3000, Loss: 3.734e+00, Loss_res: 5.348e-03,  Loss_bcs1: 2.106e-02,  Loss_bcs2: 1.285e-02,  loss_ics_u: 1.932e-01, Loss_ut_ics: 6.077e-03,, Time: 7.05
# min_grad: 1.293e-01
# update_res: 7.976e-01
# update_ics_ut: 7.108e-01
# update_ics_u_t: 7.312e-01
# update_bcs1: 8.688e-01
# update_bcs2: 1.125e+00
# adaptive_constant_res_val: 6.166e+00
# adaptive_constant_ics_val: 5.495e+00
# adaptive_constant_ics_t_val: 5.653e+00
# adaptive_constant_bcs1_val: 6.717e+00
# adaptive_constant_bcs2_val: 8.697e+00
# It: 3100, Loss: 9.206e-01, Loss_res: 3.754e-03,  Loss_bcs1: 2.597e-02,  Loss_bcs2: 1.069e-02,  loss_ics_u: 1.094e-01, Loss_ut_ics: 5.083e-03,, Time: 6.89
# min_grad: 1.470e-01
# update_res: 8.646e-01
# update_ics_ut: 7.297e-01
# update_ics_u_t: 1.098e+00
# update_bcs1: 7.438e-01
# update_bcs2: 7.802e-01
# adaptive_constant_res_val: 5.881e+00
# adaptive_constant_ics_val: 4.963e+00
# adaptive_constant_ics_t_val: 7.467e+00
# adaptive_constant_bcs1_val: 5.059e+00
# adaptive_constant_bcs2_val: 5.306e+00
# It: 3200, Loss: 9.855e-01, Loss_res: 2.221e-03,  Loss_bcs1: 2.762e-02,  Loss_bcs2: 1.233e-02,  loss_ics_u: 1.539e-01, Loss_ut_ics: 4.493e-04,, Time: 7.03
# min_grad: 8.946e-02
# update_res: 7.628e-01
# update_ics_ut: 9.594e-01
# update_ics_u_t: 7.642e-01
# update_bcs1: 9.823e-01
# update_bcs2: 7.034e-01
# adaptive_constant_res_val: 8.526e+00
# adaptive_constant_ics_val: 1.072e+01
# adaptive_constant_ics_t_val: 8.543e+00
# adaptive_constant_bcs1_val: 1.098e+01
# adaptive_constant_bcs2_val: 7.863e+00
# It: 3300, Loss: 1.831e+00, Loss_res: 5.235e-03,  Loss_bcs1: 3.541e-02,  Loss_bcs2: 1.311e-02,  loss_ics_u: 1.200e-01, Loss_ut_ics: 8.622e-04,, Time: 7.13
# min_grad: 1.031e-01
# update_res: 5.046e-01
# update_ics_ut: 8.661e-01
# update_ics_u_t: 9.081e-01
# update_bcs1: 9.319e-01
# update_bcs2: 9.379e-01
# adaptive_constant_res_val: 4.896e+00
# adaptive_constant_ics_val: 8.404e+00
# adaptive_constant_ics_t_val: 8.811e+00
# adaptive_constant_bcs1_val: 9.042e+00
# adaptive_constant_bcs2_val: 9.100e+00
# It: 3400, Loss: 1.164e+00, Loss_res: 2.946e-03,  Loss_bcs1: 2.645e-02,  Loss_bcs2: 1.470e-02,  loss_ics_u: 9.194e-02, Loss_ut_ics: 4.105e-04,, Time: 7.01
# min_grad: 9.984e-02
# update_res: 7.663e-01
# update_ics_ut: 8.808e-01
# update_ics_u_t: 9.767e-01
# update_bcs1: 7.551e-01
# update_bcs2: 7.652e-01
# adaptive_constant_res_val: 7.676e+00
# adaptive_constant_ics_val: 8.822e+00
# adaptive_constant_ics_t_val: 9.783e+00
# adaptive_constant_bcs1_val: 7.563e+00
# adaptive_constant_bcs2_val: 7.665e+00
# It: 3500, Loss: 1.323e+00, Loss_res: 5.936e-03,  Loss_bcs1: 2.386e-02,  Loss_bcs2: 1.509e-02,  loss_ics_u: 1.109e-01, Loss_ut_ics: 2.909e-04,, Time: 6.91
# min_grad: 7.945e-02
# update_res: 7.698e-01
# update_ics_ut: 8.285e-01
# update_ics_u_t: 8.409e-01
# update_bcs1: 8.731e-01
# update_bcs2: 8.573e-01
# adaptive_constant_res_val: 9.689e+00
# adaptive_constant_ics_val: 1.043e+01
# adaptive_constant_ics_t_val: 1.058e+01
# adaptive_constant_bcs1_val: 1.099e+01
# adaptive_constant_bcs2_val: 1.079e+01
# It: 3600, Loss: 2.447e+00, Loss_res: 2.249e-03,  Loss_bcs1: 3.471e-02,  Loss_bcs2: 1.117e-02,  loss_ics_u: 1.820e-01, Loss_ut_ics: 2.390e-03,, Time: 7.00
# min_grad: 7.432e-02
# update_res: 8.316e-01
# update_ics_ut: 1.111e+00
# update_ics_u_t: 7.726e-01
# update_bcs1: 6.783e-01
# update_bcs2: 6.735e-01
# adaptive_constant_res_val: 1.119e+01
# adaptive_constant_ics_val: 1.495e+01
# adaptive_constant_ics_t_val: 1.040e+01
# adaptive_constant_bcs1_val: 9.128e+00
# adaptive_constant_bcs2_val: 9.063e+00
# It: 3700, Loss: 2.489e+00, Loss_res: 3.342e-03,  Loss_bcs1: 4.116e-02,  Loss_bcs2: 1.241e-02,  loss_ics_u: 1.276e-01, Loss_ut_ics: 5.430e-03,, Time: 7.01
# min_grad: 9.163e-02
# update_res: 7.953e-01
# update_ics_ut: 7.259e-01
# update_ics_u_t: 1.137e+00
# update_bcs1: 9.279e-01
# update_bcs2: 6.543e-01
# adaptive_constant_res_val: 8.680e+00
# adaptive_constant_ics_val: 7.922e+00
# adaptive_constant_ics_t_val: 1.241e+01
# adaptive_constant_bcs1_val: 1.013e+01
# adaptive_constant_bcs2_val: 7.141e+00
# It: 3800, Loss: 1.525e+00, Loss_res: 1.729e-03,  Loss_bcs1: 2.957e-02,  Loss_bcs2: 2.680e-02,  loss_ics_u: 1.277e-01, Loss_ut_ics: 6.044e-04,, Time: 7.26
# min_grad: 1.215e-01
# update_res: 7.623e-01
# update_ics_ut: 9.212e-01
# update_ics_u_t: 7.354e-01
# update_bcs1: 8.092e-01
# update_bcs2: 9.228e-01
# adaptive_constant_res_val: 6.275e+00
# adaptive_constant_ics_val: 7.582e+00
# adaptive_constant_ics_t_val: 6.053e+00
# adaptive_constant_bcs1_val: 6.660e+00
# adaptive_constant_bcs2_val: 7.595e+00
# It: 3900, Loss: 1.288e+00, Loss_res: 2.411e-03,  Loss_bcs1: 2.408e-02,  Loss_bcs2: 1.725e-02,  loss_ics_u: 1.285e-01, Loss_ut_ics: 1.161e-03,, Time: 7.24
# min_grad: 8.199e-02
# update_res: 8.113e-01
# update_ics_ut: 7.800e-01
# update_ics_u_t: 8.148e-01
# update_bcs1: 9.746e-01
# update_bcs2: 8.344e-01
# adaptive_constant_res_val: 9.894e+00
# adaptive_constant_ics_val: 9.512e+00
# adaptive_constant_ics_t_val: 9.937e+00
# adaptive_constant_bcs1_val: 1.189e+01
# adaptive_constant_bcs2_val: 1.018e+01
# It: 4000, Loss: 1.484e+00, Loss_res: 6.054e-03,  Loss_bcs1: 2.344e-02,  Loss_bcs2: 1.715e-02,  loss_ics_u: 1.007e-01, Loss_ut_ics: 1.296e-03,, Time: 7.25
# min_grad: 9.729e-02
# update_res: 1.240e+00
# update_ics_ut: 8.051e-01
# update_ics_u_t: 9.545e-01
# update_bcs1: 6.788e-01
# update_bcs2: 5.057e-01
# adaptive_constant_res_val: 1.275e+01
# adaptive_constant_ics_val: 8.275e+00
# adaptive_constant_ics_t_val: 9.811e+00
# adaptive_constant_bcs1_val: 6.977e+00
# adaptive_constant_bcs2_val: 5.197e+00
# It: 4100, Loss: 1.187e+00, Loss_res: 1.739e-03,  Loss_bcs1: 2.118e-02,  Loss_bcs2: 1.251e-02,  loss_ics_u: 1.142e-01, Loss_ut_ics: 7.515e-04,, Time: 7.42
# min_grad: 5.944e-02
# update_res: 8.904e-01
# update_ics_ut: 6.355e-01
# update_ics_u_t: 8.802e-01
# update_bcs1: 9.506e-01
# update_bcs2: 8.805e-01
# adaptive_constant_res_val: 1.498e+01
# adaptive_constant_ics_val: 1.069e+01
# adaptive_constant_ics_t_val: 1.481e+01
# adaptive_constant_bcs1_val: 1.599e+01
# adaptive_constant_bcs2_val: 1.481e+01
# It: 4200, Loss: 1.760e+00, Loss_res: 5.715e-03,  Loss_bcs1: 1.452e-02,  Loss_bcs2: 1.168e-02,  loss_ics_u: 1.101e-01, Loss_ut_ics: 6.208e-03,, Time: 7.00
# min_grad: 1.617e-01
# update_res: 8.954e-01
# update_ics_ut: 7.471e-01
# update_ics_u_t: 1.218e+00
# update_bcs1: 8.302e-01
# update_bcs2: 5.328e-01
# adaptive_constant_res_val: 5.539e+00
# adaptive_constant_ics_val: 4.621e+00
# adaptive_constant_ics_t_val: 7.534e+00
# adaptive_constant_bcs1_val: 5.135e+00
# adaptive_constant_bcs2_val: 3.296e+00
# It: 4300, Loss: 6.868e-01, Loss_res: 1.307e-03,  Loss_bcs1: 1.839e-02,  Loss_bcs2: 1.201e-02,  loss_ics_u: 1.172e-01, Loss_ut_ics: 5.093e-04,, Time: 7.29
# min_grad: 4.471e-02
# update_res: 8.444e-01
# update_ics_ut: 9.117e-01
# update_ics_u_t: 8.130e-01
# update_bcs1: 9.307e-01
# update_bcs2: 6.488e-01
# adaptive_constant_res_val: 1.889e+01
# adaptive_constant_ics_val: 2.039e+01
# adaptive_constant_ics_t_val: 1.819e+01
# adaptive_constant_bcs1_val: 2.082e+01
# adaptive_constant_bcs2_val: 1.451e+01
# It: 4400, Loss: 3.351e+00, Loss_res: 2.977e-03,  Loss_bcs1: 2.985e-02,  Loss_bcs2: 9.202e-03,  loss_ics_u: 1.218e-01, Loss_ut_ics: 3.138e-03,, Time: 7.21
# min_grad: 7.145e-02
# update_res: 1.013e+00
# update_ics_ut: 7.035e-01
# update_ics_u_t: 8.447e-01
# update_bcs1: 7.015e-01
# update_bcs2: 1.061e+00
# adaptive_constant_res_val: 1.418e+01
# adaptive_constant_ics_val: 9.846e+00
# adaptive_constant_ics_t_val: 1.182e+01
# adaptive_constant_bcs1_val: 9.818e+00
# adaptive_constant_bcs2_val: 1.485e+01
# It: 4500, Loss: 1.595e+00, Loss_res: 1.476e-03,  Loss_bcs1: 2.565e-02,  Loss_bcs2: 1.010e-02,  loss_ics_u: 1.133e-01, Loss_ut_ics: 4.762e-03,, Time: 6.90
# min_grad: 1.276e-01
# update_res: 9.193e-01
# update_ics_ut: 1.125e+00
# update_ics_u_t: 6.559e-01
# update_bcs1: 7.021e-01
# update_bcs2: 6.329e-01
# adaptive_constant_res_val: 7.202e+00
# adaptive_constant_ics_val: 8.815e+00
# adaptive_constant_ics_t_val: 5.138e+00
# adaptive_constant_bcs1_val: 5.500e+00
# adaptive_constant_bcs2_val: 4.958e+00
# It: 4600, Loss: 1.288e+00, Loss_res: 8.808e-04,  Loss_bcs1: 2.589e-02,  Loss_bcs2: 1.304e-02,  loss_ics_u: 1.201e-01, Loss_ut_ics: 3.083e-03,, Time: 7.30
# min_grad: 6.417e-02
# update_res: 8.571e-01
# update_ics_ut: 9.111e-01
# update_ics_u_t: 6.424e-01
# update_bcs1: 7.038e-01
# update_bcs2: 1.005e+00
# adaptive_constant_res_val: 1.336e+01
# adaptive_constant_ics_val: 1.420e+01
# adaptive_constant_ics_t_val: 1.001e+01
# adaptive_constant_bcs1_val: 1.097e+01
# adaptive_constant_bcs2_val: 1.566e+01
# It: 4700, Loss: 2.086e+00, Loss_res: 2.896e-03,  Loss_bcs1: 2.386e-02,  Loss_bcs2: 1.090e-02,  loss_ics_u: 1.127e-01, Loss_ut_ics: 1.557e-03,, Time: 7.20
# min_grad: 4.667e-02
# update_res: 9.389e-01
# update_ics_ut: 9.119e-01
# update_ics_u_t: 6.873e-01
# update_bcs1: 6.996e-01
# update_bcs2: 8.858e-01
# adaptive_constant_res_val: 2.012e+01
# adaptive_constant_ics_val: 1.954e+01
# adaptive_constant_ics_t_val: 1.473e+01
# adaptive_constant_bcs1_val: 1.499e+01
# adaptive_constant_bcs2_val: 1.898e+01
# It: 4800, Loss: 3.150e+00, Loss_res: 4.147e-03,  Loss_bcs1: 3.067e-02,  Loss_bcs2: 1.266e-02,  loss_ics_u: 1.130e-01, Loss_ut_ics: 1.080e-02,, Time: 7.18
# min_grad: 7.682e-02
# update_res: 4.629e-01
# update_ics_ut: 4.701e-01
# update_ics_u_t: 2.595e+00
# update_bcs1: 4.251e-01
# update_bcs2: 5.488e-01
# adaptive_constant_res_val: 6.025e+00
# adaptive_constant_ics_val: 6.119e+00
# adaptive_constant_ics_t_val: 3.378e+01
# adaptive_constant_bcs1_val: 5.534e+00
# adaptive_constant_bcs2_val: 7.144e+00
# It: 4900, Loss: 9.614e-01, Loss_res: 1.613e-03,  Loss_bcs1: 2.348e-02,  Loss_bcs2: 1.158e-02,  loss_ics_u: 1.197e-01, Loss_ut_ics: 1.990e-04,, Time: 7.31
# min_grad: 4.715e-02
# update_res: 8.485e-01
# update_ics_ut: 8.480e-01
# update_ics_u_t: 8.514e-01
# update_bcs1: 8.986e-01
# update_bcs2: 7.156e-01
# adaptive_constant_res_val: 1.800e+01
# adaptive_constant_ics_val: 1.798e+01
# adaptive_constant_ics_t_val: 1.806e+01
# adaptive_constant_bcs1_val: 1.906e+01
# adaptive_constant_bcs2_val: 1.518e+01
# It: 5000, Loss: 2.718e+00, Loss_res: 3.577e-03,  Loss_bcs1: 1.374e-02,  Loss_bcs2: 1.367e-02,  loss_ics_u: 1.191e-01, Loss_ut_ics: 2.361e-03,, Time: 7.22
# min_grad: 8.653e-02
# update_res: 8.545e-01
# update_ics_ut: 8.069e-01
# update_ics_u_t: 7.691e-01
# update_bcs1: 8.348e-01
# update_bcs2: 9.037e-01
# adaptive_constant_res_val: 9.875e+00
# adaptive_constant_ics_val: 9.325e+00
# adaptive_constant_ics_t_val: 8.887e+00
# adaptive_constant_bcs1_val: 9.647e+00
# adaptive_constant_bcs2_val: 1.044e+01
# It: 5100, Loss: 1.308e+00, Loss_res: 1.319e-03,  Loss_bcs1: 1.908e-02,  Loss_bcs2: 1.274e-02,  loss_ics_u: 1.035e-01, Loss_ut_ics: 1.418e-03,, Time: 7.10
# min_grad: 4.929e-02
# update_res: 8.011e-01
# update_ics_ut: 8.166e-01
# update_ics_u_t: 7.914e-01
# update_bcs1: 9.002e-01
# update_bcs2: 8.520e-01
# adaptive_constant_res_val: 1.625e+01
# adaptive_constant_ics_val: 1.657e+01
# adaptive_constant_ics_t_val: 1.606e+01
# adaptive_constant_bcs1_val: 1.827e+01
# adaptive_constant_bcs2_val: 1.729e+01
# It: 5200, Loss: 2.303e+00, Loss_res: 3.176e-03,  Loss_bcs1: 1.469e-02,  Loss_bcs2: 1.412e-02,  loss_ics_u: 1.040e-01, Loss_ut_ics: 1.043e-03,, Time: 7.35
# min_grad: 7.673e-02
# update_res: 8.491e-01
# update_ics_ut: 8.109e-01
# update_ics_u_t: 8.160e-01
# update_bcs1: 7.781e-01
# update_bcs2: 9.237e-01
# adaptive_constant_res_val: 1.107e+01
# adaptive_constant_ics_val: 1.057e+01
# adaptive_constant_ics_t_val: 1.064e+01
# adaptive_constant_bcs1_val: 1.014e+01
# adaptive_constant_bcs2_val: 1.204e+01
# It: 5300, Loss: 1.412e+00, Loss_res: 2.612e-03,  Loss_bcs1: 1.471e-02,  Loss_bcs2: 1.096e-02,  loss_ics_u: 1.039e-01, Loss_ut_ics: 4.247e-04,, Time: 7.07
# min_grad: 5.303e-02
# update_res: 7.742e-01
# update_ics_ut: 8.892e-01
# update_ics_u_t: 8.819e-01
# update_bcs1: 8.696e-01
# update_bcs2: 7.250e-01
# adaptive_constant_res_val: 1.460e+01
# adaptive_constant_ics_val: 1.677e+01
# adaptive_constant_ics_t_val: 1.663e+01
# adaptive_constant_bcs1_val: 1.640e+01
# adaptive_constant_bcs2_val: 1.367e+01
# It: 5400, Loss: 3.281e+00, Loss_res: 6.243e-02,  Loss_bcs1: 1.830e-02,  Loss_bcs2: 1.206e-02,  loss_ics_u: 1.002e-01, Loss_ut_ics: 1.346e-02,, Time: 6.82
# min_grad: 9.132e-02
# update_res: 5.221e-01
# update_ics_ut: 7.113e-01
# update_ics_u_t: 1.490e+00
# update_bcs1: 7.194e-01
# update_bcs2: 8.252e-01
# adaptive_constant_res_val: 5.717e+00
# adaptive_constant_ics_val: 7.790e+00
# adaptive_constant_ics_t_val: 1.632e+01
# adaptive_constant_bcs1_val: 7.878e+00
# adaptive_constant_bcs2_val: 9.037e+00
# It: 5500, Loss: 8.761e-01, Loss_res: 5.050e-03,  Loss_bcs1: 1.288e-02,  Loss_bcs2: 9.906e-03,  loss_ics_u: 8.356e-02, Loss_ut_ics: 3.284e-04,, Time: 6.98
# min_grad: 3.249e-02
# update_res: 8.874e-01
# update_ics_ut: 8.763e-01
# update_ics_u_t: 7.737e-01
# update_bcs1: 7.821e-01
# update_bcs2: 8.258e-01
# adaptive_constant_res_val: 2.731e+01
# adaptive_constant_ics_val: 2.697e+01
# adaptive_constant_ics_t_val: 2.382e+01
# adaptive_constant_bcs1_val: 2.407e+01
# adaptive_constant_bcs2_val: 2.542e+01
# It: 5600, Loss: 7.800e+00, Loss_res: 2.159e-03,  Loss_bcs1: 6.706e-02,  Loss_bcs2: 3.978e-02,  loss_ics_u: 1.795e-01, Loss_ut_ics: 1.148e-02,, Time: 6.87
# min_grad: 1.339e-01
# update_res: 8.877e-01
# update_ics_ut: 1.017e+00
# update_ics_u_t: 8.736e-01
# update_bcs1: 5.405e-01
# update_bcs2: 7.539e-01
# adaptive_constant_res_val: 6.628e+00
# adaptive_constant_ics_val: 7.597e+00
# adaptive_constant_ics_t_val: 6.523e+00
# adaptive_constant_bcs1_val: 4.035e+00
# adaptive_constant_bcs2_val: 5.629e+00
# ...
# It: 38200, Loss: 2.577e+00, Loss_res: 7.829e-04,  Loss_bcs1: 7.392e-03,  Loss_bcs2: 5.987e-03,  loss_ics_u: 4.045e-02, Loss_ut_ics: 1.270e-03,, Time: 3.57
# min_grad: 3.117e-02
# update_res: 8.397e-01
# update_ics_ut: 8.742e-01
# update_ics_u_t: 1.032e+00
# update_bcs1: 6.151e-01
# update_bcs2: 8.710e-01
# adaptive_constant_res_val: 2.694e+01
# adaptive_constant_ics_val: 2.804e+01
# adaptive_constant_ics_t_val: 3.312e+01
# adaptive_constant_bcs1_val: 1.973e+01
# adaptive_constant_bcs2_val: 2.794e+01
# It: 38300, Loss: 1.400e+00, Loss_res: 7.942e-04,  Loss_bcs1: 7.372e-03,  Loss_bcs2: 6.175e-03,  loss_ics_u: 3.653e-02, Loss_ut_ics: 1.101e-03,, Time: 3.31
# min_grad: 2.619e-02
# update_res: 9.415e-01
# update_ics_ut: 9.768e-01
# update_ics_u_t: 6.927e-01
# update_bcs1: 8.137e-01
# update_bcs2: 6.479e-01
# adaptive_constant_res_val: 3.595e+01
# adaptive_constant_ics_val: 3.730e+01
# adaptive_constant_ics_t_val: 2.645e+01
# adaptive_constant_bcs1_val: 3.107e+01
# adaptive_constant_bcs2_val: 2.474e+01
# It: 38400, Loss: 1.964e+00, Loss_res: 5.229e-04,  Loss_bcs1: 7.712e-03,  Loss_bcs2: 7.298e-03,  loss_ics_u: 3.988e-02, Loss_ut_ics: 1.408e-03,, Time: 3.62
# min_grad: 3.025e-02
# update_res: 7.783e-01
# update_ics_ut: 8.203e-01
# update_ics_u_t: 7.963e-01
# update_bcs1: 6.474e-01
# update_bcs2: 1.142e+00
# adaptive_constant_res_val: 2.573e+01
# adaptive_constant_ics_val: 2.712e+01
# adaptive_constant_ics_t_val: 2.632e+01
# adaptive_constant_bcs1_val: 2.140e+01
# adaptive_constant_bcs2_val: 3.777e+01
# It: 38500, Loss: 1.515e+00, Loss_res: 7.324e-04,  Loss_bcs1: 7.359e-03,  Loss_bcs2: 7.073e-03,  loss_ics_u: 3.850e-02, Loss_ut_ics: 1.045e-03,, Time: 3.34
# min_grad: 3.492e-02
# update_res: 8.403e-01
# update_ics_ut: 9.205e-01
# update_ics_u_t: 7.789e-01
# update_bcs1: 8.148e-01
# update_bcs2: 7.546e-01
# adaptive_constant_res_val: 2.406e+01
# adaptive_constant_ics_val: 2.636e+01
# adaptive_constant_ics_t_val: 2.230e+01
# adaptive_constant_bcs1_val: 2.333e+01
# adaptive_constant_bcs2_val: 2.161e+01
# It: 38600, Loss: 1.480e+00, Loss_res: 7.846e-04,  Loss_bcs1: 1.017e-02,  Loss_bcs2: 5.794e-03,  loss_ics_u: 4.091e-02, Loss_ut_ics: 9.238e-04,, Time: 3.38
# min_grad: 3.303e-02
# update_res: 7.887e-01
# update_ics_ut: 9.623e-01
# update_ics_u_t: 7.380e-01
# update_bcs1: 9.174e-01
# update_bcs2: 6.600e-01
# adaptive_constant_res_val: 2.388e+01
# adaptive_constant_ics_val: 2.913e+01
# adaptive_constant_ics_t_val: 2.234e+01
# adaptive_constant_bcs1_val: 2.778e+01
# adaptive_constant_bcs2_val: 1.998e+01
# It: 38700, Loss: 1.545e+00, Loss_res: 8.862e-04,  Loss_bcs1: 6.736e-03,  Loss_bcs2: 5.262e-03,  loss_ics_u: 4.142e-02, Loss_ut_ics: 1.108e-03,, Time: 3.20
# min_grad: 2.150e-02
# update_res: 9.896e-01
# update_ics_ut: 9.663e-01
# update_ics_u_t: 8.633e-01
# update_bcs1: 6.398e-01
# update_bcs2: 6.436e-01
# adaptive_constant_res_val: 4.602e+01
# adaptive_constant_ics_val: 4.493e+01
# adaptive_constant_ics_t_val: 4.015e+01
# adaptive_constant_bcs1_val: 2.975e+01
# adaptive_constant_bcs2_val: 2.993e+01
# It: 38800, Loss: 1.827e+00, Loss_res: 9.183e-04,  Loss_bcs1: 7.679e-03,  Loss_bcs2: 5.838e-03,  loss_ics_u: 2.947e-02, Loss_ut_ics: 1.421e-03,, Time: 3.14
# min_grad: 3.242e-02
# update_res: 8.503e-01
# update_ics_ut: 8.629e-01
# update_ics_u_t: 9.717e-01
# update_bcs1: 6.381e-01
# update_bcs2: 8.834e-01
# adaptive_constant_res_val: 2.623e+01
# adaptive_constant_ics_val: 2.662e+01
# adaptive_constant_ics_t_val: 2.997e+01
# adaptive_constant_bcs1_val: 1.968e+01
# adaptive_constant_bcs2_val: 2.725e+01
# It: 38900, Loss: 1.499e+00, Loss_res: 5.284e-04,  Loss_bcs1: 1.071e-02,  Loss_bcs2: 9.625e-03,  loss_ics_u: 3.685e-02, Loss_ut_ics: 1.040e-03,, Time: 3.35
# min_grad: 4.357e-02
# update_res: 7.931e-01
# update_ics_ut: 8.041e-01
# update_ics_u_t: 5.186e-01
# update_bcs1: 1.314e+00
# update_bcs2: 7.382e-01
# adaptive_constant_res_val: 1.820e+01
# adaptive_constant_ics_val: 1.846e+01
# adaptive_constant_ics_t_val: 1.190e+01
# adaptive_constant_bcs1_val: 3.016e+01
# adaptive_constant_bcs2_val: 1.694e+01
# It: 39000, Loss: 1.004e+00, Loss_res: 7.875e-04,  Loss_bcs1: 5.728e-03,  Loss_bcs2: 6.384e-03,  loss_ics_u: 3.778e-02, Loss_ut_ics: 9.340e-04,, Time: 3.41
# min_grad: 1.988e-02
# update_res: 9.094e-01
# update_ics_ut: 7.840e-01
# update_ics_u_t: 7.703e-01
# update_bcs1: 8.623e-01
# update_bcs2: 8.588e-01
# adaptive_constant_res_val: 4.574e+01
# adaptive_constant_ics_val: 3.944e+01
# adaptive_constant_ics_t_val: 3.875e+01
# adaptive_constant_bcs1_val: 4.337e+01
# adaptive_constant_bcs2_val: 4.320e+01
# It: 39100, Loss: 2.537e+00, Loss_res: 6.426e-04,  Loss_bcs1: 1.084e-02,  Loss_bcs2: 6.378e-03,  loss_ics_u: 4.302e-02, Loss_ut_ics: 1.695e-03,, Time: 3.10
# min_grad: 3.115e-02
# update_res: 6.858e-01
# update_ics_ut: 8.856e-01
# update_ics_u_t: 8.325e-01
# update_bcs1: 8.154e-01
# update_bcs2: 8.267e-01
# adaptive_constant_res_val: 2.202e+01
# adaptive_constant_ics_val: 2.843e+01
# adaptive_constant_ics_t_val: 2.673e+01
# adaptive_constant_bcs1_val: 2.618e+01
# adaptive_constant_bcs2_val: 2.654e+01
# It: 39200, Loss: 1.397e+00, Loss_res: 1.186e-03,  Loss_bcs1: 8.748e-03,  Loss_bcs2: 6.051e-03,  loss_ics_u: 3.286e-02, Loss_ut_ics: 1.762e-03,, Time: 3.39
# min_grad: 4.447e-02
# update_res: 8.575e-01
# update_ics_ut: 7.447e-01
# update_ics_u_t: 5.617e-01
# update_bcs1: 8.726e-01
# update_bcs2: 1.183e+00
# adaptive_constant_res_val: 1.928e+01
# adaptive_constant_ics_val: 1.675e+01
# adaptive_constant_ics_t_val: 1.263e+01
# adaptive_constant_bcs1_val: 1.962e+01
# adaptive_constant_bcs2_val: 2.659e+01
# It: 39300, Loss: 8.733e-01, Loss_res: 5.267e-04,  Loss_bcs1: 8.485e-03,  Loss_bcs2: 3.970e-03,  loss_ics_u: 3.457e-02, Loss_ut_ics: 9.664e-04,, Time: 3.29
# min_grad: 1.294e-02
# update_res: 9.673e-01
# update_ics_ut: 9.392e-01
# update_ics_u_t: 4.781e-01
# update_bcs1: 9.392e-01
# update_bcs2: 7.500e-01
# adaptive_constant_res_val: 7.477e+01
# adaptive_constant_ics_val: 7.260e+01
# adaptive_constant_ics_t_val: 3.696e+01
# adaptive_constant_bcs1_val: 7.260e+01
# adaptive_constant_bcs2_val: 5.798e+01
# It: 39400, Loss: 4.076e+00, Loss_res: 1.231e-03,  Loss_bcs1: 9.717e-03,  Loss_bcs2: 5.573e-03,  loss_ics_u: 3.979e-02, Loss_ut_ics: 1.807e-03,, Time: 3.42
# min_grad: 4.255e-02
# update_res: 8.111e-01
# update_ics_ut: 8.330e-01
# update_ics_u_t: 8.164e-01
# update_bcs1: 8.180e-01
# update_bcs2: 6.664e-01
# adaptive_constant_res_val: 1.906e+01
# adaptive_constant_ics_val: 1.958e+01
# adaptive_constant_ics_t_val: 1.919e+01
# adaptive_constant_bcs1_val: 1.922e+01
# adaptive_constant_bcs2_val: 1.566e+01
# It: 39500, Loss: 9.483e-01, Loss_res: 6.415e-04,  Loss_bcs1: 8.944e-03,  Loss_bcs2: 6.613e-03,  loss_ics_u: 3.233e-02, Loss_ut_ics: 1.440e-03,, Time: 3.42
# min_grad: 2.202e-02
# update_res: 7.300e-01
# update_ics_ut: 7.947e-01
# update_ics_u_t: 5.863e-01
# update_bcs1: 1.048e+00
# update_bcs2: 1.022e+00
# adaptive_constant_res_val: 3.315e+01
# adaptive_constant_ics_val: 3.609e+01
# adaptive_constant_ics_t_val: 2.662e+01
# adaptive_constant_bcs1_val: 4.758e+01
# adaptive_constant_bcs2_val: 4.640e+01
# It: 39600, Loss: 2.301e+00, Loss_res: 6.743e-04,  Loss_bcs1: 1.040e-02,  Loss_bcs2: 6.281e-03,  loss_ics_u: 4.002e-02, Loss_ut_ics: 1.824e-03,, Time: 4.00
# min_grad: 3.003e-02
# update_res: 7.183e-01
# update_ics_ut: 7.449e-01
# update_ics_u_t: 7.187e-01
# update_bcs1: 9.814e-01
# update_bcs2: 1.009e+00
# adaptive_constant_res_val: 2.392e+01
# adaptive_constant_ics_val: 2.480e+01
# adaptive_constant_ics_t_val: 2.393e+01
# adaptive_constant_bcs1_val: 3.268e+01
# adaptive_constant_bcs2_val: 3.360e+01
# It: 39700, Loss: 1.424e+00, Loss_res: 5.839e-04,  Loss_bcs1: 6.186e-03,  Loss_bcs2: 5.527e-03,  loss_ics_u: 3.982e-02, Loss_ut_ics: 1.444e-03,, Time: 3.38
# min_grad: 2.387e-02
# update_res: 7.695e-01
# update_ics_ut: 8.319e-01
# update_ics_u_t: 9.327e-01
# update_bcs1: 5.704e-01
# update_bcs2: 1.087e+00
# adaptive_constant_res_val: 3.224e+01
# adaptive_constant_ics_val: 3.485e+01
# adaptive_constant_ics_t_val: 3.907e+01
# adaptive_constant_bcs1_val: 2.389e+01
# adaptive_constant_bcs2_val: 4.554e+01
# It: 39800, Loss: 1.806e+00, Loss_res: 9.390e-04,  Loss_bcs1: 8.237e-03,  Loss_bcs2: 6.645e-03,  loss_ics_u: 3.487e-02, Loss_ut_ics: 1.554e-03,, Time: 3.30
# min_grad: 2.798e-02
# update_res: 7.413e-01
# update_ics_ut: 6.902e-01
# update_ics_u_t: 8.819e-01
# update_bcs1: 9.740e-01
# update_bcs2: 9.623e-01
# adaptive_constant_res_val: 2.649e+01
# adaptive_constant_ics_val: 2.466e+01
# adaptive_constant_ics_t_val: 3.152e+01
# adaptive_constant_bcs1_val: 3.481e+01
# adaptive_constant_bcs2_val: 3.439e+01
# It: 39900, Loss: 1.531e+00, Loss_res: 5.313e-04,  Loss_bcs1: 9.103e-03,  Loss_bcs2: 4.566e-03,  loss_ics_u: 4.081e-02, Loss_ut_ics: 1.150e-03,, Time: 3.35
# min_grad: 3.121e-02
# update_res: 7.678e-01
# update_ics_ut: 8.740e-01
# update_ics_u_t: 9.687e-01
# update_bcs1: 8.030e-01
# update_bcs2: 7.347e-01
# adaptive_constant_res_val: 2.460e+01
# adaptive_constant_ics_val: 2.801e+01
# adaptive_constant_ics_t_val: 3.104e+01
# adaptive_constant_bcs1_val: 2.573e+01
# adaptive_constant_bcs2_val: 2.354e+01
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 1.554e+00, Loss_res: 5.757e-04,  Loss_bcs1: 9.117e-03,  Loss_bcs2: 6.574e-03,  loss_ics_u: 3.963e-02, Loss_ut_ics: 1.325e-03,, Time: 8.29
# min_grad: 2.292e-02
# update_res: 7.744e-01
# update_ics_ut: 8.021e-01
# update_ics_u_t: 8.931e-01
# update_bcs1: 8.959e-01
# update_bcs2: 8.223e-01
# adaptive_constant_res_val: 3.378e+01
# adaptive_constant_ics_val: 3.499e+01
# adaptive_constant_ics_t_val: 3.896e+01
# adaptive_constant_bcs1_val: 3.908e+01
# adaptive_constant_bcs2_val: 3.587e+01
# elapsed: 2.43e+03
# Relative L2 error_u: 4.36e-01
# Relative L2 error_r: 4.87e-02
# Save uv NN parameters successfully in %s ...checkpoints/Dec-22-2023_16-36-31-062743_M2
# Final loss total loss: 1.554487e+00
# Final loss loss_res: 5.757342e-04
# Final loss loss_bc1: 9.117362e-03
# Final loss loss_bc2: 6.574058e-03
# Final loss loss_ics_u: 3.962728e-02
# Final loss loss_ics_u_t: 1.324707e-03
# average lambda_bc : 2.7688e+01
# average lambda_ic : 2.7630e+01
# average lambda_res : 1.0
#
#
# Method: mini_batch
#
# average of time_list:2.4342e+03
# average of error_u_list:4.3636e-01
# average of error_r_list:4.8682e-02

# %%
elapsed = time.time() - start_time

# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
# Predictions

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

model.print('elapsed: {:.2e}'.format(elapsed))

model.print('Relative L2 error_u: {:.2e}'.format(error_u))
model.print('Relative L2 error_r: {:.2e}'.format(error_r))
model.plot_lambda()
# model.plot_grad()
model.save_NN()
model.plt_prediction( t , x , X_star , u_star , u_pred , r_star , r_pred)
model.print("average lambda_bc : " , np.average(model.adaptive_constant_bcs1_log))
model.print("average lambda_ic : " , np.average(model.adaptive_constant_ics_log))
model.print("average lambda_res : " , str(1.0))
# sess.close()  

# print('elapsed: {:.2e}'.format(elapsed))
# print('Relative L2 error_u: {:.2e}'.format(error_u))
# print('Relative L2 error_r: {:.2e}'.format(error_r))

time_list.append(elapsed)
error_u_list.append(error_u)
error_r_list.append(error_r)

model.print("\n\nMethod: ", mtd)
model.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
model.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
model.print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

result_dict[mtd] = [time_list ,error_u_list,error_r_list]
# scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)

###############################################################################################################################################
# Out:
# elapsed: 2.84e+03
# Relative L2 error_u: 4.24e-01
# Relative L2 error_r: 5.83e-02
# Save uv NN parameters successfully in %s ...checkpoints/Dec-22-2023_15-15-00-832488_M2
# Final loss total loss: 6.987906e-01
# Final loss loss_res: 1.131398e-03
# Final loss loss_bc1: 8.585554e-03
# Final loss loss_bc2: 5.224566e-03
# Final loss loss_ics_u: 3.143274e-02
# Final loss loss_ics_u_t: 1.262234e-03
# average lambda_bc : 1.5977e+01
# average lambda_ic : 1.6276e+01
# average lambda_res : 1.0
#
#
# Method: mini_batch
#
# average of time_list:2.8327e+03
# average of error_u_list:4.2402e-01
# average of error_r_list:5.8318e-02
