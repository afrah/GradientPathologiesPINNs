# %%
import tensorflow as tf
# from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 

import timeit

import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle

class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c , mode ,  sess):
        # Normalization 




        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        self.T = 1.0
        # weights
        self.adaptive_constant_bcs1_val = np.array(1.0)
        self.adaptive_constant_bcs2_val = np.array(1.0)
        self.adaptive_constant_ics_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)
        self.rate = 0.9

        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        # self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.adaptive_constant_bcs1_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs1_val.shape)
        self.adaptive_constant_bcs2_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs2_val.shape)
        self.adaptive_constant_ics_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_ics_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)
        

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_ics_us = self.loss_ics_u # + self.loss_ics_u_t
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        # self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss =  self.adaptive_constant_res_tf * self.loss_res + self.adaptive_constant_bcs1_tf * self.loss_bc1 + self.adaptive_constant_bcs2_tf * self.loss_bc2 + self.adaptive_constant_ics_tf * ( self.loss_ics_us)

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step, 1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_tensor_list = [self.loss ,  self.loss_res, self.loss_bc1 , self.loss_bc2 , self.loss_ics_us, self.loss_ics_u_t] 
        self.loss_list = ["total loss" , "loss_res"  , "loss_bc1", "loss_bc2", "loss_ics_u", "loss_ics_u_t"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_u_log = []
        self.loss_r_log = []

        # self.saver = tf.train.Saver()

         # # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs1_layers = self.generate_grad_dict()
        self.dict_gradients_bcs2_layers = self.generate_grad_dict()
        self.dict_gradients_ics_layers = self.generate_grad_dict()
        
        # Gradients Storage
        self.grad_res = []
        self.grad_ics = []
        self.grad_bcs1 = []
        self.grad_bcs2 = []

        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs1.append(tf.gradients(self.loss_bc1, self.weights[i])[0])
            self.grad_bcs2.append(tf.gradients(self.loss_bc2, self.weights[i])[0])
            self.grad_ics.append(tf.gradients(self.loss_ics_us, self.weights[i])[0])
          
        self.max_grad_res_list = []
        self.mean_grad_bcs1_list = []
        self.mean_grad_bcs2_list = []
        self.mean_grad_ics_list = []

        self.adaptive_constant_bcs1_log = []
        self.adaptive_constant_bcs2_log = []
        self.adaptive_constant_ics_log = []
        self.adaptive_constant_res_log = []

        self.mean_adaptive_constant_res_log = []
        self.mean_adaptive_constant_bcs1_log = []
        self.mean_adaptive_constant_bcs2_log = []
        self.mean_adaptive_constant_ics_log = []

        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.reduce_max(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs1_list.append(tf.reduce_max(tf.abs(self.grad_bcs1[i])))
            self.mean_grad_bcs2_list.append(tf.reduce_max(tf.abs(self.grad_bcs2[i])))
            self.mean_grad_ics_list.append(tf.reduce_max(tf.abs(self.grad_ics[i])))
        
        self.max_grad_res = tf.reduce_max(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs1 = tf.reduce_max(tf.stack(self.mean_grad_bcs1_list))
        self.mean_grad_bcs2 = tf.reduce_max(tf.stack(self.mean_grad_bcs2_list))
        self.mean_grad_ics = tf.reduce_max(tf.stack(self.mean_grad_ics_list))
        
        self.adaptive_constant_bcs1 = self.mean_grad_bcs1
        self.adaptive_constant_bcs2 = self.mean_grad_bcs2
        self.adaptive_constant_ics = self.mean_grad_ics
        self.adaptive_constant_res = self.max_grad_res 

         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev, dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss


    def lambda_balance(self  , term  ):
                histoy_mean =  np.mean(self.loss_history[term])
                m = 4 #len(self.loss_list)
                num = np.exp ( np.mean(self.loss_history[term] [-99::]) )#/(self.T * histoy_mean)) np.exp( )
                denum = 1 
                loss_list = [ "loss_res"  , "loss_bc1", "loss_bc2", "loss_ics_us"] 

                for  key in loss_list:
                    denum +=  np.exp( self.loss_history[key] [-99::] /  np.mean(self.loss_history[key]  [-99::]) )# /(self.T * histoy_mean))  np.exp(self.loss_history[key][-1] )
                return m * (num / denum)
    
    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(1 , nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1],
                       self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1],
                        self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                       self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], 
                       self.x_r_tf: X_res_batch[:, 1:2],
                       self.adaptive_constant_bcs1_tf: self.adaptive_constant_bcs1_val,
                       self.adaptive_constant_bcs2_tf: self.adaptive_constant_bcs2_val,
                       self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                       self.adaptive_constant_res_tf: self.adaptive_constant_res_val
                       }#self.lam_r_val}

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)
            
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])

            # Print
            if it % 1000 == 0:
                elapsed = timeit.default_timer() - start_time

                # loss_value = self.sess.run(self.loss, tf_dict)
                # loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                # loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                # loss_res_value = self.sess.run(self.loss_res, tf_dict)
                [loss ,  loss_res,    loss_bc1 , loss_bc2 , loss_ics_u, loss_ics_u_t]  =  batch_losses 
                self.print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs1: %.3e,  Loss_bcs2: %.3e,  loss_ics_u: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss, loss_res, loss_bc1, loss_bc2, loss_ics_u ,  loss_ics_u_t, elapsed))
                
                # Compute and Print adaptive weights during training
                    # Compute the adaptive constant
                adaptive_constant_res_val, adaptive_constant_bcs1_val, adaptive_constant_bcs2_val, adaptive_constant_ics_val = self.sess.run( [self.adaptive_constant_res,
                                                                                                                                               self.adaptive_constant_bcs1, 
                                                                                                                                               self.adaptive_constant_bcs2, 
                                                                                                                                               self.adaptive_constant_ics  ], tf_dict)
                # Print adaptive weights during training

                min_grad = np.min( [adaptive_constant_res_val, adaptive_constant_bcs1_val, adaptive_constant_bcs2_val, adaptive_constant_ics_val])

                update_res = self.lambda_balance( "loss_res"  )
                update_ics_u = self.lambda_balance( "loss_ics_us"  )
                update_bcs1 = self.lambda_balance( "loss_bc1"  )
                update_bcs2 = self.lambda_balance( "loss_bc2"  )
                
                self.adaptive_constant_res_val =  update_res / (min_grad + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_res_val
                self.adaptive_constant_ics_val =  update_ics_u  / (min_grad + 1e-12)#( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs1_val =  update_bcs1  / (min_grad + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val
                self.adaptive_constant_bcs2_val =  update_bcs2  / (min_grad + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val

                self.print('min_grad: {:.3e}'.format( min_grad))

                self.print('update_res: {:.3e}'.format( update_res))
                self.print('update_ics_u_t: {:.3e}'.format( update_ics_u))
                self.print('update_bcs1: {:.3e}'.format( update_bcs1))
                self.print('update_bcs2: {:.3e}'.format( update_bcs2))
                
                self.print('adaptive_constant_res_val: {:.3e}'.format( self.adaptive_constant_res_val))
                self.print('adaptive_constant_ics_val: {:.3e}'.format( self.adaptive_constant_ics_val))
                self.print('adaptive_constant_bcs1_val: {:.3e}'.format( self.adaptive_constant_bcs1_val))
                self.print('adaptive_constant_bcs2_val: {:.3e}'.format( self.adaptive_constant_bcs2_val))
                
                self.adaptive_constant_res_log.append(self.adaptive_constant_res_val)
                self.adaptive_constant_bcs1_log.append(self.adaptive_constant_bcs1_val)
                self.adaptive_constant_bcs2_log.append(self.adaptive_constant_bcs2_val)
                self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)

                max_grad_res , mean_grad_bcs1, mean_grad_bcs2, mean_grad_ics = self.sess.run( [ self.max_grad_res , self.mean_grad_bcs1, self.mean_grad_bcs2, self.mean_grad_ics  ], tf_dict)

                self.mean_adaptive_constant_res_log.append( max_grad_res)
                self.mean_adaptive_constant_bcs1_log.append( mean_grad_bcs1)
                self.mean_adaptive_constant_bcs2_log.append( mean_grad_bcs2)
                self.mean_adaptive_constant_ics_log.append( mean_grad_ics)


                sys.stdout.flush()
                start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()


    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size)
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1],
                    self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1],
                    self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                    self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1], 
                    self.x_r_tf: X_res_batch[:, 1:2],
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs1_val,
                    self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val
                    }#self.lam_r_val}
        
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 1000 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                # Compute and Print adaptive weights during training
                    # Compute the adaptive constant
                adaptive_constant_bcs_val, adaptive_constant_ics_val = self.sess.run( [self.adaptive_constant_bcs1, self.adaptive_constant_ics  ], tf_dict)
                # Print adaptive weights during training
                self.adaptive_constant_ics_val = adaptive_constant_ics_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs1_val = adaptive_constant_bcs_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs1_val


                print('lambda_u: {:.3e}'.format(self.adaptive_constant_bcs1_val))
                print('lambda_ut: {:.3e}'.format(self.adaptive_constant_ics_val))
                sys.stdout.flush()

                         
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   
     ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1  , grad_bc2 ,grad_ics  = self.sess.run([ self.grad_res[i],self.grad_bcs1[i],self.grad_bcs2[i],self.grad_ics[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs1_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())
            self.dict_gradients_bcs2_layers['layer_' + str(i + 1)].append(grad_bc2.flatten())
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs1_layers['layer_' + str(j + 1)][-1]
            gradients_bc2 = self.dict_gradients_bcs2_layers['layer_' + str(j + 1)][-1]
            gradients_ics = self.dict_gradients_ics_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')
            sns.distplot(gradients_bc2, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc2}}$')
            sns.distplot(gradients_ics, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{ics}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=4)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        #plt.show()
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , t , x , X_star , u_star , u_pred , r_star , r_pred):
        
        U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
        r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
        U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
        R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


        plt.figure(figsize=(18, 9))
        plt.subplot(2, 3, 1)
        plt.pcolor(t, x, U_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$x_1$')
        plt.ylabel('$x_2$')
        plt.title('Exact u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 2)
        plt.pcolor(t, x, U_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 3)
        plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()

        plt.subplot(2, 3, 4)
        plt.pcolor(t, x, r_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Exact r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 5)
        plt.pcolor(t, x, R_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 6)
        plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"))
        plt.close("all")

        
    
    def plot_lambda(self ):

        fontsize = 17
        fig, ax = plt.subplots()
        fig.set_size_inches([16,8])
        ax.semilogy(self.mean_adaptive_constant_bcs1_log, label=r'$\bar{\nabla_\theta {u_{bc1}}}$' , color = 'tab:green')
        ax.semilogy(self.mean_adaptive_constant_bcs2_log, label=r'$\bar{\nabla_\theta {u_{bc2}}}$' , color = 'tab:green')
        ax.semilogy(self.mean_adaptive_constant_ics_log, label=r'$\bar{\nabla_\theta {u_{ics}}}$' , color = 'tab:blue')
        ax.semilogy(self.mean_adaptive_constant_res_log, label=r'$Max{\nabla_\theta {u_{phy}}}$' , color = 'tab:red')
        ax.set_xlabel("epochs", fontsize=fontsize)
        ax.set_ylabel(r'$\bar{\nabla_\theta {u}}$', fontsize=fontsize)
        ax.tick_params(labelsize=fontsize)
        ax.legend(loc='center left', bbox_to_anchor=(-0.25, 0.5))

        ax2 = ax.twinx() 

        # fig, ax = plt.subplots()
        # fig.set_size_inches([15,8])
    
        ax2.semilogy(self.adaptive_constant_bcs1_log, label=r'$\bar{\lambda_{bc1}}$'  ,  linestyle='dashed' , color = 'tab:green') 
        ax2.semilogy(self.adaptive_constant_bcs2_log, label=r'$\bar{\lambda_{bc2}}$'  ,  linestyle='dashed' , color = 'tab:green') 
        ax2.semilogy(self.adaptive_constant_ics_log, label=r'$\bar{\lambda_{ics}}$' , linestyle='dashed'  , color = 'tab:blue')
        ax2.semilogy(self.adaptive_constant_res_log, label=r'$\bar{\lambda_{phy}}$' ,  linestyle='dashed' , color = 'tab:red')
        ax2.set_xlabel("epochs", fontsize=fontsize)
        ax2.set_ylabel(r'$\bar{\lambda}$', fontsize=fontsize)
        ax2.tick_params(labelsize=fontsize)
        ax2.legend(loc='center right', bbox_to_anchor=(1.2, 0.5))

        plt.tight_layout()

        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)

# %%
   #  
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        r_pred = model.predict_r(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))


    return [elapsed, error_u  ]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M2'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []

    for index in range(iterations):

        print("Epoch: ", str(index+1))

     # Create residual sampler

        # [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )
        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator ,  ics_sampler, bcs_sampler, res_sampler, c , mode , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

            model.print('elapsed: {:.2e}'.format(elapsed))

            model.print('Relative L2 error_u: {:.2e}'.format(error_u))
            model.print('Relative L2 error_r: {:.2e}'.format(error_r))
            model.plot_lambda()
            # model.plot_grad()
            model.save_NN()
            model.plt_prediction( t , x , X_star , u_star , u_pred , r_star , r_pred)
            model.print("average lambda_bc : " , np.average(model.adaptive_constant_bcs1_log))
            model.print("average lambda_ic : " , np.average(model.adaptive_constant_ics_log))
            model.print("average lambda_res : " , str(1.0))
            # sess.close()  

        # print('elapsed: {:.2e}'.format(elapsed))
        # print('Relative L2 error_u: {:.2e}'.format(error_u))
        # print('Relative L2 error_r: {:.2e}'.format(error_r))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    model.print("\n\nMethod: ", mtd)
    model.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    model.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    model.print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list,error_r_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_10361/4049125936.py:65: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10361/4049125936.py:66: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10361/4049125936.py:67: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10361/4049125936.py:67: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-22 16:25:28.118234: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-22 16:25:28.141635: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-22 16:25:28.142046: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x565192bbd990 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-22 16:25:28.142059: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-22 16:25:28.142568: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_10361/1187760618.py:127: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10361/1187760618.py:177: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10361/1187760618.py:179: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10361/1187760618.py:242: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1000, Loss: 1.936e-01, Loss_res: 2.648e-03,  Loss_bcs1: 3.470e-02,  Loss_bcs2: 1.097e-02,  loss_ics_u: 1.453e-01, Loss_ut_ics: 4.562e-03,, Time: 48.62
# min_grad: 5.603e-02
# update_res: 3.827e+00
# update_ics_u_t: 3.999e+00
# update_bcs1: 4.167e+00
# update_bcs2: 4.103e+00
# adaptive_constant_res_val: 6.830e+01
# adaptive_constant_ics_val: 7.136e+01
# adaptive_constant_bcs1_val: 7.437e+01
# adaptive_constant_bcs2_val: 7.322e+01
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 2000, Loss: 1.025e+01, Loss_res: 2.567e-02,  Loss_bcs1: 1.905e-02,  Loss_bcs2: 1.241e-02,  loss_ics_u: 8.647e-02, Loss_ut_ics: 7.337e-04,, Time: 41.41
# min_grad: 1.021e-01
# update_res: 4.884e+00
# update_ics_u_t: 2.837e+00
# update_bcs1: 3.814e+00
# update_bcs2: 5.130e+00
# adaptive_constant_res_val: 4.785e+01
# adaptive_constant_ics_val: 2.780e+01
# adaptive_constant_bcs1_val: 3.737e+01
# adaptive_constant_bcs2_val: 5.026e+01
# It: 3000, Loss: 4.504e+00, Loss_res: 1.410e-03,  Loss_bcs1: 1.566e-02,  Loss_bcs2: 7.837e-03,  loss_ics_u: 1.244e-01, Loss_ut_ics: 2.892e-04,, Time: 37.53
# min_grad: 4.445e-02
# update_res: 3.989e+00
# update_ics_u_t: 4.220e+00
# update_bcs1: 4.721e+00
# update_bcs2: 4.324e+00
# adaptive_constant_res_val: 8.975e+01
# adaptive_constant_ics_val: 9.493e+01
# adaptive_constant_bcs1_val: 1.062e+02
# adaptive_constant_bcs2_val: 9.727e+01
# It: 4000, Loss: 2.352e+01, Loss_res: 1.085e-01,  Loss_bcs1: 1.877e-02,  Loss_bcs2: 1.156e-02,  loss_ics_u: 1.124e-01, Loss_ut_ics: 9.287e-03,, Time: 37.64
# min_grad: 1.095e-01
# update_res: 7.277e+00
# update_ics_u_t: 3.621e+00
# update_bcs1: 2.447e+00
# update_bcs2: 4.196e+00
# adaptive_constant_res_val: 6.646e+01
# adaptive_constant_ics_val: 3.307e+01
# adaptive_constant_bcs1_val: 2.235e+01
# adaptive_constant_bcs2_val: 3.832e+01
# It: 5000, Loss: 4.119e+00, Loss_res: 3.600e-03,  Loss_bcs1: 2.299e-02,  Loss_bcs2: 5.298e-03,  loss_ics_u: 9.564e-02, Loss_ut_ics: 1.475e-04,, Time: 37.16
# min_grad: 3.778e-02
# update_res: 4.131e+00
# update_ics_u_t: 3.833e+00
# update_bcs1: 3.469e+00
# update_bcs2: 3.668e+00
# adaptive_constant_res_val: 1.094e+02
# adaptive_constant_ics_val: 1.015e+02
# adaptive_constant_bcs1_val: 9.182e+01
# adaptive_constant_bcs2_val: 9.710e+01
# It: 6000, Loss: 1.277e+01, Loss_res: 4.686e-03,  Loss_bcs1: 1.624e-02,  Loss_bcs2: 1.104e-02,  loss_ics_u: 9.557e-02, Loss_ut_ics: 1.004e-03,, Time: 35.91
# min_grad: 9.506e-02
# update_res: 1.466e+00
# update_ics_u_t: 3.672e+00
# update_bcs1: 4.327e+00
# update_bcs2: 3.587e+00
# adaptive_constant_res_val: 1.543e+01
# adaptive_constant_ics_val: 3.863e+01
# adaptive_constant_bcs1_val: 4.552e+01
# adaptive_constant_bcs2_val: 3.774e+01
# It: 7000, Loss: 4.181e+00, Loss_res: 1.670e-03,  Loss_bcs1: 8.757e-03,  Loss_bcs2: 1.042e-02,  loss_ics_u: 8.706e-02, Loss_ut_ics: 7.347e-04,, Time: 35.90
# min_grad: 4.984e-02
# update_res: 3.918e+00
# update_ics_u_t: 4.358e+00
# update_bcs1: 3.374e+00
# update_bcs2: 2.935e+00
# adaptive_constant_res_val: 7.863e+01
# adaptive_constant_ics_val: 8.746e+01
# adaptive_constant_bcs1_val: 6.769e+01
# adaptive_constant_bcs2_val: 5.890e+01
# It: 8000, Loss: 1.105e+01, Loss_res: 1.650e-03,  Loss_bcs1: 4.058e-02,  Loss_bcs2: 1.554e-02,  loss_ics_u: 8.297e-02, Loss_ut_ics: 1.343e-03,, Time: 36.69
# min_grad: 6.498e-02
# update_res: 3.942e+00
# update_ics_u_t: 3.497e+00
# update_bcs1: 6.093e+00
# update_bcs2: 5.215e+00
# adaptive_constant_res_val: 6.067e+01
# adaptive_constant_ics_val: 5.382e+01
# adaptive_constant_bcs1_val: 9.377e+01
# adaptive_constant_bcs2_val: 8.026e+01
# It: 9000, Loss: 7.884e+00, Loss_res: 1.966e-03,  Loss_bcs1: 1.615e-02,  Loss_bcs2: 8.635e-03,  loss_ics_u: 1.033e-01, Loss_ut_ics: 9.388e-04,, Time: 35.37
# min_grad: 8.075e-02
# update_res: 3.947e+00
# update_ics_u_t: 4.314e+00
# update_bcs1: 4.461e+00
# update_bcs2: 3.479e+00
# adaptive_constant_res_val: 4.888e+01
# adaptive_constant_ics_val: 5.342e+01
# adaptive_constant_bcs1_val: 5.525e+01
# adaptive_constant_bcs2_val: 4.309e+01
# It: 10000, Loss: 6.841e+00, Loss_res: 2.903e-02,  Loss_bcs1: 1.117e-02,  Loss_bcs2: 8.692e-03,  loss_ics_u: 8.291e-02, Loss_ut_ics: 1.006e-03,, Time: 35.02
# min_grad: 4.379e-02
# update_res: 2.564e+01
# update_ics_u_t: 4.224e+00
# update_bcs1: 3.279e+00
# update_bcs2: 4.612e+00
# adaptive_constant_res_val: 5.856e+02
# adaptive_constant_ics_val: 9.646e+01
# adaptive_constant_bcs1_val: 7.489e+01
# adaptive_constant_bcs2_val: 1.053e+02
# It: 11000, Loss: 1.694e+01, Loss_res: 9.601e-04,  Loss_bcs1: 4.926e-02,  Loss_bcs2: 6.648e-03,  loss_ics_u: 1.243e-01, Loss_ut_ics: 1.399e-03,, Time: 34.84
# min_grad: 8.876e-02
# update_res: 3.959e+00
# update_ics_u_t: 4.977e+00
# update_bcs1: 6.713e+00
# update_bcs2: 3.989e+00
# adaptive_constant_res_val: 4.460e+01
# adaptive_constant_ics_val: 5.608e+01
# adaptive_constant_bcs1_val: 7.563e+01
# adaptive_constant_bcs2_val: 4.494e+01
# It: 12000, Loss: 7.282e+00, Loss_res: 2.694e-03,  Loss_bcs1: 1.742e-02,  Loss_bcs2: 2.258e-02,  loss_ics_u: 8.611e-02, Loss_ut_ics: 4.447e-04,, Time: 34.55
# min_grad: 9.191e-02
# update_res: 4.009e+00
# update_ics_u_t: 4.052e+00
# update_bcs1: 4.048e+00
# update_bcs2: 5.227e+00
# adaptive_constant_res_val: 4.361e+01
# adaptive_constant_ics_val: 4.408e+01
# adaptive_constant_bcs1_val: 4.404e+01
# adaptive_constant_bcs2_val: 5.687e+01
# It: 13000, Loss: 6.295e+00, Loss_res: 1.719e-03,  Loss_bcs1: 1.977e-02,  Loss_bcs2: 1.558e-02,  loss_ics_u: 1.013e-01, Loss_ut_ics: 4.414e-04,, Time: 35.27
# min_grad: 8.406e-02
# update_res: 3.921e+00
# update_ics_u_t: 3.762e+00
# update_bcs1: 4.994e+00
# update_bcs2: 3.753e+00
# adaptive_constant_res_val: 4.664e+01
# adaptive_constant_ics_val: 4.475e+01
# adaptive_constant_bcs1_val: 5.940e+01
# adaptive_constant_bcs2_val: 4.464e+01
# It: 14000, Loss: 5.069e+00, Loss_res: 2.155e-03,  Loss_bcs1: 1.414e-02,  Loss_bcs2: 2.235e-02,  loss_ics_u: 6.996e-02, Loss_ut_ics: 1.442e-03,, Time: 35.98
# min_grad: 1.408e-01
# update_res: 4.075e+00
# update_ics_u_t: 3.185e+00
# update_bcs1: 4.896e+00
# update_bcs2: 3.960e+00
# adaptive_constant_res_val: 2.894e+01
# adaptive_constant_ics_val: 2.262e+01
# adaptive_constant_bcs1_val: 3.477e+01
# adaptive_constant_bcs2_val: 2.812e+01
# It: 15000, Loss: 2.948e+00, Loss_res: 2.939e-03,  Loss_bcs1: 1.012e-02,  Loss_bcs2: 1.703e-02,  loss_ics_u: 8.985e-02, Loss_ut_ics: 4.133e-04,, Time: 35.77
# min_grad: 7.063e-02
# update_res: 4.144e+00
# update_ics_u_t: 5.596e+00
# update_bcs1: 4.626e+00
# update_bcs2: 5.158e+00
# adaptive_constant_res_val: 5.868e+01
# adaptive_constant_ics_val: 7.923e+01
# adaptive_constant_bcs1_val: 6.550e+01
# adaptive_constant_bcs2_val: 7.303e+01
# It: 16000, Loss: 8.515e+00, Loss_res: 2.131e-03,  Loss_bcs1: 1.592e-02,  Loss_bcs2: 1.487e-02,  loss_ics_u: 7.902e-02, Loss_ut_ics: 1.881e-04,, Time: 36.65
# min_grad: 7.650e-02
# update_res: 4.088e+00
# update_ics_u_t: 3.871e+00
# update_bcs1: 3.940e+00
# update_bcs2: 3.273e+00
# adaptive_constant_res_val: 5.344e+01
# adaptive_constant_ics_val: 5.060e+01
# adaptive_constant_bcs1_val: 5.150e+01
# adaptive_constant_bcs2_val: 4.278e+01
# It: 17000, Loss: 5.130e+00, Loss_res: 8.848e-03,  Loss_bcs1: 1.134e-02,  Loss_bcs2: 1.414e-02,  loss_ics_u: 6.854e-02, Loss_ut_ics: 1.280e-03,, Time: 37.09
# min_grad: 6.757e-02
# update_res: 6.078e+00
# update_ics_u_t: 4.735e+00
# update_bcs1: 4.145e+00
# update_bcs2: 5.261e+00
# adaptive_constant_res_val: 8.995e+01
# adaptive_constant_ics_val: 7.007e+01
# adaptive_constant_bcs1_val: 6.134e+01
# adaptive_constant_bcs2_val: 7.786e+01
# It: 18000, Loss: 6.475e+00, Loss_res: 1.117e-03,  Loss_bcs1: 1.302e-02,  Loss_bcs2: 8.386e-03,  loss_ics_u: 7.026e-02, Loss_ut_ics: 5.302e-04,, Time: 39.45
# min_grad: 3.892e-02
# update_res: 4.042e+00
# update_ics_u_t: 3.906e+00
# update_bcs1: 3.273e+00
# update_bcs2: 3.230e+00
# adaptive_constant_res_val: 1.039e+02
# adaptive_constant_ics_val: 1.004e+02
# adaptive_constant_bcs1_val: 8.411e+01
# adaptive_constant_bcs2_val: 8.299e+01
# It: 19000, Loss: 8.556e+00, Loss_res: 2.060e-03,  Loss_bcs1: 1.296e-02,  Loss_bcs2: 8.782e-03,  loss_ics_u: 6.499e-02, Loss_ut_ics: 8.869e-04,, Time: 62.67
# min_grad: 6.504e-02
# update_res: 3.853e+00
# update_ics_u_t: 4.060e+00
# update_bcs1: 3.675e+00
# update_bcs2: 3.961e+00
# adaptive_constant_res_val: 5.924e+01
# adaptive_constant_ics_val: 6.242e+01
# adaptive_constant_bcs1_val: 5.651e+01
# adaptive_constant_bcs2_val: 6.089e+01
# It: 20000, Loss: 4.636e+00, Loss_res: 2.001e-03,  Loss_bcs1: 9.511e-03,  Loss_bcs2: 7.369e-03,  loss_ics_u: 5.657e-02, Loss_ut_ics: 7.252e-04,, Time: 73.86
# min_grad: 4.159e-02
# update_res: 3.433e+00
# update_ics_u_t: 3.819e+00
# update_bcs1: 3.662e+00
# update_bcs2: 3.003e+00
# adaptive_constant_res_val: 8.255e+01
# adaptive_constant_ics_val: 9.181e+01
# adaptive_constant_bcs1_val: 8.806e+01
# adaptive_constant_bcs2_val: 7.221e+01
# It: 21000, Loss: 6.266e+00, Loss_res: 1.653e-03,  Loss_bcs1: 6.495e-03,  Loss_bcs2: 7.830e-03,  loss_ics_u: 5.437e-02, Loss_ut_ics: 2.739e-04,, Time: 73.41
# min_grad: 5.776e-02
# update_res: 4.395e+00
# update_ics_u_t: 4.454e+00
# update_bcs1: 4.615e+00
# update_bcs2: 3.135e+00
# adaptive_constant_res_val: 7.610e+01
# adaptive_constant_ics_val: 7.712e+01
# adaptive_constant_bcs1_val: 7.990e+01
# adaptive_constant_bcs2_val: 5.428e+01
# It: 22000, Loss: 5.051e+00, Loss_res: 3.384e-03,  Loss_bcs1: 9.260e-03,  Loss_bcs2: 6.132e-03,  loss_ics_u: 4.825e-02, Loss_ut_ics: 1.063e-03,, Time: 72.69
# min_grad: 2.986e-02
# update_res: 4.746e+00
# update_ics_u_t: 3.704e+00
# update_bcs1: 5.168e+00
# update_bcs2: 2.901e+00
# adaptive_constant_res_val: 1.589e+02
# adaptive_constant_ics_val: 1.241e+02
# adaptive_constant_bcs1_val: 1.731e+02
# adaptive_constant_bcs2_val: 9.714e+01
# It: 23000, Loss: 6.902e+00, Loss_res: 8.580e-04,  Loss_bcs1: 4.738e-03,  Loss_bcs2: 4.778e-03,  loss_ics_u: 4.419e-02, Loss_ut_ics: 2.556e-04,, Time: 70.43
# min_grad: 2.891e-02
# update_res: 3.878e+00
# update_ics_u_t: 3.882e+00
# update_bcs1: 3.646e+00
# update_bcs2: 2.826e+00
# adaptive_constant_res_val: 1.341e+02
# adaptive_constant_ics_val: 1.343e+02
# adaptive_constant_bcs1_val: 1.261e+02
# adaptive_constant_bcs2_val: 9.778e+01
# It: 24000, Loss: 7.911e+00, Loss_res: 2.029e-03,  Loss_bcs1: 5.134e-03,  Loss_bcs2: 6.771e-03,  loss_ics_u: 4.713e-02, Loss_ut_ics: 1.880e-03,, Time: 71.09
# min_grad: 5.398e-02
# update_res: 3.795e+00
# update_ics_u_t: 3.922e+00
# update_bcs1: 4.025e+00
# update_bcs2: 2.706e+00
# adaptive_constant_res_val: 7.031e+01
# adaptive_constant_ics_val: 7.266e+01
# adaptive_constant_bcs1_val: 7.458e+01
# adaptive_constant_bcs2_val: 5.014e+01
# It: 25000, Loss: 3.558e+00, Loss_res: 1.306e-03,  Loss_bcs1: 5.224e-03,  Loss_bcs2: 5.834e-03,  loss_ics_u: 3.832e-02, Loss_ut_ics: 6.378e-04,, Time: 69.82
# min_grad: 2.105e-02
# update_res: 3.741e+00
# update_ics_u_t: 3.463e+00
# update_bcs1: 4.008e+00
# update_bcs2: 4.402e+00
# adaptive_constant_res_val: 1.777e+02
# adaptive_constant_ics_val: 1.645e+02
# adaptive_constant_bcs1_val: 1.904e+02
# adaptive_constant_bcs2_val: 2.091e+02
# It: 26000, Loss: 9.114e+00, Loss_res: 2.832e-03,  Loss_bcs1: 4.450e-03,  Loss_bcs2: 6.754e-03,  loss_ics_u: 3.862e-02, Loss_ut_ics: 5.309e-04,, Time: 70.36
# min_grad: 3.087e-02
# update_res: 4.179e+00
# update_ics_u_t: 3.839e+00
# update_bcs1: 3.828e+00
# update_bcs2: 4.014e+00
# adaptive_constant_res_val: 1.354e+02
# adaptive_constant_ics_val: 1.243e+02
# adaptive_constant_bcs1_val: 1.240e+02
# adaptive_constant_bcs2_val: 1.300e+02
# It: 27000, Loss: 6.842e+00, Loss_res: 1.048e-03,  Loss_bcs1: 7.591e-03,  Loss_bcs2: 6.315e-03,  loss_ics_u: 3.971e-02, Loss_ut_ics: 4.711e-04,, Time: 70.25
# min_grad: 5.002e-02
# update_res: 4.026e+00
# update_ics_u_t: 4.268e+00
# update_bcs1: 3.512e+00
# update_bcs2: 4.611e+00
# adaptive_constant_res_val: 8.050e+01
# adaptive_constant_ics_val: 8.534e+01
# adaptive_constant_bcs1_val: 7.022e+01
# adaptive_constant_bcs2_val: 9.220e+01
# It: 28000, Loss: 3.658e+00, Loss_res: 1.209e-03,  Loss_bcs1: 5.308e-03,  Loss_bcs2: 6.846e-03,  loss_ics_u: 2.996e-02, Loss_ut_ics: 5.595e-04,, Time: 70.64
# min_grad: 3.497e-02
# update_res: 4.506e+00
# update_ics_u_t: 3.574e+00
# update_bcs1: 5.140e+00
# update_bcs2: 3.866e+00
# adaptive_constant_res_val: 1.289e+02
# adaptive_constant_ics_val: 1.022e+02
# adaptive_constant_bcs1_val: 1.470e+02
# adaptive_constant_bcs2_val: 1.106e+02
# It: 29000, Loss: 4.868e+00, Loss_res: 1.959e-03,  Loss_bcs1: 4.046e-03,  Loss_bcs2: 6.791e-03,  loss_ics_u: 3.200e-02, Loss_ut_ics: 4.676e-04,, Time: 70.32
# min_grad: 4.749e-02
# update_res: 3.675e+00
# update_ics_u_t: 3.738e+00
# update_bcs1: 3.816e+00
# update_bcs2: 4.464e+00
# adaptive_constant_res_val: 7.738e+01
# adaptive_constant_ics_val: 7.870e+01
# adaptive_constant_bcs1_val: 8.034e+01
# adaptive_constant_bcs2_val: 9.398e+01
# It: 30000, Loss: 3.225e+00, Loss_res: 1.425e-03,  Loss_bcs1: 3.782e-03,  Loss_bcs2: 6.489e-03,  loss_ics_u: 2.796e-02, Loss_ut_ics: 6.487e-04,, Time: 70.11
# min_grad: 2.813e-02
# update_res: 4.170e+00
# update_ics_u_t: 3.359e+00
# update_bcs1: 3.485e+00
# update_bcs2: 3.367e+00
# adaptive_constant_res_val: 1.482e+02
# adaptive_constant_ics_val: 1.194e+02
# adaptive_constant_bcs1_val: 1.239e+02
# adaptive_constant_bcs2_val: 1.197e+02
# It: 31000, Loss: 4.616e+00, Loss_res: 7.268e-04,  Loss_bcs1: 4.613e-03,  Loss_bcs2: 5.457e-03,  loss_ics_u: 2.750e-02, Loss_ut_ics: 3.444e-04,, Time: 73.02
# min_grad: 3.278e-02
# update_res: 3.958e+00
# update_ics_u_t: 4.163e+00
# update_bcs1: 3.393e+00
# update_bcs2: 2.635e+00
# adaptive_constant_res_val: 1.207e+02
# adaptive_constant_ics_val: 1.270e+02
# adaptive_constant_bcs1_val: 1.035e+02
# adaptive_constant_bcs2_val: 8.036e+01
# It: 32000, Loss: 4.742e+00, Loss_res: 1.099e-03,  Loss_bcs1: 5.714e-03,  Loss_bcs2: 8.269e-03,  loss_ics_u: 2.641e-02, Loss_ut_ics: 3.510e-04,, Time: 73.69
# min_grad: 3.263e-02
# update_res: 3.892e+00
# update_ics_u_t: 3.729e+00
# update_bcs1: 3.852e+00
# update_bcs2: 4.146e+00
# adaptive_constant_res_val: 1.193e+02
# adaptive_constant_ics_val: 1.143e+02
# adaptive_constant_bcs1_val: 1.181e+02
# adaptive_constant_bcs2_val: 1.271e+02
# It: 33000, Loss: 4.534e+00, Loss_res: 1.346e-03,  Loss_bcs1: 4.146e-03,  Loss_bcs2: 5.950e-03,  loss_ics_u: 2.737e-02, Loss_ut_ics: 5.804e-04,, Time: 71.28
# min_grad: 2.793e-02
# update_res: 3.839e+00
# update_ics_u_t: 4.442e+00
# update_bcs1: 3.182e+00
# update_bcs2: 4.056e+00
# adaptive_constant_res_val: 1.374e+02
# adaptive_constant_ics_val: 1.590e+02
# adaptive_constant_bcs1_val: 1.139e+02
# adaptive_constant_bcs2_val: 1.452e+02
# It: 34000, Loss: 5.193e+00, Loss_res: 3.396e-03,  Loss_bcs1: 5.000e-03,  Loss_bcs2: 9.428e-03,  loss_ics_u: 1.753e-02, Loss_ut_ics: 3.430e-04,, Time: 70.36
# min_grad: 3.060e-02
# update_res: 4.047e+00
# update_ics_u_t: 3.747e+00
# update_bcs1: 3.841e+00
# update_bcs2: 4.940e+00
# adaptive_constant_res_val: 1.323e+02
# adaptive_constant_ics_val: 1.225e+02
# adaptive_constant_bcs1_val: 1.255e+02
# adaptive_constant_bcs2_val: 1.614e+02
# It: 35000, Loss: 4.359e+00, Loss_res: 1.714e-03,  Loss_bcs1: 3.962e-03,  Loss_bcs2: 6.650e-03,  loss_ics_u: 2.092e-02, Loss_ut_ics: 6.416e-04,, Time: 67.17
# min_grad: 1.879e-02
# update_res: 4.318e+00
# update_ics_u_t: 4.108e+00
# update_bcs1: 4.075e+00
# update_bcs2: 3.232e+00
# adaptive_constant_res_val: 2.297e+02
# adaptive_constant_ics_val: 2.186e+02
# adaptive_constant_bcs1_val: 2.168e+02
# adaptive_constant_bcs2_val: 1.720e+02
# It: 36000, Loss: 6.760e+00, Loss_res: 2.246e-03,  Loss_bcs1: 4.357e-03,  Loss_bcs2: 7.679e-03,  loss_ics_u: 1.821e-02, Loss_ut_ics: 2.751e-04,, Time: 67.62
# min_grad: 2.093e-02
# update_res: 4.903e+00
# update_ics_u_t: 3.829e+00
# update_bcs1: 3.752e+00
# update_bcs2: 4.101e+00
# adaptive_constant_res_val: 2.342e+02
# adaptive_constant_ics_val: 1.829e+02
# adaptive_constant_bcs1_val: 1.792e+02
# adaptive_constant_bcs2_val: 1.960e+02
# It: 37000, Loss: 5.830e+00, Loss_res: 1.287e-03,  Loss_bcs1: 2.763e-03,  Loss_bcs2: 6.985e-03,  loss_ics_u: 2.003e-02, Loss_ut_ics: 2.753e-04,, Time: 75.74
# min_grad: 1.839e-02
# update_res: 4.007e+00
# update_ics_u_t: 4.295e+00
# update_bcs1: 3.995e+00
# update_bcs2: 3.540e+00
# adaptive_constant_res_val: 2.179e+02
# adaptive_constant_ics_val: 2.335e+02
# adaptive_constant_bcs1_val: 2.172e+02
# adaptive_constant_bcs2_val: 1.925e+02
# It: 38000, Loss: 6.642e+00, Loss_res: 1.290e-03,  Loss_bcs1: 3.372e-03,  Loss_bcs2: 6.587e-03,  loss_ics_u: 1.867e-02, Loss_ut_ics: 6.334e-04,, Time: 80.11
# min_grad: 3.022e-02
# update_res: 4.526e+00
# update_ics_u_t: 4.122e+00
# update_bcs1: 3.435e+00
# update_bcs2: 2.818e+00
# adaptive_constant_res_val: 1.498e+02
# adaptive_constant_ics_val: 1.364e+02
# adaptive_constant_bcs1_val: 1.137e+02
# adaptive_constant_bcs2_val: 9.324e+01
# It: 39000, Loss: 3.412e+00, Loss_res: 1.195e-03,  Loss_bcs1: 4.779e-03,  Loss_bcs2: 5.383e-03,  loss_ics_u: 1.604e-02, Loss_ut_ics: 3.513e-04,, Time: 75.92
# min_grad: 2.721e-02
# update_res: 3.980e+00
# update_ics_u_t: 3.968e+00
# update_bcs1: 4.055e+00
# update_bcs2: 2.513e+00
# adaptive_constant_res_val: 1.463e+02
# adaptive_constant_ics_val: 1.458e+02
# adaptive_constant_bcs1_val: 1.490e+02
# adaptive_constant_bcs2_val: 9.234e+01
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 3.698e+00, Loss_res: 8.301e-04,  Loss_bcs1: 4.330e-03,  Loss_bcs2: 9.016e-03,  loss_ics_u: 1.439e-02, Loss_ut_ics: 5.501e-04,, Time: 83.20
# min_grad: 2.652e-02
# update_res: 3.644e+00
# update_ics_u_t: 3.683e+00
# update_bcs1: 4.106e+00
# update_bcs2: 4.968e+00
# adaptive_constant_res_val: 1.374e+02
# adaptive_constant_ics_val: 1.389e+02
# adaptive_constant_bcs1_val: 1.548e+02
# adaptive_constant_bcs2_val: 1.873e+02
# elapsed: 2.26e+03
# Relative L2 error_u: 3.73e-01
# Relative L2 error_r: 6.28e-02
# Save uv NN parameters successfully in %s ...checkpoints/Dec-22-2023_16-25-28-142854_M2
# Final loss total loss: 3.698004e+00
# Final loss loss_res: 8.301337e-04
# Final loss loss_bc1: 4.329696e-03
# Final loss loss_bc2: 9.015814e-03
# Final loss loss_ics_u: 1.439397e-02
# Final loss loss_ics_u_t: 5.501033e-04
# average lambda_bc : 9.9283e+01
# average lambda_ic : 9.8548e+01
# average lambda_res : 1.0
#
#
# Method: mini_batch
#
# average of time_list:2.2646e+03
# average of error_u_list:3.7320e-01
# average of error_r_list:6.2769e-02

# %%
elapsed = time.time() - start_time

# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
# Predictions

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

model.print('elapsed: {:.2e}'.format(elapsed))

model.print('Relative L2 error_u: {:.2e}'.format(error_u))
model.print('Relative L2 error_r: {:.2e}'.format(error_r))
model.plot_lambda()
# model.plot_grad()
model.save_NN()
model.plt_prediction( t , x , X_star , u_star , u_pred , r_star , r_pred)
model.print("average lambda_bc : " , np.average(model.adaptive_constant_bcs1_log))
model.print("average lambda_ic : " , np.average(model.adaptive_constant_ics_log))
model.print("average lambda_res : " , str(1.0))
# sess.close()  

# print('elapsed: {:.2e}'.format(elapsed))
# print('Relative L2 error_u: {:.2e}'.format(error_u))
# print('Relative L2 error_r: {:.2e}'.format(error_r))

time_list.append(elapsed)
error_u_list.append(error_u)
error_r_list.append(error_r)

model.print("\n\nMethod: ", mtd)
model.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
model.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
model.print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

result_dict[mtd] = [time_list ,error_u_list,error_r_list]
# scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)

###############################################################################################################################################
# Out:
# elapsed: 6.63e+02
# Relative L2 error_u: 6.00e-01
# Relative L2 error_r: 6.55e-02
# Save uv NN parameters successfully in %s ...checkpoints/Dec-22-2023_04-51-31-118194_M2
# Final loss total loss: 1.378906e+03
# Final loss loss_res: 1.345077e-03
# Final loss loss_bc1: 1.812455e-02
# Final loss loss_bc2: 1.195523e-02
# Final loss loss_ics_u: 1.028388e-01
# Final loss loss_ics_u_t: 1.613473e-03
# average lambda_bc : 9.6451e+03
# average lambda_ic : 9.1887e+03
# average lambda_res : 1.0
#
#
# Method: mini_batch
#
# average of time_list:6.6284e+02
# average of error_u_list:6.0045e-01
# average of error_r_list:6.5523e-02
