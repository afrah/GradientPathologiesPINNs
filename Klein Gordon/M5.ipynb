# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import griddata
# from Klein_Gordon_model_tf import Sampler, Klein_Gordon
import timeit
import os
os.environ["KMP_WARNINGS"] = "FALSE" 

import scipy
import scipy.io
import time


import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle
def u(x):
    """
    :param x: x = (t, x)
    """
    return x[:, 1:2] * np.cos(5 * np.pi * x[:, 0:1]) + (x[:, 0:1] * x[:, 1:2])**3

def u_tt(x):
    return - 25 * np.pi**2 * x[:, 1:2] * np.cos(5 * np.pi * x[:, 0:1]) + 6 * x[:,0:1] * x[:,1:2]**3

def u_xx(x):
    return np.zeros((x.shape[0], 1)) +  6 * x[:,1:2] * x[:,0:1]**3

def f(x, alpha, beta, gamma, k):
    return u_tt(x) + alpha * u_xx(x) + beta * u(x) + gamma * u(x)**k

def operator(u, t, x, alpha, beta, gamma, k,  sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt + alpha * u_xx + beta * u + gamma * u**k
    return residual

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Klein_Gordon:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess):
            # mode = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess)



        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Klein_Gordon constant
        self.alpha = tf.constant(alpha, dtype=tf.float32)
        self.beta = tf.constant(beta, dtype=tf.float32)
        self.gamma = tf.constant(gamma, dtype=tf.float32)
        self.k = tf.constant(k, dtype=tf.float32)


        # Record stiff ratio
        # self.stiff_ratio = stiff_ratio

        # Adaptive re-weighting constant
        self.rate = 0.9
        self.adaptive_constant_ics_val = np.array(1.0)
        self.adaptive_constant_bcs_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)

        # if model in ['M3', 'M4']:
        #     # Initialize encoder weights and biases
        #     self.encoder_weights_1 = self.xavier_init([2, layers[1]])
        #     self.encoder_biases_1 = self.xavier_init([1, layers[1]])

        #     self.encoder_weights_2 = self.xavier_init([2, layers[1]])
        #     self.encoder_biases_2 = self.xavier_init([1, layers[1]])

        # Define Tensorflow session
        self.sess = sess #tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.adaptive_constant_ics_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_ics_val.shape)
        self.adaptive_constant_bcs_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)

        # Boundary loss and Initial loss
        self.loss_ic_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ic_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred - self.u_bc1_tf))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred - self.u_bc2_tf))

        self.loss_bcs =  (self.loss_bc1 + self.loss_bc2)
        self.loss_ics =  (self.loss_ic_u + self.loss_ic_u_t)
        self.loss_u = self.loss_bcs + self.loss_ics

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred - self.r_tf))

        # Total loss
        self.loss = self.adaptive_constant_res_tf * self.loss_res + self.adaptive_constant_bcs_tf * (self.loss_bc1 + self.loss_bc2) + self.adaptive_constant_ics_tf * (self.loss_ic_u + self.loss_ic_u_t)

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)


        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bcs , self.loss_ics ] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs", "loss_ics"] 
        
        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_u_log = []
        self.loss_r_log = []
        # self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs_layers = self.generate_grad_dict()
        self.dict_gradients_ics_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_ics = []
        self.grad_bcs = []

        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])
            self.grad_ics.append(tf.gradients(self.loss_ics, self.weights[i])[0])

        # Store the adaptive constant
  
        self.adaptive_constant_bcs_log = []
        self.adaptive_constant_ics_log = []
        self.adaptive_constant_res_log = []

        self.mean_adaptive_constant_res_log = []
        self.mean_adaptive_constant_bcs_log = []
        self.mean_adaptive_constant_ics_log = []
        # Compute the adaptive constant
        
        self.max_grad_res_list = []
        self.mean_grad_bcs_list = []
        self.mean_grad_ics_list = []

        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.reduce_max(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs_list.append(tf.reduce_mean(tf.abs(self.grad_bcs[i])))
            self.mean_grad_ics_list.append(tf.reduce_mean(tf.abs(self.grad_ics[i])))
        
        self.max_grad_res = tf.reduce_max(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs = tf.reduce_mean(tf.stack(self.mean_grad_bcs_list))
        self.mean_grad_ics = tf.reduce_mean(tf.stack(self.mean_grad_ics_list))
        
        self.adaptive_constant_bcs = self.max_grad_res / self.mean_grad_bcs
        self.adaptive_constant_ics = self.max_grad_res / self.mean_grad_ics
        self.adaptive_constant_res = self.max_grad_res

        # # Stiff Ratio
        # if self.stiff_ratio:
        #     self.Hessian, self.Hessian_ics, self.Hessian_bcs, self.Hessian_res = self.get_H_op()
        #     self.eigenvalues, _ = tf.linalg.eigh(self.Hessian)
        #     self.eigenvalues_ics, _ = tf.linalg.eigh(self.Hessian_ics)
        #     self.eigenvalues_bcs, _ = tf.linalg.eigh(self.Hessian_bcs)
        #     self.eigenvalues_res, _ = tf.linalg.eigh(self.Hessian_res)

        #     self.eigenvalue_log = []
        #     self.eigenvalue_ics_log = []
        #     self.eigenvalue_bcs_log = []
        #     self.eigenvalue_res_log = []

        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Create dictionary to store gradients
    def generate_grad_dict(self, layers):
        num = len(layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Save gradients
    def save_gradients(self, tf_dict):
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_ics_value , grad_bcs_value, grad_res_value= self.sess.run([self.grad_ics[i],
                                                                            self.grad_bcs[i],
                                                                            self.grad_res[i]],
                                                                            feed_dict=tf_dict)

            # save gradients of loss_res and loss_bcs
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics_value.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bcs_value.flatten())
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res_value.flatten())
        return None

    # Compute the Hessian
    def flatten(self, vectors):
        return tf.concat([tf.reshape(v, [-1]) for v in vectors], axis=0)

    def get_Hv(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_ics(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_ics, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_bcs(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_bcs, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_res(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_res,
                                                   self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod,
                                          self.weights))
        return Hv_op

    def get_H_op(self):
        self.P = self.flatten(self.weights).get_shape().as_list()[0]
        H = tf.map_fn(self.get_Hv, tf.eye(self.P, self.P),
                      dtype='float32')
        H_ics = tf.map_fn(self.get_Hv_ics, tf.eye(self.P, self.P),
                          dtype='float32')
        H_bcs = tf.map_fn(self.get_Hv_bcs, tf.eye(self.P, self.P),
                          dtype='float32')
        H_res = tf.map_fn(self.get_Hv_res, tf.eye(self.P, self.P),
                          dtype='float32')

        return H, H_ics, H_bcs, H_res

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # if self.model in ['M3', 'M4']:
    #     num_layers = len(self.layers)
    #     encoder_1 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_1), self.encoder_biases_1))
    #     encoder_2 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_2), self.encoder_biases_2))

    #     for l in range(0, num_layers - 2):
    #         W = self.weights[l]
    #         b = self.biases[l]
    #         H = tf.math.multiply(tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_1) + \
    #             tf.math.multiply(1 - tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_2)

    #     W = self.weights[-1]
    #     b = self.biases[-1]
    #     H = tf.add(tf.matmul(H, W), b)
    #     return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1))
        return u

    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,  self.alpha, self.beta, self.gamma, self.k, self.sigma_t, self.sigma_x)
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
################################################################################################################

    def train(self, nIter=10000):

        start_time = timeit.default_timer()
        batch_size = 500
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size)
        X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
        X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)

        batch_size = 5000

        # Fetch residual mini-batch
        X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.u_bc1_tf: u_bc1_batch,
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.u_bc2_tf: u_bc2_batch,
                    self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                    self.r_tf: f_res_batch,
                    self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val}

        # Run the Tensorflow session to minimize the loss

        for it in range(nIter):
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_u, self.loss_res], tf_dict)

                # Compute and Print adaptive weights during training
                # Compute the adaptive constant
                adaptive_constant_ics_val, adaptive_constant_bcs_val = self.sess.run( [self.adaptive_constant_ics, self.adaptive_constant_bcs], tf_dict)
                # Print adaptive weights during training
                self.adaptive_constant_ics_val = adaptive_constant_ics_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs_val = adaptive_constant_bcs_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val

                # # Store loss and adaptive weights
                # self.loss_u_log.append(loss_u_value)
                # self.loss_r_log.append(loss_r_value)

                # self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)
                # self.adaptive_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                if it % 1000 == 0:

                    print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' %  (it, loss_value, loss_u_value, loss_r_value, elapsed))
                    print("constant_ics_val: {:.3f}, constant_bcs_val: {:.3f}".format(  self.adaptive_constant_ics_val,  self.adaptive_constant_bcs_val))
                start_time = timeit.default_timer()

            # # Compute the eigenvalues of the Hessian of losses
            # if self.stiff_ratio:
            #     if it % 1000 == 0:
            #         print("Eigenvalues information stored ...")
            #         eigenvalues, eigenvalues_ics, eigenvalues_bcs, eigenvalues_res = self.sess.run([self.eigenvalues,
            #                                                                                         self.eigenvalues_ics,
            #                                                                                         self.eigenvalues_bcs,
            #                                                                                         self.eigenvalues_res], tf_dict)
            #         self.eigenvalue_log.append(eigenvalues)
            #         self.eigenvalue_ics_log.append(eigenvalues_bcs)
            #         self.eigenvalue_bcs_log.append(eigenvalues_bcs)
            #         self.eigenvalue_res_log.append(eigenvalues_res)

            # # Store gradients
            # if it % 10000 == 0:
            #     self.save_gradients(tf_dict)
            #     print("Gradients information stored ...")

################################################################################################################
                

    def lambda_balance(self  , term  ):
                histoy_mean =  np.mean(self.loss_history[term])
                m = 3 #len(self.loss_list)
                num = np.exp( (self.loss_history[term][-1] -2 * self.loss_history[term][-2] +  self.loss_history[term][-3]) / np.mean(self.loss_history[term][-99::]) )#/(self.T * histoy_mean)) np.exp( )
                denum = 0 

                for  key in self.loss_list:
                    denum +=  np.exp(  (self.loss_history[key][-1] -2 * self.loss_history[key][-2] +  self.loss_history[key][-3])  /  np.mean(self.loss_history[key][-99::]) )# /(self.T * histoy_mean))  np.exp(self.loss_history[key][-1] )
                return m * (num / denum)
    
    def trainmb(self, nIter=10000, batch_size=128):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(1 , nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size)
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)

            # Fetch residual mini-batch
            X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.u_bc1_tf: u_bc1_batch,
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.u_bc2_tf: u_bc2_batch,
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.r_tf: f_res_batch,
                       self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                       self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val,
                       self.adaptive_constant_res_tf: self.adaptive_constant_res_val
                       }

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                [loss ,  loss_res,  loss_bcs , loss_ics ]  = batch_losses

                self.print('It: %d, Loss: %.3e, loss_bcs: %.3ee, loss_ics: %.3e, Loss_r: %.3e, Time: %.2f' %(it, loss, loss_bcs , loss_ics, loss_res, elapsed))

                # Compute and Print adaptive weights during training
                adaptive_constant_res_val, adaptive_constant_bcs_val, adaptive_constant_ics_val = self.sess.run( [self.adaptive_constant_res,
                                                                                                                                               self.adaptive_constant_bcs, 
                                                                                                                                               self.adaptive_constant_ics  ], tf_dict)
                min_grad = np.min( [adaptive_constant_res_val, adaptive_constant_bcs_val, adaptive_constant_ics_val])

                update_res = self.lambda_balance( "loss_res"  )
                update_ics_u = self.lambda_balance( "loss_ics"  )
                update_bcs = self.lambda_balance( "loss_bcs"  )
                
                self.adaptive_constant_res_val =  update_res / (min_grad + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_res_val
                self.adaptive_constant_ics_val =  update_ics_u  / (min_grad + 1e-12)#( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs_val = update_bcs  / (min_grad + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val

                self.print('min_grad: {:.3e}'.format( min_grad))

                self.print('update_res: {:.3e}'.format( update_res))
                self.print('update_ics_u_t: {:.3e}'.format( update_ics_u))
                self.print('update_bcs1: {:.3e}'.format( update_bcs))
                
                self.print('adaptive_constant_res_val: {:.3e}'.format( self.adaptive_constant_res_val))
                self.print('adaptive_constant_ics_val: {:.3e}'.format( self.adaptive_constant_ics_val))
                self.print('adaptive_constant_bcs1_val: {:.3e}'.format( self.adaptive_constant_bcs_val))
                
                self.adaptive_constant_res_log.append(self.adaptive_constant_res_val)
                self.adaptive_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)

                max_grad_res , mean_grad_bcs, mean_grad_ics = self.sess.run( [ self.max_grad_res , self.mean_grad_bcs , self.mean_grad_ics  ], tf_dict)

                self.mean_adaptive_constant_res_log.append( max_grad_res)
                self.mean_adaptive_constant_bcs_log.append( mean_grad_bcs)
                self.mean_adaptive_constant_ics_log.append( mean_grad_ics)

            start_time =  timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()
            
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

  # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1  , grad_ics  = self.sess.run([ self.grad_res[i],self.grad_bcs[i],self.grad_ics[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs_layers['layer_' + str(j + 1)][-1]
            gradients_ics = self.dict_gradients_ics_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')
            sns.distplot(gradients_ics, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{ics}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=3)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all" , )
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        plt.close("all" , )
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
        from mpl_toolkits.axes_grid1 import ImageGrid

        ### Plot ###
        plt.close("all" , )

        # Exact solution & Predicted solution
        # Exact soluton
        U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
        F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

        # Predicted solution
        U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
        F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

        titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $f(x)$' , 'Predicted $f(x)$' , 'Absolute error']
        data = [U_star , U_pred ,  np.abs(U_star - U_pred) , F_star , F_pred ,  np.abs(F_star - F_pred) ]
        

        fig_1 = plt.figure(1, figsize=(13, 5))
        grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                        label_mode="1", axes_pad=1.7, share_all=False, 
                        cbar_mode="each", cbar_location="right", 
                        cbar_size="5%", cbar_pad=0.0)
    # CREATE ARGUMENTS DICT FOR CONTOURPLOTS
        minmax_list = []
        kwargs_list = []
        for d in data:
            # if(local):
            #     minmax_list.append([np.min(d), np.max(d)])
            # else:
            minmax_list.append([np.min(d), np.max(d)])

            kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60),
                cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

        for ax, z, kwargs, minmax, title in zip(grid, data, kwargs_list, minmax_list, titles):
        #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
            #pcfsets.append(pcf)
            # if (timeStp == 0):
                #  print( z[timeStp,:,:])
            pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
            cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
            ax.cax.tick_params(labelsize=14.5)
            ax.set_title(title, fontsize=14.5, pad=7)
            ax.set_ylabel("time", labelpad=14.5, fontsize=14.5, rotation="horizontal")
            ax.set_xlabel("x", fontsize=14.5)
            ax.tick_params(labelsize=14.5)
            ax.set_xlim(x1.min(), x1.max())
            ax.set_ylim(x2.min(), x2.max())
            ax.set_aspect("equal")

        fig_1.set_size_inches(15, 10, True)
        fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
        plt.close("all" , )


    def plot_grad(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adaptive_constant_bcs_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc}}}$')
        ax.semilogy(self.adaptive_constant_ics_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{ic}}}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)
        plt.close("all" , )



  
    
    def plot_lambda(self ):

        fontsize = 17
        fig, ax = plt.subplots()
        fig.set_size_inches([16,8])
        ax.semilogy(self.mean_adaptive_constant_bcs_log, label=r'$\bar{\nabla_\theta {u_{bc}}}$' , color = 'tab:green')
        ax.semilogy(self.mean_adaptive_constant_ics_log, label=r'$\bar{\nabla_\theta {u_{ics}}}$' , color = 'tab:blue')
        ax.semilogy(self.mean_adaptive_constant_res_log, label=r'$Max{\nabla_\theta {u_{phy}}}$' , color = 'tab:red')
        ax.set_xlabel("epochs", fontsize=fontsize)
        ax.set_ylabel(r'$\bar{\nabla_\theta {u}}$', fontsize=fontsize)
        ax.tick_params(labelsize=fontsize)
        ax.legend(loc='center left', bbox_to_anchor=(-0.25, 0.5))

        ax2 = ax.twinx() 

        # fig, ax = plt.subplots()
        # fig.set_size_inches([15,8])
    
        ax2.semilogy(self.adaptive_constant_bcs_log, label=r'$\bar{\lambda_{bc}}$'  ,  linestyle='dashed' , color = 'tab:green') 
        ax2.semilogy(self.adaptive_constant_ics_log, label=r'$\bar{\lambda_{ics}}$' , linestyle='dashed'  , color = 'tab:blue')
        ax2.semilogy(self.adaptive_constant_res_log, label=r'$\bar{\lambda_{phy}}$' ,  linestyle='dashed' , color = 'tab:red')
        ax2.set_xlabel("epochs", fontsize=fontsize)
        ax2.set_ylabel(r'$\bar{\lambda}$', fontsize=fontsize)
        ax2.tick_params(labelsize=fontsize)
        ax2.legend(loc='center right', bbox_to_anchor=(1.2, 0.5))

        plt.tight_layout()

        path = os.path.join(self.dirname,'lambda_history.png')
        plt.savefig(path)

# %%
def test_method(method , layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma ,k ,mode , stiff_ratio ,  X_star , u_star , f_star):


    model = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, stiff_ratio)

    # Train model
    start_time = time.time()

    if method =="full_batch":
        model.train(nIter=40001 )
    elif method =="mini_batch":
        model.trainmb(nIter=40001, batch_size=128)
    else:
        print("unknown method!")
    elapsed = time.time() - start_time

    # Predictions
    u_pred = model.predict_u(X_star)
    f_pred = model.predict_r(X_star)

    # Relative error
    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_f: {:.2e}'.format(error_f))

    return [elapsed, error_u , error_f]

# %%
# Parameters of equations
alpha = -1.0
beta = 0.0
gamma = 1.0
k = 3
# Domain boundaries
ics_coords = np.array([[0.0, 0.0], [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0], [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0], [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0], [1.0, 1.0]])


# Define model
layers = [2, 50, 50, 50, 50, 50, 1]
mode = 'M2'          # Method: 'M1', 'M2', 'M3', 'M4'
stiff_ratio = False  # Log the eigenvalues of Hessian of losses



nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 128

# Test data
nn = 100
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

# Exact solution
u_star = u(X_star)
f_star = f(X_star, alpha, beta, gamma, k)


iterations = 1
methods = ["mini_batch" ]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_f_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create initial conditions samplers
        ics_sampler = Sampler(2, ics_coords, lambda x: u(x), name='Initial Condition 1')

        # Create boundary conditions samplers
        bc1 = Sampler(2, bc1_coords, lambda x: u(x), name='Dirichlet BC1')
        bc2 = Sampler(2, bc2_coords, lambda x: u(x), name='Dirichlet BC2')
        bcs_sampler = [bc1, bc2]

        # Create residual sampler
        res_sampler = Sampler(2, dom_coords, lambda x: f(x, alpha, beta, gamma, k), name='Forcing')
        bcs_sampler = [bc1, bc2]

        # [elapsed, error_u , error_f] = test_method(mtd , layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma ,k ,mode , stiff_ratio ,  X_star , u_star , f_star)

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            model = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess)

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                model.train(nIter=nIter )
            elif mtd =="mini_batch":
                model.trainmb(nIter=nIter, batch_size=128)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            f_pred = model.predict_r(X_star)

            # Relative error
            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_f: {:.2e}'.format(error_f))
            
            model.print("average lambda_bc" , np.average(model.adaptive_constant_bcs_log))
            model.print("average lambda_bc" , np.average(model.adaptive_constant_ics_log))
            model.print("average lambda_res" , str(1.0))
            # sess.close()  

            model.plot_grad()
            model.save_NN()
            model.plt_prediction( t , x , X_star , u_star , u_pred , f_star , f_pred)

            time_list.append(elapsed)
            error_u_list.append(error_u)
            error_f_list.append(error_f)

    # print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_f_list:" , sum(error_f_list) / len(error_f_list) )

    result_dict[mtd] = [time_list ,error_u_list ,  error_f_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_Helmholtz_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_15335/3484867031.py:66: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_15335/3484867031.py:67: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_15335/3484867031.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_15335/3484867031.py:68: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_15335/2165439087.py:270: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_15335/2165439087.py:69: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-12-22 19:33:23.224760: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-22 19:33:23.245596: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-22 19:33:23.246183: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562c7a233350 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-22 19:33:23.246196: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-22 19:33:23.246907: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_15335/2165439087.py:120: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_15335/2165439087.py:122: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tmp/ipykernel_15335/2165439087.py:192: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 2.673e+03, loss_bcs: 1.346e+01e, loss_ics: 3.780e+01, Loss_r: 2.622e+03, Time: 0.01
# min_grad: 2.393e+02
# update_res: 3.977e-01
# update_ics_u_t: 5.653e-01
# update_bcs1: 1.639e+00
# adaptive_constant_res_val: 1.662e-03
# adaptive_constant_ics_val: 2.363e-03
# adaptive_constant_bcs1_val: 6.849e-03
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 8.904e+00, loss_bcs: 1.081e+01e, loss_ics: 3.832e+01, Loss_r: 5.258e+03, Time: 0.01
# min_grad: 1.989e+03
# update_res: 9.155e-01
# update_ics_u_t: 7.871e-01
# update_bcs1: 5.127e-01
# adaptive_constant_res_val: 4.603e-04
# adaptive_constant_ics_val: 3.957e-04
# adaptive_constant_bcs1_val: 2.578e-04
# It: 300, Loss: 2.103e+00, loss_bcs: 1.225e+01e, loss_ics: 3.675e+01, Loss_r: 4.531e+03, Time: 0.02
# min_grad: 2.387e+03
# update_res: 7.558e-01
# update_ics_u_t: 7.799e-01
# update_bcs1: 7.093e-01
# adaptive_constant_res_val: 3.166e-04
# adaptive_constant_ics_val: 3.267e-04
# adaptive_constant_bcs1_val: 2.971e-04
# It: 400, Loss: 1.255e+00, loss_bcs: 1.287e+01e, loss_ics: 3.596e+01, Loss_r: 3.914e+03, Time: 0.01
# min_grad: 1.763e+03
# update_res: 6.504e-01
# update_ics_u_t: 8.294e-01
# update_bcs1: 7.112e-01
# adaptive_constant_res_val: 3.689e-04
# adaptive_constant_ics_val: 4.705e-04
# adaptive_constant_bcs1_val: 4.034e-04
# It: 500, Loss: 1.442e+00, loss_bcs: 1.242e+01e, loss_ics: 3.558e+01, Loss_r: 3.849e+03, Time: 0.01
# min_grad: 1.734e+03
# update_res: 7.194e-01
# update_ics_u_t: 7.764e-01
# update_bcs1: 7.324e-01
# adaptive_constant_res_val: 4.149e-04
# adaptive_constant_ics_val: 4.478e-04
# adaptive_constant_bcs1_val: 4.224e-04
# It: 600, Loss: 1.393e+00, loss_bcs: 1.202e+01e, loss_ics: 3.539e+01, Loss_r: 3.308e+03, Time: 0.01
# min_grad: 1.400e+03
# update_res: 7.687e-01
# update_ics_u_t: 8.035e-01
# update_bcs1: 6.531e-01
# adaptive_constant_res_val: 5.493e-04
# adaptive_constant_ics_val: 5.741e-04
# adaptive_constant_bcs1_val: 4.666e-04
# It: 700, Loss: 1.695e+00, loss_bcs: 1.391e+01e, loss_ics: 3.422e+01, Loss_r: 3.038e+03, Time: 0.01
# min_grad: 8.047e+02
# update_res: 8.506e-01
# update_ics_u_t: 7.342e-01
# update_bcs1: 6.719e-01
# adaptive_constant_res_val: 1.057e-03
# adaptive_constant_ics_val: 9.124e-04
# adaptive_constant_bcs1_val: 8.350e-04
# It: 800, Loss: 3.320e+00, loss_bcs: 1.216e+01e, loss_ics: 3.390e+01, Loss_r: 3.102e+03, Time: 0.01
# min_grad: 5.989e+02
# update_res: 5.999e-01
# update_ics_u_t: 8.140e-01
# update_bcs1: 7.539e-01
# adaptive_constant_res_val: 1.002e-03
# adaptive_constant_ics_val: 1.359e-03
# adaptive_constant_bcs1_val: 1.259e-03
# It: 900, Loss: 2.975e+00, loss_bcs: 1.441e+01e, loss_ics: 3.360e+01, Loss_r: 2.907e+03, Time: 0.01
# min_grad: 1.789e+02
# update_res: 7.369e-01
# update_ics_u_t: 6.339e-01
# update_bcs1: 9.792e-01
# adaptive_constant_res_val: 4.118e-03
# adaptive_constant_ics_val: 3.543e-03
# adaptive_constant_bcs1_val: 5.473e-03
# It: 1000, Loss: 1.068e+01, loss_bcs: 1.255e+01e, loss_ics: 3.403e+01, Loss_r: 2.547e+03, Time: 0.01
# min_grad: 4.631e+02
# update_res: 5.664e-01
# update_ics_u_t: 8.575e-01
# update_bcs1: 7.290e-01
# adaptive_constant_res_val: 1.223e-03
# adaptive_constant_ics_val: 1.852e-03
# adaptive_constant_bcs1_val: 1.574e-03
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 3.151e+00, loss_bcs: 1.356e+01e, loss_ics: 3.435e+01, Loss_r: 2.506e+03, Time: 0.01
# min_grad: 2.187e+02
# update_res: 7.377e-01
# update_ics_u_t: 6.817e-01
# update_bcs1: 8.876e-01
# adaptive_constant_res_val: 3.374e-03
# adaptive_constant_ics_val: 3.118e-03
# adaptive_constant_bcs1_val: 4.059e-03
# It: 1200, Loss: 8.414e+00, loss_bcs: 1.274e+01e, loss_ics: 3.389e+01, Loss_r: 2.447e+03, Time: 0.01
# min_grad: 4.243e+02
# update_res: 4.635e-01
# update_ics_u_t: 8.403e-01
# update_bcs1: 8.561e-01
# adaptive_constant_res_val: 1.092e-03
# adaptive_constant_ics_val: 1.980e-03
# adaptive_constant_bcs1_val: 2.018e-03
# It: 1300, Loss: 4.336e+00, loss_bcs: 1.410e+01e, loss_ics: 3.379e+01, Loss_r: 3.882e+03, Time: 0.01
# min_grad: 2.958e+02
# update_res: 8.897e-01
# update_ics_u_t: 6.529e-01
# update_bcs1: 8.023e-01
# adaptive_constant_res_val: 3.008e-03
# adaptive_constant_ics_val: 2.207e-03
# adaptive_constant_bcs1_val: 2.712e-03
# It: 1400, Loss: 8.740e+00, loss_bcs: 1.569e+01e, loss_ics: 3.375e+01, Loss_r: 2.867e+03, Time: 0.01
# min_grad: 3.643e+02
# update_res: 7.227e-01
# update_ics_u_t: 7.583e-01
# update_bcs1: 7.824e-01
# adaptive_constant_res_val: 1.984e-03
# adaptive_constant_ics_val: 2.082e-03
# adaptive_constant_bcs1_val: 2.148e-03
# It: 1500, Loss: 7.027e+00, loss_bcs: 1.472e+01e, loss_ics: 3.311e+01, Loss_r: 3.491e+03, Time: 0.01
# min_grad: 3.230e+02
# update_res: 7.198e-01
# update_ics_u_t: 6.630e-01
# update_bcs1: 9.483e-01
# adaptive_constant_res_val: 2.228e-03
# adaptive_constant_ics_val: 2.052e-03
# adaptive_constant_bcs1_val: 2.936e-03
# It: 1600, Loss: 7.547e+00, loss_bcs: 1.305e+01e, loss_ics: 3.292e+01, Loss_r: 3.339e+03, Time: 0.02
# min_grad: 5.739e+02
# update_res: 9.900e-01
# update_ics_u_t: 6.699e-01
# update_bcs1: 6.713e-01
# adaptive_constant_res_val: 1.725e-03
# adaptive_constant_ics_val: 1.167e-03
# adaptive_constant_bcs1_val: 1.170e-03
# It: 1700, Loss: 5.015e+00, loss_bcs: 1.267e+01e, loss_ics: 3.324e+01, Loss_r: 2.876e+03, Time: 0.04
# min_grad: 2.199e+02
# update_res: 7.813e-01
# update_ics_u_t: 7.467e-01
# update_bcs1: 7.165e-01
# adaptive_constant_res_val: 3.552e-03
# adaptive_constant_ics_val: 3.395e-03
# adaptive_constant_bcs1_val: 3.258e-03
# It: 1800, Loss: 9.967e+00, loss_bcs: 1.389e+01e, loss_ics: 3.188e+01, Loss_r: 2.763e+03, Time: 0.01
# min_grad: 7.767e+02
# update_res: 7.107e-01
# update_ics_u_t: 6.729e-01
# update_bcs1: 9.203e-01
# adaptive_constant_res_val: 9.150e-04
# adaptive_constant_ics_val: 8.663e-04
# adaptive_constant_bcs1_val: 1.185e-03
# It: 1900, Loss: 2.956e+00, loss_bcs: 1.396e+01e, loss_ics: 3.205e+01, Loss_r: 3.182e+03, Time: 0.01
# min_grad: 4.829e+02
# update_res: 1.062e+00
# update_ics_u_t: 6.176e-01
# update_bcs1: 6.949e-01
# adaptive_constant_res_val: 2.199e-03
# adaptive_constant_ics_val: 1.279e-03
# adaptive_constant_bcs1_val: 1.439e-03
# It: 2000, Loss: 5.447e+00, loss_bcs: 1.444e+01e, loss_ics: 3.120e+01, Loss_r: 2.449e+03, Time: 0.01
# min_grad: 2.869e+02
# update_res: 7.481e-01
# update_ics_u_t: 6.771e-01
# update_bcs1: 8.693e-01
# adaptive_constant_res_val: 2.608e-03
# adaptive_constant_ics_val: 2.360e-03
# adaptive_constant_bcs1_val: 3.030e-03
# It: 2100, Loss: 6.648e+00, loss_bcs: 1.493e+01e, loss_ics: 3.141e+01, Loss_r: 2.504e+03, Time: 0.01
# min_grad: 4.700e+02
# update_res: 5.205e-01
# update_ics_u_t: 8.298e-01
# update_bcs1: 8.682e-01
# adaptive_constant_res_val: 1.108e-03
# adaptive_constant_ics_val: 1.766e-03
# adaptive_constant_bcs1_val: 1.847e-03
# It: 2200, Loss: 2.334e+00, loss_bcs: 1.321e+01e, loss_ics: 3.098e+01, Loss_r: 2.036e+03, Time: 0.01
# min_grad: 7.166e+02
# update_res: 9.230e-01
# update_ics_u_t: 6.978e-01
# update_bcs1: 6.852e-01
# adaptive_constant_res_val: 1.288e-03
# adaptive_constant_ics_val: 9.737e-04
# adaptive_constant_bcs1_val: 9.561e-04
# It: 2300, Loss: 3.660e+00, loss_bcs: 1.410e+01e, loss_ics: 3.058e+01, Loss_r: 2.808e+03, Time: 0.01
# min_grad: 8.568e+02
# update_res: 6.762e-01
# update_ics_u_t: 6.806e-01
# update_bcs1: 9.532e-01
# adaptive_constant_res_val: 7.892e-04
# adaptive_constant_ics_val: 7.943e-04
# adaptive_constant_bcs1_val: 1.112e-03
# It: 2400, Loss: 1.780e+00, loss_bcs: 1.420e+01e, loss_ics: 3.038e+01, Loss_r: 2.204e+03, Time: 0.01
# min_grad: 6.023e+02
# update_res: 9.768e-01
# update_ics_u_t: 6.207e-01
# update_bcs1: 7.794e-01
# adaptive_constant_res_val: 1.622e-03
# adaptive_constant_ics_val: 1.030e-03
# adaptive_constant_bcs1_val: 1.294e-03
# It: 2500, Loss: 4.850e+00, loss_bcs: 1.411e+01e, loss_ics: 2.963e+01, Loss_r: 2.961e+03, Time: 0.01
# min_grad: 4.094e+02
# update_res: 9.942e-01
# update_ics_u_t: 6.647e-01
# update_bcs1: 6.648e-01
# adaptive_constant_res_val: 2.428e-03
# adaptive_constant_ics_val: 1.624e-03
# adaptive_constant_bcs1_val: 1.624e-03
# It: 2600, Loss: 4.830e+00, loss_bcs: 1.443e+01e, loss_ics: 2.900e+01, Loss_r: 1.960e+03, Time: 0.01
# min_grad: 2.787e+02
# update_res: 7.804e-01
# update_ics_u_t: 7.240e-01
# update_bcs1: 7.608e-01
# adaptive_constant_res_val: 2.800e-03
# adaptive_constant_ics_val: 2.597e-03
# adaptive_constant_bcs1_val: 2.730e-03
# It: 2700, Loss: 7.284e+00, loss_bcs: 1.380e+01e, loss_ics: 2.841e+01, Loss_r: 2.562e+03, Time: 0.02
# min_grad: 5.741e+02
# update_res: 6.302e-01
# update_ics_u_t: 7.936e-01
# update_bcs1: 7.660e-01
# adaptive_constant_res_val: 1.098e-03
# adaptive_constant_ics_val: 1.382e-03
# adaptive_constant_bcs1_val: 1.334e-03
# It: 2800, Loss: 2.047e+00, loss_bcs: 1.396e+01e, loss_ics: 2.859e+01, Loss_r: 1.812e+03, Time: 0.02
# min_grad: 4.081e+02
# update_res: 5.512e-01
# update_ics_u_t: 8.207e-01
# update_bcs1: 8.139e-01
# adaptive_constant_res_val: 1.351e-03
# adaptive_constant_ics_val: 2.011e-03
# adaptive_constant_bcs1_val: 1.994e-03
# It: 2900, Loss: 2.986e+00, loss_bcs: 1.409e+01e, loss_ics: 2.856e+01, Loss_r: 2.148e+03, Time: 0.01
# min_grad: 5.693e+02
# update_res: 8.317e-01
# update_ics_u_t: 7.171e-01
# update_bcs1: 7.349e-01
# adaptive_constant_res_val: 1.461e-03
# adaptive_constant_ics_val: 1.260e-03
# adaptive_constant_bcs1_val: 1.291e-03
# It: 3000, Loss: 3.596e+00, loss_bcs: 1.432e+01e, loss_ics: 2.765e+01, Loss_r: 2.425e+03, Time: 0.01
# min_grad: 5.679e+02
# update_res: 9.283e-01
# update_ics_u_t: 6.892e-01
# update_bcs1: 6.896e-01
# adaptive_constant_res_val: 1.635e-03
# adaptive_constant_ics_val: 1.214e-03
# adaptive_constant_bcs1_val: 1.214e-03
# It: 3100, Loss: 3.827e+00, loss_bcs: 1.335e+01e, loss_ics: 2.731e+01, Loss_r: 2.311e+03, Time: 0.01
# min_grad: 8.264e+02
# update_res: 4.427e-01
# update_ics_u_t: 9.015e-01
# update_bcs1: 7.735e-01
# adaptive_constant_res_val: 5.356e-04
# adaptive_constant_ics_val: 1.091e-03
# adaptive_constant_bcs1_val: 9.360e-04
# It: 3200, Loss: 1.431e+00, loss_bcs: 1.247e+01e, loss_ics: 2.684e+01, Loss_r: 2.596e+03, Time: 0.01
# min_grad: 6.361e+02
# update_res: 1.146e+00
# update_ics_u_t: 6.056e-01
# update_bcs1: 6.464e-01
# adaptive_constant_res_val: 1.802e-03
# adaptive_constant_ics_val: 9.521e-04
# adaptive_constant_bcs1_val: 1.016e-03
# It: 3300, Loss: 4.858e+00, loss_bcs: 1.410e+01e, loss_ics: 2.648e+01, Loss_r: 2.675e+03, Time: 0.01
# min_grad: 7.865e+02
# update_res: 7.796e-01
# update_ics_u_t: 6.958e-01
# update_bcs1: 8.314e-01
# adaptive_constant_res_val: 9.912e-04
# adaptive_constant_ics_val: 8.846e-04
# adaptive_constant_bcs1_val: 1.057e-03
# It: 3400, Loss: 1.578e+00, loss_bcs: 1.192e+01e, loss_ics: 2.607e+01, Loss_r: 1.556e+03, Time: 0.01
# min_grad: 3.197e+02
# update_res: 5.824e-01
# update_ics_u_t: 9.161e-01
# update_bcs1: 5.985e-01
# adaptive_constant_res_val: 1.822e-03
# adaptive_constant_ics_val: 2.865e-03
# adaptive_constant_bcs1_val: 1.872e-03
# It: 3500, Loss: 4.272e+00, loss_bcs: 1.283e+01e, loss_ics: 2.604e+01, Loss_r: 2.291e+03, Time: 0.01
# min_grad: 1.379e+03
# update_res: 9.184e-01
# update_ics_u_t: 7.815e-01
# update_bcs1: 5.313e-01
# adaptive_constant_res_val: 6.658e-04
# adaptive_constant_ics_val: 5.665e-04
# adaptive_constant_bcs1_val: 3.852e-04
# It: 3600, Loss: 1.186e+00, loss_bcs: 1.411e+01e, loss_ics: 2.521e+01, Loss_r: 1.751e+03, Time: 0.03
# min_grad: 7.583e+02
# update_res: 6.476e-01
# update_ics_u_t: 8.100e-01
# update_bcs1: 7.295e-01
# adaptive_constant_res_val: 8.540e-04
# adaptive_constant_ics_val: 1.068e-03
# adaptive_constant_bcs1_val: 9.621e-04
# It: 3700, Loss: 1.807e+00, loss_bcs: 1.307e+01e, loss_ics: 2.523e+01, Loss_r: 2.070e+03, Time: 0.01
# min_grad: 7.680e+02
# update_res: 7.850e-01
# update_ics_u_t: 6.822e-01
# update_bcs1: 8.473e-01
# adaptive_constant_res_val: 1.022e-03
# adaptive_constant_ics_val: 8.882e-04
# adaptive_constant_bcs1_val: 1.103e-03
# It: 3800, Loss: 1.908e+00, loss_bcs: 1.298e+01e, loss_ics: 2.455e+01, Loss_r: 1.832e+03, Time: 0.01
# min_grad: 8.100e+02
# update_res: 8.913e-01
# update_ics_u_t: 6.921e-01
# update_bcs1: 7.364e-01
# adaptive_constant_res_val: 1.100e-03
# adaptive_constant_ics_val: 8.544e-04
# adaptive_constant_bcs1_val: 9.092e-04
# It: 3900, Loss: 3.226e+00, loss_bcs: 1.556e+01e, loss_ics: 2.511e+01, Loss_r: 2.900e+03, Time: 0.01
# min_grad: 7.597e+02
# update_res: 7.185e-01
# update_ics_u_t: 6.918e-01
# update_bcs1: 9.109e-01
# adaptive_constant_res_val: 9.458e-04
# adaptive_constant_ics_val: 9.106e-04
# adaptive_constant_bcs1_val: 1.199e-03
# It: 4000, Loss: 2.219e+00, loss_bcs: 1.424e+01e, loss_ics: 2.479e+01, Loss_r: 2.304e+03, Time: 0.01
# min_grad: 4.363e+02
# update_res: 7.388e-01
# update_ics_u_t: 8.108e-01
# update_bcs1: 6.355e-01
# adaptive_constant_res_val: 1.693e-03
# adaptive_constant_ics_val: 1.859e-03
# adaptive_constant_bcs1_val: 1.457e-03
# It: 4100, Loss: 3.401e+00, loss_bcs: 1.168e+01e, loss_ics: 2.423e+01, Loss_r: 1.971e+03, Time: 0.01
# min_grad: 8.313e+02
# update_res: 4.920e-01
# update_ics_u_t: 9.420e-01
# update_bcs1: 6.440e-01
# adaptive_constant_res_val: 5.918e-04
# adaptive_constant_ics_val: 1.133e-03
# adaptive_constant_bcs1_val: 7.747e-04
# It: 4200, Loss: 1.079e+00, loss_bcs: 1.529e+01e, loss_ics: 2.403e+01, Loss_r: 1.757e+03, Time: 0.01
# min_grad: 9.552e+02
# update_res: 6.425e-01
# update_ics_u_t: 7.468e-01
# update_bcs1: 8.831e-01
# adaptive_constant_res_val: 6.726e-04
# adaptive_constant_ics_val: 7.818e-04
# adaptive_constant_bcs1_val: 9.246e-04
# It: 4300, Loss: 1.551e+00, loss_bcs: 1.440e+01e, loss_ics: 2.345e+01, Loss_r: 2.259e+03, Time: 0.01
# min_grad: 1.652e+03
# update_res: 8.766e-01
# update_ics_u_t: 7.624e-01
# update_bcs1: 6.096e-01
# adaptive_constant_res_val: 5.305e-04
# adaptive_constant_ics_val: 4.615e-04
# adaptive_constant_bcs1_val: 3.690e-04
# It: 4400, Loss: 1.433e+00, loss_bcs: 1.460e+01e, loss_ics: 2.347e+01, Loss_r: 2.670e+03, Time: 0.01
# min_grad: 5.829e+02
# update_res: 1.143e+00
# update_ics_u_t: 6.525e-01
# update_bcs1: 5.448e-01
# adaptive_constant_res_val: 1.960e-03
# adaptive_constant_ics_val: 1.119e-03
# adaptive_constant_bcs1_val: 9.346e-04
# It: 4500, Loss: 4.985e+00, loss_bcs: 1.244e+01e, loss_ics: 2.346e+01, Loss_r: 2.524e+03, Time: 0.01
# min_grad: 1.020e+03
# update_res: 1.014e+00
# update_ics_u_t: 7.005e-01
# update_bcs1: 5.884e-01
# adaptive_constant_res_val: 9.947e-04
# adaptive_constant_ics_val: 6.871e-04
# adaptive_constant_bcs1_val: 5.771e-04
# It: 4600, Loss: 2.848e+00, loss_bcs: 1.350e+01e, loss_ics: 2.268e+01, Loss_r: 2.840e+03, Time: 0.01
# min_grad: 5.914e+02
# update_res: 8.408e-01
# update_ics_u_t: 7.217e-01
# update_bcs1: 7.057e-01
# adaptive_constant_res_val: 1.422e-03
# adaptive_constant_ics_val: 1.220e-03
# adaptive_constant_bcs1_val: 1.193e-03
# It: 4700, Loss: 3.049e+00, loss_bcs: 1.486e+01e, loss_ics: 2.270e+01, Loss_r: 2.112e+03, Time: 0.01
# min_grad: 6.244e+02
# update_res: 8.531e-01
# update_ics_u_t: 7.079e-01
# update_bcs1: 7.674e-01
# adaptive_constant_res_val: 1.366e-03
# adaptive_constant_ics_val: 1.134e-03
# adaptive_constant_bcs1_val: 1.229e-03
# It: 4800, Loss: 1.965e+00, loss_bcs: 1.518e+01e, loss_ics: 2.233e+01, Loss_r: 1.406e+03, Time: 0.01
# min_grad: 4.526e+02
# update_res: 7.657e-01
# update_ics_u_t: 7.362e-01
# update_bcs1: 7.738e-01
# adaptive_constant_res_val: 1.692e-03
# adaptive_constant_ics_val: 1.627e-03
# adaptive_constant_bcs1_val: 1.710e-03
# It: 4900, Loss: 3.297e+00, loss_bcs: 1.345e+01e, loss_ics: 2.243e+01, Loss_r: 1.914e+03, Time: 0.03
# min_grad: 7.833e+02
# update_res: 5.718e-01
# update_ics_u_t: 8.194e-01
# update_bcs1: 7.838e-01
# adaptive_constant_res_val: 7.300e-04
# adaptive_constant_ics_val: 1.046e-03
# adaptive_constant_bcs1_val: 1.001e-03
# It: 5000, Loss: 1.519e+00, loss_bcs: 1.332e+01e, loss_ics: 2.210e+01, Loss_r: 2.031e+03, Time: 0.01
# min_grad: 9.250e+02
# update_res: 7.130e-01
# update_ics_u_t: 7.474e-01
# update_bcs1: 8.000e-01
# adaptive_constant_res_val: 7.708e-04
# adaptive_constant_ics_val: 8.080e-04
# adaptive_constant_bcs1_val: 8.648e-04
# It: 5100, Loss: 1.124e+00, loss_bcs: 1.496e+01e, loss_ics: 2.148e+01, Loss_r: 1.419e+03, Time: 0.01
# min_grad: 5.802e+02
# update_res: 8.456e-01
# update_ics_u_t: 7.884e-01
# update_bcs1: 5.598e-01
# adaptive_constant_res_val: 1.457e-03
# adaptive_constant_ics_val: 1.359e-03
# adaptive_constant_bcs1_val: 9.648e-04
# It: 5200, Loss: 2.111e+00, loss_bcs: 1.505e+01e, loss_ics: 2.156e+01, Loss_r: 1.418e+03, Time: 0.01
# min_grad: 5.118e+02
# update_res: 8.171e-01
# update_ics_u_t: 7.372e-01
# update_bcs1: 7.165e-01
# adaptive_constant_res_val: 1.596e-03
# adaptive_constant_ics_val: 1.440e-03
# adaptive_constant_bcs1_val: 1.400e-03
# It: 5300, Loss: 3.203e+00, loss_bcs: 1.416e+01e, loss_ics: 2.148e+01, Loss_r: 1.975e+03, Time: 0.01
# min_grad: 2.686e+02
# update_res: 8.128e-01
# update_ics_u_t: 7.904e-01
# update_bcs1: 6.054e-01
# adaptive_constant_res_val: 3.027e-03
# adaptive_constant_ics_val: 2.943e-03
# adaptive_constant_bcs1_val: 2.254e-03
# It: 5400, Loss: 4.860e+00, loss_bcs: 1.517e+01e, loss_ics: 2.125e+01, Loss_r: 1.574e+03, Time: 0.01
# min_grad: 2.091e+03
# update_res: 7.330e-01
# update_ics_u_t: 6.977e-01
# update_bcs1: 8.743e-01
# adaptive_constant_res_val: 3.505e-04
# adaptive_constant_ics_val: 3.336e-04
# adaptive_constant_bcs1_val: 4.181e-04
# It: 5500, Loss: 5.265e-01, loss_bcs: 1.351e+01e, loss_ics: 2.075e+01, Loss_r: 1.466e+03, Time: 0.01
# min_grad: 6.866e+02
# update_res: 7.117e-01
# update_ics_u_t: 7.985e-01
# update_bcs1: 6.481e-01
# adaptive_constant_res_val: 1.037e-03
# adaptive_constant_ics_val: 1.163e-03
# adaptive_constant_bcs1_val: 9.439e-04
# It: 5600, Loss: 1.447e+00, loss_bcs: 1.398e+01e, loss_ics: 2.150e+01, Loss_r: 1.359e+03, Time: 0.01
# min_grad: 9.258e+02
# update_res: 5.336e-01
# update_ics_u_t: 8.455e-01
# update_bcs1: 7.918e-01
# adaptive_constant_res_val: 5.763e-04
# adaptive_constant_ics_val: 9.132e-04
# adaptive_constant_bcs1_val: 8.552e-04
# It: 5700, Loss: 1.145e+00, loss_bcs: 1.604e+01e, loss_ics: 2.111e+01, Loss_r: 1.930e+03, Time: 0.01
# min_grad: 9.601e+02
# update_res: 7.142e-01
# update_ics_u_t: 8.108e-01
# update_bcs1: 6.934e-01
# adaptive_constant_res_val: 7.438e-04
# adaptive_constant_ics_val: 8.444e-04
# adaptive_constant_bcs1_val: 7.221e-04
# It: 5800, Loss: 1.382e+00, loss_bcs: 1.595e+01e, loss_ics: 2.091e+01, Loss_r: 1.819e+03, Time: 0.01
# min_grad: 8.263e+02
# update_res: 5.862e-01
# update_ics_u_t: 7.693e-01
# update_bcs1: 8.874e-01
# adaptive_constant_res_val: 7.094e-04
# adaptive_constant_ics_val: 9.310e-04
# adaptive_constant_bcs1_val: 1.074e-03
# It: 5900, Loss: 9.884e-01, loss_bcs: 1.453e+01e, loss_ics: 2.040e+01, Loss_r: 1.345e+03, Time: 0.01
# min_grad: 8.658e+02
# update_res: 7.739e-01
# update_ics_u_t: 7.101e-01
# update_bcs1: 8.051e-01
# adaptive_constant_res_val: 8.939e-04
# adaptive_constant_ics_val: 8.203e-04
# adaptive_constant_bcs1_val: 9.300e-04
# It: 6000, Loss: 1.502e+00, loss_bcs: 1.360e+01e, loss_ics: 2.024e+01, Loss_r: 1.648e+03, Time: 0.01
# min_grad: 1.180e+03
# update_res: 7.753e-01
# update_ics_u_t: 7.413e-01
# update_bcs1: 7.598e-01
# adaptive_constant_res_val: 6.572e-04
# adaptive_constant_ics_val: 6.284e-04
# adaptive_constant_bcs1_val: 6.440e-04
# It: 6100, Loss: 5.959e-01, loss_bcs: 1.534e+01e, loss_ics: 1.964e+01, Loss_r: 8.730e+02, Time: 0.01
# min_grad: 7.082e+02
# update_res: 3.917e-01
# update_ics_u_t: 8.609e-01
# update_bcs1: 8.903e-01
# adaptive_constant_res_val: 5.532e-04
# adaptive_constant_ics_val: 1.216e-03
# adaptive_constant_bcs1_val: 1.257e-03
# It: 6200, Loss: 8.361e-01, loss_bcs: 1.274e+01e, loss_ics: 1.985e+01, Loss_r: 1.439e+03, Time: 0.01
# min_grad: 2.422e+03
# update_res: 7.398e-01
# update_ics_u_t: 7.484e-01
# update_bcs1: 7.704e-01
# adaptive_constant_res_val: 3.054e-04
# adaptive_constant_ics_val: 3.090e-04
# adaptive_constant_bcs1_val: 3.181e-04
# It: 6300, Loss: 4.001e-01, loss_bcs: 1.559e+01e, loss_ics: 1.989e+01, Loss_r: 1.274e+03, Time: 0.01
# min_grad: 9.032e+02
# update_res: 6.544e-01
# update_ics_u_t: 7.467e-01
# update_bcs1: 8.510e-01
# adaptive_constant_res_val: 7.245e-04
# adaptive_constant_ics_val: 8.267e-04
# adaptive_constant_bcs1_val: 9.422e-04
# It: 6400, Loss: 1.306e+00, loss_bcs: 1.545e+01e, loss_ics: 1.956e+01, Loss_r: 1.760e+03, Time: 0.01
# min_grad: 1.136e+03
# update_res: 1.027e+00
# update_ics_u_t: 6.687e-01
# update_bcs1: 6.077e-01
# adaptive_constant_res_val: 9.037e-04
# adaptive_constant_ics_val: 5.884e-04
# adaptive_constant_bcs1_val: 5.347e-04
# It: 6500, Loss: 1.086e+00, loss_bcs: 1.587e+01e, loss_ics: 1.966e+01, Loss_r: 1.180e+03, Time: 0.01
# min_grad: 5.113e+02
# update_res: 5.888e-01
# update_ics_u_t: 7.821e-01
# update_bcs1: 8.746e-01
# adaptive_constant_res_val: 1.151e-03
# adaptive_constant_ics_val: 1.530e-03
# adaptive_constant_bcs1_val: 1.710e-03
# It: 6600, Loss: 1.071e+00, loss_bcs: 1.466e+01e, loss_ics: 1.894e+01, Loss_r: 8.835e+02, Time: 0.01
# min_grad: 1.491e+03
# update_res: 7.315e-01
# update_ics_u_t: 7.587e-01
# update_bcs1: 7.811e-01
# adaptive_constant_res_val: 4.907e-04
# adaptive_constant_ics_val: 5.089e-04
# adaptive_constant_bcs1_val: 5.239e-04
# It: 6700, Loss: 4.302e-01, loss_bcs: 1.663e+01e, loss_ics: 1.884e+01, Loss_r: 8.394e+02, Time: 0.01
# min_grad: 8.095e+02
# update_res: 6.043e-01
# update_ics_u_t: 7.608e-01
# update_bcs1: 8.819e-01
# adaptive_constant_res_val: 7.465e-04
# adaptive_constant_ics_val: 9.398e-04
# adaptive_constant_bcs1_val: 1.089e-03
# It: 6800, Loss: 9.132e-01, loss_bcs: 1.585e+01e, loss_ics: 1.927e+01, Loss_r: 1.176e+03, Time: 0.01
# min_grad: 9.019e+02
# update_res: 9.697e-01
# update_ics_u_t: 6.721e-01
# update_bcs1: 6.788e-01
# adaptive_constant_res_val: 1.075e-03
# adaptive_constant_ics_val: 7.452e-04
# adaptive_constant_bcs1_val: 7.526e-04
# It: 6900, Loss: 1.355e+00, loss_bcs: 1.698e+01e, loss_ics: 1.988e+01, Loss_r: 1.234e+03, Time: 0.01
# min_grad: 2.113e+03
# update_res: 7.988e-01
# update_ics_u_t: 6.653e-01
# update_bcs1: 8.643e-01
# adaptive_constant_res_val: 3.780e-04
# adaptive_constant_ics_val: 3.148e-04
# adaptive_constant_bcs1_val: 4.090e-04
# It: 7000, Loss: 4.928e-01, loss_bcs: 1.576e+01e, loss_ics: 1.987e+01, Loss_r: 1.270e+03, Time: 0.01
# min_grad: 7.426e+02
# update_res: 7.584e-01
# update_ics_u_t: 7.534e-01
# update_bcs1: 7.196e-01
# adaptive_constant_res_val: 1.021e-03
# adaptive_constant_ics_val: 1.014e-03
# adaptive_constant_bcs1_val: 9.689e-04
# It: 7100, Loss: 1.349e+00, loss_bcs: 1.603e+01e, loss_ics: 2.015e+01, Loss_r: 1.285e+03, Time: 0.02
# min_grad: 7.624e+02
# update_res: 6.526e-01
# update_ics_u_t: 7.106e-01
# update_bcs1: 9.243e-01
# adaptive_constant_res_val: 8.560e-04
# adaptive_constant_ics_val: 9.320e-04
# adaptive_constant_bcs1_val: 1.212e-03
# It: 7200, Loss: 1.126e+00, loss_bcs: 1.630e+01e, loss_ics: 2.060e+01, Loss_r: 1.269e+03, Time: 0.01
# min_grad: 3.825e+02
# update_res: 6.245e-01
# update_ics_u_t: 7.855e-01
# update_bcs1: 8.031e-01
# adaptive_constant_res_val: 1.633e-03
# adaptive_constant_ics_val: 2.053e-03
# adaptive_constant_bcs1_val: 2.099e-03
# It: 7300, Loss: 9.159e-01, loss_bcs: 1.649e+01e, loss_ics: 2.150e+01, Loss_r: 5.127e+02, Time: 0.01
# min_grad: 1.996e+03
# update_res: 7.780e-01
# update_ics_u_t: 7.616e-01
# update_bcs1: 6.844e-01
# adaptive_constant_res_val: 3.897e-04
# adaptive_constant_ics_val: 3.815e-04
# adaptive_constant_bcs1_val: 3.428e-04
# It: 7400, Loss: 2.609e-01, loss_bcs: 1.606e+01e, loss_ics: 2.216e+01, Loss_r: 6.338e+02, Time: 0.01
# min_grad: 4.369e+02
# update_res: 9.030e-01
# update_ics_u_t: 6.874e-01
# update_bcs1: 7.234e-01
# adaptive_constant_res_val: 2.067e-03
# adaptive_constant_ics_val: 1.573e-03
# adaptive_constant_bcs1_val: 1.656e-03
# It: 7500, Loss: 2.259e+00, loss_bcs: 1.668e+01e, loss_ics: 2.701e+01, Loss_r: 1.059e+03, Time: 0.02
# min_grad: 4.908e+02
# update_res: 7.889e-01
# update_ics_u_t: 7.746e-01
# update_bcs1: 6.645e-01
# adaptive_constant_res_val: 1.607e-03
# adaptive_constant_ics_val: 1.578e-03
# adaptive_constant_bcs1_val: 1.354e-03
# It: 7600, Loss: 7.707e-01, loss_bcs: 1.721e+01e, loss_ics: 3.240e+01, Loss_r: 4.331e+02, Time: 0.01
# min_grad: 3.742e+02
# update_res: 7.339e-01
# update_ics_u_t: 7.326e-01
# update_bcs1: 8.168e-01
# adaptive_constant_res_val: 1.961e-03
# adaptive_constant_ics_val: 1.958e-03
# adaptive_constant_bcs1_val: 2.183e-03
# It: 7700, Loss: 1.043e+00, loss_bcs: 1.794e+01e, loss_ics: 4.558e+01, Loss_r: 4.663e+02, Time: 0.01
# min_grad: 2.255e+02
# update_res: 8.955e-01
# update_ics_u_t: 7.878e-01
# update_bcs1: 5.951e-01
# adaptive_constant_res_val: 3.972e-03
# adaptive_constant_ics_val: 3.494e-03
# adaptive_constant_bcs1_val: 2.640e-03
# It: 7800, Loss: 8.654e-01, loss_bcs: 1.972e+01e, loss_ics: 6.933e+01, Loss_r: 1.438e+02, Time: 0.01
# min_grad: 8.012e+01
# update_res: 6.571e-01
# update_ics_u_t: 8.100e-01
# update_bcs1: 7.728e-01
# adaptive_constant_res_val: 8.202e-03
# adaptive_constant_ics_val: 1.011e-02
# adaptive_constant_bcs1_val: 9.646e-03
# It: 7900, Loss: 2.395e+00, loss_bcs: 1.868e+01e, loss_ics: 6.502e+01, Loss_r: 1.899e+02, Time: 0.01
# min_grad: 1.345e+02
# update_res: 7.142e-01
# update_ics_u_t: 7.513e-01
# update_bcs1: 8.234e-01
# adaptive_constant_res_val: 5.310e-03
# adaptive_constant_ics_val: 5.586e-03
# adaptive_constant_bcs1_val: 6.123e-03
# It: 8000, Loss: 8.849e-01, loss_bcs: 2.016e+01e, loss_ics: 6.696e+01, Loss_r: 7.295e+01, Time: 0.01
# min_grad: 7.571e+01
# update_res: 7.411e-01
# update_ics_u_t: 7.987e-01
# update_bcs1: 7.310e-01
# adaptive_constant_res_val: 9.788e-03
# adaptive_constant_ics_val: 1.055e-02
# adaptive_constant_bcs1_val: 9.655e-03
# ...
# It: 37300, Loss: 3.236e-02, loss_bcs: 1.711e-02e, loss_ics: 3.587e-02, Loss_r: 3.520e-01, Time: 0.02
# min_grad: 1.989e+01
# update_res: 7.499e-01
# update_ics_u_t: 7.494e-01
# update_bcs1: 7.505e-01
# adaptive_constant_res_val: 3.771e-02
# adaptive_constant_ics_val: 3.768e-02
# adaptive_constant_bcs1_val: 3.774e-02
# It: 37400, Loss: 7.937e-03, loss_bcs: 1.570e-02e, loss_ics: 4.003e-02, Loss_r: 1.548e-01, Time: 0.02
# min_grad: 1.604e+01
# update_res: 7.497e-01
# update_ics_u_t: 7.506e-01
# update_bcs1: 7.499e-01
# adaptive_constant_res_val: 4.673e-02
# adaptive_constant_ics_val: 4.679e-02
# adaptive_constant_bcs1_val: 4.674e-02
# It: 37500, Loss: 1.284e-02, loss_bcs: 1.643e-02e, loss_ics: 3.751e-02, Loss_r: 2.208e-01, Time: 0.02
# min_grad: 5.192e+01
# update_res: 7.497e-01
# update_ics_u_t: 7.505e-01
# update_bcs1: 7.502e-01
# adaptive_constant_res_val: 1.444e-02
# adaptive_constant_ics_val: 1.445e-02
# adaptive_constant_bcs1_val: 1.445e-02
# It: 37600, Loss: 2.708e-03, loss_bcs: 1.607e-02e, loss_ics: 3.777e-02, Loss_r: 1.337e-01, Time: 0.02
# min_grad: 1.806e+01
# update_res: 7.500e-01
# update_ics_u_t: 7.500e-01
# update_bcs1: 7.500e-01
# adaptive_constant_res_val: 4.153e-02
# adaptive_constant_ics_val: 4.153e-02
# adaptive_constant_bcs1_val: 4.153e-02
# It: 37700, Loss: 1.078e-02, loss_bcs: 1.507e-02e, loss_ics: 3.802e-02, Loss_r: 2.064e-01, Time: 0.02
# min_grad: 4.619e+01
# update_res: 7.495e-01
# update_ics_u_t: 7.508e-01
# update_bcs1: 7.503e-01
# adaptive_constant_res_val: 1.623e-02
# adaptive_constant_ics_val: 1.625e-02
# adaptive_constant_bcs1_val: 1.624e-02
# It: 37800, Loss: 3.591e-03, loss_bcs: 1.631e-02e, loss_ics: 3.348e-02, Loss_r: 1.714e-01, Time: 0.02
# min_grad: 3.671e+01
# update_res: 7.500e-01
# update_ics_u_t: 7.501e-01
# update_bcs1: 7.499e-01
# adaptive_constant_res_val: 2.043e-02
# adaptive_constant_ics_val: 2.043e-02
# adaptive_constant_bcs1_val: 2.043e-02
# It: 37900, Loss: 3.762e-03, loss_bcs: 1.677e-02e, loss_ics: 3.984e-02, Loss_r: 1.275e-01, Time: 0.02
# min_grad: 2.774e+01
# update_res: 7.501e-01
# update_ics_u_t: 7.502e-01
# update_bcs1: 7.498e-01
# adaptive_constant_res_val: 2.704e-02
# adaptive_constant_ics_val: 2.704e-02
# adaptive_constant_bcs1_val: 2.703e-02
# It: 38000, Loss: 6.526e-03, loss_bcs: 1.616e-02e, loss_ics: 3.595e-02, Loss_r: 1.892e-01, Time: 0.02
# min_grad: 1.349e+01
# update_res: 7.501e-01
# update_ics_u_t: 7.501e-01
# update_bcs1: 7.498e-01
# adaptive_constant_res_val: 5.561e-02
# adaptive_constant_ics_val: 5.561e-02
# adaptive_constant_bcs1_val: 5.559e-02
# It: 38100, Loss: 9.537e-03, loss_bcs: 1.572e-02e, loss_ics: 3.635e-02, Loss_r: 1.194e-01, Time: 0.02
# min_grad: 3.655e+01
# update_res: 7.502e-01
# update_ics_u_t: 7.495e-01
# update_bcs1: 7.500e-01
# adaptive_constant_res_val: 2.053e-02
# adaptive_constant_ics_val: 2.050e-02
# adaptive_constant_bcs1_val: 2.052e-02
# It: 38200, Loss: 4.147e-03, loss_bcs: 1.674e-02e, loss_ics: 3.931e-02, Loss_r: 1.460e-01, Time: 0.03
# min_grad: 2.916e+01
# update_res: 7.501e-01
# update_ics_u_t: 7.500e-01
# update_bcs1: 7.499e-01
# adaptive_constant_res_val: 2.573e-02
# adaptive_constant_ics_val: 2.572e-02
# adaptive_constant_bcs1_val: 2.572e-02
# It: 38300, Loss: 9.631e-03, loss_bcs: 1.634e-02e, loss_ics: 3.417e-02, Loss_r: 3.239e-01, Time: 0.02
# min_grad: 3.141e+01
# update_res: 7.503e-01
# update_ics_u_t: 7.501e-01
# update_bcs1: 7.494e-01
# adaptive_constant_res_val: 2.389e-02
# adaptive_constant_ics_val: 2.388e-02
# adaptive_constant_bcs1_val: 2.386e-02
# It: 38400, Loss: 5.284e-03, loss_bcs: 1.487e-02e, loss_ics: 3.851e-02, Loss_r: 1.678e-01, Time: 0.02
# min_grad: 3.718e+01
# update_res: 7.498e-01
# update_ics_u_t: 7.502e-01
# update_bcs1: 7.502e-01
# adaptive_constant_res_val: 2.017e-02
# adaptive_constant_ics_val: 2.018e-02
# adaptive_constant_bcs1_val: 2.018e-02
# It: 38500, Loss: 3.897e-03, loss_bcs: 1.587e-02e, loss_ics: 3.369e-02, Loss_r: 1.436e-01, Time: 0.02
# min_grad: 2.351e+01
# update_res: 7.498e-01
# update_ics_u_t: 7.502e-01
# update_bcs1: 7.502e-01
# adaptive_constant_res_val: 3.189e-02
# adaptive_constant_ics_val: 3.191e-02
# adaptive_constant_bcs1_val: 3.191e-02
# It: 38600, Loss: 7.577e-03, loss_bcs: 1.532e-02e, loss_ics: 3.293e-02, Loss_r: 1.893e-01, Time: 0.02
# min_grad: 3.816e+01
# update_res: 7.501e-01
# update_ics_u_t: 7.495e-01
# update_bcs1: 7.503e-01
# adaptive_constant_res_val: 1.966e-02
# adaptive_constant_ics_val: 1.964e-02
# adaptive_constant_bcs1_val: 1.966e-02
# It: 38700, Loss: 3.711e-03, loss_bcs: 1.454e-02e, loss_ics: 3.615e-02, Loss_r: 1.381e-01, Time: 0.02
# min_grad: 1.824e+01
# update_res: 7.505e-01
# update_ics_u_t: 7.500e-01
# update_bcs1: 7.492e-01
# adaptive_constant_res_val: 4.114e-02
# adaptive_constant_ics_val: 4.111e-02
# adaptive_constant_bcs1_val: 4.107e-02
# It: 38800, Loss: 9.223e-03, loss_bcs: 1.594e-02e, loss_ics: 3.432e-02, Loss_r: 1.740e-01, Time: 0.02
# min_grad: 3.128e+01
# update_res: 7.501e-01
# update_ics_u_t: 7.501e-01
# update_bcs1: 7.498e-01
# adaptive_constant_res_val: 2.398e-02
# adaptive_constant_ics_val: 2.398e-02
# adaptive_constant_bcs1_val: 2.397e-02
# It: 38900, Loss: 3.421e-03, loss_bcs: 1.707e-02e, loss_ics: 3.535e-02, Loss_r: 9.026e-02, Time: 0.04
# min_grad: 1.900e+01
# update_res: 7.496e-01
# update_ics_u_t: 7.496e-01
# update_bcs1: 7.510e-01
# adaptive_constant_res_val: 3.945e-02
# adaptive_constant_ics_val: 3.945e-02
# adaptive_constant_bcs1_val: 3.952e-02
# It: 39000, Loss: 2.847e-02, loss_bcs: 1.550e-02e, loss_ics: 3.784e-02, Loss_r: 6.683e-01, Time: 0.02
# min_grad: 5.362e+01
# update_res: 7.505e-01
# update_ics_u_t: 7.496e-01
# update_bcs1: 7.495e-01
# adaptive_constant_res_val: 1.400e-02
# adaptive_constant_ics_val: 1.398e-02
# adaptive_constant_bcs1_val: 1.398e-02
# It: 39100, Loss: 3.329e-03, loss_bcs: 1.541e-02e, loss_ics: 3.781e-02, Loss_r: 1.847e-01, Time: 0.02
# min_grad: 1.708e+01
# update_res: 7.501e-01
# update_ics_u_t: 7.500e-01
# update_bcs1: 7.501e-01
# adaptive_constant_res_val: 4.391e-02
# adaptive_constant_ics_val: 4.390e-02
# adaptive_constant_bcs1_val: 4.391e-02
# It: 39200, Loss: 9.032e-03, loss_bcs: 1.481e-02e, loss_ics: 3.228e-02, Loss_r: 1.586e-01, Time: 0.02
# min_grad: 3.330e+01
# update_res: 7.502e-01
# update_ics_u_t: 7.497e-01
# update_bcs1: 7.500e-01
# adaptive_constant_res_val: 2.252e-02
# adaptive_constant_ics_val: 2.251e-02
# adaptive_constant_bcs1_val: 2.252e-02
# It: 39300, Loss: 4.526e-03, loss_bcs: 1.566e-02e, loss_ics: 3.529e-02, Loss_r: 1.500e-01, Time: 0.02
# min_grad: 3.236e+01
# update_res: 7.499e-01
# update_ics_u_t: 7.497e-01
# update_bcs1: 7.504e-01
# adaptive_constant_res_val: 2.317e-02
# adaptive_constant_ics_val: 2.317e-02
# adaptive_constant_bcs1_val: 2.319e-02
# It: 39400, Loss: 5.481e-03, loss_bcs: 1.676e-02e, loss_ics: 3.630e-02, Loss_r: 1.835e-01, Time: 0.02
# min_grad: 1.668e+01
# update_res: 7.497e-01
# update_ics_u_t: 7.504e-01
# update_bcs1: 7.501e-01
# adaptive_constant_res_val: 4.494e-02
# adaptive_constant_ics_val: 4.498e-02
# adaptive_constant_bcs1_val: 4.496e-02
# It: 39500, Loss: 7.707e-03, loss_bcs: 1.461e-02e, loss_ics: 3.720e-02, Loss_r: 1.196e-01, Time: 0.02
# min_grad: 4.228e+01
# update_res: 7.500e-01
# update_ics_u_t: 7.502e-01
# update_bcs1: 7.499e-01
# adaptive_constant_res_val: 1.774e-02
# adaptive_constant_ics_val: 1.774e-02
# adaptive_constant_bcs1_val: 1.774e-02
# It: 39600, Loss: 2.800e-03, loss_bcs: 1.680e-02e, loss_ics: 3.557e-02, Loss_r: 1.055e-01, Time: 0.02
# min_grad: 1.900e+01
# update_res: 7.499e-01
# update_ics_u_t: 7.503e-01
# update_bcs1: 7.500e-01
# adaptive_constant_res_val: 3.948e-02
# adaptive_constant_ics_val: 3.950e-02
# adaptive_constant_bcs1_val: 3.948e-02
# It: 39700, Loss: 8.458e-03, loss_bcs: 1.545e-02e, loss_ics: 3.281e-02, Loss_r: 1.660e-01, Time: 0.02
# min_grad: 2.114e+01
# update_res: 7.502e-01
# update_ics_u_t: 7.498e-01
# update_bcs1: 7.498e-01
# adaptive_constant_res_val: 3.549e-02
# adaptive_constant_ics_val: 3.547e-02
# adaptive_constant_bcs1_val: 3.547e-02
# It: 39800, Loss: 7.307e-03, loss_bcs: 1.661e-02e, loss_ics: 3.577e-02, Loss_r: 1.536e-01, Time: 0.02
# min_grad: 2.303e+01
# update_res: 7.501e-01
# update_ics_u_t: 7.500e-01
# update_bcs1: 7.499e-01
# adaptive_constant_res_val: 3.257e-02
# adaptive_constant_ics_val: 3.256e-02
# adaptive_constant_bcs1_val: 3.256e-02
# It: 39900, Loss: 6.539e-03, loss_bcs: 1.398e-02e, loss_ics: 3.459e-02, Loss_r: 1.522e-01, Time: 0.02
# min_grad: 1.560e+01
# update_res: 7.502e-01
# update_ics_u_t: 7.497e-01
# update_bcs1: 7.500e-01
# adaptive_constant_res_val: 4.808e-02
# adaptive_constant_ics_val: 4.805e-02
# adaptive_constant_bcs1_val: 4.808e-02
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 1.143e-02, loss_bcs: 1.484e-02e, loss_ics: 3.515e-02, Loss_r: 1.877e-01, Time: 1.94
# min_grad: 2.032e+01
# update_res: 7.502e-01
# update_ics_u_t: 7.498e-01
# update_bcs1: 7.498e-01
# adaptive_constant_res_val: 3.691e-02
# adaptive_constant_ics_val: 3.689e-02
# adaptive_constant_bcs1_val: 3.689e-02
# average lambda_bc1.7595e-02
# average lambda_bc1.7599e-02
# average lambda_res1.0
# Relative L2 error_u: 4.17e-01
# Relative L2 error_f: 5.17e-03
# Save uv NN parameters successfully in %s ...checkpoints/Dec-22-2023_19-33-23-247196_M2
# Final loss total loss: 1.142805e-02
# Final loss loss_res: 1.877054e-01
# Final loss loss_bcs: 1.483608e-02
# Final loss loss_ics: 3.514922e-02
# average of time_list: 895.6651058197021
# average of error_u_list: 0.41740550741254184
# average of error_f_list: 0.005174100689360629

# %%
def plot_lambda(self ):

    fontsize = 17
    fig, ax = plt.subplots()
    fig.set_size_inches([16,8])
    ax.semilogy(self.mean_adaptive_constant_bcs_log, label=r'$\bar{\nabla_\theta {u_{bc}}}$' , color = 'tab:green')
    ax.semilogy(self.mean_adaptive_constant_ics_log, label=r'$\bar{\nabla_\theta {u_{ics}}}$' , color = 'tab:blue')
    ax.semilogy(self.mean_adaptive_constant_res_log, label=r'$Max{\nabla_\theta {u_{phy}}}$' , color = 'tab:red')
    ax.set_xlabel("epochs", fontsize=fontsize)
    ax.set_ylabel(r'$\bar{\nabla_\theta {u}}$', fontsize=fontsize)
    ax.tick_params(labelsize=fontsize)
    ax.legend(loc='center left', bbox_to_anchor=(-0.25, 0.5))

    ax2 = ax.twinx() 

    # fig, ax = plt.subplots()
    # fig.set_size_inches([15,8])

    ax2.semilogy(self.adaptive_constant_bcs_log, label=r'$\bar{\lambda_{bc}}$'  ,  linestyle='dashed' , color = 'tab:green') 
    ax2.semilogy(self.adaptive_constant_ics_log, label=r'$\bar{\lambda_{ics}}$' , linestyle='dashed'  , color = 'tab:blue')
    ax2.semilogy(self.adaptive_constant_res_log, label=r'$\bar{\lambda_{phy}}$' ,  linestyle='dashed' , color = 'tab:red')
    ax2.set_xlabel("epochs", fontsize=fontsize)
    ax2.set_ylabel(r'$\bar{\lambda}$', fontsize=fontsize)
    ax2.tick_params(labelsize=fontsize)
    ax2.legend(loc='center right', bbox_to_anchor=(1.2, 0.5))

    plt.tight_layout()

    path = os.path.join(self.dirname,'lambda_history.png')
    plt.savefig(path)

plot_lambda(model)

# %%
def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
    from mpl_toolkits.axes_grid1 import ImageGrid

    ### Plot ###
    print(x1.shape)
    print(x2.shape)

    # Exact solution & Predicted solution
    # Exact soluton
    U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')
    print(u_star.shape)

    # Predicted solution
    U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
    F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

    titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $f(x)$' , 'Predicted $f(x)$' , 'Absolute error']
    data = [U_star , U_pred ,  np.abs(U_star - U_pred) , F_star , F_pred ,  np.abs(F_star - F_pred) ]
    
    print(U_star.shape)

    fig_1 = plt.figure(1, figsize=(13, 5))
    grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                    label_mode="1", axes_pad=1.7, share_all=False, 
                    cbar_mode="each", cbar_location="right", 
                    cbar_size="5%", cbar_pad=0.0)
# CREATE ARGUMENTS DICT FOR CONTOURPLOTS
    minmax_list = []
    kwargs_list = []
    for d in data:
        # if(local):
        #     minmax_list.append([np.min(d), np.max(d)])
        # else:
        minmax_list.append([np.min(d), np.max(d)])

        kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60),
            cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

    for ax, z, kwargs, minmax, title in zip(grid, data, kwargs_list, minmax_list, titles):
    #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
        #pcfsets.append(pcf)
        # if (timeStp == 0):
            #  print( z[timeStp,:,:])
        pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
        print(z.shape)
        cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
        ax.cax.tick_params(labelsize=14.5)
        ax.set_title(title, fontsize=14.5, pad=7)
        ax.set_ylabel("time", labelpad=14.5, fontsize=14.5, rotation="horizontal")
        ax.set_xlabel("x", fontsize=14.5)
        ax.tick_params(labelsize=14.5)
        ax.set_xlim(x1.min(), x1.max())
        ax.set_ylim(x2.min(), x2.max())
        ax.set_aspect("equal")

    fig_1.set_size_inches(15, 10, True)
    fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
    plt.tight_layout()
    plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
    plt.close("all" , )

# %%
plt_prediction(model, t , x , X_star , u_star , u_pred , f_star , f_pred)
# Out:
# (100, 100)
# (100, 100)
# (10000, 1)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)

# %%
X_star.shape
# Out:
# (10000, 2)

# %%
# Test data
nn = 100
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

# Exact solution
u_star = u(X_star)
f_star = f(X_star, alpha, beta, gamma, k)

# Predictions
u_pred = mode.predict_u(X_star)
f_pred = mode.predict_r(X_star)

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
print('Relative L2 error_u: {:.2e}'.format(error_u))

### Plot ###

# Test data
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (t, x), method='cubic')

U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (t, x), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact u(x)')

plt.subplot(1, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(x)')

plt.subplot(1, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()


fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(t, x, F_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact u(x)')

plt.subplot(1, 3, 2)
plt.pcolor(t, x, F_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(x)')

plt.subplot(1, 3, 3)
plt.pcolor(t, x, np.abs(F_star - F_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %%
# Loss
loss_r = mode.loss_r_log
loss_u = mode.loss_u_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_r, label='$\mathcal{L}_{r}$')
ax.plot(loss_u, label='$\mathcal{L}_{u}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Adaptive Constant
adaptive_constant_ics = mode.adaptive_constant_ics_log
adaptive_constant_bcs = mode.adaptive_constant_bcs_log

fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant_ics, label='$\lambda_{u_0}$')
ax.plot(adaptive_constant_bcs, label='$\lambda_{u_b}$')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Gradients at the end of training
data_gradients_ics = mode.dict_gradients_ics_layers
data_gradients_bcs = mode.dict_gradients_bcs_layers
data_gradients_res = mode.dict_gradients_res_layers

num_hidden_layers = len(layers) - 1
cnt = 1
fig_4 = plt.figure(4, figsize=(13, 8))
for j in range(num_hidden_layers):
    ax = plt.subplot(2, 3, cnt)
    gradients_ics = data_gradients_ics['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]

    sns.distplot(gradients_ics, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_0}\mathcal{L}_{u_0}$')
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')

    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    ax.set_xlim([-1, 1])
    ax.set_ylim([0, 500])
    ax.get_legend().remove()
    cnt += 1
handles, labels = ax.get_legend_handles_labels()
fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.3, 0.01),
                borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=3)
plt.tight_layout()
plt.show()

# %%
# Eigenvalues of Hessian of losses if applicable
if stiff_ratio:
    eigenvalues_list = mode.eigenvalue_log
    eigenvalues_ics_list = mode.eigenvalue_ics_log
    eigenvalues_bcs_list = mode.eigenvalue_bcs_log
    eigenvalues_res_list = mode.eigenvalue_res_log

    eigenvalues_ics = eigenvalues_ics_list[-1]
    eigenvalues_bcs = eigenvalues_bcs_list[-1]
    eigenvalues_res = eigenvalues_res_list[-1]

    fig_5 = plt.figure(5)
    ax = fig_5.add_subplot(1, 1, 1)
    ax.plot(eigenvalues_ics, label='$\mathcal{L}_{u_0}$')
    ax.plot(eigenvalues_bcs, label='$\mathcal{L}_{u_b}$')
    ax.plot(eigenvalues_res, label='$\mathcal{L}_r$')
    ax.set_xlabel('index')
    ax.set_ylabel('eigenvalue')
    ax.set_yscale('symlog')
    plt.legend()
    plt.tight_layout()
    plt.show()
