# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import griddata
# from Klein_Gordon_model_tf import Sampler, Klein_Gordon
import timeit
import os
os.environ["KMP_WARNINGS"] = "FALSE" 

import scipy
import scipy.io
import time


import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle
def u(x):
    """
    :param x: x = (t, x)
    """
    return x[:, 1:2] * np.cos(5 * np.pi * x[:, 0:1]) + (x[:, 0:1] * x[:, 1:2])**3

def u_tt(x):
    return - 25 * np.pi**2 * x[:, 1:2] * np.cos(5 * np.pi * x[:, 0:1]) + 6 * x[:,0:1] * x[:,1:2]**3

def u_xx(x):
    return np.zeros((x.shape[0], 1)) +  6 * x[:,1:2] * x[:,0:1]**3

def f(x, alpha, beta, gamma, k):
    return u_tt(x) + alpha * u_xx(x) + beta * u(x) + gamma * u(x)**k

def operator(u, t, x, alpha, beta, gamma, k,  sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt + alpha * u_xx + beta * u + gamma * u**k
    return residual

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Klein_Gordon:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess):
            # mode = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess)



        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Klein_Gordon constant
        self.alpha = tf.constant(alpha, dtype=tf.float32)
        self.beta = tf.constant(beta, dtype=tf.float32)
        self.gamma = tf.constant(gamma, dtype=tf.float32)
        self.k = tf.constant(k, dtype=tf.float32)

        self.rate = 0.5
        self.rho = 0.5
        self.T = 0.9
        # Record stiff ratio
        # self.stiff_ratio = stiff_ratio

        # Adaptive re-weighting constant
        self.rate = 0.9
        self.adaptive_constant_ics_val = np.array(1.0)
        self.adaptive_constant_bcs_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)

        # if model in ['M3', 'M4']:
        #     # Initialize encoder weights and biases
        #     self.encoder_weights_1 = self.xavier_init([2, layers[1]])
        #     self.encoder_biases_1 = self.xavier_init([1, layers[1]])

        #     self.encoder_weights_2 = self.xavier_init([2, layers[1]])
        #     self.encoder_biases_2 = self.xavier_init([1, layers[1]])

        # Define Tensorflow session
        self.sess = sess #tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.adaptive_constant_ics_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_ics_val.shape)
        self.adaptive_constant_bcs_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)

        # Boundary loss and Initial loss
        self.loss_ic_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ic_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred - self.u_bc1_tf))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred - self.u_bc2_tf))

        self.loss_bcs =  (self.loss_bc1 + self.loss_bc2)
        self.loss_ics =  (self.loss_ic_u + self.loss_ic_u_t)

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred - self.r_tf))

        # Total loss
        self.loss =  self.adaptive_constant_res_tf *  self.loss_res + self.adaptive_constant_bcs_tf * self.loss_bcs + self.adaptive_constant_ics_tf * self.loss_ics

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)


        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bcs,  self.loss_ics  ] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs" , "loss_ics" ] 
        
        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_u_log = []
        self.loss_r_log = []
        # self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs_layers = self.generate_grad_dict()
        self.dict_gradients_ics_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_ics = []
        self.grad_bcs = []

        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])
            self.grad_ics.append(tf.gradients(self.loss_ics, self.weights[i])[0])

        # Store the adaptive constant
        self.adaptive_constant_ics_log = []
        self.adaptive_constant_bcs_log = []
        self.adaptive_constant_res_log = []

        # Compute the adaptive constant
        self.adaptive_constant_ics_list = []
        self.adaptive_constant_bcs_list = []
        
        self.max_grad_res_list = []
        self.mean_grad_bcs_list = []
        self.mean_grad_ics_list = []

        self.mean_grad_res_log  = []
        self.mean_grad_bcs_log  = []
        self.mean_grad_ics_log  = []
    
        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.reduce_mean(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs_list.append(tf.reduce_mean(tf.abs(self.grad_bcs[i])))
            self.mean_grad_ics_list.append(tf.reduce_mean(tf.abs(self.grad_ics[i])))
        
        self.mean_grad_res = tf.reduce_mean(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs = tf.reduce_mean(tf.stack(self.mean_grad_bcs_list))
        self.mean_grad_ics = tf.reduce_mean(tf.stack(self.mean_grad_ics_list))
        
        # self.adaptive_constant_bcs = self.max_grad_res / self.mean_grad_bcs
        # self.adaptive_constant_ics = self.max_grad_res / self.mean_grad_ics

        # # Stiff Ratio
        # if self.stiff_ratio:
        #     self.Hessian, self.Hessian_ics, self.Hessian_bcs, self.Hessian_res = self.get_H_op()
        #     self.eigenvalues, _ = tf.linalg.eigh(self.Hessian)
        #     self.eigenvalues_ics, _ = tf.linalg.eigh(self.Hessian_ics)
        #     self.eigenvalues_bcs, _ = tf.linalg.eigh(self.Hessian_bcs)
        #     self.eigenvalues_res, _ = tf.linalg.eigh(self.Hessian_res)

        #     self.eigenvalue_log = []
        #     self.eigenvalue_ics_log = []
        #     self.eigenvalue_bcs_log = []
        #     self.eigenvalue_res_log = []

        # Initialize Tensorflow variables

        self.prev_lam_ics =1
        self.prev_lam_bcs = 1
        self.prev_lam_res = 1
        self.index = 1
        
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Create dictionary to store gradients
    def generate_grad_dict(self, layers):
        num = len(layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Save gradients
    def save_gradients(self, tf_dict):
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_ics_value , grad_bcs_value, grad_res_value= self.sess.run([self.grad_ics[i],
                                                                            self.grad_bcs[i],
                                                                            self.grad_res[i]],
                                                                            feed_dict=tf_dict)

            # save gradients of loss_res and loss_bcs
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics_value.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bcs_value.flatten())
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res_value.flatten())
        return None

    # Compute the Hessian
    def flatten(self, vectors):
        return tf.concat([tf.reshape(v, [-1]) for v in vectors], axis=0)

    def get_Hv(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_ics(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_ics, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_bcs(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_bcs, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_res(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_res,
                                                   self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod,
                                          self.weights))
        return Hv_op

    def get_H_op(self):
        self.P = self.flatten(self.weights).get_shape().as_list()[0]
        H = tf.map_fn(self.get_Hv, tf.eye(self.P, self.P),
                      dtype='float32')
        H_ics = tf.map_fn(self.get_Hv_ics, tf.eye(self.P, self.P),
                          dtype='float32')
        H_bcs = tf.map_fn(self.get_Hv_bcs, tf.eye(self.P, self.P),
                          dtype='float32')
        H_res = tf.map_fn(self.get_Hv_res, tf.eye(self.P, self.P),
                          dtype='float32')

        return H, H_ics, H_bcs, H_res

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # if self.model in ['M3', 'M4']:
    #     num_layers = len(self.layers)
    #     encoder_1 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_1), self.encoder_biases_1))
    #     encoder_2 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_2), self.encoder_biases_2))

    #     for l in range(0, num_layers - 2):
    #         W = self.weights[l]
    #         b = self.biases[l]
    #         H = tf.math.multiply(tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_1) + \
    #             tf.math.multiply(1 - tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_2)

    #     W = self.weights[-1]
    #     b = self.biases[-1]
    #     H = tf.add(tf.matmul(H, W), b)
    #     return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1))
        return u

    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,  self.alpha, self.beta, self.gamma, self.k, self.sigma_t, self.sigma_x)
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
################################################################################################################

    def train(self, nIter=10000):

        start_time = timeit.default_timer()
        batch_size = 500
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size)
        X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
        X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)

        batch_size = 5000

        # Fetch residual mini-batch
        X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.u_bc1_tf: u_bc1_batch,
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.u_bc2_tf: u_bc2_batch,
                    self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                    self.r_tf: f_res_batch,
                    self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val}

        # Run the Tensorflow session to minimize the loss

        for it in range(nIter):
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_u, self.loss_res], tf_dict)

                # Compute and Print adaptive weights during training
                # Compute the adaptive constant
                adaptive_constant_ics_val, adaptive_constant_bcs_val = self.sess.run( [self.adaptive_constant_ics, self.adaptive_constant_bcs], tf_dict)
                # Print adaptive weights during training
                self.adaptive_constant_ics_val = adaptive_constant_ics_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs_val = adaptive_constant_bcs_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val

                # # Store loss and adaptive weights
                # self.loss_u_log.append(loss_u_value)
                # self.loss_r_log.append(loss_r_value)

                # self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)
                # self.adaptive_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                if it % 1000 == 0:

                    print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' %  (it, loss_value, loss_u_value, loss_r_value, elapsed))
                    print("constant_ics_val: {:.3f}, constant_bcs_val: {:.3f}".format(  self.adaptive_constant_ics_val,  self.adaptive_constant_bcs_val))
                start_time = timeit.default_timer()

            # # Compute the eigenvalues of the Hessian of losses
            # if self.stiff_ratio:
            #     if it % 1000 == 0:
            #         print("Eigenvalues information stored ...")
            #         eigenvalues, eigenvalues_ics, eigenvalues_bcs, eigenvalues_res = self.sess.run([self.eigenvalues,
            #                                                                                         self.eigenvalues_ics,
            #                                                                                         self.eigenvalues_bcs,
            #                                                                                         self.eigenvalues_res], tf_dict)
            #         self.eigenvalue_log.append(eigenvalues)
            #         self.eigenvalue_ics_log.append(eigenvalues_bcs)
            #         self.eigenvalue_bcs_log.append(eigenvalues_bcs)
            #         self.eigenvalue_res_log.append(eigenvalues_res)

            # # Store gradients
            # if it % 10000 == 0:
            #     self.save_gradients(tf_dict)
            #     print("Gradients information stored ...")

################################################################################################################
                

    def lambda_balance(self ,term , index):

        loss_list = ["loss_res" , "loss_bcs" , "loss_ics"] 
        m = len(loss_list)
        num = np.exp(self.loss_history[term][-1] /(self.T * self.loss_history[term][index]))
        denum = 0 

        for  key in loss_list:
            denum +=  np.exp(self.loss_history[key][-1] /(self.T * self.loss_history[key][index]))
        return m * (num / denum)
     
    def relobralo( self, term ,prev_lamda ):

        lambda_hist = self.rho  * prev_lamda + (1.0 - self.rho) *  self.lambda_balance( term ,1)
        lambda_i = self.rate  * lambda_hist + (1.0 - self.rate) *  self.lambda_balance( term , self.index)

        return lambda_i
    
    ###################################################################################
    def trainmb(self, nIter=10000, batch_size=128):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(1,nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size)
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)

            # Fetch residual mini-batch
            X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.u_bc1_tf: u_bc1_batch,
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.u_bc2_tf: u_bc2_batch,
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.r_tf: f_res_batch,
                       self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                       self.adaptive_constant_res_tf: self.adaptive_constant_res_val,
                       self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val}

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)

            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value , loss_ics, loss_bcs , loss_r_value = self.sess.run([self.loss ,self.loss_ics, self.loss_bcs, self.loss_res], tf_dict)
                self.print('It: %d, Loss: %.3e, loss_ics: %.3e, loss_bcs: %.3e, Loss_r: %.3e, Time: %.2f' %(it, loss_value, loss_ics, loss_bcs ,  loss_r_value, elapsed))

                # Compute and Print adaptive weights during training
                
            if it % 100 == 0:

                # Compute the adaptive constant
                # Print adaptive weights during training
                self.adaptive_constant_ics_val =   self.relobralo( "loss_ics"  ,self.prev_lam_ics )  
                self.adaptive_constant_bcs_val =  self.relobralo( "loss_bcs"  ,self.prev_lam_bcs )  
                self.adaptive_constant_res_val =  self.relobralo( "loss_res"  ,self.prev_lam_res )  

                # # Store loss and adaptive weights
                # self.loss_u_log.append(loss_u_value)
                # self.loss_r_log.append(loss_r_value)

                self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)
                self.adaptive_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                self.adaptive_constant_res_log.append(self.adaptive_constant_res_val)
                
                mean_grad_bcs , mean_grad_ics, mean_grad_res = self.sess.run([self.mean_grad_bcs ,self.mean_grad_ics, self.mean_grad_res], tf_dict)

                self.mean_grad_bcs_log.append(mean_grad_bcs)
                self.mean_grad_ics_log.append(mean_grad_ics)
                self.mean_grad_res_log.append(mean_grad_res)

                self.print("constant_ics_val: {:.3f}".format( self.adaptive_constant_ics_val))
                self.print("constant_bcs_val: {:.3f}".format( self.adaptive_constant_bcs_val))
                self.print("constant_res_val: {:.3f}".format( self.adaptive_constant_res_val))

                self.prev_lam_ics = self.adaptive_constant_ics_val
                self.prev_lam_bcs = self.adaptive_constant_bcs_val
                self.prev_lam_res = self.adaptive_constant_res_val
                self.index= it

            sys.stdout.flush()
            start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

 

    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

  # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1  , grad_ics  = self.sess.run([ self.grad_res[i],self.grad_bcs[i],self.grad_ics[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs_layers['layer_' + str(j + 1)][-1]
            gradients_ics = self.dict_gradients_ics_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')
            sns.distplot(gradients_ics, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{ics}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=3)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all" , )
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        plt.close("all" , )
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)



    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
        from mpl_toolkits.axes_grid1 import ImageGrid

        ### Plot ###
        plt.close("all" , )

        # Exact solution & Predicted solution
        # Exact soluton
        U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
        F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

        # Predicted solution
        U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
        F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

        titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $f(x)$' , 'Predicted $f(x)$' , 'Absolute error']
        data = [U_star , U_pred ,  np.abs(U_star - U_pred) , F_star , F_pred ,  np.abs(F_star - F_pred) ]
        

        fig_1 = plt.figure(1, figsize=(13, 5))
        grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                        label_mode="1", axes_pad=1.7, share_all=False, 
                        cbar_mode="each", cbar_location="right", 
                        cbar_size="5%", cbar_pad=0.0)
    # CREATE ARGUMENTS DICT FOR CONTOURPLOTS
        minmax_list = []
        kwargs_list = []
        for d in data:
            # if(local):
            #     minmax_list.append([np.min(d), np.max(d)])
            # else:
            minmax_list.append([np.min(d), np.max(d)])

            kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60),
                cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

        for ax, z, kwargs, minmax, title in zip(grid, data, kwargs_list, minmax_list, titles):
        #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
            #pcfsets.append(pcf)
            # if (timeStp == 0):
                #  print( z[timeStp,:,:])
            pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
            cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
            ax.cax.tick_params(labelsize=14.5)
            ax.set_title(title, fontsize=14.5, pad=7)
            ax.set_ylabel("time", labelpad=14.5, fontsize=14.5, rotation="horizontal")
            ax.set_xlabel("x", fontsize=14.5)
            ax.tick_params(labelsize=14.5)
            ax.set_xlim(x1.min(), x1.max())
            ax.set_ylim(x2.min(), x2.max())
            ax.set_aspect("equal")

        fig_1.set_size_inches(15, 10, True)
        fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
        plt.close("all" , )


    def plot_lambda(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adaptive_constant_bcs_log, label=r'$lambda_{bc}$')
        ax.semilogy(self.adaptive_constant_ics_log, label=r'$lambda_{ic}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\lambda$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'lambda_history.png')
        plt.savefig(path)
        plt.close("all" , )





    def plot_grad(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.mean_grad_bcs_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc}}}$')
        ax.semilogy(self.mean_grad_res_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{res}}}$')
        ax.semilogy(self.mean_grad_ics_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{ics}}}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\bar{\nabla_{\theta} \mathcal{L}}$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)
        plt.close("all" , )

# %%
def test_method(method , layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma ,k ,mode , stiff_ratio ,  X_star , u_star , f_star):


    model = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, stiff_ratio)

    # Train model
    start_time = time.time()

    if method =="full_batch":
        model.train(nIter=40001 )
    elif method =="mini_batch":
        model.trainmb(nIter=40001, batch_size=128)
    else:
        print("unknown method!")
    elapsed = time.time() - start_time

    # Predictions
    u_pred = model.predict_u(X_star)
    f_pred = model.predict_r(X_star)

    # Relative error
    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_f: {:.2e}'.format(error_f))

    return [elapsed, error_u , error_f]

# %%
# Parameters of equations
alpha = -1.0
beta = 0.0
gamma = 1.0
k = 3
# Domain boundaries
ics_coords = np.array([[0.0, 0.0], [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0], [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0], [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0], [1.0, 1.0]])


# Define model
layers = [2, 50, 50, 50, 50, 50, 1]
mode = 'relobralo'          # Method: 'M1', 'M2', 'M3', 'M4'
stiff_ratio = False  # Log the eigenvalues of Hessian of losses



nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 128

# Test data
nn = 100
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

# Exact solution
u_star = u(X_star)
f_star = f(X_star, alpha, beta, gamma, k)


iterations = 1
methods = ["mini_batch" ]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_f_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create initial conditions samplers
        ics_sampler = Sampler(2, ics_coords, lambda x: u(x), name='Initial Condition 1')

        # Create boundary conditions samplers
        bc1 = Sampler(2, bc1_coords, lambda x: u(x), name='Dirichlet BC1')
        bc2 = Sampler(2, bc2_coords, lambda x: u(x), name='Dirichlet BC2')
        bcs_sampler = [bc1, bc2]

        # Create residual sampler
        res_sampler = Sampler(2, dom_coords, lambda x: f(x, alpha, beta, gamma, k), name='Forcing')
        bcs_sampler = [bc1, bc2]

        # [elapsed, error_u , error_f] = test_method(mtd , layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma ,k ,mode , stiff_ratio ,  X_star , u_star , f_star)

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            model = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess)

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                model.train(nIter=nIter )
            elif mtd =="mini_batch":
                model.trainmb(nIter=nIter, batch_size=128)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            f_pred = model.predict_r(X_star)

            # Relative error
            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_f: {:.2e}'.format(error_f))
            
            model.print("average adaptive_constant_bcs_log : " , np.average(model.adaptive_constant_bcs_log))
            model.print("average adaptive_constant_ics_log : " , np.average(model.adaptive_constant_ics_log))
            model.print("average adaptive_constant_res_log : " , np.average(model.adaptive_constant_res_log))
            # sess.close()  

            model.plot_lambda()
            model.plot_grad()
            model.save_NN()
            model.plt_prediction( t , x , X_star , u_star , u_pred , f_star , f_pred)

            time_list.append(elapsed)
            error_u_list.append(error_u)
            error_f_list.append(error_f)

    # print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_f_list:" , sum(error_f_list) / len(error_f_list) )

    result_dict[mtd] = [time_list ,error_u_list ,  error_f_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_Helmholtz_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_12945/3607589975.py:66: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12945/3607589975.py:67: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12945/3607589975.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12945/3607589975.py:68: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-18 02:41:45.394454: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-18 02:41:45.467366: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-18 02:41:45.468146: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c98b930b40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-18 02:41:45.468171: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-18 02:41:45.481178: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_12945/3267424194.py:278: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12945/3267424194.py:71: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From /tmp/ipykernel_12945/3267424194.py:121: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_12945/3267424194.py:123: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tmp/ipykernel_12945/3267424194.py:200: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 1.097e+04, loss_ics: 2.426e+01, loss_bcs: 4.747e+00, Loss_r: 1.094e+04, Time: 0.04
# constant_ics_val: 2.100
# constant_bcs_val: 0.450
# constant_res_val: 0.450
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 3.791e+03, loss_ics: 1.613e+01, loss_bcs: 7.676e+00, Loss_r: 8.342e+03, Time: 0.01
# constant_ics_val: 2.361
# constant_bcs_val: 0.359
# constant_res_val: 0.280
# It: 300, Loss: 1.033e+03, loss_ics: 1.475e+01, loss_bcs: 9.357e+00, Loss_r: 3.547e+03, Time: 0.08
# constant_ics_val: 2.498
# constant_bcs_val: 0.325
# constant_res_val: 0.178
# It: 400, Loss: 2.994e+02, loss_ics: 1.865e+01, loss_bcs: 1.289e+01, Loss_r: 1.399e+03, Time: 0.03
# constant_ics_val: 2.576
# constant_bcs_val: 0.302
# constant_res_val: 0.122
# It: 500, Loss: 1.444e+02, loss_ics: 1.697e+01, loss_bcs: 1.450e+01, Loss_r: 7.884e+02, Time: 0.04
# constant_ics_val: 1.491
# constant_bcs_val: 1.382
# constant_res_val: 0.127
# It: 600, Loss: 6.862e+01, loss_ics: 1.610e+01, loss_bcs: 1.283e+01, Loss_r: 2.117e+02, Time: 0.04
# constant_ics_val: 1.561
# constant_bcs_val: 1.315
# constant_res_val: 0.124
# It: 700, Loss: 5.833e+01, loss_ics: 1.313e+01, loss_bcs: 1.180e+01, Loss_r: 1.804e+02, Time: 0.03
# constant_ics_val: 1.088
# constant_bcs_val: 1.742
# constant_res_val: 0.170
# It: 800, Loss: 5.097e+01, loss_ics: 1.140e+01, loss_bcs: 1.004e+01, Loss_r: 1.242e+02, Time: 0.02
# constant_ics_val: 0.836
# constant_bcs_val: 1.981
# constant_res_val: 0.184
# It: 900, Loss: 3.338e+01, loss_ics: 9.118e+00, loss_bcs: 5.870e+00, Loss_r: 7.702e+01, Time: 0.03
# constant_ics_val: 1.804
# constant_bcs_val: 1.030
# constant_res_val: 0.167
# It: 1000, Loss: 1.262e+01, loss_ics: 6.177e-01, loss_bcs: 1.700e+00, Loss_r: 5.856e+01, Time: 0.05
# constant_ics_val: 0.971
# constant_bcs_val: 1.787
# constant_res_val: 0.242
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 1.201e+01, loss_ics: 4.203e-01, loss_bcs: 4.322e-01, Loss_r: 4.474e+01, Time: 0.06
# constant_ics_val: 1.051
# constant_bcs_val: 1.480
# constant_res_val: 0.469
# It: 1200, Loss: 1.503e+01, loss_ics: 3.926e-01, loss_bcs: 2.718e-01, Loss_r: 3.028e+01, Time: 0.03
# constant_ics_val: 1.140
# constant_bcs_val: 1.262
# constant_res_val: 0.598
# It: 1300, Loss: 1.113e+01, loss_ics: 4.059e-01, loss_bcs: 2.428e-01, Loss_r: 1.732e+01, Time: 0.05
# constant_ics_val: 1.162
# constant_bcs_val: 1.186
# constant_res_val: 0.652
# It: 1400, Loss: 2.361e+01, loss_ics: 4.881e-01, loss_bcs: 1.886e-01, Loss_r: 3.503e+01, Time: 0.04
# constant_ics_val: 1.333
# constant_bcs_val: 0.997
# constant_res_val: 0.670
# It: 1500, Loss: 5.870e+00, loss_ics: 2.788e-01, loss_bcs: 1.764e-01, Loss_r: 7.942e+00, Time: 0.03
# constant_ics_val: 1.211
# constant_bcs_val: 1.074
# constant_res_val: 0.715
# It: 1600, Loss: 5.081e+00, loss_ics: 2.082e-01, loss_bcs: 1.313e-01, Loss_r: 6.553e+00, Time: 0.06
# constant_ics_val: 1.135
# constant_bcs_val: 1.069
# constant_res_val: 0.795
# It: 1700, Loss: 6.792e+00, loss_ics: 3.233e-01, loss_bcs: 9.941e-02, Loss_r: 7.943e+00, Time: 0.04
# constant_ics_val: 1.185
# constant_bcs_val: 1.011
# constant_res_val: 0.803
# It: 1800, Loss: 9.446e+00, loss_ics: 5.727e-01, loss_bcs: 8.637e-02, Loss_r: 1.080e+01, Time: 0.05
# constant_ics_val: 1.128
# constant_bcs_val: 1.025
# constant_res_val: 0.848
# It: 1900, Loss: 3.841e+00, loss_ics: 1.265e-01, loss_bcs: 8.228e-02, Loss_r: 4.264e+00, Time: 0.05
# constant_ics_val: 1.082
# constant_bcs_val: 1.064
# constant_res_val: 0.853
# It: 2000, Loss: 2.016e+01, loss_ics: 1.382e-01, loss_bcs: 8.709e-02, Loss_r: 2.334e+01, Time: 0.08
# constant_ics_val: 0.956
# constant_bcs_val: 0.962
# constant_res_val: 1.082
# It: 2100, Loss: 8.939e+00, loss_ics: 1.347e-01, loss_bcs: 8.454e-02, Loss_r: 8.068e+00, Time: 0.06
# constant_ics_val: 1.101
# constant_bcs_val: 0.958
# constant_res_val: 0.941
# It: 2200, Loss: 2.354e+01, loss_ics: 6.311e-01, loss_bcs: 8.083e-02, Loss_r: 2.421e+01, Time: 0.04
# constant_ics_val: 1.957
# constant_bcs_val: 0.533
# constant_res_val: 0.510
# It: 2300, Loss: 9.984e-01, loss_ics: 5.984e-02, loss_bcs: 1.038e-01, Loss_r: 1.619e+00, Time: 0.06
# constant_ics_val: 1.378
# constant_bcs_val: 0.937
# constant_res_val: 0.685
# It: 2400, Loss: 1.849e+00, loss_ics: 7.559e-02, loss_bcs: 5.990e-02, Loss_r: 2.463e+00, Time: 0.03
# constant_ics_val: 1.185
# constant_bcs_val: 0.938
# constant_res_val: 0.877
# It: 2500, Loss: 3.306e+00, loss_ics: 1.458e-01, loss_bcs: 5.268e-02, Loss_r: 3.518e+00, Time: 0.05
# constant_ics_val: 1.130
# constant_bcs_val: 0.944
# constant_res_val: 0.926
# It: 2600, Loss: 3.124e+00, loss_ics: 7.402e-02, loss_bcs: 4.572e-02, Loss_r: 3.235e+00, Time: 0.03
# constant_ics_val: 1.066
# constant_bcs_val: 0.977
# constant_res_val: 0.957
# It: 2700, Loss: 2.017e+00, loss_ics: 6.868e-02, loss_bcs: 4.507e-02, Loss_r: 1.985e+00, Time: 0.08
# constant_ics_val: 1.063
# constant_bcs_val: 1.002
# constant_res_val: 0.935
# It: 2800, Loss: 7.114e+00, loss_ics: 2.269e-01, loss_bcs: 3.602e-02, Loss_r: 7.311e+00, Time: 0.05
# constant_ics_val: 0.972
# constant_bcs_val: 0.927
# constant_res_val: 1.100
# It: 2900, Loss: 3.081e+00, loss_ics: 7.278e-02, loss_bcs: 3.373e-02, Loss_r: 2.707e+00, Time: 0.07
# constant_ics_val: 0.985
# constant_bcs_val: 1.015
# constant_res_val: 1.000
# It: 3000, Loss: 1.534e+00, loss_ics: 6.580e-02, loss_bcs: 2.539e-02, Loss_r: 1.444e+00, Time: 0.06
# constant_ics_val: 1.056
# constant_bcs_val: 1.005
# constant_res_val: 0.939
# It: 3100, Loss: 2.564e+00, loss_ics: 8.479e-02, loss_bcs: 3.729e-02, Loss_r: 2.596e+00, Time: 0.04
# constant_ics_val: 1.029
# constant_bcs_val: 1.061
# constant_res_val: 0.910
# It: 3200, Loss: 3.716e+00, loss_ics: 8.043e-02, loss_bcs: 2.387e-02, Loss_r: 3.965e+00, Time: 0.04
# constant_ics_val: 1.167
# constant_bcs_val: 0.953
# constant_res_val: 0.880
# It: 3300, Loss: 1.307e+00, loss_ics: 5.457e-02, loss_bcs: 2.931e-02, Loss_r: 1.382e+00, Time: 0.03
# constant_ics_val: 1.058
# constant_bcs_val: 1.077
# constant_res_val: 0.864
# It: 3400, Loss: 1.841e+00, loss_ics: 7.804e-02, loss_bcs: 1.977e-02, Loss_r: 2.010e+00, Time: 0.04
# constant_ics_val: 1.143
# constant_bcs_val: 0.964
# constant_res_val: 0.893
# It: 3500, Loss: 2.511e+00, loss_ics: 6.985e-02, loss_bcs: 2.366e-02, Loss_r: 2.696e+00, Time: 0.05
# constant_ics_val: 1.013
# constant_bcs_val: 0.965
# constant_res_val: 1.023
# It: 3600, Loss: 1.515e+01, loss_ics: 3.801e-01, loss_bcs: 2.518e-02, Loss_r: 1.442e+01, Time: 0.02
# constant_ics_val: 0.960
# constant_bcs_val: 0.868
# constant_res_val: 1.172
# It: 3700, Loss: 9.750e+00, loss_ics: 9.228e-02, loss_bcs: 3.195e-02, Loss_r: 8.222e+00, Time: 0.09
# constant_ics_val: 1.109
# constant_bcs_val: 0.926
# constant_res_val: 0.966
# It: 3800, Loss: 2.215e+00, loss_ics: 4.726e-02, loss_bcs: 2.249e-02, Loss_r: 2.218e+00, Time: 0.02
# constant_ics_val: 1.064
# constant_bcs_val: 0.983
# constant_res_val: 0.953
# It: 3900, Loss: 1.525e+00, loss_ics: 4.560e-02, loss_bcs: 2.077e-02, Loss_r: 1.529e+00, Time: 0.07
# constant_ics_val: 1.046
# constant_bcs_val: 0.996
# constant_res_val: 0.958
# It: 4000, Loss: 3.113e+00, loss_ics: 5.729e-02, loss_bcs: 1.786e-02, Loss_r: 3.167e+00, Time: 0.03
# constant_ics_val: 0.959
# constant_bcs_val: 0.912
# constant_res_val: 1.130
# It: 4100, Loss: 1.757e+00, loss_ics: 4.765e-02, loss_bcs: 1.720e-02, Loss_r: 1.501e+00, Time: 0.07
# constant_ics_val: 1.039
# constant_bcs_val: 0.920
# constant_res_val: 1.041
# It: 4200, Loss: 1.141e+00, loss_ics: 3.618e-02, loss_bcs: 2.156e-02, Loss_r: 1.041e+00, Time: 0.04
# constant_ics_val: 1.011
# constant_bcs_val: 1.020
# constant_res_val: 0.969
# It: 4300, Loss: 1.308e+00, loss_ics: 5.812e-02, loss_bcs: 1.363e-02, Loss_r: 1.274e+00, Time: 0.05
# constant_ics_val: 1.103
# constant_bcs_val: 0.948
# constant_res_val: 0.949
# It: 4400, Loss: 2.845e+00, loss_ics: 5.643e-02, loss_bcs: 1.501e-02, Loss_r: 2.917e+00, Time: 0.06
# constant_ics_val: 1.046
# constant_bcs_val: 0.961
# constant_res_val: 0.994
# It: 4500, Loss: 1.785e+00, loss_ics: 4.527e-02, loss_bcs: 1.416e-02, Loss_r: 1.735e+00, Time: 0.04
# constant_ics_val: 1.050
# constant_bcs_val: 0.995
# constant_res_val: 0.955
# It: 4600, Loss: 2.775e+00, loss_ics: 4.748e-02, loss_bcs: 1.374e-02, Loss_r: 2.839e+00, Time: 0.04
# constant_ics_val: 1.052
# constant_bcs_val: 0.986
# constant_res_val: 0.962
# It: 4700, Loss: 8.135e-01, loss_ics: 3.875e-02, loss_bcs: 1.915e-02, Loss_r: 7.838e-01, Time: 0.05
# constant_ics_val: 1.046
# constant_bcs_val: 1.023
# constant_res_val: 0.931
# It: 4800, Loss: 1.391e+00, loss_ics: 3.330e-02, loss_bcs: 1.535e-02, Loss_r: 1.440e+00, Time: 0.04
# constant_ics_val: 0.985
# constant_bcs_val: 0.966
# constant_res_val: 1.049
# It: 4900, Loss: 1.547e+00, loss_ics: 3.539e-02, loss_bcs: 1.079e-02, Loss_r: 1.431e+00, Time: 0.02
# constant_ics_val: 1.025
# constant_bcs_val: 0.935
# constant_res_val: 1.040
# It: 5000, Loss: 4.104e+00, loss_ics: 6.231e-02, loss_bcs: 1.491e-02, Loss_r: 3.871e+00, Time: 0.03
# constant_ics_val: 0.963
# constant_bcs_val: 0.853
# constant_res_val: 1.184
# It: 5100, Loss: 4.584e+00, loss_ics: 5.418e-02, loss_bcs: 1.310e-02, Loss_r: 3.818e+00, Time: 0.04
# constant_ics_val: 0.962
# constant_bcs_val: 0.953
# constant_res_val: 1.084
# It: 5200, Loss: 6.990e+00, loss_ics: 1.077e-01, loss_bcs: 1.587e-02, Loss_r: 6.337e+00, Time: 0.05
# constant_ics_val: 1.023
# constant_bcs_val: 0.955
# constant_res_val: 1.022
# It: 5300, Loss: 1.667e+00, loss_ics: 3.776e-02, loss_bcs: 1.394e-02, Loss_r: 1.580e+00, Time: 0.06
# constant_ics_val: 0.997
# constant_bcs_val: 1.029
# constant_res_val: 0.974
# It: 5400, Loss: 1.273e+00, loss_ics: 4.478e-02, loss_bcs: 1.153e-02, Loss_r: 1.249e+00, Time: 0.03
# constant_ics_val: 1.029
# constant_bcs_val: 1.003
# constant_res_val: 0.968
# It: 5500, Loss: 9.321e-01, loss_ics: 2.853e-02, loss_bcs: 1.422e-02, Loss_r: 9.179e-01, Time: 0.03
# constant_ics_val: 0.982
# constant_bcs_val: 1.001
# constant_res_val: 1.017
# It: 5600, Loss: 2.919e+00, loss_ics: 2.821e-02, loss_bcs: 1.024e-02, Loss_r: 2.833e+00, Time: 0.04
# constant_ics_val: 1.012
# constant_bcs_val: 0.968
# constant_res_val: 1.020
# It: 5700, Loss: 1.092e+00, loss_ics: 2.909e-02, loss_bcs: 9.252e-03, Loss_r: 1.033e+00, Time: 0.07
# constant_ics_val: 1.026
# constant_bcs_val: 1.004
# constant_res_val: 0.971
# It: 5800, Loss: 1.846e+00, loss_ics: 3.121e-02, loss_bcs: 1.237e-02, Loss_r: 1.856e+00, Time: 0.04
# constant_ics_val: 0.973
# constant_bcs_val: 0.984
# constant_res_val: 1.043
# It: 5900, Loss: 5.005e+00, loss_ics: 2.947e-02, loss_bcs: 7.552e-03, Loss_r: 4.763e+00, Time: 0.03
# constant_ics_val: 0.969
# constant_bcs_val: 0.964
# constant_res_val: 1.067
# It: 6000, Loss: 3.305e+00, loss_ics: 4.974e-02, loss_bcs: 8.486e-03, Loss_r: 3.046e+00, Time: 0.03
# constant_ics_val: 1.033
# constant_bcs_val: 0.984
# constant_res_val: 0.983
# It: 6100, Loss: 2.196e+00, loss_ics: 2.427e-02, loss_bcs: 9.959e-03, Loss_r: 2.199e+00, Time: 0.04
# constant_ics_val: 1.027
# constant_bcs_val: 0.971
# constant_res_val: 1.002
# It: 6200, Loss: 7.585e-01, loss_ics: 2.597e-02, loss_bcs: 9.924e-03, Loss_r: 7.209e-01, Time: 0.09
# constant_ics_val: 1.050
# constant_bcs_val: 0.994
# constant_res_val: 0.955
# It: 6300, Loss: 7.794e-01, loss_ics: 1.988e-02, loss_bcs: 1.119e-02, Loss_r: 7.824e-01, Time: 0.06
# constant_ics_val: 1.161
# constant_bcs_val: 0.901
# constant_res_val: 0.938
# It: 6400, Loss: 7.496e+00, loss_ics: 1.062e-01, loss_bcs: 1.137e-02, Loss_r: 7.846e+00, Time: 0.04
# constant_ics_val: 1.014
# constant_bcs_val: 0.870
# constant_res_val: 1.117
# It: 6500, Loss: 3.701e+00, loss_ics: 1.917e-02, loss_bcs: 1.467e-02, Loss_r: 3.285e+00, Time: 0.04
# constant_ics_val: 0.964
# constant_bcs_val: 1.021
# constant_res_val: 1.015
# It: 6600, Loss: 8.230e-01, loss_ics: 2.720e-02, loss_bcs: 8.379e-03, Loss_r: 7.769e-01, Time: 0.03
# constant_ics_val: 1.036
# constant_bcs_val: 0.996
# constant_res_val: 0.968
# It: 6700, Loss: 1.094e+00, loss_ics: 2.409e-02, loss_bcs: 7.064e-03, Loss_r: 1.097e+00, Time: 0.02
# constant_ics_val: 1.070
# constant_bcs_val: 0.958
# constant_res_val: 0.971
# It: 6800, Loss: 8.718e-01, loss_ics: 1.740e-02, loss_bcs: 9.629e-03, Loss_r: 8.688e-01, Time: 0.06
# constant_ics_val: 1.000
# constant_bcs_val: 0.987
# constant_res_val: 1.014
# It: 6900, Loss: 8.639e-01, loss_ics: 2.351e-02, loss_bcs: 8.214e-03, Loss_r: 8.211e-01, Time: 0.04
# constant_ics_val: 1.043
# constant_bcs_val: 0.960
# constant_res_val: 0.997
# It: 7000, Loss: 2.895e+00, loss_ics: 3.394e-02, loss_bcs: 9.422e-03, Loss_r: 2.860e+00, Time: 0.06
# constant_ics_val: 0.929
# constant_bcs_val: 0.881
# constant_res_val: 1.190
# It: 7100, Loss: 2.505e+00, loss_ics: 2.054e-02, loss_bcs: 1.015e-02, Loss_r: 2.081e+00, Time: 0.05
# constant_ics_val: 0.941
# constant_bcs_val: 0.948
# constant_res_val: 1.111
# It: 7200, Loss: 5.079e-01, loss_ics: 1.710e-02, loss_bcs: 8.920e-03, Loss_r: 4.349e-01, Time: 0.05
# constant_ics_val: 1.026
# constant_bcs_val: 0.979
# constant_res_val: 0.995
# It: 7300, Loss: 6.627e-01, loss_ics: 1.724e-02, loss_bcs: 9.226e-03, Loss_r: 6.393e-01, Time: 0.04
# constant_ics_val: 0.969
# constant_bcs_val: 0.960
# constant_res_val: 1.071
# It: 7400, Loss: 5.122e-01, loss_ics: 1.740e-02, loss_bcs: 7.518e-03, Loss_r: 4.558e-01, Time: 0.03
# constant_ics_val: 0.985
# constant_bcs_val: 0.971
# constant_res_val: 1.044
# It: 7500, Loss: 7.863e-01, loss_ics: 1.699e-02, loss_bcs: 8.793e-03, Loss_r: 7.292e-01, Time: 0.03
# constant_ics_val: 0.941
# constant_bcs_val: 0.925
# constant_res_val: 1.134
# It: 7600, Loss: 1.985e+00, loss_ics: 4.695e-02, loss_bcs: 6.799e-03, Loss_r: 1.705e+00, Time: 0.04
# constant_ics_val: 0.880
# constant_bcs_val: 0.869
# constant_res_val: 1.251
# It: 7700, Loss: 1.824e+00, loss_ics: 2.650e-02, loss_bcs: 7.236e-03, Loss_r: 1.434e+00, Time: 0.02
# constant_ics_val: 0.902
# constant_bcs_val: 0.947
# constant_res_val: 1.151
# It: 7800, Loss: 2.469e+00, loss_ics: 3.500e-02, loss_bcs: 4.792e-03, Loss_r: 2.114e+00, Time: 0.06
# constant_ics_val: 0.877
# constant_bcs_val: 0.875
# constant_res_val: 1.248
# It: 7900, Loss: 2.367e+00, loss_ics: 2.444e-02, loss_bcs: 1.064e-02, Loss_r: 1.872e+00, Time: 0.03
# constant_ics_val: 1.057
# constant_bcs_val: 0.921
# constant_res_val: 1.022
# It: 8000, Loss: 6.487e+00, loss_ics: 2.077e-02, loss_bcs: 5.874e-03, Loss_r: 6.320e+00, Time: 0.09
# constant_ics_val: 1.310
# constant_bcs_val: 0.779
# constant_res_val: 0.911
# It: 8100, Loss: 7.218e-01, loss_ics: 1.140e-02, loss_bcs: 8.275e-03, Loss_r: 7.690e-01, Time: 0.08
# constant_ics_val: 1.122
# constant_bcs_val: 0.978
# constant_res_val: 0.900
# It: 8200, Loss: 1.597e+00, loss_ics: 1.658e-02, loss_bcs: 5.417e-03, Loss_r: 1.748e+00, Time: 0.05
# constant_ics_val: 1.061
# constant_bcs_val: 0.931
# constant_res_val: 1.009
# It: 8300, Loss: 5.017e-01, loss_ics: 1.039e-02, loss_bcs: 9.293e-03, Loss_r: 4.779e-01, Time: 0.03
# constant_ics_val: 0.990
# constant_bcs_val: 1.035
# constant_res_val: 0.976
# It: 8400, Loss: 3.631e-01, loss_ics: 1.361e-02, loss_bcs: 5.913e-03, Loss_r: 3.521e-01, Time: 0.05
# constant_ics_val: 1.019
# constant_bcs_val: 1.015
# constant_res_val: 0.966
# It: 8500, Loss: 1.112e+00, loss_ics: 2.000e-02, loss_bcs: 7.329e-03, Loss_r: 1.123e+00, Time: 0.04
# constant_ics_val: 1.011
# constant_bcs_val: 0.978
# constant_res_val: 1.011
# It: 8600, Loss: 9.250e-01, loss_ics: 2.515e-02, loss_bcs: 5.965e-03, Loss_r: 8.836e-01, Time: 0.14
# constant_ics_val: 1.007
# constant_bcs_val: 1.010
# constant_res_val: 0.982
# It: 8700, Loss: 7.332e-01, loss_ics: 1.286e-02, loss_bcs: 4.187e-03, Loss_r: 7.289e-01, Time: 0.08
# constant_ics_val: 1.003
# constant_bcs_val: 1.027
# constant_res_val: 0.971
# It: 8800, Loss: 5.889e-01, loss_ics: 1.124e-02, loss_bcs: 5.304e-03, Loss_r: 5.895e-01, Time: 0.06
# constant_ics_val: 0.997
# constant_bcs_val: 1.040
# constant_res_val: 0.963
# It: 8900, Loss: 5.250e-01, loss_ics: 1.385e-02, loss_bcs: 3.711e-03, Loss_r: 5.267e-01, Time: 0.08
# constant_ics_val: 0.967
# constant_bcs_val: 0.942
# constant_res_val: 1.091
# It: 9000, Loss: 8.660e-01, loss_ics: 9.861e-03, loss_bcs: 3.872e-03, Loss_r: 7.816e-01, Time: 0.04
# constant_ics_val: 0.956
# constant_bcs_val: 0.960
# constant_res_val: 1.084
# It: 9100, Loss: 1.128e+00, loss_ics: 1.524e-02, loss_bcs: 4.807e-03, Loss_r: 1.023e+00, Time: 0.07
# constant_ics_val: 1.168
# constant_bcs_val: 0.874
# constant_res_val: 0.958
# It: 9200, Loss: 4.964e-01, loss_ics: 1.318e-02, loss_bcs: 5.994e-03, Loss_r: 4.966e-01, Time: 0.03
# constant_ics_val: 1.062
# constant_bcs_val: 0.996
# constant_res_val: 0.943
# It: 9300, Loss: 7.830e-01, loss_ics: 1.000e-02, loss_bcs: 4.825e-03, Loss_r: 8.142e-01, Time: 0.04
# constant_ics_val: 1.003
# constant_bcs_val: 0.955
# constant_res_val: 1.042
# It: 9400, Loss: 8.929e-01, loss_ics: 4.480e-02, loss_bcs: 4.519e-03, Loss_r: 8.099e-01, Time: 0.04
# constant_ics_val: 1.059
# constant_bcs_val: 0.953
# constant_res_val: 0.988
# It: 9500, Loss: 4.897e-01, loss_ics: 1.604e-02, loss_bcs: 4.457e-03, Loss_r: 4.743e-01, Time: 0.04
# constant_ics_val: 1.015
# constant_bcs_val: 1.017
# constant_res_val: 0.969
# It: 9600, Loss: 3.744e-01, loss_ics: 1.977e-02, loss_bcs: 4.128e-03, Loss_r: 3.615e-01, Time: 0.03
# constant_ics_val: 1.046
# constant_bcs_val: 0.997
# constant_res_val: 0.958
# It: 9700, Loss: 5.877e-01, loss_ics: 1.832e-02, loss_bcs: 4.257e-03, Loss_r: 5.892e-01, Time: 0.04
# constant_ics_val: 0.985
# constant_bcs_val: 0.981
# constant_res_val: 1.034
# It: 9800, Loss: 3.119e+00, loss_ics: 1.340e-02, loss_bcs: 4.806e-03, Loss_r: 2.999e+00, Time: 0.03
# constant_ics_val: 0.909
# constant_bcs_val: 0.899
# constant_res_val: 1.192
# It: 9900, Loss: 5.074e+00, loss_ics: 2.523e-02, loss_bcs: 6.503e-03, Loss_r: 4.232e+00, Time: 0.05
# constant_ics_val: 1.199
# constant_bcs_val: 0.837
# constant_res_val: 0.963
# It: 10000, Loss: 6.426e-01, loss_ics: 9.157e-03, loss_bcs: 4.413e-03, Loss_r: 6.518e-01, Time: 0.03
# constant_ics_val: 1.093
# constant_bcs_val: 0.952
# constant_res_val: 0.954
# It: 10100, Loss: 5.176e-01, loss_ics: 1.071e-02, loss_bcs: 4.413e-03, Loss_r: 5.257e-01, Time: 0.04
# constant_ics_val: 1.119
# constant_bcs_val: 0.957
# constant_res_val: 0.924
# It: 10200, Loss: 5.507e-01, loss_ics: 2.677e-02, loss_bcs: 6.010e-03, Loss_r: 5.574e-01, Time: 0.03
# constant_ics_val: 1.063
# constant_bcs_val: 0.977
# constant_res_val: 0.960
# It: 10300, Loss: 5.901e-01, loss_ics: 1.068e-02, loss_bcs: 4.101e-03, Loss_r: 5.987e-01, Time: 0.08
# constant_ics_val: 1.000
# constant_bcs_val: 0.983
# constant_res_val: 1.017
# It: 10400, Loss: 6.048e-01, loss_ics: 1.047e-02, loss_bcs: 6.063e-03, Loss_r: 5.784e-01, Time: 0.02
# constant_ics_val: 0.967
# constant_bcs_val: 1.017
# constant_res_val: 1.016
# It: 10500, Loss: 7.418e-01, loss_ics: 1.486e-02, loss_bcs: 3.200e-03, Loss_r: 7.128e-01, Time: 0.05
# constant_ics_val: 0.969
# constant_bcs_val: 0.957
# constant_res_val: 1.074
# It: 10600, Loss: 4.266e-01, loss_ics: 1.028e-02, loss_bcs: 4.094e-03, Loss_r: 3.843e-01, Time: 0.07
# constant_ics_val: 0.964
# constant_bcs_val: 1.019
# constant_res_val: 1.017
# It: 10700, Loss: 7.733e-01, loss_ics: 1.281e-02, loss_bcs: 4.057e-03, Loss_r: 7.445e-01, Time: 0.04
# constant_ics_val: 1.035
# constant_bcs_val: 0.955
# constant_res_val: 1.010
# It: 10800, Loss: 9.158e-01, loss_ics: 1.009e-02, loss_bcs: 3.807e-03, Loss_r: 8.928e-01, Time: 0.03
# constant_ics_val: 1.025
# constant_bcs_val: 0.982
# constant_res_val: 0.993
# It: 10900, Loss: 4.458e-01, loss_ics: 9.611e-03, loss_bcs: 2.883e-03, Loss_r: 4.362e-01, Time: 0.02
# constant_ics_val: 1.048
# constant_bcs_val: 0.977
# constant_res_val: 0.975
# It: 11000, Loss: 1.257e+00, loss_ics: 3.316e-02, loss_bcs: 1.807e-03, Loss_r: 1.251e+00, Time: 0.04
# constant_ics_val: 1.153
# constant_bcs_val: 0.881
# constant_res_val: 0.966
# It: 11100, Loss: 6.107e-01, loss_ics: 1.877e-02, loss_bcs: 4.583e-03, Loss_r: 6.057e-01, Time: 0.05
# constant_ics_val: 0.983
# constant_bcs_val: 1.123
# constant_res_val: 0.894
# It: 11200, Loss: 4.738e-01, loss_ics: 5.696e-03, loss_bcs: 3.957e-03, Loss_r: 5.186e-01, Time: 0.04
# constant_ics_val: 0.958
# constant_bcs_val: 1.075
# constant_res_val: 0.967
# It: 11300, Loss: 3.262e-01, loss_ics: 1.303e-02, loss_bcs: 5.404e-03, Loss_r: 3.185e-01, Time: 0.05
# constant_ics_val: 1.058
# constant_bcs_val: 0.977
# constant_res_val: 0.964
# It: 11400, Loss: 5.122e-01, loss_ics: 1.952e-02, loss_bcs: 3.291e-03, Loss_r: 5.063e-01, Time: 0.04
# constant_ics_val: 0.992
# constant_bcs_val: 0.941
# constant_res_val: 1.067
# It: 11500, Loss: 1.398e+00, loss_ics: 5.127e-02, loss_bcs: 3.512e-03, Loss_r: 1.260e+00, Time: 0.05
# constant_ics_val: 0.961
# constant_bcs_val: 0.984
# constant_res_val: 1.055
# It: 11600, Loss: 1.011e+00, loss_ics: 1.522e-02, loss_bcs: 2.703e-03, Loss_r: 9.421e-01, Time: 0.03
# constant_ics_val: 0.958
# constant_bcs_val: 1.001
# constant_res_val: 1.041
# It: 11700, Loss: 6.846e-01, loss_ics: 2.261e-02, loss_bcs: 2.235e-03, Loss_r: 6.345e-01, Time: 0.03
# constant_ics_val: 0.915
# constant_bcs_val: 0.907
# constant_res_val: 1.178
# It: 11800, Loss: 3.159e-01, loss_ics: 1.100e-02, loss_bcs: 4.266e-03, Loss_r: 2.564e-01, Time: 0.04
# constant_ics_val: 0.918
# constant_bcs_val: 1.041
# constant_res_val: 1.042
# It: 11900, Loss: 7.760e-01, loss_ics: 6.881e-03, loss_bcs: 3.081e-03, Loss_r: 7.359e-01, Time: 0.04
# constant_ics_val: 0.886
# constant_bcs_val: 0.944
# constant_res_val: 1.170
# It: 12000, Loss: 6.270e-01, loss_ics: 7.767e-03, loss_bcs: 3.365e-03, Loss_r: 5.273e-01, Time: 0.04
# constant_ics_val: 1.127
# constant_bcs_val: 0.879
# constant_res_val: 0.993
# It: 12100, Loss: 3.345e-01, loss_ics: 8.932e-03, loss_bcs: 3.557e-03, Loss_r: 3.235e-01, Time: 0.06
# constant_ics_val: 1.033
# constant_bcs_val: 1.004
# constant_res_val: 0.962
# It: 12200, Loss: 3.630e-01, loss_ics: 7.353e-03, loss_bcs: 3.300e-03, Loss_r: 3.659e-01, Time: 0.06
# constant_ics_val: 1.022
# constant_bcs_val: 1.008
# constant_res_val: 0.969
# It: 12300, Loss: 2.387e+00, loss_ics: 8.908e-03, loss_bcs: 1.970e-03, Loss_r: 2.451e+00, Time: 0.05
# constant_ics_val: 0.914
# constant_bcs_val: 0.903
# constant_res_val: 1.183
# It: 12400, Loss: 1.159e+00, loss_ics: 1.345e-02, loss_bcs: 2.074e-03, Loss_r: 9.673e-01, Time: 0.05
# constant_ics_val: 1.024
# constant_bcs_val: 0.937
# constant_res_val: 1.039
# It: 12500, Loss: 1.036e+00, loss_ics: 9.288e-03, loss_bcs: 2.644e-03, Loss_r: 9.851e-01, Time: 0.05
# constant_ics_val: 0.993
# constant_bcs_val: 1.014
# constant_res_val: 0.993
# It: 12600, Loss: 2.096e-01, loss_ics: 7.158e-03, loss_bcs: 3.427e-03, Loss_r: 2.004e-01, Time: 0.05
# constant_ics_val: 0.996
# constant_bcs_val: 1.042
# constant_res_val: 0.962
# It: 12700, Loss: 4.303e-01, loss_ics: 1.071e-02, loss_bcs: 3.477e-03, Loss_r: 4.322e-01, Time: 0.07
# constant_ics_val: 1.011
# constant_bcs_val: 1.005
# constant_res_val: 0.985
# It: 12800, Loss: 8.173e-01, loss_ics: 9.528e-03, loss_bcs: 2.373e-03, Loss_r: 8.179e-01, Time: 0.08
# constant_ics_val: 0.949
# constant_bcs_val: 0.931
# constant_res_val: 1.120
# It: 12900, Loss: 3.377e-01, loss_ics: 4.625e-03, loss_bcs: 4.133e-03, Loss_r: 2.942e-01, Time: 0.04
# constant_ics_val: 0.945
# constant_bcs_val: 1.060
# constant_res_val: 0.996
# It: 13000, Loss: 3.087e-01, loss_ics: 8.316e-03, loss_bcs: 3.172e-03, Loss_r: 2.988e-01, Time: 0.03
# constant_ics_val: 1.034
# constant_bcs_val: 1.006
# constant_res_val: 0.960
# It: 13100, Loss: 3.169e-01, loss_ics: 8.838e-03, loss_bcs: 2.874e-03, Loss_r: 3.177e-01, Time: 0.03
# constant_ics_val: 1.045
# constant_bcs_val: 1.001
# constant_res_val: 0.954
# It: 13200, Loss: 3.199e-01, loss_ics: 1.431e-02, loss_bcs: 2.302e-03, Loss_r: 3.172e-01, Time: 0.03
# constant_ics_val: 1.021
# constant_bcs_val: 0.967
# constant_res_val: 1.012
# It: 13300, Loss: 5.445e-01, loss_ics: 9.353e-03, loss_bcs: 3.408e-03, Loss_r: 5.251e-01, Time: 0.05
# constant_ics_val: 1.007
# constant_bcs_val: 0.947
# constant_res_val: 1.046
# It: 13400, Loss: 9.749e-01, loss_ics: 2.895e-02, loss_bcs: 2.578e-03, Loss_r: 9.019e-01, Time: 0.05
# constant_ics_val: 1.076
# constant_bcs_val: 0.924
# constant_res_val: 0.999
# It: 13500, Loss: 2.194e-01, loss_ics: 5.242e-03, loss_bcs: 3.954e-03, Loss_r: 2.103e-01, Time: 0.06
# constant_ics_val: 0.996
# constant_bcs_val: 1.048
# constant_res_val: 0.956
# It: 13600, Loss: 2.172e-01, loss_ics: 8.134e-03, loss_bcs: 3.123e-03, Loss_r: 2.153e-01, Time: 0.05
# constant_ics_val: 1.042
# constant_bcs_val: 0.991
# constant_res_val: 0.967
# It: 13700, Loss: 6.479e-01, loss_ics: 6.300e-03, loss_bcs: 5.274e-03, Loss_r: 6.577e-01, Time: 0.04
# constant_ics_val: 0.951
# constant_bcs_val: 0.991
# constant_res_val: 1.058
# It: 13800, Loss: 5.027e-01, loss_ics: 1.360e-02, loss_bcs: 2.337e-03, Loss_r: 4.609e-01, Time: 0.06
# constant_ics_val: 1.123
# constant_bcs_val: 0.923
# constant_res_val: 0.954
# It: 13900, Loss: 1.775e-01, loss_ics: 6.820e-03, loss_bcs: 3.801e-03, Loss_r: 1.743e-01, Time: 0.05
# constant_ics_val: 1.025
# constant_bcs_val: 1.044
# constant_res_val: 0.931
# It: 14000, Loss: 1.839e-01, loss_ics: 1.124e-02, loss_bcs: 2.742e-03, Loss_r: 1.820e-01, Time: 0.02
# constant_ics_val: 1.107
# constant_bcs_val: 0.972
# constant_res_val: 0.921
# It: 14100, Loss: 4.871e-01, loss_ics: 6.846e-03, loss_bcs: 3.814e-03, Loss_r: 5.165e-01, Time: 0.06
# constant_ics_val: 1.031
# constant_bcs_val: 0.998
# constant_res_val: 0.971
# It: 14200, Loss: 3.178e-01, loss_ics: 5.681e-03, loss_bcs: 3.261e-03, Loss_r: 3.177e-01, Time: 0.03
# constant_ics_val: 0.998
# constant_bcs_val: 1.012
# ...
# constant_res_val: 1.037
# It: 35200, Loss: 1.632e-01, loss_ics: 2.498e-03, loss_bcs: 2.501e-03, Loss_r: 1.526e-01, Time: 0.02
# constant_ics_val: 0.924
# constant_bcs_val: 0.922
# constant_res_val: 1.154
# It: 35300, Loss: 7.445e-02, loss_ics: 2.372e-03, loss_bcs: 2.823e-03, Loss_r: 6.034e-02, Time: 0.04
# constant_ics_val: 0.958
# constant_bcs_val: 0.941
# constant_res_val: 1.101
# It: 35400, Loss: 8.129e-02, loss_ics: 3.281e-03, loss_bcs: 2.711e-03, Loss_r: 6.863e-02, Time: 0.06
# constant_ics_val: 1.001
# constant_bcs_val: 0.969
# constant_res_val: 1.030
# It: 35500, Loss: 9.296e-02, loss_ics: 2.444e-03, loss_bcs: 2.746e-03, Loss_r: 8.532e-02, Time: 0.04
# constant_ics_val: 0.984
# constant_bcs_val: 0.978
# constant_res_val: 1.038
# It: 35600, Loss: 7.620e-02, loss_ics: 4.557e-03, loss_bcs: 2.827e-03, Loss_r: 6.645e-02, Time: 0.03
# constant_ics_val: 1.027
# constant_bcs_val: 0.972
# constant_res_val: 1.002
# It: 35700, Loss: 4.635e-02, loss_ics: 2.901e-03, loss_bcs: 2.998e-03, Loss_r: 4.039e-02, Time: 0.02
# constant_ics_val: 0.998
# constant_bcs_val: 1.031
# constant_res_val: 0.971
# It: 35800, Loss: 6.171e-02, loss_ics: 2.844e-03, loss_bcs: 3.260e-03, Loss_r: 5.715e-02, Time: 0.06
# constant_ics_val: 0.980
# constant_bcs_val: 1.039
# constant_res_val: 0.981
# It: 35900, Loss: 4.461e-02, loss_ics: 1.583e-03, loss_bcs: 2.697e-03, Loss_r: 4.105e-02, Time: 0.04
# constant_ics_val: 0.963
# constant_bcs_val: 1.056
# constant_res_val: 0.981
# It: 36000, Loss: 1.059e-01, loss_ics: 1.669e-03, loss_bcs: 2.700e-03, Loss_r: 1.035e-01, Time: 0.03
# constant_ics_val: 0.960
# constant_bcs_val: 1.011
# constant_res_val: 1.030
# It: 36100, Loss: 6.010e-02, loss_ics: 3.768e-03, loss_bcs: 3.114e-03, Loss_r: 5.180e-02, Time: 0.03
# constant_ics_val: 0.996
# constant_bcs_val: 1.010
# constant_res_val: 0.994
# It: 36200, Loss: 6.220e-02, loss_ics: 2.518e-03, loss_bcs: 2.710e-03, Loss_r: 5.730e-02, Time: 0.05
# constant_ics_val: 0.967
# constant_bcs_val: 1.010
# constant_res_val: 1.023
# It: 36300, Loss: 6.665e-02, loss_ics: 1.526e-03, loss_bcs: 2.797e-03, Loss_r: 6.095e-02, Time: 0.04
# constant_ics_val: 0.951
# constant_bcs_val: 1.005
# constant_res_val: 1.043
# It: 36400, Loss: 5.503e-02, loss_ics: 2.978e-03, loss_bcs: 3.006e-03, Loss_r: 4.713e-02, Time: 0.04
# constant_ics_val: 0.978
# constant_bcs_val: 0.974
# constant_res_val: 1.047
# It: 36500, Loss: 4.827e-02, loss_ics: 2.747e-03, loss_bcs: 2.811e-03, Loss_r: 4.091e-02, Time: 0.04
# constant_ics_val: 1.015
# constant_bcs_val: 1.003
# constant_res_val: 0.982
# It: 36600, Loss: 4.261e-02, loss_ics: 2.305e-03, loss_bcs: 2.741e-03, Loss_r: 3.820e-02, Time: 0.03
# constant_ics_val: 1.033
# constant_bcs_val: 1.002
# constant_res_val: 0.965
# It: 36700, Loss: 4.242e-02, loss_ics: 3.172e-03, loss_bcs: 2.789e-03, Loss_r: 3.766e-02, Time: 0.04
# constant_ics_val: 1.066
# constant_bcs_val: 0.998
# constant_res_val: 0.936
# It: 36800, Loss: 5.870e-02, loss_ics: 1.659e-03, loss_bcs: 2.803e-03, Loss_r: 5.783e-02, Time: 0.05
# constant_ics_val: 1.032
# constant_bcs_val: 0.998
# constant_res_val: 0.970
# It: 36900, Loss: 4.141e-02, loss_ics: 1.875e-03, loss_bcs: 3.131e-03, Loss_r: 3.749e-02, Time: 0.04
# constant_ics_val: 0.995
# constant_bcs_val: 1.041
# constant_res_val: 0.964
# It: 37000, Loss: 4.435e-02, loss_ics: 2.737e-03, loss_bcs: 2.850e-03, Loss_r: 4.010e-02, Time: 0.04
# constant_ics_val: 1.022
# constant_bcs_val: 1.013
# constant_res_val: 0.965
# It: 37100, Loss: 6.405e-02, loss_ics: 1.890e-03, loss_bcs: 2.920e-03, Loss_r: 6.129e-02, Time: 0.03
# constant_ics_val: 0.993
# constant_bcs_val: 1.011
# constant_res_val: 0.996
# It: 37200, Loss: 3.890e-02, loss_ics: 1.916e-03, loss_bcs: 2.295e-03, Loss_r: 3.483e-02, Time: 0.04
# constant_ics_val: 1.020
# constant_bcs_val: 0.992
# constant_res_val: 0.988
# It: 37300, Loss: 7.028e-02, loss_ics: 2.334e-03, loss_bcs: 3.147e-03, Loss_r: 6.557e-02, Time: 0.04
# constant_ics_val: 0.976
# constant_bcs_val: 1.003
# constant_res_val: 1.021
# It: 37400, Loss: 6.300e-02, loss_ics: 1.996e-03, loss_bcs: 2.415e-03, Loss_r: 5.742e-02, Time: 0.06
# constant_ics_val: 1.019
# constant_bcs_val: 0.988
# constant_res_val: 0.993
# It: 37500, Loss: 5.883e-02, loss_ics: 2.959e-03, loss_bcs: 2.593e-03, Loss_r: 5.363e-02, Time: 0.10
# constant_ics_val: 1.059
# constant_bcs_val: 0.994
# constant_res_val: 0.947
# It: 37600, Loss: 5.295e-02, loss_ics: 1.905e-03, loss_bcs: 2.544e-03, Loss_r: 5.110e-02, Time: 0.04
# constant_ics_val: 1.013
# constant_bcs_val: 1.019
# constant_res_val: 0.968
# It: 37700, Loss: 5.373e-02, loss_ics: 3.196e-03, loss_bcs: 2.918e-03, Loss_r: 4.908e-02, Time: 0.04
# constant_ics_val: 0.988
# constant_bcs_val: 1.003
# constant_res_val: 1.008
# It: 37800, Loss: 4.445e-02, loss_ics: 2.207e-03, loss_bcs: 3.011e-03, Loss_r: 3.892e-02, Time: 0.03
# constant_ics_val: 0.997
# constant_bcs_val: 1.026
# constant_res_val: 0.977
# It: 37900, Loss: 1.916e-01, loss_ics: 2.793e-03, loss_bcs: 2.905e-03, Loss_r: 1.903e-01, Time: 0.06
# constant_ics_val: 0.901
# constant_bcs_val: 0.915
# constant_res_val: 1.184
# It: 38000, Loss: 4.833e-02, loss_ics: 1.965e-03, loss_bcs: 2.440e-03, Loss_r: 3.744e-02, Time: 0.08
# constant_ics_val: 0.942
# constant_bcs_val: 0.967
# constant_res_val: 1.091
# It: 38100, Loss: 5.234e-02, loss_ics: 2.721e-03, loss_bcs: 2.545e-03, Loss_r: 4.338e-02, Time: 0.03
# constant_ics_val: 1.019
# constant_bcs_val: 0.969
# constant_res_val: 1.012
# It: 38200, Loss: 4.198e-02, loss_ics: 1.878e-03, loss_bcs: 2.755e-03, Loss_r: 3.695e-02, Time: 0.02
# constant_ics_val: 1.025
# constant_bcs_val: 0.998
# constant_res_val: 0.977
# It: 38300, Loss: 3.771e-02, loss_ics: 2.542e-03, loss_bcs: 3.181e-03, Loss_r: 3.267e-02, Time: 0.14
# constant_ics_val: 1.004
# constant_bcs_val: 1.033
# constant_res_val: 0.962
# It: 38400, Loss: 8.502e-02, loss_ics: 2.158e-03, loss_bcs: 2.503e-03, Loss_r: 8.341e-02, Time: 0.04
# constant_ics_val: 0.984
# constant_bcs_val: 0.991
# constant_res_val: 1.025
# It: 38500, Loss: 4.619e-02, loss_ics: 2.458e-03, loss_bcs: 2.839e-03, Loss_r: 3.996e-02, Time: 0.06
# constant_ics_val: 0.994
# constant_bcs_val: 0.993
# constant_res_val: 1.013
# It: 38600, Loss: 4.126e-02, loss_ics: 1.603e-03, loss_bcs: 2.476e-03, Loss_r: 3.673e-02, Time: 0.03
# constant_ics_val: 1.008
# constant_bcs_val: 1.013
# constant_res_val: 0.980
# It: 38700, Loss: 4.514e-02, loss_ics: 2.122e-03, loss_bcs: 3.272e-03, Loss_r: 4.051e-02, Time: 0.03
# constant_ics_val: 0.982
# constant_bcs_val: 1.053
# constant_res_val: 0.965
# It: 38800, Loss: 7.807e-02, loss_ics: 2.066e-03, loss_bcs: 2.907e-03, Loss_r: 7.566e-02, Time: 0.03
# constant_ics_val: 0.948
# constant_bcs_val: 0.997
# constant_res_val: 1.055
# It: 38900, Loss: 6.163e-02, loss_ics: 2.968e-03, loss_bcs: 3.155e-03, Loss_r: 5.276e-02, Time: 0.04
# constant_ics_val: 0.971
# constant_bcs_val: 0.993
# constant_res_val: 1.036
# It: 39000, Loss: 3.744e-02, loss_ics: 1.764e-03, loss_bcs: 2.674e-03, Loss_r: 3.194e-02, Time: 0.05
# constant_ics_val: 0.981
# constant_bcs_val: 1.017
# constant_res_val: 1.002
# It: 39100, Loss: 5.794e-02, loss_ics: 1.484e-03, loss_bcs: 2.735e-03, Loss_r: 5.361e-02, Time: 0.04
# constant_ics_val: 0.960
# constant_bcs_val: 1.021
# constant_res_val: 1.019
# It: 39200, Loss: 7.714e-02, loss_ics: 2.713e-03, loss_bcs: 2.958e-03, Loss_r: 7.016e-02, Time: 0.06
# constant_ics_val: 0.953
# constant_bcs_val: 0.952
# constant_res_val: 1.095
# It: 39300, Loss: 7.378e-02, loss_ics: 2.828e-03, loss_bcs: 2.870e-03, Loss_r: 6.245e-02, Time: 0.04
# constant_ics_val: 0.984
# constant_bcs_val: 0.944
# constant_res_val: 1.072
# It: 39400, Loss: 5.097e-02, loss_ics: 2.425e-03, loss_bcs: 2.561e-03, Loss_r: 4.305e-02, Time: 0.02
# constant_ics_val: 0.998
# constant_bcs_val: 0.974
# constant_res_val: 1.028
# It: 39500, Loss: 3.327e-02, loss_ics: 2.558e-03, loss_bcs: 2.868e-03, Loss_r: 2.716e-02, Time: 0.04
# constant_ics_val: 1.027
# constant_bcs_val: 0.991
# constant_res_val: 0.983
# It: 39600, Loss: 4.983e-02, loss_ics: 2.224e-03, loss_bcs: 2.529e-03, Loss_r: 4.583e-02, Time: 0.07
# constant_ics_val: 1.024
# constant_bcs_val: 0.993
# constant_res_val: 0.983
# It: 39700, Loss: 5.711e-02, loss_ics: 3.006e-03, loss_bcs: 2.811e-03, Loss_r: 5.214e-02, Time: 0.04
# constant_ics_val: 0.991
# constant_bcs_val: 0.988
# constant_res_val: 1.022
# It: 39800, Loss: 4.938e-02, loss_ics: 2.168e-03, loss_bcs: 3.029e-03, Loss_r: 4.330e-02, Time: 0.03
# constant_ics_val: 0.989
# constant_bcs_val: 0.996
# constant_res_val: 1.014
# It: 39900, Loss: 4.489e-02, loss_ics: 2.252e-03, loss_bcs: 2.709e-03, Loss_r: 3.939e-02, Time: 0.03
# constant_ics_val: 1.002
# constant_bcs_val: 1.009
# constant_res_val: 0.989
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 3.661e-02, loss_ics: 2.436e-03, loss_bcs: 3.286e-03, Loss_r: 3.120e-02, Time: 1.83
# constant_ics_val: 0.986
# constant_bcs_val: 1.027
# constant_res_val: 0.987
# average adaptive_constant_bcs_log : 9.8589e-01
# average adaptive_constant_ics_log : 1.0345e+00
# average adaptive_constant_res_log : 9.7964e-01
# Relative L2 error_u: 6.89e-02
# Relative L2 error_f: 2.69e-03
# Save uv NN parameters successfully in %s ...checkpoints/Dec-18-2023_02-41-45-481736_relobralo
# Final loss total loss: 4.297756e-02
# Final loss loss_res: 3.760116e-02
# Final loss loss_bcs: 3.309852e-03
# Final loss loss_ics: 2.448591e-03
# average of time_list: 1996.4133412837982
# average of error_u_list: 0.0689262248594332
# average of error_f_list: 0.0026870598100001038

# %%
average of time_list: 493.56567120552063
average of error_u_list: 0.16921026076112308
average of error_f_list: 0.0032112047062549773
# Out:
#   File "/tmp/ipykernel_12945/1474304749.py", line 1
#     average of time_list: 493.56567120552063
#              ^
# SyntaxError: invalid syntax

# %%
def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
    from mpl_toolkits.axes_grid1 import ImageGrid

    ### Plot ###
    print(x1.shape)
    print(x2.shape)

    # Exact solution & Predicted solution
    # Exact soluton
    U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')
    print(u_star.shape)

    # Predicted solution
    U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
    F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

    titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $f(x)$' , 'Predicted $f(x)$' , 'Absolute error']
    data = [U_star , U_pred ,  np.abs(U_star - U_pred) , F_star , F_pred ,  np.abs(F_star - F_pred) ]
    
    print(U_star.shape)

    fig_1 = plt.figure(1, figsize=(13, 5))
    grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                    label_mode="1", axes_pad=1.7, share_all=False, 
                    cbar_mode="each", cbar_location="right", 
                    cbar_size="5%", cbar_pad=0.0)
# CREATE ARGUMENTS DICT FOR CONTOURPLOTS
    minmax_list = []
    kwargs_list = []
    for d in data:
        # if(local):
        #     minmax_list.append([np.min(d), np.max(d)])
        # else:
        minmax_list.append([np.min(d), np.max(d)])

        kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60),
            cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

    for ax, z, kwargs, minmax, title in zip(grid, data, kwargs_list, minmax_list, titles):
    #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
        #pcfsets.append(pcf)
        # if (timeStp == 0):
            #  print( z[timeStp,:,:])
        pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
        print(z.shape)
        cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
        ax.cax.tick_params(labelsize=14.5)
        ax.set_title(title, fontsize=14.5, pad=7)
        ax.set_ylabel("time", labelpad=14.5, fontsize=14.5, rotation="horizontal")
        ax.set_xlabel("x", fontsize=14.5)
        ax.tick_params(labelsize=14.5)
        ax.set_xlim(x1.min(), x1.max())
        ax.set_ylim(x2.min(), x2.max())
        ax.set_aspect("equal")

    fig_1.set_size_inches(15, 10, True)
    fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
    plt.tight_layout()
    plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
    plt.close("all" , )

# %%
plt_prediction(model, t , x , X_star , u_star , u_pred , f_star , f_pred)
# Out:
# (100, 100)
# (100, 100)
# (10000, 1)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)

# %%
X_star.shape
# Out:
# (10000, 2)

# %%
# Test data
nn = 100
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

# Exact solution
u_star = u(X_star)
f_star = f(X_star, alpha, beta, gamma, k)

# Predictions
u_pred = mode.predict_u(X_star)
f_pred = mode.predict_r(X_star)

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
print('Relative L2 error_u: {:.2e}'.format(error_u))

### Plot ###

# Test data
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (t, x), method='cubic')

U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (t, x), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact u(x)')

plt.subplot(1, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(x)')

plt.subplot(1, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()


fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(t, x, F_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact u(x)')

plt.subplot(1, 3, 2)
plt.pcolor(t, x, F_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(x)')

plt.subplot(1, 3, 3)
plt.pcolor(t, x, np.abs(F_star - F_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %%
# Loss
loss_r = mode.loss_r_log
loss_u = mode.loss_u_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_r, label='$\mathcal{L}_{r}$')
ax.plot(loss_u, label='$\mathcal{L}_{u}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Adaptive Constant
adaptive_constant_ics = mode.adaptive_constant_ics_log
adaptive_constant_bcs = mode.adaptive_constant_bcs_log

fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant_ics, label='$\lambda_{u_0}$')
ax.plot(adaptive_constant_bcs, label='$\lambda_{u_b}$')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Gradients at the end of training
data_gradients_ics = mode.dict_gradients_ics_layers
data_gradients_bcs = mode.dict_gradients_bcs_layers
data_gradients_res = mode.dict_gradients_res_layers

num_hidden_layers = len(layers) - 1
cnt = 1
fig_4 = plt.figure(4, figsize=(13, 8))
for j in range(num_hidden_layers):
    ax = plt.subplot(2, 3, cnt)
    gradients_ics = data_gradients_ics['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]

    sns.distplot(gradients_ics, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_0}\mathcal{L}_{u_0}$')
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')

    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    ax.set_xlim([-1, 1])
    ax.set_ylim([0, 500])
    ax.get_legend().remove()
    cnt += 1
handles, labels = ax.get_legend_handles_labels()
fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.3, 0.01),
                borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=3)
plt.tight_layout()
plt.show()

# %%
# Eigenvalues of Hessian of losses if applicable
if stiff_ratio:
    eigenvalues_list = mode.eigenvalue_log
    eigenvalues_ics_list = mode.eigenvalue_ics_log
    eigenvalues_bcs_list = mode.eigenvalue_bcs_log
    eigenvalues_res_list = mode.eigenvalue_res_log

    eigenvalues_ics = eigenvalues_ics_list[-1]
    eigenvalues_bcs = eigenvalues_bcs_list[-1]
    eigenvalues_res = eigenvalues_res_list[-1]

    fig_5 = plt.figure(5)
    ax = fig_5.add_subplot(1, 1, 1)
    ax.plot(eigenvalues_ics, label='$\mathcal{L}_{u_0}$')
    ax.plot(eigenvalues_bcs, label='$\mathcal{L}_{u_b}$')
    ax.plot(eigenvalues_res, label='$\mathcal{L}_r$')
    ax.set_xlabel('index')
    ax.set_ylabel('eigenvalue')
    ax.set_yscale('symlog')
    plt.legend()
    plt.tight_layout()
    plt.show()
