# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import griddata
# from Klein_Gordon_model_tf import Sampler, Klein_Gordon
import timeit
import os
os.environ["KMP_WARNINGS"] = "FALSE" 

import scipy
import scipy.io
import time


import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle
def u(x):
    """
    :param x: x = (t, x)
    """
    return x[:, 1:2] * np.cos(5 * np.pi * x[:, 0:1]) + (x[:, 0:1] * x[:, 1:2])**3

def u_tt(x):
    return - 25 * np.pi**2 * x[:, 1:2] * np.cos(5 * np.pi * x[:, 0:1]) + 6 * x[:,0:1] * x[:,1:2]**3

def u_xx(x):
    return np.zeros((x.shape[0], 1)) +  6 * x[:,1:2] * x[:,0:1]**3

def f(x, alpha, beta, gamma, k):
    return u_tt(x) + alpha * u_xx(x) + beta * u(x) + gamma * u(x)**k

def operator(u, t, x, alpha, beta, gamma, k,  sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt + alpha * u_xx + beta * u + gamma * u**k
    return residual

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Klein_Gordon:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess):
            # mode = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess)



        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Klein_Gordon constant
        self.alpha = tf.constant(alpha, dtype=tf.float32)
        self.beta = tf.constant(beta, dtype=tf.float32)
        self.gamma = tf.constant(gamma, dtype=tf.float32)
        self.k = tf.constant(k, dtype=tf.float32)

        self.rate = 0.5
        self.rho = 0.5
        self.T = 0.9
        # Record stiff ratio
        # self.stiff_ratio = stiff_ratio

        # Adaptive re-weighting constant
        self.adaptive_constant_ics_val = np.array(1.0)
        self.adaptive_constant_bcs_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)

        # if model in ['M3', 'M4']:
        #     # Initialize encoder weights and biases
        #     self.encoder_weights_1 = self.xavier_init([2, layers[1]])
        #     self.encoder_biases_1 = self.xavier_init([1, layers[1]])

        #     self.encoder_weights_2 = self.xavier_init([2, layers[1]])
        #     self.encoder_biases_2 = self.xavier_init([1, layers[1]])

        # Define Tensorflow session
        self.sess = sess #tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.adaptive_constant_ics_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_ics_val.shape)
        self.adaptive_constant_bcs_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)

        # Boundary loss and Initial loss
        self.loss_ic_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ic_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred - self.u_bc1_tf))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred - self.u_bc2_tf))

        self.loss_bcs =  (self.loss_bc1 + self.loss_bc2)
        self.loss_ics =  (self.loss_ic_u + self.loss_ic_u_t)

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred - self.r_tf))

        # Total loss
        self.loss =  self.adaptive_constant_res_tf *  self.loss_res + self.adaptive_constant_bcs_tf * self.loss_bcs + self.adaptive_constant_ics_tf * self.loss_ics

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)


        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bcs,  self.loss_ics  ] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs" , "loss_ics" ] 
        
        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_u_log = []
        self.loss_r_log = []
        # self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs_layers = self.generate_grad_dict()
        self.dict_gradients_ics_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_ics = []
        self.grad_bcs = []

        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])
            self.grad_ics.append(tf.gradients(self.loss_ics, self.weights[i])[0])

        # Store the adaptive constant
        self.adaptive_constant_ics_log = []
        self.adaptive_constant_bcs_log = []
        self.adaptive_constant_res_log = []

        # Compute the adaptive constant
        self.adaptive_constant_ics_list = []
        self.adaptive_constant_bcs_list = []
        
        self.max_grad_res_list = []
        self.mean_grad_bcs_list = []
        self.mean_grad_ics_list = []

        self.mean_grad_res_log  = []
        self.mean_grad_bcs_log  = []
        self.mean_grad_ics_log  = []
    
        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.reduce_mean(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs_list.append(tf.reduce_mean(tf.abs(self.grad_bcs[i])))
            self.mean_grad_ics_list.append(tf.reduce_mean(tf.abs(self.grad_ics[i])))
        
        self.mean_grad_res = tf.reduce_mean(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs = tf.reduce_mean(tf.stack(self.mean_grad_bcs_list))
        self.mean_grad_ics = tf.reduce_mean(tf.stack(self.mean_grad_ics_list))
        
        # self.adaptive_constant_bcs = self.max_grad_res / self.mean_grad_bcs
        # self.adaptive_constant_ics = self.max_grad_res / self.mean_grad_ics

        # # Stiff Ratio
        # if self.stiff_ratio:
        #     self.Hessian, self.Hessian_ics, self.Hessian_bcs, self.Hessian_res = self.get_H_op()
        #     self.eigenvalues, _ = tf.linalg.eigh(self.Hessian)
        #     self.eigenvalues_ics, _ = tf.linalg.eigh(self.Hessian_ics)
        #     self.eigenvalues_bcs, _ = tf.linalg.eigh(self.Hessian_bcs)
        #     self.eigenvalues_res, _ = tf.linalg.eigh(self.Hessian_res)

        #     self.eigenvalue_log = []
        #     self.eigenvalue_ics_log = []
        #     self.eigenvalue_bcs_log = []
        #     self.eigenvalue_res_log = []

        # Initialize Tensorflow variables

        self.prev_lam_ics =1
        self.prev_lam_bcs = 1
        self.prev_lam_res = 1
        self.index = 1
        
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Create dictionary to store gradients
    def generate_grad_dict(self, layers):
        num = len(layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Save gradients
    def save_gradients(self, tf_dict):
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_ics_value , grad_bcs_value, grad_res_value= self.sess.run([self.grad_ics[i],
                                                                            self.grad_bcs[i],
                                                                            self.grad_res[i]],
                                                                            feed_dict=tf_dict)

            # save gradients of loss_res and loss_bcs
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics_value.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bcs_value.flatten())
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res_value.flatten())
        return None

    # Compute the Hessian
    def flatten(self, vectors):
        return tf.concat([tf.reshape(v, [-1]) for v in vectors], axis=0)

    def get_Hv(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_ics(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_ics, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_bcs(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_bcs, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_res(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_res,
                                                   self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod,
                                          self.weights))
        return Hv_op

    def get_H_op(self):
        self.P = self.flatten(self.weights).get_shape().as_list()[0]
        H = tf.map_fn(self.get_Hv, tf.eye(self.P, self.P),
                      dtype='float32')
        H_ics = tf.map_fn(self.get_Hv_ics, tf.eye(self.P, self.P),
                          dtype='float32')
        H_bcs = tf.map_fn(self.get_Hv_bcs, tf.eye(self.P, self.P),
                          dtype='float32')
        H_res = tf.map_fn(self.get_Hv_res, tf.eye(self.P, self.P),
                          dtype='float32')

        return H, H_ics, H_bcs, H_res

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # if self.model in ['M3', 'M4']:
    #     num_layers = len(self.layers)
    #     encoder_1 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_1), self.encoder_biases_1))
    #     encoder_2 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_2), self.encoder_biases_2))

    #     for l in range(0, num_layers - 2):
    #         W = self.weights[l]
    #         b = self.biases[l]
    #         H = tf.math.multiply(tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_1) + \
    #             tf.math.multiply(1 - tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_2)

    #     W = self.weights[-1]
    #     b = self.biases[-1]
    #     H = tf.add(tf.matmul(H, W), b)
    #     return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1))
        return u

    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,  self.alpha, self.beta, self.gamma, self.k, self.sigma_t, self.sigma_x)
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
################################################################################################################

    def train(self,bcbatch_size , fbatch_size , nIter=10000):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size)
        X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size)

        # Fetch residual mini-batch
        X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, fbatch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.u_bc1_tf: u_bc1_batch,
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.u_bc2_tf: u_bc2_batch,
                    self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                    self.r_tf: f_res_batch,
                    self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                    self.adaptive_constant_res_tf: self.adaptive_constant_res_val,
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val}

        for it in range(1,nIter):

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)

            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value , loss_ics, loss_bcs , loss_r_value = self.sess.run([self.loss ,self.loss_ics, self.loss_bcs, self.loss_res], tf_dict)
                self.print('It: %d, Loss: %.3e, loss_ics: %.3e, loss_bcs: %.3e, Loss_r: %.3e, Time: %.2f' %(it, loss_value, loss_ics, loss_bcs ,  loss_r_value, elapsed))

                # Compute and Print adaptive weights during training
                
            if it % 100 == 0:

                # Compute the adaptive constant
                # Print adaptive weights during training
                self.adaptive_constant_ics_val =   self.relobralo( "loss_ics"  ,self.prev_lam_ics )  
                self.adaptive_constant_bcs_val =  self.relobralo( "loss_bcs"  ,self.prev_lam_bcs )  
                self.adaptive_constant_res_val =  self.relobralo( "loss_res"  ,self.prev_lam_res )  

                # # Store loss and adaptive weights
                # self.loss_u_log.append(loss_u_value)
                # self.loss_r_log.append(loss_r_value)

                self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)
                self.adaptive_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                self.adaptive_constant_res_log.append(self.adaptive_constant_res_val)
                
                mean_grad_bcs , mean_grad_ics, mean_grad_res = self.sess.run([self.mean_grad_bcs ,self.mean_grad_ics, self.mean_grad_res], tf_dict)

                self.mean_grad_bcs_log.append(mean_grad_bcs)
                self.mean_grad_ics_log.append(mean_grad_ics)
                self.mean_grad_res_log.append(mean_grad_res)

                self.print("constant_ics_val: {:.3f}".format( self.adaptive_constant_ics_val))
                self.print("constant_bcs_val: {:.3f}".format( self.adaptive_constant_bcs_val))
                self.print("constant_res_val: {:.3f}".format( self.adaptive_constant_res_val))

                self.prev_lam_ics = self.adaptive_constant_ics_val
                self.prev_lam_bcs = self.adaptive_constant_bcs_val
                self.prev_lam_res = self.adaptive_constant_res_val
                self.index= it

            sys.stdout.flush()
            start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

 
################################################################################################################
                

    def lambda_balance(self ,term , index):

        loss_list = ["loss_res" , "loss_bcs" , "loss_ics"] 
        m = len(loss_list)
        num = np.exp(self.loss_history[term][-1] /(self.T * self.loss_history[term][index]))
        denum = 0 

        for  key in loss_list:
            denum +=  np.exp(self.loss_history[key][-1] /(self.T * self.loss_history[key][index]))
        return m * (num / denum)
     
    def relobralo( self, term ,prev_lamda ):

        lambda_hist = self.rho  * prev_lamda + (1.0 - self.rho) *  self.lambda_balance( term ,1)
        lambda_i = self.rate  * lambda_hist + (1.0 - self.rate) *  self.lambda_balance( term , self.index)

        return lambda_i
    
    ###################################################################################
    def trainmb(self, nIter=10000, batch_size=128):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(1,nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size)
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)

            # Fetch residual mini-batch
            X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.u_bc1_tf: u_bc1_batch,
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.u_bc2_tf: u_bc2_batch,
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.r_tf: f_res_batch,
                       self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                       self.adaptive_constant_res_tf: self.adaptive_constant_res_val,
                       self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val}

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)

            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value , loss_ics, loss_bcs , loss_r_value = self.sess.run([self.loss ,self.loss_ics, self.loss_bcs, self.loss_res], tf_dict)
                self.print('It: %d, Loss: %.3e, loss_ics: %.3e, loss_bcs: %.3e, Loss_r: %.3e, Time: %.2f' %(it, loss_value, loss_ics, loss_bcs ,  loss_r_value, elapsed))

                # Compute and Print adaptive weights during training
                
            if it % 100 == 0:

                # Compute the adaptive constant
                # Print adaptive weights during training
                self.adaptive_constant_ics_val =   self.relobralo( "loss_ics"  ,self.prev_lam_ics )  
                self.adaptive_constant_bcs_val =  self.relobralo( "loss_bcs"  ,self.prev_lam_bcs )  
                self.adaptive_constant_res_val =  self.relobralo( "loss_res"  ,self.prev_lam_res )  

                # # Store loss and adaptive weights
                # self.loss_u_log.append(loss_u_value)
                # self.loss_r_log.append(loss_r_value)

                self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)
                self.adaptive_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                self.adaptive_constant_res_log.append(self.adaptive_constant_res_val)
                
                mean_grad_bcs , mean_grad_ics, mean_grad_res = self.sess.run([self.mean_grad_bcs ,self.mean_grad_ics, self.mean_grad_res], tf_dict)

                self.mean_grad_bcs_log.append(mean_grad_bcs)
                self.mean_grad_ics_log.append(mean_grad_ics)
                self.mean_grad_res_log.append(mean_grad_res)

                self.print("constant_ics_val: {:.3f}".format( self.adaptive_constant_ics_val))
                self.print("constant_bcs_val: {:.3f}".format( self.adaptive_constant_bcs_val))
                self.print("constant_res_val: {:.3f}".format( self.adaptive_constant_res_val))

                self.prev_lam_ics = self.adaptive_constant_ics_val
                self.prev_lam_bcs = self.adaptive_constant_bcs_val
                self.prev_lam_res = self.adaptive_constant_res_val
                self.index= it

            sys.stdout.flush()
            start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

 

    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

  # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1  , grad_ics  = self.sess.run([ self.grad_res[i],self.grad_bcs[i],self.grad_ics[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs_layers['layer_' + str(j + 1)][-1]
            gradients_ics = self.dict_gradients_ics_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')
            sns.distplot(gradients_ics, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{ics}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=3)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all" , )
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        plt.close("all" , )
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)



    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
        from mpl_toolkits.axes_grid1 import ImageGrid

        ### Plot ###
        plt.close("all" , )

        # Exact solution & Predicted solution
        # Exact soluton
        U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
        F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

        # Predicted solution
        U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
        F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

        titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $f(x)$' , 'Predicted $f(x)$' , 'Absolute error']
        data = [U_star , U_pred ,  np.abs(U_star - U_pred) , F_star , F_pred ,  np.abs(F_star - F_pred) ]
        

        fig_1 = plt.figure(1, figsize=(13, 5))
        grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                        label_mode="1", axes_pad=1.7, share_all=False, 
                        cbar_mode="each", cbar_location="right", 
                        cbar_size="5%", cbar_pad=0.0)
    # CREATE ARGUMENTS DICT FOR CONTOURPLOTS
        minmax_list = []
        kwargs_list = []
        for d in data:
            # if(local):
            #     minmax_list.append([np.min(d), np.max(d)])
            # else:
            minmax_list.append([np.min(d), np.max(d)])

            kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60),
                cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

        for ax, z, kwargs, minmax, title in zip(grid, data, kwargs_list, minmax_list, titles):
        #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
            #pcfsets.append(pcf)
            # if (timeStp == 0):
                #  print( z[timeStp,:,:])
            pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
            cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
            ax.cax.tick_params(labelsize=14.5)
            ax.set_title(title, fontsize=14.5, pad=7)
            ax.set_ylabel("time", labelpad=14.5, fontsize=14.5, rotation="horizontal")
            ax.set_xlabel("x", fontsize=14.5)
            ax.tick_params(labelsize=14.5)
            ax.set_xlim(x1.min(), x1.max())
            ax.set_ylim(x2.min(), x2.max())
            ax.set_aspect("equal")

        fig_1.set_size_inches(15, 10, True)
        fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
        plt.close("all" , )


    def plot_lambda(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adaptive_constant_bcs_log, label=r'$lambda_{bc}$')
        ax.semilogy(self.adaptive_constant_ics_log, label=r'$lambda_{ic}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\lambda$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'lambda_history.png')
        plt.savefig(path)
        plt.close("all" , )





    def plot_grad(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.mean_grad_bcs_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc}}}$')
        ax.semilogy(self.mean_grad_res_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{res}}}$')
        ax.semilogy(self.mean_grad_ics_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{ics}}}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\bar{\nabla_{\theta} \mathcal{L}}$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)
        plt.close("all" , )

# %%
def test_method(method , layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma ,k ,mode , stiff_ratio ,  X_star , u_star , f_star):


    model = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, stiff_ratio)

    # Train model
    start_time = time.time()

    if method =="full_batch":
        model.train(nIter=40001 )
    elif method =="mini_batch":
        model.trainmb(nIter=40001, batch_size=128)
    else:
        print("unknown method!")
    elapsed = time.time() - start_time

    # Predictions
    u_pred = model.predict_u(X_star)
    f_pred = model.predict_r(X_star)

    # Relative error
    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_f: {:.2e}'.format(error_f))

    return [elapsed, error_u , error_f]

# %%
# Parameters of equations
alpha = -1.0
beta = 0.0
gamma = 1.0
k = 3
# Domain boundaries
ics_coords = np.array([[0.0, 0.0], [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0], [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0], [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0], [1.0, 1.0]])


# Define model
layers = [2, 50, 50, 50, 50, 50, 1]
mode = 'relobralo'          # Method: 'M1', 'M2', 'M3', 'M4'
stiff_ratio = False  # Log the eigenvalues of Hessian of losses



nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 128

# Test data
nn = 100
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

# Exact solution
u_star = u(X_star)
f_star = f(X_star, alpha, beta, gamma, k)


iterations = 1
methods = ["full_batch" ]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_f_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create initial conditions samplers
        ics_sampler = Sampler(2, ics_coords, lambda x: u(x), name='Initial Condition 1')

        # Create boundary conditions samplers
        bc1 = Sampler(2, bc1_coords, lambda x: u(x), name='Dirichlet BC1')
        bc2 = Sampler(2, bc2_coords, lambda x: u(x), name='Dirichlet BC2')
        bcs_sampler = [bc1, bc2]

        # Create residual sampler
        res_sampler = Sampler(2, dom_coords, lambda x: f(x, alpha, beta, gamma, k), name='Forcing')
        bcs_sampler = [bc1, bc2]

        # [elapsed, error_u , error_f] = test_method(mtd , layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma ,k ,mode , stiff_ratio ,  X_star , u_star , f_star)

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            model = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, alpha, beta, gamma, k, mode, sess)

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                model.train(bcbatch_size , ubatch_size , nIter=nIter )
            elif mtd =="mini_batch":
                model.trainmb(nIter=nIter, batch_size=128)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            f_pred = model.predict_r(X_star)

            # Relative error
            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_f: {:.2e}'.format(error_f))
            
            model.print("average adaptive_constant_bcs_log : " , np.average(model.adaptive_constant_bcs_log))
            model.print("average adaptive_constant_ics_log : " , np.average(model.adaptive_constant_ics_log))
            model.print("average adaptive_constant_res_log : " , np.average(model.adaptive_constant_res_log))
            # sess.close() 

            model.plot_lambda()
            model.plot_grad()
            model.save_NN()
            model.plt_prediction( t , x , X_star , u_star , u_pred , f_star , f_pred)

            time_list.append(elapsed)
            error_u_list.append(error_u)
            error_f_list.append(error_f)

    # print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_f_list:" , sum(error_f_list) / len(error_f_list) )

    result_dict[mtd] = [time_list ,error_u_list ,  error_f_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_Helmholtz_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)
# Out:
# Method:  full_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_13026/1757824062.py:66: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_13026/1757824062.py:67: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_13026/1757824062.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_13026/1757824062.py:68: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-18 02:42:12.259114: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-18 02:42:12.287384: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-18 02:42:12.289530: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562544bf19c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-18 02:42:12.289594: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-18 02:42:12.297347: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_13026/1271366133.py:277: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_13026/1271366133.py:70: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From /tmp/ipykernel_13026/1271366133.py:120: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_13026/1271366133.py:122: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tmp/ipykernel_13026/1271366133.py:199: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 1.756e+03, loss_ics: 2.195e+01, loss_bcs: 1.449e+01, Loss_r: 1.720e+03, Time: 0.18
# constant_ics_val: 2.500
# constant_bcs_val: 0.250
# constant_res_val: 0.250
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 1.650e+02, loss_ics: 6.970e+01, loss_bcs: 1.847e+01, Loss_r: 7.688e+01, Time: 0.11
# constant_ics_val: 2.686
# constant_bcs_val: 0.214
# constant_res_val: 0.101
# It: 300, Loss: 1.036e+02, loss_ics: 4.752e+01, loss_bcs: 1.635e+01, Loss_r: 3.969e+01, Time: 0.13
# constant_ics_val: 1.908
# constant_bcs_val: 0.662
# constant_res_val: 0.430
# It: 400, Loss: 7.142e+01, loss_ics: 3.238e+01, loss_bcs: 1.470e+01, Loss_r: 2.434e+01, Time: 0.16
# constant_ics_val: 1.698
# constant_bcs_val: 0.761
# constant_res_val: 0.541
# It: 500, Loss: 3.970e+01, loss_ics: 1.622e+01, loss_bcs: 1.224e+01, Loss_r: 1.124e+01, Time: 0.17
# constant_ics_val: 1.589
# constant_bcs_val: 0.842
# constant_res_val: 0.569
# It: 600, Loss: 3.095e+01, loss_ics: 1.444e+01, loss_bcs: 1.086e+01, Loss_r: 5.649e+00, Time: 0.11
# constant_ics_val: 1.684
# constant_bcs_val: 0.805
# constant_res_val: 0.511
# It: 700, Loss: 2.852e+01, loss_ics: 1.396e+01, loss_bcs: 9.837e+00, Loss_r: 4.728e+00, Time: 0.14
# constant_ics_val: 1.702
# constant_bcs_val: 0.718
# constant_res_val: 0.580
# It: 800, Loss: 2.536e+01, loss_ics: 1.305e+01, loss_bcs: 8.506e+00, Loss_r: 3.812e+00, Time: 0.14
# constant_ics_val: 1.711
# constant_bcs_val: 0.681
# constant_res_val: 0.609
# It: 900, Loss: 2.094e+01, loss_ics: 1.108e+01, loss_bcs: 6.306e+00, Loss_r: 3.560e+00, Time: 0.19
# constant_ics_val: 1.682
# constant_bcs_val: 0.620
# constant_res_val: 0.698
# It: 1000, Loss: 8.682e+00, loss_ics: 3.346e+00, loss_bcs: 1.544e+00, Loss_r: 3.792e+00, Time: 0.17
# constant_ics_val: 1.486
# constant_bcs_val: 0.541
# constant_res_val: 0.972
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 2.688e+00, loss_ics: 4.915e-01, loss_bcs: 3.991e-01, Loss_r: 1.797e+00, Time: 0.13
# constant_ics_val: 1.105
# constant_bcs_val: 0.906
# constant_res_val: 0.989
# It: 1200, Loss: 1.918e+00, loss_ics: 2.603e-01, loss_bcs: 2.327e-01, Loss_r: 1.425e+00, Time: 0.11
# constant_ics_val: 0.999
# constant_bcs_val: 0.980
# constant_res_val: 1.021
# It: 1300, Loss: 7.229e+00, loss_ics: 2.390e-01, loss_bcs: 1.493e-01, Loss_r: 6.840e+00, Time: 0.13
# constant_ics_val: 0.581
# constant_bcs_val: 0.487
# constant_res_val: 1.932
# It: 1400, Loss: 6.505e+00, loss_ics: 2.372e-01, loss_bcs: 1.099e-01, Loss_r: 6.158e+00, Time: 0.14
# constant_ics_val: 1.231
# constant_bcs_val: 0.703
# constant_res_val: 1.066
# It: 1500, Loss: 4.613e+00, loss_ics: 1.377e-01, loss_bcs: 8.578e-02, Loss_r: 4.389e+00, Time: 0.15
# constant_ics_val: 1.109
# constant_bcs_val: 0.997
# constant_res_val: 0.894
# It: 1600, Loss: 1.253e+00, loss_ics: 1.328e-01, loss_bcs: 6.940e-02, Loss_r: 1.050e+00, Time: 0.11
# constant_ics_val: 1.174
# constant_bcs_val: 1.074
# constant_res_val: 0.753
# It: 1700, Loss: 1.174e+00, loss_ics: 1.161e-01, loss_bcs: 5.812e-02, Loss_r: 9.998e-01, Time: 0.09
# constant_ics_val: 1.041
# constant_bcs_val: 1.003
# constant_res_val: 0.956
# It: 1800, Loss: 1.080e+00, loss_ics: 1.017e-01, loss_bcs: 4.933e-02, Loss_r: 9.290e-01, Time: 0.11
# constant_ics_val: 1.028
# constant_bcs_val: 0.984
# constant_res_val: 0.989
# It: 1900, Loss: 5.594e+00, loss_ics: 9.526e-02, loss_bcs: 4.188e-02, Loss_r: 5.457e+00, Time: 0.10
# constant_ics_val: 0.560
# constant_bcs_val: 0.530
# constant_res_val: 1.909
# It: 2000, Loss: 9.550e-01, loss_ics: 8.689e-02, loss_bcs: 3.697e-02, Loss_r: 8.311e-01, Time: 0.13
# constant_ics_val: 1.062
# constant_bcs_val: 0.967
# constant_res_val: 0.970
# It: 2100, Loss: 6.658e+00, loss_ics: 1.132e-01, loss_bcs: 3.287e-02, Loss_r: 6.512e+00, Time: 0.12
# constant_ics_val: 0.564
# constant_bcs_val: 0.475
# constant_res_val: 1.962
# It: 2200, Loss: 2.146e+00, loss_ics: 7.500e-02, loss_bcs: 3.019e-02, Loss_r: 2.041e+00, Time: 0.10
# constant_ics_val: 0.915
# constant_bcs_val: 1.042
# constant_res_val: 1.043
# It: 2300, Loss: 4.424e+00, loss_ics: 1.570e-01, loss_bcs: 2.677e-02, Loss_r: 4.240e+00, Time: 0.13
# constant_ics_val: 1.313
# constant_bcs_val: 0.657
# constant_res_val: 1.030
# It: 2400, Loss: 7.873e-01, loss_ics: 6.715e-02, loss_bcs: 2.583e-02, Loss_r: 6.943e-01, Time: 0.16
# constant_ics_val: 1.013
# constant_bcs_val: 1.177
# constant_res_val: 0.809
# It: 2500, Loss: 3.848e+00, loss_ics: 7.317e-02, loss_bcs: 2.430e-02, Loss_r: 3.751e+00, Time: 0.16
# constant_ics_val: 0.531
# constant_bcs_val: 0.552
# constant_res_val: 1.917
# It: 2600, Loss: 1.905e+00, loss_ics: 9.255e-02, loss_bcs: 2.203e-02, Loss_r: 1.791e+00, Time: 0.09
# constant_ics_val: 1.124
# constant_bcs_val: 0.875
# constant_res_val: 1.002
# It: 2700, Loss: 8.476e-01, loss_ics: 6.122e-02, loss_bcs: 2.228e-02, Loss_r: 7.641e-01, Time: 0.19
# constant_ics_val: 0.997
# constant_bcs_val: 1.143
# constant_res_val: 0.861
# It: 2800, Loss: 2.975e+00, loss_ics: 5.567e-02, loss_bcs: 2.178e-02, Loss_r: 2.898e+00, Time: 0.13
# constant_ics_val: 0.623
# constant_bcs_val: 0.652
# constant_res_val: 1.725
# It: 2900, Loss: 5.724e-01, loss_ics: 5.361e-02, loss_bcs: 2.086e-02, Loss_r: 4.979e-01, Time: 0.11
# constant_ics_val: 1.038
# constant_bcs_val: 1.032
# constant_res_val: 0.930
# It: 3000, Loss: 5.637e-01, loss_ics: 5.183e-02, loss_bcs: 2.051e-02, Loss_r: 4.914e-01, Time: 0.13
# constant_ics_val: 1.011
# constant_bcs_val: 1.012
# constant_res_val: 0.977
# It: 3100, Loss: 5.320e-01, loss_ics: 5.017e-02, loss_bcs: 2.011e-02, Loss_r: 4.617e-01, Time: 0.13
# constant_ics_val: 1.011
# constant_bcs_val: 1.015
# constant_res_val: 0.973
# It: 3200, Loss: 1.357e+00, loss_ics: 4.774e-02, loss_bcs: 2.028e-02, Loss_r: 1.289e+00, Time: 0.12
# constant_ics_val: 0.740
# constant_bcs_val: 0.735
# constant_res_val: 1.525
# It: 3300, Loss: 1.401e+00, loss_ics: 7.871e-02, loss_bcs: 1.838e-02, Loss_r: 1.304e+00, Time: 0.16
# constant_ics_val: 1.192
# constant_bcs_val: 0.676
# constant_res_val: 1.132
# It: 3400, Loss: 6.704e-01, loss_ics: 4.482e-02, loss_bcs: 1.984e-02, Loss_r: 6.057e-01, Time: 0.13
# constant_ics_val: 0.966
# constant_bcs_val: 1.130
# constant_res_val: 0.904
# It: 3500, Loss: 4.467e-01, loss_ics: 4.393e-02, loss_bcs: 1.937e-02, Loss_r: 3.834e-01, Time: 0.15
# constant_ics_val: 1.059
# constant_bcs_val: 1.092
# constant_res_val: 0.849
# It: 3600, Loss: 4.338e-01, loss_ics: 4.288e-02, loss_bcs: 1.936e-02, Loss_r: 3.715e-01, Time: 0.14
# constant_ics_val: 1.016
# constant_bcs_val: 1.036
# constant_res_val: 0.948
# It: 3700, Loss: 4.155e-01, loss_ics: 4.164e-02, loss_bcs: 1.892e-02, Loss_r: 3.549e-01, Time: 0.12
# constant_ics_val: 1.011
# constant_bcs_val: 1.014
# constant_res_val: 0.975
# It: 3800, Loss: 3.994e-01, loss_ics: 4.022e-02, loss_bcs: 1.891e-02, Loss_r: 3.403e-01, Time: 0.13
# constant_ics_val: 1.006
# constant_bcs_val: 1.018
# constant_res_val: 0.977
# It: 3900, Loss: 4.123e-01, loss_ics: 3.910e-02, loss_bcs: 1.866e-02, Loss_r: 3.546e-01, Time: 0.12
# constant_ics_val: 0.995
# constant_bcs_val: 1.000
# constant_res_val: 1.005
# It: 4000, Loss: 1.939e+00, loss_ics: 3.852e-02, loss_bcs: 1.901e-02, Loss_r: 1.881e+00, Time: 0.14
# constant_ics_val: 0.557
# constant_bcs_val: 0.552
# constant_res_val: 1.891
# It: 4100, Loss: 3.580e-01, loss_ics: 3.711e-02, loss_bcs: 1.815e-02, Loss_r: 3.028e-01, Time: 0.13
# constant_ics_val: 1.021
# constant_bcs_val: 1.007
# constant_res_val: 0.972
# It: 4200, Loss: 3.604e-01, loss_ics: 3.659e-02, loss_bcs: 1.806e-02, Loss_r: 3.058e-01, Time: 0.14
# constant_ics_val: 0.994
# constant_bcs_val: 1.004
# constant_res_val: 1.002
# It: 4300, Loss: 3.343e-01, loss_ics: 3.515e-02, loss_bcs: 1.758e-02, Loss_r: 2.816e-01, Time: 0.13
# constant_ics_val: 1.011
# constant_bcs_val: 1.012
# constant_res_val: 0.977
# It: 4400, Loss: 6.887e+00, loss_ics: 2.096e-01, loss_bcs: 1.721e-02, Loss_r: 6.660e+00, Time: 0.12
# constant_ics_val: 0.551
# constant_bcs_val: 0.483
# constant_res_val: 1.967
# It: 4500, Loss: 1.216e+00, loss_ics: 3.356e-02, loss_bcs: 1.673e-02, Loss_r: 1.166e+00, Time: 0.14
# constant_ics_val: 0.723
# constant_bcs_val: 1.217
# constant_res_val: 1.060
# It: 4600, Loss: 3.355e-01, loss_ics: 3.220e-02, loss_bcs: 1.673e-02, Loss_r: 2.866e-01, Time: 0.14
# constant_ics_val: 1.041
# constant_bcs_val: 1.180
# constant_res_val: 0.779
# It: 4700, Loss: 2.903e-01, loss_ics: 3.166e-02, loss_bcs: 1.624e-02, Loss_r: 2.424e-01, Time: 0.13
# constant_ics_val: 1.037
# constant_bcs_val: 1.069
# constant_res_val: 0.894
# It: 4800, Loss: 5.138e-01, loss_ics: 3.078e-02, loss_bcs: 1.608e-02, Loss_r: 4.669e-01, Time: 0.12
# constant_ics_val: 0.834
# constant_bcs_val: 0.843
# constant_res_val: 1.323
# It: 4900, Loss: 3.760e-01, loss_ics: 2.938e-02, loss_bcs: 1.562e-02, Loss_r: 3.310e-01, Time: 0.12
# constant_ics_val: 1.013
# constant_bcs_val: 1.006
# constant_res_val: 0.981
# It: 5000, Loss: 3.880e-01, loss_ics: 2.834e-02, loss_bcs: 1.502e-02, Loss_r: 3.446e-01, Time: 0.16
# constant_ics_val: 1.020
# constant_bcs_val: 0.997
# constant_res_val: 0.983
# It: 5100, Loss: 4.004e-01, loss_ics: 3.176e-02, loss_bcs: 1.452e-02, Loss_r: 3.541e-01, Time: 0.14
# constant_ics_val: 1.025
# constant_bcs_val: 0.999
# constant_res_val: 0.976
# It: 5200, Loss: 1.199e+00, loss_ics: 4.017e-02, loss_bcs: 1.366e-02, Loss_r: 1.145e+00, Time: 0.13
# constant_ics_val: 0.688
# constant_bcs_val: 0.677
# constant_res_val: 1.635
# It: 5300, Loss: 4.077e-01, loss_ics: 2.851e-02, loss_bcs: 1.393e-02, Loss_r: 3.653e-01, Time: 0.15
# constant_ics_val: 0.964
# constant_bcs_val: 1.087
# constant_res_val: 0.949
# It: 5400, Loss: 2.257e-01, loss_ics: 2.545e-02, loss_bcs: 1.342e-02, Loss_r: 1.868e-01, Time: 0.14
# constant_ics_val: 1.043
# constant_bcs_val: 1.116
# constant_res_val: 0.841
# It: 5500, Loss: 2.786e-01, loss_ics: 2.634e-02, loss_bcs: 1.320e-02, Loss_r: 2.390e-01, Time: 0.15
# constant_ics_val: 0.832
# constant_bcs_val: 0.851
# constant_res_val: 1.317
# It: 5600, Loss: 1.042e+00, loss_ics: 2.427e-02, loss_bcs: 1.240e-02, Loss_r: 1.006e+00, Time: 0.13
# constant_ics_val: 0.548
# constant_bcs_val: 0.558
# constant_res_val: 1.894
# It: 5700, Loss: 6.576e-01, loss_ics: 3.261e-02, loss_bcs: 1.221e-02, Loss_r: 6.128e-01, Time: 0.17
# constant_ics_val: 1.225
# constant_bcs_val: 0.805
# constant_res_val: 0.970
# It: 5800, Loss: 6.102e-01, loss_ics: 3.879e-02, loss_bcs: 1.176e-02, Loss_r: 5.596e-01, Time: 0.10
# constant_ics_val: 1.056
# constant_bcs_val: 0.997
# constant_res_val: 0.946
# It: 5900, Loss: 2.520e-01, loss_ics: 2.139e-02, loss_bcs: 1.149e-02, Loss_r: 2.191e-01, Time: 0.20
# constant_ics_val: 0.978
# constant_bcs_val: 1.190
# constant_res_val: 0.831
# It: 6000, Loss: 6.095e-01, loss_ics: 2.956e-02, loss_bcs: 1.096e-02, Loss_r: 5.690e-01, Time: 0.11
# constant_ics_val: 0.978
# constant_bcs_val: 0.798
# constant_res_val: 1.224
# It: 6100, Loss: 1.772e-01, loss_ics: 2.019e-02, loss_bcs: 1.067e-02, Loss_r: 1.464e-01, Time: 0.12
# constant_ics_val: 0.997
# constant_bcs_val: 1.140
# constant_res_val: 0.863
# It: 6200, Loss: 2.264e-01, loss_ics: 2.091e-02, loss_bcs: 1.016e-02, Loss_r: 1.953e-01, Time: 0.14
# constant_ics_val: 0.883
# constant_bcs_val: 0.911
# constant_res_val: 1.206
# It: 6300, Loss: 1.796e-01, loss_ics: 1.902e-02, loss_bcs: 9.675e-03, Loss_r: 1.509e-01, Time: 0.17
# constant_ics_val: 0.987
# constant_bcs_val: 1.010
# constant_res_val: 1.003
# It: 6400, Loss: 2.641e-01, loss_ics: 1.803e-02, loss_bcs: 9.619e-03, Loss_r: 2.364e-01, Time: 0.15
# constant_ics_val: 0.930
# constant_bcs_val: 0.945
# constant_res_val: 1.126
# It: 6500, Loss: 3.927e-01, loss_ics: 2.277e-02, loss_bcs: 8.785e-03, Loss_r: 3.612e-01, Time: 0.12
# constant_ics_val: 1.085
# constant_bcs_val: 0.719
# constant_res_val: 1.196
# It: 6600, Loss: 1.494e-01, loss_ics: 1.699e-02, loss_bcs: 8.857e-03, Loss_r: 1.236e-01, Time: 0.14
# constant_ics_val: 1.028
# constant_bcs_val: 1.105
# constant_res_val: 0.867
# It: 6700, Loss: 4.300e-01, loss_ics: 1.615e-02, loss_bcs: 8.676e-03, Loss_r: 4.052e-01, Time: 0.12
# constant_ics_val: 0.579
# constant_bcs_val: 0.593
# constant_res_val: 1.828
# It: 6800, Loss: 1.846e+00, loss_ics: 1.554e-02, loss_bcs: 8.568e-03, Loss_r: 1.822e+00, Time: 0.12
# constant_ics_val: 0.462
# constant_bcs_val: 0.457
# constant_res_val: 2.081
# It: 6900, Loss: 1.090e+00, loss_ics: 5.066e-02, loss_bcs: 7.540e-03, Loss_r: 1.032e+00, Time: 0.15
# constant_ics_val: 1.748
# constant_bcs_val: 0.425
# constant_res_val: 0.827
# It: 7000, Loss: 2.008e-01, loss_ics: 1.476e-02, loss_bcs: 7.556e-03, Loss_r: 1.785e-01, Time: 0.15
# constant_ics_val: 1.061
# constant_bcs_val: 1.158
# constant_res_val: 0.781
# It: 7100, Loss: 2.797e+00, loss_ics: 8.724e-02, loss_bcs: 7.052e-03, Loss_r: 2.702e+00, Time: 0.12
# constant_ics_val: 0.549
# constant_bcs_val: 0.524
# constant_res_val: 1.927
# It: 7200, Loss: 1.666e-01, loss_ics: 1.387e-02, loss_bcs: 6.984e-03, Loss_r: 1.457e-01, Time: 0.12
# constant_ics_val: 0.733
# constant_bcs_val: 1.224
# constant_res_val: 1.043
# It: 7300, Loss: 1.185e-01, loss_ics: 1.320e-02, loss_bcs: 6.687e-03, Loss_r: 9.864e-02, Time: 0.14
# constant_ics_val: 0.983
# constant_bcs_val: 1.107
# constant_res_val: 0.911
# It: 7400, Loss: 2.514e-01, loss_ics: 1.907e-02, loss_bcs: 5.945e-03, Loss_r: 2.263e-01, Time: 0.12
# constant_ics_val: 0.510
# constant_bcs_val: 0.527
# constant_res_val: 1.963
# It: 7500, Loss: 1.256e-01, loss_ics: 1.228e-02, loss_bcs: 6.168e-03, Loss_r: 1.072e-01, Time: 0.15
# constant_ics_val: 0.834
# constant_bcs_val: 1.075
# constant_res_val: 1.091
# It: 7600, Loss: 1.076e-01, loss_ics: 1.180e-02, loss_bcs: 5.942e-03, Loss_r: 8.988e-02, Time: 0.16
# constant_ics_val: 0.982
# constant_bcs_val: 1.042
# constant_res_val: 0.976
# It: 7700, Loss: 1.596e-01, loss_ics: 1.137e-02, loss_bcs: 5.596e-03, Loss_r: 1.427e-01, Time: 0.12
# constant_ics_val: 0.934
# constant_bcs_val: 0.891
# constant_res_val: 1.175
# It: 7800, Loss: 1.010e-01, loss_ics: 1.100e-02, loss_bcs: 5.465e-03, Loss_r: 8.455e-02, Time: 0.11
# constant_ics_val: 1.046
# constant_bcs_val: 1.042
# constant_res_val: 0.913
# It: 7900, Loss: 9.872e-02, loss_ics: 1.051e-02, loss_bcs: 5.310e-03, Loss_r: 8.291e-02, Time: 0.12
# constant_ics_val: 1.012
# constant_bcs_val: 1.004
# constant_res_val: 0.984
# It: 8000, Loss: 9.562e-02, loss_ics: 1.018e-02, loss_bcs: 5.039e-03, Loss_r: 8.039e-02, Time: 0.12
# constant_ics_val: 1.008
# constant_bcs_val: 0.993
# constant_res_val: 0.999
# It: 8100, Loss: 6.454e-01, loss_ics: 9.712e-03, loss_bcs: 4.989e-03, Loss_r: 6.307e-01, Time: 0.12
# constant_ics_val: 0.507
# constant_bcs_val: 0.502
# constant_res_val: 1.991
# It: 8200, Loss: 1.192e-01, loss_ics: 9.431e-03, loss_bcs: 4.663e-03, Loss_r: 1.051e-01, Time: 0.13
# constant_ics_val: 1.009
# constant_bcs_val: 0.989
# constant_res_val: 1.002
# It: 8300, Loss: 1.107e-01, loss_ics: 9.216e-03, loss_bcs: 4.493e-03, Loss_r: 9.700e-02, Time: 0.13
# constant_ics_val: 1.066
# constant_bcs_val: 1.003
# constant_res_val: 0.931
# It: 8400, Loss: 2.182e-01, loss_ics: 8.749e-03, loss_bcs: 4.300e-03, Loss_r: 2.051e-01, Time: 0.15
# constant_ics_val: 0.793
# constant_bcs_val: 0.779
# constant_res_val: 1.428
# It: 8500, Loss: 9.151e-02, loss_ics: 8.289e-03, loss_bcs: 4.229e-03, Loss_r: 7.900e-02, Time: 0.12
# constant_ics_val: 1.056
# constant_bcs_val: 1.035
# constant_res_val: 0.909
# It: 8600, Loss: 1.500e-01, loss_ics: 8.250e-03, loss_bcs: 3.962e-03, Loss_r: 1.378e-01, Time: 0.13
# constant_ics_val: 0.674
# constant_bcs_val: 0.661
# constant_res_val: 1.666
# It: 8700, Loss: 1.893e-01, loss_ics: 1.279e-02, loss_bcs: 3.742e-03, Loss_r: 1.728e-01, Time: 0.13
# constant_ics_val: 0.972
# constant_bcs_val: 0.863
# constant_res_val: 1.166
# It: 8800, Loss: 7.475e-02, loss_ics: 7.524e-03, loss_bcs: 3.772e-03, Loss_r: 6.345e-02, Time: 0.11
# constant_ics_val: 0.938
# constant_bcs_val: 1.174
# constant_res_val: 0.888
# It: 8900, Loss: 1.239e-01, loss_ics: 7.880e-03, loss_bcs: 3.672e-03, Loss_r: 1.124e-01, Time: 0.15
# constant_ics_val: 0.935
# constant_bcs_val: 0.837
# constant_res_val: 1.228
# It: 9000, Loss: 6.549e-01, loss_ics: 9.206e-03, loss_bcs: 3.428e-03, Loss_r: 6.422e-01, Time: 0.14
# constant_ics_val: 0.496
# constant_bcs_val: 0.467
# constant_res_val: 2.037
# It: 9100, Loss: 6.919e-02, loss_ics: 6.697e-03, loss_bcs: 3.405e-03, Loss_r: 5.909e-02, Time: 0.09
# constant_ics_val: 0.910
# constant_bcs_val: 1.073
# constant_res_val: 1.017
# It: 9200, Loss: 7.174e-02, loss_ics: 6.480e-03, loss_bcs: 3.294e-03, Loss_r: 6.197e-02, Time: 0.12
# constant_ics_val: 0.988
# constant_bcs_val: 1.009
# constant_res_val: 1.003
# It: 9300, Loss: 1.249e-01, loss_ics: 6.238e-03, loss_bcs: 3.224e-03, Loss_r: 1.154e-01, Time: 0.10
# constant_ics_val: 0.646
# constant_bcs_val: 0.645
# constant_res_val: 1.709
# It: 9400, Loss: 6.474e-02, loss_ics: 6.240e-03, loss_bcs: 3.113e-03, Loss_r: 5.539e-02, Time: 0.12
# constant_ics_val: 0.991
# constant_bcs_val: 0.993
# constant_res_val: 1.016
# It: 9500, Loss: 4.376e-01, loss_ics: 1.927e-02, loss_bcs: 2.964e-03, Loss_r: 4.153e-01, Time: 0.15
# constant_ics_val: 0.510
# constant_bcs_val: 0.500
# constant_res_val: 1.991
# It: 9600, Loss: 7.925e-02, loss_ics: 6.835e-03, loss_bcs: 2.866e-03, Loss_r: 6.955e-02, Time: 0.14
# constant_ics_val: 0.758
# constant_bcs_val: 1.180
# constant_res_val: 1.062
# It: 9700, Loss: 7.018e-01, loss_ics: 5.370e-03, loss_bcs: 2.967e-03, Loss_r: 6.934e-01, Time: 0.16
# constant_ics_val: 0.441
# constant_bcs_val: 0.545
# constant_res_val: 2.014
# It: 9800, Loss: 5.775e-02, loss_ics: 5.312e-03, loss_bcs: 2.781e-03, Loss_r: 4.965e-02, Time: 0.12
# constant_ics_val: 1.012
# constant_bcs_val: 1.001
# constant_res_val: 0.987
# It: 9900, Loss: 5.721e-02, loss_ics: 5.080e-03, loss_bcs: 2.738e-03, Loss_r: 4.939e-02, Time: 0.16
# constant_ics_val: 1.005
# constant_bcs_val: 0.991
# constant_res_val: 1.004
# It: 10000, Loss: 6.378e-02, loss_ics: 5.029e-03, loss_bcs: 2.608e-03, Loss_r: 5.614e-02, Time: 0.12
# constant_ics_val: 0.986
# constant_bcs_val: 0.971
# constant_res_val: 1.043
# It: 10100, Loss: 5.617e-02, loss_ics: 4.749e-03, loss_bcs: 2.615e-03, Loss_r: 4.881e-02, Time: 0.14
# constant_ics_val: 1.016
# constant_bcs_val: 1.028
# constant_res_val: 0.957
# It: 10200, Loss: 1.045e+00, loss_ics: 4.641e-03, loss_bcs: 2.501e-03, Loss_r: 1.037e+00, Time: 0.11
# constant_ics_val: 0.505
# constant_bcs_val: 0.507
# constant_res_val: 1.988
# It: 10300, Loss: 3.845e-01, loss_ics: 1.707e-02, loss_bcs: 2.390e-03, Loss_r: 3.650e-01, Time: 0.13
# constant_ics_val: 1.878
# constant_bcs_val: 0.376
# constant_res_val: 0.745
# It: 10400, Loss: 5.064e-02, loss_ics: 4.393e-03, loss_bcs: 2.436e-03, Loss_r: 4.381e-02, Time: 0.14
# constant_ics_val: 1.079
# constant_bcs_val: 1.179
# constant_res_val: 0.743
# It: 10500, Loss: 6.382e-02, loss_ics: 4.315e-03, loss_bcs: 2.327e-03, Loss_r: 5.718e-02, Time: 0.15
# constant_ics_val: 0.964
# constant_bcs_val: 0.986
# constant_res_val: 1.050
# It: 10600, Loss: 1.475e-01, loss_ics: 8.544e-03, loss_bcs: 2.235e-03, Loss_r: 1.367e-01, Time: 0.12
# constant_ics_val: 0.990
# constant_bcs_val: 0.984
# constant_res_val: 1.026
# It: 10700, Loss: 4.764e-02, loss_ics: 4.031e-03, loss_bcs: 2.291e-03, Loss_r: 4.132e-02, Time: 0.11
# constant_ics_val: 0.906
# constant_bcs_val: 1.250
# constant_res_val: 0.843
# It: 10800, Loss: 4.800e-02, loss_ics: 3.939e-03, loss_bcs: 2.214e-03, Loss_r: 4.185e-02, Time: 0.13
# constant_ics_val: 0.977
# constant_bcs_val: 1.057
# constant_res_val: 0.966
# It: 10900, Loss: 1.765e-01, loss_ics: 6.607e-03, loss_bcs: 2.103e-03, Loss_r: 1.678e-01, Time: 0.17
# constant_ics_val: 0.503
# constant_bcs_val: 0.513
# constant_res_val: 1.984
# It: 11000, Loss: 4.500e-02, loss_ics: 3.720e-03, loss_bcs: 2.165e-03, Loss_r: 3.911e-02, Time: 0.33
# constant_ics_val: 0.820
# constant_bcs_val: 1.126
# constant_res_val: 1.054
# It: 11100, Loss: 4.616e-02, loss_ics: 3.638e-03, loss_bcs: 2.091e-03, Loss_r: 4.043e-02, Time: 0.12
# constant_ics_val: 0.943
# constant_bcs_val: 1.019
# constant_res_val: 1.038
# It: 11200, Loss: 7.519e-02, loss_ics: 4.036e-03, loss_bcs: 2.061e-03, Loss_r: 6.909e-02, Time: 0.18
# constant_ics_val: 0.914
# constant_bcs_val: 0.717
# constant_res_val: 1.368
# It: 11300, Loss: 4.318e-02, loss_ics: 3.420e-03, loss_bcs: 2.051e-03, Loss_r: 3.771e-02, Time: 0.12
# constant_ics_val: 0.998
# constant_bcs_val: 1.041
# constant_res_val: 0.961
# It: 11400, Loss: 4.198e-02, loss_ics: 3.337e-03, loss_bcs: 1.995e-03, Loss_r: 3.665e-02, Time: 0.12
# constant_ics_val: 1.001
# constant_bcs_val: 1.009
# constant_res_val: 0.990
# It: 11500, Loss: 4.427e-02, loss_ics: 3.207e-03, loss_bcs: 1.994e-03, Loss_r: 3.906e-02, Time: 0.14
# constant_ics_val: 0.998
# constant_bcs_val: 0.997
# constant_res_val: 1.006
# It: 11600, Loss: 4.356e-02, loss_ics: 3.168e-03, loss_bcs: 1.951e-03, Loss_r: 3.844e-02, Time: 0.13
# constant_ics_val: 1.007
# constant_bcs_val: 1.002
# constant_res_val: 0.991
# It: 11700, Loss: 2.278e-01, loss_ics: 1.025e-02, loss_bcs: 1.900e-03, Loss_r: 2.157e-01, Time: 0.09
# constant_ics_val: 0.624
# constant_bcs_val: 0.537
# constant_res_val: 1.839
# It: 11800, Loss: 3.915e-02, loss_ics: 3.001e-03, loss_bcs: 1.887e-03, Loss_r: 3.426e-02, Time: 0.16
# constant_ics_val: 0.779
# constant_bcs_val: 1.192
# constant_res_val: 1.029
# It: 11900, Loss: 2.875e-01, loss_ics: 1.083e-02, loss_bcs: 1.853e-03, Loss_r: 2.748e-01, Time: 0.12
# constant_ics_val: 0.478
# constant_bcs_val: 0.556
# constant_res_val: 1.966
# It: 12000, Loss: 3.797e-02, loss_ics: 2.868e-03, loss_bcs: 1.829e-03, Loss_r: 3.328e-02, Time: 0.17
# constant_ics_val: 0.738
# constant_bcs_val: 1.208
# constant_res_val: 1.054
# It: 12100, Loss: 1.485e+00, loss_ics: 3.353e-03, loss_bcs: 1.888e-03, Loss_r: 1.480e+00, Time: 0.11
# constant_ics_val: 0.435
# constant_bcs_val: 0.552
# constant_res_val: 2.013
# It: 12200, Loss: 3.943e-02, loss_ics: 2.721e-03, loss_bcs: 1.768e-03, Loss_r: 3.495e-02, Time: 0.11
# constant_ics_val: 0.966
# constant_bcs_val: 1.043
# constant_res_val: 0.990
# It: 12300, Loss: 3.613e-02, loss_ics: 2.690e-03, loss_bcs: 1.751e-03, Loss_r: 3.169e-02, Time: 0.13
# constant_ics_val: 1.003
# constant_bcs_val: 1.028
# constant_res_val: 0.969
# It: 12400, Loss: 4.006e-01, loss_ics: 7.877e-03, loss_bcs: 1.721e-03, Loss_r: 3.910e-01, Time: 0.12
# constant_ics_val: 0.502
# constant_bcs_val: 0.507
# constant_res_val: 1.991
# It: 12500, Loss: 4.530e-02, loss_ics: 3.098e-03, loss_bcs: 1.691e-03, Loss_r: 4.051e-02, Time: 0.22
# constant_ics_val: 0.768
# constant_bcs_val: 1.183
# constant_res_val: 1.048
# It: 12600, Loss: 4.738e-02, loss_ics: 3.105e-03, loss_bcs: 1.678e-03, Loss_r: 4.259e-02, Time: 0.18
# constant_ics_val: 0.889
# constant_bcs_val: 1.066
# constant_res_val: 1.045
# It: 12700, Loss: 4.629e-02, loss_ics: 2.529e-03, loss_bcs: 1.647e-03, Loss_r: 4.211e-02, Time: 0.16
# constant_ics_val: 0.904
# constant_bcs_val: 1.050
# constant_res_val: 1.046
# It: 12800, Loss: 3.374e-02, loss_ics: 2.377e-03, loss_bcs: 1.629e-03, Loss_r: 2.974e-02, Time: 0.15
# constant_ics_val: 1.016
# constant_bcs_val: 1.069
# constant_res_val: 0.916
# It: 12900, Loss: 1.285e-01, loss_ics: 3.364e-03, loss_bcs: 1.594e-03, Loss_r: 1.235e-01, Time: 0.22
# constant_ics_val: 0.642
# constant_bcs_val: 0.612
# constant_res_val: 1.747
# It: 13000, Loss: 2.641e-01, loss_ics: 2.401e-03, loss_bcs: 1.591e-03, Loss_r: 2.601e-01, Time: 0.14
# constant_ics_val: 0.612
# constant_bcs_val: 0.692
# constant_res_val: 1.696
# It: 13100, Loss: 2.407e-01, loss_ics: 8.030e-03, loss_bcs: 1.578e-03, Loss_r: 2.311e-01, Time: 0.16
# constant_ics_val: 1.700
# constant_bcs_val: 0.544
# constant_res_val: 0.756
# It: 13200, Loss: 2.091e-01, loss_ics: 2.337e-03, loss_bcs: 1.545e-03, Loss_r: 2.053e-01, Time: 0.12
# constant_ics_val: 0.800
# constant_bcs_val: 0.665
# constant_res_val: 1.535
# It: 13300, Loss: 3.137e-02, loss_ics: 2.186e-03, loss_bcs: 1.517e-03, Loss_r: 2.767e-02, Time: 0.09
# constant_ics_val: 1.053
# constant_bcs_val: 1.062
# constant_res_val: 0.885
# It: 13400, Loss: 3.099e-02, loss_ics: 2.103e-03, loss_bcs: 1.503e-03, Loss_r: 2.738e-02, Time: 0.12
# constant_ics_val: 1.012
# constant_bcs_val: 1.016
# constant_res_val: 0.972
# It: 13500, Loss: 3.285e-02, loss_ics: 2.089e-03, loss_bcs: 1.466e-03, Loss_r: 2.929e-02, Time: 0.12
# constant_ics_val: 0.976
# constant_bcs_val: 0.966
# constant_res_val: 1.058
# It: 13600, Loss: 1.090e-01, loss_ics: 4.128e-03, loss_bcs: 1.443e-03, Loss_r: 1.035e-01, Time: 0.08
# constant_ics_val: 0.850
# constant_bcs_val: 0.571
# constant_res_val: 1.579
# It: 13700, Loss: 2.966e-02, loss_ics: 2.001e-03, loss_bcs: 1.445e-03, Loss_r: 2.621e-02, Time: 0.17
# constant_ics_val: 0.885
# constant_bcs_val: 1.144
# constant_res_val: 0.971
# It: 13800, Loss: 6.452e-02, loss_ics: 1.969e-03, loss_bcs: 1.426e-03, Loss_r: 6.112e-02, Time: 0.10
# constant_ics_val: 0.683
# constant_bcs_val: 0.749
# constant_res_val: 1.568
# It: 13900, Loss: 3.192e-02, loss_ics: 2.098e-03, loss_bcs: 1.411e-03, Loss_r: 2.842e-02, Time: 0.10
# constant_ics_val: 1.002
# constant_bcs_val: 1.028
# constant_res_val: 0.969
# It: 14000, Loss: 2.857e-02, loss_ics: 1.883e-03, loss_bcs: 1.391e-03, Loss_r: 2.530e-02, Time: 0.10
# constant_ics_val: 0.987
# constant_bcs_val: 1.041
# constant_res_val: 0.972
# It: 14100, Loss: 2.864e-02, loss_ics: 1.857e-03, loss_bcs: 1.366e-03, Loss_r: 2.541e-02, Time: 0.11
# constant_ics_val: 0.994
# constant_bcs_val: 1.004
# constant_res_val: 1.003
# It: 14200, Loss: 2.866e-02, loss_ics: 1.803e-03, loss_bcs: 1.358e-03, Loss_r: 2.550e-02, Time: 0.09
# constant_ics_val: 1.005
# constant_bcs_val: 0.990
# ...
# constant_res_val: 0.994
# It: 35200, Loss: 7.622e-03, loss_ics: 2.139e-04, loss_bcs: 2.741e-04, Loss_r: 7.134e-03, Time: 0.12
# constant_ics_val: 0.998
# constant_bcs_val: 1.002
# constant_res_val: 0.999
# It: 35300, Loss: 7.503e-03, loss_ics: 2.124e-04, loss_bcs: 2.724e-04, Loss_r: 7.018e-03, Time: 0.10
# constant_ics_val: 1.003
# constant_bcs_val: 1.002
# constant_res_val: 0.995
# It: 35400, Loss: 7.462e-03, loss_ics: 2.115e-04, loss_bcs: 2.712e-04, Loss_r: 6.979e-03, Time: 0.10
# constant_ics_val: 1.000
# constant_bcs_val: 1.001
# constant_res_val: 0.999
# It: 35500, Loss: 8.283e-03, loss_ics: 2.101e-04, loss_bcs: 2.721e-04, Loss_r: 7.801e-03, Time: 0.10
# constant_ics_val: 0.976
# constant_bcs_val: 0.973
# constant_res_val: 1.052
# It: 35600, Loss: 7.527e-03, loss_ics: 2.143e-04, loss_bcs: 2.689e-04, Loss_r: 7.044e-03, Time: 0.12
# constant_ics_val: 1.014
# constant_bcs_val: 1.008
# constant_res_val: 0.978
# It: 35700, Loss: 7.925e-03, loss_ics: 2.074e-04, loss_bcs: 2.664e-04, Loss_r: 7.451e-03, Time: 0.09
# constant_ics_val: 0.983
# constant_bcs_val: 0.998
# constant_res_val: 1.019
# It: 35800, Loss: 9.333e-03, loss_ics: 2.717e-04, loss_bcs: 2.658e-04, Loss_r: 8.795e-03, Time: 0.11
# constant_ics_val: 1.023
# constant_bcs_val: 0.976
# constant_res_val: 1.001
# It: 35900, Loss: 7.388e-03, loss_ics: 2.053e-04, loss_bcs: 2.663e-04, Loss_r: 6.916e-03, Time: 0.14
# constant_ics_val: 0.955
# constant_bcs_val: 1.081
# constant_res_val: 0.964
# It: 36000, Loss: 7.308e-03, loss_ics: 2.041e-04, loss_bcs: 2.648e-04, Loss_r: 6.839e-03, Time: 0.10
# constant_ics_val: 0.990
# constant_bcs_val: 1.021
# constant_res_val: 0.989
# It: 36100, Loss: 7.289e-03, loss_ics: 2.034e-04, loss_bcs: 2.637e-04, Loss_r: 6.822e-03, Time: 0.16
# constant_ics_val: 0.996
# constant_bcs_val: 1.005
# constant_res_val: 0.998
# It: 36200, Loss: 8.472e-03, loss_ics: 2.467e-04, loss_bcs: 2.620e-04, Loss_r: 7.963e-03, Time: 0.17
# constant_ics_val: 1.014
# constant_bcs_val: 0.963
# constant_res_val: 1.023
# It: 36300, Loss: 7.236e-03, loss_ics: 2.006e-04, loss_bcs: 2.617e-04, Loss_r: 6.774e-03, Time: 0.11
# constant_ics_val: 0.962
# constant_bcs_val: 1.054
# constant_res_val: 0.983
# It: 36400, Loss: 7.215e-03, loss_ics: 1.997e-04, loss_bcs: 2.605e-04, Loss_r: 6.755e-03, Time: 0.08
# constant_ics_val: 0.990
# constant_bcs_val: 1.014
# constant_res_val: 0.996
# It: 36500, Loss: 7.243e-03, loss_ics: 2.014e-04, loss_bcs: 2.596e-04, Loss_r: 6.782e-03, Time: 0.11
# constant_ics_val: 0.996
# constant_bcs_val: 1.003
# constant_res_val: 1.001
# It: 36600, Loss: 7.197e-03, loss_ics: 1.975e-04, loss_bcs: 2.590e-04, Loss_r: 6.741e-03, Time: 0.17
# constant_ics_val: 0.994
# constant_bcs_val: 1.004
# constant_res_val: 1.002
# It: 36700, Loss: 7.501e-03, loss_ics: 2.103e-04, loss_bcs: 2.573e-04, Loss_r: 7.034e-03, Time: 0.07
# constant_ics_val: 1.010
# constant_bcs_val: 0.974
# constant_res_val: 1.016
# It: 36800, Loss: 7.140e-03, loss_ics: 1.954e-04, loss_bcs: 2.565e-04, Loss_r: 6.688e-03, Time: 0.10
# constant_ics_val: 0.985
# constant_bcs_val: 1.015
# constant_res_val: 0.999
# It: 36900, Loss: 7.093e-03, loss_ics: 1.942e-04, loss_bcs: 2.557e-04, Loss_r: 6.643e-03, Time: 0.08
# constant_ics_val: 0.996
# constant_bcs_val: 1.005
# constant_res_val: 0.999
# It: 37000, Loss: 7.071e-03, loss_ics: 1.933e-04, loss_bcs: 2.548e-04, Loss_r: 6.623e-03, Time: 0.14
# constant_ics_val: 1.000
# constant_bcs_val: 0.999
# constant_res_val: 1.000
# It: 37100, Loss: 7.058e-03, loss_ics: 1.922e-04, loss_bcs: 2.540e-04, Loss_r: 6.612e-03, Time: 0.13
# constant_ics_val: 0.999
# constant_bcs_val: 1.000
# constant_res_val: 1.001
# It: 37200, Loss: 7.026e-03, loss_ics: 1.912e-04, loss_bcs: 2.528e-04, Loss_r: 6.582e-03, Time: 0.14
# constant_ics_val: 1.000
# constant_bcs_val: 1.000
# constant_res_val: 1.000
# It: 37300, Loss: 7.025e-03, loss_ics: 1.905e-04, loss_bcs: 2.516e-04, Loss_r: 6.583e-03, Time: 0.09
# constant_ics_val: 0.999
# constant_bcs_val: 1.000
# constant_res_val: 1.001
# It: 37400, Loss: 6.981e-03, loss_ics: 1.893e-04, loss_bcs: 2.509e-04, Loss_r: 6.541e-03, Time: 0.13
# constant_ics_val: 0.999
# constant_bcs_val: 1.002
# constant_res_val: 1.000
# It: 37500, Loss: 7.063e-03, loss_ics: 1.890e-04, loss_bcs: 2.500e-04, Loss_r: 6.624e-03, Time: 0.14
# constant_ics_val: 0.994
# constant_bcs_val: 0.994
# constant_res_val: 1.012
# It: 37600, Loss: 6.950e-03, loss_ics: 1.873e-04, loss_bcs: 2.494e-04, Loss_r: 6.514e-03, Time: 0.14
# constant_ics_val: 0.999
# constant_bcs_val: 1.002
# constant_res_val: 0.998
# It: 37700, Loss: 6.915e-03, loss_ics: 1.863e-04, loss_bcs: 2.482e-04, Loss_r: 6.481e-03, Time: 0.14
# constant_ics_val: 1.000
# constant_bcs_val: 1.001
# constant_res_val: 0.999
# It: 37800, Loss: 7.012e-03, loss_ics: 1.875e-04, loss_bcs: 2.475e-04, Loss_r: 6.577e-03, Time: 0.12
# constant_ics_val: 1.006
# constant_bcs_val: 0.993
# constant_res_val: 1.001
# It: 37900, Loss: 7.833e-03, loss_ics: 2.201e-04, loss_bcs: 2.459e-04, Loss_r: 7.367e-03, Time: 0.07
# constant_ics_val: 1.020
# constant_bcs_val: 0.962
# constant_res_val: 1.018
# It: 38000, Loss: 7.137e-03, loss_ics: 1.834e-04, loss_bcs: 2.466e-04, Loss_r: 6.707e-03, Time: 0.16
# constant_ics_val: 0.952
# constant_bcs_val: 1.023
# constant_res_val: 1.026
# It: 38100, Loss: 6.871e-03, loss_ics: 1.843e-04, loss_bcs: 2.445e-04, Loss_r: 6.442e-03, Time: 0.08
# constant_ics_val: 0.996
# constant_bcs_val: 1.009
# constant_res_val: 0.995
# It: 38200, Loss: 6.807e-03, loss_ics: 1.816e-04, loss_bcs: 2.438e-04, Loss_r: 6.382e-03, Time: 0.12
# constant_ics_val: 0.996
# constant_bcs_val: 1.006
# constant_res_val: 0.999
# It: 38300, Loss: 6.843e-03, loss_ics: 1.804e-04, loss_bcs: 2.432e-04, Loss_r: 6.420e-03, Time: 0.16
# constant_ics_val: 0.999
# constant_bcs_val: 1.000
# constant_res_val: 1.001
# It: 38400, Loss: 6.766e-03, loss_ics: 1.797e-04, loss_bcs: 2.420e-04, Loss_r: 6.344e-03, Time: 0.11
# constant_ics_val: 1.002
# constant_bcs_val: 1.001
# constant_res_val: 0.997
# It: 38500, Loss: 6.758e-03, loss_ics: 1.798e-04, loss_bcs: 2.411e-04, Loss_r: 6.337e-03, Time: 0.12
# constant_ics_val: 0.999
# constant_bcs_val: 1.000
# constant_res_val: 1.000
# It: 38600, Loss: 7.500e-03, loss_ics: 1.777e-04, loss_bcs: 2.385e-04, Loss_r: 7.083e-03, Time: 0.06
# constant_ics_val: 0.961
# constant_bcs_val: 0.969
# constant_res_val: 1.069
# It: 38700, Loss: 6.703e-03, loss_ics: 1.771e-04, loss_bcs: 2.395e-04, Loss_r: 6.286e-03, Time: 0.10
# constant_ics_val: 1.009
# constant_bcs_val: 1.015
# constant_res_val: 0.977
# It: 38800, Loss: 6.713e-03, loss_ics: 1.762e-04, loss_bcs: 2.383e-04, Loss_r: 6.298e-03, Time: 0.17
# constant_ics_val: 1.001
# constant_bcs_val: 1.004
# constant_res_val: 0.995
# It: 38900, Loss: 6.662e-03, loss_ics: 1.755e-04, loss_bcs: 2.378e-04, Loss_r: 6.249e-03, Time: 0.07
# constant_ics_val: 1.000
# constant_bcs_val: 1.002
# constant_res_val: 0.997
# It: 39000, Loss: 6.646e-03, loss_ics: 1.749e-04, loss_bcs: 2.369e-04, Loss_r: 6.234e-03, Time: 0.09
# constant_ics_val: 0.999
# constant_bcs_val: 1.001
# constant_res_val: 1.000
# It: 39100, Loss: 6.622e-03, loss_ics: 1.737e-04, loss_bcs: 2.362e-04, Loss_r: 6.212e-03, Time: 0.09
# constant_ics_val: 0.999
# constant_bcs_val: 1.001
# constant_res_val: 1.000
# It: 39200, Loss: 6.608e-03, loss_ics: 1.732e-04, loss_bcs: 2.354e-04, Loss_r: 6.200e-03, Time: 0.09
# constant_ics_val: 0.997
# constant_bcs_val: 0.999
# constant_res_val: 1.004
# It: 39300, Loss: 6.583e-03, loss_ics: 1.720e-04, loss_bcs: 2.345e-04, Loss_r: 6.177e-03, Time: 0.09
# constant_ics_val: 0.998
# constant_bcs_val: 1.000
# constant_res_val: 1.001
# It: 39400, Loss: 6.563e-03, loss_ics: 1.712e-04, loss_bcs: 2.338e-04, Loss_r: 6.158e-03, Time: 0.14
# constant_ics_val: 0.999
# constant_bcs_val: 1.000
# constant_res_val: 1.001
# It: 39500, Loss: 6.565e-03, loss_ics: 1.704e-04, loss_bcs: 2.332e-04, Loss_r: 6.161e-03, Time: 0.12
# constant_ics_val: 1.001
# constant_bcs_val: 0.998
# constant_res_val: 1.001
# It: 39600, Loss: 6.524e-03, loss_ics: 1.695e-04, loss_bcs: 2.322e-04, Loss_r: 6.122e-03, Time: 0.11
# constant_ics_val: 1.001
# constant_bcs_val: 1.000
# constant_res_val: 0.999
# It: 39700, Loss: 6.517e-03, loss_ics: 1.687e-04, loss_bcs: 2.315e-04, Loss_r: 6.117e-03, Time: 0.15
# constant_ics_val: 1.000
# constant_bcs_val: 1.000
# constant_res_val: 1.000
# It: 39800, Loss: 6.488e-03, loss_ics: 1.680e-04, loss_bcs: 2.305e-04, Loss_r: 6.090e-03, Time: 0.13
# constant_ics_val: 1.000
# constant_bcs_val: 1.000
# constant_res_val: 1.000
# It: 39900, Loss: 6.466e-03, loss_ics: 1.673e-04, loss_bcs: 2.298e-04, Loss_r: 6.069e-03, Time: 0.16
# constant_ics_val: 1.000
# constant_bcs_val: 1.001
# constant_res_val: 1.000
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 6.733e-03, loss_ics: 1.739e-04, loss_bcs: 2.292e-04, Loss_r: 6.330e-03, Time: 2.16
# constant_ics_val: 1.012
# constant_bcs_val: 0.985
# constant_res_val: 1.003
# average adaptive_constant_bcs_log : 9.3667e-01
# average adaptive_constant_ics_log : 9.7345e-01
# average adaptive_constant_res_log : 1.0899e+00
# Relative L2 error_u: 3.27e-02
# Relative L2 error_f: 9.84e-04
# Save uv NN parameters successfully in %s ...checkpoints/Dec-18-2023_02-42-12-298637_relobralo
# Final loss total loss: 6.652338e-03
# Final loss loss_res: 6.248474e-03
# Final loss loss_bcs: 2.288866e-04
# Final loss loss_ics: 1.749785e-04
# average of time_list: 5151.033104419708
# average of error_u_list: 0.03272558663893216
# average of error_f_list: 0.000983663607456621

# %%
average of time_list: 493.56567120552063
average of error_u_list: 0.16921026076112308
average of error_f_list: 0.0032112047062549773
# Out:
#   File "/tmp/ipykernel_11722/1474304749.py", line 1
#     average of time_list: 493.56567120552063
#              ^
# SyntaxError: invalid syntax

# %%
def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
    from mpl_toolkits.axes_grid1 import ImageGrid

    ### Plot ###
    print(x1.shape)
    print(x2.shape)

    # Exact solution & Predicted solution
    # Exact soluton
    U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')
    print(u_star.shape)

    # Predicted solution
    U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
    F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

    titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $f(x)$' , 'Predicted $f(x)$' , 'Absolute error']
    data = [U_star , U_pred ,  np.abs(U_star - U_pred) , F_star , F_pred ,  np.abs(F_star - F_pred) ]
    
    print(U_star.shape)

    fig_1 = plt.figure(1, figsize=(13, 5))
    grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                    label_mode="1", axes_pad=1.7, share_all=False, 
                    cbar_mode="each", cbar_location="right", 
                    cbar_size="5%", cbar_pad=0.0)
# CREATE ARGUMENTS DICT FOR CONTOURPLOTS
    minmax_list = []
    kwargs_list = []
    for d in data:
        # if(local):
        #     minmax_list.append([np.min(d), np.max(d)])
        # else:
        minmax_list.append([np.min(d), np.max(d)])

        kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60),
            cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

    for ax, z, kwargs, minmax, title in zip(grid, data, kwargs_list, minmax_list, titles):
    #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
        #pcfsets.append(pcf)
        # if (timeStp == 0):
            #  print( z[timeStp,:,:])
        pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
        print(z.shape)
        cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
        ax.cax.tick_params(labelsize=14.5)
        ax.set_title(title, fontsize=14.5, pad=7)
        ax.set_ylabel("time", labelpad=14.5, fontsize=14.5, rotation="horizontal")
        ax.set_xlabel("x", fontsize=14.5)
        ax.tick_params(labelsize=14.5)
        ax.set_xlim(x1.min(), x1.max())
        ax.set_ylim(x2.min(), x2.max())
        ax.set_aspect("equal")

    fig_1.set_size_inches(15, 10, True)
    fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
    plt.tight_layout()
    plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
    plt.close("all" , )

# %%
plt_prediction(model, t , x , X_star , u_star , u_pred , f_star , f_pred)
# Out:
# (100, 100)
# (100, 100)
# (10000, 1)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)

# %%
X_star.shape
# Out:
# (10000, 2)

# %%
# Test data
nn = 100
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

# Exact solution
u_star = u(X_star)
f_star = f(X_star, alpha, beta, gamma, k)

# Predictions
u_pred = mode.predict_u(X_star)
f_pred = mode.predict_r(X_star)

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
print('Relative L2 error_u: {:.2e}'.format(error_u))

### Plot ###

# Test data
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (t, x), method='cubic')

U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (t, x), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact u(x)')

plt.subplot(1, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(x)')

plt.subplot(1, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()


fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(t, x, F_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact u(x)')

plt.subplot(1, 3, 2)
plt.pcolor(t, x, F_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(x)')

plt.subplot(1, 3, 3)
plt.pcolor(t, x, np.abs(F_star - F_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %%
# Loss
loss_r = mode.loss_r_log
loss_u = mode.loss_u_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_r, label='$\mathcal{L}_{r}$')
ax.plot(loss_u, label='$\mathcal{L}_{u}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Adaptive Constant
adaptive_constant_ics = mode.adaptive_constant_ics_log
adaptive_constant_bcs = mode.adaptive_constant_bcs_log

fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant_ics, label='$\lambda_{u_0}$')
ax.plot(adaptive_constant_bcs, label='$\lambda_{u_b}$')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Gradients at the end of training
data_gradients_ics = mode.dict_gradients_ics_layers
data_gradients_bcs = mode.dict_gradients_bcs_layers
data_gradients_res = mode.dict_gradients_res_layers

num_hidden_layers = len(layers) - 1
cnt = 1
fig_4 = plt.figure(4, figsize=(13, 8))
for j in range(num_hidden_layers):
    ax = plt.subplot(2, 3, cnt)
    gradients_ics = data_gradients_ics['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]

    sns.distplot(gradients_ics, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_0}\mathcal{L}_{u_0}$')
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')

    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    ax.set_xlim([-1, 1])
    ax.set_ylim([0, 500])
    ax.get_legend().remove()
    cnt += 1
handles, labels = ax.get_legend_handles_labels()
fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.3, 0.01),
                borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=3)
plt.tight_layout()
plt.show()

# %%
# Eigenvalues of Hessian of losses if applicable
if stiff_ratio:
    eigenvalues_list = mode.eigenvalue_log
    eigenvalues_ics_list = mode.eigenvalue_ics_log
    eigenvalues_bcs_list = mode.eigenvalue_bcs_log
    eigenvalues_res_list = mode.eigenvalue_res_log

    eigenvalues_ics = eigenvalues_ics_list[-1]
    eigenvalues_bcs = eigenvalues_bcs_list[-1]
    eigenvalues_res = eigenvalues_res_list[-1]

    fig_5 = plt.figure(5)
    ax = fig_5.add_subplot(1, 1, 1)
    ax.plot(eigenvalues_ics, label='$\mathcal{L}_{u_0}$')
    ax.plot(eigenvalues_bcs, label='$\mathcal{L}_{u_b}$')
    ax.plot(eigenvalues_res, label='$\mathcal{L}_r$')
    ax.set_xlabel('index')
    ax.set_ylabel('eigenvalue')
    ax.set_yscale('symlog')
    plt.legend()
    plt.tight_layout()
    plt.show()
