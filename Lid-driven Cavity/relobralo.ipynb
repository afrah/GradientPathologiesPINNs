# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import pandas as pd
# from NS_model_tf import Sampler, Navier_Stokes2D
import os
os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import scipy
import scipy.io
import time

import sys

import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle
def U_gamma_1(x):
    num = x.shape[0]
    return np.tile(np.array([1.0, 0.0]), (num, 1))


def U_gamma_2(x):
    num = x.shape[0]
    return np.zeros((num, 2))


def f(x):
    num = x.shape[0]
    return np.zeros((num, 2))

def operator(psi, p, x, y, Re, sigma_x=1.0, sigma_y=1.0):
    u = tf.gradients(psi, y)[0] / sigma_y
    v = - tf.gradients(psi, x)[0] / sigma_x

    u_x = tf.gradients(u, x)[0] / sigma_x
    u_y = tf.gradients(u, y)[0] / sigma_y

    v_x = tf.gradients(v, x)[0] / sigma_x
    v_y = tf.gradients(v, y)[0] / sigma_y

    p_x = tf.gradients(p, x)[0] / sigma_x
    p_y = tf.gradients(p, y)[0] / sigma_y

    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    u_yy = tf.gradients(u_y, y)[0] / sigma_y

    v_xx = tf.gradients(v_x, x)[0] / sigma_x
    v_yy = tf.gradients(v_y, y)[0] / sigma_y

    Ru_momentum = u * u_x + v * u_y + p_x - (u_xx + u_yy) / Re
    Rv_momentum = u * v_x + v * v_y + p_y - (v_xx + v_yy) / Re

    return Ru_momentum, Rv_momentum

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Navier_Stokes2D:
    def __init__(self, layers, operator, bcs_sampler, res_sampler, Re, mode , sess):


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]
        self.mu_y, self.sigma_y = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler


        # Navier Stokes constant
        self.Re = tf.constant(Re, dtype=tf.float32)

        # Adaptive re-weighting constant
        self.rate = 0.9
        self.rho = 0.9
        self.T = 0.9

        self.adaptive_constant_bcs_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)

        # Define Tensorflow session
        self.sess = sess

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)


        # Define placeholders and computational graph
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc1_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc2_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc3_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.U_bc4_tf = tf.placeholder(tf.float32, shape=(None, 2))

        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.y_r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.adaptive_constant_bcs_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)

        # Evaluate predictions
        self.u_bc1_pred, self.v_bc1_pred = self.net_uv(self.x_bc1_tf, self.y_bc1_tf)
        self.u_bc2_pred, self.v_bc2_pred = self.net_uv(self.x_bc2_tf, self.y_bc2_tf)
        self.u_bc3_pred, self.v_bc3_pred = self.net_uv(self.x_bc3_tf, self.y_bc3_tf)
        self.u_bc4_pred, self.v_bc4_pred = self.net_uv(self.x_bc4_tf, self.y_bc4_tf)

        self.U_bc1_pred = tf.concat([self.u_bc1_pred, self.v_bc1_pred], axis=1)
        self.U_bc2_pred = tf.concat([self.u_bc2_pred, self.v_bc2_pred], axis=1)
        self.U_bc3_pred = tf.concat([self.u_bc3_pred, self.v_bc3_pred], axis=1)
        self.U_bc4_pred = tf.concat([self.u_bc4_pred, self.v_bc4_pred], axis=1)

        self.psi_pred, self.p_pred = self.net_psi_p(self.x_u_tf, self.y_u_tf)
        self.u_pred, self.v_pred = self.net_uv(self.x_u_tf, self.y_u_tf)
        self.u_momentum_pred, self.v_momentum_pred = self.net_r(self.x_r_tf, self.y_r_tf)

        # Residual loss
        self.loss_u_momentum = tf.reduce_mean(tf.square(self.u_momentum_pred))
        self.loss_v_momentum = tf.reduce_mean(tf.square(self.v_momentum_pred))

        self.loss_res = self.loss_u_momentum + self.loss_v_momentum
        
        # Boundary loss
        self.loss_bc1 = tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.U_bc2_pred))
        self.loss_bc3 = tf.reduce_mean(tf.square(self.U_bc3_pred))
        self.loss_bc4 = tf.reduce_mean(tf.square(self.U_bc4_pred))
        
        self.loss_bcs =  tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf) +tf.square(self.U_bc2_pred) + tf.square(self.U_bc3_pred) + tf.square(self.U_bc4_pred))
        
        # Total loss
        self.loss = self.adaptive_constant_res_tf * self.loss_res +  self.adaptive_constant_bcs_tf * tf.reduce_mean(tf.square(self.U_bc1_pred - self.U_bc1_tf) + tf.square(self.U_bc2_pred) + tf.square(self.U_bc3_pred) + tf.square(self.U_bc4_pred))

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step, 1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_tensor_list = [self.loss ,  self.loss_res ,  self.loss_bcs,  self.loss_bc1 , self.loss_bc2 , self.loss_bc3, self.loss_bc4] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs" , "loss_bc1", "loss_bc2", "loss_bc3", "loss_bc4"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
       
        # self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_bcs = []
        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])

        self.adpative_constant_bcs_list = []
        self.adpative_constant_res_list = []
        
        self.adpative_constant_bcs_log = []
        self.adpative_constant_res_log = []

        self.mean_constant_bcs_log = []
        self.mean_constant_res_log = []

        for i in range(len(self.layers) - 1):
            self.adpative_constant_res_list.append( tf.reduce_mean(tf.abs(self.grad_res[i])))
            self.adpative_constant_bcs_list.append(  tf.reduce_mean(tf.abs(self.grad_bcs[i])))

        self.mean_constant_bcs = tf.reduce_mean(tf.stack(self.adpative_constant_bcs_list))
        self.mean_constant_res =  tf.reduce_mean(tf.stack(self.adpative_constant_res_list))

        self.prev_lam_bcs = 1
        self.prev_lam_res = 1
        self.index =1

        self.mean_grad_res_log  = []
        self.mean_grad_bcs_log  = []
        self.mean_grad_ics_log  = []
    

        init = tf.global_variables_initializer()
        self.sess.run(init)
        

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev, dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H


    # Forward pass for stream-pressure formulation
    def net_psi_p(self, x, y):
        psi_p = self.forward_pass(tf.concat([x, y], 1))
        psi = psi_p[:, 0:1]
        p = psi_p[:, 1:2]
        return psi, p

    # Forward pass for velocities
    def net_uv(self, x, y):
        psi, p = self.net_psi_p(x, y)
        u = tf.gradients(psi, y)[0] / self.sigma_y
        v = - tf.gradients(psi, x)[0] / self.sigma_x
        return u, v

    # Forward pass for residual
    def net_r(self, x, y):
        psi, p = self.net_psi_p(x, y)
        u_momentum_pred, v_momentum_pred = self.operator(psi, p, x, y,  self.Re,  self.sigma_x, self.sigma_y)

        return u_momentum_pred, v_momentum_pred

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
    def train(self, nIter ,  bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        batch_size = bcbatch_size
        X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
        X_bc3_batch, _ = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
        X_bc4_batch, _ = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

        # Fetch residual mini-batch
        batch_size = ubatch_size

        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                    self.U_bc1_tf: u_bc1_batch,
                    self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                    self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                    self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                    self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val
                    }
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)

                # Compute the adaptive constant
                adaptive_constant_bcs_val = self.sess.run(self.adaptive_constant_bcs, tf_dict)

                self.adaptive_constant_bcs_val = adaptive_constant_bcs_val *  (1.0 - self.beta) + self.beta * self.adaptive_constant_bcs_val

                # self.adpative_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                # self.loss_bcs_log.append(loss_u_value)
                # self.loss_res_log.append(loss_r_value)

                print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' % (it, loss_value, loss_u_value, loss_r_value, elapsed))

                print("constant_bcs_val: {:.3f}".format(self.adaptive_constant_bcs_val))
                start_time = timeit.default_timer()

            sys.stdout.flush()
            start_time = timeit.default_timer()

            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
            # # Store gradients
            # if it % 10000 == 0:
            #     self.save_gradients(tf_dict)
            #     print("Gradients information stored ...")



######################################################################################################################################
                

    def lambda_balance(self ,term , index):
        loss_list = ["loss_res" , "loss_bcs" ] 
        m= len(loss_list)
        num = np.exp(self.loss_history[term][-1] /(self.T * self.loss_history[term][index]))
        denum = 0 

        for  key in loss_list:
            denum +=  np.exp(self.loss_history[key][-1] /(self.T * self.loss_history[key][index]))
        return m * (num / denum)
     
    def relobralo( self, term ,prev_lamda ):

        lambda_hist = self.rho  * prev_lamda + (1.0 - self.rho) *  self.lambda_balance( term , 1)
        lambda_i = self.rate  * lambda_hist + (1.0 - self.rate) *  self.lambda_balance( term , self.index)

        return lambda_i
    

   # Trains the model by minimizing the MSE loss
    def trainmb(self, nIter, batch_size):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range( 1, nIter):
            # Fetch boundary mini-batches
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, _ = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, _ = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                       self.U_bc1_tf: u_bc1_batch,
                       self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                       self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                       self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                       self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                       self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs_val,
                       self.adaptive_constant_res_tf: self.adaptive_constant_res_val
                       }

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_r_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)
                self.print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_r: %.3e, Time: %.2f' % (it, loss_value, loss_u_value, loss_r_value, elapsed))

            if it % 100 == 0:

                # Compute the adaptive constant
                # adaptive_constant_bcs_val = self.sess.run(self.adaptive_constant_bcs, tf_dict)

                self.adaptive_constant_bcs_val = self.relobralo( "loss_bcs"  ,self.prev_lam_bcs)  
                self.adaptive_constant_res_val = self.relobralo( "loss_res"  ,self.prev_lam_res )  

                self.adpative_constant_bcs_log.append(self.adaptive_constant_bcs_val)
                self.adpative_constant_res_log.append(self.adaptive_constant_res_val)

                self.mean_grad_bcs_log.append(self.mean_constant_bcs)
                self.mean_grad_res_log.append(self.mean_constant_res)


                self.print("adaptive_constant_bcs_val: {:.3f}".format(self.adaptive_constant_bcs_val))
                self.print("adaptive_constant_res_val: {:.3f}".format(self.adaptive_constant_res_val))


                mean_constant_bcs , mean_constant_res = self.sess.run([self.mean_constant_bcs ,self.mean_constant_res], tf_dict)

                self.mean_constant_bcs_log.append(mean_constant_bcs)
                self.mean_constant_res_log.append(mean_constant_res)
            
                self.prev_lam_bcs = self.adaptive_constant_bcs_val
                self.prev_lam_res = self.adaptive_constant_res_val
                self.index =it
  
            sys.stdout.flush()

            start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

 

    # Evaluates predictions at test points
    def predict_psi_p(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2]}
        psi_star = self.sess.run(self.psi_pred, tf_dict)
        p_star = self.sess.run(self.p_pred, tf_dict)
        return psi_star, p_star

    def predict_uv(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        v_star = self.sess.run(self.v_pred, tf_dict)
        return u_star, v_star



 ############################################################

    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values

    def plot_loss_history(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.show()
    ############################################################
  
  # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1    = self.sess.run([ self.grad_res[i],self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=3)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('relobralo.ipynb', os.path.join(dirname, 'relobralo.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        loss_list = ["total loss" , "loss_res"  , "loss_bc1", "loss_bc2", "loss_bc3", "loss_bc4"] 

        for key in loss_list:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        plt.close("all" , )
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
        from mpl_toolkits.axes_grid1 import ImageGrid

        ### Plot ###

        # Exact solution & Predicted solution
        # Exact soluton
        U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
        F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

        # Predicted solution
        U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
        F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

        titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $v(x)$' , 'Predicted $v(x)$' , 'Absolute error']
        data = [U_star.T , U_pred ,  np.abs(U_star.T - U_pred) , F_star.T , F_pred ,  np.abs(F_star.T - F_pred) ]

        fig_1 = plt.figure(1, figsize=(13, 5))
        grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                        label_mode="1", axes_pad=1.7, share_all=False, 
                        cbar_mode="each", cbar_location="right", 
                        cbar_size="5%", cbar_pad=0.0)
    # CREATE ARGUMENTS DICT FOR CONTOURPLOTS
        minmax_list = []
        for d in data:
            # if(local):
            #     minmax_list.append([np.min(d), np.max(d)])
            # else:
            minmax_list.append([np.min(d), np.max(d)])

            # kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60), cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

        for ax, z, minmax, title in zip(grid, data, minmax_list, titles):
        #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
            #pcfsets.append(pcf)
            # if (timeStp == 0):
            pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
            cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
            ax.cax.tick_params(labelsize=14.5)
            ax.set_title(title, fontsize=14.5, pad=7)
            ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
            ax.set_xlabel("x", fontsize=14.5)
            ax.tick_params(labelsize=14.5)
            ax.set_xlim(x1.min(), x1.max())
            ax.set_ylim(x2.min(), x2.max())
            ax.set_aspect("equal")

        fig_1.set_size_inches(15, 10, True)
        fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
        plt.close("all" , )


    def plot_lambda(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adpative_constant_bcs_log, label=r'$\lambda_{bc}$')
        ax.semilogy(self.adpative_constant_res_log, label=r'$\lambda_{res}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\lambda$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'lambda_history.png')
        plt.savefig(path)
        plt.close("all" , )



    def plot_grad(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.mean_constant_bcs_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc}}}$')
        ax.semilogy(self.mean_constant_res_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{res}}}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\bar{\nabla_\theta \mathcal{L}}$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)
        plt.close("all" , )

# %%
#        [elapsed, error_u , error_v ,  error_p] = test_method(mtd , layers, operator, bcs_sampler, res_sampler ,Re , stiff_ratio ,  X_star , X , Y)

def test_method(method , layers, operator, bcs_sampler, res_sampler, Re ,  mode , X_star , X , Y , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):


    model = Navier_Stokes2D(layers, operator, bcs_sampler, res_sampler, Re, mode)

    # Train model
    start_time = time.time()

    if method =="full_batch":
        model.train(nIter  , bcbatch_size , ubatch_size  )
    elif method =="mini_batch":
        model.trainmb(nIter, mbbatch_size)
    else:
        print("unknown method!")
    elapsed = time.time() - start_time

    # Predictions
    _, p_pred = model.predict_psi_p(X_star)
    u_pred, v_pred = model.predict_uv(X_star)

    # psi_star = griddata(X_star, psi_pred.flatten(), (X, Y), method='cubic')
    p_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
    # u_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
    # v_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')

    # velocity = np.sqrt(u_pred**2 + v_pred**2)
    # velocity_star = griddata(X_star, velocity.flatten(), (X, Y), method='cubic')

    # Reference
    u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
    v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
    # velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

    u_pred = u_pred.reshape(100,100)
    v_pred = v_pred.reshape(100,100)
    p_pred = p_pred.reshape(100,100)

    # Relative error
    error_u = np.linalg.norm(u_ref - u_pred.T, 2) / np.linalg.norm(u_ref, 2)
    print('l2 error: {:.2e}'.format(error_u))
    error_v = np.linalg.norm(v_ref - v_pred.T, 2) / np.linalg.norm(v_ref, 2)
    print('l2 error: {:.2e}'.format(error_v))
    error_p = np.linalg.norm(p_pred - p_star.T, 2) / np.linalg.norm(p_star, 2)
    print('l2 error: {:.2e}'.format(error_p))

    return [elapsed, error_u , error_v ,error_p ]

# %%
nIter =40001
bcbatch_size = 350
ubatch_size = 5000
mbbatch_size = 128

# Parameters of equations
Re = 100.0

# Domain boundaries
bc1_coords = np.array([[0.0, 1.0], [1.0, 1.0]])
bc2_coords = np.array([[0.0, 0.0], [0.0, 1.0]])
bc3_coords = np.array([[1.0, 0.0], [1.0, 1.0]])
bc4_coords = np.array([[0.0, 0.0], [1.0, 0.0]])
dom_coords = np.array([[0.0, 0.0], [1.0, 1.0]])

# Define model
model = 'relobralo'
layers = [2, 50, 50, 50, 50 , 50 , 2]

stiff_ratio = False  # Log the eigenvalues of Hessian of losses


# Test Data
nx = 100
ny = 100  # change to 100
x = np.linspace(0.0, 1.0, nx)
y = np.linspace(0.0, 1.0, ny)
X, Y = np.meshgrid(x, y)


X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))


iterations = 1
methods = ["mini_batch" ]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_v_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create boundary conditions samplers
        bc1 = Sampler(2, bc1_coords, lambda x: U_gamma_1(x), name='Dirichlet BC1')
        bc2 = Sampler(2, bc2_coords, lambda x: U_gamma_2(x), name='Dirichlet BC2')
        bc3 = Sampler(2, bc3_coords, lambda x: U_gamma_2(x), name='Dirichlet BC3')
        bc4 = Sampler(2, bc4_coords, lambda x: U_gamma_2(x), name='Dirichlet BC4')
        bcs_sampler = [bc1, bc2, bc3, bc4]

        # Create residual sampler
        res_sampler = Sampler(2, dom_coords, lambda x: f(x), name='Forcing')

        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:

            mode = Navier_Stokes2D(layers, operator, bcs_sampler, res_sampler, Re, model , sess)

            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                mode.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                mode.trainmb(nIter, mbbatch_size)
            else:
                mode.print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            _, p_pred = mode.predict_psi_p(X_star)
            u_pred, v_pred = mode.predict_uv(X_star)

            # Reference
            u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
            v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
            # velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

            u_pred = u_pred.reshape(100,100)
            v_pred = v_pred.reshape(100,100)

            # Relative error
            error_u = np.linalg.norm(u_ref - u_pred.T, 2) / np.linalg.norm(u_ref, 2)
            error_v = np.linalg.norm(v_ref - v_pred.T, 2) / np.linalg.norm(v_ref, 2)

            mode.print('l2 error: {:.2e}'.format(error_u))
            mode.print('l2 error: {:.2e}'.format(error_v))

       
            mode.print("average adpative_constant_bcs_log: " , np.average(mode.adpative_constant_bcs_log))
            mode.print("average adpative_constant_res_log: " , np.average(mode.adpative_constant_res_log))
            # sess.close
            mode.plot_lambda()

            mode.plot_grad()
            mode.save_NN()
            mode.plt_prediction( X , Y , X_star , u_ref , u_pred , v_ref , v_pred)


        mode.print('elapsed: {:.2e}'.format(elapsed))
        mode.print('Relative L2 error_u: {:.2e}'.format(error_u))
        mode.print('Relative L2 error_v: {:.2e}'.format(error_v))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_v_list.append(error_v)

    mode.print("\n\nMethod: ", mtd)
    mode.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    mode.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    mode.print("average of error_v_list:" , sum(error_v_list) / len(error_v_list) )

    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(mode.dirname,""+mtd+"_Lid-driven-Cavity_"+model+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_6573/2026186351.py:59: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6573/2026186351.py:60: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6573/2026186351.py:61: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6573/2026186351.py:61: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-17 13:34:11.202373: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-17 13:34:11.235449: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-17 13:34:11.235949: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563b86f59150 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-17 13:34:11.235967: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-17 13:34:11.236929: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_6573/4263428409.py:172: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6573/4263428409.py:55: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6573/4263428409.py:115: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6573/4263428409.py:117: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6573/4263428409.py:163: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 9.330e-02, Loss_u: 8.512e-02, Loss_r: 8.173e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 4.626e-02, Loss_u: 4.028e-02, Loss_r: 6.132e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.991
# adaptive_constant_res_val: 1.009
# It: 300, Loss: 3.205e-02, Loss_u: 2.624e-02, Loss_r: 6.009e-03, Time: 0.03
# adaptive_constant_bcs_val: 1.000
# adaptive_constant_res_val: 1.000
# It: 400, Loss: 3.623e-02, Loss_u: 2.965e-02, Loss_r: 6.571e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.985
# adaptive_constant_res_val: 1.015
# It: 500, Loss: 3.145e-02, Loss_u: 2.884e-02, Loss_r: 3.002e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 600, Loss: 2.735e-02, Loss_u: 2.342e-02, Loss_r: 3.884e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.988
# adaptive_constant_res_val: 1.012
# It: 700, Loss: 2.602e-02, Loss_u: 2.252e-02, Loss_r: 3.729e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.023
# adaptive_constant_res_val: 0.977
# It: 800, Loss: 3.382e-02, Loss_u: 2.684e-02, Loss_r: 6.511e-03, Time: 0.03
# adaptive_constant_bcs_val: 1.033
# adaptive_constant_res_val: 0.967
# It: 900, Loss: 3.786e-02, Loss_u: 3.374e-02, Loss_r: 3.113e-03, Time: 0.03
# adaptive_constant_bcs_val: 1.057
# adaptive_constant_res_val: 0.943
# It: 1000, Loss: 3.768e-02, Loss_u: 3.270e-02, Loss_r: 3.318e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.033
# adaptive_constant_res_val: 0.967
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 2.903e-02, Loss_u: 2.539e-02, Loss_r: 2.906e-03, Time: 0.03
# adaptive_constant_bcs_val: 1.017
# adaptive_constant_res_val: 0.983
# It: 1200, Loss: 2.799e-02, Loss_u: 2.556e-02, Loss_r: 2.030e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.991
# adaptive_constant_res_val: 1.009
# It: 1300, Loss: 3.344e-02, Loss_u: 3.094e-02, Loss_r: 2.767e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.969
# adaptive_constant_res_val: 1.031
# It: 1400, Loss: 3.142e-02, Loss_u: 2.925e-02, Loss_r: 2.973e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.931
# adaptive_constant_res_val: 1.069
# It: 1500, Loss: 2.424e-02, Loss_u: 2.408e-02, Loss_r: 1.701e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.951
# adaptive_constant_res_val: 1.049
# It: 1600, Loss: 2.436e-02, Loss_u: 2.364e-02, Loss_r: 1.786e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.943
# adaptive_constant_res_val: 1.057
# It: 1700, Loss: 3.209e-02, Loss_u: 3.220e-02, Loss_r: 1.619e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.959
# adaptive_constant_res_val: 1.041
# It: 1800, Loss: 2.331e-02, Loss_u: 2.133e-02, Loss_r: 2.728e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.948
# adaptive_constant_res_val: 1.052
# It: 1900, Loss: 2.921e-02, Loss_u: 2.675e-02, Loss_r: 3.660e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.940
# adaptive_constant_res_val: 1.060
# It: 2000, Loss: 3.232e-02, Loss_u: 3.171e-02, Loss_r: 2.367e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.952
# adaptive_constant_res_val: 1.048
# It: 2100, Loss: 2.560e-02, Loss_u: 2.364e-02, Loss_r: 2.960e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.946
# adaptive_constant_res_val: 1.054
# It: 2200, Loss: 2.404e-02, Loss_u: 2.132e-02, Loss_r: 3.679e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.948
# adaptive_constant_res_val: 1.052
# It: 2300, Loss: 3.002e-02, Loss_u: 2.905e-02, Loss_r: 2.356e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 2400, Loss: 2.671e-02, Loss_u: 2.426e-02, Loss_r: 2.534e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.021
# adaptive_constant_res_val: 0.979
# It: 2500, Loss: 3.545e-02, Loss_u: 3.104e-02, Loss_r: 3.825e-03, Time: 0.05
# adaptive_constant_bcs_val: 1.009
# adaptive_constant_res_val: 0.991
# It: 2600, Loss: 2.806e-02, Loss_u: 2.509e-02, Loss_r: 2.757e-03, Time: 0.09
# adaptive_constant_bcs_val: 1.029
# adaptive_constant_res_val: 0.971
# It: 2700, Loss: 2.965e-02, Loss_u: 2.471e-02, Loss_r: 4.339e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.024
# adaptive_constant_res_val: 0.976
# It: 2800, Loss: 3.746e-02, Loss_u: 3.451e-02, Loss_r: 2.186e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.070
# adaptive_constant_res_val: 0.930
# It: 2900, Loss: 3.251e-02, Loss_u: 2.763e-02, Loss_r: 3.159e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.037
# adaptive_constant_res_val: 0.963
# It: 3000, Loss: 3.043e-02, Loss_u: 2.507e-02, Loss_r: 4.590e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.011
# adaptive_constant_res_val: 0.989
# It: 3100, Loss: 2.059e-02, Loss_u: 1.758e-02, Loss_r: 2.836e-03, Time: 0.03
# adaptive_constant_bcs_val: 1.022
# adaptive_constant_res_val: 0.978
# It: 3200, Loss: 2.511e-02, Loss_u: 2.086e-02, Loss_r: 3.876e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.018
# adaptive_constant_res_val: 0.982
# It: 3300, Loss: 1.838e-02, Loss_u: 1.263e-02, Loss_r: 5.622e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.976
# adaptive_constant_res_val: 1.024
# It: 3400, Loss: 3.198e-02, Loss_u: 2.880e-02, Loss_r: 3.787e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.009
# adaptive_constant_res_val: 0.991
# It: 3500, Loss: 2.729e-02, Loss_u: 2.334e-02, Loss_r: 3.764e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.928
# adaptive_constant_res_val: 1.072
# It: 3600, Loss: 2.638e-02, Loss_u: 2.383e-02, Loss_r: 3.981e-03, Time: 0.12
# adaptive_constant_bcs_val: 0.907
# adaptive_constant_res_val: 1.093
# It: 3700, Loss: 2.566e-02, Loss_u: 2.592e-02, Loss_r: 1.972e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.938
# adaptive_constant_res_val: 1.062
# It: 3800, Loss: 2.922e-02, Loss_u: 2.766e-02, Loss_r: 3.085e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.969
# adaptive_constant_res_val: 1.031
# It: 3900, Loss: 2.187e-02, Loss_u: 1.990e-02, Loss_r: 2.518e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.014
# adaptive_constant_res_val: 0.986
# It: 4000, Loss: 2.383e-02, Loss_u: 1.956e-02, Loss_r: 4.057e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.938
# adaptive_constant_res_val: 1.062
# It: 4100, Loss: 2.059e-02, Loss_u: 1.756e-02, Loss_r: 3.879e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.957
# adaptive_constant_res_val: 1.043
# It: 4200, Loss: 2.559e-02, Loss_u: 2.430e-02, Loss_r: 2.224e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.952
# adaptive_constant_res_val: 1.048
# It: 4300, Loss: 2.368e-02, Loss_u: 2.132e-02, Loss_r: 3.225e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.941
# adaptive_constant_res_val: 1.059
# It: 4400, Loss: 2.082e-02, Loss_u: 1.952e-02, Loss_r: 2.307e-03, Time: 0.07
# adaptive_constant_bcs_val: 0.973
# adaptive_constant_res_val: 1.027
# It: 4500, Loss: 3.262e-02, Loss_u: 2.945e-02, Loss_r: 3.869e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.978
# adaptive_constant_res_val: 1.022
# It: 4600, Loss: 2.323e-02, Loss_u: 2.087e-02, Loss_r: 2.759e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.995
# adaptive_constant_res_val: 1.005
# It: 4700, Loss: 2.110e-02, Loss_u: 1.834e-02, Loss_r: 2.843e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.995
# adaptive_constant_res_val: 1.005
# It: 4800, Loss: 2.633e-02, Loss_u: 2.117e-02, Loss_r: 5.227e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.897
# adaptive_constant_res_val: 1.103
# It: 4900, Loss: 2.749e-02, Loss_u: 2.817e-02, Loss_r: 2.004e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.946
# adaptive_constant_res_val: 1.054
# It: 5000, Loss: 1.944e-02, Loss_u: 1.725e-02, Loss_r: 2.962e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.912
# adaptive_constant_res_val: 1.088
# It: 5100, Loss: 2.630e-02, Loss_u: 2.597e-02, Loss_r: 2.405e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.946
# adaptive_constant_res_val: 1.054
# It: 5200, Loss: 2.358e-02, Loss_u: 2.207e-02, Loss_r: 2.572e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.912
# adaptive_constant_res_val: 1.088
# It: 5300, Loss: 2.276e-02, Loss_u: 2.125e-02, Loss_r: 3.117e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.899
# adaptive_constant_res_val: 1.101
# It: 5400, Loss: 2.477e-02, Loss_u: 2.436e-02, Loss_r: 2.605e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.933
# adaptive_constant_res_val: 1.067
# It: 5500, Loss: 2.513e-02, Loss_u: 2.413e-02, Loss_r: 2.455e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.956
# adaptive_constant_res_val: 1.044
# It: 5600, Loss: 1.818e-02, Loss_u: 1.713e-02, Loss_r: 1.722e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.933
# adaptive_constant_res_val: 1.067
# It: 5700, Loss: 1.933e-02, Loss_u: 1.751e-02, Loss_r: 2.811e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.849
# adaptive_constant_res_val: 1.151
# It: 5800, Loss: 1.826e-02, Loss_u: 1.731e-02, Loss_r: 3.097e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.837
# adaptive_constant_res_val: 1.163
# It: 5900, Loss: 1.681e-02, Loss_u: 1.624e-02, Loss_r: 2.763e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.823
# adaptive_constant_res_val: 1.177
# It: 6000, Loss: 1.491e-02, Loss_u: 1.603e-02, Loss_r: 1.459e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.872
# adaptive_constant_res_val: 1.128
# It: 6100, Loss: 1.230e-02, Loss_u: 1.254e-02, Loss_r: 1.203e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.884
# adaptive_constant_res_val: 1.116
# It: 6200, Loss: 1.669e-02, Loss_u: 1.685e-02, Loss_r: 1.602e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.901
# adaptive_constant_res_val: 1.099
# It: 6300, Loss: 2.170e-02, Loss_u: 1.916e-02, Loss_r: 4.044e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.902
# adaptive_constant_res_val: 1.098
# It: 6400, Loss: 1.668e-02, Loss_u: 1.481e-02, Loss_r: 3.025e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.915
# adaptive_constant_res_val: 1.085
# It: 6500, Loss: 1.893e-02, Loss_u: 1.817e-02, Loss_r: 2.129e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.938
# adaptive_constant_res_val: 1.062
# It: 6600, Loss: 1.759e-02, Loss_u: 1.579e-02, Loss_r: 2.614e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.910
# adaptive_constant_res_val: 1.090
# It: 6700, Loss: 1.916e-02, Loss_u: 1.632e-02, Loss_r: 3.945e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.936
# adaptive_constant_res_val: 1.064
# It: 6800, Loss: 1.986e-02, Loss_u: 1.859e-02, Loss_r: 2.309e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.951
# adaptive_constant_res_val: 1.049
# It: 6900, Loss: 1.983e-02, Loss_u: 1.833e-02, Loss_r: 2.286e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.961
# adaptive_constant_res_val: 1.039
# It: 7000, Loss: 1.692e-02, Loss_u: 1.568e-02, Loss_r: 1.783e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.994
# adaptive_constant_res_val: 1.006
# It: 7100, Loss: 1.986e-02, Loss_u: 1.803e-02, Loss_r: 1.921e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.986
# adaptive_constant_res_val: 1.014
# It: 7200, Loss: 2.065e-02, Loss_u: 1.857e-02, Loss_r: 2.311e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.978
# adaptive_constant_res_val: 1.022
# It: 7300, Loss: 2.215e-02, Loss_u: 2.019e-02, Loss_r: 2.357e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.943
# adaptive_constant_res_val: 1.057
# It: 7400, Loss: 1.509e-02, Loss_u: 1.346e-02, Loss_r: 2.274e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.958
# adaptive_constant_res_val: 1.042
# It: 7500, Loss: 1.637e-02, Loss_u: 1.564e-02, Loss_r: 1.332e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.966
# adaptive_constant_res_val: 1.034
# It: 7600, Loss: 2.015e-02, Loss_u: 1.858e-02, Loss_r: 2.129e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.937
# adaptive_constant_res_val: 1.063
# It: 7700, Loss: 1.807e-02, Loss_u: 1.710e-02, Loss_r: 1.922e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.943
# adaptive_constant_res_val: 1.057
# It: 7800, Loss: 2.153e-02, Loss_u: 1.984e-02, Loss_r: 2.667e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.939
# adaptive_constant_res_val: 1.061
# It: 7900, Loss: 1.581e-02, Loss_u: 1.472e-02, Loss_r: 1.873e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.936
# adaptive_constant_res_val: 1.064
# It: 8000, Loss: 2.138e-02, Loss_u: 1.827e-02, Loss_r: 4.024e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.936
# adaptive_constant_res_val: 1.064
# It: 8100, Loss: 2.185e-02, Loss_u: 1.940e-02, Loss_r: 3.458e-03, Time: 0.07
# adaptive_constant_bcs_val: 0.953
# adaptive_constant_res_val: 1.047
# It: 8200, Loss: 2.114e-02, Loss_u: 2.037e-02, Loss_r: 1.636e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.993
# adaptive_constant_res_val: 1.007
# It: 8300, Loss: 1.725e-02, Loss_u: 1.560e-02, Loss_r: 1.748e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.015
# adaptive_constant_res_val: 0.985
# It: 8400, Loss: 2.729e-02, Loss_u: 1.820e-02, Loss_r: 8.946e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.054
# adaptive_constant_res_val: 0.946
# It: 8500, Loss: 1.134e-02, Loss_u: 8.318e-03, Loss_r: 2.714e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.048
# adaptive_constant_res_val: 0.952
# It: 8600, Loss: 1.659e-02, Loss_u: 1.377e-02, Loss_r: 2.265e-03, Time: 0.04
# adaptive_constant_bcs_val: 1.001
# adaptive_constant_res_val: 0.999
# It: 8700, Loss: 1.816e-02, Loss_u: 1.558e-02, Loss_r: 2.564e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 8800, Loss: 2.016e-02, Loss_u: 1.855e-02, Loss_r: 1.868e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 8900, Loss: 1.934e-02, Loss_u: 1.674e-02, Loss_r: 2.642e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.940
# adaptive_constant_res_val: 1.060
# It: 9000, Loss: 2.174e-02, Loss_u: 1.996e-02, Loss_r: 2.808e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.920
# adaptive_constant_res_val: 1.080
# It: 9100, Loss: 2.303e-02, Loss_u: 2.311e-02, Loss_r: 1.622e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.935
# adaptive_constant_res_val: 1.065
# It: 9200, Loss: 1.577e-02, Loss_u: 1.439e-02, Loss_r: 2.174e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.961
# adaptive_constant_res_val: 1.039
# It: 9300, Loss: 1.880e-02, Loss_u: 1.706e-02, Loss_r: 2.318e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.983
# adaptive_constant_res_val: 1.017
# It: 9400, Loss: 1.687e-02, Loss_u: 1.530e-02, Loss_r: 1.801e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.986
# adaptive_constant_res_val: 1.014
# It: 9500, Loss: 1.575e-02, Loss_u: 1.158e-02, Loss_r: 4.269e-03, Time: 0.03
# adaptive_constant_bcs_val: 1.014
# adaptive_constant_res_val: 0.986
# It: 9600, Loss: 1.442e-02, Loss_u: 1.198e-02, Loss_r: 2.305e-03, Time: 0.03
# adaptive_constant_bcs_val: 1.003
# adaptive_constant_res_val: 0.997
# It: 9700, Loss: 1.411e-02, Loss_u: 1.215e-02, Loss_r: 1.928e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.897
# adaptive_constant_res_val: 1.103
# It: 9800, Loss: 1.763e-02, Loss_u: 1.758e-02, Loss_r: 1.690e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.937
# adaptive_constant_res_val: 1.063
# It: 9900, Loss: 1.145e-02, Loss_u: 1.042e-02, Loss_r: 1.585e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.936
# adaptive_constant_res_val: 1.064
# It: 10000, Loss: 1.506e-02, Loss_u: 1.397e-02, Loss_r: 1.872e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.975
# adaptive_constant_res_val: 1.025
# It: 10100, Loss: 1.677e-02, Loss_u: 1.523e-02, Loss_r: 1.873e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.884
# adaptive_constant_res_val: 1.116
# It: 10200, Loss: 1.444e-02, Loss_u: 1.485e-02, Loss_r: 1.182e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.911
# adaptive_constant_res_val: 1.089
# It: 10300, Loss: 1.515e-02, Loss_u: 1.493e-02, Loss_r: 1.415e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.881
# adaptive_constant_res_val: 1.119
# It: 10400, Loss: 1.444e-02, Loss_u: 1.492e-02, Loss_r: 1.158e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.939
# adaptive_constant_res_val: 1.061
# It: 10500, Loss: 1.885e-02, Loss_u: 1.795e-02, Loss_r: 1.880e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.866
# adaptive_constant_res_val: 1.134
# It: 10600, Loss: 1.611e-02, Loss_u: 1.493e-02, Loss_r: 2.801e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.886
# adaptive_constant_res_val: 1.114
# It: 10700, Loss: 1.418e-02, Loss_u: 1.211e-02, Loss_r: 3.100e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.872
# adaptive_constant_res_val: 1.128
# It: 10800, Loss: 1.042e-02, Loss_u: 1.074e-02, Loss_r: 9.361e-04, Time: 0.03
# adaptive_constant_bcs_val: 0.926
# adaptive_constant_res_val: 1.074
# It: 10900, Loss: 1.642e-02, Loss_u: 1.399e-02, Loss_r: 3.231e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.941
# adaptive_constant_res_val: 1.059
# It: 11000, Loss: 1.588e-02, Loss_u: 1.537e-02, Loss_r: 1.343e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 11100, Loss: 1.533e-02, Loss_u: 9.889e-03, Loss_r: 5.448e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.898
# adaptive_constant_res_val: 1.102
# It: 11200, Loss: 1.372e-02, Loss_u: 1.345e-02, Loss_r: 1.490e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.947
# adaptive_constant_res_val: 1.053
# It: 11300, Loss: 1.372e-02, Loss_u: 1.190e-02, Loss_r: 2.325e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.920
# adaptive_constant_res_val: 1.080
# It: 11400, Loss: 1.752e-02, Loss_u: 1.639e-02, Loss_r: 2.256e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.962
# adaptive_constant_res_val: 1.038
# It: 11500, Loss: 1.038e-02, Loss_u: 8.332e-03, Loss_r: 2.279e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.945
# adaptive_constant_res_val: 1.055
# It: 11600, Loss: 1.288e-02, Loss_u: 9.894e-03, Loss_r: 3.341e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.868
# adaptive_constant_res_val: 1.132
# It: 11700, Loss: 1.290e-02, Loss_u: 1.258e-02, Loss_r: 1.741e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.890
# adaptive_constant_res_val: 1.110
# It: 11800, Loss: 1.932e-02, Loss_u: 1.696e-02, Loss_r: 3.797e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.885
# adaptive_constant_res_val: 1.115
# It: 11900, Loss: 1.211e-02, Loss_u: 1.166e-02, Loss_r: 1.612e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.940
# adaptive_constant_res_val: 1.060
# It: 12000, Loss: 1.129e-02, Loss_u: 1.032e-02, Loss_r: 1.502e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.947
# adaptive_constant_res_val: 1.053
# It: 12100, Loss: 1.680e-02, Loss_u: 1.473e-02, Loss_r: 2.707e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.947
# adaptive_constant_res_val: 1.053
# It: 12200, Loss: 1.033e-02, Loss_u: 9.776e-03, Loss_r: 1.022e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.947
# adaptive_constant_res_val: 1.053
# It: 12300, Loss: 1.428e-02, Loss_u: 1.191e-02, Loss_r: 2.847e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.883
# adaptive_constant_res_val: 1.117
# It: 12400, Loss: 1.496e-02, Loss_u: 1.526e-02, Loss_r: 1.336e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.930
# adaptive_constant_res_val: 1.070
# It: 12500, Loss: 1.949e-02, Loss_u: 1.797e-02, Loss_r: 2.600e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.921
# adaptive_constant_res_val: 1.079
# It: 12600, Loss: 1.230e-02, Loss_u: 1.211e-02, Loss_r: 1.060e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.960
# adaptive_constant_res_val: 1.040
# It: 12700, Loss: 1.031e-02, Loss_u: 8.911e-03, Loss_r: 1.688e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.962
# adaptive_constant_res_val: 1.038
# It: 12800, Loss: 1.280e-02, Loss_u: 1.068e-02, Loss_r: 2.439e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.919
# adaptive_constant_res_val: 1.081
# It: 12900, Loss: 1.535e-02, Loss_u: 1.404e-02, Loss_r: 2.255e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.914
# adaptive_constant_res_val: 1.086
# It: 13000, Loss: 1.628e-02, Loss_u: 1.420e-02, Loss_r: 3.042e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.834
# adaptive_constant_res_val: 1.166
# It: 13100, Loss: 1.111e-02, Loss_u: 1.150e-02, Loss_r: 1.303e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.844
# adaptive_constant_res_val: 1.156
# It: 13200, Loss: 7.736e-03, Loss_u: 8.620e-03, Loss_r: 3.964e-04, Time: 0.03
# adaptive_constant_bcs_val: 0.881
# adaptive_constant_res_val: 1.119
# It: 13300, Loss: 1.408e-02, Loss_u: 1.398e-02, Loss_r: 1.572e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.886
# adaptive_constant_res_val: 1.114
# It: 13400, Loss: 1.124e-02, Loss_u: 1.157e-02, Loss_r: 8.824e-04, Time: 0.04
# adaptive_constant_bcs_val: 0.953
# adaptive_constant_res_val: 1.047
# It: 13500, Loss: 1.130e-02, Loss_u: 1.031e-02, Loss_r: 1.413e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.908
# adaptive_constant_res_val: 1.092
# It: 13600, Loss: 1.137e-02, Loss_u: 1.078e-02, Loss_r: 1.447e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.913
# adaptive_constant_res_val: 1.087
# It: 13700, Loss: 1.808e-02, Loss_u: 1.449e-02, Loss_r: 4.460e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.820
# adaptive_constant_res_val: 1.180
# It: 13800, Loss: 1.414e-02, Loss_u: 1.402e-02, Loss_r: 2.237e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.863
# adaptive_constant_res_val: 1.137
# It: 13900, Loss: 1.033e-02, Loss_u: 1.093e-02, Loss_r: 7.949e-04, Time: 0.04
# adaptive_constant_bcs_val: 0.921
# adaptive_constant_res_val: 1.079
# It: 14000, Loss: 1.553e-02, Loss_u: 1.066e-02, Loss_r: 5.292e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.906
# adaptive_constant_res_val: 1.094
# It: 14100, Loss: 1.283e-02, Loss_u: 1.234e-02, Loss_r: 1.508e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.948
# adaptive_constant_res_val: 1.052
# It: 14200, Loss: 1.362e-02, Loss_u: 1.321e-02, Loss_r: 1.041e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.926
# adaptive_constant_res_val: 1.074
# It: 14300, Loss: 1.501e-02, Loss_u: 1.526e-02, Loss_r: 8.134e-04, Time: 0.03
# adaptive_constant_bcs_val: 0.954
# adaptive_constant_res_val: 1.046
# It: 14400, Loss: 1.396e-02, Loss_u: 1.306e-02, Loss_r: 1.432e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.905
# adaptive_constant_res_val: 1.095
# It: 14500, Loss: 1.362e-02, Loss_u: 1.383e-02, Loss_r: 9.987e-04, Time: 0.03
# adaptive_constant_bcs_val: 0.940
# adaptive_constant_res_val: 1.060
# It: 14600, Loss: 1.195e-02, Loss_u: 1.127e-02, Loss_r: 1.282e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.938
# adaptive_constant_res_val: 1.062
# It: 14700, Loss: 1.711e-02, Loss_u: 1.542e-02, Loss_r: 2.493e-03, Time: 0.03
# adaptive_constant_bcs_val: 0.988
# adaptive_constant_res_val: 1.012
# It: 14800, Loss: 1.136e-02, Loss_u: 9.951e-03, Loss_r: 1.513e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.995
# adaptive_constant_res_val: 1.005
# It: 14900, Loss: 1.544e-02, Loss_u: 1.352e-02, Loss_r: 1.972e-03, Time: 0.05
# adaptive_constant_bcs_val: 1.019
# adaptive_constant_res_val: 0.981
# It: 15000, Loss: 1.655e-02, Loss_u: 1.489e-02, Loss_r: 1.410e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.980
# adaptive_constant_res_val: 1.020
# It: 15100, Loss: 7.269e-03, Loss_u: 6.100e-03, Loss_r: 1.264e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.983
# adaptive_constant_res_val: 1.017
# It: 15200, Loss: 9.102e-03, Loss_u: 8.281e-03, Loss_r: 9.458e-04, Time: 0.05
# adaptive_constant_bcs_val: 0.988
# adaptive_constant_res_val: 1.012
# It: 15300, Loss: 1.312e-02, Loss_u: 1.028e-02, Loss_r: 2.928e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 15400, Loss: 8.311e-03, Loss_u: 7.509e-03, Loss_r: 8.317e-04, Time: 0.04
# adaptive_constant_bcs_val: 1.020
# adaptive_constant_res_val: 0.980
# It: 15500, Loss: 1.010e-02, Loss_u: 8.058e-03, Loss_r: 1.918e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.977
# adaptive_constant_res_val: 1.023
# It: 15600, Loss: 1.386e-02, Loss_u: 1.200e-02, Loss_r: 2.087e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 15700, Loss: 1.064e-02, Loss_u: 9.770e-03, Loss_r: 1.011e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.974
# adaptive_constant_res_val: 1.026
# It: 15800, Loss: 7.068e-03, Loss_u: 5.929e-03, Loss_r: 1.261e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.963
# adaptive_constant_res_val: 1.037
# It: 15900, Loss: 1.378e-02, Loss_u: 1.272e-02, Loss_r: 1.479e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.994
# adaptive_constant_res_val: 1.006
# It: 16000, Loss: 1.376e-02, Loss_u: 1.161e-02, Loss_r: 2.201e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.975
# adaptive_constant_res_val: 1.025
# It: 16100, Loss: 1.579e-02, Loss_u: 1.471e-02, Loss_r: 1.410e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 16200, Loss: 1.711e-02, Loss_u: 1.204e-02, Loss_r: 5.079e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.907
# adaptive_constant_res_val: 1.093
# It: 16300, Loss: 2.074e-02, Loss_u: 1.562e-02, Loss_r: 6.005e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.882
# adaptive_constant_res_val: 1.118
# It: 16400, Loss: 1.005e-02, Loss_u: 1.030e-02, Loss_r: 8.641e-04, Time: 0.05
# adaptive_constant_bcs_val: 0.932
# adaptive_constant_res_val: 1.068
# It: 16500, Loss: 1.290e-02, Loss_u: 1.217e-02, Loss_r: 1.456e-03, Time: 0.04
# adaptive_constant_bcs_val: 0.922
# adaptive_constant_res_val: 1.078
# It: 16600, Loss: 9.199e-03, Loss_u: 7.349e-03, Loss_r: 2.250e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.924
# adaptive_constant_res_val: 1.076
# It: 16700, Loss: 9.971e-03, Loss_u: 9.211e-03, Loss_r: 1.353e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.928
# adaptive_constant_res_val: 1.072
# It: 16800, Loss: 1.600e-02, Loss_u: 1.396e-02, Loss_r: 2.840e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.883
# adaptive_constant_res_val: 1.117
# It: 16900, Loss: 1.273e-02, Loss_u: 1.196e-02, Loss_r: 1.948e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.873
# adaptive_constant_res_val: 1.127
# It: 17000, Loss: 9.035e-03, Loss_u: 9.043e-03, Loss_r: 1.010e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.877
# adaptive_constant_res_val: 1.123
# It: 17100, Loss: 1.068e-02, Loss_u: 1.026e-02, Loss_r: 1.494e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.937
# adaptive_constant_res_val: 1.063
# It: 17200, Loss: 1.347e-02, Loss_u: 1.326e-02, Loss_r: 9.860e-04, Time: 0.08
# adaptive_constant_bcs_val: 1.015
# adaptive_constant_res_val: 0.985
# It: 17300, Loss: 1.308e-02, Loss_u: 1.142e-02, Loss_r: 1.504e-03, Time: 0.12
# adaptive_constant_bcs_val: 0.987
# adaptive_constant_res_val: 1.013
# It: 17400, Loss: 1.363e-02, Loss_u: 9.334e-03, Loss_r: 4.359e-03, Time: 0.14
# adaptive_constant_bcs_val: 0.939
# adaptive_constant_res_val: 1.061
# It: 17500, Loss: 1.335e-02, Loss_u: 1.287e-02, Loss_r: 1.183e-03, Time: 0.14
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 17600, Loss: 9.290e-03, Loss_u: 7.105e-03, Loss_r: 2.164e-03, Time: 0.06
# adaptive_constant_bcs_val: 1.011
# adaptive_constant_res_val: 0.989
# It: 17700, Loss: 1.073e-02, Loss_u: 9.513e-03, Loss_r: 1.126e-03, Time: 0.07
# adaptive_constant_bcs_val: 1.019
# adaptive_constant_res_val: 0.981
# It: 17800, Loss: 1.076e-02, Loss_u: 8.611e-03, Loss_r: 2.027e-03, Time: 0.06
# adaptive_constant_bcs_val: 1.011
# adaptive_constant_res_val: 0.989
# It: 17900, Loss: 1.151e-02, Loss_u: 9.208e-03, Loss_r: 2.220e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.999
# adaptive_constant_res_val: 1.001
# It: 18000, Loss: 1.372e-02, Loss_u: 1.134e-02, Loss_r: 2.382e-03, Time: 0.05
# adaptive_constant_bcs_val: 1.015
# adaptive_constant_res_val: 0.985
# It: 18100, Loss: 1.145e-02, Loss_u: 9.526e-03, Loss_r: 1.806e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.977
# adaptive_constant_res_val: 1.023
# It: 18200, Loss: 1.029e-02, Loss_u: 9.365e-03, Loss_r: 1.118e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.942
# adaptive_constant_res_val: 1.058
# It: 18300, Loss: 1.203e-02, Loss_u: 1.136e-02, Loss_r: 1.258e-03, Time: 0.06
# adaptive_constant_bcs_val: 0.969
# adaptive_constant_res_val: 1.031
# It: 18400, Loss: 1.183e-02, Loss_u: 1.038e-02, Loss_r: 1.720e-03, Time: 0.05
# adaptive_constant_bcs_val: 0.941
# adaptive_constant_res_val: 1.059
# It: 18500, Loss: 1.530e-02, Loss_u: 1.411e-02, Loss_r: 1.907e-03, Time: 0.18
# adaptive_constant_bcs_val: 0.987
# adaptive_constant_res_val: 1.013
# It: 18600, Loss: 1.760e-02, Loss_u: 1.562e-02, Loss_r: 2.161e-03, Time: 0.19
# adaptive_constant_bcs_val: 0.966
# adaptive_constant_res_val: 1.034
# It: 18700, Loss: 1.365e-02, Loss_u: 8.648e-03, Loss_r: 5.124e-03, Time: 0.15
# adaptive_constant_bcs_val: 0.871
# adaptive_constant_res_val: 1.129
# It: 18800, Loss: 1.359e-02, Loss_u: 1.441e-02, Loss_r: 9.117e-04, Time: 0.16
# adaptive_constant_bcs_val: 0.929
# adaptive_constant_res_val: 1.071
# It: 18900, Loss: 1.377e-02, Loss_u: 1.316e-02, Loss_r: 1.442e-03, Time: 0.19
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 19000, Loss: 1.420e-02, Loss_u: 1.330e-02, Loss_r: 1.093e-03, Time: 0.14
# adaptive_constant_bcs_val: 0.988
# adaptive_constant_res_val: 1.012
# It: 19100, Loss: 1.591e-02, Loss_u: 1.491e-02, Loss_r: 1.158e-03, Time: 0.17
# adaptive_constant_bcs_val: 1.025
# adaptive_constant_res_val: 0.975
# It: 19200, Loss: 2.077e-02, Loss_u: 1.688e-02, Loss_r: 3.561e-03, Time: 0.15
# adaptive_constant_bcs_val: 0.945
# adaptive_constant_res_val: 1.055
# It: 19300, Loss: 1.139e-02, Loss_u: 1.043e-02, Loss_r: 1.464e-03, Time: 0.13
# adaptive_constant_bcs_val: 0.977
# adaptive_constant_res_val: 1.023
# It: 19400, Loss: 1.394e-02, Loss_u: 1.222e-02, Loss_r: 1.948e-03, Time: 0.18
# adaptive_constant_bcs_val: 0.996
# adaptive_constant_res_val: 1.004
# It: 19500, Loss: 1.204e-02, Loss_u: 9.977e-03, Loss_r: 2.098e-03, Time: 0.14
# adaptive_constant_bcs_val: 0.943
# adaptive_constant_res_val: 1.057
# It: 19600, Loss: 1.036e-02, Loss_u: 9.942e-03, Loss_r: 9.342e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.949
# adaptive_constant_res_val: 1.051
# It: 19700, Loss: 1.250e-02, Loss_u: 1.182e-02, Loss_r: 1.212e-03, Time: 0.14
# adaptive_constant_bcs_val: 0.864
# adaptive_constant_res_val: 1.136
# It: 19800, Loss: 1.331e-02, Loss_u: 1.439e-02, Loss_r: 7.689e-04, Time: 0.17
# adaptive_constant_bcs_val: 0.915
# adaptive_constant_res_val: 1.085
# It: 19900, Loss: 1.037e-02, Loss_u: 9.821e-03, Loss_r: 1.275e-03, Time: 0.13
# adaptive_constant_bcs_val: 0.910
# adaptive_constant_res_val: 1.090
# It: 20000, Loss: 1.108e-02, Loss_u: 1.000e-02, Loss_r: 1.813e-03, Time: 0.15
# adaptive_constant_bcs_val: 0.892
# adaptive_constant_res_val: 1.108
# It: 20100, Loss: 1.104e-02, Loss_u: 1.136e-02, Loss_r: 8.182e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.881
# adaptive_constant_res_val: 1.119
# It: 20200, Loss: 1.320e-02, Loss_u: 1.211e-02, Loss_r: 2.265e-03, Time: 0.13
# adaptive_constant_bcs_val: 0.864
# adaptive_constant_res_val: 1.136
# It: 20300, Loss: 9.026e-03, Loss_u: 9.497e-03, Loss_r: 7.217e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.913
# adaptive_constant_res_val: 1.087
# It: 20400, Loss: 1.074e-02, Loss_u: 9.574e-03, Loss_r: 1.837e-03, Time: 0.17
# adaptive_constant_bcs_val: 0.880
# adaptive_constant_res_val: 1.120
# It: 20500, Loss: 1.470e-02, Loss_u: 1.214e-02, Loss_r: 3.583e-03, Time: 0.14
# adaptive_constant_bcs_val: 0.873
# adaptive_constant_res_val: 1.127
# It: 20600, Loss: 1.321e-02, Loss_u: 1.353e-02, Loss_r: 1.243e-03, Time: 0.13
# adaptive_constant_bcs_val: 0.941
# adaptive_constant_res_val: 1.059
# It: 20700, Loss: 1.506e-02, Loss_u: 1.397e-02, Loss_r: 1.812e-03, Time: 0.15
# adaptive_constant_bcs_val: 0.902
# adaptive_constant_res_val: 1.098
# It: 20800, Loss: 1.329e-02, Loss_u: 1.399e-02, Loss_r: 6.107e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.945
# adaptive_constant_res_val: 1.055
# It: 20900, Loss: 8.827e-03, Loss_u: 8.523e-03, Loss_r: 7.293e-04, Time: 0.14
# adaptive_constant_bcs_val: 0.956
# adaptive_constant_res_val: 1.044
# It: 21000, Loss: 1.569e-02, Loss_u: 1.266e-02, Loss_r: 3.436e-03, Time: 0.17
# adaptive_constant_bcs_val: 0.971
# adaptive_constant_res_val: 1.029
# It: 21100, Loss: 1.054e-02, Loss_u: 1.019e-02, Loss_r: 6.327e-04, Time: 0.15
# adaptive_constant_bcs_val: 1.019
# adaptive_constant_res_val: 0.981
# It: 21200, Loss: 1.572e-02, Loss_u: 1.405e-02, Loss_r: 1.427e-03, Time: 0.16
# adaptive_constant_bcs_val: 0.997
# adaptive_constant_res_val: 1.003
# It: 21300, Loss: 1.176e-02, Loss_u: 1.100e-02, Loss_r: 8.009e-04, Time: 0.17
# adaptive_constant_bcs_val: 1.023
# adaptive_constant_res_val: 0.977
# It: 21400, Loss: 1.557e-02, Loss_u: 1.164e-02, Loss_r: 3.756e-03, Time: 0.15
# adaptive_constant_bcs_val: 0.916
# adaptive_constant_res_val: 1.084
# It: 21500, Loss: 1.104e-02, Loss_u: 1.105e-02, Loss_r: 8.469e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.957
# adaptive_constant_res_val: 1.043
# It: 21600, Loss: 1.353e-02, Loss_u: 1.289e-02, Loss_r: 1.145e-03, Time: 0.37
# adaptive_constant_bcs_val: 0.917
# adaptive_constant_res_val: 1.083
# It: 21700, Loss: 1.268e-02, Loss_u: 1.178e-02, Loss_r: 1.738e-03, Time: 0.14
# adaptive_constant_bcs_val: 0.894
# adaptive_constant_res_val: 1.106
# It: 21800, Loss: 8.638e-03, Loss_u: 8.779e-03, Loss_r: 7.175e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.940
# adaptive_constant_res_val: 1.060
# It: 21900, Loss: 1.038e-02, Loss_u: 9.128e-03, Loss_r: 1.701e-03, Time: 0.17
# adaptive_constant_bcs_val: 0.923
# adaptive_constant_res_val: 1.077
# It: 22000, Loss: 6.900e-03, Loss_u: 6.149e-03, Loss_r: 1.135e-03, Time: 0.15
# adaptive_constant_bcs_val: 0.930
# adaptive_constant_res_val: 1.070
# It: 22100, Loss: 1.964e-02, Loss_u: 1.907e-02, Loss_r: 1.790e-03, Time: 0.16
# adaptive_constant_bcs_val: 1.022
# adaptive_constant_res_val: 0.978
# It: 22200, Loss: 1.177e-02, Loss_u: 1.054e-02, Loss_r: 1.023e-03, Time: 0.15
# ...
# It: 32600, Loss: 8.317e-03, Loss_u: 7.501e-03, Loss_r: 7.663e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.993
# adaptive_constant_res_val: 1.007
# It: 32700, Loss: 9.178e-03, Loss_u: 8.789e-03, Loss_r: 4.463e-04, Time: 0.15
# adaptive_constant_bcs_val: 1.019
# adaptive_constant_res_val: 0.981
# It: 32800, Loss: 1.293e-02, Loss_u: 1.142e-02, Loss_r: 1.310e-03, Time: 0.13
# adaptive_constant_bcs_val: 1.039
# adaptive_constant_res_val: 0.961
# It: 32900, Loss: 1.245e-02, Loss_u: 1.122e-02, Loss_r: 8.293e-04, Time: 0.17
# adaptive_constant_bcs_val: 1.016
# adaptive_constant_res_val: 0.984
# It: 33000, Loss: 1.082e-02, Loss_u: 9.051e-03, Loss_r: 1.645e-03, Time: 0.13
# adaptive_constant_bcs_val: 0.953
# adaptive_constant_res_val: 1.047
# It: 33100, Loss: 8.014e-03, Loss_u: 7.469e-03, Loss_r: 8.532e-04, Time: 0.11
# adaptive_constant_bcs_val: 0.952
# adaptive_constant_res_val: 1.048
# It: 33200, Loss: 1.205e-02, Loss_u: 1.158e-02, Loss_r: 9.753e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.955
# adaptive_constant_res_val: 1.045
# It: 33300, Loss: 1.070e-02, Loss_u: 1.039e-02, Loss_r: 7.385e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.985
# adaptive_constant_res_val: 1.015
# It: 33400, Loss: 8.236e-03, Loss_u: 7.689e-03, Loss_r: 6.536e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.966
# adaptive_constant_res_val: 1.034
# It: 33500, Loss: 1.017e-02, Loss_u: 9.773e-03, Loss_r: 7.051e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.954
# adaptive_constant_res_val: 1.046
# It: 33600, Loss: 7.175e-03, Loss_u: 6.722e-03, Loss_r: 7.260e-04, Time: 0.16
# adaptive_constant_bcs_val: 0.951
# adaptive_constant_res_val: 1.049
# It: 33700, Loss: 6.081e-03, Loss_u: 5.803e-03, Loss_r: 5.336e-04, Time: 0.17
# adaptive_constant_bcs_val: 0.952
# adaptive_constant_res_val: 1.048
# It: 33800, Loss: 9.952e-03, Loss_u: 9.131e-03, Loss_r: 1.204e-03, Time: 0.13
# adaptive_constant_bcs_val: 0.975
# adaptive_constant_res_val: 1.025
# It: 33900, Loss: 1.167e-02, Loss_u: 1.042e-02, Loss_r: 1.474e-03, Time: 0.12
# adaptive_constant_bcs_val: 0.977
# adaptive_constant_res_val: 1.023
# It: 34000, Loss: 1.252e-02, Loss_u: 1.199e-02, Loss_r: 7.841e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.023
# adaptive_constant_res_val: 0.977
# It: 34100, Loss: 5.253e-03, Loss_u: 4.465e-03, Loss_r: 7.006e-04, Time: 0.14
# adaptive_constant_bcs_val: 0.948
# adaptive_constant_res_val: 1.052
# It: 34200, Loss: 8.668e-03, Loss_u: 8.364e-03, Loss_r: 7.048e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.931
# adaptive_constant_res_val: 1.069
# It: 34300, Loss: 1.039e-02, Loss_u: 1.042e-02, Loss_r: 6.408e-04, Time: 0.11
# adaptive_constant_bcs_val: 0.953
# adaptive_constant_res_val: 1.047
# It: 34400, Loss: 1.070e-02, Loss_u: 1.047e-02, Loss_r: 6.979e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.959
# adaptive_constant_res_val: 1.041
# It: 34500, Loss: 9.632e-03, Loss_u: 8.901e-03, Loss_r: 1.052e-03, Time: 0.17
# adaptive_constant_bcs_val: 0.906
# adaptive_constant_res_val: 1.094
# It: 34600, Loss: 8.003e-03, Loss_u: 7.945e-03, Loss_r: 7.345e-04, Time: 0.14
# adaptive_constant_bcs_val: 0.913
# adaptive_constant_res_val: 1.087
# It: 34700, Loss: 1.091e-02, Loss_u: 1.127e-02, Loss_r: 5.673e-04, Time: 0.18
# adaptive_constant_bcs_val: 0.968
# adaptive_constant_res_val: 1.032
# It: 34800, Loss: 1.032e-02, Loss_u: 1.015e-02, Loss_r: 4.842e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.977
# adaptive_constant_res_val: 1.023
# It: 34900, Loss: 1.121e-02, Loss_u: 9.430e-03, Loss_r: 1.948e-03, Time: 0.15
# adaptive_constant_bcs_val: 0.961
# adaptive_constant_res_val: 1.039
# It: 35000, Loss: 8.063e-03, Loss_u: 7.771e-03, Loss_r: 5.758e-04, Time: 0.44
# adaptive_constant_bcs_val: 0.989
# adaptive_constant_res_val: 1.011
# It: 35100, Loss: 1.059e-02, Loss_u: 1.016e-02, Loss_r: 5.356e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.028
# adaptive_constant_res_val: 0.972
# It: 35200, Loss: 8.294e-03, Loss_u: 7.368e-03, Loss_r: 7.433e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.958
# adaptive_constant_res_val: 1.042
# It: 35300, Loss: 8.434e-03, Loss_u: 7.956e-03, Loss_r: 7.798e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.927
# adaptive_constant_res_val: 1.073
# It: 35400, Loss: 5.989e-03, Loss_u: 5.516e-03, Loss_r: 8.156e-04, Time: 0.14
# adaptive_constant_bcs_val: 0.874
# adaptive_constant_res_val: 1.126
# It: 35500, Loss: 8.469e-03, Loss_u: 8.841e-03, Loss_r: 6.581e-04, Time: 0.15
# adaptive_constant_bcs_val: 0.865
# adaptive_constant_res_val: 1.135
# It: 35600, Loss: 1.214e-02, Loss_u: 1.326e-02, Loss_r: 5.981e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.934
# adaptive_constant_res_val: 1.066
# It: 35700, Loss: 1.089e-02, Loss_u: 1.074e-02, Loss_r: 8.163e-04, Time: 0.16
# adaptive_constant_bcs_val: 0.964
# adaptive_constant_res_val: 1.036
# It: 35800, Loss: 1.229e-02, Loss_u: 1.186e-02, Loss_r: 8.201e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.004
# adaptive_constant_res_val: 0.996
# It: 35900, Loss: 1.571e-02, Loss_u: 1.491e-02, Loss_r: 7.395e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.038
# adaptive_constant_res_val: 0.962
# It: 36000, Loss: 1.034e-02, Loss_u: 8.959e-03, Loss_r: 1.082e-03, Time: 0.17
# adaptive_constant_bcs_val: 1.092
# adaptive_constant_res_val: 0.908
# It: 36100, Loss: 8.277e-03, Loss_u: 6.939e-03, Loss_r: 7.713e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.087
# adaptive_constant_res_val: 0.913
# It: 36200, Loss: 1.382e-02, Loss_u: 1.155e-02, Loss_r: 1.379e-03, Time: 0.14
# adaptive_constant_bcs_val: 1.084
# adaptive_constant_res_val: 0.916
# It: 36300, Loss: 1.025e-02, Loss_u: 8.917e-03, Loss_r: 6.403e-04, Time: 0.12
# adaptive_constant_bcs_val: 1.090
# adaptive_constant_res_val: 0.910
# It: 36400, Loss: 1.807e-02, Loss_u: 1.588e-02, Loss_r: 8.413e-04, Time: 0.15
# adaptive_constant_bcs_val: 1.136
# adaptive_constant_res_val: 0.864
# It: 36500, Loss: 1.003e-02, Loss_u: 8.334e-03, Loss_r: 6.573e-04, Time: 0.12
# adaptive_constant_bcs_val: 1.102
# adaptive_constant_res_val: 0.898
# It: 36600, Loss: 1.124e-02, Loss_u: 9.329e-03, Loss_r: 1.065e-03, Time: 0.15
# adaptive_constant_bcs_val: 1.057
# adaptive_constant_res_val: 0.943
# It: 36700, Loss: 1.271e-02, Loss_u: 1.032e-02, Loss_r: 1.909e-03, Time: 0.56
# adaptive_constant_bcs_val: 1.032
# adaptive_constant_res_val: 0.968
# It: 36800, Loss: 6.366e-03, Loss_u: 5.635e-03, Loss_r: 5.705e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.035
# adaptive_constant_res_val: 0.965
# It: 36900, Loss: 9.852e-03, Loss_u: 8.848e-03, Loss_r: 7.207e-04, Time: 0.12
# adaptive_constant_bcs_val: 1.065
# adaptive_constant_res_val: 0.935
# It: 37000, Loss: 9.359e-03, Loss_u: 7.873e-03, Loss_r: 1.039e-03, Time: 0.14
# adaptive_constant_bcs_val: 1.043
# adaptive_constant_res_val: 0.957
# It: 37100, Loss: 1.645e-02, Loss_u: 1.488e-02, Loss_r: 9.769e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.080
# adaptive_constant_res_val: 0.920
# It: 37200, Loss: 1.297e-02, Loss_u: 1.145e-02, Loss_r: 6.567e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.058
# adaptive_constant_res_val: 0.942
# It: 37300, Loss: 1.100e-02, Loss_u: 1.008e-02, Loss_r: 3.609e-04, Time: 0.16
# adaptive_constant_bcs_val: 1.116
# adaptive_constant_res_val: 0.884
# It: 37400, Loss: 1.617e-02, Loss_u: 1.335e-02, Loss_r: 1.448e-03, Time: 0.13
# adaptive_constant_bcs_val: 1.109
# adaptive_constant_res_val: 0.891
# It: 37500, Loss: 1.165e-02, Loss_u: 9.978e-03, Loss_r: 6.639e-04, Time: 0.15
# adaptive_constant_bcs_val: 1.100
# adaptive_constant_res_val: 0.900
# It: 37600, Loss: 1.864e-02, Loss_u: 1.619e-02, Loss_r: 9.282e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.118
# adaptive_constant_res_val: 0.882
# It: 37700, Loss: 7.653e-03, Loss_u: 6.468e-03, Loss_r: 4.800e-04, Time: 0.16
# adaptive_constant_bcs_val: 1.143
# adaptive_constant_res_val: 0.857
# It: 37800, Loss: 9.209e-03, Loss_u: 7.363e-03, Loss_r: 9.257e-04, Time: 0.16
# adaptive_constant_bcs_val: 1.126
# adaptive_constant_res_val: 0.874
# It: 37900, Loss: 1.266e-02, Loss_u: 1.027e-02, Loss_r: 1.259e-03, Time: 0.15
# adaptive_constant_bcs_val: 1.069
# adaptive_constant_res_val: 0.931
# It: 38000, Loss: 1.395e-02, Loss_u: 1.238e-02, Loss_r: 7.622e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.104
# adaptive_constant_res_val: 0.896
# It: 38100, Loss: 1.295e-02, Loss_u: 1.116e-02, Loss_r: 7.107e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.096
# adaptive_constant_res_val: 0.904
# It: 38200, Loss: 7.565e-03, Loss_u: 6.335e-03, Loss_r: 6.906e-04, Time: 0.15
# adaptive_constant_bcs_val: 1.080
# adaptive_constant_res_val: 0.920
# It: 38300, Loss: 8.730e-03, Loss_u: 7.506e-03, Loss_r: 6.808e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.091
# adaptive_constant_res_val: 0.909
# It: 38400, Loss: 1.242e-02, Loss_u: 1.095e-02, Loss_r: 5.201e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.132
# adaptive_constant_res_val: 0.868
# It: 38500, Loss: 1.425e-02, Loss_u: 1.195e-02, Loss_r: 8.277e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.114
# adaptive_constant_res_val: 0.886
# It: 38600, Loss: 7.774e-03, Loss_u: 6.232e-03, Loss_r: 9.389e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.069
# adaptive_constant_res_val: 0.931
# It: 38700, Loss: 9.758e-03, Loss_u: 8.286e-03, Loss_r: 9.641e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.050
# adaptive_constant_res_val: 0.950
# It: 38800, Loss: 1.140e-02, Loss_u: 1.009e-02, Loss_r: 8.528e-04, Time: 0.14
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 38900, Loss: 7.557e-03, Loss_u: 7.093e-03, Loss_r: 5.655e-04, Time: 0.14
# adaptive_constant_bcs_val: 0.984
# adaptive_constant_res_val: 1.016
# It: 39000, Loss: 1.258e-02, Loss_u: 1.211e-02, Loss_r: 6.490e-04, Time: 0.14
# adaptive_constant_bcs_val: 0.993
# adaptive_constant_res_val: 1.007
# It: 39100, Loss: 9.592e-03, Loss_u: 9.106e-03, Loss_r: 5.482e-04, Time: 0.14
# adaptive_constant_bcs_val: 1.040
# adaptive_constant_res_val: 0.960
# It: 39200, Loss: 1.372e-02, Loss_u: 1.245e-02, Loss_r: 8.117e-04, Time: 0.16
# adaptive_constant_bcs_val: 1.023
# adaptive_constant_res_val: 0.977
# It: 39300, Loss: 8.286e-03, Loss_u: 7.472e-03, Loss_r: 6.562e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.020
# adaptive_constant_res_val: 0.980
# It: 39400, Loss: 1.040e-02, Loss_u: 9.560e-03, Loss_r: 6.622e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.006
# adaptive_constant_res_val: 0.994
# It: 39500, Loss: 9.393e-03, Loss_u: 8.626e-03, Loss_r: 7.210e-04, Time: 0.13
# adaptive_constant_bcs_val: 1.002
# adaptive_constant_res_val: 0.998
# It: 39600, Loss: 1.076e-02, Loss_u: 9.657e-03, Loss_r: 1.085e-03, Time: 0.13
# adaptive_constant_bcs_val: 0.965
# adaptive_constant_res_val: 1.035
# It: 39700, Loss: 5.411e-03, Loss_u: 4.819e-03, Loss_r: 7.341e-04, Time: 0.13
# adaptive_constant_bcs_val: 0.959
# adaptive_constant_res_val: 1.041
# It: 39800, Loss: 6.583e-03, Loss_u: 5.927e-03, Loss_r: 8.624e-04, Time: 0.14
# adaptive_constant_bcs_val: 0.979
# adaptive_constant_res_val: 1.021
# It: 39900, Loss: 7.039e-03, Loss_u: 5.815e-03, Loss_r: 1.316e-03, Time: 0.17
# adaptive_constant_bcs_val: 0.951
# adaptive_constant_res_val: 1.049
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 4.842e-03, Loss_u: 4.515e-03, Loss_r: 5.210e-04, Time: 5.99
# adaptive_constant_bcs_val: 0.958
# adaptive_constant_res_val: 1.042
# l2 error: 8.41e-02
# l2 error: 1.83e-01
# average lambda_bc: 9.5887e-01
# average lambda_res: 1.0
# Save uv NN parameters successfully in %s ...checkpoints/Dec-17-2023_13-34-11-237258_relobralo
# Final loss total loss: 4.860038e-03
# Final loss loss_res: 5.048765e-04
# Final loss loss_bc1: 1.491536e-03
# Final loss loss_bc2: 2.583577e-03
# Final loss loss_bc3: 4.587660e-04
# Final loss loss_bc4: 1.819415e-05
# elapsed: 4.46e+03
# Relative L2 error_u: 8.41e-02
# Relative L2 error_v: 1.83e-01
#
#
# Method: mini_batch
#
# average of time_list:4.4637e+03
# average of error_u_list:8.4073e-02
# average of error_v_list:1.8273e-01

# %%
mode.print('elapsed: {:.2e}'.format(elapsed))
mode.print('Relative L2 error_u: {:.2e}'.format(error_u))
mode.print('Relative L2 error_v: {:.2e}'.format(error_v))
# Out:
# elapsed: 1.66e+02
# Relative L2 error_u: 3.04e-01
# Relative L2 error_v: 9.55e-01

# %%
mode.print("average adpative_constant_res_log: " , np.average(mode.adpative_constant_res_log))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13207/447425965.py in <module>
# ----> 1 mode.print("average adpative_constant_res_log: " , np.average(mode.adpative_constant_res_log))
#
# NameError: name 'mode' is not defined

# %%
def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
    from mpl_toolkits.axes_grid1 import ImageGrid

    ### Plot ###

    # Exact solution & Predicted solution
    # Exact soluton
    U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

    # Predicted solution
    U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
    F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

    titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $v(x)$' , 'Predicted $v(x)$' , 'Absolute error']
    data = [U_star.T , U_pred ,  np.abs(U_star.T - U_pred) , F_star.T , F_pred ,  np.abs(F_star.T - F_pred) ]

    fig_1 = plt.figure(1, figsize=(13, 5))
    grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                    label_mode="1", axes_pad=1.7, share_all=False, 
                    cbar_mode="each", cbar_location="right", 
                    cbar_size="5%", cbar_pad=0.0)
# CREATE ARGUMENTS DICT FOR CONTOURPLOTS
    minmax_list = []
    for d in data:
        # if(local):
        #     minmax_list.append([np.min(d), np.max(d)])
        # else:
        minmax_list.append([np.min(d), np.max(d)])

        # kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60), cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

    for ax, z, minmax, title in zip(grid, data, minmax_list, titles):
    #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
        #pcfsets.append(pcf)
        # if (timeStp == 0):
        pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
        cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
        ax.cax.tick_params(labelsize=14.5)
        ax.set_title(title, fontsize=14.5, pad=7)
        ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
        ax.set_xlabel("x", fontsize=14.5)
        ax.tick_params(labelsize=14.5)
        ax.set_xlim(x1.min(), x1.max())
        ax.set_ylim(x2.min(), x2.max())
        ax.set_aspect("equal")

    fig_1.set_size_inches(15, 10, True)
    fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
    plt.tight_layout()
    plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
    plt.close("all" , )

# %%
u_ref.flatten()[:,None].shape
# Out:
# (10000, 1)

# %%
# Out:
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)

# %%
v_pred.shape
# Out:
# (100, 100)

# %%
import scipy.io

mode = 'M2'
mbbatch_size = 128
ubatch_size = 5000
bcbatch_size = 500
iterations = 40000

time_list = []
error_u_list = []
error_v_list = []
error_p_list = []
    
methods = ["mini_batch" , "full_batch"]
result_dict =  dict((mtd, []) for mtd in methods)

##Mini Batch
time_list = [1831.07 , ]
error_u_list = [0.2112 , 0.]
error_v_list = [0.3271 , 0.]
error_p_list = [0.094 , 0.]

for mtd in methods:
    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ,  error_p_list]


##Full Batch
time_list = [8048.86 , ]
error_u_list = [ 0.0367 ,0. ]
error_v_list = [0.0706 , 0.]
error_p_list = [0.465 , 0.]

for mtd in methods:
    result_dict[mtd] = [time_list ,error_u_list ,error_v_list ,  error_p_list]


scipy.io.savemat("./dataset/NS_model_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_"+str(bcbatch_size)+"_"+str(iterations)+".mat" , result_dict)

# %%
### Plot ###
###########

# %%
# Test Data
nx = 100
ny = 100  # change to 100
x = np.linspace(0.0, 1.0, nx)
y = np.linspace(0.0, 1.0, ny)
X, Y = np.meshgrid(x, y)

X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))

# Predictions
psi_pred, p_pred = mode.predict_psi_p(X_star)
u_pred, v_pred = mode.predict_uv(X_star)

psi_star = griddata(X_star, psi_pred.flatten(), (X, Y), method='cubic')
p_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
u_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
v_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')

velocity = np.sqrt(u_pred**2 + v_pred**2)
velocity_star = griddata(X_star, velocity.flatten(), (X, Y), method='cubic')

# Reference
u_ref= np.genfromtxt("reference_u.csv", delimiter=',')
v_ref= np.genfromtxt("reference_v.csv", delimiter=',')
velocity_ref = np.sqrt(u_ref**2 + v_ref**2)

# Relative error
error = np.linalg.norm(u_star - u_pred.T, 2) / np.linalg.norm(u_star, 2)
print('l2 error: {:.2e}'.format(error))
error = np.linalg.norm(v_star - v_pred.T, 2) / np.linalg.norm(v_star, 2)
print('l2 error: {:.2e}'.format(error))
error = np.linalg.norm(p_pred - p_star.T, 2) / np.linalg.norm(p_star, 2)
print('l2 error: {:.2e}'.format(error))

### Plot ###
###########

# %%
# Reference solution & Prediceted solution
fig_1 = plt.figure(1, figsize=(18, 5))
fig_1.add_subplot(1, 3, 1)
plt.pcolor(X.T, Y.T, velocity_ref, cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Reference Velocity')

fig_1.add_subplot(1, 3, 2)
plt.pcolor(x, Y, velocity_star, cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Predicted Velocity')
plt.tight_layout()

fig_1.add_subplot(1, 3, 3)
plt.pcolor(X, Y, np.abs(velocity_star - velocity_ref.T), cmap='jet')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Absolute Error')
plt.show()

# %%
    ## Loss ##
loss_res = mode.loss_res_log
loss_bcs = mode.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
## Adaptive Constant
adaptive_constant = mode.adpative_constant_bcs_log
    
fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# %%
## Gradients #
data_gradients_res = mode.dict_gradients_res_layers
data_gradients_bcs = mode.dict_gradients_bcs_layers

num_hidden_layers = len(layers) -1
cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_{u_b}$')

    # ax.get_legend().remove()
    ax.set_xlim([-1.0, 1.0])
    ax.set_ylim([0, 100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()

fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()
