# %%
import tensorflow as tf
# from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os



os.environ["KMP_WARNINGS"] = "FALSE" 

import timeit

import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle

class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c , mode ,  sess):
        # Normalization 




        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        self.T = 1.0
        # weights
        self.adaptive_constant_bcs1_val = np.array(1.0)
        self.adaptive_constant_bcs2_val = np.array(1.0)
        self.adaptive_constant_ics_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)
        self.rate = 0.9

        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        # self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.adaptive_constant_bcs1_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs1_val.shape)
        self.adaptive_constant_bcs2_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bcs2_val.shape)
        self.adaptive_constant_ics_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_ics_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)
        

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_ics_us = self.loss_ics_u + self.loss_ics_u_t
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        # self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss =  self.adaptive_constant_res_tf * self.loss_res + self.adaptive_constant_bcs1_tf * self.loss_bc1 + self.adaptive_constant_bcs2_tf * self.loss_bc2 + self.adaptive_constant_ics_tf * ( self.loss_ics_us)

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step, 1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_tensor_list = [self.loss ,  self.loss_res, self.loss_bc1 , self.loss_bc2 , self.loss_ics_us , self.loss_ics_u, self.loss_ics_u_t] 
        self.loss_list = ["total loss" , "loss_res"  , "loss_bc1", "loss_bc2", "loss_ics_us", "loss_ics_u", "loss_ics_u_t"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_u_log = []
        self.loss_r_log = []

        # self.saver = tf.train.Saver()

         # # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs1_layers = self.generate_grad_dict()
        self.dict_gradients_bcs2_layers = self.generate_grad_dict()
        self.dict_gradients_ics_layers = self.generate_grad_dict()
        
        # Gradients Storage
        self.grad_res = []
        self.grad_ics = []
        self.grad_bcs1 = []
        self.grad_bcs2 = []

        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs1.append(tf.gradients(self.loss_bc1, self.weights[i])[0])
            self.grad_bcs2.append(tf.gradients(self.loss_bc2, self.weights[i])[0])
            self.grad_ics.append(tf.gradients(self.loss_ics_us, self.weights[i])[0])
          
        self.max_grad_res_list = []
        self.mean_grad_bcs1_list = []
        self.mean_grad_bcs2_list = []
        self.mean_grad_ics_list = []

        self.adaptive_constant_bcs1_log = []
        self.adaptive_constant_bcs2_log = []
        self.adaptive_constant_ics_log = []
        self.adaptive_constant_res_log = []

        self.mean_adaptive_constant_res_log = []
        self.mean_adaptive_constant_bcs1_log = []
        self.mean_adaptive_constant_bcs2_log = []
        self.mean_adaptive_constant_ics_log = []

        for i in range(1 , len(self.layers) - 2):
            self.max_grad_res_list.append(tf.reduce_mean(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs1_list.append(tf.reduce_mean(tf.abs(self.grad_bcs1[i])))
            self.mean_grad_bcs2_list.append(tf.reduce_mean(tf.abs(self.grad_bcs2[i])))
            self.mean_grad_ics_list.append(tf.reduce_mean(tf.abs(self.grad_ics[i])))
        
        self.max_grad_res = tf.reduce_mean(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs1 = tf.reduce_mean(tf.stack(self.mean_grad_bcs1_list))
        self.mean_grad_bcs2 = tf.reduce_mean(tf.stack(self.mean_grad_bcs2_list))
        self.mean_grad_ics = tf.reduce_mean(tf.stack(self.mean_grad_ics_list))
        
        self.adaptive_constant_bcs1 = self.mean_grad_bcs1
        self.adaptive_constant_bcs2 = self.mean_grad_bcs2
        self.adaptive_constant_ics = self.mean_grad_ics
        self.adaptive_constant_res = self.max_grad_res 

         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev, dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss


    def lambda_balance(self  , term  ):
                histoy_mean =  np.mean(self.loss_history[term])
                m = 4 #len(self.loss_list)
                num = np.exp( np.std(self.loss_history[term][-100::]) / (np.mean(self.loss_history[term][-100::]) + 1e-12) )#/(self.T * histoy_mean)) np.exp( )
                denum = 0 
                self.loss_list = [ "loss_res"  , "loss_bc1", "loss_bc2", "loss_ics_us"] 

                for  key in self.loss_list:
                    denum +=  np.exp(  np.std(self.loss_history[key][-100::]) / (np.mean(self.loss_history[key][-100::]) + 1e-12) )# /(self.T * histoy_mean))  np.exp(self.loss_history[key][-1] )
                return m * (num / denum)
    
    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(1 , nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1],
                       self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1],
                        self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                       self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], 
                       self.x_r_tf: X_res_batch[:, 1:2],
                       self.adaptive_constant_bcs1_tf: self.adaptive_constant_bcs1_val,
                       self.adaptive_constant_bcs2_tf: self.adaptive_constant_bcs2_val,
                       self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val,
                       self.adaptive_constant_res_tf: self.adaptive_constant_res_val
                       }#self.lam_r_val}

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)
            
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])

            # Print
            if it % 1000 == 0:
                elapsed = timeit.default_timer() - start_time

                # loss_value = self.sess.run(self.loss, tf_dict)
                # loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                # loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                # loss_res_value = self.sess.run(self.loss_res, tf_dict)
                [loss ,  loss_res, loss_bc1 , loss_bc2 , loss_ics_us , loss_ics_u, loss_ics_u_t]   =  batch_losses 
                self.print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs1: %.3e,  Loss_bcs2: %.3e,  loss_ics_u: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss, loss_res, loss_bc1, loss_bc2, loss_ics_u ,  loss_ics_u_t, elapsed))
                
                # Compute and Print adaptive weights during training
                    # Compute the adaptive constant
                adaptive_constant_res_val, adaptive_constant_bcs1_val, adaptive_constant_bcs2_val, adaptive_constant_ics_val = self.sess.run( [self.adaptive_constant_res,
                                                                                                                                               self.adaptive_constant_bcs1, 
                                                                                                                                               self.adaptive_constant_bcs2, 
                                                                                                                                               self.adaptive_constant_ics  ], tf_dict)
                # Print adaptive weights during training

                max_grad = np.max( [adaptive_constant_res_val, adaptive_constant_bcs1_val, adaptive_constant_bcs2_val, adaptive_constant_ics_val])
                min_grad = np.min( [adaptive_constant_res_val, adaptive_constant_bcs1_val, adaptive_constant_bcs2_val, adaptive_constant_ics_val])

                update_res = self.lambda_balance( "loss_res"  )
                update_ics_u = self.lambda_balance( "loss_ics_us"  )
                update_bcs1 = self.lambda_balance( "loss_bc1"  )
                update_bcs2 = self.lambda_balance( "loss_bc2"  )
                
                self.adaptive_constant_res_val =  update_res *  (max_grad/min_grad ) #/ (adaptive_constant_res_val + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_res_val
                self.adaptive_constant_ics_val =  update_ics_u  *  (max_grad/min_grad )# / (adaptive_constant_ics_val + 1e-12)#( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs1_val = update_bcs1 *  (max_grad/min_grad )# / (adaptive_constant_bcs1_val + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val
                self.adaptive_constant_bcs2_val = update_bcs2  *  (max_grad/min_grad ) #/ (adaptive_constant_bcs2_val + 1e-12) #( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val

                self.print('min_grad: {:.3e}'.format( min_grad))
                self.print('max_grad: {:.3e}'.format( max_grad))

                self.print('update_res: {:.3e}'.format( update_res))
                self.print('update_ics_u_t: {:.3e}'.format( update_ics_u))
                self.print('update_bcs1: {:.3e}'.format( update_bcs1))
                self.print('update_bcs2: {:.3e}'.format( update_bcs2))
                
                self.print('adaptive_constant_res_val: {:.3e}'.format( self.adaptive_constant_res_val))
                self.print('adaptive_constant_ics_val: {:.3e}'.format( self.adaptive_constant_ics_val))
                self.print('adaptive_constant_bcs1_val: {:.3e}'.format( self.adaptive_constant_bcs1_val))
                self.print('adaptive_constant_bcs2_val: {:.3e}'.format( self.adaptive_constant_bcs2_val))
                
                self.adaptive_constant_res_log.append(self.adaptive_constant_res_val)
                self.adaptive_constant_bcs1_log.append(self.adaptive_constant_bcs1_val)
                self.adaptive_constant_bcs2_log.append(self.adaptive_constant_bcs2_val)
                self.adaptive_constant_ics_log.append(self.adaptive_constant_ics_val)

                max_grad_res , mean_grad_bcs1, mean_grad_bcs2, mean_grad_ics = self.sess.run( [ self.max_grad_res , self.mean_grad_bcs1, self.mean_grad_bcs2, self.mean_grad_ics  ], tf_dict)

                self.mean_adaptive_constant_res_log.append( max_grad_res)
                self.mean_adaptive_constant_bcs1_log.append( mean_grad_bcs1)
                self.mean_adaptive_constant_bcs2_log.append( mean_grad_bcs2)
                self.mean_adaptive_constant_ics_log.append( mean_grad_ics)


                sys.stdout.flush()
                start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()


    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size)
        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size)
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size)
        
        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1],
                    self.x_ics_tf: X_ics_batch[:, 1:2],
                    self.u_ics_tf: u_ics_batch,
                    self.t_bc1_tf: X_bc1_batch[:, 0:1],
                    self.x_bc1_tf: X_bc1_batch[:, 1:2],
                    self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                    self.x_bc2_tf: X_bc2_batch[:, 1:2],
                    self.t_r_tf: X_res_batch[:, 0:1], 
                    self.x_r_tf: X_res_batch[:, 1:2],
                    self.adaptive_constant_bcs_tf: self.adaptive_constant_bcs1_val,
                    self.adaptive_constant_ics_tf: self.adaptive_constant_ics_val
                    }#self.lam_r_val}
        
        for it in range(nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 1000 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %(it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                # Compute and Print adaptive weights during training
                    # Compute the adaptive constant
                adaptive_constant_bcs_val, adaptive_constant_ics_val = self.sess.run( [self.adaptive_constant_bcs1, self.adaptive_constant_ics  ], tf_dict)
                # Print adaptive weights during training
                self.adaptive_constant_ics_val = adaptive_constant_ics_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs1_val = adaptive_constant_bcs_val * ( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs1_val


                print('lambda_u: {:.3e}'.format(self.adaptive_constant_bcs1_val))
                print('lambda_ut: {:.3e}'.format(self.adaptive_constant_ics_val))
                sys.stdout.flush()

                         
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   
     ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1  , grad_bc2 ,grad_ics  = self.sess.run([ self.grad_res[i],self.grad_bcs1[i],self.grad_bcs2[i],self.grad_ics[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs1_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())
            self.dict_gradients_bcs2_layers['layer_' + str(i + 1)].append(grad_bc2.flatten())
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs1_layers['layer_' + str(j + 1)][-1]
            gradients_bc2 = self.dict_gradients_bcs2_layers['layer_' + str(j + 1)][-1]
            gradients_ics = self.dict_gradients_ics_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')
            sns.distplot(gradients_bc2, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc2}}$')
            sns.distplot(gradients_ics, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{ics}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=4)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        #plt.show()
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , t , x , X_star , u_star , u_pred , r_star , r_pred):
        
        U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
        r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
        U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
        R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


        plt.figure(figsize=(18, 9))
        plt.subplot(2, 3, 1)
        plt.pcolor(t, x, U_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$x_1$')
        plt.ylabel('$x_2$')
        plt.title('Exact u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 2)
        plt.pcolor(t, x, U_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 3)
        plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()

        plt.subplot(2, 3, 4)
        plt.pcolor(t, x, r_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Exact r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 5)
        plt.pcolor(t, x, R_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 6)
        plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"))
        plt.close("all")

        
    
    def plot_lambda(self ):

        fontsize = 17
        fig, ax = plt.subplots()
        fig.set_size_inches([16,8])
        ax.semilogy(self.mean_adaptive_constant_bcs1_log, label=r'$\bar{\nabla_\theta {u_{bc1}}}$' , color = 'tab:green')
        ax.semilogy(self.mean_adaptive_constant_bcs2_log, label=r'$\bar{\nabla_\theta {u_{bc2}}}$' , color = 'tab:brown')
        ax.semilogy(self.mean_adaptive_constant_ics_log, label=r'$\bar{\nabla_\theta {u_{ics}}}$' , color = 'tab:blue')
        ax.semilogy(self.mean_adaptive_constant_res_log, label=r'$Max{\nabla_\theta {u_{phy}}}$' , color = 'tab:red')
        ax.set_xlabel("epochs", fontsize=fontsize)
        ax.set_ylabel(r'$\bar{\nabla_\theta {u}}$', fontsize=fontsize)
        ax.tick_params(labelsize=fontsize)
        ax.legend(loc='center left', bbox_to_anchor=(-0.25, 0.5))

        ax2 = ax.twinx() 

        # fig, ax = plt.subplots()
        # fig.set_size_inches([15,8])
    
        ax2.semilogy(self.adaptive_constant_bcs1_log, label=r'$\bar{\lambda_{bc1}}$'  ,  linestyle='dashed' , color = 'tab:green') 
        ax2.semilogy(self.adaptive_constant_bcs2_log, label=r'$\bar{\lambda_{bc2}}$'  ,  linestyle='dashed' , color = 'tab:brown') 
        ax2.semilogy(self.adaptive_constant_ics_log, label=r'$\bar{\lambda_{ics}}$' , linestyle='dashed'  , color = 'tab:blue')
        ax2.semilogy(self.adaptive_constant_res_log, label=r'$\bar{\lambda_{phy}}$' ,  linestyle='dashed' , color = 'tab:red')
        ax2.set_xlabel("epochs", fontsize=fontsize)
        ax2.set_ylabel(r'$\bar{\lambda}$', fontsize=fontsize)
        ax2.tick_params(labelsize=fontsize)
        ax2.legend(loc='center right', bbox_to_anchor=(1.2, 0.5))

        plt.tight_layout()

        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)

# %%
   #  
#test_method(mtd , layers,  X_u, Y_u, X_r, Y_r ,  X_star , u_star , r_star  , nIter ,batch_size , bcbatch_size , ubatch_size)
def test_method(method , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size ):

    tf.reset_default_graph()
    gpu_options = tf.GPUOptions(visible_device_list="0")
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
        # sess.run(init)

        model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size , sess)
        # Train model
        start_time = time.time()

        if method =="full_batch":
            print("full_batch method is used")
            model.train(nIter  , bcbatch_size , ubatch_size  )
        elif method =="mini_batch":
            print("mini_batch method is used")
            model.trainmb(nIter, mbbatch_size)
        else:
            print("unknown method!")
        elapsed = time.time() - start_time

        # Predictions
        u_pred = model.predict_u(X_star)
        r_pred = model.predict_r(X_star)
        # Predictions

        sess.close()   

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

    print('elapsed: {:.2e}'.format(elapsed))

    print('Relative L2 error_u: {:.2e}'.format(error_u))


    return [elapsed, error_u  ]

###############################################################################################################################################

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')



nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M2'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []

    for index in range(iterations):

        print("Epoch: ", str(index+1))

     # Create residual sampler

        # [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )
        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator ,  ics_sampler, bcs_sampler, res_sampler, c , mode , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

            model.print('elapsed: {:.2e}'.format(elapsed))

            model.print('Relative L2 error_u: {:.2e}'.format(error_u))
            model.print('Relative L2 error_r: {:.2e}'.format(error_r))
            model.plot_lambda()
            # model.plot_grad()
            model.save_NN()
            model.plt_prediction( t , x , X_star , u_star , u_pred , r_star , r_pred)
            model.print("average lambda_bc : " , np.average(model.adaptive_constant_bcs1_log))
            model.print("average lambda_ic : " , np.average(model.adaptive_constant_ics_log))
            model.print("average lambda_res : " , str(1.0))
            # sess.close()  

        # print('elapsed: {:.2e}'.format(elapsed))
        # print('Relative L2 error_u: {:.2e}'.format(error_u))
        # print('Relative L2 error_r: {:.2e}'.format(error_r))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    model.print("\n\nMethod: ", mtd)
    model.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    model.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    model.print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list,error_r_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_17977/4049125936.py:65: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17977/4049125936.py:66: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17977/4049125936.py:67: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17977/4049125936.py:67: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-24 22:36:44.871437: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 22:36:44.895694: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-24 22:36:44.896221: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55716d5c5d10 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-24 22:36:44.896234: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-24 22:36:44.896918: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_17977/2110774777.py:127: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17977/2110774777.py:177: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17977/2110774777.py:179: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_17977/2110774777.py:242: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1000, Loss: 2.136e-01, Loss_res: 3.641e-03,  Loss_bcs1: 3.351e-02,  Loss_bcs2: 1.185e-02,  loss_ics_u: 1.585e-01, Loss_ut_ics: 6.032e-03,, Time: 49.74
# min_grad: 2.111e-04
# max_grad: 4.979e-04
# update_res: 1.771e+00
# update_ics_u_t: 7.064e-01
# update_bcs1: 7.453e-01
# update_bcs2: 7.771e-01
# adaptive_constant_res_val: 4.177e+00
# adaptive_constant_ics_val: 1.666e+00
# adaptive_constant_bcs1_val: 1.758e+00
# adaptive_constant_bcs2_val: 1.833e+00
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 2000, Loss: 3.781e-01, Loss_res: 6.917e-04,  Loss_bcs1: 3.255e-02,  Loss_bcs2: 1.166e-02,  loss_ics_u: 1.755e-01, Loss_ut_ics: 2.548e-03,, Time: 40.89
# min_grad: 3.059e-05
# max_grad: 8.930e-04
# update_res: 3.266e+00
# update_ics_u_t: 2.234e-01
# update_bcs1: 2.480e-01
# update_bcs2: 2.625e-01
# adaptive_constant_res_val: 9.536e+01
# adaptive_constant_ics_val: 6.522e+00
# adaptive_constant_bcs1_val: 7.241e+00
# adaptive_constant_bcs2_val: 7.665e+00
# It: 3000, Loss: 2.402e+00, Loss_res: 9.488e-05,  Loss_bcs1: 6.594e-02,  Loss_bcs2: 3.625e-02,  loss_ics_u: 2.474e-01, Loss_ut_ics: 3.703e-03,, Time: 36.63
# min_grad: 7.029e-06
# max_grad: 3.697e-04
# update_res: 3.441e+00
# update_ics_u_t: 1.705e-01
# update_bcs1: 1.851e-01
# update_bcs2: 2.034e-01
# adaptive_constant_res_val: 1.810e+02
# adaptive_constant_ics_val: 8.969e+00
# adaptive_constant_bcs1_val: 9.735e+00
# adaptive_constant_bcs2_val: 1.070e+01
# It: 4000, Loss: 2.664e+00, Loss_res: 1.743e-04,  Loss_bcs1: 5.734e-02,  Loss_bcs2: 2.337e-02,  loss_ics_u: 2.025e-01, Loss_ut_ics: 8.333e-04,, Time: 36.92
# min_grad: 3.629e-05
# max_grad: 3.314e-04
# update_res: 3.116e+00
# update_ics_u_t: 2.747e-01
# update_bcs1: 2.924e-01
# update_bcs2: 3.166e-01
# adaptive_constant_res_val: 2.846e+01
# adaptive_constant_ics_val: 2.508e+00
# adaptive_constant_bcs1_val: 2.670e+00
# adaptive_constant_bcs2_val: 2.891e+00
# It: 5000, Loss: 5.248e-01, Loss_res: 4.926e-04,  Loss_bcs1: 3.539e-02,  Loss_bcs2: 1.317e-02,  loss_ics_u: 1.502e-01, Loss_ut_ics: 6.511e-04,, Time: 38.05
# min_grad: 6.401e-05
# max_grad: 3.139e-04
# update_res: 2.276e+00
# update_ics_u_t: 5.513e-01
# update_bcs1: 5.667e-01
# update_bcs2: 6.062e-01
# adaptive_constant_res_val: 1.116e+01
# adaptive_constant_ics_val: 2.704e+00
# adaptive_constant_bcs1_val: 2.779e+00
# adaptive_constant_bcs2_val: 2.973e+00
# It: 6000, Loss: 3.720e-01, Loss_res: 4.473e-04,  Loss_bcs1: 2.199e-02,  Loss_bcs2: 8.409e-03,  loss_ics_u: 1.033e-01, Loss_ut_ics: 5.650e-04,, Time: 39.11
# min_grad: 9.794e-05
# max_grad: 4.742e-04
# update_res: 2.138e+00
# update_ics_u_t: 5.961e-01
# update_bcs1: 6.333e-01
# update_bcs2: 6.330e-01
# adaptive_constant_res_val: 1.035e+01
# adaptive_constant_ics_val: 2.886e+00
# adaptive_constant_bcs1_val: 3.066e+00
# adaptive_constant_bcs2_val: 3.065e+00
# It: 7000, Loss: 4.048e-01, Loss_res: 5.916e-04,  Loss_bcs1: 2.744e-02,  Loss_bcs2: 1.018e-02,  loss_ics_u: 9.716e-02, Loss_ut_ics: 1.021e-03,, Time: 37.59
# min_grad: 7.118e-05
# max_grad: 2.082e-04
# update_res: 2.440e+00
# update_ics_u_t: 4.595e-01
# update_bcs1: 5.389e-01
# update_bcs2: 5.617e-01
# adaptive_constant_res_val: 7.137e+00
# adaptive_constant_ics_val: 1.344e+00
# adaptive_constant_bcs1_val: 1.576e+00
# adaptive_constant_bcs2_val: 1.643e+00
# It: 8000, Loss: 1.671e-01, Loss_res: 2.352e-04,  Loss_bcs1: 1.627e-02,  Loss_bcs2: 5.997e-03,  loss_ics_u: 9.646e-02, Loss_ut_ics: 2.253e-04,, Time: 37.68
# min_grad: 3.370e-05
# max_grad: 2.092e-04
# update_res: 1.845e+00
# update_ics_u_t: 6.872e-01
# update_bcs1: 7.384e-01
# update_bcs2: 7.296e-01
# adaptive_constant_res_val: 1.145e+01
# adaptive_constant_ics_val: 4.266e+00
# adaptive_constant_bcs1_val: 4.584e+00
# adaptive_constant_bcs2_val: 4.530e+00
# It: 9000, Loss: 5.750e-01, Loss_res: 1.527e-03,  Loss_bcs1: 1.399e-02,  Loss_bcs2: 9.363e-03,  loss_ics_u: 1.052e-01, Loss_ut_ics: 5.122e-04,, Time: 37.49
# min_grad: 6.058e-05
# max_grad: 3.866e-04
# update_res: 2.127e+00
# update_ics_u_t: 5.939e-01
# update_bcs1: 6.584e-01
# update_bcs2: 6.204e-01
# adaptive_constant_res_val: 1.358e+01
# adaptive_constant_ics_val: 3.790e+00
# adaptive_constant_bcs1_val: 4.202e+00
# adaptive_constant_bcs2_val: 3.959e+00
# It: 10000, Loss: 4.316e-01, Loss_res: 7.786e-04,  Loss_bcs1: 9.595e-03,  Loss_bcs2: 7.610e-03,  loss_ics_u: 9.220e-02, Loss_ut_ics: 3.013e-04,, Time: 35.39
# min_grad: 6.615e-05
# max_grad: 7.940e-04
# update_res: 1.861e+00
# update_ics_u_t: 6.944e-01
# update_bcs1: 7.263e-01
# update_bcs2: 7.186e-01
# adaptive_constant_res_val: 2.233e+01
# adaptive_constant_ics_val: 8.335e+00
# adaptive_constant_bcs1_val: 8.718e+00
# adaptive_constant_bcs2_val: 8.625e+00
# It: 11000, Loss: 8.591e-01, Loss_res: 3.984e-04,  Loss_bcs1: 1.187e-02,  Loss_bcs2: 9.009e-03,  loss_ics_u: 7.942e-02, Loss_ut_ics: 8.526e-04,, Time: 38.60
# min_grad: 3.646e-05
# max_grad: 5.038e-04
# update_res: 1.253e+00
# update_ics_u_t: 8.588e-01
# update_bcs1: 9.827e-01
# update_bcs2: 9.051e-01
# adaptive_constant_res_val: 1.732e+01
# adaptive_constant_ics_val: 1.187e+01
# adaptive_constant_bcs1_val: 1.358e+01
# adaptive_constant_bcs2_val: 1.251e+01
# It: 12000, Loss: 1.194e+00, Loss_res: 1.861e-03,  Loss_bcs1: 6.769e-03,  Loss_bcs2: 3.575e-03,  loss_ics_u: 8.482e-02, Loss_ut_ics: 1.537e-03,, Time: 63.71
# min_grad: 4.253e-05
# max_grad: 7.665e-04
# update_res: 1.435e+00
# update_ics_u_t: 8.048e-01
# update_bcs1: 8.952e-01
# update_bcs2: 8.648e-01
# adaptive_constant_res_val: 2.587e+01
# adaptive_constant_ics_val: 1.450e+01
# adaptive_constant_bcs1_val: 1.613e+01
# adaptive_constant_bcs2_val: 1.559e+01
# It: 13000, Loss: 1.278e+00, Loss_res: 1.130e-03,  Loss_bcs1: 6.352e-03,  Loss_bcs2: 3.086e-03,  loss_ics_u: 7.453e-02, Loss_ut_ics: 1.211e-03,, Time: 67.53
# min_grad: 2.170e-05
# max_grad: 2.234e-03
# update_res: 1.459e+00
# update_ics_u_t: 7.797e-01
# update_bcs1: 8.791e-01
# update_bcs2: 8.822e-01
# adaptive_constant_res_val: 1.502e+02
# adaptive_constant_ics_val: 8.027e+01
# adaptive_constant_bcs1_val: 9.050e+01
# adaptive_constant_bcs2_val: 9.082e+01
# It: 14000, Loss: 1.008e+01, Loss_res: 5.700e-04,  Loss_bcs1: 1.129e-02,  Loss_bcs2: 9.469e-03,  loss_ics_u: 1.004e-01, Loss_ut_ics: 6.843e-04,, Time: 74.83
# min_grad: 7.698e-05
# max_grad: 2.483e-04
# update_res: 1.102e+00
# update_ics_u_t: 9.291e-01
# update_bcs1: 1.005e+00
# update_bcs2: 9.635e-01
# adaptive_constant_res_val: 3.554e+00
# adaptive_constant_ics_val: 2.996e+00
# adaptive_constant_bcs1_val: 3.243e+00
# adaptive_constant_bcs2_val: 3.107e+00
# It: 15000, Loss: 3.678e-01, Loss_res: 5.016e-04,  Loss_bcs1: 1.253e-02,  Loss_bcs2: 7.594e-03,  loss_ics_u: 1.005e-01, Loss_ut_ics: 1.959e-04,, Time: 76.70
# min_grad: 5.262e-05
# max_grad: 1.446e-04
# update_res: 1.020e+00
# update_ics_u_t: 9.977e-01
# update_bcs1: 9.998e-01
# update_bcs2: 9.823e-01
# adaptive_constant_res_val: 2.804e+00
# adaptive_constant_ics_val: 2.743e+00
# adaptive_constant_bcs1_val: 2.748e+00
# adaptive_constant_bcs2_val: 2.700e+00
# It: 16000, Loss: 2.910e-01, Loss_res: 5.103e-04,  Loss_bcs1: 1.253e-02,  Loss_bcs2: 8.381e-03,  loss_ics_u: 8.442e-02, Loss_ut_ics: 3.533e-04,, Time: 76.47
# min_grad: 3.642e-05
# max_grad: 1.338e-04
# update_res: 1.033e+00
# update_ics_u_t: 9.818e-01
# update_bcs1: 9.959e-01
# update_bcs2: 9.892e-01
# adaptive_constant_res_val: 3.794e+00
# adaptive_constant_ics_val: 3.606e+00
# adaptive_constant_bcs1_val: 3.657e+00
# adaptive_constant_bcs2_val: 3.633e+00
# It: 17000, Loss: 3.595e-01, Loss_res: 5.324e-04,  Loss_bcs1: 1.274e-02,  Loss_bcs2: 6.697e-03,  loss_ics_u: 7.893e-02, Loss_ut_ics: 5.445e-04,, Time: 76.32
# min_grad: 6.163e-05
# max_grad: 1.592e-04
# update_res: 1.025e+00
# update_ics_u_t: 9.705e-01
# update_bcs1: 1.001e+00
# update_bcs2: 1.003e+00
# adaptive_constant_res_val: 2.649e+00
# adaptive_constant_ics_val: 2.508e+00
# adaptive_constant_bcs1_val: 2.587e+00
# adaptive_constant_bcs2_val: 2.592e+00
# It: 18000, Loss: 2.541e-01, Loss_res: 6.059e-04,  Loss_bcs1: 9.047e-03,  Loss_bcs2: 7.415e-03,  loss_ics_u: 8.330e-02, Loss_ut_ics: 4.092e-04,, Time: 77.13
# min_grad: 3.480e-05
# max_grad: 1.491e-04
# update_res: 1.043e+00
# update_ics_u_t: 9.651e-01
# update_bcs1: 1.005e+00
# update_bcs2: 9.870e-01
# adaptive_constant_res_val: 4.469e+00
# adaptive_constant_ics_val: 4.136e+00
# adaptive_constant_bcs1_val: 4.308e+00
# adaptive_constant_bcs2_val: 4.230e+00
# It: 19000, Loss: 3.730e-01, Loss_res: 3.786e-04,  Loss_bcs1: 9.304e-03,  Loss_bcs2: 7.923e-03,  loss_ics_u: 7.166e-02, Loss_ut_ics: 3.269e-04,, Time: 78.60
# min_grad: 4.212e-05
# max_grad: 1.092e-04
# update_res: 1.035e+00
# update_ics_u_t: 9.576e-01
# update_bcs1: 1.010e+00
# update_bcs2: 9.972e-01
# adaptive_constant_res_val: 2.685e+00
# adaptive_constant_ics_val: 2.484e+00
# adaptive_constant_bcs1_val: 2.620e+00
# adaptive_constant_bcs2_val: 2.586e+00
# It: 20000, Loss: 2.331e-01, Loss_res: 4.047e-04,  Loss_bcs1: 7.311e-03,  Loss_bcs2: 8.816e-03,  loss_ics_u: 7.591e-02, Loss_ut_ics: 6.145e-04,, Time: 78.35
# min_grad: 4.564e-05
# max_grad: 1.793e-04
# update_res: 1.042e+00
# update_ics_u_t: 9.436e-01
# update_bcs1: 1.031e+00
# update_bcs2: 9.838e-01
# adaptive_constant_res_val: 4.093e+00
# adaptive_constant_ics_val: 3.706e+00
# adaptive_constant_bcs1_val: 4.048e+00
# adaptive_constant_bcs2_val: 3.864e+00
# It: 21000, Loss: 2.394e-01, Loss_res: 6.314e-04,  Loss_bcs1: 8.962e-03,  Loss_bcs2: 7.325e-03,  loss_ics_u: 4.552e-02, Loss_ut_ics: 9.411e-04,, Time: 78.56
# min_grad: 3.672e-05
# max_grad: 2.273e-04
# update_res: 1.618e+00
# update_ics_u_t: 7.437e-01
# update_bcs1: 8.327e-01
# update_bcs2: 8.056e-01
# adaptive_constant_res_val: 1.001e+01
# adaptive_constant_ics_val: 4.603e+00
# adaptive_constant_bcs1_val: 5.153e+00
# adaptive_constant_bcs2_val: 4.986e+00
# It: 22000, Loss: 3.089e-01, Loss_res: 1.472e-03,  Loss_bcs1: 7.357e-03,  Loss_bcs2: 6.172e-03,  loss_ics_u: 4.875e-02, Loss_ut_ics: 2.367e-04,, Time: 77.27
# min_grad: 5.906e-05
# max_grad: 3.949e-04
# update_res: 1.374e+00
# update_ics_u_t: 8.358e-01
# update_bcs1: 8.911e-01
# update_bcs2: 8.991e-01
# adaptive_constant_res_val: 9.188e+00
# adaptive_constant_ics_val: 5.589e+00
# adaptive_constant_bcs1_val: 5.959e+00
# adaptive_constant_bcs2_val: 6.012e+00
# It: 23000, Loss: 3.040e-01, Loss_res: 5.913e-04,  Loss_bcs1: 5.229e-03,  Loss_bcs2: 5.316e-03,  loss_ics_u: 4.193e-02, Loss_ut_ics: 1.960e-04,, Time: 77.84
# min_grad: 4.196e-05
# max_grad: 4.844e-04
# update_res: 1.831e+00
# update_ics_u_t: 6.970e-01
# update_bcs1: 7.306e-01
# update_bcs2: 7.417e-01
# adaptive_constant_res_val: 2.113e+01
# adaptive_constant_ics_val: 8.046e+00
# adaptive_constant_bcs1_val: 8.434e+00
# adaptive_constant_bcs2_val: 8.562e+00
# It: 24000, Loss: 4.575e-01, Loss_res: 4.207e-04,  Loss_bcs1: 7.258e-03,  Loss_bcs2: 7.148e-03,  loss_ics_u: 4.043e-02, Loss_ut_ics: 1.101e-04,, Time: 79.01
# min_grad: 4.109e-05
# max_grad: 3.602e-04
# update_res: 1.072e+00
# update_ics_u_t: 9.268e-01
# update_bcs1: 9.900e-01
# update_bcs2: 1.011e+00
# adaptive_constant_res_val: 9.398e+00
# adaptive_constant_ics_val: 8.124e+00
# adaptive_constant_bcs1_val: 8.678e+00
# adaptive_constant_bcs2_val: 8.864e+00
# It: 25000, Loss: 4.010e-01, Loss_res: 4.631e-04,  Loss_bcs1: 7.135e-03,  Loss_bcs2: 4.987e-03,  loss_ics_u: 3.566e-02, Loss_ut_ics: 1.090e-04,, Time: 63.96
# min_grad: 3.594e-05
# max_grad: 2.623e-04
# update_res: 1.047e+00
# update_ics_u_t: 9.221e-01
# update_bcs1: 9.976e-01
# update_bcs2: 1.033e+00
# adaptive_constant_res_val: 7.639e+00
# adaptive_constant_ics_val: 6.729e+00
# adaptive_constant_bcs1_val: 7.280e+00
# adaptive_constant_bcs2_val: 7.541e+00
# It: 26000, Loss: 2.846e-01, Loss_res: 6.423e-04,  Loss_bcs1: 6.635e-03,  Loss_bcs2: 3.718e-03,  loss_ics_u: 3.000e-02, Loss_ut_ics: 2.152e-04,, Time: 38.46
# min_grad: 2.249e-05
# max_grad: 6.868e-04
# update_res: 1.237e+00
# update_ics_u_t: 8.796e-01
# update_bcs1: 9.178e-01
# update_bcs2: 9.654e-01
# adaptive_constant_res_val: 3.778e+01
# adaptive_constant_ics_val: 2.686e+01
# adaptive_constant_bcs1_val: 2.802e+01
# adaptive_constant_bcs2_val: 2.948e+01
# It: 27000, Loss: 8.785e-01, Loss_res: 4.228e-04,  Loss_bcs1: 4.222e-03,  Loss_bcs2: 3.497e-03,  loss_ics_u: 2.364e-02, Loss_ut_ics: 2.345e-04,, Time: 35.60
# min_grad: 1.661e-05
# max_grad: 1.200e-04
# update_res: 1.190e+00
# update_ics_u_t: 8.835e-01
# update_bcs1: 9.649e-01
# update_bcs2: 9.616e-01
# adaptive_constant_res_val: 8.600e+00
# adaptive_constant_ics_val: 6.385e+00
# adaptive_constant_bcs1_val: 6.973e+00
# adaptive_constant_bcs2_val: 6.949e+00
# It: 28000, Loss: 2.874e-01, Loss_res: 3.506e-04,  Loss_bcs1: 6.351e-03,  Loss_bcs2: 4.310e-03,  loss_ics_u: 3.283e-02, Loss_ut_ics: 8.240e-05,, Time: 34.94
# min_grad: 1.830e-05
# max_grad: 8.638e-05
# update_res: 1.005e+00
# update_ics_u_t: 9.549e-01
# update_bcs1: 1.003e+00
# update_bcs2: 1.038e+00
# adaptive_constant_res_val: 4.743e+00
# adaptive_constant_ics_val: 4.508e+00
# adaptive_constant_bcs1_val: 4.733e+00
# adaptive_constant_bcs2_val: 4.899e+00
# It: 29000, Loss: 1.988e-01, Loss_res: 3.474e-04,  Loss_bcs1: 7.402e-03,  Loss_bcs2: 5.854e-03,  loss_ics_u: 2.949e-02, Loss_ut_ics: 1.154e-04,, Time: 39.83
# min_grad: 3.282e-05
# max_grad: 9.117e-05
# update_res: 1.009e+00
# update_ics_u_t: 9.311e-01
# update_bcs1: 9.900e-01
# update_bcs2: 1.070e+00
# adaptive_constant_res_val: 2.802e+00
# adaptive_constant_ics_val: 2.586e+00
# adaptive_constant_bcs1_val: 2.750e+00
# adaptive_constant_bcs2_val: 2.973e+00
# It: 30000, Loss: 1.012e-01, Loss_res: 3.351e-04,  Loss_bcs1: 8.123e-03,  Loss_bcs2: 3.576e-03,  loss_ics_u: 2.584e-02, Loss_ut_ics: 1.636e-04,, Time: 36.08
# min_grad: 1.642e-05
# max_grad: 7.769e-05
# update_res: 1.002e+00
# update_ics_u_t: 9.506e-01
# update_bcs1: 1.020e+00
# update_bcs2: 1.027e+00
# adaptive_constant_res_val: 4.744e+00
# adaptive_constant_ics_val: 4.499e+00
# adaptive_constant_bcs1_val: 4.829e+00
# adaptive_constant_bcs2_val: 4.859e+00
# It: 31000, Loss: 1.358e-01, Loss_res: 6.191e-04,  Loss_bcs1: 6.410e-03,  Loss_bcs2: 3.976e-03,  loss_ics_u: 1.819e-02, Loss_ut_ics: 1.575e-04,, Time: 34.63
# min_grad: 2.294e-05
# max_grad: 1.727e-04
# update_res: 1.021e+00
# update_ics_u_t: 9.432e-01
# update_bcs1: 1.016e+00
# update_bcs2: 1.019e+00
# adaptive_constant_res_val: 7.693e+00
# adaptive_constant_ics_val: 7.103e+00
# adaptive_constant_bcs1_val: 7.652e+00
# adaptive_constant_bcs2_val: 7.675e+00
# It: 32000, Loss: 2.467e-01, Loss_res: 2.058e-03,  Loss_bcs1: 6.723e-03,  Loss_bcs2: 6.506e-03,  loss_ics_u: 1.770e-02, Loss_ut_ics: 5.278e-04,, Time: 34.10
# min_grad: 2.291e-05
# max_grad: 9.163e-04
# update_res: 1.426e+00
# update_ics_u_t: 8.064e-01
# update_bcs1: 8.861e-01
# update_bcs2: 8.813e-01
# adaptive_constant_res_val: 5.704e+01
# adaptive_constant_ics_val: 3.225e+01
# adaptive_constant_bcs1_val: 3.544e+01
# adaptive_constant_bcs2_val: 3.525e+01
# It: 33000, Loss: 1.018e+00, Loss_res: 4.313e-04,  Loss_bcs1: 7.819e-03,  Loss_bcs2: 5.184e-03,  loss_ics_u: 1.645e-02, Loss_ut_ics: 8.564e-05,, Time: 36.51
# min_grad: 2.868e-05
# max_grad: 1.595e-04
# update_res: 9.972e-01
# update_ics_u_t: 9.563e-01
# update_bcs1: 1.013e+00
# update_bcs2: 1.034e+00
# adaptive_constant_res_val: 5.545e+00
# adaptive_constant_ics_val: 5.318e+00
# adaptive_constant_bcs1_val: 5.632e+00
# adaptive_constant_bcs2_val: 5.748e+00
# It: 34000, Loss: 1.403e-01, Loss_res: 3.962e-04,  Loss_bcs1: 6.310e-03,  Loss_bcs2: 3.850e-03,  loss_ics_u: 1.507e-02, Loss_ut_ics: 5.869e-05,, Time: 35.60
# min_grad: 2.133e-05
# max_grad: 1.368e-04
# update_res: 1.001e+00
# update_ics_u_t: 9.545e-01
# update_bcs1: 1.031e+00
# update_bcs2: 1.013e+00
# adaptive_constant_res_val: 6.422e+00
# adaptive_constant_ics_val: 6.124e+00
# adaptive_constant_bcs1_val: 6.614e+00
# adaptive_constant_bcs2_val: 6.502e+00
# It: 35000, Loss: 1.824e-01, Loss_res: 3.169e-04,  Loss_bcs1: 7.997e-03,  Loss_bcs2: 4.102e-03,  loss_ics_u: 1.638e-02, Loss_ut_ics: 9.162e-05,, Time: 37.17
# min_grad: 2.003e-05
# max_grad: 1.531e-04
# update_res: 9.892e-01
# update_ics_u_t: 9.467e-01
# update_bcs1: 1.021e+00
# update_bcs2: 1.043e+00
# adaptive_constant_res_val: 7.563e+00
# adaptive_constant_ics_val: 7.239e+00
# adaptive_constant_bcs1_val: 7.805e+00
# adaptive_constant_bcs2_val: 7.977e+00
# It: 36000, Loss: 2.045e-01, Loss_res: 3.393e-04,  Loss_bcs1: 7.827e-03,  Loss_bcs2: 5.300e-03,  loss_ics_u: 1.356e-02, Loss_ut_ics: 6.481e-05,, Time: 38.27
# min_grad: 1.199e-05
# max_grad: 7.479e-05
# update_res: 9.968e-01
# update_ics_u_t: 9.429e-01
# update_bcs1: 1.053e+00
# update_bcs2: 1.007e+00
# adaptive_constant_res_val: 6.216e+00
# adaptive_constant_ics_val: 5.880e+00
# adaptive_constant_bcs1_val: 6.566e+00
# adaptive_constant_bcs2_val: 6.281e+00
# It: 37000, Loss: 1.618e-01, Loss_res: 3.698e-04,  Loss_bcs1: 8.236e-03,  Loss_bcs2: 4.497e-03,  loss_ics_u: 1.304e-02, Loss_ut_ics: 9.024e-05,, Time: 44.98
# min_grad: 2.026e-05
# max_grad: 2.222e-04
# update_res: 9.927e-01
# update_ics_u_t: 9.583e-01
# update_bcs1: 1.030e+00
# update_bcs2: 1.019e+00
# adaptive_constant_res_val: 1.088e+01
# adaptive_constant_ics_val: 1.051e+01
# adaptive_constant_bcs1_val: 1.130e+01
# adaptive_constant_bcs2_val: 1.117e+01
# It: 38000, Loss: 2.610e-01, Loss_res: 6.011e-04,  Loss_bcs1: 8.129e-03,  Loss_bcs2: 3.504e-03,  loss_ics_u: 1.167e-02, Loss_ut_ics: 8.764e-05,, Time: 73.08
# min_grad: 2.359e-05
# max_grad: 3.609e-04
# update_res: 1.065e+00
# update_ics_u_t: 9.329e-01
# update_bcs1: 1.013e+00
# update_bcs2: 9.890e-01
# adaptive_constant_res_val: 1.630e+01
# adaptive_constant_ics_val: 1.427e+01
# adaptive_constant_bcs1_val: 1.549e+01
# adaptive_constant_bcs2_val: 1.513e+01
# It: 39000, Loss: 3.804e-01, Loss_res: 3.413e-04,  Loss_bcs1: 7.576e-03,  Loss_bcs2: 6.464e-03,  loss_ics_u: 1.107e-02, Loss_ut_ics: 1.138e-04,, Time: 73.87
# min_grad: 2.004e-05
# max_grad: 5.767e-04
# update_res: 1.171e+00
# update_ics_u_t: 9.019e-01
# update_bcs1: 9.696e-01
# update_bcs2: 9.576e-01
# adaptive_constant_res_val: 3.369e+01
# adaptive_constant_ics_val: 2.596e+01
# adaptive_constant_bcs1_val: 2.790e+01
# adaptive_constant_bcs2_val: 2.756e+01
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 5.921e-01, Loss_res: 2.280e-04,  Loss_bcs1: 7.159e-03,  Loss_bcs2: 4.239e-03,  loss_ics_u: 1.014e-02, Loss_ut_ics: 1.794e-04,, Time: 56.45
# min_grad: 1.028e-05
# max_grad: 1.306e-04
# update_res: 1.031e+00
# update_ics_u_t: 9.495e-01
# update_bcs1: 1.019e+00
# update_bcs2: 1.001e+00
# adaptive_constant_res_val: 1.309e+01
# adaptive_constant_ics_val: 1.206e+01
# adaptive_constant_bcs1_val: 1.295e+01
# adaptive_constant_bcs2_val: 1.272e+01
# elapsed: 2.13e+03
# Relative L2 error_u: 3.60e-01
# Relative L2 error_r: 3.10e-02
# Save uv NN parameters successfully in %s ...checkpoints/Dec-24-2023_22-36-44-897182_M2
# Final loss total loss: 5.920801e-01
# Final loss loss_res: 2.280085e-04
# Final loss loss_bc1: 7.158972e-03
# Final loss loss_bc2: 4.239425e-03
# Final loss loss_ics_us: 1.031804e-02
# Final loss loss_ics_u: 1.013864e-02
# Final loss loss_ics_u_t: 1.794018e-04
# average lambda_bc : 1.0248e+01
# average lambda_ic : 9.4111e+00
# average lambda_res : 1.0
#
#
# Method: mini_batch
#
# average of time_list:2.1304e+03
# average of error_u_list:3.5979e-01
# average of error_r_list:3.1048e-02

# %%
model = [100 , 40 , 30 , 12 , 1 , 232]
model[-60::]
# Out:
# [100, 40, 30, 12, 1, 232]
