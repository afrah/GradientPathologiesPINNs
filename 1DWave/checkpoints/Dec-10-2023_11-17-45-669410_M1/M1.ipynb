# %%
import tensorflow as tf
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import layers, activations

# tf.enable_eager_execution()
os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time
from pyDOE import lhs


import logging

import os.path
import shutil
from datetime import datetime
import pickle
 #############################################################################
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual


class PINN:
    # Initialize the class
    def __init__(self, layers, operator , ics_sampler, bcs_sampler, res_sampler, c ,mode,  sess):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        

        self.lam_bc1_val =  tf.Variable([1.0], dtype=tf.float32)
        self.lam_bc2_val =  tf.Variable([1.0], dtype=tf.float32)
        self.lam_ics_val =  tf.Variable([1.0], dtype=tf.float32)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        # Define Tensorflow session
        self.sess = sess #tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

    
        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
    
        
        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)


        # Evaluate predictions

        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        
        # Boundary loss and Initial loss
        # self.loss_coll_u = tf.reduce_mean(tf.square(self.u_coll_tf - self.u_coll_pred))

        self.loss_ics_u =  100 *  (tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred)) + tf.reduce_mean(tf.square( tf.gradients(self.u_ics_pred, self.t_ics_tf)[0] / self.sigma_t)))
        self.loss_bc1 =100 *  tf.reduce_mean(tf.square(self.u_bc1_pred)) #+ tf.reduce_mean(tf.square(self.u_bc2_pred))
        self.loss_bc2 =100 * tf.reduce_mean(tf.square(self.u_bc2_pred))

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.loss_res + self.loss_bc1 +  self.loss_bc2 + self.loss_ics_u  # + self.lam_ut_tf * self.loss_ics_u_t 

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,  1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step , var_list=  self.weights + self.biases )

        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bc1 , self.loss_bc2 , self.loss_ics_u] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bc1", "loss_bc2", "loss_ics_u"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs1_layers = self.generate_grad_dict()
        self.dict_gradients_bcs2_layers = self.generate_grad_dict()
        self.dict_gradients_ics_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_ics = []
        self.grad_bcs1 = []
        self.grad_bcs2 = []

        self.adaptive_constant_bcs1_log = []
        self.adaptive_constant_bcs2_log = []
        self.adaptive_constant_ics_log = []
        self.adaptive_constant_res_log = []

        self.max_grad_res_list = []
        self.mean_grad1_bcs_list = []
        self.mean_grad2_bcs_list = []
        self.mean_grad_ics_list = []


        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs1.append(tf.gradients(self.loss_bc1, self.weights[i])[0])
            self.grad_bcs2.append(tf.gradients(self.loss_bc2, self.weights[i])[0])
            self.grad_ics.append(tf.gradients(self.loss_ics_u, self.weights[i])[0])


        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.math.reduce_mean(tf.abs(self.grad_res[i]))) 
            self.mean_grad1_bcs_list.append(tf.math.reduce_mean(tf.abs(self.grad_bcs1[i])))
            self.mean_grad2_bcs_list.append(tf.math.reduce_mean(tf.abs(self.grad_bcs1[i])))
            self.mean_grad_ics_list.append(tf.math.reduce_mean(tf.abs(self.grad_ics[i])))
        
        self.max_grad_res = tf.math.reduce_mean(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs1 = tf.math.reduce_mean(tf.stack(self.mean_grad1_bcs_list))
        self.mean_grad_bcs2 = tf.math.reduce_mean(tf.stack(self.mean_grad2_bcs_list))
        self.mean_grad_ics = tf.math.reduce_mean(tf.stack(self.mean_grad_ics_list))
        
        self.adaptive_constant_bcs1 = self.mean_grad_bcs1
        self.adaptive_constant_bcs2 = self.mean_grad_bcs2
        self.adaptive_constant_ics = self.mean_grad_ics
        self.adaptive_constant_res = self.max_grad_res


         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
############################################################################################################


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

#######################################################################################################
    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,  dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),  self.layers, self.weights, self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x, self.c, self.sigma_t,  self.sigma_x)
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y


    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )

        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size )
        
        for it in range(1 , nIter):

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)
            # Define a dictionary for associating placeholders with data
            tf_dict = {
                self.t_ics_tf: X_ics_batch[:, 0:1], 
                self.x_ics_tf: X_ics_batch[:, 1:2],
                self.u_ics_tf: u_ics_batch,
                self.t_bc1_tf: X_bc1_batch[:, 0:1],
                self.x_bc1_tf: X_bc1_batch[:, 1:2],
                self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                self.x_bc2_tf: X_bc2_batch[:, 1:2],
                self.t_r_tf: X_res_batch[:, 0:1], 
                self.x_r_tf: X_res_batch[:, 1:2]
                       }

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            # self.print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_res ] , tf_dict)

                self.print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e,  Loss_res: %.3e,  Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u , loss_res , elapsed))
                
                    # Compute the adaptive constant
                adaptive_constant_res , adaptive_constant_bcs1_val, adaptive_constant_bcs2 , adaptive_constant_ics_val = self.sess.run( [self.adaptive_constant_res , self.adaptive_constant_bcs1, self.adaptive_constant_bcs2, self.adaptive_constant_ics  ], tf_dict)
                # self.print adaptive weights during training
                self.adaptive_constant_res_val = 1.0 # loss_res / adaptive_constant_res #* ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_ics_val =  1.0 # loss_ics_u_t / adaptive_constant_ics_val #* ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs_val =  1.0 # (loss_bc1+ loss_bc2 + loss_ics_u) /adaptive_constant_bcs_val #* ( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val


                self.print('adaptive_constant_res_val: {:.3e}'.format( adaptive_constant_res))
                self.print('adaptive_constant_ics_val: {:.3e}'.format( adaptive_constant_ics_val))
                self.print('adaptive_constant_bcs1_val: {:.3e}'.format( adaptive_constant_bcs1_val))
                self.print('adaptive_constant_bcs2_val: {:.3e}'.format( adaptive_constant_bcs2))
                
                self.adaptive_constant_res_log.append(adaptive_constant_res)
                self.adaptive_constant_bcs1_log.append(adaptive_constant_bcs1_val)
                self.adaptive_constant_bcs2_log.append(adaptive_constant_bcs2)
                self.adaptive_constant_ics_log.append(adaptive_constant_ics_val)


                start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
####################################################################################################
    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size )

        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size )
    

        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)
        # Define a dictionary for associating placeholders with data
        tf_dict = {
            self.t_ics_tf: X_ics_batch[:, 0:1], 
            self.x_ics_tf: X_ics_batch[:, 1:2],
            self.u_ics_tf: u_ics_batch,
            self.t_bc1_tf: X_bc1_batch[:, 0:1],
            self.x_bc1_tf: X_bc1_batch[:, 1:2],
            self.t_bc2_tf: X_bc2_batch[:, 0:1], 
            self.x_bc2_tf: X_bc2_batch[:, 1:2],
            self.t_r_tf: X_res_batch[:, 0:1], 
            self.x_r_tf: X_res_batch[:, 1:2]
                    }
        for it in range(1 , nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # self.print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_res ] , tf_dict)

                self.print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e,  Loss_res: %.3e,  Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u , loss_res , elapsed))
          
                
                sys.stdout.flush()
                start_time = timeit.default_timer()

    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   
###################################################################################################################


    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1 , grad_bcs2 , grad_ics  = self.sess.run([ self.grad_res[i],self.grad_bcs1[i],self.grad_bcs2[i],self.grad_ics[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs1_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())
            self.dict_gradients_bcs2_layers['layer_' + str(i + 1)].append(grad_bcs2.flatten())
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs1_layers['layer_' + str(j + 1)][-1]
            gradients_bc2 = self.dict_gradients_bcs2_layers['layer_' + str(j + 1)][-1]
            gradients_ics = self.dict_gradients_ics_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')
            sns.distplot(gradients_bc2, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc2}}$')
            sns.distplot(gradients_ics, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{ics}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=4)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")

    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M1.ipynb', os.path.join(dirname, 'M1.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        #plt.show()
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)

    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values

    def plt_prediction(self , t , x , X_star , u_star , u_pred , r_star , r_pred):
        
        U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
        r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
        U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
        R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


        plt.figure(figsize=(18, 9))
        plt.subplot(2, 3, 1)
        plt.pcolor(t, x, U_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$x_1$')
        plt.ylabel('$x_2$')
        plt.title('Exact u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 2)
        plt.pcolor(t, x, U_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 3)
        plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()

        plt.subplot(2, 3, 4)
        plt.pcolor(t, x, r_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Exact r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 5)
        plt.pcolor(t, x, R_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 6)
        plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"))
        plt.close("all")

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')
coll_sampler = Sampler(2, dom_coords, lambda x: u(x, a, c), name='coll')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M1'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        # [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )
        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator ,  ics_sampler, bcs_sampler, res_sampler, c , mode , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

            print('elapsed: {:.2e}'.format(elapsed))

            print('Relative L2 error_u: {:.2e}'.format(error_u))
            print('Relative L2 error_r: {:.2e}'.format(error_r))

            model.save_NN()
            mode.plt_prediction( t , x , X_star , u_star , u_pred , r_star , r_pred)
            sess.close()  

        print('elapsed: {:.2e}'.format(elapsed))
        print('Relative L2 error_u: {:.2e}'.format(error_u))
        print('Relative L2 error_r: {:.2e}'.format(error_r))

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list,error_r_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_39039/356373291.py:66: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_39039/356373291.py:67: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_39039/356373291.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_39039/356373291.py:68: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /tmp/ipykernel_39039/724299257.py:125: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-12-10 01:23:52.842517: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-10 01:23:52.867644: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-10 01:23:52.871017: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55efad863420 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-10 01:23:52.871048: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-10 01:23:52.872649: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_39039/724299257.py:171: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_39039/724299257.py:173: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_39039/724299257.py:228: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 3.588e+01,  loss_bc1: 5.320e+00,  loss_bc2: 3.413e+00, loss_ics_u: 2.690e+01,  Loss_res: 2.441e-01,  Time: 26.94
# adaptive_constant_res_val: 5.165e-02
# adaptive_constant_ics_val: 1.904e+00
# adaptive_constant_bcs1_val: 1.169e+00
# adaptive_constant_bcs2_val: 1.169e+00
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 2.472e+01,  loss_bc1: 3.347e+00,  loss_bc2: 1.408e+00, loss_ics_u: 1.891e+01,  Loss_res: 1.053e+00,  Time: 17.14
# adaptive_constant_res_val: 1.177e-01
# adaptive_constant_ics_val: 1.342e+00
# adaptive_constant_bcs1_val: 1.146e+00
# adaptive_constant_bcs2_val: 1.146e+00
# It: 300, Loss: 1.995e+01,  loss_bc1: 3.113e+00,  loss_bc2: 1.235e+00, loss_ics_u: 1.474e+01,  Loss_res: 8.653e-01,  Time: 8.68
# adaptive_constant_res_val: 1.385e-01
# adaptive_constant_ics_val: 1.221e+00
# adaptive_constant_bcs1_val: 8.883e-01
# adaptive_constant_bcs2_val: 8.883e-01
# It: 400, Loss: 1.858e+01,  loss_bc1: 2.972e+00,  loss_bc2: 1.243e+00, loss_ics_u: 1.351e+01,  Loss_res: 8.572e-01,  Time: 8.55
# adaptive_constant_res_val: 1.935e-01
# adaptive_constant_ics_val: 9.776e-01
# adaptive_constant_bcs1_val: 8.199e-01
# adaptive_constant_bcs2_val: 8.199e-01
# It: 500, Loss: 1.997e+01,  loss_bc1: 2.512e+00,  loss_bc2: 9.122e-01, loss_ics_u: 1.563e+01,  Loss_res: 9.157e-01,  Time: 8.59
# adaptive_constant_res_val: 1.849e-01
# adaptive_constant_ics_val: 5.614e+00
# adaptive_constant_bcs1_val: 8.456e-01
# adaptive_constant_bcs2_val: 8.456e-01
# It: 600, Loss: 1.625e+01,  loss_bc1: 2.443e+00,  loss_bc2: 1.134e+00, loss_ics_u: 1.199e+01,  Loss_res: 6.859e-01,  Time: 8.49
# adaptive_constant_res_val: 1.747e-01
# adaptive_constant_ics_val: 8.554e-01
# adaptive_constant_bcs1_val: 8.557e-01
# adaptive_constant_bcs2_val: 8.557e-01
# It: 700, Loss: 1.581e+01,  loss_bc1: 2.238e+00,  loss_bc2: 9.679e-01, loss_ics_u: 1.197e+01,  Loss_res: 6.312e-01,  Time: 8.56
# adaptive_constant_res_val: 1.653e-01
# adaptive_constant_ics_val: 1.468e+00
# adaptive_constant_bcs1_val: 8.870e-01
# adaptive_constant_bcs2_val: 8.870e-01
# It: 800, Loss: 1.495e+01,  loss_bc1: 2.052e+00,  loss_bc2: 1.013e+00, loss_ics_u: 1.147e+01,  Loss_res: 4.161e-01,  Time: 8.48
# adaptive_constant_res_val: 1.182e-01
# adaptive_constant_ics_val: 9.375e-01
# adaptive_constant_bcs1_val: 9.239e-01
# adaptive_constant_bcs2_val: 9.239e-01
# It: 900, Loss: 1.474e+01,  loss_bc1: 1.946e+00,  loss_bc2: 9.631e-01, loss_ics_u: 1.140e+01,  Loss_res: 4.272e-01,  Time: 8.45
# adaptive_constant_res_val: 1.032e-01
# adaptive_constant_ics_val: 1.013e+00
# adaptive_constant_bcs1_val: 9.100e-01
# adaptive_constant_bcs2_val: 9.100e-01
# It: 1000, Loss: 1.443e+01,  loss_bc1: 1.962e+00,  loss_bc2: 8.691e-01, loss_ics_u: 1.125e+01,  Loss_res: 3.461e-01,  Time: 8.49
# adaptive_constant_res_val: 1.242e-01
# adaptive_constant_ics_val: 1.066e+00
# adaptive_constant_bcs1_val: 9.443e-01
# adaptive_constant_bcs2_val: 9.443e-01
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 1.504e+01,  loss_bc1: 1.949e+00,  loss_bc2: 7.654e-01, loss_ics_u: 1.187e+01,  Loss_res: 4.572e-01,  Time: 16.68
# adaptive_constant_res_val: 1.470e-01
# adaptive_constant_ics_val: 4.093e+00
# adaptive_constant_bcs1_val: 1.010e+00
# adaptive_constant_bcs2_val: 1.010e+00
# It: 1200, Loss: 1.380e+01,  loss_bc1: 1.786e+00,  loss_bc2: 9.231e-01, loss_ics_u: 1.073e+01,  Loss_res: 3.580e-01,  Time: 8.49
# adaptive_constant_res_val: 1.276e-01
# adaptive_constant_ics_val: 9.021e-01
# adaptive_constant_bcs1_val: 9.936e-01
# adaptive_constant_bcs2_val: 9.936e-01
# It: 1300, Loss: 1.382e+01,  loss_bc1: 1.652e+00,  loss_bc2: 8.744e-01, loss_ics_u: 1.072e+01,  Loss_res: 5.754e-01,  Time: 8.52
# adaptive_constant_res_val: 1.840e-01
# adaptive_constant_ics_val: 1.592e+00
# adaptive_constant_bcs1_val: 9.185e-01
# adaptive_constant_bcs2_val: 9.185e-01
# It: 1400, Loss: 1.328e+01,  loss_bc1: 1.607e+00,  loss_bc2: 8.832e-01, loss_ics_u: 1.032e+01,  Loss_res: 4.751e-01,  Time: 9.11
# adaptive_constant_res_val: 2.037e-01
# adaptive_constant_ics_val: 1.015e+00
# adaptive_constant_bcs1_val: 9.652e-01
# adaptive_constant_bcs2_val: 9.652e-01
# It: 1500, Loss: 1.317e+01,  loss_bc1: 1.574e+00,  loss_bc2: 9.378e-01, loss_ics_u: 1.019e+01,  Loss_res: 4.668e-01,  Time: 9.04
# adaptive_constant_res_val: 1.081e-01
# adaptive_constant_ics_val: 1.308e+00
# adaptive_constant_bcs1_val: 9.457e-01
# adaptive_constant_bcs2_val: 9.457e-01
# It: 1600, Loss: 1.510e+01,  loss_bc1: 1.836e+00,  loss_bc2: 9.557e-01, loss_ics_u: 1.192e+01,  Loss_res: 3.856e-01,  Time: 8.75
# adaptive_constant_res_val: 1.504e-01
# adaptive_constant_ics_val: 7.485e+00
# adaptive_constant_bcs1_val: 1.238e+00
# adaptive_constant_bcs2_val: 1.238e+00
# It: 1700, Loss: 1.244e+01,  loss_bc1: 1.574e+00,  loss_bc2: 8.799e-01, loss_ics_u: 9.611e+00,  Loss_res: 3.733e-01,  Time: 8.77
# adaptive_constant_res_val: 1.893e-01
# adaptive_constant_ics_val: 9.894e-01
# adaptive_constant_bcs1_val: 9.863e-01
# adaptive_constant_bcs2_val: 9.863e-01
# It: 1800, Loss: 1.223e+01,  loss_bc1: 1.483e+00,  loss_bc2: 8.602e-01, loss_ics_u: 9.552e+00,  Loss_res: 3.373e-01,  Time: 8.79
# adaptive_constant_res_val: 1.773e-01
# adaptive_constant_ics_val: 1.249e+00
# adaptive_constant_bcs1_val: 9.704e-01
# adaptive_constant_bcs2_val: 9.704e-01
# It: 1900, Loss: 1.760e+01,  loss_bc1: 1.382e+00,  loss_bc2: 1.129e+00, loss_ics_u: 1.474e+01,  Loss_res: 3.438e-01,  Time: 8.78
# adaptive_constant_res_val: 1.612e-01
# adaptive_constant_ics_val: 1.066e+01
# adaptive_constant_bcs1_val: 1.012e+00
# adaptive_constant_bcs2_val: 1.012e+00
# It: 2000, Loss: 1.177e+01,  loss_bc1: 1.416e+00,  loss_bc2: 8.852e-01, loss_ics_u: 9.237e+00,  Loss_res: 2.333e-01,  Time: 8.70
# adaptive_constant_res_val: 9.299e-02
# adaptive_constant_ics_val: 1.788e+00
# adaptive_constant_bcs1_val: 1.034e+00
# adaptive_constant_bcs2_val: 1.034e+00
# It: 2100, Loss: 1.170e+01,  loss_bc1: 1.457e+00,  loss_bc2: 8.593e-01, loss_ics_u: 9.092e+00,  Loss_res: 2.905e-01,  Time: 8.69
# adaptive_constant_res_val: 1.818e-01
# adaptive_constant_ics_val: 2.342e+00
# adaptive_constant_bcs1_val: 1.108e+00
# adaptive_constant_bcs2_val: 1.108e+00
# It: 2200, Loss: 1.114e+01,  loss_bc1: 1.222e+00,  loss_bc2: 8.191e-01, loss_ics_u: 8.780e+00,  Loss_res: 3.167e-01,  Time: 8.73
# adaptive_constant_res_val: 2.065e-01
# adaptive_constant_ics_val: 1.112e+00
# adaptive_constant_bcs1_val: 9.978e-01
# adaptive_constant_bcs2_val: 9.978e-01
# It: 2300, Loss: 1.126e+01,  loss_bc1: 1.185e+00,  loss_bc2: 7.843e-01, loss_ics_u: 8.906e+00,  Loss_res: 3.809e-01,  Time: 8.79
# adaptive_constant_res_val: 2.818e-01
# adaptive_constant_ics_val: 2.876e+00
# adaptive_constant_bcs1_val: 9.510e-01
# adaptive_constant_bcs2_val: 9.510e-01
# It: 2400, Loss: 1.134e+01,  loss_bc1: 1.542e+00,  loss_bc2: 7.187e-01, loss_ics_u: 8.775e+00,  Loss_res: 3.068e-01,  Time: 8.75
# adaptive_constant_res_val: 2.141e-01
# adaptive_constant_ics_val: 2.779e+00
# adaptive_constant_bcs1_val: 1.463e+00
# adaptive_constant_bcs2_val: 1.463e+00
# It: 2500, Loss: 1.137e+01,  loss_bc1: 9.877e-01,  loss_bc2: 6.712e-01, loss_ics_u: 9.392e+00,  Loss_res: 3.185e-01,  Time: 8.88
# adaptive_constant_res_val: 1.789e-01
# adaptive_constant_ics_val: 4.773e+00
# adaptive_constant_bcs1_val: 1.070e+00
# adaptive_constant_bcs2_val: 1.070e+00
# It: 2600, Loss: 9.901e+00,  loss_bc1: 9.860e-01,  loss_bc2: 5.845e-01, loss_ics_u: 8.181e+00,  Loss_res: 1.499e-01,  Time: 8.68
# adaptive_constant_res_val: 1.099e-01
# adaptive_constant_ics_val: 1.718e+00
# adaptive_constant_bcs1_val: 9.895e-01
# adaptive_constant_bcs2_val: 9.895e-01
# It: 2700, Loss: 1.009e+01,  loss_bc1: 7.828e-01,  loss_bc2: 5.610e-01, loss_ics_u: 8.471e+00,  Loss_res: 2.713e-01,  Time: 8.78
# adaptive_constant_res_val: 2.343e-01
# adaptive_constant_ics_val: 3.641e+00
# adaptive_constant_bcs1_val: 8.180e-01
# adaptive_constant_bcs2_val: 8.180e-01
# It: 2800, Loss: 9.327e+00,  loss_bc1: 7.407e-01,  loss_bc2: 4.236e-01, loss_ics_u: 7.956e+00,  Loss_res: 2.063e-01,  Time: 8.78
# adaptive_constant_res_val: 2.012e-01
# adaptive_constant_ics_val: 1.343e+00
# adaptive_constant_bcs1_val: 7.161e-01
# adaptive_constant_bcs2_val: 7.161e-01
# It: 2900, Loss: 9.332e+00,  loss_bc1: 6.922e-01,  loss_bc2: 4.238e-01, loss_ics_u: 8.016e+00,  Loss_res: 1.999e-01,  Time: 8.77
# adaptive_constant_res_val: 1.447e-01
# adaptive_constant_ics_val: 3.388e+00
# adaptive_constant_bcs1_val: 8.770e-01
# adaptive_constant_bcs2_val: 8.770e-01
# It: 3000, Loss: 8.789e+00,  loss_bc1: 6.622e-01,  loss_bc2: 3.614e-01, loss_ics_u: 7.625e+00,  Loss_res: 1.406e-01,  Time: 8.68
# adaptive_constant_res_val: 1.560e-01
# adaptive_constant_ics_val: 1.815e+00
# adaptive_constant_bcs1_val: 6.382e-01
# adaptive_constant_bcs2_val: 6.382e-01
# It: 3100, Loss: 8.689e+00,  loss_bc1: 6.547e-01,  loss_bc2: 3.832e-01, loss_ics_u: 7.512e+00,  Loss_res: 1.390e-01,  Time: 8.81
# adaptive_constant_res_val: 8.290e-02
# adaptive_constant_ics_val: 6.187e-01
# adaptive_constant_bcs1_val: 7.798e-01
# adaptive_constant_bcs2_val: 7.798e-01
# It: 3200, Loss: 8.951e+00,  loss_bc1: 5.598e-01,  loss_bc2: 4.009e-01, loss_ics_u: 7.771e+00,  Loss_res: 2.185e-01,  Time: 8.79
# adaptive_constant_res_val: 1.264e-01
# adaptive_constant_ics_val: 3.494e+00
# adaptive_constant_bcs1_val: 7.391e-01
# adaptive_constant_bcs2_val: 7.391e-01
# It: 3300, Loss: 8.662e+00,  loss_bc1: 5.954e-01,  loss_bc2: 3.525e-01, loss_ics_u: 7.482e+00,  Loss_res: 2.323e-01,  Time: 8.77
# adaptive_constant_res_val: 1.155e-01
# adaptive_constant_ics_val: 1.893e+00
# adaptive_constant_bcs1_val: 7.412e-01
# adaptive_constant_bcs2_val: 7.412e-01
# It: 3400, Loss: 8.292e+00,  loss_bc1: 5.785e-01,  loss_bc2: 3.521e-01, loss_ics_u: 7.191e+00,  Loss_res: 1.705e-01,  Time: 8.77
# adaptive_constant_res_val: 1.134e-01
# adaptive_constant_ics_val: 8.349e-01
# adaptive_constant_bcs1_val: 7.113e-01
# adaptive_constant_bcs2_val: 7.113e-01
# It: 3500, Loss: 8.825e+00,  loss_bc1: 5.763e-01,  loss_bc2: 3.855e-01, loss_ics_u: 7.693e+00,  Loss_res: 1.700e-01,  Time: 8.89
# adaptive_constant_res_val: 2.407e-01
# adaptive_constant_ics_val: 4.882e+00
# adaptive_constant_bcs1_val: 7.860e-01
# adaptive_constant_bcs2_val: 7.860e-01
# It: 3600, Loss: 8.293e+00,  loss_bc1: 5.640e-01,  loss_bc2: 3.250e-01, loss_ics_u: 7.168e+00,  Loss_res: 2.359e-01,  Time: 10.00
# adaptive_constant_res_val: 2.286e-01
# adaptive_constant_ics_val: 2.181e+00
# adaptive_constant_bcs1_val: 6.370e-01
# adaptive_constant_bcs2_val: 6.370e-01
# It: 3700, Loss: 8.218e+00,  loss_bc1: 5.468e-01,  loss_bc2: 2.882e-01, loss_ics_u: 7.085e+00,  Loss_res: 2.989e-01,  Time: 11.07
# adaptive_constant_res_val: 3.348e-01
# adaptive_constant_ics_val: 1.114e+00
# adaptive_constant_bcs1_val: 4.107e-01
# adaptive_constant_bcs2_val: 4.107e-01
# It: 3800, Loss: 8.647e+00,  loss_bc1: 5.891e-01,  loss_bc2: 2.629e-01, loss_ics_u: 7.515e+00,  Loss_res: 2.801e-01,  Time: 8.88
# adaptive_constant_res_val: 2.785e-01
# adaptive_constant_ics_val: 4.712e+00
# adaptive_constant_bcs1_val: 5.657e-01
# adaptive_constant_bcs2_val: 5.657e-01
# It: 3900, Loss: 8.446e+00,  loss_bc1: 5.543e-01,  loss_bc2: 3.157e-01, loss_ics_u: 7.413e+00,  Loss_res: 1.631e-01,  Time: 11.36
# adaptive_constant_res_val: 1.806e-01
# adaptive_constant_ics_val: 5.733e+00
# adaptive_constant_bcs1_val: 5.487e-01
# adaptive_constant_bcs2_val: 5.487e-01
# It: 4000, Loss: 1.132e+01,  loss_bc1: 5.817e-01,  loss_bc2: 4.391e-01, loss_ics_u: 9.949e+00,  Loss_res: 3.492e-01,  Time: 12.55
# adaptive_constant_res_val: 6.387e-01
# adaptive_constant_ics_val: 1.235e+01
# adaptive_constant_bcs1_val: 5.398e-01
# adaptive_constant_bcs2_val: 5.398e-01
# It: 4100, Loss: 1.123e+01,  loss_bc1: 6.267e-01,  loss_bc2: 4.126e-01, loss_ics_u: 9.776e+00,  Loss_res: 4.108e-01,  Time: 16.86
# adaptive_constant_res_val: 7.087e-01
# adaptive_constant_ics_val: 1.207e+01
# adaptive_constant_bcs1_val: 7.288e-01
# adaptive_constant_bcs2_val: 7.288e-01
# It: 4200, Loss: 7.769e+00,  loss_bc1: 6.279e-01,  loss_bc2: 3.298e-01, loss_ics_u: 6.545e+00,  Loss_res: 2.666e-01,  Time: 9.37
# adaptive_constant_res_val: 4.547e-01
# adaptive_constant_ics_val: 2.788e+00
# adaptive_constant_bcs1_val: 6.008e-01
# adaptive_constant_bcs2_val: 6.008e-01
# It: 4300, Loss: 8.846e+00,  loss_bc1: 7.607e-01,  loss_bc2: 3.477e-01, loss_ics_u: 7.448e+00,  Loss_res: 2.894e-01,  Time: 10.22
# adaptive_constant_res_val: 4.069e-01
# adaptive_constant_ics_val: 8.033e+00
# adaptive_constant_bcs1_val: 1.319e+00
# adaptive_constant_bcs2_val: 1.319e+00
# It: 4400, Loss: 7.779e+00,  loss_bc1: 6.753e-01,  loss_bc2: 2.974e-01, loss_ics_u: 6.362e+00,  Loss_res: 4.440e-01,  Time: 14.31
# adaptive_constant_res_val: 7.859e-01
# adaptive_constant_ics_val: 4.398e+00
# adaptive_constant_bcs1_val: 6.925e-01
# adaptive_constant_bcs2_val: 6.925e-01
# It: 4500, Loss: 1.094e+01,  loss_bc1: 5.669e-01,  loss_bc2: 3.056e-01, loss_ics_u: 9.801e+00,  Loss_res: 2.694e-01,  Time: 18.56
# adaptive_constant_res_val: 8.417e-01
# adaptive_constant_ics_val: 1.594e+01
# adaptive_constant_bcs1_val: 4.621e-01
# adaptive_constant_bcs2_val: 4.621e-01
# It: 4600, Loss: 2.513e+01,  loss_bc1: 1.030e+00,  loss_bc2: 9.018e-01, loss_ics_u: 2.151e+01,  Loss_res: 1.683e+00,  Time: 13.36
# adaptive_constant_res_val: 2.750e+00
# adaptive_constant_ics_val: 3.017e+01
# adaptive_constant_bcs1_val: 1.412e+00
# adaptive_constant_bcs2_val: 1.412e+00
# It: 4700, Loss: 1.054e+01,  loss_bc1: 6.519e-01,  loss_bc2: 2.971e-01, loss_ics_u: 9.133e+00,  Loss_res: 4.575e-01,  Time: 10.72
# adaptive_constant_res_val: 3.192e-01
# adaptive_constant_ics_val: 1.702e+01
# adaptive_constant_bcs1_val: 8.888e-01
# adaptive_constant_bcs2_val: 8.888e-01
# It: 4800, Loss: 6.499e+00,  loss_bc1: 5.759e-01,  loss_bc2: 3.336e-01, loss_ics_u: 5.293e+00,  Loss_res: 2.967e-01,  Time: 13.30
# adaptive_constant_res_val: 6.977e-01
# adaptive_constant_ics_val: 3.326e+00
# adaptive_constant_bcs1_val: 7.442e-01
# adaptive_constant_bcs2_val: 7.442e-01
# It: 4900, Loss: 5.888e+00,  loss_bc1: 5.078e-01,  loss_bc2: 3.354e-01, loss_ics_u: 4.774e+00,  Loss_res: 2.703e-01,  Time: 9.50
# adaptive_constant_res_val: 3.649e-01
# adaptive_constant_ics_val: 1.145e+00
# adaptive_constant_bcs1_val: 3.663e-01
# adaptive_constant_bcs2_val: 3.663e-01
# It: 5000, Loss: 8.347e+00,  loss_bc1: 5.974e-01,  loss_bc2: 3.187e-01, loss_ics_u: 7.162e+00,  Loss_res: 2.696e-01,  Time: 9.51
# adaptive_constant_res_val: 2.221e-01
# adaptive_constant_ics_val: 1.473e+01
# adaptive_constant_bcs1_val: 4.916e-01
# adaptive_constant_bcs2_val: 4.916e-01
# It: 5100, Loss: 7.731e+00,  loss_bc1: 5.919e-01,  loss_bc2: 4.327e-01, loss_ics_u: 6.338e+00,  Loss_res: 3.684e-01,  Time: 9.46
# adaptive_constant_res_val: 7.380e-01
# adaptive_constant_ics_val: 1.343e+01
# adaptive_constant_bcs1_val: 5.968e-01
# adaptive_constant_bcs2_val: 5.968e-01
# It: 5200, Loss: 5.591e+00,  loss_bc1: 5.264e-01,  loss_bc2: 3.465e-01, loss_ics_u: 4.497e+00,  Loss_res: 2.206e-01,  Time: 9.47
# adaptive_constant_res_val: 1.643e-01
# adaptive_constant_ics_val: 2.490e+00
# adaptive_constant_bcs1_val: 4.703e-01
# adaptive_constant_bcs2_val: 4.703e-01
# It: 5300, Loss: 7.355e+00,  loss_bc1: 7.937e-01,  loss_bc2: 3.245e-01, loss_ics_u: 5.881e+00,  Loss_res: 3.556e-01,  Time: 9.59
# adaptive_constant_res_val: 3.118e-01
# adaptive_constant_ics_val: 1.204e+01
# adaptive_constant_bcs1_val: 1.390e+00
# adaptive_constant_bcs2_val: 1.390e+00
# It: 5400, Loss: 5.297e+00,  loss_bc1: 5.718e-01,  loss_bc2: 3.119e-01, loss_ics_u: 4.016e+00,  Loss_res: 3.972e-01,  Time: 9.06
# adaptive_constant_res_val: 5.618e-01
# adaptive_constant_ics_val: 1.660e+00
# adaptive_constant_bcs1_val: 5.384e-01
# adaptive_constant_bcs2_val: 5.384e-01
# It: 5500, Loss: 8.015e+00,  loss_bc1: 5.534e-01,  loss_bc2: 4.110e-01, loss_ics_u: 6.751e+00,  Loss_res: 3.001e-01,  Time: 8.76
# adaptive_constant_res_val: 2.677e-01
# adaptive_constant_ics_val: 1.926e+01
# adaptive_constant_bcs1_val: 8.368e-01
# adaptive_constant_bcs2_val: 8.368e-01
# It: 5600, Loss: 5.374e+00,  loss_bc1: 5.650e-01,  loss_bc2: 3.076e-01, loss_ics_u: 4.194e+00,  Loss_res: 3.078e-01,  Time: 8.92
# adaptive_constant_res_val: 3.912e-01
# adaptive_constant_ics_val: 6.792e+00
# adaptive_constant_bcs1_val: 6.941e-01
# adaptive_constant_bcs2_val: 6.941e-01
# It: 5700, Loss: 4.813e+00,  loss_bc1: 5.253e-01,  loss_bc2: 2.860e-01, loss_ics_u: 3.608e+00,  Loss_res: 3.934e-01,  Time: 8.59
# adaptive_constant_res_val: 6.120e-01
# adaptive_constant_ics_val: 2.680e+00
# adaptive_constant_bcs1_val: 3.748e-01
# adaptive_constant_bcs2_val: 3.748e-01
# It: 5800, Loss: 4.689e+00,  loss_bc1: 5.551e-01,  loss_bc2: 3.301e-01, loss_ics_u: 3.509e+00,  Loss_res: 2.947e-01,  Time: 8.53
# adaptive_constant_res_val: 5.055e-01
# adaptive_constant_ics_val: 5.957e+00
# adaptive_constant_bcs1_val: 4.963e-01
# adaptive_constant_bcs2_val: 4.963e-01
# It: 5900, Loss: 4.838e+00,  loss_bc1: 5.085e-01,  loss_bc2: 3.180e-01, loss_ics_u: 3.834e+00,  Loss_res: 1.772e-01,  Time: 8.76
# adaptive_constant_res_val: 2.835e-01
# adaptive_constant_ics_val: 1.056e+01
# adaptive_constant_bcs1_val: 3.316e-01
# adaptive_constant_bcs2_val: 3.316e-01
# It: 6000, Loss: 4.296e+00,  loss_bc1: 5.529e-01,  loss_bc2: 3.193e-01, loss_ics_u: 3.065e+00,  Loss_res: 3.583e-01,  Time: 8.80
# adaptive_constant_res_val: 7.293e-01
# adaptive_constant_ics_val: 3.927e+00
# adaptive_constant_bcs1_val: 7.533e-01
# adaptive_constant_bcs2_val: 7.533e-01
# It: 6100, Loss: 4.063e+00,  loss_bc1: 5.284e-01,  loss_bc2: 2.889e-01, loss_ics_u: 3.100e+00,  Loss_res: 1.460e-01,  Time: 9.07
# adaptive_constant_res_val: 4.404e-01
# adaptive_constant_ics_val: 6.108e+00
# adaptive_constant_bcs1_val: 3.544e-01
# adaptive_constant_bcs2_val: 3.544e-01
# It: 6200, Loss: 5.272e+00,  loss_bc1: 5.401e-01,  loss_bc2: 2.783e-01, loss_ics_u: 4.003e+00,  Loss_res: 4.510e-01,  Time: 9.05
# adaptive_constant_res_val: 8.726e-01
# adaptive_constant_ics_val: 1.445e+01
# adaptive_constant_bcs1_val: 5.565e-01
# adaptive_constant_bcs2_val: 5.565e-01
# It: 6300, Loss: 3.942e+00,  loss_bc1: 5.268e-01,  loss_bc2: 3.026e-01, loss_ics_u: 2.878e+00,  Loss_res: 2.346e-01,  Time: 8.82
# adaptive_constant_res_val: 3.078e-01
# adaptive_constant_ics_val: 3.760e+00
# adaptive_constant_bcs1_val: 5.203e-01
# adaptive_constant_bcs2_val: 5.203e-01
# It: 6400, Loss: 3.646e+00,  loss_bc1: 5.214e-01,  loss_bc2: 2.974e-01, loss_ics_u: 2.538e+00,  Loss_res: 2.894e-01,  Time: 8.65
# adaptive_constant_res_val: 5.162e-01
# adaptive_constant_ics_val: 2.243e+00
# adaptive_constant_bcs1_val: 4.478e-01
# adaptive_constant_bcs2_val: 4.478e-01
# It: 6500, Loss: 4.507e+00,  loss_bc1: 5.405e-01,  loss_bc2: 3.184e-01, loss_ics_u: 3.312e+00,  Loss_res: 3.359e-01,  Time: 8.59
# adaptive_constant_res_val: 9.244e-01
# adaptive_constant_ics_val: 9.203e+00
# adaptive_constant_bcs1_val: 3.354e-01
# adaptive_constant_bcs2_val: 3.354e-01
# It: 6600, Loss: 4.111e+00,  loss_bc1: 5.495e-01,  loss_bc2: 3.667e-01, loss_ics_u: 2.886e+00,  Loss_res: 3.090e-01,  Time: 8.63
# adaptive_constant_res_val: 5.472e-01
# adaptive_constant_ics_val: 5.168e+00
# adaptive_constant_bcs1_val: 4.881e-01
# adaptive_constant_bcs2_val: 4.881e-01
# It: 6700, Loss: 3.631e+00,  loss_bc1: 5.204e-01,  loss_bc2: 2.980e-01, loss_ics_u: 2.622e+00,  Loss_res: 1.900e-01,  Time: 8.67
# adaptive_constant_res_val: 3.389e-01
# adaptive_constant_ics_val: 9.343e+00
# adaptive_constant_bcs1_val: 3.036e-01
# adaptive_constant_bcs2_val: 3.036e-01
# It: 6800, Loss: 3.620e+00,  loss_bc1: 5.049e-01,  loss_bc2: 2.630e-01, loss_ics_u: 2.681e+00,  Loss_res: 1.709e-01,  Time: 8.66
# adaptive_constant_res_val: 4.826e-01
# adaptive_constant_ics_val: 8.663e+00
# adaptive_constant_bcs1_val: 2.958e-01
# adaptive_constant_bcs2_val: 2.958e-01
# It: 6900, Loss: 4.271e+00,  loss_bc1: 5.588e-01,  loss_bc2: 2.646e-01, loss_ics_u: 3.302e+00,  Loss_res: 1.463e-01,  Time: 8.73
# adaptive_constant_res_val: 5.433e-01
# adaptive_constant_ics_val: 1.568e+01
# adaptive_constant_bcs1_val: 4.085e-01
# adaptive_constant_bcs2_val: 4.085e-01
# It: 7000, Loss: 2.051e+01,  loss_bc1: 6.137e-01,  loss_bc2: 3.776e-01, loss_ics_u: 1.876e+01,  Loss_res: 7.653e-01,  Time: 8.67
# adaptive_constant_res_val: 1.520e+00
# adaptive_constant_ics_val: 6.609e+01
# adaptive_constant_bcs1_val: 6.827e-01
# adaptive_constant_bcs2_val: 6.827e-01
# It: 7100, Loss: 4.038e+00,  loss_bc1: 5.535e-01,  loss_bc2: 2.907e-01, loss_ics_u: 3.010e+00,  Loss_res: 1.844e-01,  Time: 8.65
# adaptive_constant_res_val: 6.400e-01
# adaptive_constant_ics_val: 1.644e+01
# adaptive_constant_bcs1_val: 4.086e-01
# adaptive_constant_bcs2_val: 4.086e-01
# It: 7200, Loss: 2.907e+00,  loss_bc1: 5.163e-01,  loss_bc2: 3.014e-01, loss_ics_u: 1.873e+00,  Loss_res: 2.166e-01,  Time: 8.62
# adaptive_constant_res_val: 2.260e-01
# adaptive_constant_ics_val: 2.087e+00
# adaptive_constant_bcs1_val: 3.752e-01
# adaptive_constant_bcs2_val: 3.752e-01
# It: 7300, Loss: 5.598e+00,  loss_bc1: 6.999e-01,  loss_bc2: 3.053e-01, loss_ics_u: 4.163e+00,  Loss_res: 4.304e-01,  Time: 8.62
# adaptive_constant_res_val: 7.074e-01
# adaptive_constant_ics_val: 2.182e+01
# adaptive_constant_bcs1_val: 1.105e+00
# adaptive_constant_bcs2_val: 1.105e+00
# It: 7400, Loss: 2.744e+00,  loss_bc1: 5.482e-01,  loss_bc2: 2.886e-01, loss_ics_u: 1.741e+00,  Loss_res: 1.665e-01,  Time: 8.71
# adaptive_constant_res_val: 3.598e-01
# adaptive_constant_ics_val: 2.502e+00
# adaptive_constant_bcs1_val: 5.340e-01
# adaptive_constant_bcs2_val: 5.340e-01
# It: 7500, Loss: 3.603e+00,  loss_bc1: 5.219e-01,  loss_bc2: 2.962e-01, loss_ics_u: 2.547e+00,  Loss_res: 2.378e-01,  Time: 8.65
# adaptive_constant_res_val: 3.647e-01
# adaptive_constant_ics_val: 1.651e+01
# adaptive_constant_bcs1_val: 3.337e-01
# adaptive_constant_bcs2_val: 3.337e-01
# It: 7600, Loss: 3.817e+00,  loss_bc1: 5.649e-01,  loss_bc2: 3.325e-01, loss_ics_u: 2.709e+00,  Loss_res: 2.105e-01,  Time: 8.73
# adaptive_constant_res_val: 8.332e-01
# adaptive_constant_ics_val: 1.595e+01
# adaptive_constant_bcs1_val: 2.927e-01
# adaptive_constant_bcs2_val: 2.927e-01
# It: 7700, Loss: 2.573e+00,  loss_bc1: 5.651e-01,  loss_bc2: 2.944e-01, loss_ics_u: 1.578e+00,  Loss_res: 1.352e-01,  Time: 8.63
# adaptive_constant_res_val: 2.483e-01
# adaptive_constant_ics_val: 1.293e+00
# adaptive_constant_bcs1_val: 6.726e-01
# adaptive_constant_bcs2_val: 6.726e-01
# It: 7800, Loss: 2.501e+00,  loss_bc1: 5.395e-01,  loss_bc2: 3.046e-01, loss_ics_u: 1.533e+00,  Loss_res: 1.242e-01,  Time: 8.77
# adaptive_constant_res_val: 3.870e-01
# adaptive_constant_ics_val: 2.018e+00
# adaptive_constant_bcs1_val: 3.871e-01
# adaptive_constant_bcs2_val: 3.871e-01
# It: 7900, Loss: 2.521e+00,  loss_bc1: 5.215e-01,  loss_bc2: 2.980e-01, loss_ics_u: 1.531e+00,  Loss_res: 1.699e-01,  Time: 8.62
# adaptive_constant_res_val: 8.596e-01
# adaptive_constant_ics_val: 2.550e+00
# adaptive_constant_bcs1_val: 2.958e-01
# adaptive_constant_bcs2_val: 2.958e-01
# It: 8000, Loss: 2.396e+00,  loss_bc1: 5.408e-01,  loss_bc2: 3.111e-01, loss_ics_u: 1.422e+00,  Loss_res: 1.214e-01,  Time: 8.61
# adaptive_constant_res_val: 5.881e-01
# adaptive_constant_ics_val: 1.545e+00
# adaptive_constant_bcs1_val: 3.223e-01
# adaptive_constant_bcs2_val: 3.223e-01
# It: 8100, Loss: 2.432e+00,  loss_bc1: 5.215e-01,  loss_bc2: 2.932e-01, loss_ics_u: 1.435e+00,  Loss_res: 1.823e-01,  Time: 8.66
# adaptive_constant_res_val: 8.254e-01
# adaptive_constant_ics_val: 2.565e+00
# adaptive_constant_bcs1_val: 3.192e-01
# adaptive_constant_bcs2_val: 3.192e-01
# It: 8200, Loss: 2.633e+00,  loss_bc1: 5.447e-01,  loss_bc2: 2.993e-01, loss_ics_u: 1.616e+00,  Loss_res: 1.725e-01,  Time: 8.65
# adaptive_constant_res_val: 5.469e-01
# adaptive_constant_ics_val: 8.164e+00
# adaptive_constant_bcs1_val: 3.676e-01
# adaptive_constant_bcs2_val: 3.676e-01
# It: 8300, Loss: 2.663e+00,  loss_bc1: 5.217e-01,  loss_bc2: 3.003e-01, loss_ics_u: 1.660e+00,  Loss_res: 1.803e-01,  Time: 8.80
# adaptive_constant_res_val: 6.795e-01
# adaptive_constant_ics_val: 1.245e+01
# adaptive_constant_bcs1_val: 2.618e-01
# adaptive_constant_bcs2_val: 2.618e-01
# It: 8400, Loss: 2.199e+00,  loss_bc1: 5.368e-01,  loss_bc2: 2.990e-01, loss_ics_u: 1.193e+00,  Loss_res: 1.699e-01,  Time: 8.70
# adaptive_constant_res_val: 6.487e-01
# adaptive_constant_ics_val: 1.018e+00
# adaptive_constant_bcs1_val: 2.520e-01
# adaptive_constant_bcs2_val: 2.520e-01
# It: 8500, Loss: 2.191e+00,  loss_bc1: 5.468e-01,  loss_bc2: 3.048e-01, loss_ics_u: 1.181e+00,  Loss_res: 1.580e-01,  Time: 8.67
# adaptive_constant_res_val: 3.446e-01
# adaptive_constant_ics_val: 4.236e+00
# adaptive_constant_bcs1_val: 4.642e-01
# adaptive_constant_bcs2_val: 4.642e-01
# It: 8600, Loss: 2.038e+00,  loss_bc1: 5.449e-01,  loss_bc2: 3.012e-01, loss_ics_u: 1.086e+00,  Loss_res: 1.063e-01,  Time: 8.62
# adaptive_constant_res_val: 4.451e-01
# adaptive_constant_ics_val: 8.382e-01
# adaptive_constant_bcs1_val: 2.982e-01
# adaptive_constant_bcs2_val: 2.982e-01
# It: 8700, Loss: 3.611e+00,  loss_bc1: 5.639e-01,  loss_bc2: 2.981e-01, loss_ics_u: 2.464e+00,  Loss_res: 2.849e-01,  Time: 8.62
# adaptive_constant_res_val: 1.313e+00
# adaptive_constant_ics_val: 2.495e+01
# adaptive_constant_bcs1_val: 3.725e-01
# adaptive_constant_bcs2_val: 3.725e-01
# It: 8800, Loss: 2.764e+00,  loss_bc1: 5.371e-01,  loss_bc2: 3.083e-01, loss_ics_u: 1.793e+00,  Loss_res: 1.255e-01,  Time: 8.64
# adaptive_constant_res_val: 3.362e-01
# adaptive_constant_ics_val: 1.907e+01
# adaptive_constant_bcs1_val: 2.203e-01
# adaptive_constant_bcs2_val: 2.203e-01
# It: 8900, Loss: 2.230e+00,  loss_bc1: 5.452e-01,  loss_bc2: 3.160e-01, loss_ics_u: 1.200e+00,  Loss_res: 1.693e-01,  Time: 8.65
# adaptive_constant_res_val: 1.536e+00
# adaptive_constant_ics_val: 4.035e+00
# adaptive_constant_bcs1_val: 4.967e-01
# adaptive_constant_bcs2_val: 4.967e-01
# It: 9000, Loss: 2.026e+00,  loss_bc1: 5.283e-01,  loss_bc2: 3.155e-01, loss_ics_u: 1.029e+00,  Loss_res: 1.535e-01,  Time: 8.75
# adaptive_constant_res_val: 4.224e-01
# adaptive_constant_ics_val: 5.077e+00
# adaptive_constant_bcs1_val: 2.591e-01
# adaptive_constant_bcs2_val: 2.591e-01
# It: 9100, Loss: 3.050e+00,  loss_bc1: 5.435e-01,  loss_bc2: 3.192e-01, loss_ics_u: 1.855e+00,  Loss_res: 3.322e-01,  Time: 8.53
# adaptive_constant_res_val: 1.548e+00
# adaptive_constant_ics_val: 7.773e+00
# adaptive_constant_bcs1_val: 4.630e-01
# adaptive_constant_bcs2_val: 4.630e-01
# It: 9200, Loss: 5.529e+00,  loss_bc1: 5.692e-01,  loss_bc2: 3.353e-01, loss_ics_u: 4.342e+00,  Loss_res: 2.821e-01,  Time: 8.66
# adaptive_constant_res_val: 1.931e+00
# adaptive_constant_ics_val: 3.720e+01
# adaptive_constant_bcs1_val: 7.284e-01
# adaptive_constant_bcs2_val: 7.284e-01
# It: 9300, Loss: 1.917e+00,  loss_bc1: 5.327e-01,  loss_bc2: 3.145e-01, loss_ics_u: 9.537e-01,  Loss_res: 1.161e-01,  Time: 8.63
# adaptive_constant_res_val: 1.441e-01
# adaptive_constant_ics_val: 6.352e+00
# adaptive_constant_bcs1_val: 2.712e-01
# adaptive_constant_bcs2_val: 2.712e-01
# It: 9400, Loss: 2.007e+00,  loss_bc1: 5.308e-01,  loss_bc2: 3.081e-01, loss_ics_u: 1.036e+00,  Loss_res: 1.327e-01,  Time: 8.66
# adaptive_constant_res_val: 5.811e-01
# adaptive_constant_ics_val: 8.387e+00
# adaptive_constant_bcs1_val: 2.821e-01
# adaptive_constant_bcs2_val: 2.821e-01
# It: 9500, Loss: 3.410e+00,  loss_bc1: 5.355e-01,  loss_bc2: 3.369e-01, loss_ics_u: 2.039e+00,  Loss_res: 4.987e-01,  Time: 8.59
# adaptive_constant_res_val: 2.635e+00
# adaptive_constant_ics_val: 1.783e+01
# adaptive_constant_bcs1_val: 5.275e-01
# adaptive_constant_bcs2_val: 5.275e-01
# It: 9600, Loss: 1.915e+00,  loss_bc1: 5.305e-01,  loss_bc2: 3.142e-01, loss_ics_u: 8.192e-01,  Loss_res: 2.510e-01,  Time: 8.63
# adaptive_constant_res_val: 1.155e+00
# adaptive_constant_ics_val: 2.185e+00
# adaptive_constant_bcs1_val: 2.118e-01
# adaptive_constant_bcs2_val: 2.118e-01
# It: 9700, Loss: 3.005e+00,  loss_bc1: 5.603e-01,  loss_bc2: 3.043e-01, loss_ics_u: 1.452e+00,  Loss_res: 6.882e-01,  Time: 8.73
# adaptive_constant_res_val: 3.075e+00
# adaptive_constant_ics_val: 1.329e+01
# adaptive_constant_bcs1_val: 6.509e-01
# adaptive_constant_bcs2_val: 6.509e-01
# ...
# adaptive_constant_res_val: 5.389e-01
# adaptive_constant_ics_val: 4.528e+00
# adaptive_constant_bcs1_val: 3.647e-02
# adaptive_constant_bcs2_val: 3.647e-02
# It: 34100, Loss: 6.087e-02,  loss_bc1: 1.403e-02,  loss_bc2: 7.624e-03, loss_ics_u: 1.525e-02,  Loss_res: 2.397e-02,  Time: 3.90
# adaptive_constant_res_val: 1.176e+00
# adaptive_constant_ics_val: 1.461e+00
# adaptive_constant_bcs1_val: 3.875e-02
# adaptive_constant_bcs2_val: 3.875e-02
# It: 34200, Loss: 4.894e-02,  loss_bc1: 1.341e-02,  loss_bc2: 7.115e-03, loss_ics_u: 1.166e-02,  Loss_res: 1.676e-02,  Time: 3.89
# adaptive_constant_res_val: 5.352e-01
# adaptive_constant_ics_val: 3.636e-01
# adaptive_constant_bcs1_val: 1.976e-02
# adaptive_constant_bcs2_val: 1.976e-02
# It: 34300, Loss: 5.693e-02,  loss_bc1: 1.354e-02,  loss_bc2: 7.050e-03, loss_ics_u: 1.369e-02,  Loss_res: 2.266e-02,  Time: 3.85
# adaptive_constant_res_val: 6.825e-01
# adaptive_constant_ics_val: 1.587e+00
# adaptive_constant_bcs1_val: 2.523e-02
# adaptive_constant_bcs2_val: 2.523e-02
# It: 34400, Loss: 4.984e-02,  loss_bc1: 1.351e-02,  loss_bc2: 7.240e-03, loss_ics_u: 1.270e-02,  Loss_res: 1.638e-02,  Time: 3.94
# adaptive_constant_res_val: 4.950e-01
# adaptive_constant_ics_val: 6.318e-01
# adaptive_constant_bcs1_val: 2.169e-02
# adaptive_constant_bcs2_val: 2.169e-02
# It: 34500, Loss: 6.546e-02,  loss_bc1: 1.352e-02,  loss_bc2: 7.123e-03, loss_ics_u: 1.494e-02,  Loss_res: 2.986e-02,  Time: 3.87
# adaptive_constant_res_val: 1.097e+00
# adaptive_constant_ics_val: 1.841e+00
# adaptive_constant_bcs1_val: 1.001e-02
# adaptive_constant_bcs2_val: 1.001e-02
# It: 34600, Loss: 5.349e-02,  loss_bc1: 1.329e-02,  loss_bc2: 7.221e-03, loss_ics_u: 1.184e-02,  Loss_res: 2.114e-02,  Time: 3.89
# adaptive_constant_res_val: 8.162e-01
# adaptive_constant_ics_val: 5.187e-01
# adaptive_constant_bcs1_val: 2.095e-02
# adaptive_constant_bcs2_val: 2.095e-02
# It: 34700, Loss: 5.188e-02,  loss_bc1: 1.336e-02,  loss_bc2: 7.071e-03, loss_ics_u: 1.251e-02,  Loss_res: 1.894e-02,  Time: 4.03
# adaptive_constant_res_val: 8.004e-01
# adaptive_constant_ics_val: 1.094e+00
# adaptive_constant_bcs1_val: 2.344e-02
# adaptive_constant_bcs2_val: 2.344e-02
# It: 34800, Loss: 6.265e-02,  loss_bc1: 1.330e-02,  loss_bc2: 6.985e-03, loss_ics_u: 2.054e-02,  Loss_res: 2.182e-02,  Time: 4.02
# adaptive_constant_res_val: 3.630e-01
# adaptive_constant_ics_val: 2.891e+00
# adaptive_constant_bcs1_val: 1.282e-02
# adaptive_constant_bcs2_val: 1.282e-02
# It: 34900, Loss: 5.189e-02,  loss_bc1: 1.318e-02,  loss_bc2: 6.699e-03, loss_ics_u: 1.488e-02,  Loss_res: 1.714e-02,  Time: 4.35
# adaptive_constant_res_val: 2.057e-01
# adaptive_constant_ics_val: 1.673e+00
# adaptive_constant_bcs1_val: 1.650e-02
# adaptive_constant_bcs2_val: 1.650e-02
# It: 35000, Loss: 5.544e-02,  loss_bc1: 1.331e-02,  loss_bc2: 7.102e-03, loss_ics_u: 1.528e-02,  Loss_res: 1.975e-02,  Time: 4.23
# adaptive_constant_res_val: 5.570e-01
# adaptive_constant_ics_val: 2.045e+00
# adaptive_constant_bcs1_val: 3.633e-02
# adaptive_constant_bcs2_val: 3.633e-02
# It: 35100, Loss: 5.300e-02,  loss_bc1: 1.317e-02,  loss_bc2: 6.914e-03, loss_ics_u: 1.069e-02,  Loss_res: 2.222e-02,  Time: 4.46
# adaptive_constant_res_val: 6.538e-01
# adaptive_constant_ics_val: 1.541e-01
# adaptive_constant_bcs1_val: 1.236e-02
# adaptive_constant_bcs2_val: 1.236e-02
# It: 35200, Loss: 5.289e-02,  loss_bc1: 1.322e-02,  loss_bc2: 6.621e-03, loss_ics_u: 1.441e-02,  Loss_res: 1.863e-02,  Time: 4.46
# adaptive_constant_res_val: 3.155e-01
# adaptive_constant_ics_val: 1.848e+00
# adaptive_constant_bcs1_val: 2.321e-02
# adaptive_constant_bcs2_val: 2.321e-02
# It: 35300, Loss: 5.286e-02,  loss_bc1: 1.318e-02,  loss_bc2: 6.851e-03, loss_ics_u: 1.481e-02,  Loss_res: 1.803e-02,  Time: 4.41
# adaptive_constant_res_val: 5.928e-01
# adaptive_constant_ics_val: 1.467e+00
# adaptive_constant_bcs1_val: 4.398e-02
# adaptive_constant_bcs2_val: 4.398e-02
# It: 35400, Loss: 5.285e-02,  loss_bc1: 1.305e-02,  loss_bc2: 6.804e-03, loss_ics_u: 1.816e-02,  Loss_res: 1.484e-02,  Time: 3.82
# adaptive_constant_res_val: 5.855e-01
# adaptive_constant_ics_val: 2.770e+00
# adaptive_constant_bcs1_val: 2.245e-02
# adaptive_constant_bcs2_val: 2.245e-02
# It: 35500, Loss: 4.983e-02,  loss_bc1: 1.306e-02,  loss_bc2: 6.806e-03, loss_ics_u: 1.148e-02,  Loss_res: 1.848e-02,  Time: 3.88
# adaptive_constant_res_val: 2.449e-01
# adaptive_constant_ics_val: 8.459e-01
# adaptive_constant_bcs1_val: 2.871e-02
# adaptive_constant_bcs2_val: 2.871e-02
# It: 35600, Loss: 4.887e-02,  loss_bc1: 1.298e-02,  loss_bc2: 6.649e-03, loss_ics_u: 1.192e-02,  Loss_res: 1.732e-02,  Time: 4.34
# adaptive_constant_res_val: 5.165e-01
# adaptive_constant_ics_val: 5.734e-01
# adaptive_constant_bcs1_val: 1.915e-02
# adaptive_constant_bcs2_val: 1.915e-02
# It: 35700, Loss: 5.013e-02,  loss_bc1: 1.298e-02,  loss_bc2: 6.740e-03, loss_ics_u: 1.095e-02,  Loss_res: 1.947e-02,  Time: 4.09
# adaptive_constant_res_val: 2.998e-01
# adaptive_constant_ics_val: 4.106e-01
# adaptive_constant_bcs1_val: 1.126e-02
# adaptive_constant_bcs2_val: 1.126e-02
# It: 35800, Loss: 4.963e-02,  loss_bc1: 1.302e-02,  loss_bc2: 6.684e-03, loss_ics_u: 1.200e-02,  Loss_res: 1.792e-02,  Time: 3.86
# adaptive_constant_res_val: 6.047e-01
# adaptive_constant_ics_val: 7.699e-01
# adaptive_constant_bcs1_val: 4.092e-02
# adaptive_constant_bcs2_val: 4.092e-02
# It: 35900, Loss: 6.089e-02,  loss_bc1: 1.287e-02,  loss_bc2: 6.570e-03, loss_ics_u: 2.613e-02,  Loss_res: 1.531e-02,  Time: 3.89
# adaptive_constant_res_val: 4.433e-01
# adaptive_constant_ics_val: 3.755e+00
# adaptive_constant_bcs1_val: 4.024e-02
# adaptive_constant_bcs2_val: 4.024e-02
# It: 36000, Loss: 4.892e-02,  loss_bc1: 1.281e-02,  loss_bc2: 6.531e-03, loss_ics_u: 1.201e-02,  Loss_res: 1.756e-02,  Time: 4.06
# adaptive_constant_res_val: 1.631e-01
# adaptive_constant_ics_val: 1.174e+00
# adaptive_constant_bcs1_val: 1.536e-02
# adaptive_constant_bcs2_val: 1.536e-02
# It: 36100, Loss: 5.123e-02,  loss_bc1: 1.283e-02,  loss_bc2: 6.426e-03, loss_ics_u: 1.171e-02,  Loss_res: 2.027e-02,  Time: 3.86
# adaptive_constant_res_val: 1.084e+00
# adaptive_constant_ics_val: 5.808e-01
# adaptive_constant_bcs1_val: 2.297e-02
# adaptive_constant_bcs2_val: 2.297e-02
# It: 36200, Loss: 4.779e-02,  loss_bc1: 1.301e-02,  loss_bc2: 6.580e-03, loss_ics_u: 1.140e-02,  Loss_res: 1.680e-02,  Time: 3.90
# adaptive_constant_res_val: 4.511e-01
# adaptive_constant_ics_val: 7.305e-01
# adaptive_constant_bcs1_val: 5.261e-02
# adaptive_constant_bcs2_val: 5.261e-02
# It: 36300, Loss: 6.247e-02,  loss_bc1: 1.267e-02,  loss_bc2: 6.454e-03, loss_ics_u: 2.631e-02,  Loss_res: 1.704e-02,  Time: 3.84
# adaptive_constant_res_val: 2.332e-01
# adaptive_constant_ics_val: 3.750e+00
# adaptive_constant_bcs1_val: 1.088e-02
# adaptive_constant_bcs2_val: 1.088e-02
# It: 36400, Loss: 4.643e-02,  loss_bc1: 1.314e-02,  loss_bc2: 6.444e-03, loss_ics_u: 1.041e-02,  Loss_res: 1.643e-02,  Time: 3.94
# adaptive_constant_res_val: 2.561e-01
# adaptive_constant_ics_val: 2.772e-01
# adaptive_constant_bcs1_val: 5.686e-02
# adaptive_constant_bcs2_val: 5.686e-02
# It: 36500, Loss: 5.111e-02,  loss_bc1: 1.261e-02,  loss_bc2: 6.286e-03, loss_ics_u: 1.415e-02,  Loss_res: 1.807e-02,  Time: 3.92
# adaptive_constant_res_val: 3.549e-01
# adaptive_constant_ics_val: 1.127e+00
# adaptive_constant_bcs1_val: 2.149e-02
# adaptive_constant_bcs2_val: 2.149e-02
# It: 36600, Loss: 4.995e-02,  loss_bc1: 1.259e-02,  loss_bc2: 6.341e-03, loss_ics_u: 9.983e-03,  Loss_res: 2.104e-02,  Time: 3.88
# adaptive_constant_res_val: 3.755e-01
# adaptive_constant_ics_val: 1.066e-01
# adaptive_constant_bcs1_val: 9.859e-03
# adaptive_constant_bcs2_val: 9.859e-03
# It: 36700, Loss: 4.388e-02,  loss_bc1: 1.268e-02,  loss_bc2: 6.383e-03, loss_ics_u: 1.119e-02,  Loss_res: 1.363e-02,  Time: 3.88
# adaptive_constant_res_val: 2.534e-01
# adaptive_constant_ics_val: 6.180e-01
# adaptive_constant_bcs1_val: 1.484e-02
# adaptive_constant_bcs2_val: 1.484e-02
# It: 36800, Loss: 4.820e-02,  loss_bc1: 1.272e-02,  loss_bc2: 6.394e-03, loss_ics_u: 1.209e-02,  Loss_res: 1.700e-02,  Time: 3.93
# adaptive_constant_res_val: 4.229e-01
# adaptive_constant_ics_val: 1.375e+00
# adaptive_constant_bcs1_val: 2.262e-02
# adaptive_constant_bcs2_val: 2.262e-02
# It: 36900, Loss: 4.707e-02,  loss_bc1: 1.262e-02,  loss_bc2: 6.207e-03, loss_ics_u: 1.086e-02,  Loss_res: 1.738e-02,  Time: 3.92
# adaptive_constant_res_val: 4.588e-01
# adaptive_constant_ics_val: 6.938e-01
# adaptive_constant_bcs1_val: 2.392e-02
# adaptive_constant_bcs2_val: 2.392e-02
# It: 37000, Loss: 4.277e-02,  loss_bc1: 1.248e-02,  loss_bc2: 6.332e-03, loss_ics_u: 9.975e-03,  Loss_res: 1.398e-02,  Time: 3.86
# adaptive_constant_res_val: 1.378e-01
# adaptive_constant_ics_val: 3.471e-01
# adaptive_constant_bcs1_val: 7.105e-03
# adaptive_constant_bcs2_val: 7.105e-03
# It: 37100, Loss: 5.349e-02,  loss_bc1: 1.247e-02,  loss_bc2: 6.255e-03, loss_ics_u: 1.603e-02,  Loss_res: 1.873e-02,  Time: 3.94
# adaptive_constant_res_val: 2.447e-01
# adaptive_constant_ics_val: 1.292e+00
# adaptive_constant_bcs1_val: 1.035e-02
# adaptive_constant_bcs2_val: 1.035e-02
# It: 37200, Loss: 4.920e-02,  loss_bc1: 1.242e-02,  loss_bc2: 6.657e-03, loss_ics_u: 1.377e-02,  Loss_res: 1.636e-02,  Time: 3.87
# adaptive_constant_res_val: 1.916e-01
# adaptive_constant_ics_val: 1.925e+00
# adaptive_constant_bcs1_val: 9.055e-03
# adaptive_constant_bcs2_val: 9.055e-03
# It: 37300, Loss: 4.958e-02,  loss_bc1: 1.243e-02,  loss_bc2: 6.248e-03, loss_ics_u: 1.499e-02,  Loss_res: 1.592e-02,  Time: 3.90
# adaptive_constant_res_val: 1.502e-01
# adaptive_constant_ics_val: 2.360e+00
# adaptive_constant_bcs1_val: 6.630e-03
# adaptive_constant_bcs2_val: 6.630e-03
# It: 37400, Loss: 4.405e-02,  loss_bc1: 1.240e-02,  loss_bc2: 6.121e-03, loss_ics_u: 9.525e-03,  Loss_res: 1.600e-02,  Time: 3.90
# adaptive_constant_res_val: 3.304e-01
# adaptive_constant_ics_val: 1.773e-01
# adaptive_constant_bcs1_val: 2.390e-02
# adaptive_constant_bcs2_val: 2.390e-02
# It: 37500, Loss: 4.412e-02,  loss_bc1: 1.230e-02,  loss_bc2: 6.246e-03, loss_ics_u: 1.214e-02,  Loss_res: 1.343e-02,  Time: 3.86
# adaptive_constant_res_val: 2.076e-01
# adaptive_constant_ics_val: 1.170e+00
# adaptive_constant_bcs1_val: 2.043e-02
# adaptive_constant_bcs2_val: 2.043e-02
# It: 37600, Loss: 4.414e-02,  loss_bc1: 1.226e-02,  loss_bc2: 6.092e-03, loss_ics_u: 1.072e-02,  Loss_res: 1.507e-02,  Time: 3.83
# adaptive_constant_res_val: 2.788e-01
# adaptive_constant_ics_val: 5.865e-01
# adaptive_constant_bcs1_val: 1.267e-02
# adaptive_constant_bcs2_val: 1.267e-02
# It: 37700, Loss: 4.417e-02,  loss_bc1: 1.223e-02,  loss_bc2: 6.753e-03, loss_ics_u: 1.274e-02,  Loss_res: 1.245e-02,  Time: 3.92
# adaptive_constant_res_val: 2.686e-01
# adaptive_constant_ics_val: 1.775e+00
# adaptive_constant_bcs1_val: 2.162e-02
# adaptive_constant_bcs2_val: 2.162e-02
# It: 37800, Loss: 5.051e-02,  loss_bc1: 1.222e-02,  loss_bc2: 6.342e-03, loss_ics_u: 1.573e-02,  Loss_res: 1.622e-02,  Time: 3.85
# adaptive_constant_res_val: 1.901e-01
# adaptive_constant_ics_val: 2.493e+00
# adaptive_constant_bcs1_val: 2.630e-02
# adaptive_constant_bcs2_val: 2.630e-02
# It: 37900, Loss: 4.587e-02,  loss_bc1: 1.227e-02,  loss_bc2: 5.991e-03, loss_ics_u: 1.089e-02,  Loss_res: 1.671e-02,  Time: 3.90
# adaptive_constant_res_val: 3.447e-01
# adaptive_constant_ics_val: 5.640e-01
# adaptive_constant_bcs1_val: 1.031e-02
# adaptive_constant_bcs2_val: 1.031e-02
# It: 38000, Loss: 5.203e-02,  loss_bc1: 1.224e-02,  loss_bc2: 5.926e-03, loss_ics_u: 1.343e-02,  Loss_res: 2.043e-02,  Time: 4.02
# adaptive_constant_res_val: 4.712e-01
# adaptive_constant_ics_val: 2.077e+00
# adaptive_constant_bcs1_val: 1.416e-02
# adaptive_constant_bcs2_val: 1.416e-02
# It: 38100, Loss: 4.347e-02,  loss_bc1: 1.218e-02,  loss_bc2: 6.195e-03, loss_ics_u: 1.000e-02,  Loss_res: 1.509e-02,  Time: 3.87
# adaptive_constant_res_val: 2.951e-01
# adaptive_constant_ics_val: 8.317e-01
# adaptive_constant_bcs1_val: 1.116e-02
# adaptive_constant_bcs2_val: 1.116e-02
# It: 38200, Loss: 4.677e-02,  loss_bc1: 1.214e-02,  loss_bc2: 5.879e-03, loss_ics_u: 1.209e-02,  Loss_res: 1.666e-02,  Time: 3.94
# adaptive_constant_res_val: 3.644e-01
# adaptive_constant_ics_val: 1.756e+00
# adaptive_constant_bcs1_val: 2.048e-02
# adaptive_constant_bcs2_val: 2.048e-02
# It: 38300, Loss: 4.414e-02,  loss_bc1: 1.210e-02,  loss_bc2: 6.249e-03, loss_ics_u: 1.065e-02,  Loss_res: 1.515e-02,  Time: 3.93
# adaptive_constant_res_val: 2.176e-01
# adaptive_constant_ics_val: 1.257e+00
# adaptive_constant_bcs1_val: 2.582e-02
# adaptive_constant_bcs2_val: 2.582e-02
# It: 38400, Loss: 4.343e-02,  loss_bc1: 1.210e-02,  loss_bc2: 5.732e-03, loss_ics_u: 1.125e-02,  Loss_res: 1.435e-02,  Time: 4.46
# adaptive_constant_res_val: 2.698e-01
# adaptive_constant_ics_val: 8.301e-01
# adaptive_constant_bcs1_val: 2.098e-02
# adaptive_constant_bcs2_val: 2.098e-02
# It: 38500, Loss: 4.316e-02,  loss_bc1: 1.200e-02,  loss_bc2: 5.942e-03, loss_ics_u: 9.466e-03,  Loss_res: 1.575e-02,  Time: 4.38
# adaptive_constant_res_val: 2.958e-01
# adaptive_constant_ics_val: 7.373e-01
# adaptive_constant_bcs1_val: 7.785e-03
# adaptive_constant_bcs2_val: 7.785e-03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_39039/356373291.py in <module>
#      78             elif mtd =="mini_batch":
#      79                 print("mini_batch method is used")
# ---> 80                 model.trainmb(nIter, mbbatch_size)
#      81             else:
#      82                 print("unknown method!")
#
# /tmp/ipykernel_39039/724299257.py in trainmb(self, nIter, batch_size, log_NTK, update_lam)
#     321
#     322             # Run the Tensorflow session to minimize the loss
# --> 323             _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)
#     324
#     325             # self.print
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/twoPhase/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
def plot_grad(self , path):

    fig, ax = plt.subplots()
    fig.set_size_inches([15,8])
    ax.semilogy(self.adaptive_constant_bcs2_log, label="adaptive_constant_bcs2_log")
    ax.semilogy(self.adaptive_constant_ics_log, label="adaptive_constant_ics_log")
    ax.semilogy(self.adaptive_constant_res_log, label="adaptive_constant_res_log")
    ax.semilogy(self.adaptive_constant_bcs1_log, label="adaptive_constant_bcs1_log")

    ax.set_xlabel("epochs", fontsize=15)
    ax.set_ylabel("loss", fontsize=15)
    ax.tick_params(labelsize=15)
    ax.legend()
    plt.savefig(path)


plot_grad(model , os.path.join(model.dirname,'grad_history.png'))

# %%
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

# %%
# # Predictions
# u_pred = model.predict_u(X_star)
# r_pred = model.predict_r(X_star)
# # Predictions
# r_pred =r_pred.reshape(200,200)

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
# error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)

# print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
# print('Relative L2 error_r: {:.2e}'.format(error_r))
# r_pred =r_pred.reshape(200,200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_39039/2242230702.py in <module>
#       5 # r_pred =r_pred.reshape(200,200)
#       6
# ----> 7 error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
#       8 # error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)
#       9
#
# NameError: name 'u_pred' is not defined

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
# R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, r_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - r_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_39039/1239256772.py in <module>
#       1 U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
#       2 r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
# ----> 3 U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
#       4 # R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')
#       5
#
# NameError: name 'u_pred' is not defined
