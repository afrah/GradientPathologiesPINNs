# %%
import tensorflow as tf
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import layers, activations

# tf.enable_eager_execution()
os.environ["KMP_WARNINGS"] = "FALSE" 
import timeit

import sys

import scipy
import scipy.io
import time
from pyDOE import lhs


import logging

import os.path
import shutil
from datetime import datetime
import pickle
 #############################################################################
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) -  a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) -  a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual


class PINN:
    # Initialize the class
    def __init__(self, layers, operator , ics_sampler, bcs_sampler, res_sampler, c ,mode,  sess):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        self.sess = sess
        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        

        self.lam_bc1_val =  tf.Variable([1.0], dtype=tf.float32)
        self.lam_bc2_val =  tf.Variable([1.0], dtype=tf.float32)
        self.lam_ics_val =  tf.Variable([1.0], dtype=tf.float32)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        # Define Tensorflow session
        self.sess = sess #tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

    
        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
    
        
        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)


        # Evaluate predictions

        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        
        # Boundary loss and Initial loss
        # self.loss_coll_u = tf.reduce_mean(tf.square(self.u_coll_tf - self.u_coll_pred))

        self.loss_ics_u =  100 *  (tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred)) + tf.reduce_mean(tf.square( tf.gradients(self.u_ics_pred, self.t_ics_tf)[0] / self.sigma_t)))
        self.loss_bc1 =100 *  tf.reduce_mean(tf.square(self.u_bc1_pred)) #+ tf.reduce_mean(tf.square(self.u_bc2_pred))
        self.loss_bc2 =100 * tf.reduce_mean(tf.square(self.u_bc2_pred))

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.loss_res + self.loss_bc1 +  self.loss_bc2 + self.loss_ics_u  # + self.lam_ut_tf * self.loss_ics_u_t 

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,  1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step , var_list=  self.weights + self.biases )

        self.loss_tensor_list = [self.loss ,  self.loss_res,  self.loss_bc1 , self.loss_bc2 , self.loss_ics_u] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bc1", "loss_bc2", "loss_ics_u"] 

        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs1_layers = self.generate_grad_dict()
        self.dict_gradients_bcs2_layers = self.generate_grad_dict()
        self.dict_gradients_ics_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_ics = []
        self.grad_bcs1 = []
        self.grad_bcs2 = []

        self.adaptive_constant_bcs1_log = []
        self.adaptive_constant_bcs2_log = []
        self.adaptive_constant_ics_log = []
        self.adaptive_constant_res_log = []

        self.max_grad_res_list = []
        self.mean_grad1_bcs_list = []
        self.mean_grad2_bcs_list = []
        self.mean_grad_ics_list = []


        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs1.append(tf.gradients(self.loss_bc1, self.weights[i])[0])
            self.grad_bcs2.append(tf.gradients(self.loss_bc2, self.weights[i])[0])
            self.grad_ics.append(tf.gradients(self.loss_ics_u, self.weights[i])[0])


        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.math.reduce_mean(tf.abs(self.grad_res[i]))) 
            self.mean_grad1_bcs_list.append(tf.math.reduce_mean(tf.abs(self.grad_bcs1[i])))
            self.mean_grad2_bcs_list.append(tf.math.reduce_mean(tf.abs(self.grad_bcs1[i])))
            self.mean_grad_ics_list.append(tf.math.reduce_mean(tf.abs(self.grad_ics[i])))
        
        self.max_grad_res = tf.math.reduce_mean(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs1 = tf.math.reduce_mean(tf.stack(self.mean_grad1_bcs_list))
        self.mean_grad_bcs2 = tf.math.reduce_mean(tf.stack(self.mean_grad2_bcs_list))
        self.mean_grad_ics = tf.math.reduce_mean(tf.stack(self.mean_grad_ics_list))
        
        self.adaptive_constant_bcs1 = self.mean_grad_bcs1
        self.adaptive_constant_bcs2 = self.mean_grad_bcs2
        self.adaptive_constant_ics = self.mean_grad_ics
        self.adaptive_constant_res = self.max_grad_res


         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
############################################################################################################


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

#######################################################################################################
    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,  dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),  self.layers, self.weights, self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x, self.c, self.sigma_t,  self.sigma_x)
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y


    def trainmb(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )

        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size )
        
        for it in range(1 , nIter):

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)
            # Define a dictionary for associating placeholders with data
            tf_dict = {
                self.t_ics_tf: X_ics_batch[:, 0:1], 
                self.x_ics_tf: X_ics_batch[:, 1:2],
                self.u_ics_tf: u_ics_batch,
                self.t_bc1_tf: X_bc1_batch[:, 0:1],
                self.x_bc1_tf: X_bc1_batch[:, 1:2],
                self.t_bc2_tf: X_bc2_batch[:, 0:1], 
                self.x_bc2_tf: X_bc2_batch[:, 1:2],
                self.t_r_tf: X_res_batch[:, 0:1], 
                self.x_r_tf: X_res_batch[:, 1:2]
                       }

            # Run the Tensorflow session to minimize the loss
            _, batch_losses = self.sess.run([self.train_op, self.loss_tensor_list] ,tf_dict)

            # self.print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_res ] , tf_dict)

                self.print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e,  Loss_res: %.3e,  Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u , loss_res , elapsed))
                
                    # Compute the adaptive constant
                adaptive_constant_res , adaptive_constant_bcs1_val, adaptive_constant_bcs2 , adaptive_constant_ics_val = self.sess.run( [self.adaptive_constant_res , self.adaptive_constant_bcs1, self.adaptive_constant_bcs2, self.adaptive_constant_ics  ], tf_dict)
                # self.print adaptive weights during training
                self.adaptive_constant_res_val = 1.0 # loss_res / adaptive_constant_res #* ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_ics_val =  1.0 # loss_ics_u_t / adaptive_constant_ics_val #* ( 1.0 - self.rate) + self.rate * self.adaptive_constant_ics_val
                self.adaptive_constant_bcs_val =  1.0 # (loss_bc1+ loss_bc2 + loss_ics_u) /adaptive_constant_bcs_val #* ( 1.0 - self.rate) + self.rate * self.adaptive_constant_bcs_val


                self.print('adaptive_constant_res_val: {:.3e}'.format( adaptive_constant_res))
                self.print('adaptive_constant_ics_val: {:.3e}'.format( adaptive_constant_ics_val))
                self.print('adaptive_constant_bcs1_val: {:.3e}'.format( adaptive_constant_bcs1_val))
                self.print('adaptive_constant_bcs2_val: {:.3e}'.format( adaptive_constant_bcs2))
                
                self.adaptive_constant_res_log.append(adaptive_constant_res)
                self.adaptive_constant_bcs1_log.append(adaptive_constant_bcs1_val)
                self.adaptive_constant_bcs2_log.append(adaptive_constant_bcs2)
                self.adaptive_constant_ics_log.append(adaptive_constant_ics_val)


                start_time = timeit.default_timer()
            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()
            self.assign_batch_losses(batch_losses)
            for key in self.loss_history:
                self.loss_history[key].append(self.epoch_loss[key])
####################################################################################################
    def train(self, nIter , bcbatch_size , ubatch_size):

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, bcbatch_size )

        X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], bcbatch_size )
        X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], bcbatch_size )
    

        # Fetch residual mini-batch
        X_res_batch, _ = self.fetch_minibatch(self.res_sampler, ubatch_size)
        # Define a dictionary for associating placeholders with data
        tf_dict = {
            self.t_ics_tf: X_ics_batch[:, 0:1], 
            self.x_ics_tf: X_ics_batch[:, 1:2],
            self.u_ics_tf: u_ics_batch,
            self.t_bc1_tf: X_bc1_batch[:, 0:1],
            self.x_bc1_tf: X_bc1_batch[:, 1:2],
            self.t_bc2_tf: X_bc2_batch[:, 0:1], 
            self.x_bc2_tf: X_bc2_batch[:, 1:2],
            self.t_r_tf: X_res_batch[:, 0:1], 
            self.x_r_tf: X_res_batch[:, 1:2]
                    }
        for it in range(1 , nIter):

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # self.print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss , loss_bc1 , loss_bc2 , loss_ics_u , loss_res = self.sess.run( [self.loss  , self.loss_bc1 ,self.loss_bc2 , self.loss_ics_u, self.loss_res ] , tf_dict)

                self.print('It: %d, Loss: %.3e,  loss_bc1: %.3e,  loss_bc2: %.3e, loss_ics_u: %.3e,  Loss_res: %.3e,  Time: %.2f' %(it, loss, loss_bc1 , loss_bc2 , loss_ics_u , loss_res , elapsed))
          
                
                sys.stdout.flush()
                start_time = timeit.default_timer()

    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star
    
   ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   # ###############################################################################################################################################
   # 
   
###################################################################################################################


    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1 , grad_bcs2 , grad_ics  = self.sess.run([ self.grad_res[i],self.grad_bcs1[i],self.grad_bcs2[i],self.grad_ics[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs1_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())
            self.dict_gradients_bcs2_layers['layer_' + str(i + 1)].append(grad_bcs2.flatten())
            self.dict_gradients_ics_layers['layer_' + str(i + 1)].append(grad_ics.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs1_layers['layer_' + str(j + 1)][-1]
            gradients_bc2 = self.dict_gradients_bcs2_layers['layer_' + str(j + 1)][-1]
            gradients_ics = self.dict_gradients_ics_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')
            sns.distplot(gradients_bc2, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc2}}$')
            sns.distplot(gradients_ics, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{ics}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=4)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")

    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M1.ipynb', os.path.join(dirname, 'M1.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        #plt.show()
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)

    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values

    def plt_prediction(self , t , x , X_star , u_star , u_pred , r_star , r_pred):
        
        U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
        r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
        U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
        R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


        plt.figure(figsize=(18, 9))
        plt.subplot(2, 3, 1)
        plt.pcolor(t, x, U_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$x_1$')
        plt.ylabel('$x_2$')
        plt.title('Exact u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 2)
        plt.pcolor(t, x, U_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted u(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 3)
        plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()

        plt.subplot(2, 3, 4)
        plt.pcolor(t, x, r_star, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Exact r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 5)
        plt.pcolor(t, x, R_pred, cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Predicted r(t, x)')
        plt.tight_layout()

        plt.subplot(2, 3, 6)
        plt.pcolor(t, x, np.abs(r_star - R_pred), cmap='jet')
        plt.colorbar()
        plt.xlabel('$t$')
        plt.ylabel('$x$')
        plt.title('Absolute error')
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"))
        plt.close("all")


    def plot_grad(self):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adaptive_constant_bcs2_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc2}}}$')
        ax.semilogy(self.adaptive_constant_ics_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{ics}}}$')
        ax.semilogy(self.adaptive_constant_res_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{phy}}}$')
        ax.semilogy(self.adaptive_constant_bcs1_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc1}}}$')

        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)

# %%
# Define PINN model
a = 0.5
c = 2

kernel_size = 300

# Domain boundaries
ics_coords = np.array([[0.0, 0.0],  [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],  [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],  [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],  [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')
coll_sampler = Sampler(2, dom_coords, lambda x: u(x, a, c), name='coll')



nIter =40000
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 300



# Define model
mode = 'M1'
layers = [2, 500, 500, 500, 1]


nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
r_star = r(X_star, a, c)

iterations = 1
methods = [  "mini_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    model.print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_r_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))

        # Create residual sampler

        # [elapsed, error_u , model] = test_method(mtd , layers,  ics_sampler, bcs_sampler, res_sampler, c ,kernel_size , X_star , u_star , r_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size )
        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            # sess.run(init)

            model = PINN(layers, operator ,  ics_sampler, bcs_sampler, res_sampler, c , mode , sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                model.print("full_batch method is used")
                model.train(nIter  , bcbatch_size , ubatch_size  )
            elif mtd =="mini_batch":
                model.print("mini_batch method is used")
                model.trainmb(nIter, mbbatch_size)
            else:
                model.print("unknown method!")
            elapsed = time.time() - start_time

            # Predictions
            u_pred = model.predict_u(X_star)
            r_pred = model.predict_r(X_star)
            # Predictions

            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

            model.print('elapsed: {:.2e}'.format(elapsed))

            model.print('Relative L2 error_u: {:.2e}'.format(error_u))
            model.print('Relative L2 error_r: {:.2e}'.format(error_r))

            model.save_NN()
            model.plt_prediction( t , x , X_star , u_star , u_pred , r_star , r_pred)
            sess.close()  

        time_list.append(elapsed)
        error_u_list.append(error_u)
        error_r_list.append(error_r)

    print("\n\nMethod: ", mtd)
    print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    print("average of error_r_list:" , sum(error_r_list) / len(error_r_list) )

    result_dict[mtd] = [time_list ,error_u_list,error_r_list]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_1Dwave_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)

###############################################################################################################################################
# Out:
# Method:  mini_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_6926/356373291.py:66: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6926/356373291.py:67: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6926/356373291.py:68: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6926/356373291.py:68: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-10 11:17:45.613419: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-10 11:17:45.642701: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-10 11:17:45.643195: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55af70625100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-10 11:17:45.643214: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-10 11:17:45.648110: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_6926/3759871455.py:125: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6926/3759871455.py:171: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6926/3759871455.py:173: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6926/3759871455.py:228: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# mini_batch method is used
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 4.527e+01,  loss_bc1: 5.024e+00,  loss_bc2: 2.729e+00, loss_ics_u: 3.724e+01,  Loss_res: 2.796e-01,  Time: 13.71
# adaptive_constant_res_val: 4.386e-02
# adaptive_constant_ics_val: 5.506e-01
# adaptive_constant_bcs1_val: 1.010e+00
# adaptive_constant_bcs2_val: 1.010e+00
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 3.649e+01,  loss_bc1: 5.474e+00,  loss_bc2: 2.856e+00, loss_ics_u: 2.698e+01,  Loss_res: 1.183e+00,  Time: 7.72
# adaptive_constant_res_val: 1.084e-01
# adaptive_constant_ics_val: 1.456e+00
# adaptive_constant_bcs1_val: 1.226e+00
# adaptive_constant_bcs2_val: 1.226e+00
# It: 300, Loss: 3.019e+01,  loss_bc1: 4.303e+00,  loss_bc2: 2.035e+00, loss_ics_u: 2.174e+01,  Loss_res: 2.115e+00,  Time: 3.40
# adaptive_constant_res_val: 2.175e-01
# adaptive_constant_ics_val: 1.330e+00
# adaptive_constant_bcs1_val: 1.117e+00
# adaptive_constant_bcs2_val: 1.117e+00
# It: 400, Loss: 2.269e+01,  loss_bc1: 3.281e+00,  loss_bc2: 9.439e-01, loss_ics_u: 1.661e+01,  Loss_res: 1.849e+00,  Time: 3.34
# adaptive_constant_res_val: 2.721e-01
# adaptive_constant_ics_val: 1.785e+00
# adaptive_constant_bcs1_val: 9.985e-01
# adaptive_constant_bcs2_val: 9.985e-01
# It: 500, Loss: 2.619e+01,  loss_bc1: 3.929e+00,  loss_bc2: 1.795e+00, loss_ics_u: 1.904e+01,  Loss_res: 1.429e+00,  Time: 3.60
# adaptive_constant_res_val: 3.046e-01
# adaptive_constant_ics_val: 6.064e+00
# adaptive_constant_bcs1_val: 1.069e+00
# adaptive_constant_bcs2_val: 1.069e+00
# It: 600, Loss: 1.756e+01,  loss_bc1: 2.838e+00,  loss_bc2: 1.341e+00, loss_ics_u: 1.257e+01,  Loss_res: 8.022e-01,  Time: 3.86
# adaptive_constant_res_val: 1.852e-01
# adaptive_constant_ics_val: 7.849e-01
# adaptive_constant_bcs1_val: 7.964e-01
# adaptive_constant_bcs2_val: 7.964e-01
# It: 700, Loss: 1.717e+01,  loss_bc1: 2.709e+00,  loss_bc2: 1.192e+00, loss_ics_u: 1.242e+01,  Loss_res: 8.456e-01,  Time: 3.83
# adaptive_constant_res_val: 2.062e-01
# adaptive_constant_ics_val: 1.213e+00
# adaptive_constant_bcs1_val: 7.988e-01
# adaptive_constant_bcs2_val: 7.988e-01
# It: 800, Loss: 1.618e+01,  loss_bc1: 2.489e+00,  loss_bc2: 1.282e+00, loss_ics_u: 1.158e+01,  Loss_res: 8.267e-01,  Time: 3.74
# adaptive_constant_res_val: 2.506e-01
# adaptive_constant_ics_val: 8.697e-01
# adaptive_constant_bcs1_val: 8.095e-01
# adaptive_constant_bcs2_val: 8.095e-01
# It: 900, Loss: 1.585e+01,  loss_bc1: 2.423e+00,  loss_bc2: 1.117e+00, loss_ics_u: 1.175e+01,  Loss_res: 5.558e-01,  Time: 3.81
# adaptive_constant_res_val: 1.393e-01
# adaptive_constant_ics_val: 9.440e-01
# adaptive_constant_bcs1_val: 7.996e-01
# adaptive_constant_bcs2_val: 7.996e-01
# It: 1000, Loss: 1.514e+01,  loss_bc1: 2.193e+00,  loss_bc2: 1.269e+00, loss_ics_u: 1.120e+01,  Loss_res: 4.800e-01,  Time: 3.95
# adaptive_constant_res_val: 1.394e-01
# adaptive_constant_ics_val: 9.779e-01
# adaptive_constant_bcs1_val: 8.154e-01
# adaptive_constant_bcs2_val: 8.154e-01
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 1.609e+01,  loss_bc1: 2.180e+00,  loss_bc2: 1.074e+00, loss_ics_u: 1.245e+01,  Loss_res: 3.884e-01,  Time: 8.34
# adaptive_constant_res_val: 1.077e-01
# adaptive_constant_ics_val: 4.036e+00
# adaptive_constant_bcs1_val: 9.731e-01
# adaptive_constant_bcs2_val: 9.731e-01
# It: 1200, Loss: 1.466e+01,  loss_bc1: 2.005e+00,  loss_bc2: 1.295e+00, loss_ics_u: 1.083e+01,  Loss_res: 5.284e-01,  Time: 4.30
# adaptive_constant_res_val: 1.968e-01
# adaptive_constant_ics_val: 1.353e+00
# adaptive_constant_bcs1_val: 7.155e-01
# adaptive_constant_bcs2_val: 7.155e-01
# It: 1300, Loss: 1.422e+01,  loss_bc1: 1.953e+00,  loss_bc2: 1.229e+00, loss_ics_u: 1.050e+01,  Loss_res: 5.433e-01,  Time: 4.25
# adaptive_constant_res_val: 1.924e-01
# adaptive_constant_ics_val: 7.480e-01
# adaptive_constant_bcs1_val: 8.332e-01
# adaptive_constant_bcs2_val: 8.332e-01
# It: 1400, Loss: 1.405e+01,  loss_bc1: 1.838e+00,  loss_bc2: 1.291e+00, loss_ics_u: 1.033e+01,  Loss_res: 5.915e-01,  Time: 4.33
# adaptive_constant_res_val: 1.811e-01
# adaptive_constant_ics_val: 9.008e-01
# adaptive_constant_bcs1_val: 8.216e-01
# adaptive_constant_bcs2_val: 8.216e-01
# It: 1500, Loss: 1.392e+01,  loss_bc1: 1.775e+00,  loss_bc2: 1.253e+00, loss_ics_u: 1.045e+01,  Loss_res: 4.387e-01,  Time: 3.97
# adaptive_constant_res_val: 1.427e-01
# adaptive_constant_ics_val: 1.932e+00
# adaptive_constant_bcs1_val: 8.982e-01
# adaptive_constant_bcs2_val: 8.982e-01
# It: 1600, Loss: 1.354e+01,  loss_bc1: 1.764e+00,  loss_bc2: 1.215e+00, loss_ics_u: 1.002e+01,  Loss_res: 5.388e-01,  Time: 3.98
# adaptive_constant_res_val: 2.277e-01
# adaptive_constant_ics_val: 1.462e+00
# adaptive_constant_bcs1_val: 7.523e-01
# adaptive_constant_bcs2_val: 7.523e-01
# It: 1700, Loss: 1.318e+01,  loss_bc1: 1.733e+00,  loss_bc2: 1.302e+00, loss_ics_u: 9.765e+00,  Loss_res: 3.806e-01,  Time: 4.20
# adaptive_constant_res_val: 1.719e-01
# adaptive_constant_ics_val: 1.527e+00
# adaptive_constant_bcs1_val: 9.494e-01
# adaptive_constant_bcs2_val: 9.494e-01
# It: 1800, Loss: 1.296e+01,  loss_bc1: 1.528e+00,  loss_bc2: 1.289e+00, loss_ics_u: 9.731e+00,  Loss_res: 4.066e-01,  Time: 4.09
# adaptive_constant_res_val: 2.120e-01
# adaptive_constant_ics_val: 2.144e+00
# adaptive_constant_bcs1_val: 8.059e-01
# adaptive_constant_bcs2_val: 8.059e-01
# It: 1900, Loss: 1.251e+01,  loss_bc1: 1.540e+00,  loss_bc2: 1.267e+00, loss_ics_u: 9.329e+00,  Loss_res: 3.791e-01,  Time: 4.23
# adaptive_constant_res_val: 1.835e-01
# adaptive_constant_ics_val: 9.941e-01
# adaptive_constant_bcs1_val: 7.591e-01
# adaptive_constant_bcs2_val: 7.591e-01
# It: 2000, Loss: 1.239e+01,  loss_bc1: 1.673e+00,  loss_bc2: 1.267e+00, loss_ics_u: 9.053e+00,  Loss_res: 4.007e-01,  Time: 4.16
# adaptive_constant_res_val: 2.467e-01
# adaptive_constant_ics_val: 1.098e+00
# adaptive_constant_bcs1_val: 9.854e-01
# adaptive_constant_bcs2_val: 9.854e-01
# It: 2100, Loss: 1.230e+01,  loss_bc1: 1.519e+00,  loss_bc2: 1.238e+00, loss_ics_u: 9.202e+00,  Loss_res: 3.386e-01,  Time: 4.36
# adaptive_constant_res_val: 2.024e-01
# adaptive_constant_ics_val: 2.848e+00
# adaptive_constant_bcs1_val: 1.072e+00
# adaptive_constant_bcs2_val: 1.072e+00
# It: 2200, Loss: 1.174e+01,  loss_bc1: 1.559e+00,  loss_bc2: 1.249e+00, loss_ics_u: 8.651e+00,  Loss_res: 2.804e-01,  Time: 3.98
# adaptive_constant_res_val: 1.290e-01
# adaptive_constant_ics_val: 1.845e+00
# adaptive_constant_bcs1_val: 9.394e-01
# adaptive_constant_bcs2_val: 9.394e-01
# It: 2300, Loss: 1.193e+01,  loss_bc1: 1.423e+00,  loss_bc2: 1.192e+00, loss_ics_u: 9.023e+00,  Loss_res: 2.905e-01,  Time: 4.00
# adaptive_constant_res_val: 1.886e-01
# adaptive_constant_ics_val: 2.922e+00
# adaptive_constant_bcs1_val: 8.690e-01
# adaptive_constant_bcs2_val: 8.690e-01
# It: 2400, Loss: 1.141e+01,  loss_bc1: 1.269e+00,  loss_bc2: 1.138e+00, loss_ics_u: 8.600e+00,  Loss_res: 4.010e-01,  Time: 4.04
# adaptive_constant_res_val: 2.482e-01
# adaptive_constant_ics_val: 2.793e+00
# adaptive_constant_bcs1_val: 8.304e-01
# adaptive_constant_bcs2_val: 8.304e-01
# It: 2500, Loss: 1.284e+01,  loss_bc1: 1.247e+00,  loss_bc2: 1.027e+00, loss_ics_u: 1.007e+01,  Loss_res: 4.969e-01,  Time: 4.09
# adaptive_constant_res_val: 3.174e-01
# adaptive_constant_ics_val: 5.253e+00
# adaptive_constant_bcs1_val: 6.913e-01
# adaptive_constant_bcs2_val: 6.913e-01
# It: 2600, Loss: 1.082e+01,  loss_bc1: 1.107e+00,  loss_bc2: 9.480e-01, loss_ics_u: 8.366e+00,  Loss_res: 3.965e-01,  Time: 4.04
# adaptive_constant_res_val: 3.131e-01
# adaptive_constant_ics_val: 2.037e+00
# adaptive_constant_bcs1_val: 7.391e-01
# adaptive_constant_bcs2_val: 7.391e-01
# It: 2700, Loss: 1.130e+01,  loss_bc1: 1.138e+00,  loss_bc2: 8.612e-01, loss_ics_u: 8.943e+00,  Loss_res: 3.621e-01,  Time: 4.04
# adaptive_constant_res_val: 3.468e-01
# adaptive_constant_ics_val: 4.591e+00
# adaptive_constant_bcs1_val: 8.524e-01
# adaptive_constant_bcs2_val: 8.524e-01
# It: 2800, Loss: 9.817e+00,  loss_bc1: 9.081e-01,  loss_bc2: 7.893e-01, loss_ics_u: 7.744e+00,  Loss_res: 3.759e-01,  Time: 4.17
# adaptive_constant_res_val: 2.520e-01
# adaptive_constant_ics_val: 1.153e+00
# adaptive_constant_bcs1_val: 8.931e-01
# adaptive_constant_bcs2_val: 8.931e-01
# It: 2900, Loss: 9.515e+00,  loss_bc1: 9.969e-01,  loss_bc2: 6.724e-01, loss_ics_u: 7.594e+00,  Loss_res: 2.518e-01,  Time: 4.06
# adaptive_constant_res_val: 1.479e-01
# adaptive_constant_ics_val: 2.289e+00
# adaptive_constant_bcs1_val: 1.158e+00
# adaptive_constant_bcs2_val: 1.158e+00
# It: 3000, Loss: 1.045e+01,  loss_bc1: 7.887e-01,  loss_bc2: 6.294e-01, loss_ics_u: 8.683e+00,  Loss_res: 3.461e-01,  Time: 3.95
# adaptive_constant_res_val: 2.972e-01
# adaptive_constant_ics_val: 3.936e+00
# adaptive_constant_bcs1_val: 1.055e+00
# adaptive_constant_bcs2_val: 1.055e+00
# It: 3100, Loss: 8.797e+00,  loss_bc1: 7.185e-01,  loss_bc2: 5.139e-01, loss_ics_u: 7.304e+00,  Loss_res: 2.605e-01,  Time: 3.95
# adaptive_constant_res_val: 1.673e-01
# adaptive_constant_ics_val: 1.281e+00
# adaptive_constant_bcs1_val: 9.932e-01
# adaptive_constant_bcs2_val: 9.932e-01
# It: 3200, Loss: 8.365e+00,  loss_bc1: 5.937e-01,  loss_bc2: 5.065e-01, loss_ics_u: 7.049e+00,  Loss_res: 2.165e-01,  Time: 3.99
# adaptive_constant_res_val: 1.564e-01
# adaptive_constant_ics_val: 8.835e-01
# adaptive_constant_bcs1_val: 6.460e-01
# adaptive_constant_bcs2_val: 6.460e-01
# It: 3300, Loss: 8.264e+00,  loss_bc1: 5.472e-01,  loss_bc2: 4.815e-01, loss_ics_u: 7.066e+00,  Loss_res: 1.694e-01,  Time: 3.96
# adaptive_constant_res_val: 1.913e-01
# adaptive_constant_ics_val: 1.784e+00
# adaptive_constant_bcs1_val: 6.338e-01
# adaptive_constant_bcs2_val: 6.338e-01
# It: 3400, Loss: 8.205e+00,  loss_bc1: 5.084e-01,  loss_bc2: 4.705e-01, loss_ics_u: 7.010e+00,  Loss_res: 2.163e-01,  Time: 4.03
# adaptive_constant_res_val: 1.899e-01
# adaptive_constant_ics_val: 2.941e+00
# adaptive_constant_bcs1_val: 6.317e-01
# adaptive_constant_bcs2_val: 6.317e-01
# It: 3500, Loss: 9.317e+00,  loss_bc1: 5.279e-01,  loss_bc2: 4.909e-01, loss_ics_u: 8.031e+00,  Loss_res: 2.672e-01,  Time: 4.41
# adaptive_constant_res_val: 3.260e-01
# adaptive_constant_ics_val: 6.538e+00
# adaptive_constant_bcs1_val: 8.185e-01
# adaptive_constant_bcs2_val: 8.185e-01
# It: 3600, Loss: 8.211e+00,  loss_bc1: 5.224e-01,  loss_bc2: 4.137e-01, loss_ics_u: 7.065e+00,  Loss_res: 2.094e-01,  Time: 3.97
# adaptive_constant_res_val: 1.703e-01
# adaptive_constant_ics_val: 3.911e+00
# adaptive_constant_bcs1_val: 6.768e-01
# adaptive_constant_bcs2_val: 6.768e-01
# It: 3700, Loss: 9.118e+00,  loss_bc1: 4.823e-01,  loss_bc2: 4.230e-01, loss_ics_u: 7.725e+00,  Loss_res: 4.873e-01,  Time: 4.41
# adaptive_constant_res_val: 8.106e-01
# adaptive_constant_ics_val: 6.221e+00
# adaptive_constant_bcs1_val: 6.090e-01
# adaptive_constant_bcs2_val: 6.090e-01
# It: 3800, Loss: 1.101e+01,  loss_bc1: 5.287e-01,  loss_bc2: 4.015e-01, loss_ics_u: 9.800e+00,  Loss_res: 2.848e-01,  Time: 4.13
# adaptive_constant_res_val: 3.533e-01
# adaptive_constant_ics_val: 1.091e+01
# adaptive_constant_bcs1_val: 5.097e-01
# adaptive_constant_bcs2_val: 5.097e-01
# It: 3900, Loss: 7.407e+00,  loss_bc1: 4.765e-01,  loss_bc2: 4.645e-01, loss_ics_u: 6.144e+00,  Loss_res: 3.213e-01,  Time: 4.42
# adaptive_constant_res_val: 3.950e-01
# adaptive_constant_ics_val: 1.280e+00
# adaptive_constant_bcs1_val: 6.868e-01
# adaptive_constant_bcs2_val: 6.868e-01
# It: 4000, Loss: 7.314e+00,  loss_bc1: 5.421e-01,  loss_bc2: 4.552e-01, loss_ics_u: 6.008e+00,  Loss_res: 3.088e-01,  Time: 4.52
# adaptive_constant_res_val: 2.064e-01
# adaptive_constant_ics_val: 1.506e+00
# adaptive_constant_bcs1_val: 8.429e-01
# adaptive_constant_bcs2_val: 8.429e-01
# It: 4100, Loss: 6.899e+00,  loss_bc1: 5.074e-01,  loss_bc2: 4.614e-01, loss_ics_u: 5.695e+00,  Loss_res: 2.347e-01,  Time: 3.97
# adaptive_constant_res_val: 1.212e-01
# adaptive_constant_ics_val: 1.742e+00
# adaptive_constant_bcs1_val: 5.464e-01
# adaptive_constant_bcs2_val: 5.464e-01
# It: 4200, Loss: 1.056e+01,  loss_bc1: 7.235e-01,  loss_bc2: 4.359e-01, loss_ics_u: 7.834e+00,  Loss_res: 1.569e+00,  Time: 4.04
# adaptive_constant_res_val: 1.626e+00
# adaptive_constant_ics_val: 7.814e+00
# adaptive_constant_bcs1_val: 8.790e-01
# adaptive_constant_bcs2_val: 8.790e-01
# It: 4300, Loss: 1.007e+01,  loss_bc1: 6.527e-01,  loss_bc2: 6.399e-01, loss_ics_u: 8.101e+00,  Loss_res: 6.796e-01,  Time: 4.05
# adaptive_constant_res_val: 9.012e-01
# adaptive_constant_ics_val: 5.929e+00
# adaptive_constant_bcs1_val: 1.196e+00
# adaptive_constant_bcs2_val: 1.196e+00
# It: 4400, Loss: 7.178e+00,  loss_bc1: 4.498e-01,  loss_bc2: 3.925e-01, loss_ics_u: 5.996e+00,  Loss_res: 3.393e-01,  Time: 3.91
# adaptive_constant_res_val: 3.909e-01
# adaptive_constant_ics_val: 5.755e+00
# adaptive_constant_bcs1_val: 4.586e-01
# adaptive_constant_bcs2_val: 4.586e-01
# It: 4500, Loss: 6.572e+00,  loss_bc1: 4.490e-01,  loss_bc2: 4.680e-01, loss_ics_u: 5.368e+00,  Loss_res: 2.868e-01,  Time: 3.99
# adaptive_constant_res_val: 2.253e-01
# adaptive_constant_ics_val: 4.495e+00
# adaptive_constant_bcs1_val: 5.432e-01
# adaptive_constant_bcs2_val: 5.432e-01
# It: 4600, Loss: 8.498e+00,  loss_bc1: 5.008e-01,  loss_bc2: 4.991e-01, loss_ics_u: 7.005e+00,  Loss_res: 4.928e-01,  Time: 3.99
# adaptive_constant_res_val: 5.335e-01
# adaptive_constant_ics_val: 9.399e+00
# adaptive_constant_bcs1_val: 7.137e-01
# adaptive_constant_bcs2_val: 7.137e-01
# It: 4700, Loss: 6.042e+00,  loss_bc1: 4.983e-01,  loss_bc2: 4.200e-01, loss_ics_u: 4.731e+00,  Loss_res: 3.935e-01,  Time: 4.14
# adaptive_constant_res_val: 2.659e-01
# adaptive_constant_ics_val: 2.947e+00
# adaptive_constant_bcs1_val: 7.038e-01
# adaptive_constant_bcs2_val: 7.038e-01
# It: 4800, Loss: 5.871e+00,  loss_bc1: 4.668e-01,  loss_bc2: 4.486e-01, loss_ics_u: 4.674e+00,  Loss_res: 2.816e-01,  Time: 3.90
# adaptive_constant_res_val: 3.518e-01
# adaptive_constant_ics_val: 4.212e+00
# adaptive_constant_bcs1_val: 3.256e-01
# adaptive_constant_bcs2_val: 3.256e-01
# It: 4900, Loss: 5.753e+00,  loss_bc1: 4.717e-01,  loss_bc2: 4.115e-01, loss_ics_u: 4.361e+00,  Loss_res: 5.083e-01,  Time: 3.98
# adaptive_constant_res_val: 3.556e-01
# adaptive_constant_ics_val: 1.588e+00
# adaptive_constant_bcs1_val: 7.137e-01
# adaptive_constant_bcs2_val: 7.137e-01
# It: 5000, Loss: 5.369e+00,  loss_bc1: 4.810e-01,  loss_bc2: 4.964e-01, loss_ics_u: 4.070e+00,  Loss_res: 3.223e-01,  Time: 4.03
# adaptive_constant_res_val: 2.561e-01
# adaptive_constant_ics_val: 1.923e+00
# adaptive_constant_bcs1_val: 5.117e-01
# adaptive_constant_bcs2_val: 5.117e-01
# It: 5100, Loss: 7.762e+00,  loss_bc1: 5.005e-01,  loss_bc2: 6.103e-01, loss_ics_u: 6.037e+00,  Loss_res: 6.134e-01,  Time: 3.95
# adaptive_constant_res_val: 9.337e-01
# adaptive_constant_ics_val: 8.409e+00
# adaptive_constant_bcs1_val: 8.859e-01
# adaptive_constant_bcs2_val: 8.859e-01
# It: 5200, Loss: 5.683e+00,  loss_bc1: 4.577e-01,  loss_bc2: 4.314e-01, loss_ics_u: 4.378e+00,  Loss_res: 4.162e-01,  Time: 3.97
# adaptive_constant_res_val: 5.592e-01
# adaptive_constant_ics_val: 4.860e+00
# adaptive_constant_bcs1_val: 5.879e-01
# adaptive_constant_bcs2_val: 5.879e-01
# It: 5300, Loss: 2.075e+01,  loss_bc1: 5.018e-01,  loss_bc2: 4.545e-01, loss_ics_u: 1.871e+01,  Loss_res: 1.082e+00,  Time: 3.90
# adaptive_constant_res_val: 1.573e+00
# adaptive_constant_ics_val: 2.629e+01
# adaptive_constant_bcs1_val: 5.902e-01
# adaptive_constant_bcs2_val: 5.902e-01
# It: 5400, Loss: 5.647e+00,  loss_bc1: 4.629e-01,  loss_bc2: 4.579e-01, loss_ics_u: 4.288e+00,  Loss_res: 4.389e-01,  Time: 3.93
# adaptive_constant_res_val: 5.753e-01
# adaptive_constant_ics_val: 4.566e+00
# adaptive_constant_bcs1_val: 3.228e-01
# adaptive_constant_bcs2_val: 3.228e-01
# It: 5500, Loss: 9.142e+00,  loss_bc1: 4.022e-01,  loss_bc2: 4.206e-01, loss_ics_u: 7.835e+00,  Loss_res: 4.840e-01,  Time: 3.97
# adaptive_constant_res_val: 7.773e-01
# adaptive_constant_ics_val: 1.484e+01
# adaptive_constant_bcs1_val: 2.538e-01
# adaptive_constant_bcs2_val: 2.538e-01
# It: 5600, Loss: 4.664e+00,  loss_bc1: 4.307e-01,  loss_bc2: 4.135e-01, loss_ics_u: 3.608e+00,  Loss_res: 2.121e-01,  Time: 3.95
# adaptive_constant_res_val: 1.763e-01
# adaptive_constant_ics_val: 2.097e+00
# adaptive_constant_bcs1_val: 4.054e-01
# adaptive_constant_bcs2_val: 4.054e-01
# It: 5700, Loss: 9.915e+00,  loss_bc1: 4.014e-01,  loss_bc2: 4.499e-01, loss_ics_u: 8.723e+00,  Loss_res: 3.405e-01,  Time: 3.91
# adaptive_constant_res_val: 4.901e-01
# adaptive_constant_ics_val: 1.709e+01
# adaptive_constant_bcs1_val: 2.051e-01
# adaptive_constant_bcs2_val: 2.051e-01
# It: 5800, Loss: 8.448e+00,  loss_bc1: 4.797e-01,  loss_bc2: 4.664e-01, loss_ics_u: 7.281e+00,  Loss_res: 2.214e-01,  Time: 3.94
# adaptive_constant_res_val: 5.149e-01
# adaptive_constant_ics_val: 1.541e+01
# adaptive_constant_bcs1_val: 7.499e-01
# adaptive_constant_bcs2_val: 7.499e-01
# It: 5900, Loss: 5.999e+00,  loss_bc1: 4.450e-01,  loss_bc2: 4.262e-01, loss_ics_u: 4.707e+00,  Loss_res: 4.207e-01,  Time: 4.05
# adaptive_constant_res_val: 4.580e-01
# adaptive_constant_ics_val: 9.259e+00
# adaptive_constant_bcs1_val: 3.312e-01
# adaptive_constant_bcs2_val: 3.312e-01
# It: 6000, Loss: 4.430e+00,  loss_bc1: 4.711e-01,  loss_bc2: 4.067e-01, loss_ics_u: 3.194e+00,  Loss_res: 3.575e-01,  Time: 3.94
# adaptive_constant_res_val: 3.291e-01
# adaptive_constant_ics_val: 1.444e+00
# adaptive_constant_bcs1_val: 5.065e-01
# adaptive_constant_bcs2_val: 5.065e-01
# It: 6100, Loss: 4.470e+00,  loss_bc1: 4.471e-01,  loss_bc2: 3.811e-01, loss_ics_u: 3.233e+00,  Loss_res: 4.082e-01,  Time: 3.94
# adaptive_constant_res_val: 5.382e-01
# adaptive_constant_ics_val: 2.467e+00
# adaptive_constant_bcs1_val: 3.885e-01
# adaptive_constant_bcs2_val: 3.885e-01
# It: 6200, Loss: 4.117e+00,  loss_bc1: 4.403e-01,  loss_bc2: 4.444e-01, loss_ics_u: 3.022e+00,  Loss_res: 2.098e-01,  Time: 3.90
# adaptive_constant_res_val: 2.218e-01
# adaptive_constant_ics_val: 1.320e+00
# adaptive_constant_bcs1_val: 3.762e-01
# adaptive_constant_bcs2_val: 3.762e-01
# It: 6300, Loss: 4.377e+00,  loss_bc1: 4.698e-01,  loss_bc2: 4.378e-01, loss_ics_u: 3.154e+00,  Loss_res: 3.154e-01,  Time: 3.95
# adaptive_constant_res_val: 3.451e-01
# adaptive_constant_ics_val: 4.568e+00
# adaptive_constant_bcs1_val: 5.789e-01
# adaptive_constant_bcs2_val: 5.789e-01
# It: 6400, Loss: 4.422e+00,  loss_bc1: 5.001e-01,  loss_bc2: 4.439e-01, loss_ics_u: 3.165e+00,  Loss_res: 3.125e-01,  Time: 3.92
# adaptive_constant_res_val: 5.022e-01
# adaptive_constant_ics_val: 4.713e+00
# adaptive_constant_bcs1_val: 6.363e-01
# adaptive_constant_bcs2_val: 6.363e-01
# It: 6500, Loss: 4.421e+00,  loss_bc1: 4.473e-01,  loss_bc2: 4.097e-01, loss_ics_u: 3.289e+00,  Loss_res: 2.752e-01,  Time: 3.91
# adaptive_constant_res_val: 6.502e-01
# adaptive_constant_ics_val: 5.841e+00
# adaptive_constant_bcs1_val: 3.559e-01
# adaptive_constant_bcs2_val: 3.559e-01
# It: 6600, Loss: 3.905e+00,  loss_bc1: 4.695e-01,  loss_bc2: 4.382e-01, loss_ics_u: 2.787e+00,  Loss_res: 2.110e-01,  Time: 3.95
# adaptive_constant_res_val: 3.942e-01
# adaptive_constant_ics_val: 2.762e+00
# adaptive_constant_bcs1_val: 2.915e-01
# adaptive_constant_bcs2_val: 2.915e-01
# It: 6700, Loss: 4.434e+00,  loss_bc1: 4.758e-01,  loss_bc2: 3.648e-01, loss_ics_u: 3.213e+00,  Loss_res: 3.801e-01,  Time: 3.97
# adaptive_constant_res_val: 8.184e-01
# adaptive_constant_ics_val: 5.254e+00
# adaptive_constant_bcs1_val: 3.653e-01
# adaptive_constant_bcs2_val: 3.653e-01
# It: 6800, Loss: 4.037e+00,  loss_bc1: 5.054e-01,  loss_bc2: 3.718e-01, loss_ics_u: 2.800e+00,  Loss_res: 3.601e-01,  Time: 3.91
# adaptive_constant_res_val: 8.777e-01
# adaptive_constant_ics_val: 3.845e+00
# adaptive_constant_bcs1_val: 6.200e-01
# adaptive_constant_bcs2_val: 6.200e-01
# It: 6900, Loss: 5.423e+00,  loss_bc1: 5.007e-01,  loss_bc2: 4.056e-01, loss_ics_u: 4.105e+00,  Loss_res: 4.116e-01,  Time: 3.95
# adaptive_constant_res_val: 4.882e-01
# adaptive_constant_ics_val: 9.867e+00
# adaptive_constant_bcs1_val: 7.017e-01
# adaptive_constant_bcs2_val: 7.017e-01
# It: 7000, Loss: 3.651e+00,  loss_bc1: 4.796e-01,  loss_bc2: 3.937e-01, loss_ics_u: 2.551e+00,  Loss_res: 2.264e-01,  Time: 3.94
# adaptive_constant_res_val: 5.191e-01
# adaptive_constant_ics_val: 3.829e+00
# adaptive_constant_bcs1_val: 3.371e-01
# adaptive_constant_bcs2_val: 3.371e-01
# It: 7100, Loss: 4.161e+00,  loss_bc1: 4.547e-01,  loss_bc2: 3.935e-01, loss_ics_u: 2.997e+00,  Loss_res: 3.151e-01,  Time: 3.92
# adaptive_constant_res_val: 8.574e-01
# adaptive_constant_ics_val: 6.580e+00
# adaptive_constant_bcs1_val: 3.680e-01
# adaptive_constant_bcs2_val: 3.680e-01
# It: 7200, Loss: 3.818e+00,  loss_bc1: 4.535e-01,  loss_bc2: 3.924e-01, loss_ics_u: 2.706e+00,  Loss_res: 2.662e-01,  Time: 3.92
# adaptive_constant_res_val: 3.059e-01
# adaptive_constant_ics_val: 6.651e+00
# adaptive_constant_bcs1_val: 2.043e-01
# adaptive_constant_bcs2_val: 2.043e-01
# It: 7300, Loss: 5.402e+00,  loss_bc1: 4.671e-01,  loss_bc2: 3.832e-01, loss_ics_u: 4.049e+00,  Loss_res: 5.025e-01,  Time: 3.91
# adaptive_constant_res_val: 1.580e+00
# adaptive_constant_ics_val: 1.287e+01
# adaptive_constant_bcs1_val: 3.480e-01
# adaptive_constant_bcs2_val: 3.480e-01
# It: 7400, Loss: 3.193e+00,  loss_bc1: 5.379e-01,  loss_bc2: 3.893e-01, loss_ics_u: 2.105e+00,  Loss_res: 1.602e-01,  Time: 3.90
# adaptive_constant_res_val: 3.395e-01
# adaptive_constant_ics_val: 2.420e+00
# adaptive_constant_bcs1_val: 5.243e-01
# adaptive_constant_bcs2_val: 5.243e-01
# It: 7500, Loss: 3.211e+00,  loss_bc1: 4.798e-01,  loss_bc2: 3.938e-01, loss_ics_u: 2.114e+00,  Loss_res: 2.240e-01,  Time: 3.97
# adaptive_constant_res_val: 4.421e-01
# adaptive_constant_ics_val: 3.825e+00
# adaptive_constant_bcs1_val: 3.749e-01
# adaptive_constant_bcs2_val: 3.749e-01
# It: 7600, Loss: 3.610e+00,  loss_bc1: 4.765e-01,  loss_bc2: 3.990e-01, loss_ics_u: 2.492e+00,  Loss_res: 2.420e-01,  Time: 3.94
# adaptive_constant_res_val: 6.981e-01
# adaptive_constant_ics_val: 6.530e+00
# adaptive_constant_bcs1_val: 2.807e-01
# adaptive_constant_bcs2_val: 2.807e-01
# It: 7700, Loss: 3.395e+00,  loss_bc1: 4.429e-01,  loss_bc2: 3.720e-01, loss_ics_u: 2.294e+00,  Loss_res: 2.854e-01,  Time: 3.95
# adaptive_constant_res_val: 7.652e-01
# adaptive_constant_ics_val: 5.082e+00
# adaptive_constant_bcs1_val: 2.383e-01
# adaptive_constant_bcs2_val: 2.383e-01
# It: 7800, Loss: 2.976e+00,  loss_bc1: 4.676e-01,  loss_bc2: 3.927e-01, loss_ics_u: 1.955e+00,  Loss_res: 1.610e-01,  Time: 3.92
# adaptive_constant_res_val: 5.900e-01
# adaptive_constant_ics_val: 3.772e+00
# adaptive_constant_bcs1_val: 3.235e-01
# adaptive_constant_bcs2_val: 3.235e-01
# It: 7900, Loss: 2.754e+00,  loss_bc1: 4.739e-01,  loss_bc2: 3.873e-01, loss_ics_u: 1.715e+00,  Loss_res: 1.780e-01,  Time: 4.01
# adaptive_constant_res_val: 3.703e-01
# adaptive_constant_ics_val: 7.383e-01
# adaptive_constant_bcs1_val: 3.040e-01
# adaptive_constant_bcs2_val: 3.040e-01
# It: 8000, Loss: 3.682e+00,  loss_bc1: 4.959e-01,  loss_bc2: 4.195e-01, loss_ics_u: 2.142e+00,  Loss_res: 6.243e-01,  Time: 4.33
# adaptive_constant_res_val: 1.956e+00
# adaptive_constant_ics_val: 3.767e+00
# adaptive_constant_bcs1_val: 4.343e-01
# adaptive_constant_bcs2_val: 4.343e-01
# It: 8100, Loss: 2.734e+00,  loss_bc1: 4.908e-01,  loss_bc2: 3.857e-01, loss_ics_u: 1.688e+00,  Loss_res: 1.698e-01,  Time: 4.35
# adaptive_constant_res_val: 5.918e-01
# adaptive_constant_ics_val: 2.650e+00
# adaptive_constant_bcs1_val: 3.973e-01
# adaptive_constant_bcs2_val: 3.973e-01
# It: 8200, Loss: 2.563e+00,  loss_bc1: 4.789e-01,  loss_bc2: 3.665e-01, loss_ics_u: 1.573e+00,  Loss_res: 1.447e-01,  Time: 4.37
# adaptive_constant_res_val: 2.005e-01
# adaptive_constant_ics_val: 1.521e+00
# adaptive_constant_bcs1_val: 3.623e-01
# adaptive_constant_bcs2_val: 3.623e-01
# It: 8300, Loss: 2.758e+00,  loss_bc1: 4.920e-01,  loss_bc2: 3.727e-01, loss_ics_u: 1.665e+00,  Loss_res: 2.290e-01,  Time: 4.29
# adaptive_constant_res_val: 4.318e-01
# adaptive_constant_ics_val: 3.471e+00
# adaptive_constant_bcs1_val: 3.700e-01
# adaptive_constant_bcs2_val: 3.700e-01
# It: 8400, Loss: 2.912e+00,  loss_bc1: 4.637e-01,  loss_bc2: 3.928e-01, loss_ics_u: 1.804e+00,  Loss_res: 2.509e-01,  Time: 4.00
# adaptive_constant_res_val: 5.828e-01
# adaptive_constant_ics_val: 5.813e+00
# adaptive_constant_bcs1_val: 2.159e-01
# adaptive_constant_bcs2_val: 2.159e-01
# It: 8500, Loss: 2.843e+00,  loss_bc1: 5.051e-01,  loss_bc2: 3.903e-01, loss_ics_u: 1.582e+00,  Loss_res: 3.657e-01,  Time: 3.93
# adaptive_constant_res_val: 1.503e+00
# adaptive_constant_ics_val: 3.631e+00
# adaptive_constant_bcs1_val: 3.179e-01
# adaptive_constant_bcs2_val: 3.179e-01
# It: 8600, Loss: 2.674e+00,  loss_bc1: 4.756e-01,  loss_bc2: 4.319e-01, loss_ics_u: 1.547e+00,  Loss_res: 2.195e-01,  Time: 3.97
# adaptive_constant_res_val: 6.966e-01
# adaptive_constant_ics_val: 3.397e+00
# adaptive_constant_bcs1_val: 3.184e-01
# adaptive_constant_bcs2_val: 3.184e-01
# It: 8700, Loss: 2.652e+00,  loss_bc1: 4.999e-01,  loss_bc2: 3.941e-01, loss_ics_u: 1.515e+00,  Loss_res: 2.433e-01,  Time: 4.05
# adaptive_constant_res_val: 6.571e-01
# adaptive_constant_ics_val: 4.398e+00
# adaptive_constant_bcs1_val: 1.899e-01
# adaptive_constant_bcs2_val: 1.899e-01
# It: 8800, Loss: 2.444e+00,  loss_bc1: 5.035e-01,  loss_bc2: 3.874e-01, loss_ics_u: 1.322e+00,  Loss_res: 2.315e-01,  Time: 3.91
# adaptive_constant_res_val: 7.667e-01
# adaptive_constant_ics_val: 3.034e+00
# adaptive_constant_bcs1_val: 3.108e-01
# adaptive_constant_bcs2_val: 3.108e-01
# It: 8900, Loss: 2.298e+00,  loss_bc1: 5.071e-01,  loss_bc2: 3.916e-01, loss_ics_u: 1.231e+00,  Loss_res: 1.680e-01,  Time: 3.97
# adaptive_constant_res_val: 5.603e-01
# adaptive_constant_ics_val: 2.356e+00
# adaptive_constant_bcs1_val: 3.537e-01
# adaptive_constant_bcs2_val: 3.537e-01
# It: 9000, Loss: 2.295e+00,  loss_bc1: 4.958e-01,  loss_bc2: 3.918e-01, loss_ics_u: 1.247e+00,  Loss_res: 1.606e-01,  Time: 4.07
# adaptive_constant_res_val: 4.544e-01
# adaptive_constant_ics_val: 2.507e+00
# adaptive_constant_bcs1_val: 3.345e-01
# adaptive_constant_bcs2_val: 3.345e-01
# It: 9100, Loss: 2.203e+00,  loss_bc1: 4.886e-01,  loss_bc2: 3.687e-01, loss_ics_u: 1.199e+00,  Loss_res: 1.465e-01,  Time: 3.93
# adaptive_constant_res_val: 4.118e-01
# adaptive_constant_ics_val: 8.719e-01
# adaptive_constant_bcs1_val: 3.272e-01
# adaptive_constant_bcs2_val: 3.272e-01
# It: 9200, Loss: 5.046e+00,  loss_bc1: 5.111e-01,  loss_bc2: 3.768e-01, loss_ics_u: 3.923e+00,  Loss_res: 2.356e-01,  Time: 10.07
# adaptive_constant_res_val: 7.664e-01
# adaptive_constant_ics_val: 1.676e+01
# adaptive_constant_bcs1_val: 2.735e-01
# adaptive_constant_bcs2_val: 2.735e-01
# It: 9300, Loss: 2.379e+00,  loss_bc1: 4.782e-01,  loss_bc2: 3.917e-01, loss_ics_u: 1.341e+00,  Loss_res: 1.682e-01,  Time: 4.03
# adaptive_constant_res_val: 5.666e-01
# adaptive_constant_ics_val: 5.355e+00
# adaptive_constant_bcs1_val: 2.663e-01
# adaptive_constant_bcs2_val: 2.663e-01
# It: 9400, Loss: 2.469e+00,  loss_bc1: 4.823e-01,  loss_bc2: 3.860e-01, loss_ics_u: 1.407e+00,  Loss_res: 1.934e-01,  Time: 4.70
# adaptive_constant_res_val: 5.670e-01
# adaptive_constant_ics_val: 6.399e+00
# adaptive_constant_bcs1_val: 3.039e-01
# adaptive_constant_bcs2_val: 3.039e-01
# It: 9500, Loss: 2.221e+00,  loss_bc1: 4.777e-01,  loss_bc2: 3.888e-01, loss_ics_u: 1.179e+00,  Loss_res: 1.755e-01,  Time: 4.66
# adaptive_constant_res_val: 5.759e-01
# adaptive_constant_ics_val: 4.722e+00
# adaptive_constant_bcs1_val: 2.968e-01
# adaptive_constant_bcs2_val: 2.968e-01
# It: 9600, Loss: 1.994e+00,  loss_bc1: 4.879e-01,  loss_bc2: 3.965e-01, loss_ics_u: 9.917e-01,  Loss_res: 1.181e-01,  Time: 6.70
# adaptive_constant_res_val: 2.896e-01
# adaptive_constant_ics_val: 1.231e+00
# adaptive_constant_bcs1_val: 3.938e-01
# adaptive_constant_bcs2_val: 3.938e-01
# It: 9700, Loss: 1.988e+00,  loss_bc1: 4.539e-01,  loss_bc2: 3.797e-01, loss_ics_u: 1.030e+00,  Loss_res: 1.239e-01,  Time: 4.84
# adaptive_constant_res_val: 3.311e-01
# adaptive_constant_ics_val: 1.601e+00
# adaptive_constant_bcs1_val: 1.611e-01
# adaptive_constant_bcs2_val: 1.611e-01
# ...
# adaptive_constant_bcs1_val: 2.135e-02
# adaptive_constant_bcs2_val: 2.135e-02
# It: 36800, Loss: 9.236e-02,  loss_bc1: 2.128e-02,  loss_bc2: 3.361e-02, loss_ics_u: 1.688e-02,  Loss_res: 2.060e-02,  Time: 3.72
# adaptive_constant_res_val: 4.394e-01
# adaptive_constant_ics_val: 5.605e-01
# adaptive_constant_bcs1_val: 1.118e-02
# adaptive_constant_bcs2_val: 1.118e-02
# It: 36900, Loss: 9.719e-02,  loss_bc1: 2.073e-02,  loss_bc2: 3.322e-02, loss_ics_u: 1.720e-02,  Loss_res: 2.604e-02,  Time: 3.74
# adaptive_constant_res_val: 9.970e-02
# adaptive_constant_ics_val: 5.152e-01
# adaptive_constant_bcs1_val: 1.401e-02
# adaptive_constant_bcs2_val: 1.401e-02
# It: 37000, Loss: 9.118e-02,  loss_bc1: 2.057e-02,  loss_bc2: 3.305e-02, loss_ics_u: 1.839e-02,  Loss_res: 1.917e-02,  Time: 3.78
# adaptive_constant_res_val: 1.254e-01
# adaptive_constant_ics_val: 8.001e-01
# adaptive_constant_bcs1_val: 1.667e-02
# adaptive_constant_bcs2_val: 1.667e-02
# It: 37100, Loss: 9.207e-02,  loss_bc1: 2.059e-02,  loss_bc2: 3.284e-02, loss_ics_u: 1.678e-02,  Loss_res: 2.186e-02,  Time: 3.79
# adaptive_constant_res_val: 4.106e-01
# adaptive_constant_ics_val: 6.281e-01
# adaptive_constant_bcs1_val: 1.379e-02
# adaptive_constant_bcs2_val: 1.379e-02
# It: 37200, Loss: 9.313e-02,  loss_bc1: 2.046e-02,  loss_bc2: 3.227e-02, loss_ics_u: 1.901e-02,  Loss_res: 2.139e-02,  Time: 3.82
# adaptive_constant_res_val: 4.413e-01
# adaptive_constant_ics_val: 8.641e-01
# adaptive_constant_bcs1_val: 3.610e-02
# adaptive_constant_bcs2_val: 3.610e-02
# It: 37300, Loss: 1.220e-01,  loss_bc1: 1.984e-02,  loss_bc2: 3.173e-02, loss_ics_u: 4.387e-02,  Loss_res: 2.656e-02,  Time: 3.79
# adaptive_constant_res_val: 6.079e-01
# adaptive_constant_ics_val: 2.413e+00
# adaptive_constant_bcs1_val: 1.490e-02
# adaptive_constant_bcs2_val: 1.490e-02
# It: 37400, Loss: 8.748e-02,  loss_bc1: 1.950e-02,  loss_bc2: 3.150e-02, loss_ics_u: 1.536e-02,  Loss_res: 2.113e-02,  Time: 3.78
# adaptive_constant_res_val: 2.533e-01
# adaptive_constant_ics_val: 3.288e-01
# adaptive_constant_bcs1_val: 1.417e-02
# adaptive_constant_bcs2_val: 1.417e-02
# It: 37500, Loss: 9.051e-02,  loss_bc1: 1.908e-02,  loss_bc2: 3.078e-02, loss_ics_u: 1.906e-02,  Loss_res: 2.159e-02,  Time: 3.80
# adaptive_constant_res_val: 4.785e-01
# adaptive_constant_ics_val: 9.150e-01
# adaptive_constant_bcs1_val: 1.658e-02
# adaptive_constant_bcs2_val: 1.658e-02
# It: 37600, Loss: 8.860e-02,  loss_bc1: 1.904e-02,  loss_bc2: 3.072e-02, loss_ics_u: 1.557e-02,  Loss_res: 2.326e-02,  Time: 3.72
# adaptive_constant_res_val: 3.126e-01
# adaptive_constant_ics_val: 3.762e-01
# adaptive_constant_bcs1_val: 1.894e-02
# adaptive_constant_bcs2_val: 1.894e-02
# It: 37700, Loss: 9.039e-02,  loss_bc1: 1.860e-02,  loss_bc2: 3.071e-02, loss_ics_u: 2.132e-02,  Loss_res: 1.976e-02,  Time: 3.75
# adaptive_constant_res_val: 2.724e-01
# adaptive_constant_ics_val: 9.831e-01
# adaptive_constant_bcs1_val: 2.294e-02
# adaptive_constant_bcs2_val: 2.294e-02
# It: 37800, Loss: 8.612e-02,  loss_bc1: 1.861e-02,  loss_bc2: 3.013e-02, loss_ics_u: 1.838e-02,  Loss_res: 1.900e-02,  Time: 3.81
# adaptive_constant_res_val: 3.055e-01
# adaptive_constant_ics_val: 9.071e-01
# adaptive_constant_bcs1_val: 3.424e-02
# adaptive_constant_bcs2_val: 3.424e-02
# It: 37900, Loss: 9.008e-02,  loss_bc1: 1.840e-02,  loss_bc2: 2.970e-02, loss_ics_u: 1.748e-02,  Loss_res: 2.449e-02,  Time: 3.76
# adaptive_constant_res_val: 3.489e-01
# adaptive_constant_ics_val: 5.176e-01
# adaptive_constant_bcs1_val: 3.367e-02
# adaptive_constant_bcs2_val: 3.367e-02
# It: 38000, Loss: 8.128e-02,  loss_bc1: 1.803e-02,  loss_bc2: 2.948e-02, loss_ics_u: 1.585e-02,  Loss_res: 1.792e-02,  Time: 3.72
# adaptive_constant_res_val: 2.560e-01
# adaptive_constant_ics_val: 4.712e-01
# adaptive_constant_bcs1_val: 3.244e-02
# adaptive_constant_bcs2_val: 3.244e-02
# It: 38100, Loss: 8.185e-02,  loss_bc1: 1.806e-02,  loss_bc2: 2.901e-02, loss_ics_u: 1.562e-02,  Loss_res: 1.917e-02,  Time: 3.81
# adaptive_constant_res_val: 4.351e-01
# adaptive_constant_ics_val: 5.537e-01
# adaptive_constant_bcs1_val: 2.521e-02
# adaptive_constant_bcs2_val: 2.521e-02
# It: 38200, Loss: 8.175e-02,  loss_bc1: 1.762e-02,  loss_bc2: 2.907e-02, loss_ics_u: 1.556e-02,  Loss_res: 1.950e-02,  Time: 3.76
# adaptive_constant_res_val: 3.554e-01
# adaptive_constant_ics_val: 5.574e-01
# adaptive_constant_bcs1_val: 1.411e-02
# adaptive_constant_bcs2_val: 1.411e-02
# It: 38300, Loss: 8.275e-02,  loss_bc1: 1.739e-02,  loss_bc2: 2.875e-02, loss_ics_u: 1.525e-02,  Loss_res: 2.136e-02,  Time: 3.79
# adaptive_constant_res_val: 6.201e-01
# adaptive_constant_ics_val: 4.144e-01
# adaptive_constant_bcs1_val: 1.877e-02
# adaptive_constant_bcs2_val: 1.877e-02
# It: 38400, Loss: 8.138e-02,  loss_bc1: 1.698e-02,  loss_bc2: 2.844e-02, loss_ics_u: 1.620e-02,  Loss_res: 1.977e-02,  Time: 3.73
# adaptive_constant_res_val: 4.338e-01
# adaptive_constant_ics_val: 6.496e-01
# adaptive_constant_bcs1_val: 1.082e-02
# adaptive_constant_bcs2_val: 1.082e-02
# It: 38500, Loss: 8.154e-02,  loss_bc1: 1.686e-02,  loss_bc2: 2.814e-02, loss_ics_u: 1.483e-02,  Loss_res: 2.172e-02,  Time: 3.79
# adaptive_constant_res_val: 3.359e-01
# adaptive_constant_ics_val: 3.046e-01
# adaptive_constant_bcs1_val: 1.433e-02
# adaptive_constant_bcs2_val: 1.433e-02
# It: 38600, Loss: 7.963e-02,  loss_bc1: 1.682e-02,  loss_bc2: 2.787e-02, loss_ics_u: 1.560e-02,  Loss_res: 1.933e-02,  Time: 3.80
# adaptive_constant_res_val: 2.651e-01
# adaptive_constant_ics_val: 5.996e-01
# adaptive_constant_bcs1_val: 2.680e-02
# adaptive_constant_bcs2_val: 2.680e-02
# It: 38700, Loss: 8.789e-02,  loss_bc1: 1.682e-02,  loss_bc2: 2.762e-02, loss_ics_u: 1.600e-02,  Loss_res: 2.745e-02,  Time: 3.83
# adaptive_constant_res_val: 5.983e-01
# adaptive_constant_ics_val: 7.567e-01
# adaptive_constant_bcs1_val: 3.011e-02
# adaptive_constant_bcs2_val: 3.011e-02
# It: 38800, Loss: 8.005e-02,  loss_bc1: 1.651e-02,  loss_bc2: 2.748e-02, loss_ics_u: 1.533e-02,  Loss_res: 2.074e-02,  Time: 3.79
# adaptive_constant_res_val: 3.933e-01
# adaptive_constant_ics_val: 3.515e-01
# adaptive_constant_bcs1_val: 3.013e-02
# adaptive_constant_bcs2_val: 3.013e-02
# It: 38900, Loss: 7.771e-02,  loss_bc1: 1.609e-02,  loss_bc2: 2.711e-02, loss_ics_u: 1.616e-02,  Loss_res: 1.835e-02,  Time: 3.80
# adaptive_constant_res_val: 2.679e-01
# adaptive_constant_ics_val: 7.517e-01
# adaptive_constant_bcs1_val: 1.221e-02
# adaptive_constant_bcs2_val: 1.221e-02
# It: 39000, Loss: 7.430e-02,  loss_bc1: 1.592e-02,  loss_bc2: 2.673e-02, loss_ics_u: 1.410e-02,  Loss_res: 1.754e-02,  Time: 3.77
# adaptive_constant_res_val: 1.674e-01
# adaptive_constant_ics_val: 3.269e-01
# adaptive_constant_bcs1_val: 1.096e-02
# adaptive_constant_bcs2_val: 1.096e-02
# It: 39100, Loss: 8.156e-02,  loss_bc1: 1.591e-02,  loss_bc2: 2.677e-02, loss_ics_u: 1.676e-02,  Loss_res: 2.213e-02,  Time: 3.75
# adaptive_constant_res_val: 4.478e-01
# adaptive_constant_ics_val: 8.152e-01
# adaptive_constant_bcs1_val: 2.909e-02
# adaptive_constant_bcs2_val: 2.909e-02
# It: 39200, Loss: 8.104e-02,  loss_bc1: 1.546e-02,  loss_bc2: 2.634e-02, loss_ics_u: 1.546e-02,  Loss_res: 2.378e-02,  Time: 3.74
# adaptive_constant_res_val: 3.015e-01
# adaptive_constant_ics_val: 6.652e-01
# adaptive_constant_bcs1_val: 1.463e-02
# adaptive_constant_bcs2_val: 1.463e-02
# It: 39300, Loss: 7.572e-02,  loss_bc1: 1.538e-02,  loss_bc2: 2.603e-02, loss_ics_u: 1.498e-02,  Loss_res: 1.932e-02,  Time: 3.76
# adaptive_constant_res_val: 1.865e-01
# adaptive_constant_ics_val: 6.189e-01
# adaptive_constant_bcs1_val: 1.792e-02
# adaptive_constant_bcs2_val: 1.792e-02
# It: 39400, Loss: 7.720e-02,  loss_bc1: 1.512e-02,  loss_bc2: 2.559e-02, loss_ics_u: 1.398e-02,  Loss_res: 2.251e-02,  Time: 3.76
# adaptive_constant_res_val: 1.530e-01
# adaptive_constant_ics_val: 4.145e-01
# adaptive_constant_bcs1_val: 1.023e-02
# adaptive_constant_bcs2_val: 1.023e-02
# It: 39500, Loss: 8.314e-02,  loss_bc1: 1.519e-02,  loss_bc2: 2.569e-02, loss_ics_u: 1.514e-02,  Loss_res: 2.713e-02,  Time: 3.77
# adaptive_constant_res_val: 6.292e-01
# adaptive_constant_ics_val: 6.471e-01
# adaptive_constant_bcs1_val: 2.655e-02
# adaptive_constant_bcs2_val: 2.655e-02
# It: 39600, Loss: 6.988e-02,  loss_bc1: 1.467e-02,  loss_bc2: 2.539e-02, loss_ics_u: 1.495e-02,  Loss_res: 1.487e-02,  Time: 3.75
# adaptive_constant_res_val: 1.853e-01
# adaptive_constant_ics_val: 3.994e-01
# adaptive_constant_bcs1_val: 9.379e-03
# adaptive_constant_bcs2_val: 9.379e-03
# It: 39700, Loss: 8.237e-02,  loss_bc1: 1.459e-02,  loss_bc2: 2.500e-02, loss_ics_u: 1.814e-02,  Loss_res: 2.464e-02,  Time: 3.75
# adaptive_constant_res_val: 6.078e-01
# adaptive_constant_ics_val: 1.008e+00
# adaptive_constant_bcs1_val: 1.901e-02
# adaptive_constant_bcs2_val: 1.901e-02
# It: 39800, Loss: 7.639e-02,  loss_bc1: 1.459e-02,  loss_bc2: 2.512e-02, loss_ics_u: 1.355e-02,  Loss_res: 2.313e-02,  Time: 3.79
# adaptive_constant_res_val: 1.249e-01
# adaptive_constant_ics_val: 3.025e-01
# adaptive_constant_bcs1_val: 1.922e-02
# adaptive_constant_bcs2_val: 1.922e-02
# It: 39900, Loss: 7.007e-02,  loss_bc1: 1.443e-02,  loss_bc2: 2.479e-02, loss_ics_u: 1.391e-02,  Loss_res: 1.695e-02,  Time: 3.77
# adaptive_constant_res_val: 3.338e-01
# adaptive_constant_ics_val: 3.484e-01
# adaptive_constant_bcs1_val: 2.194e-02
# adaptive_constant_bcs2_val: 2.194e-02
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# Save uv NN parameters successfully in %s ...checkpoints/Dec-10-2023_11-17-45-669410_M1
# elapsed: 1.63e+03
# Relative L2 error_u: 4.86e-02
# Relative L2 error_r: 2.63e-01
# Final loss total loss: 7.265799e-02
# Final loss loss_res: 1.928261e-02
# Final loss loss_bc1: 1.416710e-02
# Final loss loss_bc2: 2.471446e-02
# Final loss loss_ics_u: 1.449383e-02
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6926/356373291.py in <module>
#      97
#      98             model.save_NN()
# ---> 99             mode.plt_prediction( t , x , X_star , u_star , u_pred , r_star , r_pred)
#     100             sess.close()
#     101
#
# AttributeError: 'str' object has no attribute 'plt_prediction'

# %%
plot_grad(model , )

# %%
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_r = np.linalg.norm(r_star - r_pred, 2) / np.linalg.norm(u_star, 2)

# %%
# # Predictions
# u_pred = model.predict_u(X_star)
# r_pred = model.predict_r(X_star)
# # Predictions
# r_pred =r_pred.reshape(200,200)

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
# error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)

# print('elapsed: {:.2e}'.format(elapsed))

print('Relative L2 error_u: {:.2e}'.format(error_u))
# print('Relative L2 error_r: {:.2e}'.format(error_r))
# r_pred =r_pred.reshape(200,200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_39039/2242230702.py in <module>
#       5 # r_pred =r_pred.reshape(200,200)
#       6
# ----> 7 error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
#       8 # error_r = np.linalg.norm(r_star - r_pred, 2)# / np.linalg.norm(r_star, 2)
#       9
#
# NameError: name 'u_pred' is not defined

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
# R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, r_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, r_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(r_star - r_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_39039/1239256772.py in <module>
#       1 U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
#       2 r_star = griddata(X_star, r_star.flatten(), (t, x), method='cubic')
# ----> 3 U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
#       4 # R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')
#       5
#
# NameError: name 'u_pred' is not defined
