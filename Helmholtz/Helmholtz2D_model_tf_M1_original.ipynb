# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import seaborn as sns
from Helmholtz2D_model_tf import Sampler, Helmholtz2D
import timeit
import os
os.environ["KMP_WARNINGS"] = "FALSE"

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Helmholtz2D:
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, model, stiff_ratio):
        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x1, self.sigma_x1 = self.mu_X[0], self.sigma_X[0]
        self.mu_x2, self.sigma_x2 = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Helmoholtz constant
        self.lam = tf.constant(lam, dtype=tf.float32)

        # Mode
        self.model = model

        # Record stiff ratio
        self.stiff_ratio = stiff_ratio

        # Adaptive constant
        self.beta = 0.9
        self.adaptive_constant_val = np.array(1.0)

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)

        if model in ['M3', 'M4']:
            # Initialize encoder weights and biases
            self.encoder_weights_1 = self.xavier_init([2, layers[1]])
            self.encoder_biases_1 = self.xavier_init([1, layers[1]])

            self.encoder_weights_2 = self.xavier_init([2, layers[1]])
            self.encoder_biases_2 = self.xavier_init([1, layers[1]])

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.x1_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # Define placeholder for adaptive constant
        self.adaptive_constant_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_val.shape)

        # Evaluate predictions
        self.u_bc1_pred = self.net_u(self.x1_bc1_tf, self.x2_bc1_tf)
        self.u_bc2_pred = self.net_u(self.x1_bc2_tf, self.x2_bc2_tf)
        self.u_bc3_pred = self.net_u(self.x1_bc3_tf, self.x2_bc3_tf)
        self.u_bc4_pred = self.net_u(self.x1_bc4_tf, self.x2_bc4_tf)

        self.u_pred = self.net_u(self.x1_u_tf, self.x2_u_tf)
        self.r_pred = self.net_r(self.x1_r_tf, self.x2_r_tf)

        # Boundary loss
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_tf - self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_tf - self.u_bc2_pred))
        self.loss_bc3 = tf.reduce_mean(tf.square(self.u_bc3_tf - self.u_bc3_pred))
        self.loss_bc4 = tf.reduce_mean(tf.square(self.u_bc4_tf - self.u_bc4_pred))
        self.loss_bcs = self.adaptive_constant_tf * (self.loss_bc1 + self.loss_bc2 + self.loss_bc3 + self.loss_bc4)

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_tf - self.r_pred))

        # Total loss
        self.loss = self.loss_res + self.loss_bcs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict(self.layers)
        self.dict_gradients_bcs_layers = self.generate_grad_dict(self.layers)

        # Gradients Storage
        self.grad_res = []
        self.grad_bcs = []
        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])

        # Compute and store the adaptive constant
        self.adpative_constant_log = []
        self.adaptive_constant_list = []
        
        self.max_grad_res_list = []
        self.mean_grad_bcs_list = []
        
        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.reduce_max(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs_list.append(tf.reduce_mean(tf.abs(self.grad_bcs[i])))
        
        self.max_grad_res = tf.reduce_max(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs = tf.reduce_mean(tf.stack(self.mean_grad_bcs_list))
        self.adaptive_constant = self.max_grad_res / self.mean_grad_bcs

        # Stiff Ratio
        if self.stiff_ratio:
            self.Hessian, self.Hessian_bcs, self.Hessian_res = self.get_H_op()
            self.eigenvalues, _ = tf.linalg.eigh(self.Hessian)
            self.eigenvalues_bcs, _ = tf.linalg.eigh(self.Hessian_bcs)
            self.eigenvalues_res, _ = tf.linalg.eigh(self.Hessian_res)

            self.eigenvalue_log = []
            self.eigenvalue_bcs_log = []
            self.eigenvalue_res_log = []

        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

     # Create dictionary to store gradients
    def generate_grad_dict(self, layers):
        num = len(layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Save gradients
    def save_gradients(self, tf_dict):
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res_value, grad_bcs_value = self.sess.run([self.grad_res[i], self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_res and loss_bcs
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res_value.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bcs_value.flatten())
        return None

    # Compute the Hessian
    def flatten(self, vectors):
        return tf.concat([tf.reshape(v, [-1]) for v in vectors], axis=0)

    def get_Hv(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss, self.weights))
        vprod = tf.math.multiply(loss_gradients,tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_res(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_res, self.weights))
        vprod = tf.math.multiply(loss_gradients, tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_bcs(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_bcs, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_H_op(self):
        self.P = self.flatten(self.weights).get_shape().as_list()[0]
        H = tf.map_fn(self.get_Hv, tf.eye(self.P, self.P),dtype='float32')
        H_bcs = tf.map_fn(self.get_Hv_bcs, tf.eye(self.P, self.P), dtype='float32')
        H_res = tf.map_fn(self.get_Hv_res, tf.eye(self.P, self.P), dtype='float32')

        return H, H_bcs, H_res

    # Xavier initialization
    def xavier_init(self,size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        if self.model in ['M1', 'M2']:
            num_layers = len(self.layers)
            for l in range(0, num_layers - 2):
                W = self.weights[l]
                b = self.biases[l]
                H = tf.tanh(tf.add(tf.matmul(H, W), b))
            W = self.weights[-1]
            b = self.biases[-1]
            H = tf.add(tf.matmul(H, W), b)
            return H

        if self.model in ['M3', 'M4']:
            num_layers = len(self.layers)
            encoder_1 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_1), self.encoder_biases_1))
            encoder_2 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_2), self.encoder_biases_2))

            for l in range(0, num_layers - 2):
                W = self.weights[l]
                b = self.biases[l]
                H = tf.math.multiply(tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_1) + \
                    tf.math.multiply(1 - tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_2)

            W = self.weights[-1]
            b = self.biases[-1]
            H = tf.add(tf.matmul(H, W), b)
            return H

    # Forward pass for u
    def net_u(self, x1, x2):
        u = self.forward_pass(tf.concat([x1, x2], 1))
        return u

    # Forward pass for residual
    def net_r(self, x1, x2):
        u = self.net_u(x1, x2)
        residual = self.operator(u, x1, x2,
                                 self.lam,
                                 self.sigma_x1,
                                 self.sigma_x2)
        return residual

    # Feed minibatch
    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
    def train(self, nIter=10000, batch_size=128):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, u_bc3_batch = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, u_bc4_batch = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

            # Fetch residual mini-batch
            X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x1_bc1_tf: X_bc1_batch[:, 0:1], self.x2_bc1_tf: X_bc1_batch[:, 1:2],
                       self.u_bc1_tf: u_bc1_batch,
                       self.x1_bc2_tf: X_bc2_batch[:, 0:1], self.x2_bc2_tf: X_bc2_batch[:, 1:2],
                       self.u_bc2_tf: u_bc2_batch,
                       self.x1_bc3_tf: X_bc3_batch[:, 0:1], self.x2_bc3_tf: X_bc3_batch[:, 1:2],
                       self.u_bc3_tf: u_bc3_batch,
                       self.x1_bc4_tf: X_bc4_batch[:, 0:1], self.x2_bc4_tf: X_bc4_batch[:, 1:2],
                       self.u_bc4_tf: u_bc4_batch,
                       self.x1_r_tf: X_res_batch[:, 0:1], self.x2_r_tf: X_res_batch[:, 1:2], self.r_tf: f_res_batch,
                       self.adaptive_constant_tf:  self.adaptive_constant_val
                       }

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Compute the eigenvalues of the Hessian of losses
            if self.stiff_ratio:
                if it % 1000 == 0:
                    print("Eigenvalues information stored ...")
                    eigenvalues, eigenvalues_bcs, eigenvalues_res = self.sess.run([self.eigenvalues, self.eigenvalues_bcs, self.eigenvalues_res], tf_dict)

                    # Log eigenvalues
                    self.eigenvalue_log.append(eigenvalues)
                    self.eigenvalue_bcs_log.append(eigenvalues_bcs)
                    self.eigenvalue_res_log.append(eigenvalues_res)

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value, loss_res_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)

                self.loss_bcs_log.append(loss_bcs_value /  self.adaptive_constant_val)
                self.loss_res_log.append(loss_res_value)

                # Compute and Print adaptive weights during training
                if self.model in ['M2', 'M4']:
                    adaptive_constant_value = self.sess.run(self.adaptive_constant, tf_dict)
                    self.adaptive_constant_val = adaptive_constant_value * (1.0 - self.beta) \
                                                 + self.beta * self.adaptive_constant_val
                self.adpative_constant_log.append(self.adaptive_constant_val)

                print('It: %d, Loss: %.3e, Loss_bcs: %.3e, Loss_res: %.3e, Adaptive_Constant: %.2f ,Time: %.2f' %
                      (it, loss_value, loss_bcs_value, loss_res_value, self.adaptive_constant_val, elapsed))
                start_time = timeit.default_timer()

            # Store gradients
            if it % 10000 == 0:
                self.save_gradients(tf_dict)
                print("Gradients information stored ...")

                # Evaluates predictions at test points

    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x1_u_tf: X_star[:, 0:1], self.x2_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x1_r_tf: X_star[:, 0:1], self.x2_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

# %%
a_1 = 1
a_2 = 4

def u(x, a_1, a_2):
    return np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

def u_xx(x, a_1, a_2):
    return - (a_1 * np.pi) ** 2 * np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

def u_yy(x, a_1, a_2):
    return - (a_2 * np.pi) ** 2 * np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

# Forcing
def f(x, a_1, a_2, lam):
    return u_xx(x, a_1, a_2) + u_yy(x, a_1, a_2) + lam * u(x, a_1, a_2)

def operator(u, x1, x2, lam, sigma_x1=1.0, sigma_x2=1.0):
    u_x1 = tf.gradients(u, x1)[0] / sigma_x1
    u_x2 = tf.gradients(u, x2)[0] / sigma_x2
    u_xx1 = tf.gradients(u_x1, x1)[0] / sigma_x1
    u_xx2 = tf.gradients(u_x2, x2)[0] / sigma_x2
    residual = u_xx1 + u_xx2 + lam * u
    return residual

# Parameter
lam = 1.0

# Domain boundaries
bc1_coords = np.array([[-1.0, -1.0],
                        [1.0, -1.0]])
bc2_coords = np.array([[1.0, -1.0],
                        [1.0, 1.0]])
bc3_coords = np.array([[1.0, 1.0],
                        [-1.0, 1.0]])
bc4_coords = np.array([[-1.0, 1.0],
                        [-1.0, -1.0]])

dom_coords = np.array([[-1.0, -1.0],
                        [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = None

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC2')
bc3 = Sampler(2, bc3_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC3')
bc4 = Sampler(2, bc4_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC4')
bcs_sampler = [bc1, bc2, bc3, bc4]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: f(x, a_1, a_2, lam), name='Forcing')

# Define model
mode = 'M2'            # Method: 'M1', 'M2', 'M3', 'M4'
stiff_ratio = True    # Log the eigenvalues of Hessian of losses

layers = [2, 50, 50, 50, 1]
model = Helmholtz2D(layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, mode, stiff_ratio)

# %%
# Train model
model.train(nIter=40001, batch_size=128)
# Out:
# Eigenvalues information stored ...
# It: 0, Loss: 7.074e+03, Loss_bcs: 2.370e-01, Loss_res: 7.074e+03, Adaptive_Constant: 9.06 ,Time: 319.59
# Gradients information stored ...
# It: 10, Loss: 7.718e+03, Loss_bcs: 3.594e-01, Loss_res: 7.717e+03, Adaptive_Constant: 9.16 ,Time: 4.85
# It: 20, Loss: 7.339e+03, Loss_bcs: 3.640e-01, Loss_res: 7.339e+03, Adaptive_Constant: 10.41 ,Time: 0.06
# It: 30, Loss: 7.148e+03, Loss_bcs: 5.451e-01, Loss_res: 7.148e+03, Adaptive_Constant: 10.89 ,Time: 0.06
# It: 40, Loss: 6.179e+03, Loss_bcs: 1.567e-01, Loss_res: 6.179e+03, Adaptive_Constant: 18.55 ,Time: 0.07
# It: 50, Loss: 7.953e+03, Loss_bcs: 2.586e-01, Loss_res: 7.952e+03, Adaptive_Constant: 20.05 ,Time: 0.06
# It: 60, Loss: 5.428e+03, Loss_bcs: 6.858e-01, Loss_res: 5.428e+03, Adaptive_Constant: 22.50 ,Time: 0.06
# It: 70, Loss: 6.176e+03, Loss_bcs: 1.312e+00, Loss_res: 6.174e+03, Adaptive_Constant: 24.43 ,Time: 0.06
# It: 80, Loss: 7.214e+03, Loss_bcs: 2.982e+00, Loss_res: 7.211e+03, Adaptive_Constant: 24.39 ,Time: 0.06
# It: 90, Loss: 6.848e+03, Loss_bcs: 6.168e+00, Loss_res: 6.842e+03, Adaptive_Constant: 23.13 ,Time: 0.06
# It: 100, Loss: 7.831e+03, Loss_bcs: 6.185e+00, Loss_res: 7.825e+03, Adaptive_Constant: 22.79 ,Time: 0.06
# It: 110, Loss: 7.035e+03, Loss_bcs: 7.082e+00, Loss_res: 7.027e+03, Adaptive_Constant: 23.88 ,Time: 0.06
# It: 120, Loss: 7.179e+03, Loss_bcs: 1.064e+01, Loss_res: 7.168e+03, Adaptive_Constant: 26.41 ,Time: 0.06
# It: 130, Loss: 6.109e+03, Loss_bcs: 1.408e+01, Loss_res: 6.095e+03, Adaptive_Constant: 28.55 ,Time: 0.07
# It: 140, Loss: 6.779e+03, Loss_bcs: 1.325e+01, Loss_res: 6.766e+03, Adaptive_Constant: 26.95 ,Time: 0.06
# It: 150, Loss: 6.959e+03, Loss_bcs: 1.071e+01, Loss_res: 6.948e+03, Adaptive_Constant: 30.60 ,Time: 0.06
# It: 160, Loss: 6.675e+03, Loss_bcs: 1.275e+01, Loss_res: 6.662e+03, Adaptive_Constant: 29.33 ,Time: 0.06
# It: 170, Loss: 6.292e+03, Loss_bcs: 1.030e+01, Loss_res: 6.282e+03, Adaptive_Constant: 29.63 ,Time: 0.06
# It: 180, Loss: 7.072e+03, Loss_bcs: 1.137e+01, Loss_res: 7.061e+03, Adaptive_Constant: 29.85 ,Time: 0.05
# It: 190, Loss: 6.714e+03, Loss_bcs: 1.312e+01, Loss_res: 6.701e+03, Adaptive_Constant: 29.05 ,Time: 0.06
# It: 200, Loss: 6.631e+03, Loss_bcs: 1.529e+01, Loss_res: 6.615e+03, Adaptive_Constant: 30.06 ,Time: 0.05
# It: 210, Loss: 6.305e+03, Loss_bcs: 1.813e+01, Loss_res: 6.287e+03, Adaptive_Constant: 30.01 ,Time: 0.06
# It: 220, Loss: 7.488e+03, Loss_bcs: 2.017e+01, Loss_res: 7.468e+03, Adaptive_Constant: 31.93 ,Time: 0.06
# It: 230, Loss: 6.962e+03, Loss_bcs: 2.239e+01, Loss_res: 6.940e+03, Adaptive_Constant: 29.86 ,Time: 0.06
# It: 240, Loss: 6.460e+03, Loss_bcs: 2.201e+01, Loss_res: 6.438e+03, Adaptive_Constant: 28.33 ,Time: 0.06
# It: 250, Loss: 7.381e+03, Loss_bcs: 2.214e+01, Loss_res: 7.358e+03, Adaptive_Constant: 26.89 ,Time: 0.06
# It: 260, Loss: 7.128e+03, Loss_bcs: 2.261e+01, Loss_res: 7.105e+03, Adaptive_Constant: 25.47 ,Time: 0.06
# It: 270, Loss: 6.436e+03, Loss_bcs: 1.467e+01, Loss_res: 6.421e+03, Adaptive_Constant: 24.81 ,Time: 0.06
# It: 280, Loss: 6.449e+03, Loss_bcs: 1.472e+01, Loss_res: 6.435e+03, Adaptive_Constant: 24.72 ,Time: 0.06
# It: 290, Loss: 7.368e+03, Loss_bcs: 1.585e+01, Loss_res: 7.352e+03, Adaptive_Constant: 25.92 ,Time: 0.06
# It: 300, Loss: 7.172e+03, Loss_bcs: 1.794e+01, Loss_res: 7.154e+03, Adaptive_Constant: 27.07 ,Time: 0.05
# It: 310, Loss: 6.829e+03, Loss_bcs: 1.857e+01, Loss_res: 6.810e+03, Adaptive_Constant: 27.21 ,Time: 0.06
# It: 320, Loss: 6.201e+03, Loss_bcs: 1.445e+01, Loss_res: 6.187e+03, Adaptive_Constant: 27.02 ,Time: 0.05
# It: 330, Loss: 6.593e+03, Loss_bcs: 1.001e+01, Loss_res: 6.583e+03, Adaptive_Constant: 26.18 ,Time: 0.07
# It: 340, Loss: 6.634e+03, Loss_bcs: 1.556e+01, Loss_res: 6.618e+03, Adaptive_Constant: 26.05 ,Time: 0.06
# It: 350, Loss: 7.118e+03, Loss_bcs: 2.071e+01, Loss_res: 7.097e+03, Adaptive_Constant: 25.94 ,Time: 0.06
# It: 360, Loss: 7.078e+03, Loss_bcs: 2.803e+01, Loss_res: 7.050e+03, Adaptive_Constant: 24.77 ,Time: 0.05
# It: 370, Loss: 7.128e+03, Loss_bcs: 2.131e+01, Loss_res: 7.106e+03, Adaptive_Constant: 24.65 ,Time: 0.06
# It: 380, Loss: 6.163e+03, Loss_bcs: 1.547e+01, Loss_res: 6.148e+03, Adaptive_Constant: 26.13 ,Time: 0.05
# It: 390, Loss: 6.427e+03, Loss_bcs: 1.609e+01, Loss_res: 6.411e+03, Adaptive_Constant: 26.20 ,Time: 0.05
# It: 400, Loss: 6.626e+03, Loss_bcs: 1.653e+01, Loss_res: 6.610e+03, Adaptive_Constant: 26.37 ,Time: 0.05
# It: 410, Loss: 7.583e+03, Loss_bcs: 1.435e+01, Loss_res: 7.568e+03, Adaptive_Constant: 26.11 ,Time: 0.06
# It: 420, Loss: 7.312e+03, Loss_bcs: 2.026e+01, Loss_res: 7.292e+03, Adaptive_Constant: 26.65 ,Time: 0.06
# It: 430, Loss: 5.887e+03, Loss_bcs: 2.106e+01, Loss_res: 5.866e+03, Adaptive_Constant: 26.93 ,Time: 0.05
# It: 440, Loss: 7.847e+03, Loss_bcs: 2.214e+01, Loss_res: 7.825e+03, Adaptive_Constant: 29.43 ,Time: 0.05
# It: 450, Loss: 6.573e+03, Loss_bcs: 2.652e+01, Loss_res: 6.546e+03, Adaptive_Constant: 29.00 ,Time: 0.06
# It: 460, Loss: 7.235e+03, Loss_bcs: 3.907e+01, Loss_res: 7.196e+03, Adaptive_Constant: 28.35 ,Time: 0.06
# It: 470, Loss: 7.267e+03, Loss_bcs: 3.732e+01, Loss_res: 7.230e+03, Adaptive_Constant: 28.73 ,Time: 0.06
# It: 480, Loss: 7.321e+03, Loss_bcs: 3.097e+01, Loss_res: 7.291e+03, Adaptive_Constant: 29.38 ,Time: 0.06
# It: 490, Loss: 6.502e+03, Loss_bcs: 3.400e+01, Loss_res: 6.468e+03, Adaptive_Constant: 29.93 ,Time: 0.06
# It: 500, Loss: 6.365e+03, Loss_bcs: 3.068e+01, Loss_res: 6.335e+03, Adaptive_Constant: 28.78 ,Time: 0.09
# It: 510, Loss: 7.267e+03, Loss_bcs: 2.430e+01, Loss_res: 7.243e+03, Adaptive_Constant: 30.00 ,Time: 0.06
# It: 520, Loss: 5.966e+03, Loss_bcs: 2.592e+01, Loss_res: 5.940e+03, Adaptive_Constant: 34.21 ,Time: 0.06
# It: 530, Loss: 8.362e+03, Loss_bcs: 3.163e+01, Loss_res: 8.331e+03, Adaptive_Constant: 43.98 ,Time: 0.05
# It: 540, Loss: 7.481e+03, Loss_bcs: 2.982e+01, Loss_res: 7.451e+03, Adaptive_Constant: 69.91 ,Time: 0.05
# It: 550, Loss: 6.421e+03, Loss_bcs: 3.464e+01, Loss_res: 6.386e+03, Adaptive_Constant: 82.68 ,Time: 0.06
# It: 560, Loss: 6.040e+03, Loss_bcs: 3.075e+01, Loss_res: 6.009e+03, Adaptive_Constant: 84.91 ,Time: 0.05
# It: 570, Loss: 6.802e+03, Loss_bcs: 3.326e+01, Loss_res: 6.769e+03, Adaptive_Constant: 86.42 ,Time: 0.05
# It: 580, Loss: 5.960e+03, Loss_bcs: 3.754e+01, Loss_res: 5.923e+03, Adaptive_Constant: 86.85 ,Time: 0.05
# It: 590, Loss: 6.089e+03, Loss_bcs: 3.886e+01, Loss_res: 6.050e+03, Adaptive_Constant: 81.20 ,Time: 0.05
# It: 600, Loss: 5.675e+03, Loss_bcs: 4.416e+01, Loss_res: 5.631e+03, Adaptive_Constant: 83.42 ,Time: 0.05
# It: 610, Loss: 4.481e+03, Loss_bcs: 4.843e+01, Loss_res: 4.433e+03, Adaptive_Constant: 90.27 ,Time: 0.05
# It: 620, Loss: 6.274e+03, Loss_bcs: 6.226e+01, Loss_res: 6.212e+03, Adaptive_Constant: 96.13 ,Time: 0.07
# It: 630, Loss: 5.693e+03, Loss_bcs: 6.074e+01, Loss_res: 5.632e+03, Adaptive_Constant: 106.47 ,Time: 0.06
# It: 640, Loss: 4.586e+03, Loss_bcs: 6.622e+01, Loss_res: 4.520e+03, Adaptive_Constant: 108.87 ,Time: 0.06
# It: 650, Loss: 4.303e+03, Loss_bcs: 8.041e+01, Loss_res: 4.222e+03, Adaptive_Constant: 106.50 ,Time: 0.05
# It: 660, Loss: 4.626e+03, Loss_bcs: 8.725e+01, Loss_res: 4.539e+03, Adaptive_Constant: 100.05 ,Time: 0.06
# It: 670, Loss: 4.287e+03, Loss_bcs: 6.798e+01, Loss_res: 4.219e+03, Adaptive_Constant: 96.80 ,Time: 0.05
# It: 680, Loss: 4.489e+03, Loss_bcs: 6.625e+01, Loss_res: 4.423e+03, Adaptive_Constant: 99.02 ,Time: 0.05
# It: 690, Loss: 2.180e+03, Loss_bcs: 7.055e+01, Loss_res: 2.110e+03, Adaptive_Constant: 100.98 ,Time: 0.06
# It: 700, Loss: 3.686e+03, Loss_bcs: 7.032e+01, Loss_res: 3.616e+03, Adaptive_Constant: 96.20 ,Time: 0.05
# It: 710, Loss: 2.873e+03, Loss_bcs: 5.819e+01, Loss_res: 2.815e+03, Adaptive_Constant: 95.60 ,Time: 0.05
# It: 720, Loss: 2.455e+03, Loss_bcs: 5.603e+01, Loss_res: 2.399e+03, Adaptive_Constant: 96.87 ,Time: 0.05
# It: 730, Loss: 1.800e+03, Loss_bcs: 3.633e+01, Loss_res: 1.763e+03, Adaptive_Constant: 92.96 ,Time: 0.05
# It: 740, Loss: 2.755e+03, Loss_bcs: 4.339e+01, Loss_res: 2.712e+03, Adaptive_Constant: 89.28 ,Time: 0.05
# It: 750, Loss: 2.371e+03, Loss_bcs: 4.240e+01, Loss_res: 2.329e+03, Adaptive_Constant: 83.99 ,Time: 0.05
# It: 760, Loss: 1.874e+03, Loss_bcs: 4.217e+01, Loss_res: 1.831e+03, Adaptive_Constant: 80.02 ,Time: 0.06
# It: 770, Loss: 1.718e+03, Loss_bcs: 3.001e+01, Loss_res: 1.688e+03, Adaptive_Constant: 80.63 ,Time: 0.06
# It: 780, Loss: 1.529e+03, Loss_bcs: 2.926e+01, Loss_res: 1.500e+03, Adaptive_Constant: 78.41 ,Time: 0.05
# It: 790, Loss: 1.484e+03, Loss_bcs: 2.902e+01, Loss_res: 1.455e+03, Adaptive_Constant: 83.24 ,Time: 0.06
# It: 800, Loss: 1.328e+03, Loss_bcs: 3.024e+01, Loss_res: 1.297e+03, Adaptive_Constant: 85.71 ,Time: 0.06
# It: 810, Loss: 1.660e+03, Loss_bcs: 3.578e+01, Loss_res: 1.624e+03, Adaptive_Constant: 85.25 ,Time: 0.05
# It: 820, Loss: 1.010e+03, Loss_bcs: 5.057e+01, Loss_res: 9.598e+02, Adaptive_Constant: 85.07 ,Time: 0.07
# It: 830, Loss: 7.761e+02, Loss_bcs: 5.201e+01, Loss_res: 7.241e+02, Adaptive_Constant: 81.30 ,Time: 0.05
# It: 840, Loss: 8.580e+02, Loss_bcs: 4.859e+01, Loss_res: 8.094e+02, Adaptive_Constant: 78.86 ,Time: 0.06
# It: 850, Loss: 7.040e+02, Loss_bcs: 5.014e+01, Loss_res: 6.539e+02, Adaptive_Constant: 81.73 ,Time: 0.06
# It: 860, Loss: 9.900e+02, Loss_bcs: 5.249e+01, Loss_res: 9.375e+02, Adaptive_Constant: 86.39 ,Time: 0.06
# It: 870, Loss: 5.252e+02, Loss_bcs: 6.140e+01, Loss_res: 4.638e+02, Adaptive_Constant: 80.91 ,Time: 0.05
# It: 880, Loss: 3.567e+02, Loss_bcs: 4.371e+01, Loss_res: 3.130e+02, Adaptive_Constant: 84.63 ,Time: 0.05
# It: 890, Loss: 3.963e+02, Loss_bcs: 5.122e+01, Loss_res: 3.450e+02, Adaptive_Constant: 85.26 ,Time: 0.05
# It: 900, Loss: 6.081e+02, Loss_bcs: 6.507e+01, Loss_res: 5.430e+02, Adaptive_Constant: 82.92 ,Time: 0.05
# It: 910, Loss: 5.115e+02, Loss_bcs: 5.454e+01, Loss_res: 4.570e+02, Adaptive_Constant: 78.79 ,Time: 0.05
# It: 920, Loss: 4.715e+02, Loss_bcs: 5.656e+01, Loss_res: 4.150e+02, Adaptive_Constant: 80.37 ,Time: 0.05
# It: 930, Loss: 5.562e+02, Loss_bcs: 6.402e+01, Loss_res: 4.922e+02, Adaptive_Constant: 78.96 ,Time: 0.06
# It: 940, Loss: 7.191e+02, Loss_bcs: 5.291e+01, Loss_res: 6.662e+02, Adaptive_Constant: 76.03 ,Time: 0.06
# It: 950, Loss: 5.493e+02, Loss_bcs: 4.492e+01, Loss_res: 5.044e+02, Adaptive_Constant: 81.85 ,Time: 0.05
# It: 960, Loss: 3.883e+02, Loss_bcs: 5.150e+01, Loss_res: 3.368e+02, Adaptive_Constant: 79.73 ,Time: 0.06
# It: 970, Loss: 3.536e+02, Loss_bcs: 4.822e+01, Loss_res: 3.053e+02, Adaptive_Constant: 81.87 ,Time: 0.05
# It: 980, Loss: 4.855e+02, Loss_bcs: 5.001e+01, Loss_res: 4.355e+02, Adaptive_Constant: 79.88 ,Time: 0.05
# It: 990, Loss: 6.646e+02, Loss_bcs: 5.769e+01, Loss_res: 6.070e+02, Adaptive_Constant: 83.27 ,Time: 0.05
# Eigenvalues information stored ...
# It: 1000, Loss: 3.863e+02, Loss_bcs: 5.097e+01, Loss_res: 3.353e+02, Adaptive_Constant: 80.17 ,Time: 319.49
# It: 1010, Loss: 4.233e+02, Loss_bcs: 4.538e+01, Loss_res: 3.779e+02, Adaptive_Constant: 78.42 ,Time: 0.06
# It: 1020, Loss: 2.349e+02, Loss_bcs: 4.187e+01, Loss_res: 1.930e+02, Adaptive_Constant: 81.02 ,Time: 0.06
# It: 1030, Loss: 3.459e+02, Loss_bcs: 4.056e+01, Loss_res: 3.053e+02, Adaptive_Constant: 83.12 ,Time: 0.05
# It: 1040, Loss: 3.296e+02, Loss_bcs: 4.228e+01, Loss_res: 2.873e+02, Adaptive_Constant: 78.65 ,Time: 0.06
# It: 1050, Loss: 3.028e+02, Loss_bcs: 4.098e+01, Loss_res: 2.618e+02, Adaptive_Constant: 76.38 ,Time: 0.05
# It: 1060, Loss: 3.037e+02, Loss_bcs: 4.763e+01, Loss_res: 2.561e+02, Adaptive_Constant: 73.79 ,Time: 0.05
# It: 1070, Loss: 3.674e+02, Loss_bcs: 4.621e+01, Loss_res: 3.212e+02, Adaptive_Constant: 70.49 ,Time: 0.05
# It: 1080, Loss: 2.945e+02, Loss_bcs: 3.614e+01, Loss_res: 2.583e+02, Adaptive_Constant: 71.29 ,Time: 0.06
# It: 1090, Loss: 2.657e+02, Loss_bcs: 3.491e+01, Loss_res: 2.308e+02, Adaptive_Constant: 71.05 ,Time: 0.05
# It: 1100, Loss: 3.072e+02, Loss_bcs: 3.836e+01, Loss_res: 2.688e+02, Adaptive_Constant: 67.88 ,Time: 0.05
# It: 1110, Loss: 4.407e+02, Loss_bcs: 3.697e+01, Loss_res: 4.037e+02, Adaptive_Constant: 68.24 ,Time: 0.05
# It: 1120, Loss: 2.206e+02, Loss_bcs: 3.572e+01, Loss_res: 1.849e+02, Adaptive_Constant: 65.74 ,Time: 0.07
# It: 1130, Loss: 2.632e+02, Loss_bcs: 3.868e+01, Loss_res: 2.245e+02, Adaptive_Constant: 68.41 ,Time: 0.05
# It: 1140, Loss: 1.881e+02, Loss_bcs: 3.904e+01, Loss_res: 1.490e+02, Adaptive_Constant: 69.19 ,Time: 0.05
# It: 1150, Loss: 1.862e+02, Loss_bcs: 3.428e+01, Loss_res: 1.519e+02, Adaptive_Constant: 69.13 ,Time: 0.05
# It: 1160, Loss: 2.349e+02, Loss_bcs: 3.316e+01, Loss_res: 2.017e+02, Adaptive_Constant: 70.16 ,Time: 0.06
# It: 1170, Loss: 2.719e+02, Loss_bcs: 2.915e+01, Loss_res: 2.428e+02, Adaptive_Constant: 71.44 ,Time: 0.06
# It: 1180, Loss: 2.352e+02, Loss_bcs: 3.465e+01, Loss_res: 2.005e+02, Adaptive_Constant: 66.43 ,Time: 0.05
# It: 1190, Loss: 2.149e+02, Loss_bcs: 2.801e+01, Loss_res: 1.869e+02, Adaptive_Constant: 63.90 ,Time: 0.05
# It: 1200, Loss: 2.295e+02, Loss_bcs: 2.607e+01, Loss_res: 2.034e+02, Adaptive_Constant: 65.76 ,Time: 0.06
# It: 1210, Loss: 1.566e+02, Loss_bcs: 3.184e+01, Loss_res: 1.247e+02, Adaptive_Constant: 71.63 ,Time: 0.05
# It: 1220, Loss: 2.048e+02, Loss_bcs: 3.230e+01, Loss_res: 1.726e+02, Adaptive_Constant: 69.75 ,Time: 0.06
# It: 1230, Loss: 2.108e+02, Loss_bcs: 3.331e+01, Loss_res: 1.775e+02, Adaptive_Constant: 71.02 ,Time: 0.06
# It: 1240, Loss: 1.704e+02, Loss_bcs: 2.952e+01, Loss_res: 1.409e+02, Adaptive_Constant: 66.83 ,Time: 0.06
# It: 1250, Loss: 2.003e+02, Loss_bcs: 2.470e+01, Loss_res: 1.756e+02, Adaptive_Constant: 68.85 ,Time: 0.05
# It: 1260, Loss: 2.365e+02, Loss_bcs: 2.424e+01, Loss_res: 2.123e+02, Adaptive_Constant: 66.02 ,Time: 0.06
# It: 1270, Loss: 1.499e+02, Loss_bcs: 2.382e+01, Loss_res: 1.260e+02, Adaptive_Constant: 67.75 ,Time: 0.09
# It: 1280, Loss: 2.663e+02, Loss_bcs: 2.327e+01, Loss_res: 2.430e+02, Adaptive_Constant: 74.31 ,Time: 0.06
# It: 1290, Loss: 2.154e+02, Loss_bcs: 2.501e+01, Loss_res: 1.904e+02, Adaptive_Constant: 70.74 ,Time: 0.06
# It: 1300, Loss: 1.841e+02, Loss_bcs: 1.800e+01, Loss_res: 1.661e+02, Adaptive_Constant: 82.36 ,Time: 0.06
# It: 1310, Loss: 2.630e+02, Loss_bcs: 2.487e+01, Loss_res: 2.382e+02, Adaptive_Constant: 76.97 ,Time: 0.06
# It: 1320, Loss: 2.108e+02, Loss_bcs: 2.993e+01, Loss_res: 1.808e+02, Adaptive_Constant: 75.85 ,Time: 0.05
# It: 1330, Loss: 2.064e+02, Loss_bcs: 1.914e+01, Loss_res: 1.873e+02, Adaptive_Constant: 81.93 ,Time: 0.05
# It: 1340, Loss: 1.723e+02, Loss_bcs: 1.585e+01, Loss_res: 1.565e+02, Adaptive_Constant: 81.25 ,Time: 0.05
# It: 1350, Loss: 1.851e+02, Loss_bcs: 2.321e+01, Loss_res: 1.619e+02, Adaptive_Constant: 78.85 ,Time: 0.06
# It: 1360, Loss: 1.850e+02, Loss_bcs: 2.002e+01, Loss_res: 1.650e+02, Adaptive_Constant: 76.51 ,Time: 0.06
# It: 1370, Loss: 2.666e+02, Loss_bcs: 1.397e+01, Loss_res: 2.527e+02, Adaptive_Constant: 82.10 ,Time: 0.06
# It: 1380, Loss: 1.981e+02, Loss_bcs: 1.766e+01, Loss_res: 1.805e+02, Adaptive_Constant: 78.42 ,Time: 0.05
# It: 1390, Loss: 1.840e+02, Loss_bcs: 1.844e+01, Loss_res: 1.655e+02, Adaptive_Constant: 79.53 ,Time: 0.05
# It: 1400, Loss: 1.481e+02, Loss_bcs: 1.549e+01, Loss_res: 1.326e+02, Adaptive_Constant: 87.71 ,Time: 0.05
# It: 1410, Loss: 1.392e+02, Loss_bcs: 1.279e+01, Loss_res: 1.264e+02, Adaptive_Constant: 84.27 ,Time: 0.06
# It: 1420, Loss: 1.541e+02, Loss_bcs: 1.647e+01, Loss_res: 1.376e+02, Adaptive_Constant: 79.48 ,Time: 0.06
# It: 1430, Loss: 1.034e+02, Loss_bcs: 1.196e+01, Loss_res: 9.139e+01, Adaptive_Constant: 76.59 ,Time: 0.06
# It: 1440, Loss: 8.382e+01, Loss_bcs: 1.209e+01, Loss_res: 7.173e+01, Adaptive_Constant: 72.17 ,Time: 0.05
# It: 1450, Loss: 9.162e+01, Loss_bcs: 1.184e+01, Loss_res: 7.978e+01, Adaptive_Constant: 72.52 ,Time: 0.05
# It: 1460, Loss: 1.381e+02, Loss_bcs: 1.589e+01, Loss_res: 1.222e+02, Adaptive_Constant: 69.78 ,Time: 0.06
# It: 1470, Loss: 8.563e+01, Loss_bcs: 8.620e+00, Loss_res: 7.701e+01, Adaptive_Constant: 66.54 ,Time: 0.05
# It: 1480, Loss: 9.952e+01, Loss_bcs: 1.315e+01, Loss_res: 8.636e+01, Adaptive_Constant: 66.55 ,Time: 0.05
# It: 1490, Loss: 1.220e+02, Loss_bcs: 8.765e+00, Loss_res: 1.132e+02, Adaptive_Constant: 72.11 ,Time: 0.05
# It: 1500, Loss: 1.147e+02, Loss_bcs: 1.622e+01, Loss_res: 9.852e+01, Adaptive_Constant: 68.93 ,Time: 0.06
# It: 1510, Loss: 1.162e+02, Loss_bcs: 1.094e+01, Loss_res: 1.052e+02, Adaptive_Constant: 67.60 ,Time: 0.05
# It: 1520, Loss: 5.188e+01, Loss_bcs: 9.315e+00, Loss_res: 4.256e+01, Adaptive_Constant: 66.51 ,Time: 0.05
# It: 1530, Loss: 8.900e+01, Loss_bcs: 9.743e+00, Loss_res: 7.925e+01, Adaptive_Constant: 67.35 ,Time: 0.05
# It: 1540, Loss: 8.838e+01, Loss_bcs: 8.542e+00, Loss_res: 7.983e+01, Adaptive_Constant: 73.60 ,Time: 0.06
# It: 1550, Loss: 1.024e+02, Loss_bcs: 8.270e+00, Loss_res: 9.412e+01, Adaptive_Constant: 82.98 ,Time: 0.06
# It: 1560, Loss: 6.931e+01, Loss_bcs: 1.060e+01, Loss_res: 5.872e+01, Adaptive_Constant: 78.03 ,Time: 0.06
# It: 1570, Loss: 9.026e+01, Loss_bcs: 1.089e+01, Loss_res: 7.937e+01, Adaptive_Constant: 82.91 ,Time: 0.05
# It: 1580, Loss: 1.184e+02, Loss_bcs: 9.445e+00, Loss_res: 1.090e+02, Adaptive_Constant: 76.45 ,Time: 0.05
# It: 1590, Loss: 7.787e+01, Loss_bcs: 1.053e+01, Loss_res: 6.734e+01, Adaptive_Constant: 86.22 ,Time: 0.06
# It: 1600, Loss: 7.829e+01, Loss_bcs: 9.707e+00, Loss_res: 6.858e+01, Adaptive_Constant: 84.15 ,Time: 0.05
# It: 1610, Loss: 8.069e+01, Loss_bcs: 9.300e+00, Loss_res: 7.139e+01, Adaptive_Constant: 84.22 ,Time: 0.06
# It: 1620, Loss: 7.337e+01, Loss_bcs: 9.351e+00, Loss_res: 6.402e+01, Adaptive_Constant: 80.63 ,Time: 0.05
# It: 1630, Loss: 7.540e+01, Loss_bcs: 8.150e+00, Loss_res: 6.725e+01, Adaptive_Constant: 80.39 ,Time: 0.05
# It: 1640, Loss: 6.239e+01, Loss_bcs: 9.455e+00, Loss_res: 5.294e+01, Adaptive_Constant: 76.12 ,Time: 0.05
# It: 1650, Loss: 6.990e+01, Loss_bcs: 9.192e+00, Loss_res: 6.071e+01, Adaptive_Constant: 82.50 ,Time: 0.06
# It: 1660, Loss: 7.329e+01, Loss_bcs: 7.944e+00, Loss_res: 6.534e+01, Adaptive_Constant: 92.12 ,Time: 0.05
# It: 1670, Loss: 7.592e+01, Loss_bcs: 1.112e+01, Loss_res: 6.480e+01, Adaptive_Constant: 89.68 ,Time: 0.05
# It: 1680, Loss: 5.588e+01, Loss_bcs: 8.422e+00, Loss_res: 4.746e+01, Adaptive_Constant: 85.55 ,Time: 0.05
# It: 1690, Loss: 1.107e+02, Loss_bcs: 7.972e+00, Loss_res: 1.027e+02, Adaptive_Constant: 101.89 ,Time: 0.06
# It: 1700, Loss: 7.210e+01, Loss_bcs: 8.613e+00, Loss_res: 6.348e+01, Adaptive_Constant: 99.12 ,Time: 0.06
# It: 1710, Loss: 7.718e+01, Loss_bcs: 8.137e+00, Loss_res: 6.904e+01, Adaptive_Constant: 114.52 ,Time: 0.05
# It: 1720, Loss: 5.041e+01, Loss_bcs: 9.526e+00, Loss_res: 4.088e+01, Adaptive_Constant: 104.54 ,Time: 0.05
# It: 1730, Loss: 4.794e+01, Loss_bcs: 9.592e+00, Loss_res: 3.835e+01, Adaptive_Constant: 95.04 ,Time: 0.06
# It: 1740, Loss: 4.447e+01, Loss_bcs: 8.483e+00, Loss_res: 3.599e+01, Adaptive_Constant: 89.77 ,Time: 0.05
# It: 1750, Loss: 4.026e+01, Loss_bcs: 7.216e+00, Loss_res: 3.304e+01, Adaptive_Constant: 88.90 ,Time: 0.05
# It: 1760, Loss: 6.599e+01, Loss_bcs: 7.035e+00, Loss_res: 5.896e+01, Adaptive_Constant: 96.04 ,Time: 0.06
# It: 1770, Loss: 5.872e+01, Loss_bcs: 6.980e+00, Loss_res: 5.174e+01, Adaptive_Constant: 103.67 ,Time: 0.06
# It: 1780, Loss: 4.431e+01, Loss_bcs: 7.993e+00, Loss_res: 3.632e+01, Adaptive_Constant: 102.43 ,Time: 0.06
# It: 1790, Loss: 4.118e+01, Loss_bcs: 8.202e+00, Loss_res: 3.297e+01, Adaptive_Constant: 101.85 ,Time: 0.06
# It: 1800, Loss: 6.197e+01, Loss_bcs: 7.835e+00, Loss_res: 5.414e+01, Adaptive_Constant: 99.76 ,Time: 0.05
# It: 1810, Loss: 5.096e+01, Loss_bcs: 7.105e+00, Loss_res: 4.385e+01, Adaptive_Constant: 96.04 ,Time: 0.07
# It: 1820, Loss: 5.654e+01, Loss_bcs: 6.828e+00, Loss_res: 4.971e+01, Adaptive_Constant: 92.24 ,Time: 0.06
# It: 1830, Loss: 8.039e+01, Loss_bcs: 6.705e+00, Loss_res: 7.368e+01, Adaptive_Constant: 103.71 ,Time: 0.06
# It: 1840, Loss: 7.315e+01, Loss_bcs: 7.429e+00, Loss_res: 6.572e+01, Adaptive_Constant: 103.60 ,Time: 0.08
# It: 1850, Loss: 5.997e+01, Loss_bcs: 6.921e+00, Loss_res: 5.305e+01, Adaptive_Constant: 103.73 ,Time: 0.06
# It: 1860, Loss: 4.261e+01, Loss_bcs: 7.003e+00, Loss_res: 3.561e+01, Adaptive_Constant: 100.55 ,Time: 0.06
# It: 1870, Loss: 6.412e+01, Loss_bcs: 8.153e+00, Loss_res: 5.596e+01, Adaptive_Constant: 99.45 ,Time: 0.05
# It: 1880, Loss: 6.769e+01, Loss_bcs: 7.455e+00, Loss_res: 6.024e+01, Adaptive_Constant: 98.78 ,Time: 0.06
# It: 1890, Loss: 6.139e+01, Loss_bcs: 6.191e+00, Loss_res: 5.520e+01, Adaptive_Constant: 93.93 ,Time: 0.06
# It: 1900, Loss: 3.892e+01, Loss_bcs: 5.767e+00, Loss_res: 3.315e+01, Adaptive_Constant: 88.16 ,Time: 0.06
# It: 1910, Loss: 5.767e+01, Loss_bcs: 5.696e+00, Loss_res: 5.198e+01, Adaptive_Constant: 85.50 ,Time: 0.06
# It: 1920, Loss: 4.339e+01, Loss_bcs: 5.953e+00, Loss_res: 3.743e+01, Adaptive_Constant: 91.69 ,Time: 0.05
# It: 1930, Loss: 4.218e+01, Loss_bcs: 6.306e+00, Loss_res: 3.588e+01, Adaptive_Constant: 84.98 ,Time: 0.06
# It: 1940, Loss: 5.289e+01, Loss_bcs: 4.575e+00, Loss_res: 4.831e+01, Adaptive_Constant: 81.32 ,Time: 0.07
# It: 1950, Loss: 6.887e+01, Loss_bcs: 5.046e+00, Loss_res: 6.382e+01, Adaptive_Constant: 77.62 ,Time: 0.05
# It: 1960, Loss: 4.816e+01, Loss_bcs: 5.289e+00, Loss_res: 4.287e+01, Adaptive_Constant: 81.22 ,Time: 0.06
# It: 1970, Loss: 5.621e+01, Loss_bcs: 5.782e+00, Loss_res: 5.042e+01, Adaptive_Constant: 83.95 ,Time: 0.06
# It: 1980, Loss: 3.636e+01, Loss_bcs: 4.872e+00, Loss_res: 3.149e+01, Adaptive_Constant: 82.04 ,Time: 0.06
# It: 1990, Loss: 4.225e+01, Loss_bcs: 5.151e+00, Loss_res: 3.710e+01, Adaptive_Constant: 80.41 ,Time: 0.08
# Eigenvalues information stored ...
# It: 2000, Loss: 5.613e+01, Loss_bcs: 5.224e+00, Loss_res: 5.090e+01, Adaptive_Constant: 108.72 ,Time: 323.91
# It: 2010, Loss: 2.918e+01, Loss_bcs: 6.247e+00, Loss_res: 2.294e+01, Adaptive_Constant: 102.65 ,Time: 0.06
# It: 2020, Loss: 3.808e+01, Loss_bcs: 6.730e+00, Loss_res: 3.135e+01, Adaptive_Constant: 97.07 ,Time: 0.05
# It: 2030, Loss: 6.858e+01, Loss_bcs: 5.103e+00, Loss_res: 6.348e+01, Adaptive_Constant: 116.38 ,Time: 0.06
# It: 2040, Loss: 5.866e+01, Loss_bcs: 5.942e+00, Loss_res: 5.272e+01, Adaptive_Constant: 123.55 ,Time: 0.07
# It: 2050, Loss: 2.766e+01, Loss_bcs: 6.760e+00, Loss_res: 2.090e+01, Adaptive_Constant: 113.86 ,Time: 0.05
# It: 2060, Loss: 4.762e+01, Loss_bcs: 6.918e+00, Loss_res: 4.070e+01, Adaptive_Constant: 105.94 ,Time: 0.05
# It: 2070, Loss: 4.511e+01, Loss_bcs: 6.119e+00, Loss_res: 3.899e+01, Adaptive_Constant: 100.15 ,Time: 0.06
# It: 2080, Loss: 3.664e+01, Loss_bcs: 5.555e+00, Loss_res: 3.108e+01, Adaptive_Constant: 95.51 ,Time: 0.05
# It: 2090, Loss: 2.719e+01, Loss_bcs: 5.549e+00, Loss_res: 2.164e+01, Adaptive_Constant: 91.06 ,Time: 0.06
# It: 2100, Loss: 2.990e+01, Loss_bcs: 4.993e+00, Loss_res: 2.491e+01, Adaptive_Constant: 91.57 ,Time: 0.06
# It: 2110, Loss: 3.878e+01, Loss_bcs: 4.090e+00, Loss_res: 3.469e+01, Adaptive_Constant: 92.92 ,Time: 0.05
# It: 2120, Loss: 3.479e+01, Loss_bcs: 5.121e+00, Loss_res: 2.967e+01, Adaptive_Constant: 92.87 ,Time: 0.05
# It: 2130, Loss: 3.927e+01, Loss_bcs: 4.750e+00, Loss_res: 3.452e+01, Adaptive_Constant: 89.86 ,Time: 0.06
# It: 2140, Loss: 2.873e+01, Loss_bcs: 4.224e+00, Loss_res: 2.451e+01, Adaptive_Constant: 91.23 ,Time: 0.05
# It: 2150, Loss: 3.056e+01, Loss_bcs: 4.191e+00, Loss_res: 2.637e+01, Adaptive_Constant: 96.47 ,Time: 0.05
# It: 2160, Loss: 2.380e+01, Loss_bcs: 4.711e+00, Loss_res: 1.908e+01, Adaptive_Constant: 91.59 ,Time: 0.05
# It: 2170, Loss: 4.334e+01, Loss_bcs: 5.815e+00, Loss_res: 3.753e+01, Adaptive_Constant: 89.21 ,Time: 0.06
# It: 2180, Loss: 2.795e+01, Loss_bcs: 4.901e+00, Loss_res: 2.305e+01, Adaptive_Constant: 95.97 ,Time: 0.05
# It: 2190, Loss: 2.991e+01, Loss_bcs: 4.902e+00, Loss_res: 2.501e+01, Adaptive_Constant: 93.74 ,Time: 0.05
# It: 2200, Loss: 3.536e+01, Loss_bcs: 4.817e+00, Loss_res: 3.054e+01, Adaptive_Constant: 92.45 ,Time: 0.06
# It: 2210, Loss: 3.521e+01, Loss_bcs: 4.682e+00, Loss_res: 3.053e+01, Adaptive_Constant: 88.54 ,Time: 0.06
# It: 2220, Loss: 4.070e+01, Loss_bcs: 4.756e+00, Loss_res: 3.595e+01, Adaptive_Constant: 87.29 ,Time: 0.06
# It: 2230, Loss: 2.540e+01, Loss_bcs: 4.036e+00, Loss_res: 2.137e+01, Adaptive_Constant: 87.23 ,Time: 0.05
# It: 2240, Loss: 3.523e+01, Loss_bcs: 4.545e+00, Loss_res: 3.069e+01, Adaptive_Constant: 79.64 ,Time: 0.07
# It: 2250, Loss: 3.628e+01, Loss_bcs: 3.858e+00, Loss_res: 3.243e+01, Adaptive_Constant: 82.90 ,Time: 0.05
# It: 2260, Loss: 2.933e+01, Loss_bcs: 3.614e+00, Loss_res: 2.572e+01, Adaptive_Constant: 89.04 ,Time: 0.05
# It: 2270, Loss: 2.978e+01, Loss_bcs: 4.466e+00, Loss_res: 2.531e+01, Adaptive_Constant: 85.47 ,Time: 0.05
# It: 2280, Loss: 2.581e+01, Loss_bcs: 4.455e+00, Loss_res: 2.135e+01, Adaptive_Constant: 85.10 ,Time: 0.06
# It: 2290, Loss: 2.563e+01, Loss_bcs: 4.040e+00, Loss_res: 2.159e+01, Adaptive_Constant: 83.39 ,Time: 0.05
# It: 2300, Loss: 2.768e+01, Loss_bcs: 3.779e+00, Loss_res: 2.390e+01, Adaptive_Constant: 104.32 ,Time: 0.06
# It: 2310, Loss: 2.919e+01, Loss_bcs: 5.143e+00, Loss_res: 2.404e+01, Adaptive_Constant: 100.45 ,Time: 0.06
# It: 2320, Loss: 2.047e+01, Loss_bcs: 5.359e+00, Loss_res: 1.511e+01, Adaptive_Constant: 94.18 ,Time: 0.06
# It: 2330, Loss: 3.873e+01, Loss_bcs: 5.112e+00, Loss_res: 3.362e+01, Adaptive_Constant: 94.38 ,Time: 0.06
# It: 2340, Loss: 2.193e+01, Loss_bcs: 4.536e+00, Loss_res: 1.740e+01, Adaptive_Constant: 95.25 ,Time: 0.05
# It: 2350, Loss: 3.169e+01, Loss_bcs: 5.142e+00, Loss_res: 2.655e+01, Adaptive_Constant: 99.23 ,Time: 0.05
# It: 2360, Loss: 2.491e+01, Loss_bcs: 4.537e+00, Loss_res: 2.037e+01, Adaptive_Constant: 106.10 ,Time: 0.06
# It: 2370, Loss: 3.023e+01, Loss_bcs: 4.809e+00, Loss_res: 2.542e+01, Adaptive_Constant: 101.74 ,Time: 0.06
# It: 2380, Loss: 2.977e+01, Loss_bcs: 5.881e+00, Loss_res: 2.389e+01, Adaptive_Constant: 95.46 ,Time: 0.05
# It: 2390, Loss: 2.353e+01, Loss_bcs: 4.685e+00, Loss_res: 1.884e+01, Adaptive_Constant: 93.87 ,Time: 0.06
# It: 2400, Loss: 2.539e+01, Loss_bcs: 4.194e+00, Loss_res: 2.120e+01, Adaptive_Constant: 92.71 ,Time: 0.06
# It: 2410, Loss: 2.838e+01, Loss_bcs: 4.334e+00, Loss_res: 2.405e+01, Adaptive_Constant: 93.81 ,Time: 0.05
# It: 2420, Loss: 2.466e+01, Loss_bcs: 4.169e+00, Loss_res: 2.049e+01, Adaptive_Constant: 90.84 ,Time: 0.05
# It: 2430, Loss: 2.162e+01, Loss_bcs: 4.015e+00, Loss_res: 1.760e+01, Adaptive_Constant: 89.95 ,Time: 0.06
# It: 2440, Loss: 1.963e+01, Loss_bcs: 4.223e+00, Loss_res: 1.540e+01, Adaptive_Constant: 87.20 ,Time: 0.05
# It: 2450, Loss: 1.906e+01, Loss_bcs: 3.484e+00, Loss_res: 1.558e+01, Adaptive_Constant: 86.76 ,Time: 0.05
# It: 2460, Loss: 3.829e+01, Loss_bcs: 4.291e+00, Loss_res: 3.400e+01, Adaptive_Constant: 96.51 ,Time: 0.06
# It: 2470, Loss: 2.384e+01, Loss_bcs: 4.273e+00, Loss_res: 1.957e+01, Adaptive_Constant: 93.16 ,Time: 0.07
# It: 2480, Loss: 2.077e+01, Loss_bcs: 3.580e+00, Loss_res: 1.719e+01, Adaptive_Constant: 92.09 ,Time: 0.05
# It: 2490, Loss: 2.128e+01, Loss_bcs: 4.001e+00, Loss_res: 1.728e+01, Adaptive_Constant: 90.77 ,Time: 0.06
# It: 2500, Loss: 2.508e+01, Loss_bcs: 4.289e+00, Loss_res: 2.079e+01, Adaptive_Constant: 85.69 ,Time: 0.06
# It: 2510, Loss: 1.997e+01, Loss_bcs: 3.403e+00, Loss_res: 1.657e+01, Adaptive_Constant: 87.99 ,Time: 0.05
# It: 2520, Loss: 2.550e+01, Loss_bcs: 3.666e+00, Loss_res: 2.183e+01, Adaptive_Constant: 94.20 ,Time: 0.06
# It: 2530, Loss: 2.116e+01, Loss_bcs: 4.334e+00, Loss_res: 1.683e+01, Adaptive_Constant: 90.49 ,Time: 0.06
# It: 2540, Loss: 1.719e+01, Loss_bcs: 3.838e+00, Loss_res: 1.335e+01, Adaptive_Constant: 87.48 ,Time: 0.06
# It: 2550, Loss: 1.759e+01, Loss_bcs: 3.978e+00, Loss_res: 1.361e+01, Adaptive_Constant: 84.99 ,Time: 0.05
# It: 2560, Loss: 2.336e+01, Loss_bcs: 3.875e+00, Loss_res: 1.948e+01, Adaptive_Constant: 82.79 ,Time: 0.05
# It: 2570, Loss: 2.093e+01, Loss_bcs: 3.636e+00, Loss_res: 1.730e+01, Adaptive_Constant: 83.11 ,Time: 0.07
# It: 2580, Loss: 2.659e+01, Loss_bcs: 3.781e+00, Loss_res: 2.281e+01, Adaptive_Constant: 88.07 ,Time: 0.05
# It: 2590, Loss: 2.956e+01, Loss_bcs: 3.725e+00, Loss_res: 2.583e+01, Adaptive_Constant: 86.10 ,Time: 0.06
# It: 2600, Loss: 2.171e+01, Loss_bcs: 3.451e+00, Loss_res: 1.826e+01, Adaptive_Constant: 90.35 ,Time: 0.06
# It: 2610, Loss: 1.701e+01, Loss_bcs: 3.586e+00, Loss_res: 1.342e+01, Adaptive_Constant: 86.01 ,Time: 0.05
# It: 2620, Loss: 2.415e+01, Loss_bcs: 3.453e+00, Loss_res: 2.070e+01, Adaptive_Constant: 87.63 ,Time: 0.06
# It: 2630, Loss: 1.954e+01, Loss_bcs: 3.492e+00, Loss_res: 1.604e+01, Adaptive_Constant: 86.42 ,Time: 0.06
# It: 2640, Loss: 1.827e+01, Loss_bcs: 3.692e+00, Loss_res: 1.458e+01, Adaptive_Constant: 81.52 ,Time: 0.05
# It: 2650, Loss: 1.968e+01, Loss_bcs: 3.688e+00, Loss_res: 1.599e+01, Adaptive_Constant: 79.42 ,Time: 0.05
# It: 2660, Loss: 2.316e+01, Loss_bcs: 2.690e+00, Loss_res: 2.047e+01, Adaptive_Constant: 88.63 ,Time: 0.05
# It: 2670, Loss: 2.148e+01, Loss_bcs: 3.748e+00, Loss_res: 1.773e+01, Adaptive_Constant: 99.73 ,Time: 0.06
# It: 2680, Loss: 2.127e+01, Loss_bcs: 5.023e+00, Loss_res: 1.625e+01, Adaptive_Constant: 99.35 ,Time: 0.06
# It: 2690, Loss: 1.981e+01, Loss_bcs: 3.904e+00, Loss_res: 1.591e+01, Adaptive_Constant: 95.12 ,Time: 0.06
# It: 2700, Loss: 1.575e+01, Loss_bcs: 3.457e+00, Loss_res: 1.229e+01, Adaptive_Constant: 91.51 ,Time: 0.05
# It: 2710, Loss: 1.346e+01, Loss_bcs: 3.745e+00, Loss_res: 9.718e+00, Adaptive_Constant: 88.64 ,Time: 0.06
# It: 2720, Loss: 1.969e+01, Loss_bcs: 3.345e+00, Loss_res: 1.635e+01, Adaptive_Constant: 83.03 ,Time: 0.05
# It: 2730, Loss: 1.781e+01, Loss_bcs: 3.111e+00, Loss_res: 1.470e+01, Adaptive_Constant: 85.85 ,Time: 0.05
# It: 2740, Loss: 2.113e+01, Loss_bcs: 3.639e+00, Loss_res: 1.749e+01, Adaptive_Constant: 83.90 ,Time: 0.06
# It: 2750, Loss: 1.598e+01, Loss_bcs: 2.706e+00, Loss_res: 1.327e+01, Adaptive_Constant: 91.16 ,Time: 0.05
# It: 2760, Loss: 1.803e+01, Loss_bcs: 3.514e+00, Loss_res: 1.452e+01, Adaptive_Constant: 85.96 ,Time: 0.05
# It: 2770, Loss: 1.842e+01, Loss_bcs: 3.356e+00, Loss_res: 1.506e+01, Adaptive_Constant: 81.84 ,Time: 0.05
# It: 2780, Loss: 1.366e+01, Loss_bcs: 3.200e+00, Loss_res: 1.046e+01, Adaptive_Constant: 77.75 ,Time: 0.06
# It: 2790, Loss: 1.795e+01, Loss_bcs: 2.727e+00, Loss_res: 1.522e+01, Adaptive_Constant: 75.40 ,Time: 0.05
# It: 2800, Loss: 1.853e+01, Loss_bcs: 3.128e+00, Loss_res: 1.540e+01, Adaptive_Constant: 73.70 ,Time: 0.06
# It: 2810, Loss: 1.630e+01, Loss_bcs: 2.825e+00, Loss_res: 1.347e+01, Adaptive_Constant: 71.21 ,Time: 0.06
# It: 2820, Loss: 1.559e+01, Loss_bcs: 2.903e+00, Loss_res: 1.269e+01, Adaptive_Constant: 70.32 ,Time: 0.07
# It: 2830, Loss: 1.773e+01, Loss_bcs: 2.330e+00, Loss_res: 1.540e+01, Adaptive_Constant: 75.70 ,Time: 0.05
# It: 2840, Loss: 1.809e+01, Loss_bcs: 2.463e+00, Loss_res: 1.563e+01, Adaptive_Constant: 85.18 ,Time: 0.06
# It: 2850, Loss: 1.748e+01, Loss_bcs: 3.126e+00, Loss_res: 1.435e+01, Adaptive_Constant: 81.02 ,Time: 0.05
# It: 2860, Loss: 1.333e+01, Loss_bcs: 2.866e+00, Loss_res: 1.046e+01, Adaptive_Constant: 78.14 ,Time: 0.06
# It: 2870, Loss: 9.806e+00, Loss_bcs: 3.215e+00, Loss_res: 6.590e+00, Adaptive_Constant: 72.72 ,Time: 0.05
# It: 2880, Loss: 1.362e+01, Loss_bcs: 2.891e+00, Loss_res: 1.073e+01, Adaptive_Constant: 77.34 ,Time: 0.05
# It: 2890, Loss: 1.715e+01, Loss_bcs: 2.877e+00, Loss_res: 1.427e+01, Adaptive_Constant: 94.01 ,Time: 0.06
# It: 2900, Loss: 1.641e+01, Loss_bcs: 3.207e+00, Loss_res: 1.321e+01, Adaptive_Constant: 98.71 ,Time: 0.06
# It: 2910, Loss: 1.403e+01, Loss_bcs: 3.429e+00, Loss_res: 1.060e+01, Adaptive_Constant: 96.24 ,Time: 0.05
# It: 2920, Loss: 2.138e+01, Loss_bcs: 3.652e+00, Loss_res: 1.773e+01, Adaptive_Constant: 90.88 ,Time: 0.06
# It: 2930, Loss: 1.202e+01, Loss_bcs: 2.669e+00, Loss_res: 9.353e+00, Adaptive_Constant: 90.67 ,Time: 0.06
# It: 2940, Loss: 1.457e+01, Loss_bcs: 3.290e+00, Loss_res: 1.128e+01, Adaptive_Constant: 87.50 ,Time: 0.05
# It: 2950, Loss: 1.543e+01, Loss_bcs: 3.159e+00, Loss_res: 1.227e+01, Adaptive_Constant: 82.73 ,Time: 0.05
# It: 2960, Loss: 1.728e+01, Loss_bcs: 2.759e+00, Loss_res: 1.452e+01, Adaptive_Constant: 83.42 ,Time: 0.05
# It: 2970, Loss: 1.110e+01, Loss_bcs: 2.713e+00, Loss_res: 8.386e+00, Adaptive_Constant: 82.31 ,Time: 0.06
# It: 2980, Loss: 1.539e+01, Loss_bcs: 3.083e+00, Loss_res: 1.231e+01, Adaptive_Constant: 80.11 ,Time: 0.05
# It: 2990, Loss: 1.140e+01, Loss_bcs: 3.340e+00, Loss_res: 8.056e+00, Adaptive_Constant: 77.67 ,Time: 0.06
# Eigenvalues information stored ...
# It: 3000, Loss: 1.386e+01, Loss_bcs: 2.755e+00, Loss_res: 1.110e+01, Adaptive_Constant: 80.74 ,Time: 324.04
# It: 3010, Loss: 1.529e+01, Loss_bcs: 3.786e+00, Loss_res: 1.150e+01, Adaptive_Constant: 77.76 ,Time: 0.10
# It: 3020, Loss: 1.349e+01, Loss_bcs: 2.744e+00, Loss_res: 1.074e+01, Adaptive_Constant: 81.31 ,Time: 0.06
# It: 3030, Loss: 1.227e+01, Loss_bcs: 2.696e+00, Loss_res: 9.578e+00, Adaptive_Constant: 75.34 ,Time: 0.07
# It: 3040, Loss: 1.723e+01, Loss_bcs: 3.105e+00, Loss_res: 1.412e+01, Adaptive_Constant: 71.79 ,Time: 0.08
# It: 3050, Loss: 1.352e+01, Loss_bcs: 2.271e+00, Loss_res: 1.125e+01, Adaptive_Constant: 75.16 ,Time: 0.08
# It: 3060, Loss: 1.385e+01, Loss_bcs: 2.979e+00, Loss_res: 1.087e+01, Adaptive_Constant: 74.61 ,Time: 0.07
# It: 3070, Loss: 1.127e+01, Loss_bcs: 2.537e+00, Loss_res: 8.729e+00, Adaptive_Constant: 74.01 ,Time: 0.06
# It: 3080, Loss: 1.241e+01, Loss_bcs: 2.763e+00, Loss_res: 9.644e+00, Adaptive_Constant: 77.93 ,Time: 0.06
# It: 3090, Loss: 1.330e+01, Loss_bcs: 2.728e+00, Loss_res: 1.057e+01, Adaptive_Constant: 83.37 ,Time: 0.06
# It: 3100, Loss: 1.337e+01, Loss_bcs: 2.375e+00, Loss_res: 1.099e+01, Adaptive_Constant: 90.01 ,Time: 0.06
# It: 3110, Loss: 1.694e+01, Loss_bcs: 3.553e+00, Loss_res: 1.339e+01, Adaptive_Constant: 84.99 ,Time: 0.06
# It: 3120, Loss: 1.304e+01, Loss_bcs: 2.923e+00, Loss_res: 1.011e+01, Adaptive_Constant: 78.68 ,Time: 0.07
# It: 3130, Loss: 1.233e+01, Loss_bcs: 3.164e+00, Loss_res: 9.166e+00, Adaptive_Constant: 75.17 ,Time: 0.07
# It: 3140, Loss: 1.012e+01, Loss_bcs: 2.160e+00, Loss_res: 7.959e+00, Adaptive_Constant: 75.92 ,Time: 0.06
# It: 3150, Loss: 1.221e+01, Loss_bcs: 2.676e+00, Loss_res: 9.539e+00, Adaptive_Constant: 84.77 ,Time: 0.06
# It: 3160, Loss: 9.524e+00, Loss_bcs: 2.722e+00, Loss_res: 6.803e+00, Adaptive_Constant: 78.96 ,Time: 0.06
# It: 3170, Loss: 1.020e+01, Loss_bcs: 2.401e+00, Loss_res: 7.802e+00, Adaptive_Constant: 75.86 ,Time: 0.07
# It: 3180, Loss: 1.244e+01, Loss_bcs: 2.793e+00, Loss_res: 9.651e+00, Adaptive_Constant: 83.24 ,Time: 0.07
# It: 3190, Loss: 1.171e+01, Loss_bcs: 2.845e+00, Loss_res: 8.863e+00, Adaptive_Constant: 82.15 ,Time: 0.06
# It: 3200, Loss: 1.353e+01, Loss_bcs: 3.053e+00, Loss_res: 1.047e+01, Adaptive_Constant: 98.90 ,Time: 0.06
# It: 3210, Loss: 1.035e+01, Loss_bcs: 4.503e+00, Loss_res: 5.846e+00, Adaptive_Constant: 91.54 ,Time: 0.07
# It: 3220, Loss: 1.435e+01, Loss_bcs: 3.410e+00, Loss_res: 1.094e+01, Adaptive_Constant: 85.69 ,Time: 0.07
# It: 3230, Loss: 1.121e+01, Loss_bcs: 2.684e+00, Loss_res: 8.523e+00, Adaptive_Constant: 82.26 ,Time: 0.06
# It: 3240, Loss: 1.306e+01, Loss_bcs: 3.203e+00, Loss_res: 9.854e+00, Adaptive_Constant: 84.29 ,Time: 0.06
# It: 3250, Loss: 1.371e+01, Loss_bcs: 3.413e+00, Loss_res: 1.030e+01, Adaptive_Constant: 82.90 ,Time: 0.06
# It: 3260, Loss: 1.587e+01, Loss_bcs: 2.825e+00, Loss_res: 1.304e+01, Adaptive_Constant: 80.11 ,Time: 0.06
# It: 3270, Loss: 1.090e+01, Loss_bcs: 3.034e+00, Loss_res: 7.863e+00, Adaptive_Constant: 75.46 ,Time: 0.06
# It: 3280, Loss: 1.527e+01, Loss_bcs: 2.223e+00, Loss_res: 1.305e+01, Adaptive_Constant: 79.59 ,Time: 0.06
# It: 3290, Loss: 1.561e+01, Loss_bcs: 2.664e+00, Loss_res: 1.295e+01, Adaptive_Constant: 82.30 ,Time: 0.06
# It: 3300, Loss: 1.350e+01, Loss_bcs: 3.446e+00, Loss_res: 1.006e+01, Adaptive_Constant: 79.07 ,Time: 0.07
# It: 3310, Loss: 1.225e+01, Loss_bcs: 2.845e+00, Loss_res: 9.403e+00, Adaptive_Constant: 80.87 ,Time: 0.07
# It: 3320, Loss: 1.244e+01, Loss_bcs: 3.349e+00, Loss_res: 9.087e+00, Adaptive_Constant: 76.18 ,Time: 0.06
# It: 3330, Loss: 1.330e+01, Loss_bcs: 3.530e+00, Loss_res: 9.768e+00, Adaptive_Constant: 72.77 ,Time: 0.07
# It: 3340, Loss: 1.047e+01, Loss_bcs: 2.337e+00, Loss_res: 8.133e+00, Adaptive_Constant: 77.92 ,Time: 0.06
# It: 3350, Loss: 1.215e+01, Loss_bcs: 2.787e+00, Loss_res: 9.366e+00, Adaptive_Constant: 86.13 ,Time: 0.06
# It: 3360, Loss: 9.612e+00, Loss_bcs: 3.458e+00, Loss_res: 6.154e+00, Adaptive_Constant: 81.94 ,Time: 0.06
# It: 3370, Loss: 9.558e+00, Loss_bcs: 3.439e+00, Loss_res: 6.120e+00, Adaptive_Constant: 79.77 ,Time: 0.06
# It: 3380, Loss: 1.155e+01, Loss_bcs: 3.120e+00, Loss_res: 8.430e+00, Adaptive_Constant: 76.90 ,Time: 0.07
# It: 3390, Loss: 1.116e+01, Loss_bcs: 2.415e+00, Loss_res: 8.743e+00, Adaptive_Constant: 77.75 ,Time: 0.08
# It: 3400, Loss: 9.484e+00, Loss_bcs: 2.556e+00, Loss_res: 6.929e+00, Adaptive_Constant: 75.10 ,Time: 0.06
# It: 3410, Loss: 1.024e+01, Loss_bcs: 3.048e+00, Loss_res: 7.189e+00, Adaptive_Constant: 75.13 ,Time: 0.06
# It: 3420, Loss: 1.130e+01, Loss_bcs: 2.235e+00, Loss_res: 9.070e+00, Adaptive_Constant: 79.92 ,Time: 0.07
# It: 3430, Loss: 8.259e+00, Loss_bcs: 2.697e+00, Loss_res: 5.563e+00, Adaptive_Constant: 80.12 ,Time: 0.06
# It: 3440, Loss: 8.384e+00, Loss_bcs: 2.371e+00, Loss_res: 6.013e+00, Adaptive_Constant: 78.75 ,Time: 0.06
# It: 3450, Loss: 1.033e+01, Loss_bcs: 2.727e+00, Loss_res: 7.604e+00, Adaptive_Constant: 81.14 ,Time: 0.06
# It: 3460, Loss: 1.076e+01, Loss_bcs: 2.562e+00, Loss_res: 8.198e+00, Adaptive_Constant: 84.99 ,Time: 0.06
# It: 3470, Loss: 9.627e+00, Loss_bcs: 2.398e+00, Loss_res: 7.230e+00, Adaptive_Constant: 78.64 ,Time: 0.06
# It: 3480, Loss: 9.602e+00, Loss_bcs: 2.360e+00, Loss_res: 7.242e+00, Adaptive_Constant: 77.27 ,Time: 0.08
# It: 3490, Loss: 8.555e+00, Loss_bcs: 2.566e+00, Loss_res: 5.989e+00, Adaptive_Constant: 77.32 ,Time: 0.06
# It: 3500, Loss: 1.218e+01, Loss_bcs: 2.604e+00, Loss_res: 9.576e+00, Adaptive_Constant: 82.80 ,Time: 0.06
# It: 3510, Loss: 9.532e+00, Loss_bcs: 2.518e+00, Loss_res: 7.014e+00, Adaptive_Constant: 91.14 ,Time: 0.07
# It: 3520, Loss: 1.215e+01, Loss_bcs: 2.844e+00, Loss_res: 9.310e+00, Adaptive_Constant: 85.78 ,Time: 0.06
# It: 3530, Loss: 1.100e+01, Loss_bcs: 2.671e+00, Loss_res: 8.330e+00, Adaptive_Constant: 82.95 ,Time: 0.06
# It: 3540, Loss: 9.554e+00, Loss_bcs: 2.681e+00, Loss_res: 6.873e+00, Adaptive_Constant: 82.51 ,Time: 0.06
# It: 3550, Loss: 9.751e+00, Loss_bcs: 2.005e+00, Loss_res: 7.746e+00, Adaptive_Constant: 87.02 ,Time: 0.07
# It: 3560, Loss: 9.412e+00, Loss_bcs: 2.683e+00, Loss_res: 6.730e+00, Adaptive_Constant: 86.07 ,Time: 0.06
# It: 3570, Loss: 8.312e+00, Loss_bcs: 2.846e+00, Loss_res: 5.466e+00, Adaptive_Constant: 82.89 ,Time: 0.07
# It: 3580, Loss: 1.572e+01, Loss_bcs: 2.793e+00, Loss_res: 1.293e+01, Adaptive_Constant: 82.05 ,Time: 0.06
# It: 3590, Loss: 7.048e+00, Loss_bcs: 2.264e+00, Loss_res: 4.783e+00, Adaptive_Constant: 78.94 ,Time: 0.06
# It: 3600, Loss: 1.111e+01, Loss_bcs: 2.445e+00, Loss_res: 8.663e+00, Adaptive_Constant: 87.18 ,Time: 0.07
# It: 3610, Loss: 1.044e+01, Loss_bcs: 3.173e+00, Loss_res: 7.271e+00, Adaptive_Constant: 81.02 ,Time: 0.10
# It: 3620, Loss: 9.947e+00, Loss_bcs: 2.615e+00, Loss_res: 7.332e+00, Adaptive_Constant: 78.36 ,Time: 0.06
# It: 3630, Loss: 1.620e+01, Loss_bcs: 2.102e+00, Loss_res: 1.410e+01, Adaptive_Constant: 77.32 ,Time: 0.06
# It: 3640, Loss: 1.351e+01, Loss_bcs: 2.184e+00, Loss_res: 1.133e+01, Adaptive_Constant: 78.95 ,Time: 0.06
# It: 3650, Loss: 8.389e+00, Loss_bcs: 2.197e+00, Loss_res: 6.192e+00, Adaptive_Constant: 79.15 ,Time: 0.06
# It: 3660, Loss: 1.252e+01, Loss_bcs: 2.152e+00, Loss_res: 1.037e+01, Adaptive_Constant: 75.64 ,Time: 0.06
# It: 3670, Loss: 9.992e+00, Loss_bcs: 3.106e+00, Loss_res: 6.886e+00, Adaptive_Constant: 77.10 ,Time: 0.06
# It: 3680, Loss: 1.114e+01, Loss_bcs: 2.349e+00, Loss_res: 8.788e+00, Adaptive_Constant: 79.12 ,Time: 0.07
# It: 3690, Loss: 7.027e+00, Loss_bcs: 2.398e+00, Loss_res: 4.629e+00, Adaptive_Constant: 77.15 ,Time: 0.07
# It: 3700, Loss: 9.775e+00, Loss_bcs: 2.039e+00, Loss_res: 7.736e+00, Adaptive_Constant: 75.12 ,Time: 0.06
# It: 3710, Loss: 1.093e+01, Loss_bcs: 2.346e+00, Loss_res: 8.583e+00, Adaptive_Constant: 79.91 ,Time: 0.06
# It: 3720, Loss: 9.068e+00, Loss_bcs: 2.353e+00, Loss_res: 6.715e+00, Adaptive_Constant: 77.93 ,Time: 0.07
# It: 3730, Loss: 8.740e+00, Loss_bcs: 2.528e+00, Loss_res: 6.212e+00, Adaptive_Constant: 79.76 ,Time: 0.06
# It: 3740, Loss: 1.155e+01, Loss_bcs: 2.743e+00, Loss_res: 8.809e+00, Adaptive_Constant: 94.91 ,Time: 0.06
# It: 3750, Loss: 1.164e+01, Loss_bcs: 2.919e+00, Loss_res: 8.718e+00, Adaptive_Constant: 91.97 ,Time: 0.07
# It: 3760, Loss: 8.540e+00, Loss_bcs: 2.768e+00, Loss_res: 5.773e+00, Adaptive_Constant: 88.46 ,Time: 0.06
# It: 3770, Loss: 7.473e+00, Loss_bcs: 2.862e+00, Loss_res: 4.611e+00, Adaptive_Constant: 87.06 ,Time: 0.06
# It: 3780, Loss: 1.164e+01, Loss_bcs: 2.640e+00, Loss_res: 9.001e+00, Adaptive_Constant: 83.78 ,Time: 0.06
# It: 3790, Loss: 6.886e+00, Loss_bcs: 2.712e+00, Loss_res: 4.174e+00, Adaptive_Constant: 77.99 ,Time: 0.06
# It: 3800, Loss: 9.577e+00, Loss_bcs: 2.545e+00, Loss_res: 7.032e+00, Adaptive_Constant: 76.22 ,Time: 0.07
# It: 3810, Loss: 8.807e+00, Loss_bcs: 2.432e+00, Loss_res: 6.375e+00, Adaptive_Constant: 73.67 ,Time: 0.08
# It: 3820, Loss: 8.473e+00, Loss_bcs: 2.272e+00, Loss_res: 6.202e+00, Adaptive_Constant: 71.10 ,Time: 0.06
# It: 3830, Loss: 9.581e+00, Loss_bcs: 2.201e+00, Loss_res: 7.380e+00, Adaptive_Constant: 74.45 ,Time: 0.06
# It: 3840, Loss: 8.302e+00, Loss_bcs: 2.366e+00, Loss_res: 5.936e+00, Adaptive_Constant: 73.42 ,Time: 0.06
# It: 3850, Loss: 6.681e+00, Loss_bcs: 1.815e+00, Loss_res: 4.866e+00, Adaptive_Constant: 70.54 ,Time: 0.06
# It: 3860, Loss: 7.848e+00, Loss_bcs: 2.287e+00, Loss_res: 5.561e+00, Adaptive_Constant: 70.90 ,Time: 0.06
# It: 3870, Loss: 1.080e+01, Loss_bcs: 2.443e+00, Loss_res: 8.358e+00, Adaptive_Constant: 81.36 ,Time: 0.06
# It: 3880, Loss: 8.433e+00, Loss_bcs: 2.422e+00, Loss_res: 6.012e+00, Adaptive_Constant: 84.32 ,Time: 0.06
# It: 3890, Loss: 6.870e+00, Loss_bcs: 2.215e+00, Loss_res: 4.654e+00, Adaptive_Constant: 83.75 ,Time: 0.06
# It: 3900, Loss: 6.878e+00, Loss_bcs: 2.279e+00, Loss_res: 4.598e+00, Adaptive_Constant: 83.62 ,Time: 0.06
# It: 3910, Loss: 8.784e+00, Loss_bcs: 2.495e+00, Loss_res: 6.289e+00, Adaptive_Constant: 78.62 ,Time: 0.06
# It: 3920, Loss: 1.053e+01, Loss_bcs: 2.609e+00, Loss_res: 7.923e+00, Adaptive_Constant: 82.28 ,Time: 0.07
# It: 3930, Loss: 9.957e+00, Loss_bcs: 2.409e+00, Loss_res: 7.548e+00, Adaptive_Constant: 87.86 ,Time: 0.07
# It: 3940, Loss: 1.169e+01, Loss_bcs: 2.419e+00, Loss_res: 9.274e+00, Adaptive_Constant: 85.10 ,Time: 0.06
# It: 3950, Loss: 1.183e+01, Loss_bcs: 2.573e+00, Loss_res: 9.262e+00, Adaptive_Constant: 87.45 ,Time: 0.06
# It: 3960, Loss: 8.046e+00, Loss_bcs: 2.963e+00, Loss_res: 5.082e+00, Adaptive_Constant: 89.35 ,Time: 0.06
# It: 3970, Loss: 8.642e+00, Loss_bcs: 2.836e+00, Loss_res: 5.806e+00, Adaptive_Constant: 82.19 ,Time: 0.06
# It: 3980, Loss: 9.886e+00, Loss_bcs: 2.396e+00, Loss_res: 7.490e+00, Adaptive_Constant: 76.80 ,Time: 0.07
# It: 3990, Loss: 8.034e+00, Loss_bcs: 2.401e+00, Loss_res: 5.632e+00, Adaptive_Constant: 75.02 ,Time: 0.07
# Eigenvalues information stored ...
# It: 4000, Loss: 9.324e+00, Loss_bcs: 2.849e+00, Loss_res: 6.475e+00, Adaptive_Constant: 72.97 ,Time: 344.35
# It: 4010, Loss: 9.073e+00, Loss_bcs: 1.939e+00, Loss_res: 7.133e+00, Adaptive_Constant: 68.90 ,Time: 0.08
# It: 4020, Loss: 6.965e+00, Loss_bcs: 2.309e+00, Loss_res: 4.656e+00, Adaptive_Constant: 64.82 ,Time: 0.29
# It: 4030, Loss: 6.156e+00, Loss_bcs: 2.147e+00, Loss_res: 4.009e+00, Adaptive_Constant: 63.10 ,Time: 0.24
# It: 4040, Loss: 8.585e+00, Loss_bcs: 1.808e+00, Loss_res: 6.776e+00, Adaptive_Constant: 60.80 ,Time: 0.08
# It: 4050, Loss: 7.751e+00, Loss_bcs: 1.788e+00, Loss_res: 5.963e+00, Adaptive_Constant: 61.38 ,Time: 0.09
# It: 4060, Loss: 9.373e+00, Loss_bcs: 2.095e+00, Loss_res: 7.278e+00, Adaptive_Constant: 61.81 ,Time: 0.07
# It: 4070, Loss: 1.145e+01, Loss_bcs: 1.638e+00, Loss_res: 9.814e+00, Adaptive_Constant: 77.59 ,Time: 0.07
# It: 4080, Loss: 8.921e+00, Loss_bcs: 2.028e+00, Loss_res: 6.894e+00, Adaptive_Constant: 78.17 ,Time: 0.10
# It: 4090, Loss: 7.438e+00, Loss_bcs: 2.305e+00, Loss_res: 5.133e+00, Adaptive_Constant: 82.27 ,Time: 0.14
# It: 4100, Loss: 5.994e+00, Loss_bcs: 1.978e+00, Loss_res: 4.017e+00, Adaptive_Constant: 81.31 ,Time: 0.07
# It: 4110, Loss: 7.870e+00, Loss_bcs: 2.287e+00, Loss_res: 5.583e+00, Adaptive_Constant: 77.19 ,Time: 0.06
# It: 4120, Loss: 8.669e+00, Loss_bcs: 2.246e+00, Loss_res: 6.423e+00, Adaptive_Constant: 73.17 ,Time: 0.19
# It: 4130, Loss: 7.016e+00, Loss_bcs: 2.659e+00, Loss_res: 4.357e+00, Adaptive_Constant: 71.42 ,Time: 0.19
# It: 4140, Loss: 8.298e+00, Loss_bcs: 2.371e+00, Loss_res: 5.927e+00, Adaptive_Constant: 71.79 ,Time: 0.12
# It: 4150, Loss: 7.386e+00, Loss_bcs: 2.137e+00, Loss_res: 5.249e+00, Adaptive_Constant: 72.81 ,Time: 0.13
# It: 4160, Loss: 6.540e+00, Loss_bcs: 1.853e+00, Loss_res: 4.687e+00, Adaptive_Constant: 70.78 ,Time: 0.14
# It: 4170, Loss: 7.707e+00, Loss_bcs: 2.045e+00, Loss_res: 5.662e+00, Adaptive_Constant: 88.33 ,Time: 0.13
# It: 4180, Loss: 9.122e+00, Loss_bcs: 2.445e+00, Loss_res: 6.676e+00, Adaptive_Constant: 83.46 ,Time: 0.12
# It: 4190, Loss: 7.461e+00, Loss_bcs: 2.461e+00, Loss_res: 5.000e+00, Adaptive_Constant: 76.15 ,Time: 0.10
# It: 4200, Loss: 6.763e+00, Loss_bcs: 2.760e+00, Loss_res: 4.003e+00, Adaptive_Constant: 75.31 ,Time: 0.25
# It: 4210, Loss: 9.072e+00, Loss_bcs: 2.715e+00, Loss_res: 6.357e+00, Adaptive_Constant: 72.51 ,Time: 0.24
# It: 4220, Loss: 1.092e+01, Loss_bcs: 1.655e+00, Loss_res: 9.269e+00, Adaptive_Constant: 69.97 ,Time: 0.11
# It: 4230, Loss: 6.728e+00, Loss_bcs: 2.022e+00, Loss_res: 4.706e+00, Adaptive_Constant: 67.39 ,Time: 0.10
# It: 4240, Loss: 7.637e+00, Loss_bcs: 1.968e+00, Loss_res: 5.670e+00, Adaptive_Constant: 67.41 ,Time: 0.09
# It: 4250, Loss: 7.876e+00, Loss_bcs: 1.595e+00, Loss_res: 6.281e+00, Adaptive_Constant: 69.15 ,Time: 0.11
# It: 4260, Loss: 7.302e+00, Loss_bcs: 1.824e+00, Loss_res: 5.477e+00, Adaptive_Constant: 69.44 ,Time: 0.08
# It: 4270, Loss: 6.904e+00, Loss_bcs: 2.136e+00, Loss_res: 4.768e+00, Adaptive_Constant: 74.01 ,Time: 0.07
# It: 4280, Loss: 7.586e+00, Loss_bcs: 2.098e+00, Loss_res: 5.488e+00, Adaptive_Constant: 71.91 ,Time: 0.07
# It: 4290, Loss: 9.463e+00, Loss_bcs: 1.886e+00, Loss_res: 7.576e+00, Adaptive_Constant: 74.62 ,Time: 0.06
# It: 4300, Loss: 6.640e+00, Loss_bcs: 2.051e+00, Loss_res: 4.589e+00, Adaptive_Constant: 76.28 ,Time: 0.07
# It: 4310, Loss: 6.825e+00, Loss_bcs: 2.033e+00, Loss_res: 4.792e+00, Adaptive_Constant: 72.36 ,Time: 0.07
# It: 4320, Loss: 1.209e+01, Loss_bcs: 1.827e+00, Loss_res: 1.027e+01, Adaptive_Constant: 88.77 ,Time: 0.07
# It: 4330, Loss: 5.393e+00, Loss_bcs: 2.137e+00, Loss_res: 3.256e+00, Adaptive_Constant: 91.18 ,Time: 0.07
# It: 4340, Loss: 7.413e+00, Loss_bcs: 2.669e+00, Loss_res: 4.743e+00, Adaptive_Constant: 84.10 ,Time: 0.07
# It: 4350, Loss: 7.903e+00, Loss_bcs: 3.057e+00, Loss_res: 4.846e+00, Adaptive_Constant: 78.55 ,Time: 0.06
# It: 4360, Loss: 7.971e+00, Loss_bcs: 2.065e+00, Loss_res: 5.906e+00, Adaptive_Constant: 72.51 ,Time: 0.11
# It: 4370, Loss: 8.948e+00, Loss_bcs: 1.462e+00, Loss_res: 7.486e+00, Adaptive_Constant: 76.58 ,Time: 0.15
# It: 4380, Loss: 5.111e+00, Loss_bcs: 1.782e+00, Loss_res: 3.329e+00, Adaptive_Constant: 72.21 ,Time: 0.08
# It: 4390, Loss: 6.681e+00, Loss_bcs: 2.269e+00, Loss_res: 4.413e+00, Adaptive_Constant: 73.04 ,Time: 0.06
# It: 4400, Loss: 8.492e+00, Loss_bcs: 2.014e+00, Loss_res: 6.478e+00, Adaptive_Constant: 87.25 ,Time: 0.19
# It: 4410, Loss: 6.028e+00, Loss_bcs: 2.375e+00, Loss_res: 3.653e+00, Adaptive_Constant: 80.39 ,Time: 0.07
# It: 4420, Loss: 7.674e+00, Loss_bcs: 2.223e+00, Loss_res: 5.451e+00, Adaptive_Constant: 74.95 ,Time: 0.08
# It: 4430, Loss: 5.830e+00, Loss_bcs: 1.984e+00, Loss_res: 3.847e+00, Adaptive_Constant: 70.40 ,Time: 0.15
# It: 4440, Loss: 6.665e+00, Loss_bcs: 1.961e+00, Loss_res: 4.704e+00, Adaptive_Constant: 70.23 ,Time: 0.08
# It: 4450, Loss: 6.740e+00, Loss_bcs: 1.815e+00, Loss_res: 4.925e+00, Adaptive_Constant: 70.89 ,Time: 0.07
# It: 4460, Loss: 5.284e+00, Loss_bcs: 1.652e+00, Loss_res: 3.632e+00, Adaptive_Constant: 70.05 ,Time: 0.15
# It: 4470, Loss: 8.348e+00, Loss_bcs: 1.782e+00, Loss_res: 6.567e+00, Adaptive_Constant: 67.59 ,Time: 0.07
# It: 4480, Loss: 6.032e+00, Loss_bcs: 1.979e+00, Loss_res: 4.053e+00, Adaptive_Constant: 64.67 ,Time: 0.09
# It: 4490, Loss: 5.542e+00, Loss_bcs: 1.671e+00, Loss_res: 3.871e+00, Adaptive_Constant: 69.07 ,Time: 0.12
# It: 4500, Loss: 5.258e+00, Loss_bcs: 1.639e+00, Loss_res: 3.618e+00, Adaptive_Constant: 66.14 ,Time: 0.15
# ...
# It: 6500, Loss: 3.340e+00, Loss_bcs: 1.016e+00, Loss_res: 2.324e+00, Adaptive_Constant: 80.05 ,Time: 0.14
# It: 6510, Loss: 4.487e+00, Loss_bcs: 9.706e-01, Loss_res: 3.517e+00, Adaptive_Constant: 80.89 ,Time: 0.11
# It: 6520, Loss: 4.681e+00, Loss_bcs: 1.213e+00, Loss_res: 3.468e+00, Adaptive_Constant: 82.12 ,Time: 0.11
# It: 6530, Loss: 3.835e+00, Loss_bcs: 1.255e+00, Loss_res: 2.580e+00, Adaptive_Constant: 81.57 ,Time: 0.11
# It: 6540, Loss: 2.742e+00, Loss_bcs: 1.294e+00, Loss_res: 1.448e+00, Adaptive_Constant: 77.48 ,Time: 0.11
# It: 6550, Loss: 4.364e+00, Loss_bcs: 1.125e+00, Loss_res: 3.238e+00, Adaptive_Constant: 80.92 ,Time: 0.10
# It: 6560, Loss: 3.073e+00, Loss_bcs: 1.125e+00, Loss_res: 1.948e+00, Adaptive_Constant: 76.78 ,Time: 0.11
# It: 6570, Loss: 4.543e+00, Loss_bcs: 8.874e-01, Loss_res: 3.656e+00, Adaptive_Constant: 75.66 ,Time: 0.13
# It: 6580, Loss: 4.837e+00, Loss_bcs: 1.216e+00, Loss_res: 3.621e+00, Adaptive_Constant: 85.26 ,Time: 0.11
# It: 6590, Loss: 3.013e+00, Loss_bcs: 1.214e+00, Loss_res: 1.799e+00, Adaptive_Constant: 79.70 ,Time: 0.11
# It: 6600, Loss: 3.498e+00, Loss_bcs: 9.971e-01, Loss_res: 2.501e+00, Adaptive_Constant: 79.52 ,Time: 0.11
# It: 6610, Loss: 3.555e+00, Loss_bcs: 1.052e+00, Loss_res: 2.503e+00, Adaptive_Constant: 79.85 ,Time: 0.11
# It: 6620, Loss: 3.520e+00, Loss_bcs: 9.165e-01, Loss_res: 2.603e+00, Adaptive_Constant: 80.53 ,Time: 0.11
# It: 6630, Loss: 4.505e+00, Loss_bcs: 1.253e+00, Loss_res: 3.252e+00, Adaptive_Constant: 77.06 ,Time: 0.12
# It: 6640, Loss: 2.411e+00, Loss_bcs: 1.161e+00, Loss_res: 1.251e+00, Adaptive_Constant: 72.24 ,Time: 0.12
# It: 6650, Loss: 5.704e+00, Loss_bcs: 9.835e-01, Loss_res: 4.721e+00, Adaptive_Constant: 72.75 ,Time: 0.11
# It: 6660, Loss: 2.550e+00, Loss_bcs: 1.012e+00, Loss_res: 1.538e+00, Adaptive_Constant: 68.17 ,Time: 0.12
# It: 6670, Loss: 3.191e+00, Loss_bcs: 9.031e-01, Loss_res: 2.287e+00, Adaptive_Constant: 67.03 ,Time: 0.10
# It: 6680, Loss: 4.085e+00, Loss_bcs: 8.805e-01, Loss_res: 3.205e+00, Adaptive_Constant: 89.35 ,Time: 0.11
# It: 6690, Loss: 6.347e+00, Loss_bcs: 1.069e+00, Loss_res: 5.279e+00, Adaptive_Constant: 89.67 ,Time: 0.11
# It: 6700, Loss: 3.448e+00, Loss_bcs: 8.861e-01, Loss_res: 2.562e+00, Adaptive_Constant: 92.00 ,Time: 0.10
# It: 6710, Loss: 3.631e+00, Loss_bcs: 1.038e+00, Loss_res: 2.593e+00, Adaptive_Constant: 87.97 ,Time: 0.10
# It: 6720, Loss: 3.770e+00, Loss_bcs: 1.460e+00, Loss_res: 2.310e+00, Adaptive_Constant: 81.06 ,Time: 0.11
# It: 6730, Loss: 4.268e+00, Loss_bcs: 8.750e-01, Loss_res: 3.393e+00, Adaptive_Constant: 85.12 ,Time: 0.12
# It: 6740, Loss: 3.102e+00, Loss_bcs: 1.044e+00, Loss_res: 2.059e+00, Adaptive_Constant: 84.63 ,Time: 0.11
# It: 6750, Loss: 4.516e+00, Loss_bcs: 1.182e+00, Loss_res: 3.334e+00, Adaptive_Constant: 79.66 ,Time: 0.11
# It: 6760, Loss: 4.731e+00, Loss_bcs: 1.011e+00, Loss_res: 3.720e+00, Adaptive_Constant: 80.80 ,Time: 0.11
# It: 6770, Loss: 2.954e+00, Loss_bcs: 9.706e-01, Loss_res: 1.983e+00, Adaptive_Constant: 76.52 ,Time: 0.11
# It: 6780, Loss: 2.647e+00, Loss_bcs: 7.993e-01, Loss_res: 1.848e+00, Adaptive_Constant: 72.98 ,Time: 0.10
# It: 6790, Loss: 4.625e+00, Loss_bcs: 9.418e-01, Loss_res: 3.683e+00, Adaptive_Constant: 80.31 ,Time: 0.13
# It: 6800, Loss: 4.187e+00, Loss_bcs: 1.056e+00, Loss_res: 3.132e+00, Adaptive_Constant: 82.16 ,Time: 0.12
# It: 6810, Loss: 4.559e+00, Loss_bcs: 9.877e-01, Loss_res: 3.571e+00, Adaptive_Constant: 78.46 ,Time: 0.14
# It: 6820, Loss: 2.984e+00, Loss_bcs: 1.117e+00, Loss_res: 1.867e+00, Adaptive_Constant: 73.29 ,Time: 0.11
# It: 6830, Loss: 4.397e+00, Loss_bcs: 9.079e-01, Loss_res: 3.489e+00, Adaptive_Constant: 76.64 ,Time: 0.09
# It: 6840, Loss: 3.754e+00, Loss_bcs: 1.091e+00, Loss_res: 2.663e+00, Adaptive_Constant: 80.94 ,Time: 0.10
# It: 6850, Loss: 2.489e+00, Loss_bcs: 9.058e-01, Loss_res: 1.583e+00, Adaptive_Constant: 84.38 ,Time: 0.11
# It: 6860, Loss: 5.667e+00, Loss_bcs: 1.054e+00, Loss_res: 4.613e+00, Adaptive_Constant: 87.79 ,Time: 0.11
# It: 6870, Loss: 3.128e+00, Loss_bcs: 1.144e+00, Loss_res: 1.984e+00, Adaptive_Constant: 82.91 ,Time: 0.10
# It: 6880, Loss: 3.525e+00, Loss_bcs: 1.138e+00, Loss_res: 2.387e+00, Adaptive_Constant: 78.73 ,Time: 0.14
# It: 6890, Loss: 4.685e+00, Loss_bcs: 1.006e+00, Loss_res: 3.679e+00, Adaptive_Constant: 78.59 ,Time: 0.11
# It: 6900, Loss: 3.698e+00, Loss_bcs: 1.059e+00, Loss_res: 2.638e+00, Adaptive_Constant: 75.74 ,Time: 0.11
# It: 6910, Loss: 5.946e+00, Loss_bcs: 9.154e-01, Loss_res: 5.031e+00, Adaptive_Constant: 77.14 ,Time: 0.10
# It: 6920, Loss: 5.046e+00, Loss_bcs: 1.058e+00, Loss_res: 3.988e+00, Adaptive_Constant: 77.81 ,Time: 0.11
# It: 6930, Loss: 2.513e+00, Loss_bcs: 9.382e-01, Loss_res: 1.575e+00, Adaptive_Constant: 74.18 ,Time: 0.10
# It: 6940, Loss: 3.073e+00, Loss_bcs: 9.287e-01, Loss_res: 2.144e+00, Adaptive_Constant: 72.47 ,Time: 0.11
# It: 6950, Loss: 3.240e+00, Loss_bcs: 8.510e-01, Loss_res: 2.389e+00, Adaptive_Constant: 72.47 ,Time: 0.10
# It: 6960, Loss: 2.645e+00, Loss_bcs: 8.209e-01, Loss_res: 1.824e+00, Adaptive_Constant: 79.77 ,Time: 0.11
# It: 6970, Loss: 4.434e+00, Loss_bcs: 1.081e+00, Loss_res: 3.354e+00, Adaptive_Constant: 86.06 ,Time: 0.10
# It: 6980, Loss: 3.708e+00, Loss_bcs: 1.253e+00, Loss_res: 2.455e+00, Adaptive_Constant: 82.49 ,Time: 0.10
# It: 6990, Loss: 7.632e+00, Loss_bcs: 1.213e+00, Loss_res: 6.419e+00, Adaptive_Constant: 88.72 ,Time: 0.10
# Eigenvalues information stored ...
# It: 7000, Loss: 2.941e+00, Loss_bcs: 1.052e+00, Loss_res: 1.889e+00, Adaptive_Constant: 89.25 ,Time: 628.60
# It: 7010, Loss: 2.733e+00, Loss_bcs: 8.721e-01, Loss_res: 1.861e+00, Adaptive_Constant: 90.53 ,Time: 0.16
# It: 7020, Loss: 3.422e+00, Loss_bcs: 1.047e+00, Loss_res: 2.375e+00, Adaptive_Constant: 89.14 ,Time: 0.09
# It: 7030, Loss: 3.781e+00, Loss_bcs: 9.004e-01, Loss_res: 2.881e+00, Adaptive_Constant: 88.67 ,Time: 0.09
# It: 7040, Loss: 3.865e+00, Loss_bcs: 1.093e+00, Loss_res: 2.772e+00, Adaptive_Constant: 85.35 ,Time: 0.08
# It: 7050, Loss: 2.920e+00, Loss_bcs: 1.074e+00, Loss_res: 1.845e+00, Adaptive_Constant: 86.47 ,Time: 0.11
# It: 7060, Loss: 3.692e+00, Loss_bcs: 1.288e+00, Loss_res: 2.404e+00, Adaptive_Constant: 80.65 ,Time: 0.13
# It: 7070, Loss: 2.580e+00, Loss_bcs: 1.054e+00, Loss_res: 1.526e+00, Adaptive_Constant: 78.32 ,Time: 0.12
# It: 7080, Loss: 4.712e+00, Loss_bcs: 7.945e-01, Loss_res: 3.917e+00, Adaptive_Constant: 73.80 ,Time: 0.11
# It: 7090, Loss: 3.265e+00, Loss_bcs: 7.680e-01, Loss_res: 2.497e+00, Adaptive_Constant: 78.84 ,Time: 0.12
# It: 7100, Loss: 3.692e+00, Loss_bcs: 8.989e-01, Loss_res: 2.793e+00, Adaptive_Constant: 78.87 ,Time: 0.12
# It: 7110, Loss: 4.398e+00, Loss_bcs: 9.627e-01, Loss_res: 3.435e+00, Adaptive_Constant: 92.85 ,Time: 0.11
# It: 7120, Loss: 3.985e+00, Loss_bcs: 1.026e+00, Loss_res: 2.959e+00, Adaptive_Constant: 89.76 ,Time: 0.12
# It: 7130, Loss: 3.891e+00, Loss_bcs: 9.774e-01, Loss_res: 2.913e+00, Adaptive_Constant: 101.92 ,Time: 0.11
# It: 7140, Loss: 4.669e+00, Loss_bcs: 1.265e+00, Loss_res: 3.403e+00, Adaptive_Constant: 94.38 ,Time: 0.13
# It: 7150, Loss: 4.068e+00, Loss_bcs: 1.138e+00, Loss_res: 2.930e+00, Adaptive_Constant: 90.58 ,Time: 0.14
# It: 7160, Loss: 9.924e+00, Loss_bcs: 1.279e+00, Loss_res: 8.646e+00, Adaptive_Constant: 92.25 ,Time: 0.12
# It: 7170, Loss: 5.109e+00, Loss_bcs: 1.317e+00, Loss_res: 3.792e+00, Adaptive_Constant: 87.71 ,Time: 0.11
# It: 7180, Loss: 4.832e+00, Loss_bcs: 7.943e-01, Loss_res: 4.038e+00, Adaptive_Constant: 94.72 ,Time: 0.12
# It: 7190, Loss: 2.293e+00, Loss_bcs: 7.065e-01, Loss_res: 1.586e+00, Adaptive_Constant: 89.73 ,Time: 0.11
# It: 7200, Loss: 2.192e+00, Loss_bcs: 9.106e-01, Loss_res: 1.281e+00, Adaptive_Constant: 83.75 ,Time: 0.10
# It: 7210, Loss: 2.800e+00, Loss_bcs: 8.567e-01, Loss_res: 1.944e+00, Adaptive_Constant: 80.97 ,Time: 0.11
# It: 7220, Loss: 4.196e+00, Loss_bcs: 9.119e-01, Loss_res: 3.284e+00, Adaptive_Constant: 76.89 ,Time: 0.11
# It: 7230, Loss: 2.576e+00, Loss_bcs: 7.695e-01, Loss_res: 1.807e+00, Adaptive_Constant: 75.11 ,Time: 0.10
# It: 7240, Loss: 2.404e+00, Loss_bcs: 7.562e-01, Loss_res: 1.648e+00, Adaptive_Constant: 78.94 ,Time: 0.13
# It: 7250, Loss: 3.019e+00, Loss_bcs: 9.001e-01, Loss_res: 2.119e+00, Adaptive_Constant: 77.96 ,Time: 0.10
# It: 7260, Loss: 3.171e+00, Loss_bcs: 7.322e-01, Loss_res: 2.439e+00, Adaptive_Constant: 97.13 ,Time: 0.10
# It: 7270, Loss: 3.425e+00, Loss_bcs: 9.780e-01, Loss_res: 2.447e+00, Adaptive_Constant: 93.34 ,Time: 0.10
# It: 7280, Loss: 3.718e+00, Loss_bcs: 1.017e+00, Loss_res: 2.701e+00, Adaptive_Constant: 93.13 ,Time: 0.11
# It: 7290, Loss: 2.299e+00, Loss_bcs: 7.051e-01, Loss_res: 1.594e+00, Adaptive_Constant: 92.27 ,Time: 0.10
# It: 7300, Loss: 2.580e+00, Loss_bcs: 9.355e-01, Loss_res: 1.645e+00, Adaptive_Constant: 90.42 ,Time: 0.11
# It: 7310, Loss: 2.833e+00, Loss_bcs: 1.000e+00, Loss_res: 1.833e+00, Adaptive_Constant: 85.86 ,Time: 0.10
# It: 7320, Loss: 2.651e+00, Loss_bcs: 8.484e-01, Loss_res: 1.802e+00, Adaptive_Constant: 81.47 ,Time: 0.11
# It: 7330, Loss: 3.123e+00, Loss_bcs: 9.950e-01, Loss_res: 2.128e+00, Adaptive_Constant: 80.05 ,Time: 0.10
# It: 7340, Loss: 2.715e+00, Loss_bcs: 9.008e-01, Loss_res: 1.814e+00, Adaptive_Constant: 78.02 ,Time: 0.11
# It: 7350, Loss: 2.587e+00, Loss_bcs: 9.334e-01, Loss_res: 1.653e+00, Adaptive_Constant: 74.20 ,Time: 0.10
# It: 7360, Loss: 3.083e+00, Loss_bcs: 6.518e-01, Loss_res: 2.432e+00, Adaptive_Constant: 92.43 ,Time: 0.10
# It: 7370, Loss: 2.219e+00, Loss_bcs: 8.482e-01, Loss_res: 1.371e+00, Adaptive_Constant: 86.73 ,Time: 0.10
# It: 7380, Loss: 4.597e+00, Loss_bcs: 8.613e-01, Loss_res: 3.736e+00, Adaptive_Constant: 79.41 ,Time: 0.11
# It: 7390, Loss: 2.599e+00, Loss_bcs: 8.525e-01, Loss_res: 1.746e+00, Adaptive_Constant: 77.22 ,Time: 0.10
# It: 7400, Loss: 2.165e+00, Loss_bcs: 7.388e-01, Loss_res: 1.427e+00, Adaptive_Constant: 70.58 ,Time: 0.10
# It: 7410, Loss: 2.734e+00, Loss_bcs: 7.651e-01, Loss_res: 1.969e+00, Adaptive_Constant: 88.55 ,Time: 0.11
# It: 7420, Loss: 2.162e+00, Loss_bcs: 9.058e-01, Loss_res: 1.257e+00, Adaptive_Constant: 81.48 ,Time: 0.11
# It: 7430, Loss: 2.432e+00, Loss_bcs: 6.765e-01, Loss_res: 1.756e+00, Adaptive_Constant: 82.79 ,Time: 0.10
# It: 7440, Loss: 2.297e+00, Loss_bcs: 8.812e-01, Loss_res: 1.415e+00, Adaptive_Constant: 78.59 ,Time: 0.11
# It: 7450, Loss: 2.728e+00, Loss_bcs: 8.224e-01, Loss_res: 1.906e+00, Adaptive_Constant: 85.76 ,Time: 0.10
# It: 7460, Loss: 3.702e+00, Loss_bcs: 7.829e-01, Loss_res: 2.919e+00, Adaptive_Constant: 94.13 ,Time: 0.13
# It: 7470, Loss: 2.771e+00, Loss_bcs: 1.001e+00, Loss_res: 1.769e+00, Adaptive_Constant: 93.91 ,Time: 0.10
# It: 7480, Loss: 4.115e+00, Loss_bcs: 1.206e+00, Loss_res: 2.909e+00, Adaptive_Constant: 86.54 ,Time: 0.10
# It: 7490, Loss: 3.267e+00, Loss_bcs: 9.958e-01, Loss_res: 2.271e+00, Adaptive_Constant: 80.82 ,Time: 0.10
# It: 7500, Loss: 2.365e+00, Loss_bcs: 7.347e-01, Loss_res: 1.630e+00, Adaptive_Constant: 79.10 ,Time: 0.11
# It: 7510, Loss: 2.748e+00, Loss_bcs: 8.480e-01, Loss_res: 1.900e+00, Adaptive_Constant: 78.26 ,Time: 0.10
# It: 7520, Loss: 3.345e+00, Loss_bcs: 8.685e-01, Loss_res: 2.477e+00, Adaptive_Constant: 84.10 ,Time: 0.10
# It: 7530, Loss: 2.971e+00, Loss_bcs: 8.654e-01, Loss_res: 2.105e+00, Adaptive_Constant: 77.88 ,Time: 0.10
# It: 7540, Loss: 2.900e+00, Loss_bcs: 8.654e-01, Loss_res: 2.035e+00, Adaptive_Constant: 72.74 ,Time: 0.10
# It: 7550, Loss: 3.296e+00, Loss_bcs: 7.519e-01, Loss_res: 2.544e+00, Adaptive_Constant: 72.68 ,Time: 0.12
# It: 7560, Loss: 4.727e+00, Loss_bcs: 6.992e-01, Loss_res: 4.027e+00, Adaptive_Constant: 72.73 ,Time: 0.10
# It: 7570, Loss: 3.349e+00, Loss_bcs: 7.536e-01, Loss_res: 2.595e+00, Adaptive_Constant: 72.83 ,Time: 0.09
# It: 7580, Loss: 2.753e+00, Loss_bcs: 7.210e-01, Loss_res: 2.032e+00, Adaptive_Constant: 75.72 ,Time: 0.11
# It: 7590, Loss: 3.596e+00, Loss_bcs: 7.327e-01, Loss_res: 2.864e+00, Adaptive_Constant: 82.55 ,Time: 0.10
# It: 7600, Loss: 3.578e+00, Loss_bcs: 8.534e-01, Loss_res: 2.725e+00, Adaptive_Constant: 76.43 ,Time: 0.12
# It: 7610, Loss: 3.535e+00, Loss_bcs: 7.752e-01, Loss_res: 2.760e+00, Adaptive_Constant: 93.50 ,Time: 0.11
# It: 7620, Loss: 4.410e+00, Loss_bcs: 1.043e+00, Loss_res: 3.367e+00, Adaptive_Constant: 93.40 ,Time: 0.11
# It: 7630, Loss: 3.375e+00, Loss_bcs: 1.007e+00, Loss_res: 2.368e+00, Adaptive_Constant: 88.38 ,Time: 0.13
# It: 7640, Loss: 3.287e+00, Loss_bcs: 9.383e-01, Loss_res: 2.349e+00, Adaptive_Constant: 83.53 ,Time: 0.11
# It: 7650, Loss: 3.345e+00, Loss_bcs: 7.906e-01, Loss_res: 2.554e+00, Adaptive_Constant: 79.86 ,Time: 0.12
# It: 7660, Loss: 2.235e+00, Loss_bcs: 7.871e-01, Loss_res: 1.448e+00, Adaptive_Constant: 74.49 ,Time: 0.12
# It: 7670, Loss: 2.824e+00, Loss_bcs: 8.337e-01, Loss_res: 1.990e+00, Adaptive_Constant: 71.01 ,Time: 0.10
# It: 7680, Loss: 2.432e+00, Loss_bcs: 7.297e-01, Loss_res: 1.703e+00, Adaptive_Constant: 72.66 ,Time: 0.12
# It: 7690, Loss: 3.824e+00, Loss_bcs: 7.977e-01, Loss_res: 3.026e+00, Adaptive_Constant: 76.11 ,Time: 0.12
# It: 7700, Loss: 3.118e+00, Loss_bcs: 7.382e-01, Loss_res: 2.379e+00, Adaptive_Constant: 72.72 ,Time: 0.10
# It: 7710, Loss: 2.228e+00, Loss_bcs: 6.457e-01, Loss_res: 1.583e+00, Adaptive_Constant: 70.39 ,Time: 0.09
# It: 7720, Loss: 3.228e+00, Loss_bcs: 7.542e-01, Loss_res: 2.473e+00, Adaptive_Constant: 77.66 ,Time: 0.12
# It: 7730, Loss: 4.549e+00, Loss_bcs: 8.147e-01, Loss_res: 3.734e+00, Adaptive_Constant: 80.48 ,Time: 0.10
# It: 7740, Loss: 6.403e+00, Loss_bcs: 7.954e-01, Loss_res: 5.608e+00, Adaptive_Constant: 75.71 ,Time: 0.11
# It: 7750, Loss: 2.488e+00, Loss_bcs: 7.945e-01, Loss_res: 1.693e+00, Adaptive_Constant: 76.97 ,Time: 0.10
# It: 7760, Loss: 2.451e+00, Loss_bcs: 6.726e-01, Loss_res: 1.779e+00, Adaptive_Constant: 90.41 ,Time: 0.14
# It: 7770, Loss: 2.523e+00, Loss_bcs: 8.303e-01, Loss_res: 1.693e+00, Adaptive_Constant: 84.73 ,Time: 0.11
# It: 7780, Loss: 2.349e+00, Loss_bcs: 7.901e-01, Loss_res: 1.559e+00, Adaptive_Constant: 80.61 ,Time: 0.10
# It: 7790, Loss: 2.892e+00, Loss_bcs: 8.815e-01, Loss_res: 2.010e+00, Adaptive_Constant: 75.86 ,Time: 0.10
# It: 7800, Loss: 3.145e+00, Loss_bcs: 8.113e-01, Loss_res: 2.334e+00, Adaptive_Constant: 75.07 ,Time: 0.10
# It: 7810, Loss: 2.987e+00, Loss_bcs: 8.902e-01, Loss_res: 2.097e+00, Adaptive_Constant: 81.15 ,Time: 0.12
# It: 7820, Loss: 2.982e+00, Loss_bcs: 7.794e-01, Loss_res: 2.202e+00, Adaptive_Constant: 89.11 ,Time: 0.11
# It: 7830, Loss: 3.235e+00, Loss_bcs: 9.920e-01, Loss_res: 2.243e+00, Adaptive_Constant: 94.13 ,Time: 0.10
# It: 7840, Loss: 2.431e+00, Loss_bcs: 7.733e-01, Loss_res: 1.657e+00, Adaptive_Constant: 92.31 ,Time: 0.12
# It: 7850, Loss: 2.572e+00, Loss_bcs: 1.049e+00, Loss_res: 1.523e+00, Adaptive_Constant: 91.14 ,Time: 0.19
# It: 7860, Loss: 2.424e+00, Loss_bcs: 7.131e-01, Loss_res: 1.711e+00, Adaptive_Constant: 88.70 ,Time: 0.14
# It: 7870, Loss: 4.341e+00, Loss_bcs: 1.014e+00, Loss_res: 3.327e+00, Adaptive_Constant: 85.34 ,Time: 0.14
# It: 7880, Loss: 3.831e+00, Loss_bcs: 6.711e-01, Loss_res: 3.160e+00, Adaptive_Constant: 98.38 ,Time: 0.14
# It: 7890, Loss: 2.926e+00, Loss_bcs: 8.392e-01, Loss_res: 2.086e+00, Adaptive_Constant: 96.51 ,Time: 0.15
# It: 7900, Loss: 2.916e+00, Loss_bcs: 7.679e-01, Loss_res: 2.148e+00, Adaptive_Constant: 97.87 ,Time: 0.12
# It: 7910, Loss: 4.185e+00, Loss_bcs: 8.363e-01, Loss_res: 3.349e+00, Adaptive_Constant: 93.61 ,Time: 0.11
# It: 7920, Loss: 3.130e+00, Loss_bcs: 8.871e-01, Loss_res: 2.243e+00, Adaptive_Constant: 92.35 ,Time: 0.10
# It: 7930, Loss: 2.721e+00, Loss_bcs: 7.683e-01, Loss_res: 1.952e+00, Adaptive_Constant: 86.13 ,Time: 0.12
# It: 7940, Loss: 4.033e+00, Loss_bcs: 8.154e-01, Loss_res: 3.218e+00, Adaptive_Constant: 93.58 ,Time: 0.11
# It: 7950, Loss: 2.028e+00, Loss_bcs: 8.917e-01, Loss_res: 1.137e+00, Adaptive_Constant: 90.14 ,Time: 0.12
# It: 7960, Loss: 3.802e+00, Loss_bcs: 7.299e-01, Loss_res: 3.072e+00, Adaptive_Constant: 85.39 ,Time: 0.11
# It: 7970, Loss: 3.051e+00, Loss_bcs: 8.669e-01, Loss_res: 2.184e+00, Adaptive_Constant: 79.15 ,Time: 0.10
# It: 7980, Loss: 2.561e+00, Loss_bcs: 8.091e-01, Loss_res: 1.752e+00, Adaptive_Constant: 81.89 ,Time: 0.12
# It: 7990, Loss: 2.712e+00, Loss_bcs: 8.123e-01, Loss_res: 1.900e+00, Adaptive_Constant: 80.40 ,Time: 0.10
# Eigenvalues information stored ...

# %%
# Test data
nn = 100
x1 = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x2 = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
x1, x2 = np.meshgrid(x1, x2)
X_star = np.hstack((x1.flatten()[:, None], x2.flatten()[:, None]))

# Exact solution
u_star = u(X_star, a_1, a_2)
f_star = f(X_star, a_1, a_2, lam)

# Predictions
u_pred = model.predict_u(X_star)
f_pred = model.predict_r(X_star)

# Relative error
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_u: {:.2e}'.format(error_f))

### Plot ###

# Exact solution & Predicted solution
# Exact soluton
U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

# Predicted solution
U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(x1, x2, U_star, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Exact $u(x)$')

plt.subplot(1, 3, 2)
plt.pcolor(x1, x2, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Predicted $u(x)$')

plt.subplot(1, 3, 3)
plt.pcolor(x1, x2, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10639/4245028937.py in <module>
#       1 # Test data
#       2 nn = 100
# ----> 3 x1 = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
#       4 x2 = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
#       5 x1, x2 = np.meshgrid(x1, x2)
#
# NameError: name 'np' is not defined

# %%
# Residual loss & Boundary loss
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# Adaptive Constant
adaptive_constant = model.adpative_constant_log

fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Gradients at the end of training
data_gradients_res = model.dict_gradients_res_layers
data_gradients_bcs = model.dict_gradients_bcs_layers

gradients_res_list = []
gradients_bcs_list = []

num_hidden_layers = len(layers) - 1
for j in range(num_hidden_layers):
    gradient_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradient_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]

    gradients_res_list.append(gradient_res)
    gradients_bcs_list.append(gradient_bcs)

cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    
    ax.get_legend().remove()
    ax.set_xlim([-3.0, 3.0])
    ax.set_ylim([0,100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()
fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()

# %%
# Eigenvalues if applicable
if stiff_ratio:
    eigenvalues_list = model.eigenvalue_log
    eigenvalues_bcs_list = model.eigenvalue_bcs_log
    eigenvalues_res_list = model.eigenvalue_res_log
    eigenvalues_res = eigenvalues_res_list[-1]
    eigenvalues_bcs = eigenvalues_bcs_list[-1]

    fig_5 = plt.figure(5)
    ax = fig_5.add_subplot(1, 1, 1)
    ax.plot(eigenvalues_res, label='$\mathcal{L}_r$')
    ax.plot(eigenvalues_bcs, label='$\mathcal{L}_{u_b}$')
    ax.set_xlabel('index')
    ax.set_ylabel('eigenvalue')
    ax.set_yscale('symlog')
    plt.legend()
    plt.tight_layout()
    plt.show()
