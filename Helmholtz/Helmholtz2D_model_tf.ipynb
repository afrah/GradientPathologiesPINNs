# %%
import tensorflow as tf
import numpy as np
import timeit
import os 
os.environ["KMP_WARNINGS"] = "FALSE" 

# import tensorflow as tf
# import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import seaborn as sns
# from Helmholtz2D_model_tf import Sampler, Helmholtz2D
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# %%
class Helmholtz2D:
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, model, stiff_ratio):
        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x1, self.sigma_x1 = self.mu_X[0], self.sigma_X[0]
        self.mu_x2, self.sigma_x2 = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Helmoholtz constant
        self.lam = tf.constant(lam, dtype=tf.float32)

        # Mode
        self.model = model

        # Record stiff ratio
        self.stiff_ratio = stiff_ratio

        # Adaptive constant
        self.beta = 0.9
        self.adaptive_constant_val = np.array(1.0)
        self.adaptive_constant_bc1_val = np.array(1.0)
        self.adaptive_constant_bc2_val = np.array(1.0)
        self.adaptive_constant_bc3_val = np.array(1.0)
        self.adaptive_constant_bc4_val = np.array(1.0)

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)

        if model in ['M3', 'M4']:
            # Initialize encoder weights and biases
            self.encoder_weights_1 = self.xavier_init([2, layers[1]])
            self.encoder_biases_1 = self.xavier_init([1, layers[1]])

            self.encoder_weights_2 = self.xavier_init([2, layers[1]])
            self.encoder_biases_2 = self.xavier_init([1, layers[1]])

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.x1_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # Define placeholder for adaptive constant
        self.adaptive_constant_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_val.shape)
        self.adaptive_constant_bc_1_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bc1_val.shape)
        self.adaptive_constant_bc_2_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bc2_val.shape)
        self.adaptive_constant_bc_3_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bc3_val.shape)
        self.adaptive_constant_bc_4_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bc4_val.shape)

        # Evaluate predictions
        self.u_bc1_pred = self.net_u(self.x1_bc1_tf, self.x2_bc1_tf)
        self.u_bc2_pred = self.net_u(self.x1_bc2_tf, self.x2_bc2_tf)
        self.u_bc3_pred = self.net_u(self.x1_bc3_tf, self.x2_bc3_tf)
        self.u_bc4_pred = self.net_u(self.x1_bc4_tf, self.x2_bc4_tf)

        self.u_pred = self.net_u(self.x1_u_tf, self.x2_u_tf)
        self.r_pred = self.net_r(self.x1_r_tf, self.x2_r_tf)

        # Boundary loss
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_tf - self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_tf - self.u_bc2_pred))
        self.loss_bc3 = tf.reduce_mean(tf.square(self.u_bc3_tf - self.u_bc3_pred))
        self.loss_bc4 = tf.reduce_mean(tf.square(self.u_bc4_tf - self.u_bc4_pred))
        self.loss_bcs = tf.reduce_mean(tf.square(self.u_bc1_tf - self.u_bc1_pred)) + \
            self.adaptive_constant_bc_2_tf *tf.reduce_mean(tf.square(self.u_bc2_tf - self.u_bc2_pred)) + \
            self.adaptive_constant_bc_3_tf *tf.reduce_mean(tf.square(self.u_bc3_tf - self.u_bc3_pred)) + \
            self.adaptive_constant_bc_4_tf * tf.reduce_mean(tf.square(self.u_bc4_tf - self.u_bc4_pred))
            #self.adaptive_constant_tf * (self.loss_bc1 + self.loss_bc2 + self.loss_bc3 + self.loss_bc4)

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_tf - self.r_pred))

        # Total loss
        self.loss = self.loss_res + self.loss_bcs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict(self.layers)
        self.dict_gradients_bcs_layers = self.generate_grad_dict(self.layers)

        # Gradients Storage
        self.grad_res = []
        self.grad_bcs = []
        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])

        # Compute and store the adaptive constant
        self.adpative_constant_log = []
        self.adaptive_constant_list = []
        
        self.max_grad_res_list = []
        self.mean_grad_bcs_list = []
        
        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.reduce_max(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs_list.append(tf.reduce_mean(tf.abs(self.grad_bcs[i])))
        
        self.max_grad_res = tf.reduce_max(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs = tf.reduce_mean(tf.stack(self.mean_grad_bcs_list))
        self.adaptive_constant = self.max_grad_res / self.mean_grad_bcs

        # Stiff Ratio
        if self.stiff_ratio:
            self.Hessian, self.Hessian_bcs, self.Hessian_res = self.get_H_op()
            self.eigenvalues, _ = tf.linalg.eigh(self.Hessian)
            self.eigenvalues_bcs, _ = tf.linalg.eigh(self.Hessian_bcs)
            self.eigenvalues_res, _ = tf.linalg.eigh(self.Hessian_res)

            self.eigenvalue_log = []
            self.eigenvalue_bcs_log = []
            self.eigenvalue_res_log = []

        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

     # Create dictionary to store gradients
    def generate_grad_dict(self, layers):
        num = len(layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Save gradients
    def save_gradients(self, tf_dict):
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res_value, grad_bcs_value = self.sess.run([self.grad_res[i], self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_res and loss_bcs
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res_value.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bcs_value.flatten())
        return None

    # Compute the Hessian
    def flatten(self, vectors):
        return tf.concat([tf.reshape(v, [-1]) for v in vectors], axis=0)

    def get_Hv(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_res(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_res,
                                                           self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod,
                                                  self.weights))
        return Hv_op

    def get_Hv_bcs(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_bcs, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_H_op(self):
        self.P = self.flatten(self.weights).get_shape().as_list()[0]
        H = tf.map_fn(self.get_Hv, tf.eye(self.P, self.P),
                      dtype='float32')
        H_bcs = tf.map_fn(self.get_Hv_bcs, tf.eye(self.P, self.P),
                      dtype='float32')
        H_res = tf.map_fn(self.get_Hv_res, tf.eye(self.P, self.P),
                          dtype='float32')

        return H, H_bcs, H_res

    # Xavier initialization
    def xavier_init(self,size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        if self.model in ['M1', 'M2']:
            num_layers = len(self.layers)
            for l in range(0, num_layers - 2):
                W = self.weights[l]
                b = self.biases[l]
                H = tf.tanh(tf.add(tf.matmul(H, W), b))
            W = self.weights[-1]
            b = self.biases[-1]
            H = tf.add(tf.matmul(H, W), b)
            return H

        if self.model in ['M3', 'M4']:
            num_layers = len(self.layers)
            encoder_1 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_1), self.encoder_biases_1))
            encoder_2 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_2), self.encoder_biases_2))

            for l in range(0, num_layers - 2):
                W = self.weights[l]
                b = self.biases[l]
                H = tf.math.multiply(tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_1) + \
                    tf.math.multiply(1 - tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_2)

            W = self.weights[-1]
            b = self.biases[-1]
            H = tf.add(tf.matmul(H, W), b)
            return H

    # Forward pass for u
    def net_u(self, x1, x2):
        u = self.forward_pass(tf.concat([x1, x2], 1))
        return u

    # Forward pass for residual
    def net_r(self, x1, x2):
        u = self.net_u(x1, x2)
        residual = self.operator(u, x1, x2,
                                 self.lam,
                                 self.sigma_x1,
                                 self.sigma_x2)
        return residual

    # Feed minibatch
    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
    def train(self, nIter=10000, batch_size=128):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, u_bc3_batch = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, u_bc4_batch = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

            # Fetch residual mini-batch
            X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x1_bc1_tf: X_bc1_batch[:, 0:1], self.x2_bc1_tf: X_bc1_batch[:, 1:2],
                       self.u_bc1_tf: u_bc1_batch,
                       self.x1_bc2_tf: X_bc2_batch[:, 0:1], self.x2_bc2_tf: X_bc2_batch[:, 1:2],
                       self.u_bc2_tf: u_bc2_batch,
                       self.x1_bc3_tf: X_bc3_batch[:, 0:1], self.x2_bc3_tf: X_bc3_batch[:, 1:2],
                       self.u_bc3_tf: u_bc3_batch,
                       self.x1_bc4_tf: X_bc4_batch[:, 0:1], self.x2_bc4_tf: X_bc4_batch[:, 1:2],
                       self.u_bc4_tf: u_bc4_batch,
                       self.x1_r_tf: X_res_batch[:, 0:1], self.x2_r_tf: X_res_batch[:, 1:2], self.r_tf: f_res_batch,
                       self.adaptive_constant_tf:  self.adaptive_constant_val,
                       self.adaptive_constant_bc_1_tf:  self.adaptive_constant_bc1_val,
                       self.adaptive_constant_bc_2_tf:  self.adaptive_constant_bc2_val,
                       self.adaptive_constant_bc_3_tf:  self.adaptive_constant_bc3_val,
                       self.adaptive_constant_bc_4_tf:  self.adaptive_constant_bc4_val
                       }

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Compute the eigenvalues of the Hessian of losses
            if self.stiff_ratio:
                if it % 1000 == 0:
                    print("Eigenvalues information stored ...")
                    eigenvalues, eigenvalues_bcs, eigenvalues_res = self.sess.run([self.eigenvalues,
                                                                                   self.eigenvalues_bcs,
                                                                                   self.eigenvalues_res], tf_dict)

                    # Log eigenvalues
                    self.eigenvalue_log.append(eigenvalues)
                    self.eigenvalue_bcs_log.append(eigenvalues_bcs)
                    self.eigenvalue_res_log.append(eigenvalues_res)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value, loss_bc1, loss_bc2, loss_bc3 ,loss_bc4 , loss_res_value = self.sess.run([self.loss_bcs, self.loss_bc1, self.loss_bc2, self.loss_bc3, self.loss_bc4, self.loss_res], tf_dict)

                self.loss_bcs_log.append(loss_bcs_value /  self.adaptive_constant_val)
                self.loss_res_log.append(loss_res_value)

                # Compute and Print adaptive weights during training
                if self.model in ['M2', 'M4']:
                    alpha = 100
                    adaptive_constant_value = self.sess.run(self.adaptive_constant, tf_dict)
                    self.adaptive_constant_bc1_val = alpha * loss_bc1 #adaptive_constant_value * (1.0 - self.beta) + self.beta * self.adaptive_constant_val
                    self.adaptive_constant_bc2_val = alpha * loss_bc2 #adaptive_constant_value * (1.0 - self.beta) + self.beta * self.adaptive_constant_val
                    self.adaptive_constant_bc3_val = alpha * loss_bc3 #adaptive_constant_value * (1.0 - self.beta) + self.beta * self.adaptive_constant_val
                    self.adaptive_constant_bc1_val = alpha * loss_bc4 #adaptive_constant_value * (1.0 - self.beta) + self.beta * self.adaptive_constant_val
                self.adpative_constant_log.append(self.adaptive_constant_val)

                print('It: %d, Loss: %.3e, loss_bc1: %.3e, loss_bc2: %.3e, loss_bc3: %.3e, loss_bc4: %.3e, Loss_res: %.3e, Adaptive_Constant: %.2f ,Time: %.2f' %
                      (it, loss_value, loss_bc1, loss_bc2, loss_bc3, loss_bc4, loss_res_value, self.adaptive_constant_val, elapsed))
                start_time = timeit.default_timer()

            # Store gradients
            if it % 10000 == 0:
                self.save_gradients(tf_dict)
                print("Gradients information stored ...")

                # Evaluates predictions at test points

    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x1_u_tf: X_star[:, 0:1], self.x2_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x1_r_tf: X_star[:, 0:1], self.x2_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

# %%
a_1 = 1
a_2 = 4

def u(x, a_1, a_2):
    return np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

def u_xx(x, a_1, a_2):
    return - (a_1 * np.pi) ** 2 * np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

def u_yy(x, a_1, a_2):
    return - (a_2 * np.pi) ** 2 * np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

# Forcing
def f(x, a_1, a_2, lam):
    return u_xx(x, a_1, a_2) + u_yy(x, a_1, a_2) + lam * u(x, a_1, a_2)

def operator(u, x1, x2, lam, sigma_x1=1.0, sigma_x2=1.0):
    u_x1 = tf.gradients(u, x1)[0] / sigma_x1
    u_x2 = tf.gradients(u, x2)[0] / sigma_x2
    u_xx1 = tf.gradients(u_x1, x1)[0] / sigma_x1
    u_xx2 = tf.gradients(u_x2, x2)[0] / sigma_x2
    residual = u_xx1 + u_xx2 + lam * u
    return residual

# Parameter
lam = 1.0

# Domain boundaries
bc1_coords = np.array([[-1.0, -1.0],
                        [1.0, -1.0]])
bc2_coords = np.array([[1.0, -1.0],
                        [1.0, 1.0]])
bc3_coords = np.array([[1.0, 1.0],
                        [-1.0, 1.0]])
bc4_coords = np.array([[-1.0, 1.0],
                        [-1.0, -1.0]])

dom_coords = np.array([[-1.0, -1.0],
                        [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = None

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC2')
bc3 = Sampler(2, bc3_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC3')
bc4 = Sampler(2, bc4_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC4')
bcs_sampler = [bc1, bc2, bc3, bc4]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: f(x, a_1, a_2, lam), name='Forcing')



# Define model
mode = 'M1'            # Method: 'M1', 'M2', 'M3', 'M4'
stiff_ratio = False    # Log the eigenvalues of Hessian of losses

layers = [2, 50, 50, 50, 1]
model = Helmholtz2D(layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, mode, stiff_ratio)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_11939/3969895106.py:221: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_11939/3969895106.py:45: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_11939/3969895106.py:45: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_11939/3969895106.py:48: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-20 14:21:20.744620: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 14:21:20.766900: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-20 14:21:20.767417: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561d798e6c70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-20 14:21:20.767437: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-20 14:21:20.773959: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_11939/3969895106.py:108: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_11939/3969895106.py:111: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_11939/3969895106.py:116: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_11939/3969895106.py:156: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.

# %%
# Train model
model.train(nIter=40001, batch_size=128)
# Out:
# It: 0, Loss: 7.376e+03, loss_bc1: 8.642e-02, loss_bc2: 2.853e-02, loss_bc3: 1.029e-01, loss_bc4: 3.082e-02, Loss_res: 7.376e+03, Adaptive_Constant: 1.00 ,Time: 1.51
# Gradients information stored ...
# It: 10, Loss: 7.146e+03, loss_bc1: 8.833e-04, loss_bc2: 5.259e-03, loss_bc3: 5.894e-03, loss_bc4: 1.214e-04, Loss_res: 7.146e+03, Adaptive_Constant: 1.00 ,Time: 4.13
# It: 20, Loss: 6.440e+03, loss_bc1: 8.077e-03, loss_bc2: 9.588e-03, loss_bc3: 3.581e-02, loss_bc4: 3.022e-03, Loss_res: 6.440e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 30, Loss: 8.000e+03, loss_bc1: 2.227e-03, loss_bc2: 1.972e-02, loss_bc3: 2.405e-02, loss_bc4: 1.974e-03, Loss_res: 8.000e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 40, Loss: 7.614e+03, loss_bc1: 6.240e-03, loss_bc2: 3.250e-03, loss_bc3: 1.691e-03, loss_bc4: 1.487e-03, Loss_res: 7.614e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 50, Loss: 7.235e+03, loss_bc1: 5.558e-02, loss_bc2: 8.356e-02, loss_bc3: 3.668e-03, loss_bc4: 6.219e-03, Loss_res: 7.235e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 60, Loss: 7.118e+03, loss_bc1: 3.602e-02, loss_bc2: 9.682e-02, loss_bc3: 1.529e-02, loss_bc4: 3.909e-02, Loss_res: 7.118e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 70, Loss: 6.311e+03, loss_bc1: 3.234e-02, loss_bc2: 3.318e-02, loss_bc3: 5.481e-03, loss_bc4: 2.653e-02, Loss_res: 6.311e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 80, Loss: 7.229e+03, loss_bc1: 4.564e-02, loss_bc2: 2.048e-02, loss_bc3: 9.711e-02, loss_bc4: 1.000e-02, Loss_res: 7.229e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 90, Loss: 6.953e+03, loss_bc1: 1.038e-01, loss_bc2: 5.986e-02, loss_bc3: 6.084e-02, loss_bc4: 1.446e-01, Loss_res: 6.952e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 100, Loss: 6.473e+03, loss_bc1: 7.729e-02, loss_bc2: 2.852e-02, loss_bc3: 1.250e-01, loss_bc4: 7.083e-02, Loss_res: 6.472e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 110, Loss: 6.101e+03, loss_bc1: 6.062e-02, loss_bc2: 1.326e-01, loss_bc3: 6.245e-01, loss_bc4: 3.318e-02, Loss_res: 6.100e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 120, Loss: 7.555e+03, loss_bc1: 8.216e-02, loss_bc2: 4.305e-01, loss_bc3: 1.465e+00, loss_bc4: 1.757e-02, Loss_res: 7.553e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 130, Loss: 6.489e+03, loss_bc1: 4.894e-01, loss_bc2: 4.338e-01, loss_bc3: 1.363e+00, loss_bc4: 7.226e-02, Loss_res: 6.487e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 140, Loss: 5.783e+03, loss_bc1: 6.637e-01, loss_bc2: 2.309e-01, loss_bc3: 8.717e-01, loss_bc4: 1.266e-01, Loss_res: 5.781e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 150, Loss: 5.768e+03, loss_bc1: 9.459e-01, loss_bc2: 2.142e-01, loss_bc3: 1.620e+00, loss_bc4: 1.813e-01, Loss_res: 5.765e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 160, Loss: 6.752e+03, loss_bc1: 1.851e+00, loss_bc2: 4.993e-01, loss_bc3: 1.699e+00, loss_bc4: 4.907e-01, Loss_res: 6.748e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 170, Loss: 7.056e+03, loss_bc1: 2.814e+00, loss_bc2: 9.108e-01, loss_bc3: 1.377e+00, loss_bc4: 7.213e-01, Loss_res: 7.050e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 180, Loss: 6.062e+03, loss_bc1: 3.092e+00, loss_bc2: 1.233e+00, loss_bc3: 9.675e-01, loss_bc4: 4.777e-01, Loss_res: 6.056e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 190, Loss: 6.769e+03, loss_bc1: 2.590e+00, loss_bc2: 5.477e-01, loss_bc3: 1.028e+00, loss_bc4: 2.928e-01, Loss_res: 6.764e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 200, Loss: 6.863e+03, loss_bc1: 2.427e+00, loss_bc2: 2.006e-01, loss_bc3: 1.616e+00, loss_bc4: 6.337e-01, Loss_res: 6.859e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 210, Loss: 6.836e+03, loss_bc1: 2.028e+00, loss_bc2: 1.497e-01, loss_bc3: 1.895e+00, loss_bc4: 8.010e-01, Loss_res: 6.831e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 220, Loss: 7.689e+03, loss_bc1: 1.872e+00, loss_bc2: 2.071e-01, loss_bc3: 1.928e+00, loss_bc4: 6.408e-01, Loss_res: 7.684e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 230, Loss: 6.002e+03, loss_bc1: 3.616e+00, loss_bc2: 6.208e-01, loss_bc3: 9.268e-01, loss_bc4: 3.303e-01, Loss_res: 5.997e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 240, Loss: 6.992e+03, loss_bc1: 3.903e+00, loss_bc2: 1.003e+00, loss_bc3: 1.403e+00, loss_bc4: 5.238e-01, Loss_res: 6.985e+03, Adaptive_Constant: 1.00 ,Time: 0.08
# It: 250, Loss: 6.741e+03, loss_bc1: 4.018e+00, loss_bc2: 3.403e-01, loss_bc3: 2.430e+00, loss_bc4: 8.422e-01, Loss_res: 6.733e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 260, Loss: 7.441e+03, loss_bc1: 4.498e+00, loss_bc2: 2.382e-01, loss_bc3: 3.563e+00, loss_bc4: 1.124e+00, Loss_res: 7.432e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 270, Loss: 6.790e+03, loss_bc1: 3.646e+00, loss_bc2: 3.506e-01, loss_bc3: 4.378e+00, loss_bc4: 1.540e+00, Loss_res: 6.780e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 280, Loss: 6.305e+03, loss_bc1: 3.780e+00, loss_bc2: 3.017e-01, loss_bc3: 4.322e+00, loss_bc4: 1.342e+00, Loss_res: 6.296e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 290, Loss: 6.197e+03, loss_bc1: 3.020e+00, loss_bc2: 3.899e-01, loss_bc3: 3.475e+00, loss_bc4: 1.152e+00, Loss_res: 6.189e+03, Adaptive_Constant: 1.00 ,Time: 0.09
# It: 300, Loss: 7.937e+03, loss_bc1: 2.917e+00, loss_bc2: 6.178e-01, loss_bc3: 3.148e+00, loss_bc4: 1.126e+00, Loss_res: 7.929e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 310, Loss: 6.264e+03, loss_bc1: 2.397e+00, loss_bc2: 9.698e-01, loss_bc3: 3.709e+00, loss_bc4: 8.801e-01, Loss_res: 6.256e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 320, Loss: 7.179e+03, loss_bc1: 2.811e+00, loss_bc2: 9.374e-01, loss_bc3: 3.754e+00, loss_bc4: 8.681e-01, Loss_res: 7.171e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It:
+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 510, Loss: 5.488e+03, loss_bc1: 7.410e+00, loss_bc2: 9.406e-01, loss_bc3: 7.379e+00, loss_bc4: 4.731e+00, Loss_res: 5.468e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 520, Loss: 7.410e+03, loss_bc1: 1.089e+01, loss_bc2: 1.061e+00, loss_bc3: 8.456e+00, loss_bc4: 5.836e+00, Loss_res: 7.383e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 530, Loss: 5.464e+03, loss_bc1: 1.030e+01, loss_bc2: 1.075e+00, loss_bc3: 9.691e+00, loss_bc4: 8.101e+00, Loss_res: 5.435e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 540, Loss: 5.162e+03, loss_bc1: 1.036e+01, loss_bc2: 1.020e+00, loss_bc3: 8.892e+00, loss_bc4: 6.425e+00, Loss_res: 5.135e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 550, Loss: 5.175e+03, loss_bc1: 1.135e+01, loss_bc2: 9.992e-01, loss_bc3: 8.322e+00, loss_bc4: 7.775e+00, Loss_res: 5.147e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 560, Loss: 4.537e+03, loss_bc1: 1.159e+01, loss_bc2: 6.882e-01, loss_bc3: 9.260e+00, loss_bc4: 8.063e+00, Loss_res: 4.507e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 570, Loss: 3.198e+03, loss_bc1: 1.071e+01, loss_bc2: 1.096e+00, loss_bc3: 8.579e+00, loss_bc4: 6.749e+00, Loss_res: 3.171e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 580, Loss: 3.806e+03, loss_bc1: 1.026e+01, loss_bc2: 1.406e+00, loss_bc3: 9.671e+00, loss_bc4: 6.785e+00, Loss_res: 3.778e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 590, Loss: 2.713e+03, loss_bc1: 1.040e+01, loss_bc2: 9.385e-01, loss_bc3: 6.505e+00, loss_bc4: 5.639e+00, Loss_res: 2.690e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 600, Loss: 2.935e+03, loss_bc1: 1.014e+01, loss_bc2: 9.946e-01, loss_bc3: 5.898e+00, loss_bc4: 4.776e+00, Loss_res: 2.913e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 610, Loss: 2.732e+03, loss_bc1: 9.320e+00, loss_bc2: 1.526e+00, loss_bc3: 5.942e+00, loss_bc4: 3.034e+00, Loss_res: 2.712e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 620, Loss: 2.099e+03, loss_bc1: 9.933e+00, loss_bc2: 2.041e+00, loss_bc3: 6.163e+00, loss_bc4: 2.790e+00, Loss_res: 2.078e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 630, Loss: 2.372e+03, loss_bc1: 8.248e+00, loss_bc2: 1.347e+00, loss_bc3: 4.655e+00, loss_bc4: 2.434e+00, Loss_res: 2.355e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 640, Loss: 1.750e+03, loss_bc1: 8.654e+00, loss_bc2: 1.349e+00, loss_bc3: 5.282e+00, loss_bc4: 1.445e+00, Loss_res: 1.733e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 650, Loss: 1.694e+03, loss_bc1: 9.432e+00, loss_bc2: 1.273e+00, loss_bc3: 5.047e+00, loss_bc4: 1.347e+00, Loss_res: 1.677e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 660, Loss: 1.302e+03, loss_bc1: 8.414e+00, loss_bc2: 2.287e+00, loss_bc3: 9.020e+00, loss_bc4: 1.489e+00, Loss_res: 1.281e+03, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 670, Loss: 1.104e+03, loss_bc1: 9.935e+00, loss_bc2: 1.544e+00, loss_bc3: 6.251e+00, loss_bc4: 9.437e-01, Loss_res: 1.085e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 680, Loss: 1.020e+03, loss_bc1: 1.007e+01, loss_bc2: 1.964e+00, loss_bc3: 9.430e+00, loss_bc4: 1.452e+00, Loss_res: 9.967e+02, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 690, Loss: 9.184e+02, loss_bc1: 8.322e+00, loss_bc2: 3.084e+00, loss_bc3: 7.322e+00, loss_bc4: 1.218e+00, Loss_res: 8.985e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 700, Loss: 7.304e+02, loss_bc1: 9.518e+00, loss_bc2: 2.567e+00, loss_bc3: 7.725e+00, loss_bc4: 1.154e+00, Loss_res: 7.094e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 710, Loss: 1.088e+03, loss_bc1: 1.214e+01, loss_bc2: 3.535e+00, loss_bc3: 8.282e+00, loss_bc4: 1.624e+00, Loss_res: 1.063e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 720, Loss: 6.218e+02, loss_bc1: 1.093e+01, loss_bc2: 2.943e+00, loss_bc3: 8.713e+00, loss_bc4: 1.368e+00, Loss_res: 5.978e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 730, Loss: 9.094e+02, loss_bc1: 1.149e+01, loss_bc2: 4.129e+00, loss_bc3: 9.682e+00, loss_bc4: 1.345e+00, Loss_res: 8.828e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 740, Loss: 1.155e+03, loss_bc1: 1.281e+01, loss_bc2: 2.729e+00, loss_bc3: 8.885e+00, loss_bc4: 1.572e+00, Loss_res: 1.129e+03, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 750, Loss: 7.832e+02, loss_bc1: 1.230e+01, loss_bc2: 3.073e+00, loss_bc3: 1.101e+01, loss_bc4: 1.484e+00, Loss_res: 7.553e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 760, Loss: 5.622e+02, loss_bc1: 9.588e+00, loss_bc2: 3.404e+00, loss_bc3: 9.013e+00, loss_bc4: 1.514e+00, Loss_res: 5.387e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 770, Loss: 6.197e+02, loss_bc1: 1.084e+01, loss_bc2: 4.101e+00, loss_bc3: 1.035e+01, loss_bc4: 1.324e+00, Loss_res: 5.931e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 780, Loss: 4.748e+02, loss_bc1: 1.110e+01, loss_bc2: 3.750e+00, loss_bc3: 1.099e+01, loss_bc4: 1.242e+00, Loss_res: 4.477e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 790, Loss: 5.104e+02, loss_bc1: 1.297e+01, loss_bc2: 3.740e+00, loss_bc3: 8.961e+00, loss_bc4: 1.093e+00, Loss_res: 4.836e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 800, Loss: 6.505e+02, loss_bc1: 1.375e+01, loss_bc2: 3.576e+00, loss_bc3: 9.020e+00, loss_bc4: 1.046e+00, Loss_res: 6.231e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 810, Loss: 3.377e+02, loss_bc1: 1.067e+01, loss_bc2: 3.957e+00, loss_bc3: 9.742e+00, loss_bc4: 1.224e+00, Loss_res: 3.121e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 820, Loss: 4.820e+02, loss_bc1: 1.070e+01, loss_bc2: 3.985e+00, loss_bc3: 1.029e+01, loss_bc4: 7.915e-01, Loss_res: 4.562e+02, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 830, Loss: 4.394e+02, loss_bc1: 1.038e+01, loss_bc2: 3.813e+00, loss_bc3: 8.787e+00, loss_bc4: 1.093e+00, Loss_res: 4.153e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 840, Loss: 3.483e+02, loss_bc1: 9.461e+00, loss_bc2: 3.161e+00, loss_bc3: 8.400e+00, loss_bc4: 9.305e-01, Loss_res: 3.264e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 850, Loss: 3.691e+02, loss_bc1: 8.629e+00, loss_bc2: 3.306e+00, loss_bc3: 8.739e+00, loss_bc4: 8.945e-01, Loss_res: 3.475e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 860, Loss: 3.500e+02, loss_bc1: 9.075e+00, loss_bc2: 2.809e+00, loss_bc3: 8.413e+00, loss_bc4: 7.919e-01, Loss_res: 3.289e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 870, Loss: 2.682e+02, loss_bc1: 8.540e+00, loss_bc2: 2.403e+00, loss_bc3: 8.287e+00, loss_bc4: 6.902e-01, Loss_res: 2.483e+02, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 880, Loss: 3.154e+02, loss_bc1: 7.591e+00, loss_bc2: 2.230e+00, loss_bc3: 8.878e+00, loss_bc4: 4.953e-01, Loss_res: 2.962e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 890, Loss: 2.638e+02, loss_bc1: 7.665e+00, loss_bc2: 2.382e+00, loss_bc3: 6.464e+00, loss_bc4: 4.660e-01, Loss_res: 2.469e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 900, Loss: 2.811e+02, loss_bc1: 7.091e+00, loss_bc2: 1.751e+00, loss_bc3: 6.334e+00, loss_bc4: 4.358e-01, Loss_res: 2.655e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 910, Loss: 2.436e+02, loss_bc1: 6.330e+00, loss_bc2: 1.800e+00, loss_bc3: 5.406e+00, loss_bc4: 3.375e-01, Loss_res: 2.298e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 920, Loss: 2.167e+02, loss_bc1: 6.590e+00, loss_bc2: 1.595e+00, loss_bc3: 5.318e+00, loss_bc4: 3.380e-01, Loss_res: 2.028e+02, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 930, Loss: 1.414e+02, loss_bc1: 6.073e+00, loss_bc2: 1.168e+00, loss_bc3: 4.788e+00, loss_bc4: 2.442e-01, Loss_res: 1.291e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 940, Loss: 1.756e+02, loss_bc1: 5.943e+00, loss_bc2: 1.330e+00, loss_bc3: 4.839e+00, loss_bc4: 3.687e-01, Loss_res: 1.632e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 950, Loss: 1.753e+02, loss_bc1: 5.375e+00, loss_bc2: 1.574e+00, loss_bc3: 4.601e+00, loss_bc4: 3.263e-01, Loss_res: 1.635e+02, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 960, Loss: 1.333e+02, loss_bc1: 5.484e+00, loss_bc2: 1.098e+00, loss_bc3: 3.763e+00, loss_bc4: 2.377e-01, Loss_res: 1.227e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 970, Loss: 1.443e+02, loss_bc1: 4.735e+00, loss_bc2: 7.879e-01, loss_bc3: 3.859e+00, loss_bc4: 2.904e-01, Loss_res: 1.346e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 980, Loss: 1.257e+02, loss_bc1: 4.631e+00, loss_bc2: 1.534e+00, loss_bc3: 3.801e+00, loss_bc4: 4.154e-01, Loss_res: 1.153e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 990, Loss: 1.657e+02, loss_bc1: 4.989e+00, loss_bc2: 1.463e+00, loss_bc3: 3.269e+00, loss_bc4: 2.977e-01, Loss_res: 1.556e+02, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1000, Loss: 1.226e+02, loss_bc1: 4.256e+00, loss_bc2: 9.712e-01, loss_bc3: 3.000e+00, loss_bc4: 4.290e-01, Loss_res: 1.139e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1010, Loss: 1.059e+02, loss_bc1: 4.278e+00, loss_bc2: 8.711e-01, loss_bc3: 2.714e+00, loss_bc4: 5.065e-01, Loss_res: 9.750e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1020, Loss: 1.281e+02, loss_bc1: 3.835e+00, loss_bc2: 1.113e+00, loss_bc3: 2.410e+00, loss_bc4: 4.728e-01, Loss_res: 1.203e+02, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1030, Loss: 1.057e+02, loss_bc1: 3.697e+00, loss_bc2: 1.369e+00, loss_bc3: 2.976e+00, loss_bc4: 3.771e-01, Loss_res: 9.723e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 
+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1220, Loss: 6.444e+01, loss_bc1: 2.461e+00, loss_bc2: 2.467e-01, loss_bc3: 1.446e+00, loss_bc4: 4.348e-01, Loss_res: 5.985e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1230, Loss: 6.604e+01, loss_bc1: 2.374e+00, loss_bc2: 4.740e-01, loss_bc3: 1.293e+00, loss_bc4: 3.771e-01, Loss_res: 6.153e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1240, Loss: 5.230e+01, loss_bc1: 2.236e+00, loss_bc2: 3.387e-01, loss_bc3: 1.490e+00, loss_bc4: 3.397e-01, Loss_res: 4.790e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1250, Loss: 5.596e+01, loss_bc1: 2.376e+00, loss_bc2: 2.863e-01, loss_bc3: 1.179e+00, loss_bc4: 3.789e-01, Loss_res: 5.174e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1260, Loss: 5.919e+01, loss_bc1: 2.105e+00, loss_bc2: 4.098e-01, loss_bc3: 1.488e+00, loss_bc4: 3.930e-01, Loss_res: 5.479e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1270, Loss: 6.150e+01, loss_bc1: 2.056e+00, loss_bc2: 3.867e-01, loss_bc3: 1.241e+00, loss_bc4: 3.688e-01, Loss_res: 5.745e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1280, Loss: 5.007e+01, loss_bc1: 2.345e+00, loss_bc2: 3.245e-01, loss_bc3: 1.443e+00, loss_bc4: 3.388e-01, Loss_res: 4.562e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1290, Loss: 4.578e+01, loss_bc1: 2.164e+00, loss_bc2: 1.985e-01, loss_bc3: 1.401e+00, loss_bc4: 3.194e-01, Loss_res: 4.169e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1300, Loss: 4.411e+01, loss_bc1: 1.908e+00, loss_bc2: 4.023e-01, loss_bc3: 1.381e+00, loss_bc4: 3.163e-01, Loss_res: 4.010e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1310, Loss: 4.986e+01, loss_bc1: 1.948e+00, loss_bc2: 2.422e-01, loss_bc3: 1.234e+00, loss_bc4: 3.333e-01, Loss_res: 4.611e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1320, Loss: 4.518e+01, loss_bc1: 1.594e+00, loss_bc2: 1.757e-01, loss_bc3: 1.325e+00, loss_bc4: 3.132e-01, Loss_res: 4.177e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1330, Loss: 4.166e+01, loss_bc1: 1.761e+00, loss_bc2: 4.216e-01, loss_bc3: 1.455e+00, loss_bc4: 2.904e-01, Loss_res: 3.773e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1340, Loss: 4.420e+01, loss_bc1: 1.651e+00, loss_bc2: 1.713e-01, loss_bc3: 1.039e+00, loss_bc4: 3.279e-01, Loss_res: 4.101e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1350, Loss: 4.327e+01, loss_bc1: 1.565e+00, loss_bc2: 2.445e-01, loss_bc3: 1.313e+00, loss_bc4: 3.291e-01, Loss_res: 3.982e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1360, Loss: 3.356e+01, loss_bc1: 1.775e+00, loss_bc2: 2.082e-01, loss_bc3: 1.271e+00, loss_bc4: 2.493e-01, Loss_res: 3.006e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1370, Loss: 4.390e+01, loss_bc1: 1.705e+00, loss_bc2: 2.750e-01, loss_bc3: 9.621e-01, loss_bc4: 2.852e-01, Loss_res: 4.067e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1380, Loss: 5.045e+01, loss_bc1: 1.539e+00, loss_bc2: 1.988e-01, loss_bc3: 9.769e-01, loss_bc4: 3.675e-01, Loss_res: 4.737e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1390, Loss: 4.347e+01, loss_bc1: 1.549e+00, loss_bc2: 2.321e-01, loss_bc3: 1.226e+00, loss_bc4: 4.049e-01, Loss_res: 4.006e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1400, Loss: 4.198e+01, loss_bc1: 1.387e+00, loss_bc2: 2.098e-01, loss_bc3: 1.097e+00, loss_bc4: 3.279e-01, Loss_res: 3.896e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1410, Loss: 4.062e+01, loss_bc1: 1.410e+00, loss_bc2: 1.983e-01, loss_bc3: 8.444e-01, loss_bc4: 2.986e-01, Loss_res: 3.786e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1420, Loss: 4.293e+01, loss_bc1: 1.272e+00, loss_bc2: 2.231e-01, loss_bc3: 9.650e-01, loss_bc4: 2.987e-01, Loss_res: 4.017e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1430, Loss: 6.786e+01, loss_bc1: 1.252e+00, loss_bc2: 1.745e-01, loss_bc3: 9.024e-01, loss_bc4: 3.015e-01, Loss_res: 6.523e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1440, Loss: 3.821e+01, loss_bc1: 1.288e+00, loss_bc2: 1.969e-01, loss_bc3: 9.444e-01, loss_bc4: 2.522e-01, Loss_res: 3.553e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1450, Loss: 3.509e+01, loss_bc1: 1.236e+00, loss_bc2: 1.898e-01, loss_bc3: 9.608e-01, loss_bc4: 3.019e-01, Loss_res: 3.240e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1460, Loss: 2.431e+01, loss_bc1: 1.396e+00, loss_bc2: 1.928e-01, loss_bc3: 9.313e-01, loss_bc4: 2.939e-01, Loss_res: 2.150e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1470, Loss: 4.083e+01, loss_bc1: 1.166e+00, loss_bc2: 1.714e-01, loss_bc3: 1.038e+00, loss_bc4: 3.441e-01, Loss_res: 3.811e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1480, Loss: 2.472e+01, loss_bc1: 1.255e+00, loss_bc2: 1.678e-01, loss_bc3: 9.499e-01, loss_bc4: 2.796e-01, Loss_res: 2.207e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1490, Loss: 3.103e+01, loss_bc1: 1.256e+00, loss_bc2: 1.297e-01, loss_bc3: 1.080e+00, loss_bc4: 3.362e-01, Loss_res: 2.822e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1500, Loss: 2.936e+01, loss_bc1: 1.191e+00, loss_bc2: 1.643e-01, loss_bc3: 8.847e-01, loss_bc4: 3.077e-01, Loss_res: 2.682e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1510, Loss: 3.311e+01, loss_bc1: 1.189e+00, loss_bc2: 2.135e-01, loss_bc3: 8.409e-01, loss_bc4: 3.157e-01, Loss_res: 3.055e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1520, Loss: 3.453e+01, loss_bc1: 9.776e-01, loss_bc2: 1.784e-01, loss_bc3: 8.301e-01, loss_bc4: 3.291e-01, Loss_res: 3.222e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1530, Loss: 3.079e+01, loss_bc1: 1.068e+00, loss_bc2: 1.844e-01, loss_bc3: 8.823e-01, loss_bc4: 2.345e-01, Loss_res: 2.842e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1540, Loss: 3.114e+01, loss_bc1: 9.500e-01, loss_bc2: 1.690e-01, loss_bc3: 8.176e-01, loss_bc4: 2.592e-01, Loss_res: 2.895e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1550, Loss: 2.864e+01, loss_bc1: 1.014e+00, loss_bc2: 1.311e-01, loss_bc3: 7.933e-01, loss_bc4: 2.158e-01, Loss_res: 2.649e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1560, Loss: 3.223e+01, loss_bc1: 1.092e+00, loss_bc2: 1.662e-01, loss_bc3: 8.205e-01, loss_bc4: 2.230e-01, Loss_res: 2.993e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1570, Loss: 3.007e+01, loss_bc1: 1.106e+00, loss_bc2: 1.965e-01, loss_bc3: 7.414e-01, loss_bc4: 2.612e-01, Loss_res: 2.776e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 1580, Loss: 3.325e+01, loss_bc1: 9.372e-01, loss_bc2: 1.621e-01, loss_bc3: 8.090e-01, loss_bc4: 3.245e-01, Loss_res: 3.101e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1590, Loss: 2.858e+01, loss_bc1: 8.881e-01, loss_bc2: 1.390e-01, loss_bc3: 6.907e-01, loss_bc4: 3.227e-01, Loss_res: 2.654e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1600, Loss: 2.662e+01, loss_bc1: 9.486e-01, loss_bc2: 1.582e-01, loss_bc3: 7.912e-01, loss_bc4: 2.568e-01, Loss_res: 2.447e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1610, Loss: 2.869e+01, loss_bc1: 8.725e-01, loss_bc2: 1.607e-01, loss_bc3: 6.885e-01, loss_bc4: 2.734e-01, Loss_res: 2.669e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1620, Loss: 2.587e+01, loss_bc1: 9.213e-01, loss_bc2: 1.428e-01, loss_bc3: 7.839e-01, loss_bc4: 2.350e-01, Loss_res: 2.379e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1630, Loss: 2.835e+01, loss_bc1: 8.671e-01, loss_bc2: 1.661e-01, loss_bc3: 5.617e-01, loss_bc4: 2.669e-01, Loss_res: 2.649e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1640, Loss: 2.616e+01, loss_bc1: 8.771e-01, loss_bc2: 1.329e-01, loss_bc3: 7.509e-01, loss_bc4: 2.501e-01, Loss_res: 2.415e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1650, Loss: 3.553e+01, loss_bc1: 7.658e-01, loss_bc2: 1.303e-01, loss_bc3: 7.069e-01, loss_bc4: 2.471e-01, Loss_res: 3.368e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1660, Loss: 3.040e+01, loss_bc1: 7.285e-01, loss_bc2: 1.199e-01, loss_bc3: 6.047e-01, loss_bc4: 2.524e-01, Loss_res: 2.870e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1670, Loss: 2.831e+01, loss_bc1: 7.273e-01, loss_bc2: 1.168e-01, loss_bc3: 6.342e-01, loss_bc4: 2.665e-01, Loss_res: 2.657e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1680, Loss: 2.673e+01, loss_bc1: 7.412e-01, loss_bc2: 1.438e-01, loss_bc3: 6.130e-01, loss_bc4: 2.392e-01, Loss_res: 2.499e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1690, Loss: 2.169e+01, loss_bc1: 6.530e-01, loss_bc2: 1.324e-01, loss_bc3: 6.012e-01, loss_bc4: 2.553e-01, Loss_res: 2.005e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1700, Loss: 2.980e+01, loss_bc1: 7.184e-01, loss_bc2: 1.456e-01, loss_bc3: 5.741e-01, loss_bc4: 2.313e-01, Loss_res: 2.813e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1710, Loss: 2.895e+01, loss_bc1: 6.960e-01, loss_bc2: 1.354e-01, loss_bc3: 5.691e-01, loss_bc4: 2.705e-01, Loss_res: 2.728e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1720, Loss: 3.129e+01, loss_bc1: 6.453e-01, loss_bc2: 1.578e-01, loss_bc3: 5.820e-01, loss_bc4: 2.532e-01, Loss_res: 2.965e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1730, Loss: 2.295e+01, loss_bc1: 6.696e-01, loss_bc2: 1.206e-01, loss_bc3: 6.545e-01, loss_bc4: 2.222e-01, Loss_res: 2.128e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 1740, Loss: 2.142e+01, loss_bc1: 7.199e-01, loss_bc2: 1.367e-01, loss_bc3: 5.414e-01, loss_bc4: 2.381e-01, Loss_res: 1.978e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1750, Loss: 2.046e+01, loss_bc1: 7.549e-01, loss_bc2: 1.222e-01, loss_bc3: 5.328e-01, loss_bc4: 2.322e-01, Loss_res: 1.882e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1760, Loss: 2.095e+01, loss_bc1: 6.876e-01, loss_bc2: 1.455e-01, loss_bc3: 5.776e-01, loss_bc4: 2.519e-01, Loss_res: 1.928e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1770, Loss: 2.391e+01, loss_bc1: 6.970e-01, loss_bc2: 1.489e-01, loss_bc3: 5.653e-01, loss_bc4: 2.521e-01, Loss_res: 2.224e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1780, Loss: 2.161e+01, loss_bc1: 6.097e-01, loss_bc2: 1.270e-01, loss_bc3: 4.756e-01, loss_bc4: 2.257e-01, Loss_res: 2.017e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1790, Loss: 2.221e+01, loss_bc1: 7.107e-01, loss_bc2: 1.189e-01, loss_bc3: 5.509e-01, loss_bc4: 2.382e-01, Loss_res: 2.059e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1800, Loss: 1.667e+01, loss_bc1: 5.688e-01, loss_bc2: 1.363e-01, loss_bc3: 6.243e-01, loss_bc4: 2.521e-01, Loss_res: 1.509e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1810, Loss: 2.179e+01, loss_bc1: 5.336e-01, loss_bc2: 1.349e-01, loss_bc3: 6.039e-01, loss_bc4: 2.194e-01, Loss_res: 2.030e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1820, Loss: 1.858e+01, loss_bc1: 6.321e-01, loss_bc2: 1.565e-01, loss_bc3: 6.149e-01, loss_bc4: 2.106e-01, Loss_res: 1.696e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1830, Loss: 2.117e+01, loss_bc1: 5.354e-01, loss_bc2: 1.467e-01, loss_bc3: 5.739e-01, loss_bc4: 2.322e-01, Loss_res: 1.968e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1840, Loss: 2.261e+01, loss_bc1: 5.948e-01, loss_bc2: 1.814e-01, loss_bc3: 5.527e-01, loss_bc4: 2.628e-01, Loss_res: 2.102e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 1850, Loss: 1.738e+01, loss_bc1: 5.357e-01, loss_bc2: 1.851e-01, loss_bc3: 5.360e-01, loss_bc4: 1.936e-01, Loss_res: 1.593e+01, Adaptive_Constant: 1.00 ,Time: 0.08
# It: 1860, Loss: 2.451e+01, loss_bc1: 6.334e-01, loss_bc2: 1.462e-01, loss_bc3: 5.251e-01, loss_bc4: 2.198e-01, Loss_res: 2.298e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 1870, Loss: 2.485e+01, loss_bc1: 5.738e-01, loss_bc2: 1.857e-01, loss_bc3: 5.011e-01, loss_bc4: 2.144e-01, Loss_res: 2.337e+01, Adaptive_Constant: 1.00 ,Time: 0.08
# It: 1880, Loss: 1.638e+01, loss_bc1: 5.821e-01, loss_bc2: 1.384e-01, loss_bc3: 4.477e-01, loss_bc4: 2.327e-01, Loss_res: 1.498e+01, Adaptive_Constant: 1.00 ,Time: 0.08
# It: 1890, Loss: 2.079e+01, loss_bc1: 4.891e-01, loss_bc2: 1.497e-01, loss_bc3: 5.953e-01, loss_bc4: 2.342e-01, Loss_res: 1.933e+01, Adaptive_Constant: 1.00 ,Time: 0.09
# It: 1900, Loss: 2.004e+01, loss_bc1: 5.506e-01, loss_bc2: 1.236e-01, loss_bc3: 4.715e-01, loss_bc4: 2.349e-01, Loss_res: 1.866e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 1910, Loss: 2.632e+01, loss_bc1: 4.690e-01, loss_bc2: 1.714e-01, loss_bc3: 5.325e-01, loss_bc4: 2.321e-01, Loss_res: 2.491e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1920, Loss: 2.214e+01, loss_bc1: 5.042e-01, loss_bc2: 1.310e-01, loss_bc3: 4.704e-01, loss_bc4: 2.101e-01, Loss_res: 2.082e+01, Adaptive_Constant: 1.00 ,Time: 0.08
# It: 1930, Loss: 2.097e+01, loss_bc1: 5.239e-01, loss_bc2: 1.667e-01, loss_bc3: 4.659e-01, loss_bc4: 2.383e-01, Loss_res: 1.957e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 1940, Loss: 2.425e+01, loss_bc1: 4.785e-01, loss_bc2: 1.657e-01, loss_bc3: 4.614e-01, loss_bc4: 2.083e-01, Loss_res: 2.294e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1950, Loss: 1.624e+01, loss_bc1: 5.036e-01, loss_bc2: 2.021e-01, loss_bc3: 4.450e-01, loss_bc4: 1.963e-01, Loss_res: 1.489e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1960, Loss: 1.625e+01, loss_bc1: 5.024e-01, loss_bc2: 1.855e-01, loss_bc3: 5.277e-01, loss_bc4: 1.735e-01, Loss_res: 1.486e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1970, Loss: 1.763e+01, loss_bc1: 4.578e-01, loss_bc2: 1.679e-01, loss_bc3: 4.749e-01, loss_bc4: 1.938e-01, Loss_res: 1.633e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 1980, Loss: 2.223e+01, loss_bc1: 4.030e-01, loss_bc2: 1.494e-01, loss_bc3: 5.071e-01, loss_bc4: 1.874e-01, Loss_res: 2.098e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 1990, Loss: 1.509e+01, loss_bc1: 3.923e-01, loss_bc2: 1.159e-01, loss_bc3: 4.674e-01, loss_bc4: 1.920e-01, Loss_res: 1.392e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2000, Loss: 2.514e+01, loss_bc1: 4.160e-01, loss_bc2: 1.459e-01, loss_bc3: 3.904e-01, loss_bc4: 2.139e-01, Loss_res: 2.397e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2010, Loss: 1.520e+01, loss_bc1: 3.984e-01, loss_bc2: 1.343e-01, loss_bc3: 4.671e-01, loss_bc4: 1.742e-01, Loss_res: 1.403e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2020, Loss: 2.425e+01, loss_bc1: 4.620e-01, loss_bc2: 1.834e-01, loss_bc3: 4.713e-01, loss_bc4: 1.617e-01, Loss_res: 2.298e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2030, Loss: 2.226e+01, loss_bc1: 4.416e-01, loss_bc2: 1.212e-01, loss_bc3: 5.061e-01, loss_bc4: 1.976e-01, Loss_res: 2.100e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2040, Loss: 2.119e+01, loss_bc1: 4.043e-01, loss_bc2: 1.191e-01, loss_bc3: 4.819e-01, loss_bc4: 1.655e-01, Loss_res: 2.002e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 2050, Loss: 1.687e+01, loss_bc1: 4.013e-01, loss_bc2: 1.625e-01, loss_bc3: 4.027e-01, loss_bc4: 1.740e-01, Loss_res: 1.573e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2060, Loss: 1.485e+01, loss_bc1: 4.528e-01, loss_bc2: 1.500e-01, loss_bc3: 4.640e-01, loss_bc4: 1.522e-01, Loss_res: 1.363e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2070, Loss: 1.864e+01, loss_bc1: 3.901e-01, loss_bc2: 1.851e-01, loss_bc3: 4.141e-01, loss_bc4: 1.593e-01, Loss_res: 1.749e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2080, Loss: 1.491e+01, loss_bc1: 3.740e-01, loss_bc2: 1.304e-01, loss_bc3: 4.572e-01, loss_bc4: 1.588e-01, Loss_res: 1.379e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2090, Loss: 1.656e+01, loss_bc1: 3.624e-01, loss_bc2: 1.291e-01, loss_bc3: 4.362e-01, loss_bc4: 1.777e-01, Loss_res: 1.545e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2100, Loss: 1.452e+01, loss_bc1: 3.549e-01, loss_bc2: 1.235e-01, loss_bc3: 5.055e-01, loss_bc4: 1.520e-01, Loss_res: 1.339e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2110, Loss: 1.475e+01, loss_bc1: 3.894e-01, loss_bc2: 1.643e-01, loss_bc3: 4.219e-01, loss_bc4: 1.512e-01, Loss_res: 1.362e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2120, Loss: 1.588e+01, loss_bc1: 4.238e-01, loss_bc2: 1.507e-01, loss_bc3: 4.322e-01, loss_bc4: 1.922e-01, Loss_res: 1.468e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2130, Loss: 1.470e+01, loss_bc1: 3.945e-01, loss_bc2: 1.336e-01, loss_bc3: 4.336e-01, loss_bc4: 1.913e-01, Loss_res: 1.355e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2140, Loss: 1.463e+01, loss_bc1: 3.963e-01, loss_bc2: 1.801e-01, loss_bc3: 4.146e-01, loss_bc4: 1.590e-01, Loss_res: 1.348e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2150, Loss: 1.813e+01, loss_bc1: 3.657e-01, loss_bc2: 1.296e-01, loss_bc3: 4.127e-01, loss_bc4: 1.436e-01, Loss_res: 1.708e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2160, Loss: 1.814e+01, loss_bc1: 3.473e-01, loss_bc2: 1.360e-01, loss_bc3: 4.529e-01, loss_bc4: 1.316e-01, Loss_res: 1.707e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 2170, Loss: 1.849e+01, loss_bc1: 3.227e-01, loss_bc2: 1.819e-01, loss_bc3: 4.107e-01, loss_bc4: 1.496e-01, Loss_res: 1.743e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2180, Loss: 1.503e+01, loss_bc1: 3.662e-01, loss_bc2: 1.406e-01, loss_bc3: 3.503e-01, loss_bc4: 1.726e-01, Loss_res: 1.400e+01, Adaptive_Constant: 1.00 ,Time: 0.08
# It: 2190, Loss: 1.617e+01, loss_bc1: 3.561e-01, loss_bc2: 1.452e-01, loss_bc3: 4.292e-01, loss_bc4: 1.340e-01, Loss_res: 1.511e+01, Adaptive_Constant: 1.00 ,Time: 0.08
# It: 2200, Loss: 1.820e+01, loss_bc1: 3.319e-01, loss_bc2: 1.473e-01, loss_bc3: 3.917e-01, loss_bc4: 1.381e-01, Loss_res: 1.720e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2210, Loss: 1.515e+01, loss_bc1: 3.217e-01, loss_bc2: 2.016e-01, loss_bc3: 4.509e-01, loss_bc4: 1.349e-01, Loss_res: 1.404e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2220, Loss: 1.596e+01, loss_bc1: 3.557e-01, loss_bc2: 1.752e-01, loss_bc3: 4.455e-01, loss_bc4: 1.390e-01, Loss_res: 1.485e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2230, Loss: 1.533e+01, loss_bc1: 3.601e-01, loss_bc2: 1.892e-01, loss_bc3: 3.517e-01, loss_bc4: 1.387e-01, Loss_res: 1.429e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2240, Loss: 1.584e+01, loss_bc1: 3.428e-01, loss_bc2: 1.626e-01, loss_bc3: 3.133e-01, loss_bc4: 1.353e-01, Loss_res: 1.488e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2250, Loss: 1.800e+01, loss_bc1: 2.807e-01, loss_bc2: 1.903e-01, loss_bc3: 3.265e-01, loss_bc4: 1.507e-01, Loss_res: 1.705e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2260, Loss: 1.528e+01, loss_bc1: 3.480e-01, loss_bc2: 1.718e-01, loss_bc3: 3.277e-01, loss_bc4: 1.490e-01, Loss_res: 1.428e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2270, Loss: 1.764e+01, loss_bc1: 3.398e-01, loss_bc2: 1.894e-01, loss_bc3: 3.235e-01, loss_bc4: 1.336e-01, Loss_res: 1.665e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2280, Loss: 1.438e+01, loss_bc1: 2.808e-01, loss_bc2: 1.728e-01, loss_bc3: 3.656e-01, loss_bc4: 1.381e-01, Loss_res: 1.342e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2290, Loss: 1.421e+01, loss_bc1: 3.622e-01, loss_bc2: 1.628e-01, loss_bc3: 3.091e-01, loss_bc4: 1.329e-01, Loss_res: 1.324e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 2300, Loss: 1.174e+01, loss_bc1: 2.598e-01, loss_bc2: 1.542e-01, loss_bc3: 3.419e-01, loss_bc4: 1.334e-01, Loss_res: 1.085e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 2310, Loss: 1.569e+01, loss_bc1: 2.767e-01, loss_bc2: 1.778e-01, loss_bc3: 3.301e-01, loss_bc4: 1.084e-01, Loss_res: 1.480e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2320, Loss: 1.886e+01, loss_bc1: 3.659e-01, loss_bc2: 1.845e-01, loss_bc3: 3.069e-01, loss_bc4: 1.254e-01, Loss_res: 1.788e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2330, Loss: 1.356e+01, loss_bc1: 3.004e-01, loss_bc2: 1.798e-01, loss_bc3: 3.140e-01, loss_bc4: 1.148e-01, Loss_res: 1.265e+01, Adaptive_Constant: 1.00 ,Time: 0.08
# It: 2340, Loss: 1.610e+01, loss_bc1: 2.966e-01, loss_bc2: 1.681e-01, loss_bc3: 3.681e-01, loss_bc4: 1.220e-01, Loss_res: 1.515e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 2350, Loss: 1.665e+01, loss_bc1: 3.040e-01, loss_bc2: 1.646e-01, loss_bc3: 4.002e-01, loss_bc4: 1.331e-01, Loss_res: 1.565e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2360, Loss: 1.740e+01, loss_bc1: 2.377e-01, loss_bc2: 1.377e-01, loss_bc3: 3.455e-01, loss_bc4: 1.286e-01, Loss_res: 1.655e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2370, Loss: 1.338e+01, loss_bc1: 2.663e-01, loss_bc2: 1.919e-01, loss_bc3: 2.910e-01, loss_bc4: 1.183e-01, Loss_res: 1.251e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2380, Loss: 1.506e+01, loss_bc1: 3.051e-01, loss_bc2: 1.885e-01, loss_bc3: 3.187e-01, loss_bc4: 1.049e-01, Loss_res: 1.414e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2390, Loss: 1.629e+01, loss_bc1: 3.759e-01, loss_bc2: 1.785e-01, loss_bc3: 3.973e-01, loss_bc4: 1.219e-01, Loss_res: 1.521e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2400, Loss: 1.336e+01, loss_bc1: 2.968e-01, loss_bc2: 1.398e-01, loss_bc3: 3.910e-01, loss_bc4: 1.039e-01, Loss_res: 1.243e+01, Adaptive_Constant: 1.00 ,Time: 0.09
# It: 2410, Loss: 1.232e+01, loss_bc1: 2.676e-01, loss_bc2: 1.682e-01, loss_bc3: 3.282e-01, loss_bc4: 1.020e-01, Loss_res: 1.145e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2420, Loss: 1.169e+01, loss_bc1: 2.898e-01, loss_bc2: 1.672e-01, loss_bc3: 3.064e-01, loss_bc4: 1.051e-01, Loss_res: 1.082e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2430, Loss: 1.342e+01, loss_bc1: 2.777e-01, loss_bc2: 1.697e-01, loss_bc3: 3.243e-01, loss_bc4: 1.100e-01, Loss_res: 1.254e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2440, Loss: 1.439e+01, loss_bc1: 2.840e-01, loss_bc2: 1.686e-01, loss_bc3: 3.476e-01, loss_bc4: 8.882e-02, Loss_res: 1.350e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2450, Loss: 1.681e+01, loss_bc1: 2.962e-01, loss_bc2: 1.611e-01, loss_bc3: 3.086e-01, loss_bc4: 1.118e-01, Loss_res: 1.594e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2460, Loss: 1.156e+01, loss_bc1: 2.437e-01, loss_bc2: 1.885e-01, loss_bc3: 2.928e-01, loss_bc4: 1.097e-01, Loss_res: 1.072e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2470, Loss: 1.565e+01, loss_bc1: 2.773e-01, loss_bc2: 1.518e-01, loss_bc3: 3.446e-01, loss_bc4: 1.036e-01, Loss_res: 1.477e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2480, Loss: 1.082e+01, loss_bc1: 2.552e-01, loss_bc2: 1.668e-01, loss_bc3: 2.969e-01, loss_bc4: 1.106e-01, Loss_res: 9.993e+00, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2490, Loss: 1.323e+01, loss_bc1: 3.194e-01, loss_bc2: 1.442e-01, loss_bc3: 3.389e-01, loss_bc4: 9.947e-02, Loss_res: 1.233e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2500, Loss: 1.300e+01, loss_bc1: 2.633e-01, loss_bc2: 1.978e-01, loss_bc3: 3.117e-01, loss_bc4: 8.440e-02, Loss_res: 1.214e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2510, Loss: 1.381e+01, loss_bc1: 2.696e-01, loss_bc2: 1.876e-01, loss_bc3: 2.818e-01, loss_bc4: 9.699e-02, Loss_res: 1.297e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 2520, Loss: 1.255e+01, loss_bc1: 2.754e-01, loss_bc2: 1.856e-01, loss_bc3: 3.573e-01, loss_bc4: 8.468e-02, Loss_res: 1.164e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2530, Loss: 1.275e+01, loss_bc1: 2.648e-01, loss_bc2: 1.920e-01, loss_bc3: 2.725e-01, loss_bc4: 9.137e-02, Loss_res: 1.193e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2540, Loss: 1.383e+01, loss_bc1: 2.371e-01, loss_bc2: 1.610e-01, loss_bc3: 3.536e-01, loss_bc4: 9.211e-02, Loss_res: 1.298e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2550, Loss: 1.268e+01, loss_bc1: 2.227e-01, loss_bc2: 1.689e-01, loss_bc3: 2.992e-01, loss_bc4: 9.435e-02, Loss_res: 1.190e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2560, Loss: 1.344e+01, loss_bc1: 2.263e-01, loss_bc2: 1.863e-01, loss_bc3: 2.550e-01, loss_bc4: 8.002e-02, Loss_res: 1.269e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2570, Loss: 1.316e+01, loss_bc1: 2.248e-01, loss_bc2: 2.047e-01, loss_bc3: 3.164e-01, loss_bc4: 8.603e-02, Loss_res: 1.233e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2580, Loss: 1.202e+01, loss_bc1: 2.567e-01, loss_bc2: 1.404e-01, loss_bc3: 3.236e-01, loss_bc4: 8.117e-02, Loss_res: 1.122e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2590, Loss: 1.346e+01, loss_bc1: 1.939e-01, loss_bc2: 1.703e-01, loss_bc3: 2.801e-01, loss_bc4: 7.734e-02, Loss_res: 1.273e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2600, Loss: 1.614e+01, loss_bc1: 2.372e-01, loss_bc2: 1.458e-01, loss_bc3: 2.317e-01, loss_bc4: 9.232e-02, Loss_res: 1.543e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2610, Loss: 1.134e+01, loss_bc1: 2.337e-01, loss_bc2: 1.745e-01, loss_bc3: 3.123e-01, loss_bc4: 8.954e-02, Loss_res: 1.053e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2620, Loss: 1.153e+01, loss_bc1: 2.300e-01, loss_bc2: 2.113e-01, loss_bc3: 3.029e-01, loss_bc4: 7.831e-02, Loss_res: 1.071e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2630, Loss: 1.424e+01, loss_bc1: 2.075e-01, loss_bc2: 1.835e-01, loss_bc3: 3.218e-01, loss_bc4: 8.220e-02, Loss_res: 1.345e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2640, Loss: 1.191e+01, loss_bc1: 2.208e-01, loss_bc2: 1.908e-01, loss_bc3: 2.799e-01, loss_bc4: 8.599e-02, Loss_res: 1.113e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2650, Loss: 1.206e+01, loss_bc1: 2.316e-01, loss_bc2: 2.002e-01, loss_bc3: 2.922e-01, loss_bc4: 7.724e-02, Loss_res: 1.125e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2660, Loss: 1.139e+01, loss_bc1: 2.378e-01, loss_bc2: 1.562e-01, loss_bc3: 2.876e-01, loss_bc4: 7.602e-02, Loss_res: 1.063e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2670, Loss: 1.412e+01, loss_bc1: 2.226e-01, loss_bc2: 1.889e-01, loss_bc3: 2.595e-01, loss_bc4: 6.710e-02, Loss_res: 1.338e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2680, Loss: 1.477e+01, loss_bc1: 2.128e-01, loss_bc2: 1.766e-01, loss_bc3: 2.405e-01, loss_bc4: 6.634e-02, Loss_res: 1.407e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2690, Loss: 1.291e+01, loss_bc1: 2.571e-01, loss_bc2: 1.870e-01, loss_bc3: 2.837e-01, loss_bc4: 6.662e-02, Loss_res: 1.212e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2700, Loss: 1.022e+01, loss_bc1: 1.832e-01, loss_bc2: 1.614e-01, loss_bc3: 3.031e-01, loss_bc4: 6.703e-02, Loss_res: 9.507e+00, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2710, Loss: 7.684e+00, loss_bc1: 2.603e-01, loss_bc2: 1.368e-01, loss_bc3: 2.825e-01, loss_bc4: 6.531e-02, Loss_res: 6.939e+00, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2720, Loss: 1.125e+01, loss_bc1: 2.615e-01, loss_bc2: 1.485e-01, loss_bc3: 3.152e-01, loss_bc4: 6.780e-02, Loss_res: 1.046e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2730, Loss: 1.119e+01, loss_bc1: 2.447e-01, loss_bc2: 1.850e-01, loss_bc3: 2.643e-01, loss_bc4: 7.044e-02, Loss_res: 1.042e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2740, Loss: 1.209e+01, loss_bc1: 2.372e-01, loss_bc2: 1.479e-01, loss_bc3: 3.309e-01, loss_bc4: 6.384e-02, Loss_res: 1.131e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2750, Loss: 1.238e+01, loss_bc1: 1.805e-01, loss_bc2: 1.679e-01, loss_bc3: 2.183e-01, loss_bc4: 6.248e-02, Loss_res: 1.175e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2760, Loss: 1.184e+01, loss_bc1: 2.290e-01, loss_bc2: 1.431e-01, loss_bc3: 2.589e-01, loss_bc4: 6.840e-02, Loss_res: 1.114e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2770, Loss: 1.133e+01, loss_bc1: 2.318e-01, loss_bc2: 1.701e-01, loss_bc3: 2.332e-01, loss_bc4: 6.474e-02, Loss_res: 1.063e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2780, Loss: 1.055e+01, loss_bc1: 1.833e-01, loss_bc2: 1.382e-01, loss_bc3: 2.948e-01, loss_bc4: 5.960e-02, Loss_res: 9.874e+00, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 2790, Loss: 1.057e+01, loss_bc1: 2.204e-01, loss_bc2: 1.477e-01, loss_bc3: 2.714e-01, loss_bc4: 6.357e-02, Loss_res: 9.870e+00, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2800, Loss: 1.252e+01, loss_bc1: 2.227e-01, loss_bc2: 1.738e-01, loss_bc3: 3.101e-01, loss_bc4: 6.219e-02, Loss_res: 1.175e+01, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 2810, Loss: 1.134e+01, loss_bc1: 2.136e-01, loss_bc2: 1.910e-01, loss_bc3: 2.654e-01, loss_bc4: 5.797e-02, Loss_res: 1.061e+01, Adaptive_Constant: 1.00 ,Time: 0.07
# It: 2820, Loss: 1.196e+01, loss_bc1: 2.148e-01, loss_bc2: 1.786e-01, loss_bc3: 2.517e-01, loss_bc4: 6.686e-02, Loss_res: 1.124e+01, Adaptive_Constant: 1.00 ,Time: 0.05
# It:
-01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 11560, Loss: 1.914e+00, loss_bc1: 6.456e-02, loss_bc2: 3.202e-02, loss_bc3: 3.895e-02, loss_bc4: 2.106e-02, Loss_res: 1.757e+00, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 11570, Loss: 1.182e+00, loss_bc1: 4.656e-02, loss_bc2: 2.443e-02, loss_bc3: 3.852e-02, loss_bc4: 2.145e-02, Loss_res: 1.051e+00, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 11580, Loss: 1.180e+00, loss_bc1: 6.806e-02, loss_bc2: 3.076e-02, loss_bc3: 4.080e-02, loss_bc4: 1.815e-02, Loss_res: 1.022e+00, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 11590, Loss: 1.385e+00, loss_bc1: 5.731e-02, loss_bc2: 3.196e-02, loss_bc3: 4.170e-02, loss_bc4: 2.307e-02, Loss_res: 1.231e+00, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 11600, Loss: 1.239e+00, loss_bc1: 5.085e-02, loss_bc2: 5.026e-02, loss_bc3: 4.294e-02, loss_bc4: 1.830e-02, Loss_res: 1.076e+00, Adaptive_Constant: 1.00 ,Time: 0.06
# It: 11610, Loss: 1.711e+00, loss_bc1: 4.452e-02, loss_bc2: 2.422e-02, loss_bc3: 4.420e-02, loss_bc4: 2.232e-02, Loss_res: 1.576e+00, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 11620, Loss: 1.113e+00, loss_bc1: 5.527e-02, loss_bc2: 2.935e-02, loss_bc3: 4.499e-02, loss_bc4: 2.270e-02, Loss_res: 9.604e-01, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 11630, Loss: 1.154e+00, loss_bc1: 5.610e-02, loss_bc2: 2.535e-02, loss_bc3: 3.926e-02, loss_bc4: 1.826e-02, Loss_res: 1.015e+00, Adaptive_Constant: 1.00 ,Time: 0.05
# It: 11640, Loss: 1.026e+00, loss_bc1: 5.843e-02, loss_bc2: 3.598e-02, loss_bc3: 4.428e-02, loss_bc4: 1.917e-02, Loss_res: 8.684e-01, Adaptive_Constant: 1.00 ,Time: 0.05

# %%
# Test data
nn = 100
x1 = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x2 = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
x1, x2 = np.meshgrid(x1, x2)
X_star = np.hstack((x1.flatten()[:, None], x2.flatten()[:, None]))

# Exact solution
u_star = u(X_star, a_1, a_2)
f_star = f(X_star, a_1, a_2, lam)

# Predictions
u_pred = model.predict_u(X_star)
f_pred = model.predict_r(X_star)

# Relative error
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_u: {:.2e}'.format(error_f))

### Plot ###

# Exact solution & Predicted solution
# Exact soluton
U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

# Predicted solution
U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(x1, x2, U_star, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Exact $u(x)$')

plt.subplot(1, 3, 2)
plt.pcolor(x1, x2, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Predicted $u(x)$')

plt.subplot(1, 3, 3)
plt.pcolor(x1, x2, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# Relative L2 error_u: 1.98e-01
# Relative L2 error_u: 6.65e-03

# %%
# Test data
nn = 100
x1 = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x2 = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
x1, x2 = np.meshgrid(x1, x2)
X_star = np.hstack((x1.flatten()[:, None], x2.flatten()[:, None]))

# Exact solution
u_star = u(X_star, a_1, a_2)
f_star = f(X_star, a_1, a_2, lam)

# Predictions
u_pred = model.predict_u(X_star)
f_pred = model.predict_r(X_star)

# Relative error
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_u: {:.2e}'.format(error_f))

### Plot ###

# Exact solution & Predicted solution
# Exact soluton
U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

# Predicted solution
U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(x1, x2, U_star, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Exact $u(x)$')

plt.subplot(1, 3, 2)
plt.pcolor(x1, x2, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Predicted $u(x)$')

plt.subplot(1, 3, 3)
plt.pcolor(x1, x2, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# Relative L2 error_u: 1.84e-01
# Relative L2 error_u: 8.79e-03

# %%
# Residual loss & Boundary loss
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# Adaptive Constant
adaptive_constant = model.adpative_constant_log

fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# Gradients at the end of training
data_gradients_res = model.dict_gradients_res_layers
data_gradients_bcs = model.dict_gradients_bcs_layers

gradients_res_list = []
gradients_bcs_list = []

num_hidden_layers = len(layers) - 1
for j in range(num_hidden_layers):
    gradient_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradient_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]

    gradients_res_list.append(gradient_res)
    gradients_bcs_list.append(gradient_bcs)

cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    
    # ax.get_legend().remove()
    ax.set_xlim([-3.0, 3.0])
    ax.set_ylim([0,100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()
fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()
# Out:
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# Residual loss & Boundary loss
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# Adaptive Constant
adaptive_constant = model.adpative_constant_log

fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# Gradients at the end of training
data_gradients_res = model.dict_gradients_res_layers
data_gradients_bcs = model.dict_gradients_bcs_layers

gradients_res_list = []
gradients_bcs_list = []

num_hidden_layers = len(layers) - 1
for j in range(num_hidden_layers):
    gradient_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradient_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]

    gradients_res_list.append(gradient_res)
    gradients_bcs_list.append(gradient_bcs)

cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    
    # ax.get_legend().remove()
    ax.set_xlim([-3.0, 3.0])
    ax.set_ylim([0,100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()
fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()
# Out:
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
stiff_ratio = 1
# Eigenvalues if applicable
if stiff_ratio:
    eigenvalues_list = model.eigenvalue_log
    eigenvalues_bcs_list = model.eigenvalue_bcs_log
    eigenvalues_res_list = model.eigenvalue_res_log
    eigenvalues_res = eigenvalues_res_list[-1]
    eigenvalues_bcs = eigenvalues_bcs_list[-1]

    fig_5 = plt.figure(5)
    ax = fig_5.add_subplot(1, 1, 1)
    ax.plot(eigenvalues_res, label='$\mathcal{L}_r$')
    ax.plot(eigenvalues_bcs, label='$\mathcal{L}_{u_b}$')
    ax.set_xlabel('index')
    ax.set_ylabel('eigenvalue')
    ax.set_yscale('symlog')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7572/1680632721.py in <module>
#       2 # Eigenvalues if applicable
#       3 if stiff_ratio:
# ----> 4     eigenvalues_list = model.eigenvalue_log
#       5     eigenvalues_bcs_list = model.eigenvalue_bcs_log
#       6     eigenvalues_res_list = model.eigenvalue_res_log
#
# AttributeError: 'Helmholtz2D' object has no attribute 'eigenvalue_log'
