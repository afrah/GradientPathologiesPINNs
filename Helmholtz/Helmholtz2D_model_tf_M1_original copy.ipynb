# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import seaborn as sns
from Helmholtz2D_model_tf import Sampler, Helmholtz2D
import timeit
import os
os.environ["KMP_WARNINGS"] = "FALSE"

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

class Helmholtz2D:
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, model, stiff_ratio):
        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x1, self.sigma_x1 = self.mu_X[0], self.sigma_X[0]
        self.mu_x2, self.sigma_x2 = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Helmoholtz constant
        self.lam = tf.constant(lam, dtype=tf.float32)

        # Mode
        self.model = model

        # Record stiff ratio
        self.stiff_ratio = stiff_ratio

        # Adaptive constant
        self.beta = 0.9
        self.adaptive_constant_val = np.array(1.0)

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)

        if model in ['M3', 'M4']:
            # Initialize encoder weights and biases
            self.encoder_weights_1 = self.xavier_init([2, layers[1]])
            self.encoder_biases_1 = self.xavier_init([1, layers[1]])

            self.encoder_weights_2 = self.xavier_init([2, layers[1]])
            self.encoder_biases_2 = self.xavier_init([1, layers[1]])

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.x1_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # Define placeholder for adaptive constant
        self.adaptive_constant_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_val.shape)

        # Evaluate predictions
        self.u_bc1_pred = self.net_u(self.x1_bc1_tf, self.x2_bc1_tf)
        self.u_bc2_pred = self.net_u(self.x1_bc2_tf, self.x2_bc2_tf)
        self.u_bc3_pred = self.net_u(self.x1_bc3_tf, self.x2_bc3_tf)
        self.u_bc4_pred = self.net_u(self.x1_bc4_tf, self.x2_bc4_tf)

        self.u_pred = self.net_u(self.x1_u_tf, self.x2_u_tf)
        self.r_pred = self.net_r(self.x1_r_tf, self.x2_r_tf)

        # Boundary loss
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_tf - self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_tf - self.u_bc2_pred))
        self.loss_bc3 = tf.reduce_mean(tf.square(self.u_bc3_tf - self.u_bc3_pred))
        self.loss_bc4 = tf.reduce_mean(tf.square(self.u_bc4_tf - self.u_bc4_pred))
        self.loss_bcs = (self.loss_bc1 + self.loss_bc2 + self.loss_bc3 + self.loss_bc4)

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_tf - self.r_pred))

        # Total loss
        self.loss = self.loss_res +  self.adaptive_constant_tf * self.loss_bcs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict(self.layers)
        self.dict_gradients_bcs_layers = self.generate_grad_dict(self.layers)

        # Gradients Storage
        self.grad_res = []
        self.grad_bcs = []
        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])

        # Compute and store the adaptive constant
        self.adpative_constant_log = []
        self.adaptive_constant_list = []
        
        self.max_grad_res_list = []
        self.mean_grad_bcs_list = []
        
        for i in range(len(self.layers) - 1):
            self.max_grad_res_list.append(tf.reduce_max(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs_list.append(tf.reduce_mean(tf.abs(self.grad_bcs[i])))
        
        self.max_grad_res = tf.reduce_max(tf.stack(self.max_grad_res_list))
        self.mean_grad_bcs = tf.reduce_mean(tf.stack(self.mean_grad_bcs_list))
        self.adaptive_constant = self.max_grad_res / self.mean_grad_bcs

        # Stiff Ratio
        if self.stiff_ratio:
            self.Hessian, self.Hessian_bcs, self.Hessian_res = self.get_H_op()
            self.eigenvalues, _ = tf.linalg.eigh(self.Hessian)
            self.eigenvalues_bcs, _ = tf.linalg.eigh(self.Hessian_bcs)
            self.eigenvalues_res, _ = tf.linalg.eigh(self.Hessian_res)

            self.eigenvalue_log = []
            self.eigenvalue_bcs_log = []
            self.eigenvalue_res_log = []

        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

     # Create dictionary to store gradients
    def generate_grad_dict(self, layers):
        num = len(layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Save gradients
    def save_gradients(self, tf_dict):
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res_value, grad_bcs_value = self.sess.run([self.grad_res[i], self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_res and loss_bcs
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res_value.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bcs_value.flatten())
        return None

    # Compute the Hessian
    def flatten(self, vectors):
        return tf.concat([tf.reshape(v, [-1]) for v in vectors], axis=0)

    def get_Hv(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss, self.weights))
        vprod = tf.math.multiply(loss_gradients,tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_res(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_res, self.weights))
        vprod = tf.math.multiply(loss_gradients, tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_Hv_bcs(self, v):
        loss_gradients = self.flatten(tf.gradients(self.loss_bcs, self.weights))
        vprod = tf.math.multiply(loss_gradients,
                                 tf.stop_gradient(v))
        Hv_op = self.flatten(tf.gradients(vprod, self.weights))
        return Hv_op

    def get_H_op(self):
        self.P = self.flatten(self.weights).get_shape().as_list()[0]
        H = tf.map_fn(self.get_Hv, tf.eye(self.P, self.P),dtype='float32')
        H_bcs = tf.map_fn(self.get_Hv_bcs, tf.eye(self.P, self.P), dtype='float32')
        H_res = tf.map_fn(self.get_Hv_res, tf.eye(self.P, self.P), dtype='float32')

        return H, H_bcs, H_res

    # Xavier initialization
    def xavier_init(self,size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        if self.model in ['M1', 'M2']:
            num_layers = len(self.layers)
            for l in range(0, num_layers - 2):
                W = self.weights[l]
                b = self.biases[l]
                H = tf.tanh(tf.add(tf.matmul(H, W), b))
            W = self.weights[-1]
            b = self.biases[-1]
            H = tf.add(tf.matmul(H, W), b)
            return H

        if self.model in ['M3', 'M4']:
            num_layers = len(self.layers)
            encoder_1 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_1), self.encoder_biases_1))
            encoder_2 = tf.tanh(tf.add(tf.matmul(H, self.encoder_weights_2), self.encoder_biases_2))

            for l in range(0, num_layers - 2):
                W = self.weights[l]
                b = self.biases[l]
                H = tf.math.multiply(tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_1) + \
                    tf.math.multiply(1 - tf.tanh(tf.add(tf.matmul(H, W), b)), encoder_2)

            W = self.weights[-1]
            b = self.biases[-1]
            H = tf.add(tf.matmul(H, W), b)
            return H

    # Forward pass for u
    def net_u(self, x1, x2):
        u = self.forward_pass(tf.concat([x1, x2], 1))
        return u

    # Forward pass for residual
    def net_r(self, x1, x2):
        u = self.net_u(x1, x2)
        residual = self.operator(u, x1, x2,
                                 self.lam,
                                 self.sigma_x1,
                                 self.sigma_x2)
        return residual

    # Feed minibatch
    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    # Trains the model by minimizing the MSE loss
    def train(self, nIter=10000, batch_size=128):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, u_bc3_batch = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, u_bc4_batch = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

            # Fetch residual mini-batch
            X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x1_bc1_tf: X_bc1_batch[:, 0:1], self.x2_bc1_tf: X_bc1_batch[:, 1:2],
                       self.u_bc1_tf: u_bc1_batch,
                       self.x1_bc2_tf: X_bc2_batch[:, 0:1], self.x2_bc2_tf: X_bc2_batch[:, 1:2],
                       self.u_bc2_tf: u_bc2_batch,
                       self.x1_bc3_tf: X_bc3_batch[:, 0:1], self.x2_bc3_tf: X_bc3_batch[:, 1:2],
                       self.u_bc3_tf: u_bc3_batch,
                       self.x1_bc4_tf: X_bc4_batch[:, 0:1], self.x2_bc4_tf: X_bc4_batch[:, 1:2],
                       self.u_bc4_tf: u_bc4_batch,
                       self.x1_r_tf: X_res_batch[:, 0:1], self.x2_r_tf: X_res_batch[:, 1:2], self.r_tf: f_res_batch,
                       self.adaptive_constant_tf:  self.adaptive_constant_val
                       }

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Compute the eigenvalues of the Hessian of losses
            if self.stiff_ratio:
                if it % 1000 == 0:
                    print("Eigenvalues information stored ...")
                    eigenvalues, eigenvalues_bcs, eigenvalues_res = self.sess.run([self.eigenvalues, self.eigenvalues_bcs, self.eigenvalues_res], tf_dict)

                    # Log eigenvalues
                    self.eigenvalue_log.append(eigenvalues)
                    self.eigenvalue_bcs_log.append(eigenvalues_bcs)
                    self.eigenvalue_res_log.append(eigenvalues_res)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value, loss_res_value = self.sess.run([self.loss_bcs, self.loss_res], tf_dict)

                self.loss_bcs_log.append(loss_bcs_value /  self.adaptive_constant_val)
                self.loss_res_log.append(loss_res_value)

                # Compute and Print adaptive weights during training
                if self.model in ['M2', 'M4']:
                    adaptive_constant_value = self.sess.run(self.adaptive_constant, tf_dict)
                    self.adaptive_constant_val = 100 * loss_bcs_value  #adaptive_constant_value * (1.0 - self.beta)  + self.beta * self.adaptive_constant_val
                self.adpative_constant_log.append(self.adaptive_constant_val)

                print('It: %d, Loss: %.3e, Loss_bcs: %.3e, Loss_res: %.3e, Adaptive_Constant: %.2f ,Time: %.2f' %
                      (it, loss_value, loss_bcs_value, loss_res_value, self.adaptive_constant_val, elapsed))
                start_time = timeit.default_timer()

            # Store gradients
            if it % 10000 == 0:
                self.save_gradients(tf_dict)
                print("Gradients information stored ...")

                # Evaluates predictions at test points

    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x1_u_tf: X_star[:, 0:1], self.x2_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x1_r_tf: X_star[:, 0:1], self.x2_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

# %%
a_1 = 1
a_2 = 4

def u(x, a_1, a_2):
    return np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

def u_xx(x, a_1, a_2):
    return - (a_1 * np.pi) ** 2 * np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

def u_yy(x, a_1, a_2):
    return - (a_2 * np.pi) ** 2 * np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

# Forcing
def f(x, a_1, a_2, lam):
    return u_xx(x, a_1, a_2) + u_yy(x, a_1, a_2) + lam * u(x, a_1, a_2)

def operator(u, x1, x2, lam, sigma_x1=1.0, sigma_x2=1.0):
    u_x1 = tf.gradients(u, x1)[0] / sigma_x1
    u_x2 = tf.gradients(u, x2)[0] / sigma_x2
    u_xx1 = tf.gradients(u_x1, x1)[0] / sigma_x1
    u_xx2 = tf.gradients(u_x2, x2)[0] / sigma_x2
    residual = u_xx1 + u_xx2 + lam * u
    return residual

# Parameter
lam = 1.0

# Domain boundaries
bc1_coords = np.array([[-1.0, -1.0],
                        [1.0, -1.0]])
bc2_coords = np.array([[1.0, -1.0],
                        [1.0, 1.0]])
bc3_coords = np.array([[1.0, 1.0],
                        [-1.0, 1.0]])
bc4_coords = np.array([[-1.0, 1.0],
                        [-1.0, -1.0]])

dom_coords = np.array([[-1.0, -1.0],
                        [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = None

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC2')
bc3 = Sampler(2, bc3_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC3')
bc4 = Sampler(2, bc4_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC4')
bcs_sampler = [bc1, bc2, bc3, bc4]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: f(x, a_1, a_2, lam), name='Forcing')

# Define model
mode = 'M2'            # Method: 'M1', 'M2', 'M3', 'M4'
stiff_ratio = False    # Log the eigenvalues of Hessian of losses

layers = [2, 50, 50, 50, 1]
model = Helmholtz2D(layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, mode, stiff_ratio)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_10210/3876222174.py:215: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10210/3876222174.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10210/3876222174.py:54: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10210/3876222174.py:57: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# 2023-11-20 13:07:05.400623: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 13:07:05.430892: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-11-20 13:07:05.431311: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5577fad55c50 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-11-20 13:07:05.431326: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-11-20 13:07:05.431921: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_10210/3876222174.py:109: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10210/3876222174.py:112: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10210/3876222174.py:117: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_10210/3876222174.py:157: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.

# %%
# Train model
model.train(nIter=40001, batch_size=128)
# Out:
# It: 0, Loss: 8.364e+03, Loss_bcs: 9.003e-01, Loss_res: 8.363e+03, Adaptive_Constant: 0.90 ,Time: 1.73
# Gradients information stored ...
# It: 10, Loss: 6.280e+03, Loss_bcs: 5.983e-02, Loss_res: 6.280e+03, Adaptive_Constant: 0.07 ,Time: 4.53
# It: 20, Loss: 5.889e+03, Loss_bcs: 1.587e-02, Loss_res: 5.889e+03, Adaptive_Constant: 0.24 ,Time: 0.12
# It: 30, Loss: 7.132e+03, Loss_bcs: 2.085e-02, Loss_res: 7.132e+03, Adaptive_Constant: 0.09 ,Time: 0.11
# It: 40, Loss: 6.250e+03, Loss_bcs: 5.251e-03, Loss_res: 6.250e+03, Adaptive_Constant: 0.06 ,Time: 0.11
# It: 50, Loss: 6.366e+03, Loss_bcs: 1.745e-02, Loss_res: 6.366e+03, Adaptive_Constant: 0.29 ,Time: 0.12
# It: 60, Loss: 6.280e+03, Loss_bcs: 1.293e-01, Loss_res: 6.280e+03, Adaptive_Constant: 0.45 ,Time: 0.12
# It: 70, Loss: 7.390e+03, Loss_bcs: 1.952e-01, Loss_res: 7.390e+03, Adaptive_Constant: 0.44 ,Time: 0.11
# It: 80, Loss: 6.908e+03, Loss_bcs: 3.646e-01, Loss_res: 6.908e+03, Adaptive_Constant: 0.83 ,Time: 0.11
# It: 90, Loss: 6.517e+03, Loss_bcs: 6.358e-01, Loss_res: 6.517e+03, Adaptive_Constant: 0.76 ,Time: 0.14
# It: 100, Loss: 8.212e+03, Loss_bcs: 7.329e-01, Loss_res: 8.211e+03, Adaptive_Constant: 0.96 ,Time: 0.14
# It: 110, Loss: 7.017e+03, Loss_bcs: 8.454e-01, Loss_res: 7.016e+03, Adaptive_Constant: 0.88 ,Time: 0.13
# It: 120, Loss: 5.635e+03, Loss_bcs: 1.031e+00, Loss_res: 5.634e+03, Adaptive_Constant: 1.17 ,Time: 0.13
# It: 130, Loss: 6.222e+03, Loss_bcs: 2.810e+00, Loss_res: 6.220e+03, Adaptive_Constant: 2.40 ,Time: 0.12
# It: 140, Loss: 7.358e+03, Loss_bcs: 6.508e+00, Loss_res: 7.352e+03, Adaptive_Constant: 2.71 ,Time: 0.13
# It: 150, Loss: 6.715e+03, Loss_bcs: 8.550e+00, Loss_res: 6.706e+03, Adaptive_Constant: 3.15 ,Time: 0.13
# It: 160, Loss: 6.146e+03, Loss_bcs: 9.429e+00, Loss_res: 6.136e+03, Adaptive_Constant: 2.99 ,Time: 0.12
# It: 170, Loss: 7.511e+03, Loss_bcs: 1.121e+01, Loss_res: 7.500e+03, Adaptive_Constant: 3.75 ,Time: 0.12
# It: 180, Loss: 5.966e+03, Loss_bcs: 1.448e+01, Loss_res: 5.952e+03, Adaptive_Constant: 3.86 ,Time: 0.13
# It: 190, Loss: 5.791e+03, Loss_bcs: 1.434e+01, Loss_res: 5.777e+03, Adaptive_Constant: 3.71 ,Time: 0.12
# It: 200, Loss: 6.478e+03, Loss_bcs: 1.450e+01, Loss_res: 6.464e+03, Adaptive_Constant: 3.90 ,Time: 0.13
# It: 210, Loss: 5.970e+03, Loss_bcs: 2.181e+01, Loss_res: 5.948e+03, Adaptive_Constant: 5.59 ,Time: 0.11
# It: 220, Loss: 6.328e+03, Loss_bcs: 2.536e+01, Loss_res: 6.303e+03, Adaptive_Constant: 4.54 ,Time: 0.13
# It: 230, Loss: 6.704e+03, Loss_bcs: 1.811e+01, Loss_res: 6.685e+03, Adaptive_Constant: 3.99 ,Time: 0.11
# It: 240, Loss: 7.231e+03, Loss_bcs: 1.610e+01, Loss_res: 7.214e+03, Adaptive_Constant: 4.04 ,Time: 0.11
# It: 250, Loss: 5.898e+03, Loss_bcs: 1.603e+01, Loss_res: 5.882e+03, Adaptive_Constant: 3.97 ,Time: 0.12
# It: 260, Loss: 6.240e+03, Loss_bcs: 1.537e+01, Loss_res: 6.225e+03, Adaptive_Constant: 3.87 ,Time: 0.11
# It: 270, Loss: 6.662e+03, Loss_bcs: 1.453e+01, Loss_res: 6.647e+03, Adaptive_Constant: 3.75 ,Time: 0.12
# It: 280, Loss: 6.982e+03, Loss_bcs: 1.687e+01, Loss_res: 6.966e+03, Adaptive_Constant: 4.49 ,Time: 0.13
# It: 290, Loss: 6.655e+03, Loss_bcs: 3.106e+01, Loss_res: 6.623e+03, Adaptive_Constant: 6.91 ,Time: 0.12
# It: 300, Loss: 6.403e+03, Loss_bcs: 3.788e+01, Loss_res: 6.365e+03, Adaptive_Constant: 5.48 ,Time: 0.12
# It: 310, Loss: 6.394e+03, Loss_bcs: 2.314e+01, Loss_res: 6.371e+03, Adaptive_Constant: 4.22 ,Time: 0.12
# It: 320, Loss: 7.600e+03, Loss_bcs: 1.678e+01, Loss_res: 7.584e+03, Adaptive_Constant: 3.98 ,Time: 0.12
# It: 330, Loss: 6.164e+03, Loss_bcs: 2.455e+01, Loss_res: 6.140e+03, Adaptive_Constant: 6.17 ,Time: 0.12
# It: 340, Loss: 6.620e+03, Loss_bcs: 3.286e+01, Loss_res: 6.587e+03, Adaptive_Constant: 5.32 ,Time: 0.12
# It: 350, Loss: 6.423e+03, Loss_bcs: 2.646e+01, Loss_res: 6.397e+03, Adaptive_Constant: 4.97 ,Time: 0.12
# It: 360, Loss: 6.254e+03, Loss_bcs: 2.627e+01, Loss_res: 6.227e+03, Adaptive_Constant: 5.28 ,Time: 0.12
# It: 370, Loss: 5.101e+03, Loss_bcs: 3.021e+01, Loss_res: 5.071e+03, Adaptive_Constant: 5.72 ,Time: 0.12
# It: 380, Loss: 5.531e+03, Loss_bcs: 3.137e+01, Loss_res: 5.500e+03, Adaptive_Constant: 5.49 ,Time: 0.12
# It: 390, Loss: 6.011e+03, Loss_bcs: 2.235e+01, Loss_res: 5.988e+03, Adaptive_Constant: 4.07 ,Time: 0.12
# It: 400, Loss: 4.812e+03, Loss_bcs: 1.515e+01, Loss_res: 4.796e+03, Adaptive_Constant: 3.72 ,Time: 0.12
# It: 410, Loss: 6.280e+03, Loss_bcs: 2.282e+01, Loss_res: 6.257e+03, Adaptive_Constant: 6.14 ,Time: 0.12
# It: 420, Loss: 5.486e+03, Loss_bcs: 2.130e+01, Loss_res: 5.464e+03, Adaptive_Constant: 3.47 ,Time: 0.11
# It: 430, Loss: 6.496e+03, Loss_bcs: 1.450e+01, Loss_res: 6.481e+03, Adaptive_Constant: 4.18 ,Time: 0.13
# It: 440, Loss: 6.179e+03, Loss_bcs: 2.285e+01, Loss_res: 6.157e+03, Adaptive_Constant: 5.47 ,Time: 0.12
# It: 450, Loss: 5.611e+03, Loss_bcs: 1.971e+01, Loss_res: 5.591e+03, Adaptive_Constant: 3.60 ,Time: 0.11
# It: 460, Loss: 5.418e+03, Loss_bcs: 1.500e+01, Loss_res: 5.403e+03, Adaptive_Constant: 4.16 ,Time: 0.12
# It: 470, Loss: 5.706e+03, Loss_bcs: 1.690e+01, Loss_res: 5.690e+03, Adaptive_Constant: 4.06 ,Time: 0.12
# It: 480, Loss: 4.906e+03, Loss_bcs: 1.808e+01, Loss_res: 4.888e+03, Adaptive_Constant: 4.45 ,Time: 0.12
# It: 490, Loss: 5.134e+03, Loss_bcs: 1.817e+01, Loss_res: 5.116e+03, Adaptive_Constant: 4.08 ,Time: 0.11
# It: 500, Loss: 4.519e+03, Loss_bcs: 1.512e+01, Loss_res: 4.504e+03, Adaptive_Constant: 3.71 ,Time: 0.12
# It: 510, Loss: 3.363e+03, Loss_bcs: 1.483e+01, Loss_res: 3.348e+03, Adaptive_Constant: 4.00 ,Time: 0.12
# It: 520, Loss: 3.032e+03, Loss_bcs: 1.726e+01, Loss_res: 3.015e+03, Adaptive_Constant: 4.31 ,Time: 0.12
# It: 530, Loss: 2.797e+03, Loss_bcs: 2.273e+01, Loss_res: 2.775e+03, Adaptive_Constant: 5.27 ,Time: 0.12
# It: 540, Loss: 2.731e+03, Loss_bcs: 2.697e+01, Loss_res: 2.704e+03, Adaptive_Constant: 5.12 ,Time: 0.12
# It: 550, Loss: 2.941e+03, Loss_bcs: 3.001e+01, Loss_res: 2.911e+03, Adaptive_Constant: 5.86 ,Time: 0.12
# It: 560, Loss: 2.336e+03, Loss_bcs: 4.243e+01, Loss_res: 2.294e+03, Adaptive_Constant: 7.23 ,Time: 0.11
# It: 570, Loss: 2.289e+03, Loss_bcs: 4.066e+01, Loss_res: 2.249e+03, Adaptive_Constant: 5.62 ,Time: 0.12
# It: 580, Loss: 1.919e+03, Loss_bcs: 3.719e+01, Loss_res: 1.881e+03, Adaptive_Constant: 6.62 ,Time: 0.13
# It: 590, Loss: 1.608e+03, Loss_bcs: 4.246e+01, Loss_res: 1.566e+03, Adaptive_Constant: 6.42 ,Time: 0.12
# It: 600, Loss: 1.891e+03, Loss_bcs: 4.552e+01, Loss_res: 1.845e+03, Adaptive_Constant: 7.09 ,Time: 0.12
# It: 610, Loss: 1.885e+03, Loss_bcs: 4.054e+01, Loss_res: 1.845e+03, Adaptive_Constant: 5.72 ,Time: 0.12
# It: 620, Loss: 1.337e+03, Loss_bcs: 3.443e+01, Loss_res: 1.303e+03, Adaptive_Constant: 6.02 ,Time: 0.12
# It: 630, Loss: 1.451e+03, Loss_bcs: 4.016e+01, Loss_res: 1.411e+03, Adaptive_Constant: 6.67 ,Time: 0.11
# It: 640, Loss: 1.472e+03, Loss_bcs: 4.358e+01, Loss_res: 1.428e+03, Adaptive_Constant: 6.54 ,Time: 0.13
# It: 650, Loss: 1.108e+03, Loss_bcs: 4.286e+01, Loss_res: 1.065e+03, Adaptive_Constant: 6.56 ,Time: 0.11
# It: 660, Loss: 1.168e+03, Loss_bcs: 3.951e+01, Loss_res: 1.128e+03, Adaptive_Constant: 6.03 ,Time: 0.12
# It: 670, Loss: 8.375e+02, Loss_bcs: 4.516e+01, Loss_res: 7.924e+02, Adaptive_Constant: 7.49 ,Time: 0.11
# It: 680, Loss: 8.281e+02, Loss_bcs: 4.507e+01, Loss_res: 7.831e+02, Adaptive_Constant: 6.01 ,Time: 0.12
# It: 690, Loss: 8.796e+02, Loss_bcs: 3.601e+01, Loss_res: 8.436e+02, Adaptive_Constant: 5.99 ,Time: 0.11
# It: 700, Loss: 5.241e+02, Loss_bcs: 4.044e+01, Loss_res: 4.837e+02, Adaptive_Constant: 6.75 ,Time: 0.12
# It: 710, Loss: 6.490e+02, Loss_bcs: 4.468e+01, Loss_res: 6.043e+02, Adaptive_Constant: 6.62 ,Time: 0.11
# It: 720, Loss: 6.529e+02, Loss_bcs: 4.553e+01, Loss_res: 6.074e+02, Adaptive_Constant: 6.88 ,Time: 0.14
# It: 730, Loss: 5.838e+02, Loss_bcs: 4.252e+01, Loss_res: 5.413e+02, Adaptive_Constant: 6.18 ,Time: 0.11
# It: 740, Loss: 5.563e+02, Loss_bcs: 3.619e+01, Loss_res: 5.201e+02, Adaptive_Constant: 5.86 ,Time: 0.12
# It: 750, Loss: 5.542e+02, Loss_bcs: 3.389e+01, Loss_res: 5.203e+02, Adaptive_Constant: 5.79 ,Time: 0.11
# It: 760, Loss: 4.801e+02, Loss_bcs: 3.407e+01, Loss_res: 4.460e+02, Adaptive_Constant: 5.89 ,Time: 0.11
# It: 770, Loss: 4.653e+02, Loss_bcs: 3.335e+01, Loss_res: 4.319e+02, Adaptive_Constant: 5.66 ,Time: 0.12
# It: 780, Loss: 4.524e+02, Loss_bcs: 3.354e+01, Loss_res: 4.188e+02, Adaptive_Constant: 5.92 ,Time: 0.12
# It: 790, Loss: 3.666e+02, Loss_bcs: 3.603e+01, Loss_res: 3.306e+02, Adaptive_Constant: 6.08 ,Time: 0.11
# It: 800, Loss: 3.660e+02, Loss_bcs: 3.420e+01, Loss_res: 3.318e+02, Adaptive_Constant: 5.62 ,Time: 0.12
# It: 810, Loss: 3.646e+02, Loss_bcs: 3.199e+01, Loss_res: 3.326e+02, Adaptive_Constant: 5.69 ,Time: 0.12
# It: 820, Loss: 2.891e+02, Loss_bcs: 3.566e+01, Loss_res: 2.534e+02, Adaptive_Constant: 6.27 ,Time: 0.12
# It: 830, Loss: 2.126e+02, Loss_bcs: 3.550e+01, Loss_res: 1.771e+02, Adaptive_Constant: 5.67 ,Time: 0.12
# It: 840, Loss: 2.986e+02, Loss_bcs: 3.391e+01, Loss_res: 2.647e+02, Adaptive_Constant: 5.98 ,Time: 0.12
# It: 850, Loss: 2.324e+02, Loss_bcs: 3.431e+01, Loss_res: 1.981e+02, Adaptive_Constant: 5.73 ,Time: 0.13
# It: 860, Loss: 2.768e+02, Loss_bcs: 3.400e+01, Loss_res: 2.428e+02, Adaptive_Constant: 5.93 ,Time: 0.12
# It: 870, Loss: 3.030e+02, Loss_bcs: 3.186e+01, Loss_res: 2.711e+02, Adaptive_Constant: 5.37 ,Time: 0.12
# It: 880, Loss: 3.219e+02, Loss_bcs: 3.252e+01, Loss_res: 2.893e+02, Adaptive_Constant: 6.05 ,Time: 0.12
# It: 890, Loss: 2.429e+02, Loss_bcs: 3.386e+01, Loss_res: 2.091e+02, Adaptive_Constant: 5.59 ,Time: 0.11
# It: 900, Loss: 3.083e+02, Loss_bcs: 3.369e+01, Loss_res: 2.746e+02, Adaptive_Constant: 6.02 ,Time: 0.12
# It: 910, Loss: 2.760e+02, Loss_bcs: 3.425e+01, Loss_res: 2.418e+02, Adaptive_Constant: 5.69 ,Time: 0.11
# It: 920, Loss: 2.470e+02, Loss_bcs: 3.121e+01, Loss_res: 2.157e+02, Adaptive_Constant: 5.49 ,Time: 0.11
# It: 930, Loss: 2.182e+02, Loss_bcs: 3.138e+01, Loss_res: 1.868e+02, Adaptive_Constant: 5.72 ,Time: 0.12
# It: 940, Loss: 1.642e+02, Loss_bcs: 3.271e+01, Loss_res: 1.315e+02, Adaptive_Constant: 5.72 ,Time: 0.11
# It: 950, Loss: 2.463e+02, Loss_bcs: 3.199e+01, Loss_res: 2.143e+02, Adaptive_Constant: 5.59 ,Time: 0.11
# It: 960, Loss: 2.197e+02, Loss_bcs: 3.141e+01, Loss_res: 1.883e+02, Adaptive_Constant: 5.62 ,Time: 0.12
# It: 970, Loss: 1.549e+02, Loss_bcs: 3.055e+01, Loss_res: 1.243e+02, Adaptive_Constant: 5.44 ,Time: 0.12
# It: 980, Loss: 1.483e+02, Loss_bcs: 3.237e+01, Loss_res: 1.159e+02, Adaptive_Constant: 5.95 ,Time: 0.11
# It: 990, Loss: 1.444e+02, Loss_bcs: 3.531e+01, Loss_res: 1.091e+02, Adaptive_Constant: 5.93 ,Time: 0.12
# It: 1000, Loss: 1.542e+02, Loss_bcs: 3.477e+01, Loss_res: 1.194e+02, Adaptive_Constant: 5.86 ,Time: 0.12
# It: 1010, Loss: 1.561e+02, Loss_bcs: 3.190e+01, Loss_res: 1.242e+02, Adaptive_Constant: 5.44 ,Time: 0.12
# It: 1020, Loss: 1.423e+02, Loss_bcs: 3.153e+01, Loss_res: 1.107e+02, Adaptive_Constant: 5.79 ,Time: 0.12
# It: 1030, Loss: 1.971e+02, Loss_bcs: 3.097e+01, Loss_res: 1.661e+02, Adaptive_Constant: 5.34 ,Time: 0.12
# It: 1040, Loss: 2.161e+02, Loss_bcs: 2.844e+01, Loss_res: 1.876e+02, Adaptive_Constant: 5.32 ,Time: 0.11
# It: 1050, Loss: 2.417e+02, Loss_bcs: 2.850e+01, Loss_res: 2.132e+02, Adaptive_Constant: 5.35 ,Time: 0.12
# It: 1060, Loss: 1.806e+02, Loss_bcs: 2.904e+01, Loss_res: 1.515e+02, Adaptive_Constant: 5.42 ,Time: 0.12
# It: 1070, Loss: 1.708e+02, Loss_bcs: 3.166e+01, Loss_res: 1.391e+02, Adaptive_Constant: 5.84 ,Time: 0.13
# It: 1080, Loss: 1.485e+02, Loss_bcs: 3.141e+01, Loss_res: 1.170e+02, Adaptive_Constant: 5.38 ,Time: 0.11
# It: 1090, Loss: 1.290e+02, Loss_bcs: 2.738e+01, Loss_res: 1.016e+02, Adaptive_Constant: 5.09 ,Time: 0.11
# It: 1100, Loss: 1.296e+02, Loss_bcs: 2.606e+01, Loss_res: 1.035e+02, Adaptive_Constant: 5.12 ,Time: 0.12
# It: 1110, Loss: 1.506e+02, Loss_bcs: 2.646e+01, Loss_res: 1.242e+02, Adaptive_Constant: 5.17 ,Time: 0.11
# It: 1120, Loss: 1.524e+02, Loss_bcs: 2.716e+01, Loss_res: 1.252e+02, Adaptive_Constant: 5.26 ,Time: 0.12
# It: 1130, Loss: 1.834e+02, Loss_bcs: 2.845e+01, Loss_res: 1.550e+02, Adaptive_Constant: 5.41 ,Time: 0.12
# It: 1140, Loss: 1.596e+02, Loss_bcs: 2.905e+01, Loss_res: 1.305e+02, Adaptive_Constant: 5.37 ,Time: 0.12
# It: 1150, Loss: 1.440e+02, Loss_bcs: 2.799e+01, Loss_res: 1.160e+02, Adaptive_Constant: 5.21 ,Time: 0.11
# It: 1160, Loss: 1.278e+02, Loss_bcs: 2.712e+01, Loss_res: 1.007e+02, Adaptive_Constant: 5.20 ,Time: 0.12
# It: 1170, Loss: 1.263e+02, Loss_bcs: 2.457e+01, Loss_res: 1.018e+02, Adaptive_Constant: 4.72 ,Time: 0.11
# It: 1180, Loss: 1.154e+02, Loss_bcs: 2.115e+01, Loss_res: 9.425e+01, Adaptive_Constant: 4.48 ,Time: 0.12
# It: 1190, Loss: 1.648e+02, Loss_bcs: 2.194e+01, Loss_res: 1.428e+02, Adaptive_Constant: 4.90 ,Time: 0.12
# It: 1200, Loss: 1.087e+02, Loss_bcs: 2.509e+01, Loss_res: 8.357e+01, Adaptive_Constant: 5.12 ,Time: 0.11
# It: 1210, Loss: 1.449e+02, Loss_bcs: 2.342e+01, Loss_res: 1.215e+02, Adaptive_Constant: 4.57 ,Time: 0.12
# It: 1220, Loss: 1.326e+02, Loss_bcs: 2.248e+01, Loss_res: 1.101e+02, Adaptive_Constant: 4.91 ,Time: 0.12
# It: 1230, Loss: 1.475e+02, Loss_bcs: 2.419e+01, Loss_res: 1.233e+02, Adaptive_Constant: 4.92 ,Time: 0.12
# It: 1240, Loss: 9.360e+01, Loss_bcs: 2.149e+01, Loss_res: 7.211e+01, Adaptive_Constant: 4.36 ,Time: 0.12
# It: 1250, Loss: 1.100e+02, Loss_bcs: 2.070e+01, Loss_res: 8.930e+01, Adaptive_Constant: 4.74 ,Time: 0.12
# It: 1260, Loss: 1.515e+02, Loss_bcs: 2.214e+01, Loss_res: 1.294e+02, Adaptive_Constant: 4.67 ,Time: 0.11
# It: 1270, Loss: 9.875e+01, Loss_bcs: 2.243e+01, Loss_res: 7.632e+01, Adaptive_Constant: 4.80 ,Time: 0.13
# It: 1280, Loss: 1.126e+02, Loss_bcs: 2.078e+01, Loss_res: 9.178e+01, Adaptive_Constant: 4.33 ,Time: 0.14
# It: 1290, Loss: 8.260e+01, Loss_bcs: 1.756e+01, Loss_res: 6.504e+01, Adaptive_Constant: 4.06 ,Time: 0.12
# It: 1300, Loss: 1.035e+02, Loss_bcs: 1.762e+01, Loss_res: 8.588e+01, Adaptive_Constant: 4.34 ,Time: 0.11
# It: 1310, Loss: 1.083e+02, Loss_bcs: 1.893e+01, Loss_res: 8.937e+01, Adaptive_Constant: 4.36 ,Time: 0.11
# It: 1320, Loss: 9.222e+01, Loss_bcs: 1.943e+01, Loss_res: 7.279e+01, Adaptive_Constant: 4.46 ,Time: 0.12
# It: 1330, Loss: 1.066e+02, Loss_bcs: 1.848e+01, Loss_res: 8.813e+01, Adaptive_Constant: 4.15 ,Time: 0.11
# It: 1340, Loss: 1.246e+02, Loss_bcs: 1.750e+01, Loss_res: 1.071e+02, Adaptive_Constant: 4.22 ,Time: 0.12
# It: 1350, Loss: 1.139e+02, Loss_bcs: 1.751e+01, Loss_res: 9.635e+01, Adaptive_Constant: 4.15 ,Time: 0.11
# It: 1360, Loss: 7.687e+01, Loss_bcs: 1.744e+01, Loss_res: 5.944e+01, Adaptive_Constant: 4.20 ,Time: 0.12
# It: 1370, Loss: 8.617e+01, Loss_bcs: 1.671e+01, Loss_res: 6.946e+01, Adaptive_Constant: 3.98 ,Time: 0.12
# It: 1380, Loss: 9.691e+01, Loss_bcs: 1.808e+01, Loss_res: 7.884e+01, Adaptive_Constant: 4.54 ,Time: 0.11
# It: 1390, Loss: 1.198e+02, Loss_bcs: 1.794e+01, Loss_res: 1.018e+02, Adaptive_Constant: 3.95 ,Time: 0.11
# It: 1400, Loss: 6.742e+01, Loss_bcs: 1.574e+01, Loss_res: 5.168e+01, Adaptive_Constant: 3.98 ,Time: 0.11
# It: 1410, Loss: 9.212e+01, Loss_bcs: 1.689e+01, Loss_res: 7.523e+01, Adaptive_Constant: 4.24 ,Time: 0.12
# It: 1420, Loss: 9.020e+01, Loss_bcs: 1.690e+01, Loss_res: 7.330e+01, Adaptive_Constant: 3.99 ,Time: 0.11
# It: 1430, Loss: 6.406e+01, Loss_bcs: 1.656e+01, Loss_res: 4.750e+01, Adaptive_Constant: 4.15 ,Time: 0.12
# It: 1440, Loss: 1.050e+02, Loss_bcs: 1.630e+01, Loss_res: 8.871e+01, Adaptive_Constant: 3.92 ,Time: 0.11
# It: 1450, Loss: 7.228e+01, Loss_bcs: 1.548e+01, Loss_res: 5.680e+01, Adaptive_Constant: 3.95 ,Time: 0.11
# It: 1460, Loss: 1.011e+02, Loss_bcs: 1.362e+01, Loss_res: 8.752e+01, Adaptive_Constant: 3.45 ,Time: 0.11
# It: 1470, Loss: 8.209e+01, Loss_bcs: 1.246e+01, Loss_res: 6.963e+01, Adaptive_Constant: 3.61 ,Time: 0.11
# It: 1480, Loss: 6.487e+01, Loss_bcs: 1.479e+01, Loss_res: 5.008e+01, Adaptive_Constant: 4.10 ,Time: 0.11
# It: 1490, Loss: 7.712e+01, Loss_bcs: 1.496e+01, Loss_res: 6.216e+01, Adaptive_Constant: 3.65 ,Time: 0.11
# It: 1500, Loss: 7.931e+01, Loss_bcs: 1.385e+01, Loss_res: 6.547e+01, Adaptive_Constant: 3.79 ,Time: 0.12
# It: 1510, Loss: 7.541e+01, Loss_bcs: 1.459e+01, Loss_res: 6.081e+01, Adaptive_Constant: 3.85 ,Time: 0.11
# It: 1520, Loss: 8.252e+01, Loss_bcs: 1.453e+01, Loss_res: 6.799e+01, Adaptive_Constant: 3.78 ,Time: 0.11
# It: 1530, Loss: 7.309e+01, Loss_bcs: 1.442e+01, Loss_res: 5.867e+01, Adaptive_Constant: 3.82 ,Time: 0.11
# It: 1540, Loss: 8.587e+01, Loss_bcs: 1.410e+01, Loss_res: 7.178e+01, Adaptive_Constant: 3.69 ,Time: 0.11
# It: 1550, Loss: 5.172e+01, Loss_bcs: 1.404e+01, Loss_res: 3.768e+01, Adaptive_Constant: 3.80 ,Time: 0.11
# It: 1560, Loss: 7.472e+01, Loss_bcs: 1.348e+01, Loss_res: 6.125e+01, Adaptive_Constant: 3.54 ,Time: 0.11
# It: 1570, Loss: 6.792e+01, Loss_bcs: 1.239e+01, Loss_res: 5.554e+01, Adaptive_Constant: 3.50 ,Time: 0.11
# It: 1580, Loss: 6.465e+01, Loss_bcs: 1.133e+01, Loss_res: 5.331e+01, Adaptive_Constant: 3.24 ,Time: 0.12
# It: 1590, Loss: 6.985e+01, Loss_bcs: 1.113e+01, Loss_res: 5.872e+01, Adaptive_Constant: 3.43 ,Time: 0.11
# It: 1600, Loss: 5.579e+01, Loss_bcs: 1.291e+01, Loss_res: 4.288e+01, Adaptive_Constant: 3.76 ,Time: 0.12
# It: 1610, Loss: 8.336e+01, Loss_bcs: 1.337e+01, Loss_res: 6.999e+01, Adaptive_Constant: 3.56 ,Time: 0.11
# It: 1620, Loss: 7.280e+01, Loss_bcs: 1.257e+01, Loss_res: 6.024e+01, Adaptive_Constant: 3.53 ,Time: 0.11
# It: 1630, Loss: 9.785e+01, Loss_bcs: 1.417e+01, Loss_res: 8.369e+01, Adaptive_Constant: 4.01 ,Time: 0.11
# It: 1640, Loss: 5.454e+01, Loss_bcs: 1.491e+01, Loss_res: 3.963e+01, Adaptive_Constant: 3.72 ,Time: 0.11
# It: 1650, Loss: 7.664e+01, Loss_bcs: 1.395e+01, Loss_res: 6.269e+01, Adaptive_Constant: 3.75 ,Time: 0.12
# It: 1660, Loss: 6.006e+01, Loss_bcs: 1.217e+01, Loss_res: 4.789e+01, Adaptive_Constant: 3.25 ,Time: 0.11
# It: 1670, Loss: 7.843e+01, Loss_bcs: 1.079e+01, Loss_res: 6.763e+01, Adaptive_Constant: 3.33 ,Time: 0.11
# It: 1680, Loss: 6.647e+01, Loss_bcs: 1.075e+01, Loss_res: 5.572e+01, Adaptive_Constant: 3.23 ,Time: 0.11
# It: 1690, Loss: 5.781e+01, Loss_bcs: 1.017e+01, Loss_res: 4.763e+01, Adaptive_Constant: 3.15 ,Time: 0.11
# It: 1700, Loss: 4.739e+01, Loss_bcs: 1.058e+01, Loss_res: 3.681e+01, Adaptive_Constant: 3.36 ,Time: 0.11
# It: 1710, Loss: 4.769e+01, Loss_bcs: 1.137e+01, Loss_res: 3.632e+01, Adaptive_Constant: 3.38 ,Time: 0.11
# It: 1720, Loss: 5.375e+01, Loss_bcs: 1.296e+01, Loss_res: 4.080e+01, Adaptive_Constant: 3.83 ,Time: 0.13
# It: 1730, Loss: 5.382e+01, Loss_bcs: 1.292e+01, Loss_res: 4.090e+01, Adaptive_Constant: 3.37 ,Time: 0.11
# It: 1740, Loss: 5.707e+01, Loss_bcs: 1.134e+01, Loss_res: 4.572e+01, Adaptive_Constant: 3.36 ,Time: 0.11
# It: 1750, Loss: 5.569e+01, Loss_bcs: 1.085e+01, Loss_res: 4.483e+01, Adaptive_Constant: 3.23 ,Time: 0.11
# It: 1760, Loss: 4.654e+01, Loss_bcs: 9.901e+00, Loss_res: 3.664e+01, Adaptive_Constant: 3.07 ,Time: 0.11
# It: 1770, Loss: 6.372e+01, Loss_bcs: 1.018e+01, Loss_res: 5.354e+01, Adaptive_Constant: 3.32 ,Time: 0.11
# It: 1780, Loss: 6.601e+01, Loss_bcs: 1.164e+01, Loss_res: 5.437e+01, Adaptive_Constant: 3.51 ,Time: 0.11
# It: 1790, Loss: 3.843e+01, Loss_bcs: 1.130e+01, Loss_res: 2.713e+01, Adaptive_Constant: 3.22 ,Time: 0.11
# It: 1800, Loss: 6.125e+01, Loss_bcs: 9.803e+00, Loss_res: 5.145e+01, Adaptive_Constant: 3.04 ,Time: 0.11
# It: 1810, Loss: 6.749e+01, Loss_bcs: 9.490e+00, Loss_res: 5.800e+01, Adaptive_Constant: 3.12 ,Time: 0.11
# It: 1820, Loss: 5.815e+01, Loss_bcs: 9.976e+00, Loss_res: 4.818e+01, Adaptive_Constant: 3.20 ,Time: 0.11
# It: 1830, Loss: 7.042e+01, Loss_bcs: 1.028e+01, Loss_res: 6.013e+01, Adaptive_Constant: 3.22 ,Time: 0.11
# It: 1840, Loss: 6.144e+01, Loss_bcs: 1.026e+01, Loss_res: 5.118e+01, Adaptive_Constant: 3.19 ,Time: 0.11
# It: 1850, Loss: 5.938e+01, Loss_bcs: 1.069e+01, Loss_res: 4.869e+01, Adaptive_Constant: 3.35 ,Time: 0.11
# It: 1860, Loss: 6.069e+01, Loss_bcs: 1.032e+01, Loss_res: 5.037e+01, Adaptive_Constant: 3.08 ,Time: 0.11
# It: 1870, Loss: 3.860e+01, Loss_bcs: 1.047e+01, Loss_res: 2.813e+01, Adaptive_Constant: 3.40 ,Time: 0.12
# It: 1880, Loss: 6.534e+01, Loss_bcs: 1.026e+01, Loss_res: 5.508e+01, Adaptive_Constant: 3.02 ,Time: 0.11
# It: 1890, Loss: 4.565e+01, Loss_bcs: 8.981e+00, Loss_res: 3.667e+01, Adaptive_Constant: 2.98 ,Time: 0.11
# It: 1900, Loss: 5.116e+01, Loss_bcs: 8.713e+00, Loss_res: 4.245e+01, Adaptive_Constant: 2.93 ,Time: 0.11
# It: 1910, Loss: 4.459e+01, Loss_bcs: 8.384e+00, Loss_res: 3.620e+01, Adaptive_Constant: 2.86 ,Time: 0.11
# It: 1920, Loss: 5.367e+01, Loss_bcs: 8.442e+00, Loss_res: 4.523e+01, Adaptive_Constant: 2.95 ,Time: 0.11
# It: 1930, Loss: 4.562e+01, Loss_bcs: 8.706e+00, Loss_res: 3.692e+01, Adaptive_Constant: 2.95 ,Time: 0.11
# It: 1940, Loss: 3.856e+01, Loss_bcs: 8.623e+00, Loss_res: 2.993e+01, Adaptive_Constant: 2.92 ,Time: 0.14
# It: 1950, Loss: 3.596e+01, Loss_bcs: 8.679e+00, Loss_res: 2.728e+01, Adaptive_Constant: 2.97 ,Time: 0.11
# It: 1960, Loss: 4.144e+01, Loss_bcs: 8.064e+00, Loss_res: 3.337e+01, Adaptive_Constant: 2.71 ,Time: 0.11
# It: 1970, Loss: 3.776e+01, Loss_bcs: 7.964e+00, Loss_res: 2.980e+01, Adaptive_Constant: 2.94 ,Time: 0.11
# It: 1980, Loss: 3.762e+01, Loss_bcs: 7.961e+00, Loss_res: 2.966e+01, Adaptive_Constant: 2.71 ,Time: 0.11
# It: 1990, Loss: 3.015e+01, Loss_bcs: 7.716e+00, Loss_res: 2.244e+01, Adaptive_Constant: 2.85 ,Time: 0.11
# It: 2000, Loss: 5.101e+01, Loss_bcs: 8.032e+00, Loss_res: 4.297e+01, Adaptive_Constant: 2.82 ,Time: 0.11
# It: 2010, Loss: 4.391e+01, Loss_bcs: 7.915e+00, Loss_res: 3.600e+01, Adaptive_Constant: 2.80 ,Time: 0.11
# It: 2020, Loss: 2.945e+01, Loss_bcs: 7.664e+00, Loss_res: 2.179e+01, Adaptive_Constant: 2.73 ,Time: 0.12
# It: 2030, Loss: 4.614e+01, Loss_bcs: 7.226e+00, Loss_res: 3.892e+01, Adaptive_Constant: 2.64 ,Time: 0.11
# It: 2040, Loss: 3.054e+01, Loss_bcs: 6.794e+00, Loss_res: 2.375e+01, Adaptive_Constant: 2.57 ,Time: 0.11
# It: 2050, Loss: 4.895e+01, Loss_bcs: 6.638e+00, Loss_res: 4.231e+01, Adaptive_Constant: 2.58 ,Time: 0.11
# It: 2060, Loss: 3.358e+01, Loss_bcs: 6.851e+00, Loss_res: 2.672e+01, Adaptive_Constant: 2.65 ,Time: 0.11
# It: 2070, Loss: 3.467e+01, Loss_bcs: 6.885e+00, Loss_res: 2.779e+01, Adaptive_Constant: 2.60 ,Time: 0.11
# It: 2080, Loss: 4.131e+01, Loss_bcs: 6.782e+00, Loss_res: 3.453e+01, Adaptive_Constant: 2.61 ,Time: 0.11
# It: 2090, Loss: 3.398e+01, Loss_bcs: 6.592e+00, Loss_res: 2.739e+01, Adaptive_Constant: 2.52 ,Time: 0.12
# It: 2100, Loss: 4.549e+01, Loss_bcs: 6.868e+00, Loss_res: 3.863e+01, Adaptive_Constant: 2.72 ,Time: 0.11
# It: 2110, Loss: 2.877e+01, Loss_bcs: 7.571e+00, Loss_res: 2.120e+01, Adaptive_Constant: 2.78 ,Time: 0.11
# It: 2120, Loss: 3.309e+01, Loss_bcs: 7.109e+00, Loss_res: 2.598e+01, Adaptive_Constant: 2.56 ,Time: 0.11
# It: 2130, Loss: 3.798e+01, Loss_bcs: 6.733e+00, Loss_res: 3.125e+01, Adaptive_Constant: 2.64 ,Time: 0.11
# It: 2140, Loss: 4.014e+01, Loss_bcs: 6.953e+00, Loss_res: 3.319e+01, Adaptive_Constant: 2.64 ,Time: 0.11
# It: 2150, Loss: 3.012e+01, Loss_bcs: 6.511e+00, Loss_res: 2.361e+01, Adaptive_Constant: 2.47 ,Time: 0.11
# It: 2160, Loss: 2.986e+01, Loss_bcs: 6.112e+00, Loss_res: 2.375e+01, Adaptive_Constant: 2.48 ,Time: 0.12
# It: 2170, Loss: 3.713e+01, Loss_bcs: 7.307e+00, Loss_res: 2.982e+01, Adaptive_Constant: 2.95 ,Time: 0.11
# It: 2180, Loss: 3.595e+01, Loss_bcs: 7.815e+00, Loss_res: 2.814e+01, Adaptive_Constant: 2.65 ,Time: 0.11
# It: 2190, Loss: 3.476e+01, Loss_bcs: 6.952e+00, Loss_res: 2.781e+01, Adaptive_Constant: 2.62 ,Time: 0.11
# It: 2200, Loss: 4.945e+01, Loss_bcs: 6.519e+00, Loss_res: 4.294e+01, Adaptive_Constant: 2.48 ,Time: 0.12
# It: 2210, Loss: 3.213e+01, Loss_bcs: 6.171e+00, Loss_res: 2.595e+01, Adaptive_Constant: 2.48 ,Time: 0.11
# It: 2220, Loss: 3.553e+01, Loss_bcs: 6.086e+00, Loss_res: 2.944e+01, Adaptive_Constant: 2.45 ,Time: 0.11
# It: 2230, Loss: 3.219e+01, Loss_bcs: 6.297e+00, Loss_res: 2.590e+01, Adaptive_Constant: 2.57 ,Time: 0.11
# It: 2240, Loss: 3.518e+01, Loss_bcs: 6.195e+00, Loss_res: 2.899e+01, Adaptive_Constant: 2.41 ,Time: 0.12
# It: 2250, Loss: 3.233e+01, Loss_bcs: 5.719e+00, Loss_res: 2.661e+01, Adaptive_Constant: 2.37 ,Time: 0.11
# It: 2260, Loss: 3.166e+01, Loss_bcs: 5.410e+00, Loss_res: 2.625e+01, Adaptive_Constant: 2.28 ,Time: 0.11
# It: 2270, Loss: 2.570e+01, Loss_bcs: 5.287e+00, Loss_res: 2.041e+01, Adaptive_Constant: 2.32 ,Time: 0.11
# It: 2280, Loss: 3.369e+01, Loss_bcs: 4.975e+00, Loss_res: 2.872e+01, Adaptive_Constant: 2.15 ,Time: 0.12
# It: 2290, Loss: 4.785e+01, Loss_bcs: 4.887e+00, Loss_res: 4.296e+01, Adaptive_Constant: 2.28 ,Time: 0.11
# It: 2300, Loss: 2.282e+01, Loss_bcs: 5.231e+00, Loss_res: 1.759e+01, Adaptive_Constant: 2.30 ,Time: 0.11
# It: 2310, Loss: 3.445e+01, Loss_bcs: 5.376e+00, Loss_res: 2.907e+01, Adaptive_Constant: 2.34 ,Time: 0.12
# It: 2320, Loss: 3.028e+01, Loss_bcs: 6.087e+00, Loss_res: 2.419e+01, Adaptive_Constant: 2.60 ,Time: 0.11
# It: 2330, Loss: 2.036e+01, Loss_bcs: 5.805e+00, Loss_res: 1.455e+01, Adaptive_Constant: 2.23 ,Time: 0.11
# It: 2340, Loss: 2.918e+01, Loss_bcs: 5.800e+00, Loss_res: 2.338e+01, Adaptive_Constant: 2.60 ,Time: 0.11
# It: 2350, Loss: 3.024e+01, Loss_bcs: 5.343e+00, Loss_res: 2.489e+01, Adaptive_Constant: 2.06 ,Time: 0.11
# It: 2360, Loss: 2.876e+01, Loss_bcs: 4.752e+00, Loss_res: 2.401e+01, Adaptive_Constant: 2.31 ,Time: 0.11
# It: 2370, Loss: 2.254e+01, Loss_bcs: 5.305e+00, Loss_res: 1.724e+01, Adaptive_Constant: 2.30 ,Time: 0.11
# It: 2380, Loss: 3.807e+01, Loss_bcs: 5.064e+00, Loss_res: 3.300e+01, Adaptive_Constant: 2.21 ,Time: 0.13
# It: 2390, Loss: 1.992e+01, Loss_bcs: 4.718e+00, Loss_res: 1.520e+01, Adaptive_Constant: 2.14 ,Time: 0.11
# It: 2400, Loss: 1.811e+01, Loss_bcs: 4.953e+00, Loss_res: 1.316e+01, Adaptive_Constant: 2.32 ,Time: 0.11
# It: 2410, Loss: 2.553e+01, Loss_bcs: 5.261e+00, Loss_res: 2.027e+01, Adaptive_Constant: 2.27 ,Time: 0.11
# It: 2420, Loss: 3.341e+01, Loss_bcs: 4.938e+00, Loss_res: 2.848e+01, Adaptive_Constant: 2.17 ,Time: 0.11
# It: 2430, Loss: 2.726e+01, Loss_bcs: 5.143e+00, Loss_res: 2.211e+01, Adaptive_Constant: 2.37 ,Time: 0.11
# It: 2440, Loss: 2.196e+01, Loss_bcs: 5.174e+00, Loss_res: 1.678e+01, Adaptive_Constant: 2.19 ,Time: 0.11
# It: 2450, Loss: 3.166e+01, Loss_bcs: 4.562e+00, Loss_res: 2.710e+01, Adaptive_Constant: 2.09 ,Time: 0.11
# It: 2460, Loss: 2.153e+01, Loss_bcs: 4.220e+00, Loss_res: 1.731e+01, Adaptive_Constant: 2.02 ,Time: 0.11
# It: 2470, Loss: 2.080e+01, Loss_bcs: 4.216e+00, Loss_res: 1.659e+01, Adaptive_Constant: 2.08 ,Time: 0.11
# It: 2480, Loss: 3.160e+01, Loss_bcs: 4.430e+00, Loss_res: 2.717e+01, Adaptive_Constant: 2.13 ,Time: 0.11
# It: 2490, Loss: 2.471e+01, Loss_bcs: 4.122e+00, Loss_res: 2.059e+01, Adaptive_Constant: 1.94 ,Time: 0.11
# It: 2500, Loss: 2.881e+01, Loss_bcs: 4.053e+00, Loss_res: 2.476e+01, Adaptive_Constant: 2.09 ,Time: 0.11
# It: 2510, Loss: 2.441e+01, Loss_bcs: 4.492e+00, Loss_res: 1.992e+01, Adaptive_Constant: 2.15 ,Time: 0.11
# It: 2520, Loss: 1.896e+01, Loss_bcs: 4.456e+00, Loss_res: 1.450e+01, Adaptive_Constant: 2.07 ,Time: 0.11
# It: 2530, Loss: 2.818e+01, Loss_bcs: 4.204e+00, Loss_res: 2.397e+01, Adaptive_Constant: 2.03 ,Time: 0.11
# It: 2540, Loss: 2.949e+01, Loss_bcs: 4.100e+00, Loss_res: 2.539e+01, Adaptive_Constant: 2.02 ,Time: 0.11
# It: 2550, Loss: 2.549e+01, Loss_bcs: 4.277e+00, Loss_res: 2.122e+01, Adaptive_Constant: 2.11 ,Time: 0.11
# It: 2560, Loss: 2.314e+01, Loss_bcs: 3.984e+00, Loss_res: 1.915e+01, Adaptive_Constant: 1.88 ,Time: 0.11
# It: 2570, Loss: 3.055e+01, Loss_bcs: 3.510e+00, Loss_res: 2.704e+01, Adaptive_Constant: 1.86 ,Time: 0.12
# It: 2580, Loss: 2.236e+01, Loss_bcs: 3.526e+00, Loss_res: 1.883e+01, Adaptive_Constant: 1.89 ,Time: 0.12
# It: 2590, Loss: 2.173e+01, Loss_bcs: 3.999e+00, Loss_res: 1.774e+01, Adaptive_Constant: 2.11 ,Time: 0.11
# It: 2600, Loss: 3.223e+01, Loss_bcs: 4.393e+00, Loss_res: 2.784e+01, Adaptive_Constant: 2.08 ,Time: 0.12
# It: 2610, Loss: 1.937e+01, Loss_bcs: 3.653e+00, Loss_res: 1.572e+01, Adaptive_Constant: 1.76 ,Time: 0.11
# It: 2620, Loss: 1.830e+01, Loss_bcs: 3.798e+00, Loss_res: 1.450e+01, Adaptive_Constant: 2.16 ,Time: 0.11
# It: 2630, Loss: 2.200e+01, Loss_bcs: 4.153e+00, Loss_res: 1.785e+01, Adaptive_Constant: 1.92 ,Time: 0.11
# It: 2640, Loss: 1.903e+01, Loss_bcs: 3.789e+00, Loss_res: 1.524e+01, Adaptive_Constant: 1.97 ,Time: 0.11
# It: 2650, Loss: 2.711e+01, Loss_bcs: 3.564e+00, Loss_res: 2.355e+01, Adaptive_Constant: 1.81 ,Time: 0.12
# It: 2660, Loss: 1.542e+01, Loss_bcs: 3.487e+00, Loss_res: 1.193e+01, Adaptive_Constant: 1.93 ,Time: 0.12
# It: 2670, Loss: 2.574e+01, Loss_bcs: 3.853e+00, Loss_res: 2.189e+01, Adaptive_Constant: 2.00 ,Time: 0.11
# It: 2680, Loss: 2.355e+01, Loss_bcs: 3.741e+00, Loss_res: 1.981e+01, Adaptive_Constant: 1.87 ,Time: 0.12
# It: 2690, Loss: 1.900e+01, Loss_bcs: 3.514e+00, Loss_res: 1.548e+01, Adaptive_Constant: 1.88 ,Time: 0.11
# It: 2700, Loss: 2.024e+01, Loss_bcs: 3.285e+00, Loss_res: 1.696e+01, Adaptive_Constant: 1.75 ,Time: 0.11
# It: 2710, Loss: 1.788e+01, Loss_bcs: 2.973e+00, Loss_res: 1.491e+01, Adaptive_Constant: 1.70 ,Time: 0.11
# It: 2720, Loss: 1.773e+01, Loss_bcs: 3.122e+00, Loss_res: 1.461e+01, Adaptive_Constant: 1.84 ,Time: 0.11
# It: 2730, Loss: 2.757e+01, Loss_bcs: 2.972e+00, Loss_res: 2.460e+01, Adaptive_Constant: 1.62 ,Time: 0.11
# It: 2740, Loss: 2.834e+01, Loss_bcs: 3.041e+00, Loss_res: 2.530e+01, Adaptive_Constant: 1.88 ,Time: 0.11
# It: 2750, Loss: 2.011e+01, Loss_bcs: 3.275e+00, Loss_res: 1.684e+01, Adaptive_Constant: 1.74 ,Time: 0.12
# It: 2760, Loss: 1.528e+01, Loss_bcs: 3.225e+00, Loss_res: 1.206e+01, Adaptive_Constant: 1.85 ,Time: 0.12
# It: 2770, Loss: 2.339e+01, Loss_bcs: 3.277e+00, Loss_res: 2.011e+01, Adaptive_Constant: 1.77 ,Time: 0.12
# It: 2780, Loss: 1.652e+01, Loss_bcs: 3.339e+00, Loss_res: 1.319e+01, Adaptive_Constant: 1.89 ,Time: 0.12
# It: 2790, Loss: 2.087e+01, Loss_bcs: 3.203e+00, Loss_res: 1.766e+01, Adaptive_Constant: 1.70 ,Time: 0.11
# It: 2800, Loss: 1.555e+01, Loss_bcs: 3.037e+00, Loss_res: 1.252e+01, Adaptive_Constant: 1.79 ,Time: 0.12
# It: 2810, Loss: 2.108e+01, Loss_bcs: 3.150e+00, Loss_res: 1.793e+01, Adaptive_Constant: 1.76 ,Time: 0.12
# It: 2820, Loss: 1.604e+01, Loss_bcs: 2.806e+00, Loss_res: 1.324e+01, Adaptive_Constant: 1.59 ,Time: 0.12
# It: 2830, Loss: 1.640e+01, Loss_bcs: 3.016e+00, Loss_res: 1.339e+01, Adaptive_Constant: 1.89 ,Time: 0.11
# It: 2840, Loss: 1.289e+01, Loss_bcs: 3.387e+00, Loss_res: 9.506e+00, Adaptive_Constant: 1.79 ,Time: 0.11
# It: 2850, Loss: 1.955e+01, Loss_bcs: 3.316e+00, Loss_res: 1.623e+01, Adaptive_Constant: 1.85 ,Time: 0.11
# It: 2860, Loss: 1.809e+01, Loss_bcs: 3.241e+00, Loss_res: 1.485e+01, Adaptive_Constant: 1.75 ,Time: 0.13
# It: 2870, Loss: 1.674e+01, Loss_bcs: 3.123e+00, Loss_res: 1.362e+01, Adaptive_Constant: 1.78 ,Time: 0.12
# It: 2880, Loss: 1.904e+01, Loss_bcs: 3.104e+00, Loss_res: 1.593e+01, Adaptive_Constant: 1.74 ,Time: 0.12
# It: 2890, Loss: 1.650e+01, Loss_bcs: 2.690e+00, Loss_res: 1.381e+01, Adaptive_Constant: 1.55 ,Time: 0.12
# It: 2900, Loss: 1.772e+01, Loss_bcs: 2.288e+00, Loss_res: 1.543e+01, Adaptive_Constant: 1.48 ,Time: 0.12
# It: 2910, Loss: 2.113e+01, Loss_bcs: 2.514e+00, Loss_res: 1.862e+01, Adaptive_Constant: 1.70 ,Time: 0.12
# It: 2920, Loss: 1.709e+01, Loss_bcs: 2.721e+00, Loss_res: 1.437e+01, Adaptive_Constant: 1.60 ,Time: 0.12
# It: 2930, Loss: 1.530e+01, Loss_bcs: 2.521e+00, Loss_res: 1.277e+01, Adaptive_Constant: 1.57 ,Time: 0.12
# It: 2940, Loss: 2.203e+01, Loss_bcs: 2.428e+00, Loss_res: 1.960e+01, Adaptive_Constant: 1.54 ,Time: 0.12
# It: 2950, Loss: 2.272e+01, Loss_bcs: 2.448e+00, Loss_res: 2.027e+01, Adaptive_Constant: 1.59 ,Time: 0.11
# It: 2960, Loss: 2.141e+01, Loss_bcs: 2.284e+00, Loss_res: 1.912e+01, Adaptive_Constant: 1.44 ,Time: 0.12
# It: 2970, Loss: 1.420e+01, Loss_bcs: 2.380e+00, Loss_res: 1.182e+01, Adaptive_Constant: 1.65 ,Time: 0.13
# It: 2980, Loss: 1.897e+01, Loss_bcs: 2.888e+00, Loss_res: 1.608e+01, Adaptive_Constant: 1.75 ,Time: 0.12
# It: 2990, Loss: 1.524e+01, Loss_bcs: 2.707e+00, Loss_res: 1.253e+01, Adaptive_Constant: 1.55 ,Time: 0.12
# It: 3000, Loss: 1.735e+01, Loss_bcs: 2.302e+00, Loss_res: 1.504e+01, Adaptive_Constant: 1.49 ,Time: 0.13
# It: 3010, Loss: 1.770e+01, Loss_bcs: 2.366e+00, Loss_res: 1.534e+01, Adaptive_Constant: 1.59 ,Time: 0.13
# It: 3020, Loss: 1.876e+01, Loss_bcs: 2.522e+00, Loss_res: 1.624e+01, Adaptive_Constant: 1.58 ,Time: 0.13
# It: 3030, Loss: 1.822e+01, Loss_bcs: 2.452e+00, Loss_res: 1.577e+01, Adaptive_Constant: 1.55 ,Time: 0.15
# It: 3040, Loss: 2.400e+01, Loss_bcs: 2.385e+00, Loss_res: 2.162e+01, Adaptive_Constant: 1.54 ,Time: 0.12
# It: 3050, Loss: 1.623e+01, Loss_bcs: 2.096e+00, Loss_res: 1.414e+01, Adaptive_Constant: 1.36 ,Time: 0.12
# It: 3060, Loss: 1.494e+01, Loss_bcs: 2.126e+00, Loss_res: 1.281e+01, Adaptive_Constant: 1.56 ,Time: 0.11
# It: 3070, Loss: 1.938e+01, Loss_bcs: 2.242e+00, Loss_res: 1.714e+01, Adaptive_Constant: 1.44 ,Time: 0.11
# It: 3080, Loss: 1.433e+01, Loss_bcs: 2.139e+00, Loss_res: 1.219e+01, Adaptive_Constant: 1.49 ,Time: 0.12
# It: 3090, Loss: 2.453e+01, Loss_bcs: 2.069e+00, Loss_res: 2.246e+01, Adaptive_Constant: 1.39 ,Time: 0.12
# It: 3100, Loss: 1.708e+01, Loss_bcs: 2.169e+00, Loss_res: 1.492e+01, Adaptive_Constant: 1.56 ,Time: 0.11
# It: 3110, Loss: 1.287e+01, Loss_bcs: 2.351e+00, Loss_res: 1.052e+01, Adaptive_Constant: 1.51 ,Time: 0.11
# It: 3120, Loss: 1.249e+01, Loss_bcs: 2.253e+00, Loss_res: 1.023e+01, Adaptive_Constant: 1.50 ,Time: 0.11
# It: 3130, Loss: 1.388e+01, Loss_bcs: 2.183e+00, Loss_res: 1.170e+01, Adaptive_Constant: 1.46 ,Time: 0.11
# It: 3140, Loss: 1.595e+01, Loss_bcs: 2.133e+00, Loss_res: 1.382e+01, Adaptive_Constant: 1.46 ,Time: 0.11
# It: 3150, Loss: 1.821e+01, Loss_bcs: 2.118e+00, Loss_res: 1.609e+01, Adaptive_Constant: 1.45 ,Time: 0.11
# It: 3160, Loss: 2.059e+01, Loss_bcs: 2.155e+00, Loss_res: 1.843e+01, Adaptive_Constant: 1.49 ,Time: 0.12
# It: 3170, Loss: 1.056e+01, Loss_bcs: 2.197e+00, Loss_res: 8.366e+00, Adaptive_Constant: 1.48 ,Time: 0.12
# It: 3180, Loss: 1.118e+01, Loss_bcs: 2.240e+00, Loss_res: 8.937e+00, Adaptive_Constant: 1.52 ,Time: 0.13
# It: 3190, Loss: 1.477e+01, Loss_bcs: 2.262e+00, Loss_res: 1.251e+01, Adaptive_Constant: 1.49 ,Time: 0.11
# It: 3200, Loss: 1.629e+01, Loss_bcs: 2.256e+00, Loss_res: 1.403e+01, Adaptive_Constant: 1.51 ,Time: 0.15
# It: 3210, Loss: 1.428e+01, Loss_bcs: 1.877e+00, Loss_res: 1.240e+01, Adaptive_Constant: 1.24 ,Time: 0.12
# It: 3220, Loss: 1.798e+01, Loss_bcs: 1.825e+00, Loss_res: 1.615e+01, Adaptive_Constant: 1.47 ,Time: 0.12
# It: 3230, Loss: 2.731e+01, Loss_bcs: 2.114e+00, Loss_res: 2.519e+01, Adaptive_Constant: 1.44 ,Time: 0.12
# It: 3240, Loss: 1.619e+01, Loss_bcs: 2.105e+00, Loss_res: 1.409e+01, Adaptive_Constant: 1.47 ,Time: 0.13
# It: 3250, Loss: 2.287e+01, Loss_bcs: 2.008e+00, Loss_res: 2.086e+01, Adaptive_Constant: 1.37 ,Time: 0.11
# It: 3260, Loss: 1.510e+01, Loss_bcs: 1.755e+00, Loss_res: 1.335e+01, Adaptive_Constant: 1.28 ,Time: 0.12
# It: 3270, Loss: 1.402e+01, Loss_bcs: 1.558e+00, Loss_res: 1.246e+01, Adaptive_Constant: 1.22 ,Time: 0.11
# It: 3280, Loss: 1.359e+01, Loss_bcs: 1.879e+00, Loss_res: 1.171e+01, Adaptive_Constant: 1.54 ,Time: 0.11
# It: 3290, Loss: 1.145e+01, Loss_bcs: 1.836e+00, Loss_res: 9.614e+00, Adaptive_Constant: 1.19 ,Time: 0.11
# It: 3300, Loss: 1.403e+01, Loss_bcs: 1.665e+00, Loss_res: 1.237e+01, Adaptive_Constant: 1.40 ,Time: 0.11
# It: 3310, Loss: 1.399e+01, Loss_bcs: 1.852e+00, Loss_res: 1.214e+01, Adaptive_Constant: 1.32 ,Time: 0.12
# It: 3320, Loss: 1.160e+01, Loss_bcs: 1.913e+00, Loss_res: 9.685e+00, Adaptive_Constant: 1.45 ,Time: 0.11
# It: 3330, Loss: 1.380e+01, Loss_bcs: 1.814e+00, Loss_res: 1.198e+01, Adaptive_Constant: 1.25 ,Time: 0.12
# It: 3340, Loss: 1.323e+01, Loss_bcs: 1.587e+00, Loss_res: 1.165e+01, Adaptive_Constant: 1.26 ,Time: 0.12
# It: 3350, Loss: 1.195e+01, Loss_bcs: 1.588e+00, Loss_res: 1.036e+01, Adaptive_Constant: 1.26 ,Time: 0.12
# It: 3360, Loss: 1.047e+01, Loss_bcs: 1.777e+00, Loss_res: 8.697e+00, Adaptive_Constant: 1.42 ,Time: 0.13
# It: 3370, Loss: 1.944e+01, Loss_bcs: 1.990e+00, Loss_res: 1.745e+01, Adaptive_Constant: 1.41 ,Time: 0.11
# It: 3380, Loss: 1.135e+01, Loss_bcs: 1.779e+00, Loss_res: 9.574e+00, Adaptive_Constant: 1.27 ,Time: 0.11
# It: 3390, Loss: 1.066e+01, Loss_bcs: 1.723e+00, Loss_res: 8.933e+00, Adaptive_Constant: 1.36 ,Time: 0.12
# It: 3400, Loss: 1.415e+01, Loss_bcs: 1.792e+00, Loss_res: 1.236e+01, Adaptive_Constant: 1.32 ,Time: 0.11
# It: 3410, Loss: 1.609e+01, Loss_bcs: 1.838e+00, Loss_res: 1.425e+01, Adaptive_Constant: 1.40 ,Time: 0.11
# It: 3420, Loss: 1.388e+01, Loss_bcs: 1.796e+00, Loss_res: 1.208e+01, Adaptive_Constant: 1.29 ,Time: 0.11
# It: 3430, Loss: 1.531e+01, Loss_bcs: 1.670e+00, Loss_res: 1.364e+01, Adaptive_Constant: 1.30 ,Time: 0.11
# It: 3440, Loss: 1.171e+01, Loss_bcs: 1.620e+00, Loss_res: 1.009e+01, Adaptive_Constant: 1.25 ,Time: 0.11
# It: 3450, Loss: 1.137e+01, Loss_bcs: 1.546e+00, Loss_res: 9.826e+00, Adaptive_Constant: 1.24 ,Time: 0.11
# It: 3460, Loss: 1.703e+01, Loss_bcs: 1.610e+00, Loss_res: 1.542e+01, Adaptive_Constant: 1.30 ,Time: 0.12
# It: 3470, Loss: 1.123e+01, Loss_bcs: 1.785e+00, Loss_res: 9.443e+00, Adaptive_Constant: 1.37 ,Time: 0.12
# It: 3480, Loss: 1.225e+01, Loss_bcs: 1.844e+00, Loss_res: 1.040e+01, Adaptive_Constant: 1.34 ,Time: 0.12
# It: 3490, Loss: 1.217e+01, Loss_bcs: 1.769e+00, Loss_res: 1.040e+01, Adaptive_Constant: 1.32 ,Time: 0.12
# It: 3500, Loss: 1.256e+01, Loss_bcs: 1.482e+00, Loss_res: 1.108e+01, Adaptive_Constant: 1.12 ,Time: 0.12
# It: 3510, Loss: 1.456e+01, Loss_bcs: 1.325e+00, Loss_res: 1.324e+01, Adaptive_Constant: 1.18 ,Time: 0.12
# It: 3520, Loss: 1.018e+01, Loss_bcs: 1.564e+00, Loss_res: 8.617e+00, Adaptive_Constant: 1.33 ,Time: 0.12
# It: 3530, Loss: 1.460e+01, Loss_bcs: 1.748e+00, Loss_res: 1.285e+01, Adaptive_Constant: 1.32 ,Time: 0.12
# It: 3540, Loss: 1.149e+01, Loss_bcs: 1.591e+00, Loss_res: 9.902e+00, Adaptive_Constant: 1.21 ,Time: 0.13
# It: 3550, Loss: 1.448e+01, Loss_bcs: 1.456e+00, Loss_res: 1.303e+01, Adaptive_Constant: 1.21 ,Time: 0.11
# It: 3560, Loss: 1.663e+01, Loss_bcs: 1.495e+00, Loss_res: 1.514e+01, Adaptive_Constant: 1.24 ,Time: 0.11
# It: 3570, Loss: 1.202e+01, Loss_bcs: 1.390e+00, Loss_res: 1.063e+01, Adaptive_Constant: 1.12 ,Time: 0.12
# It: 3580, Loss: 1.138e+01, Loss_bcs: 1.351e+00, Loss_res: 1.002e+01, Adaptive_Constant: 1.20 ,Time: 0.12
# It: 3590, Loss: 9.193e+00, Loss_bcs: 1.480e+00, Loss_res: 7.714e+00, Adaptive_Constant: 1.23 ,Time: 0.13
# It: 3600, Loss: 9.793e+00, Loss_bcs: 1.576e+00, Loss_res: 8.217e+00, Adaptive_Constant: 1.28 ,Time: 0.12
# It: 3610, Loss: 1.377e+01, Loss_bcs: 1.480e+00, Loss_res: 1.229e+01, Adaptive_Constant: 1.15 ,Time: 0.12
# It: 3620, Loss: 1.295e+01, Loss_bcs: 1.325e+00, Loss_res: 1.163e+01, Adaptive_Constant: 1.15 ,Time: 0.12
# It: 3630, Loss: 1.292e+01, Loss_bcs: 1.291e+00, Loss_res: 1.163e+01, Adaptive_Constant: 1.12 ,Time: 0.12
# It: 3640, Loss: 1.031e+01, Loss_bcs: 1.312e+00, Loss_res: 9.003e+00, Adaptive_Constant: 1.17 ,Time: 0.12
# It: 3650, Loss: 1.231e+01, Loss_bcs: 1.354e+00, Loss_res: 1.096e+01, Adaptive_Constant: 1.16 ,Time: 0.12
# It: 3660, Loss: 8.228e+00, Loss_bcs: 1.430e+00, Loss_res: 6.799e+00, Adaptive_Constant: 1.23 ,Time: 0.12
# It: 3670, Loss: 1.150e+01, Loss_bcs: 1.417e+00, Loss_res: 1.008e+01, Adaptive_Constant: 1.15 ,Time: 0.11
# It: 3680, Loss: 1.452e+01, Loss_bcs: 1.364e+00, Loss_res: 1.316e+01, Adaptive_Constant: 1.19 ,Time: 0.12
# It: 3690, Loss: 1.215e+01, Loss_bcs: 1.374e+00, Loss_res: 1.077e+01, Adaptive_Constant: 1.16 ,Time: 0.12
# It: 3700, Loss: 1.357e+01, Loss_bcs: 1.392e+00, Loss_res: 1.218e+01, Adaptive_Constant: 1.20 ,Time: 0.12
# It: 3710, Loss: 7.751e+00, Loss_bcs: 1.442e+00, Loss_res: 6.310e+00, Adaptive_Constant: 1.20 ,Time: 0.13
# It: 3720, Loss: 1.041e+01, Loss_bcs: 1.374e+00, Loss_res: 9.040e+00, Adaptive_Constant: 1.14 ,Time: 0.13
# It: 3730, Loss: 1.041e+01, Loss_bcs: 1.293e+00, Loss_res: 9.119e+00, Adaptive_Constant: 1.13 ,Time: 0.12
# It: 3740, Loss: 8.781e+00, Loss_bcs: 1.257e+00, Loss_res: 7.524e+00, Adaptive_Constant: 1.11 ,Time: 0.12
# It: 3750, Loss: 1.389e+01, Loss_bcs: 1.244e+00, Loss_res: 1.265e+01, Adaptive_Constant: 1.12 ,Time: 0.12
# It: 3760, Loss: 1.146e+01, Loss_bcs: 1.265e+00, Loss_res: 1.019e+01, Adaptive_Constant: 1.13 ,Time: 0.12
# It: 3770, Loss: 9.352e+00, Loss_bcs: 1.223e+00, Loss_res: 8.129e+00, Adaptive_Constant: 1.08 ,Time: 0.12
# It: 3780, Loss: 1.447e+01, Loss_bcs: 1.169e+00, Loss_res: 1.330e+01, Adaptive_Constant: 1.08 ,Time: 0.12
# It: 3790, Loss: 1.085e+01, Loss_bcs: 1.273e+00, Loss_res: 9.575e+00, Adaptive_Constant: 1.18 ,Time: 0.13
# It: 3800, Loss: 1.373e+01, Loss_bcs: 1.388e+00, Loss_res: 1.234e+01, Adaptive_Constant: 1.18 ,Time: 0.14
# It: 3810, Loss: 1.526e+01, Loss_bcs: 1.379e+00, Loss_res: 1.388e+01, Adaptive_Constant: 1.17 ,Time: 0.12
# It: 3820, Loss: 1.011e+01, Loss_bcs: 1.331e+00, Loss_res: 8.779e+00, Adaptive_Constant: 1.14 ,Time: 0.12
# It: 3830, Loss: 8.888e+00, Loss_bcs: 1.237e+00, Loss_res: 7.651e+00, Adaptive_Constant: 1.09 ,Time: 0.12
# It: 3840, Loss: 7.731e+00, Loss_bcs: 1.197e+00, Loss_res: 6.534e+00, Adaptive_Constant: 1.10 ,Time: 0.12
# It: 3850, Loss: 8.371e+00, Loss_bcs: 1.242e+00, Loss_res: 7.129e+00, Adaptive_Constant: 1.13 ,Time: 0.11
# It: 3860, Loss: 9.633e+00, Loss_bcs: 1.270e+00, Loss_res: 8.362e+00, Adaptive_Constant: 1.13 ,Time: 0.12
# It: 3870, Loss: 6.843e+00, Loss_bcs: 1.159e+00, Loss_res: 5.684e+00, Adaptive_Constant: 1.03 ,Time: 0.12
# It: 3880, Loss: 1.134e+01, Loss_bcs: 9.637e-01, Loss_res: 1.038e+01, Adaptive_Constant: 0.94 ,Time: 0.11
# It: 3890, Loss: 1.074e+01, Loss_bcs: 1.007e+00, Loss_res: 9.730e+00, Adaptive_Constant: 1.08 ,Time: 0.12
# It: 3900, Loss: 8.089e+00, Loss_bcs: 1.107e+00, Loss_res: 6.981e+00, Adaptive_Constant: 1.03 ,Time: 0.12
# It: 3910, Loss: 1.092e+01, Loss_bcs: 1.114e+00, Loss_res: 9.803e+00, Adaptive_Constant: 1.08 ,Time: 0.12
# It: 3920, Loss: 1.243e+01, Loss_bcs: 1.235e+00, Loss_res: 1.119e+01, Adaptive_Constant: 1.14 ,Time: 0.12
# It: 3930, Loss: 8.288e+00, Loss_bcs: 1.148e+00, Loss_res: 7.140e+00, Adaptive_Constant: 1.00 ,Time: 0.12
# It: 3940, Loss: 9.511e+00, Loss_bcs: 1.137e+00, Loss_res: 8.374e+00, Adaptive_Constant: 1.13 ,Time: 0.12
# It: 3950, Loss: 8.474e+00, Loss_bcs: 1.161e+00, Loss_res: 7.314e+00, Adaptive_Constant: 1.03 ,Time: 0.12
# It: 3960, Loss: 9.356e+00, Loss_bcs: 1.111e+00, Loss_res: 8.245e+00, Adaptive_Constant: 1.08 ,Time: 0.12
# It: 3970, Loss: 6.550e+00, Loss_bcs: 1.171e+00, Loss_res: 5.379e+00, Adaptive_Constant: 1.08 ,Time: 0.12
# It: 3980, Loss: 1.108e+01, Loss_bcs: 1.189e+00, Loss_res: 9.889e+00, Adaptive_Constant: 1.10 ,Time: 0.11
# It: 3990, Loss: 9.880e+00, Loss_bcs: 1.110e+00, Loss_res: 8.770e+00, Adaptive_Constant: 1.01 ,Time: 0.12
# It: 4000, Loss: 1.162e+01, Loss_bcs: 1.110e+00, Loss_res: 1.051e+01, Adaptive_Constant: 1.10 ,Time: 0.11
# It: 4010, Loss: 1.168e+01, Loss_bcs: 1.071e+00, Loss_res: 1.061e+01, Adaptive_Constant: 0.97 ,Time: 0.11
# It: 4020, Loss: 9.641e+00, Loss_bcs: 1.000e+00, Loss_res: 8.641e+00, Adaptive_Constant: 1.03 ,Time: 0.11
# It: 4030, Loss: 8.627e+00, Loss_bcs: 1.032e+00, Loss_res: 7.595e+00, Adaptive_Constant: 1.00 ,Time: 0.11
# It: 4040, Loss: 1.017e+01, Loss_bcs: 9.994e-01, Loss_res: 9.173e+00, Adaptive_Constant: 1.00 ,Time: 0.11
# It: 4050, Loss: 1.400e+01, Loss_bcs: 9.504e-01, Loss_res: 1.305e+01, Adaptive_Constant: 0.95 ,Time: 0.11
# It: 4060, Loss: 1.056e+01, Loss_bcs: 9.639e-01, Loss_res: 9.592e+00, Adaptive_Constant: 1.01 ,Time: 0.11
# It: 4070, Loss: 8.273e+00, Loss_bcs: 9.572e-01, Loss_res: 7.316e+00, Adaptive_Constant: 0.95 ,Time: 0.11
# It: 4080, Loss: 1.530e+01, Loss_bcs: 9.181e-01, Loss_res: 1.438e+01, Adaptive_Constant: 0.97 ,Time: 0.13
# It: 4090, Loss: 7.661e+00, Loss_bcs: 9.827e-01, Loss_res: 6.678e+00, Adaptive_Constant: 1.01 ,Time: 0.12
# It: 4100, Loss: 7.677e+00, Loss_bcs: 1.098e+00, Loss_res: 6.579e+00, Adaptive_Constant: 1.08 ,Time: 0.11
# It: 4110, Loss: 7.293e+00, Loss_bcs: 1.102e+00, Loss_res: 6.191e+00, Adaptive_Constant: 1.02 ,Time: 0.11
# It: 4120, Loss: 1.258e+01, Loss_bcs: 1.067e+00, Loss_res: 1.151e+01, Adaptive_Constant: 1.05 ,Time: 0.12
# It: 4130, Loss: 7.123e+00, Loss_bcs: 1.106e+00, Loss_res: 6.017e+00, Adaptive_Constant: 1.06 ,Time: 0.12
# It: 4140, Loss: 6.674e+00, Loss_bcs: 1.071e+00, Loss_res: 5.603e+00, Adaptive_Constant: 1.01 ,Time: 0.12
# It: 4150, Loss: 8.928e+00, Loss_bcs: 1.057e+00, Loss_res: 7.870e+00, Adaptive_Constant: 1.04 ,Time: 0.12
# It: 4160, Loss: 9.462e+00, Loss_bcs: 1.070e+00, Loss_res: 8.392e+00, Adaptive_Constant: 1.03 ,Time: 0.12
# It: 4170, Loss: 1.051e+01, Loss_bcs: 1.089e+00, Loss_res: 9.419e+00, Adaptive_Constant: 1.06 ,Time: 0.12
# It: 4180, Loss: 6.488e+00, Loss_bcs: 1.016e+00, Loss_res: 5.472e+00, Adaptive_Constant: 0.96 ,Time: 0.13
# It: 4190, Loss: 1.068e+01, Loss_bcs: 9.344e-01, Loss_res: 9.746e+00, Adaptive_Constant: 0.98 ,Time: 0.12
# It: 4200, Loss: 8.160e+00, Loss_bcs: 1.057e+00, Loss_res: 7.102e+00, Adaptive_Constant: 1.08 ,Time: 0.12
# It: 4210, Loss: 9.251e+00, Loss_bcs: 1.090e+00, Loss_res: 8.161e+00, Adaptive_Constant: 1.01 ,Time: 0.11
# It: 4220, Loss: 8.565e+00, Loss_bcs: 9.747e-01, Loss_res: 7.591e+00, Adaptive_Constant: 0.97 ,Time: 0.12
# It: 4230, Loss: 8.300e+00, Loss_bcs: 8.737e-01, Loss_res: 7.426e+00, Adaptive_Constant: 0.90 ,Time: 0.11
# It: 4240, Loss: 1.185e+01, Loss_bcs: 9.279e-01, Loss_res: 1.092e+01, Adaptive_Constant: 1.03 ,Time: 0.12
# It: 4250, Loss: 1.136e+01, Loss_bcs: 1.011e+00, Loss_res: 1.035e+01, Adaptive_Constant: 0.98 ,Time: 0.11
# It: 4260, Loss: 8.399e+00, Loss_bcs: 8.506e-01, Loss_res: 7.549e+00, Adaptive_Constant: 0.87 ,Time: 0.12
# It: 4270, Loss: 8.752e+00, Loss_bcs: 8.046e-01, Loss_res: 7.948e+00, Adaptive_Constant: 0.93 ,Time: 0.11
# It: 4280, Loss: 6.676e+00, Loss_bcs: 9.085e-01, Loss_res: 5.768e+00, Adaptive_Constant: 0.98 ,Time: 0.12
# It: 4290, Loss: 9.651e+00, Loss_bcs: 9.103e-01, Loss_res: 8.740e+00, Adaptive_Constant: 0.93 ,Time: 0.11
# It: 4300, Loss: 1.092e+01, Loss_bcs: 8.516e-01, Loss_res: 1.007e+01, Adaptive_Constant: 0.92 ,Time: 0.13
# It: 4310, Loss: 1.430e+01, Loss_bcs: 8.587e-01, Loss_res: 1.344e+01, Adaptive_Constant: 0.94 ,Time: 0.11
# It: 4320, Loss: 1.148e+01, Loss_bcs: 8.536e-01, Loss_res: 1.063e+01, Adaptive_Constant: 0.91 ,Time: 0.12
# It: 4330, Loss: 5.810e+00, Loss_bcs: 8.086e-01, Loss_res: 5.002e+00, Adaptive_Constant: 0.89 ,Time: 0.12
# It: 4340, Loss: 7.835e+00, Loss_bcs: 7.937e-01, Loss_res: 7.042e+00, Adaptive_Constant: 0.89 ,Time: 0.12
# It: 4350, Loss: 8.895e+00, Loss_bcs: 8.894e-01, Loss_res: 8.006e+00, Adaptive_Constant: 1.00 ,Time: 0.12
# It: 4360, Loss: 9.523e+00, Loss_bcs: 8.934e-01, Loss_res: 8.629e+00, Adaptive_Constant: 0.90 ,Time: 0.12
# It: 4370, Loss: 8.650e+00, Loss_bcs: 9.003e-01, Loss_res: 7.750e+00, Adaptive_Constant: 1.00 ,Time: 0.13
# It: 4380, Loss: 9.496e+00, Loss_bcs: 9.217e-01, Loss_res: 8.574e+00, Adaptive_Constant: 0.92 ,Time: 0.12
# It: 4390, Loss: 1.044e+01, Loss_bcs: 8.899e-01, Loss_res: 9.553e+00, Adaptive_Constant: 0.97 ,Time: 0.11
# It: 4400, Loss: 7.913e+00, Loss_bcs: 8.518e-01, Loss_res: 7.061e+00, Adaptive_Constant: 0.88 ,Time: 0.11
# It: 4410, Loss: 1.146e+01, Loss_bcs: 8.055e-01, Loss_res: 1.066e+01, Adaptive_Constant: 0.92 ,Time: 0.11
# It: 4420, Loss: 1.089e+01, Loss_bcs: 7.962e-01, Loss_res: 1.010e+01, Adaptive_Constant: 0.87 ,Time: 0.12
# It: 4430, Loss: 1.018e+01, Loss_bcs: 8.102e-01, Loss_res: 9.369e+00, Adaptive_Constant: 0.93 ,Time: 0.12
# It: 4440, Loss: 6.527e+00, Loss_bcs: 8.503e-01, Loss_res: 5.677e+00, Adaptive_Constant: 0.91 ,Time: 0.12
# It: 4450, Loss: 6.857e+00, Loss_bcs: 9.263e-01, Loss_res: 5.931e+00, Adaptive_Constant: 1.02 ,Time: 0.11
# It: 4460, Loss: 8.064e+00, Loss_bcs: 9.760e-01, Loss_res: 7.088e+00, Adaptive_Constant: 0.96 ,Time: 0.11
# It: 4470, Loss: 8.001e+00, Loss_bcs: 9.008e-01, Loss_res: 7.100e+00, Adaptive_Constant: 0.94 ,Time: 0.11
# It: 4480, Loss: 8.486e+00, Loss_bcs: 8.391e-01, Loss_res: 7.647e+00, Adaptive_Constant: 0.89 ,Time: 0.11
# It: 4490, Loss: 7.004e+00, Loss_bcs: 7.962e-01, Loss_res: 6.208e+00, Adaptive_Constant: 0.89 ,Time: 0.11
# It: 4500, Loss: 6.300e+00, Loss_bcs: 8.865e-01, Loss_res: 5.414e+00, Adaptive_Constant: 1.00 ,Time: 0.12
# It: 4510, Loss: 5.830e+00, Loss_bcs: 9.177e-01, Loss_res: 4.912e+00, Adaptive_Constant: 0.92 ,Time: 0.12
# It: 4520, Loss: 6.820e+00, Loss_bcs: 7.841e-01, Loss_res: 6.036e+00, Adaptive_Constant: 0.85 ,Time: 0.11
# It: 4530, Loss: 8.824e+00, Loss_bcs: 7.441e-01, Loss_res: 8.080e+00, Adaptive_Constant: 0.87 ,Time: 0.11
# It: 4540, Loss: 7.867e+00, Loss_bcs: 7.973e-01, Loss_res: 7.069e+00, Adaptive_Constant: 0.91 ,Time: 0.12
# It: 4550, Loss: 8.147e+00, Loss_bcs: 8.223e-01, Loss_res: 7.325e+00, Adaptive_Constant: 0.90 ,Time: 0.12
# It: 4560, Loss: 9.305e+00, Loss_bcs: 8.099e-01, Loss_res: 8.495e+00, Adaptive_Constant: 0.90 ,Time: 0.12
# ...
# It: 38510, Loss: 9.370e-01, Loss_bcs: 1.813e-01, Loss_res: 7.557e-01, Adaptive_Constant: 0.41 ,Time: 0.09
# It: 38520, Loss: 6.620e-01, Loss_bcs: 1.790e-01, Loss_res: 4.830e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 38530, Loss: 6.112e-01, Loss_bcs: 1.865e-01, Loss_res: 4.246e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 38540, Loss: 1.303e+00, Loss_bcs: 1.809e-01, Loss_res: 1.122e+00, Adaptive_Constant: 0.42 ,Time: 0.08
# It: 38550, Loss: 6.499e-01, Loss_bcs: 1.918e-01, Loss_res: 4.581e-01, Adaptive_Constant: 0.45 ,Time: 0.09
# It: 38560, Loss: 1.671e+00, Loss_bcs: 1.935e-01, Loss_res: 1.478e+00, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 38570, Loss: 6.136e-01, Loss_bcs: 1.818e-01, Loss_res: 4.317e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 38580, Loss: 6.543e-01, Loss_bcs: 2.032e-01, Loss_res: 4.511e-01, Adaptive_Constant: 0.48 ,Time: 0.08
# It: 38590, Loss: 1.544e+00, Loss_bcs: 2.124e-01, Loss_res: 1.331e+00, Adaptive_Constant: 0.45 ,Time: 0.11
# It: 38600, Loss: 8.039e-01, Loss_bcs: 2.046e-01, Loss_res: 5.994e-01, Adaptive_Constant: 0.46 ,Time: 0.09
# It: 38610, Loss: 7.694e-01, Loss_bcs: 1.807e-01, Loss_res: 5.887e-01, Adaptive_Constant: 0.39 ,Time: 0.08
# It: 38620, Loss: 7.316e-01, Loss_bcs: 1.575e-01, Loss_res: 5.741e-01, Adaptive_Constant: 0.40 ,Time: 0.09
# It: 38630, Loss: 1.097e+00, Loss_bcs: 1.765e-01, Loss_res: 9.204e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 38640, Loss: 7.455e-01, Loss_bcs: 1.883e-01, Loss_res: 5.573e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 38650, Loss: 9.115e-01, Loss_bcs: 1.863e-01, Loss_res: 7.252e-01, Adaptive_Constant: 0.44 ,Time: 0.10
# It: 38660, Loss: 7.557e-01, Loss_bcs: 1.815e-01, Loss_res: 5.742e-01, Adaptive_Constant: 0.41 ,Time: 0.08
# It: 38670, Loss: 8.255e-01, Loss_bcs: 1.978e-01, Loss_res: 6.277e-01, Adaptive_Constant: 0.48 ,Time: 0.08
# It: 38680, Loss: 1.173e+00, Loss_bcs: 2.096e-01, Loss_res: 9.629e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 38690, Loss: 5.992e-01, Loss_bcs: 1.800e-01, Loss_res: 4.193e-01, Adaptive_Constant: 0.41 ,Time: 0.10
# It: 38700, Loss: 1.067e+00, Loss_bcs: 1.714e-01, Loss_res: 8.959e-01, Adaptive_Constant: 0.42 ,Time: 0.09
# It: 38710, Loss: 1.226e+00, Loss_bcs: 1.799e-01, Loss_res: 1.046e+00, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 38720, Loss: 6.479e-01, Loss_bcs: 1.966e-01, Loss_res: 4.514e-01, Adaptive_Constant: 0.46 ,Time: 0.11
# It: 38730, Loss: 7.257e-01, Loss_bcs: 2.010e-01, Loss_res: 5.247e-01, Adaptive_Constant: 0.44 ,Time: 0.08
# It: 38740, Loss: 1.129e+00, Loss_bcs: 1.796e-01, Loss_res: 9.494e-01, Adaptive_Constant: 0.41 ,Time: 0.09
# It: 38750, Loss: 7.782e-01, Loss_bcs: 1.541e-01, Loss_res: 6.241e-01, Adaptive_Constant: 0.38 ,Time: 0.10
# It: 38760, Loss: 6.440e-01, Loss_bcs: 1.805e-01, Loss_res: 4.635e-01, Adaptive_Constant: 0.48 ,Time: 0.08
# It: 38770, Loss: 6.705e-01, Loss_bcs: 1.820e-01, Loss_res: 4.885e-01, Adaptive_Constant: 0.38 ,Time: 0.10
# It: 38780, Loss: 6.150e-01, Loss_bcs: 1.657e-01, Loss_res: 4.493e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 38790, Loss: 7.742e-01, Loss_bcs: 2.084e-01, Loss_res: 5.659e-01, Adaptive_Constant: 0.48 ,Time: 0.09
# It: 38800, Loss: 1.422e+00, Loss_bcs: 2.164e-01, Loss_res: 1.205e+00, Adaptive_Constant: 0.45 ,Time: 0.07
# It: 38810, Loss: 8.334e-01, Loss_bcs: 1.994e-01, Loss_res: 6.340e-01, Adaptive_Constant: 0.44 ,Time: 0.10
# It: 38820, Loss: 1.481e+00, Loss_bcs: 1.777e-01, Loss_res: 1.303e+00, Adaptive_Constant: 0.40 ,Time: 0.08
# It: 38830, Loss: 1.157e+00, Loss_bcs: 1.657e-01, Loss_res: 9.911e-01, Adaptive_Constant: 0.41 ,Time: 0.08
# It: 38840, Loss: 9.333e-01, Loss_bcs: 1.793e-01, Loss_res: 7.540e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 38850, Loss: 7.369e-01, Loss_bcs: 1.953e-01, Loss_res: 5.417e-01, Adaptive_Constant: 0.45 ,Time: 0.09
# It: 38860, Loss: 6.407e-01, Loss_bcs: 1.870e-01, Loss_res: 4.537e-01, Adaptive_Constant: 0.42 ,Time: 0.10
# It: 38870, Loss: 9.554e-01, Loss_bcs: 1.889e-01, Loss_res: 7.665e-01, Adaptive_Constant: 0.45 ,Time: 0.10
# It: 38880, Loss: 7.628e-01, Loss_bcs: 1.963e-01, Loss_res: 5.666e-01, Adaptive_Constant: 0.43 ,Time: 0.08
# It: 38890, Loss: 4.859e-01, Loss_bcs: 1.814e-01, Loss_res: 3.044e-01, Adaptive_Constant: 0.42 ,Time: 0.08
# It: 38900, Loss: 5.694e-01, Loss_bcs: 1.704e-01, Loss_res: 3.990e-01, Adaptive_Constant: 0.41 ,Time: 0.08
# It: 38910, Loss: 6.665e-01, Loss_bcs: 1.722e-01, Loss_res: 4.943e-01, Adaptive_Constant: 0.42 ,Time: 0.08
# It: 38920, Loss: 1.011e+00, Loss_bcs: 1.735e-01, Loss_res: 8.375e-01, Adaptive_Constant: 0.41 ,Time: 0.08
# It: 38930, Loss: 6.666e-01, Loss_bcs: 1.776e-01, Loss_res: 4.890e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 38940, Loss: 6.080e-01, Loss_bcs: 1.823e-01, Loss_res: 4.258e-01, Adaptive_Constant: 0.42 ,Time: 0.08
# It: 38950, Loss: 9.047e-01, Loss_bcs: 1.911e-01, Loss_res: 7.136e-01, Adaptive_Constant: 0.45 ,Time: 0.08
# It: 38960, Loss: 8.462e-01, Loss_bcs: 1.969e-01, Loss_res: 6.494e-01, Adaptive_Constant: 0.43 ,Time: 0.10
# It: 38970, Loss: 8.244e-01, Loss_bcs: 1.818e-01, Loss_res: 6.426e-01, Adaptive_Constant: 0.42 ,Time: 0.09
# It: 38980, Loss: 7.470e-01, Loss_bcs: 1.810e-01, Loss_res: 5.661e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 38990, Loss: 8.166e-01, Loss_bcs: 1.914e-01, Loss_res: 6.252e-01, Adaptive_Constant: 0.44 ,Time: 0.08
# It: 39000, Loss: 7.041e-01, Loss_bcs: 2.037e-01, Loss_res: 5.004e-01, Adaptive_Constant: 0.46 ,Time: 0.09
# It: 39010, Loss: 1.246e+00, Loss_bcs: 2.220e-01, Loss_res: 1.024e+00, Adaptive_Constant: 0.48 ,Time: 0.09
# It: 39020, Loss: 9.092e-01, Loss_bcs: 1.937e-01, Loss_res: 7.155e-01, Adaptive_Constant: 0.40 ,Time: 0.09
# It: 39030, Loss: 8.760e-01, Loss_bcs: 1.686e-01, Loss_res: 7.075e-01, Adaptive_Constant: 0.42 ,Time: 0.09
# It: 39040, Loss: 5.937e-01, Loss_bcs: 1.590e-01, Loss_res: 4.348e-01, Adaptive_Constant: 0.38 ,Time: 0.08
# It: 39050, Loss: 8.366e-01, Loss_bcs: 1.551e-01, Loss_res: 6.815e-01, Adaptive_Constant: 0.41 ,Time: 0.10
# It: 39060, Loss: 8.068e-01, Loss_bcs: 1.861e-01, Loss_res: 6.208e-01, Adaptive_Constant: 0.45 ,Time: 0.11
# It: 39070, Loss: 8.417e-01, Loss_bcs: 1.878e-01, Loss_res: 6.539e-01, Adaptive_Constant: 0.41 ,Time: 0.09
# It: 39080, Loss: 1.104e+00, Loss_bcs: 1.678e-01, Loss_res: 9.360e-01, Adaptive_Constant: 0.41 ,Time: 0.08
# It: 39090, Loss: 8.400e-01, Loss_bcs: 1.780e-01, Loss_res: 6.620e-01, Adaptive_Constant: 0.44 ,Time: 0.08
# It: 39100, Loss: 6.620e-01, Loss_bcs: 1.863e-01, Loss_res: 4.758e-01, Adaptive_Constant: 0.42 ,Time: 0.08
# It: 39110, Loss: 8.860e-01, Loss_bcs: 1.857e-01, Loss_res: 7.003e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 39120, Loss: 7.430e-01, Loss_bcs: 1.796e-01, Loss_res: 5.634e-01, Adaptive_Constant: 0.41 ,Time: 0.09
# It: 39130, Loss: 1.109e+00, Loss_bcs: 1.808e-01, Loss_res: 9.280e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 39140, Loss: 1.010e+00, Loss_bcs: 1.804e-01, Loss_res: 8.292e-01, Adaptive_Constant: 0.41 ,Time: 0.11
# It: 39150, Loss: 8.061e-01, Loss_bcs: 2.019e-01, Loss_res: 6.042e-01, Adaptive_Constant: 0.49 ,Time: 0.09
# It: 39160, Loss: 8.551e-01, Loss_bcs: 2.033e-01, Loss_res: 6.517e-01, Adaptive_Constant: 0.41 ,Time: 0.09
# It: 39170, Loss: 6.130e-01, Loss_bcs: 1.848e-01, Loss_res: 4.282e-01, Adaptive_Constant: 0.45 ,Time: 0.08
# It: 39180, Loss: 8.989e-01, Loss_bcs: 2.107e-01, Loss_res: 6.882e-01, Adaptive_Constant: 0.47 ,Time: 0.09
# It: 39190, Loss: 1.011e+00, Loss_bcs: 1.873e-01, Loss_res: 8.239e-01, Adaptive_Constant: 0.40 ,Time: 0.08
# It: 39200, Loss: 7.170e-01, Loss_bcs: 1.691e-01, Loss_res: 5.479e-01, Adaptive_Constant: 0.43 ,Time: 0.10
# It: 39210, Loss: 9.105e-01, Loss_bcs: 1.918e-01, Loss_res: 7.187e-01, Adaptive_Constant: 0.45 ,Time: 0.08
# It: 39220, Loss: 8.368e-01, Loss_bcs: 2.067e-01, Loss_res: 6.301e-01, Adaptive_Constant: 0.46 ,Time: 0.09
# It: 39230, Loss: 7.728e-01, Loss_bcs: 1.965e-01, Loss_res: 5.763e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 39240, Loss: 1.185e+00, Loss_bcs: 1.892e-01, Loss_res: 9.958e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 39250, Loss: 8.615e-01, Loss_bcs: 1.727e-01, Loss_res: 6.889e-01, Adaptive_Constant: 0.39 ,Time: 0.09
# It: 39260, Loss: 6.623e-01, Loss_bcs: 1.572e-01, Loss_res: 5.052e-01, Adaptive_Constant: 0.40 ,Time: 0.10
# It: 39270, Loss: 8.777e-01, Loss_bcs: 1.823e-01, Loss_res: 6.954e-01, Adaptive_Constant: 0.45 ,Time: 0.09
# It: 39280, Loss: 8.285e-01, Loss_bcs: 1.792e-01, Loss_res: 6.493e-01, Adaptive_Constant: 0.39 ,Time: 0.08
# It: 39290, Loss: 6.504e-01, Loss_bcs: 1.716e-01, Loss_res: 4.788e-01, Adaptive_Constant: 0.43 ,Time: 0.08
# It: 39300, Loss: 6.911e-01, Loss_bcs: 1.893e-01, Loss_res: 5.018e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 39310, Loss: 7.676e-01, Loss_bcs: 1.959e-01, Loss_res: 5.717e-01, Adaptive_Constant: 0.45 ,Time: 0.09
# It: 39320, Loss: 7.342e-01, Loss_bcs: 1.994e-01, Loss_res: 5.348e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 39330, Loss: 9.967e-01, Loss_bcs: 1.780e-01, Loss_res: 8.186e-01, Adaptive_Constant: 0.40 ,Time: 0.08
# It: 39340, Loss: 7.432e-01, Loss_bcs: 1.730e-01, Loss_res: 5.702e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 39350, Loss: 7.469e-01, Loss_bcs: 1.831e-01, Loss_res: 5.638e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 39360, Loss: 6.704e-01, Loss_bcs: 1.889e-01, Loss_res: 4.815e-01, Adaptive_Constant: 0.44 ,Time: 0.08
# It: 39370, Loss: 7.946e-01, Loss_bcs: 1.971e-01, Loss_res: 5.975e-01, Adaptive_Constant: 0.44 ,Time: 0.08
# It: 39380, Loss: 9.995e-01, Loss_bcs: 2.000e-01, Loss_res: 7.995e-01, Adaptive_Constant: 0.45 ,Time: 0.08
# It: 39390, Loss: 7.496e-01, Loss_bcs: 1.933e-01, Loss_res: 5.563e-01, Adaptive_Constant: 0.43 ,Time: 0.08
# It: 39400, Loss: 1.001e+00, Loss_bcs: 2.082e-01, Loss_res: 7.925e-01, Adaptive_Constant: 0.49 ,Time: 0.10
# It: 39410, Loss: 7.004e-01, Loss_bcs: 2.121e-01, Loss_res: 4.882e-01, Adaptive_Constant: 0.44 ,Time: 0.11
# It: 39420, Loss: 7.056e-01, Loss_bcs: 1.855e-01, Loss_res: 5.202e-01, Adaptive_Constant: 0.42 ,Time: 0.08
# It: 39430, Loss: 7.150e-01, Loss_bcs: 2.052e-01, Loss_res: 5.098e-01, Adaptive_Constant: 0.48 ,Time: 0.09
# It: 39440, Loss: 8.744e-01, Loss_bcs: 2.050e-01, Loss_res: 6.694e-01, Adaptive_Constant: 0.42 ,Time: 0.08
# It: 39450, Loss: 5.997e-01, Loss_bcs: 1.864e-01, Loss_res: 4.133e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 39460, Loss: 9.455e-01, Loss_bcs: 1.783e-01, Loss_res: 7.673e-01, Adaptive_Constant: 0.41 ,Time: 0.09
# It: 39470, Loss: 1.151e+00, Loss_bcs: 1.834e-01, Loss_res: 9.671e-01, Adaptive_Constant: 0.45 ,Time: 0.09
# It: 39480, Loss: 7.688e-01, Loss_bcs: 1.976e-01, Loss_res: 5.712e-01, Adaptive_Constant: 0.44 ,Time: 0.10
# It: 39490, Loss: 7.278e-01, Loss_bcs: 1.874e-01, Loss_res: 5.404e-01, Adaptive_Constant: 0.43 ,Time: 0.08
# It: 39500, Loss: 7.017e-01, Loss_bcs: 1.817e-01, Loss_res: 5.200e-01, Adaptive_Constant: 0.42 ,Time: 0.09
# It: 39510, Loss: 7.118e-01, Loss_bcs: 1.957e-01, Loss_res: 5.161e-01, Adaptive_Constant: 0.46 ,Time: 0.10
# It: 39520, Loss: 9.381e-01, Loss_bcs: 1.916e-01, Loss_res: 7.465e-01, Adaptive_Constant: 0.41 ,Time: 0.09
# It: 39530, Loss: 9.313e-01, Loss_bcs: 1.838e-01, Loss_res: 7.475e-01, Adaptive_Constant: 0.44 ,Time: 0.08
# It: 39540, Loss: 5.994e-01, Loss_bcs: 1.765e-01, Loss_res: 4.229e-01, Adaptive_Constant: 0.40 ,Time: 0.09
# It: 39550, Loss: 6.363e-01, Loss_bcs: 1.603e-01, Loss_res: 4.760e-01, Adaptive_Constant: 0.40 ,Time: 0.09
# It: 39560, Loss: 8.562e-01, Loss_bcs: 1.850e-01, Loss_res: 6.712e-01, Adaptive_Constant: 0.46 ,Time: 0.10
# It: 39570, Loss: 6.736e-01, Loss_bcs: 1.887e-01, Loss_res: 4.849e-01, Adaptive_Constant: 0.41 ,Time: 0.08
# It: 39580, Loss: 7.064e-01, Loss_bcs: 1.799e-01, Loss_res: 5.265e-01, Adaptive_Constant: 0.44 ,Time: 0.08
# It: 39590, Loss: 7.461e-01, Loss_bcs: 1.877e-01, Loss_res: 5.584e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 39600, Loss: 8.720e-01, Loss_bcs: 1.690e-01, Loss_res: 7.030e-01, Adaptive_Constant: 0.39 ,Time: 0.08
# It: 39610, Loss: 6.596e-01, Loss_bcs: 1.667e-01, Loss_res: 4.928e-01, Adaptive_Constant: 0.42 ,Time: 0.09
# It: 39620, Loss: 7.983e-01, Loss_bcs: 1.695e-01, Loss_res: 6.288e-01, Adaptive_Constant: 0.40 ,Time: 0.10
# It: 39630, Loss: 7.786e-01, Loss_bcs: 1.781e-01, Loss_res: 6.005e-01, Adaptive_Constant: 0.44 ,Time: 0.10
# It: 39640, Loss: 6.698e-01, Loss_bcs: 1.907e-01, Loss_res: 4.791e-01, Adaptive_Constant: 0.43 ,Time: 0.15
# It: 39650, Loss: 5.412e-01, Loss_bcs: 1.838e-01, Loss_res: 3.574e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 39660, Loss: 1.089e+00, Loss_bcs: 1.718e-01, Loss_res: 9.170e-01, Adaptive_Constant: 0.40 ,Time: 0.10
# It: 39670, Loss: 8.315e-01, Loss_bcs: 1.785e-01, Loss_res: 6.530e-01, Adaptive_Constant: 0.45 ,Time: 0.10
# It: 39680, Loss: 8.820e-01, Loss_bcs: 1.898e-01, Loss_res: 6.922e-01, Adaptive_Constant: 0.43 ,Time: 0.08
# It: 39690, Loss: 1.088e+00, Loss_bcs: 1.762e-01, Loss_res: 9.123e-01, Adaptive_Constant: 0.41 ,Time: 0.09
# It: 39700, Loss: 9.238e-01, Loss_bcs: 1.747e-01, Loss_res: 7.491e-01, Adaptive_Constant: 0.42 ,Time: 0.08
# It: 39710, Loss: 5.631e-01, Loss_bcs: 1.808e-01, Loss_res: 3.823e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# It: 39720, Loss: 7.035e-01, Loss_bcs: 1.673e-01, Loss_res: 5.361e-01, Adaptive_Constant: 0.39 ,Time: 0.10
# It: 39730, Loss: 7.394e-01, Loss_bcs: 1.671e-01, Loss_res: 5.724e-01, Adaptive_Constant: 0.43 ,Time: 0.10
# It: 39740, Loss: 7.485e-01, Loss_bcs: 1.831e-01, Loss_res: 5.654e-01, Adaptive_Constant: 0.43 ,Time: 0.10
# It: 39750, Loss: 7.144e-01, Loss_bcs: 2.026e-01, Loss_res: 5.117e-01, Adaptive_Constant: 0.47 ,Time: 0.11
# It: 39760, Loss: 9.663e-01, Loss_bcs: 2.157e-01, Loss_res: 7.506e-01, Adaptive_Constant: 0.46 ,Time: 0.10
# It: 39770, Loss: 8.065e-01, Loss_bcs: 1.997e-01, Loss_res: 6.069e-01, Adaptive_Constant: 0.44 ,Time: 0.12
# It: 39780, Loss: 5.539e-01, Loss_bcs: 1.836e-01, Loss_res: 3.702e-01, Adaptive_Constant: 0.42 ,Time: 0.10
# It: 39790, Loss: 7.995e-01, Loss_bcs: 1.922e-01, Loss_res: 6.073e-01, Adaptive_Constant: 0.46 ,Time: 0.10
# It: 39800, Loss: 1.018e+00, Loss_bcs: 1.963e-01, Loss_res: 8.221e-01, Adaptive_Constant: 0.43 ,Time: 0.10
# It: 39810, Loss: 1.122e+00, Loss_bcs: 1.870e-01, Loss_res: 9.347e-01, Adaptive_Constant: 0.44 ,Time: 0.11
# It: 39820, Loss: 8.433e-01, Loss_bcs: 1.882e-01, Loss_res: 6.551e-01, Adaptive_Constant: 0.43 ,Time: 0.10
# It: 39830, Loss: 7.778e-01, Loss_bcs: 1.889e-01, Loss_res: 5.889e-01, Adaptive_Constant: 0.44 ,Time: 0.10
# It: 39840, Loss: 6.998e-01, Loss_bcs: 1.791e-01, Loss_res: 5.207e-01, Adaptive_Constant: 0.41 ,Time: 0.10
# It: 39850, Loss: 1.044e+00, Loss_bcs: 1.756e-01, Loss_res: 8.688e-01, Adaptive_Constant: 0.43 ,Time: 0.12
# It: 39860, Loss: 6.510e-01, Loss_bcs: 1.942e-01, Loss_res: 4.568e-01, Adaptive_Constant: 0.45 ,Time: 0.10
# It: 39870, Loss: 9.229e-01, Loss_bcs: 1.986e-01, Loss_res: 7.243e-01, Adaptive_Constant: 0.44 ,Time: 0.11
# It: 39880, Loss: 6.663e-01, Loss_bcs: 1.946e-01, Loss_res: 4.718e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 39890, Loss: 7.212e-01, Loss_bcs: 2.086e-01, Loss_res: 5.126e-01, Adaptive_Constant: 0.47 ,Time: 0.11
# It: 39900, Loss: 9.898e-01, Loss_bcs: 1.995e-01, Loss_res: 7.903e-01, Adaptive_Constant: 0.42 ,Time: 0.10
# It: 39910, Loss: 7.710e-01, Loss_bcs: 1.835e-01, Loss_res: 5.875e-01, Adaptive_Constant: 0.43 ,Time: 0.11
# It: 39920, Loss: 5.664e-01, Loss_bcs: 1.748e-01, Loss_res: 3.916e-01, Adaptive_Constant: 0.40 ,Time: 0.11
# It: 39930, Loss: 8.950e-01, Loss_bcs: 1.677e-01, Loss_res: 7.273e-01, Adaptive_Constant: 0.41 ,Time: 0.10
# It: 39940, Loss: 7.832e-01, Loss_bcs: 1.881e-01, Loss_res: 5.950e-01, Adaptive_Constant: 0.45 ,Time: 0.10
# It: 39950, Loss: 6.472e-01, Loss_bcs: 1.852e-01, Loss_res: 4.620e-01, Adaptive_Constant: 0.41 ,Time: 0.11
# It: 39960, Loss: 6.659e-01, Loss_bcs: 1.708e-01, Loss_res: 4.950e-01, Adaptive_Constant: 0.42 ,Time: 0.09
# It: 39970, Loss: 9.157e-01, Loss_bcs: 1.835e-01, Loss_res: 7.322e-01, Adaptive_Constant: 0.44 ,Time: 0.10
# It: 39980, Loss: 6.420e-01, Loss_bcs: 1.933e-01, Loss_res: 4.487e-01, Adaptive_Constant: 0.44 ,Time: 0.09
# It: 39990, Loss: 8.706e-01, Loss_bcs: 1.788e-01, Loss_res: 6.918e-01, Adaptive_Constant: 0.41 ,Time: 0.10
# It: 40000, Loss: 1.127e+00, Loss_bcs: 1.731e-01, Loss_res: 9.543e-01, Adaptive_Constant: 0.43 ,Time: 0.09
# Gradients information stored ...

# %%
# Test data
nn = 100
x1 = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x2 = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
x1, x2 = np.meshgrid(x1, x2)
X_star = np.hstack((x1.flatten()[:, None], x2.flatten()[:, None]))

# Exact solution
u_star = u(X_star, a_1, a_2)
f_star = f(X_star, a_1, a_2, lam)

# Predictions
u_pred = model.predict_u(X_star)
f_pred = model.predict_r(X_star)

# Relative error
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_u: {:.2e}'.format(error_f))

### Plot ###

# Exact solution & Predicted solution
# Exact soluton
U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

# Predicted solution
U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(x1, x2, U_star, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Exact $u(x)$')

plt.subplot(1, 3, 2)
plt.pcolor(x1, x2, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Predicted $u(x)$')

plt.subplot(1, 3, 3)
plt.pcolor(x1, x2, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# Relative L2 error_u: 2.98e-01
# Relative L2 error_u: 1.22e-02

# %%
# Test data
nn = 100
x1 = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x2 = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
x1, x2 = np.meshgrid(x1, x2)
X_star = np.hstack((x1.flatten()[:, None], x2.flatten()[:, None]))

# Exact solution
u_star = u(X_star, a_1, a_2)
f_star = f(X_star, a_1, a_2, lam)

# Predictions
u_pred = model.predict_u(X_star)
f_pred = model.predict_r(X_star)

# Relative error
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

print('Relative L2 error_u: {:.2e}'.format(error_u))
print('Relative L2 error_u: {:.2e}'.format(error_f))

### Plot ###

# Exact solution & Predicted solution
# Exact soluton
U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

# Predicted solution
U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(x1, x2, U_star, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Exact $u(x)$')

plt.subplot(1, 3, 2)
plt.pcolor(x1, x2, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Predicted $u(x)$')

plt.subplot(1, 3, 3)
plt.pcolor(x1, x2, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# Relative L2 error_u: 1.79e-02
# Relative L2 error_u: 9.96e-03

# %%
# Residual loss & Boundary loss
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# Adaptive Constant
adaptive_constant = model.adpative_constant_log

fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Gradients at the end of training
data_gradients_res = model.dict_gradients_res_layers
data_gradients_bcs = model.dict_gradients_bcs_layers

gradients_res_list = []
gradients_bcs_list = []

num_hidden_layers = len(layers) - 1
for j in range(num_hidden_layers):
    gradient_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradient_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]

    gradients_res_list.append(gradient_res)
    gradients_bcs_list.append(gradient_bcs)

cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    
    ax.get_legend().remove()
    ax.set_xlim([-3.0, 3.0])
    ax.set_ylim([0,100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()
fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()
# Out:
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9841/1481205784.py in <module>
#      29                     norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
#      30
# ---> 31     ax.get_legend().remove()
#      32     ax.set_xlim([-3.0, 3.0])
#      33     ax.set_ylim([0,100])
#
# AttributeError: 'NoneType' object has no attribute 'remove'

# %%
# Eigenvalues if applicable
if stiff_ratio:
    eigenvalues_list = model.eigenvalue_log
    eigenvalues_bcs_list = model.eigenvalue_bcs_log
    eigenvalues_res_list = model.eigenvalue_res_log
    eigenvalues_res = eigenvalues_res_list[-1]
    eigenvalues_bcs = eigenvalues_bcs_list[-1]

    fig_5 = plt.figure(5)
    ax = fig_5.add_subplot(1, 1, 1)
    ax.plot(eigenvalues_res, label='$\mathcal{L}_r$')
    ax.plot(eigenvalues_bcs, label='$\mathcal{L}_{u_b}$')
    ax.set_xlabel('index')
    ax.set_ylabel('eigenvalue')
    ax.set_yscale('symlog')
    plt.legend()
    plt.tight_layout()
    plt.show()
