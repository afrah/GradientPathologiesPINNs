# %%
import tensorflow as tf
import numpy as np
import timeit

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import seaborn as sns

import os
os.environ["KMP_WARNINGS"] = "FALSE" 


import scipy
import scipy.io
import time

import sys

import scipy
import scipy.io
import time


import logging

import os.path
import shutil
from datetime import datetime
import pickle
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y
    

######################################################################################################
def u(x, a_1, a_2):
    return np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

def u_xx(x, a_1, a_2):
    return - (a_1 * np.pi) ** 2 * np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

def u_yy(x, a_1, a_2):
    return - (a_2 * np.pi) ** 2 * np.sin(a_1 * np.pi * x[:, 0:1]) * np.sin(a_2 * np.pi * x[:, 1:2])

# Forcing
def f(x, a_1, a_2, lam):
    return u_xx(x, a_1, a_2) + u_yy(x, a_1, a_2) + lam * u(x, a_1, a_2)

def operator(u, x1, x2, lam, sigma_x1=1.0, sigma_x2=1.0):
    u_x1 = tf.gradients(u, x1)[0] / sigma_x1
    u_x2 = tf.gradients(u, x2)[0] / sigma_x2
    u_xx1 = tf.gradients(u_x1, x1)[0] / sigma_x1
    u_xx2 = tf.gradients(u_x2, x2)[0] / sigma_x2
    residual = u_xx1 + u_xx2 + lam * u
    return residual
#######################################################################################################

class Helmholtz2D:
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, mode, sess):
        # Normalization constants


        self.mode = mode

        self.dirname, logpath = self.make_output_dir()
        self.logger = self.get_logger(logpath)     

        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x1, self.sigma_x1 = self.mu_X[0], self.sigma_X[0]
        self.mu_x2, self.sigma_x2 = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Helmoholtz constant
        self.lam = tf.constant(lam, dtype=tf.float32)

        # Mode
        self.model = mode

        # Record stiff ratio
        # self.stiff_ratio = stiff_ratio

        # Adaptive constant
        self.rate = 0.5
        self.rho = 0.5
        self.T = 0.9

        self.adaptive_constant_bc_val = np.array(1.0)
        self.adaptive_constant_res_val = np.array(1.0)

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)

        # if mode in ['M3', 'M4']:
        #     # Initialize encoder weights and biases
        #     self.encoder_weights_1 = self.xavier_init([2, layers[1]])
        #     self.encoder_biases_1 = self.xavier_init([1, layers[1]])

        #     self.encoder_weights_2 = self.xavier_init([2, layers[1]])
        #     self.encoder_biases_2 = self.xavier_init([1, layers[1]])

        # Define Tensorflow session
        self.sess = sess #tf.Session(config=tf.ConfigProto(log_device_placement=False))

        # Define placeholders and computational graph
        self.x1_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # Define placeholder for adaptive constant
        self.adaptive_constant_bc_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_bc_val.shape)
        self.adaptive_constant_res_tf = tf.placeholder(tf.float32, shape=self.adaptive_constant_res_val.shape)

        # Evaluate predictions
        self.u_bc1_pred = self.net_u(self.x1_bc1_tf, self.x2_bc1_tf)
        self.u_bc2_pred = self.net_u(self.x1_bc2_tf, self.x2_bc2_tf)
        self.u_bc3_pred = self.net_u(self.x1_bc3_tf, self.x2_bc3_tf)
        self.u_bc4_pred = self.net_u(self.x1_bc4_tf, self.x2_bc4_tf)

        self.u_pred = self.net_u(self.x1_u_tf, self.x2_u_tf)
        self.r_pred = self.net_r(self.x1_r_tf, self.x2_r_tf)

        # Boundary loss
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_tf - self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_tf - self.u_bc2_pred))
        self.loss_bc3 = tf.reduce_mean(tf.square(self.u_bc3_tf - self.u_bc3_pred))
        self.loss_bc4 = tf.reduce_mean(tf.square(self.u_bc4_tf - self.u_bc4_pred))
        self.loss_bcs =  (self.loss_bc1 + self.loss_bc2 + self.loss_bc3 + self.loss_bc4)

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_tf - self.r_pred))

        # Total loss
        self.loss = self.adaptive_constant_res_tf * self.loss_res + self.adaptive_constant_bc_tf * (self.loss_bc1 + self.loss_bc2 + self.loss_bc3 + self.loss_bc4)

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step, 1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_tensor_list = [self.loss ,  self.loss_res ,  self.loss_bcs,  self.loss_bc1 , self.loss_bc2 , self.loss_bc3, self.loss_bc4] 
        self.loss_list = ["total loss" , "loss_res" , "loss_bcs" , "loss_bc1", "loss_bc2", "loss_bc3", "loss_bc4"] 



        self.prev_lam_bc =1
        self.prev_lam_res = 1
        self.index =1
        self.epoch_loss = dict.fromkeys(self.loss_list, 0)
        self.loss_history = dict((loss, []) for loss in self.loss_list)
        # Logger
        self.loss_bcs_log = []
        self.loss_res_log = []
        # self.saver = tf.train.Saver()

        # Generate dicts for gradients storage
        self.dict_gradients_res_layers = self.generate_grad_dict()
        self.dict_gradients_bcs_layers = self.generate_grad_dict()

        # Gradients Storage
        self.grad_res = []
        self.grad_bcs = []
        for i in range(len(self.layers) - 1):
            self.grad_res.append(tf.gradients(self.loss_res, self.weights[i])[0])
            self.grad_bcs.append(tf.gradients(self.loss_bcs, self.weights[i])[0])

        # Compute and store the adaptive constant
        self.adpative_constant_bc_log = []
        self.adpative_constant_res_log = []
        
        self.mean_grad_res_list = []
        self.mean_grad_bcs_list = []
        
        self.mean_grad_res_log = []
        self.mean_grad_bcs_log = []
    
        for i in range(len(self.layers) - 1):
            self.mean_grad_res_list.append(tf.reduce_mean(tf.abs(self.grad_res[i]))) 
            self.mean_grad_bcs_list.append(tf.reduce_mean(tf.abs(self.grad_bcs[i])))
        
        self.mean_grad_res = tf.reduce_mean(tf.stack(self.mean_grad_res_list))
        self.mean_grad_bcs = tf.reduce_mean(tf.stack(self.mean_grad_bcs_list))

        # # Stiff Ratio
        # if self.stiff_ratio:
        #     self.Hessian, self.Hessian_bcs, self.Hessian_res = self.get_H_op()
        #     self.eigenvalues, _ = tf.linalg.eigh(self.Hessian)
        #     self.eigenvalues_bcs, _ = tf.linalg.eigh(self.Hessian_bcs)
        #     self.eigenvalues_res, _ = tf.linalg.eigh(self.Hessian_res)

        #     self.eigenvalue_log = []
        #     self.eigenvalue_bcs_log = []
        #     self.eigenvalue_res_log = []

        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

     # Create dictionary to store gradients
    def generate_grad_dict(self, layers):
        num = len(layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict

    # Save gradients
    def save_gradients(self, tf_dict):
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res_value, grad_bcs_value = self.sess.run([self.grad_res[i], self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_res and loss_bcs
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res_value.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bcs_value.flatten())
        return None



    # Xavier initialization
    def xavier_init(self,size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H):
        num_layers = len(self.layers)
        for l in range(0, num_layers - 2):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, x1, x2):
        u = self.forward_pass(tf.concat([x1, x2], 1))
        return u

    # Forward pass for residual
    def net_r(self, x1, x2):
        u = self.net_u(x1, x2)
        residual = self.operator(u, x1, x2,
                                 self.lam,
                                 self.sigma_x1,
                                 self.sigma_x2)
        return residual

    # Feed minibatch
    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y


    def lambda_balance(self ,term , index):

        loss_list = ["loss_res" , "loss_bcs" ] 

        m = len(loss_list)
        num = np.exp(self.loss_history[term][-1] /(self.T * self.loss_history[term][index] +1e-12))
        denum = 0 

        for  key in loss_list:
            denum +=  np.exp(self.loss_history[key][-1] /(self.T * self.loss_history[key][index] +1e-12))
        return m * (num / denum)
     
    def relobralo( self, term ,prev_lamda ):

        lambda_hist = self.rho  * prev_lamda + (1.0 - self.rho) *  self.lambda_balance( term , 1)
        lambda_i = self.rate  * lambda_hist + (1.0 - self.rate) *  self.lambda_balance( term , self.index)

        return lambda_i
    
  # Trains the model by minimizing the MSE loss
    def trainmb(self, nIter=10000, batch_size=128):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        for it in range(1 , nIter):
            # Fetch boundary mini-batches
            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, u_bc3_batch = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, u_bc4_batch = self.fetch_minibatch(self.bcs_sampler[3], batch_size)

            # Fetch residual mini-batch
            X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x1_bc1_tf: X_bc1_batch[:, 0:1], self.x2_bc1_tf: X_bc1_batch[:, 1:2],
                       self.u_bc1_tf: u_bc1_batch,
                       self.x1_bc2_tf: X_bc2_batch[:, 0:1], self.x2_bc2_tf: X_bc2_batch[:, 1:2],
                       self.u_bc2_tf: u_bc2_batch,
                       self.x1_bc3_tf: X_bc3_batch[:, 0:1], self.x2_bc3_tf: X_bc3_batch[:, 1:2],
                       self.u_bc3_tf: u_bc3_batch,
                       self.x1_bc4_tf: X_bc4_batch[:, 0:1], self.x2_bc4_tf: X_bc4_batch[:, 1:2],
                       self.u_bc4_tf: u_bc4_batch,
                       self.x1_r_tf: X_res_batch[:, 0:1], self.x2_r_tf: X_res_batch[:, 1:2], self.r_tf: f_res_batch,
                       self.adaptive_constant_res_tf:  self.adaptive_constant_res_val,
                       self.adaptive_constant_bc_tf:  self.adaptive_constant_bc_val
                       }

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)

            for loss_values, key in zip(batch_losses, self.loss_list):
                self.loss_history[key].append(loss_values)
 

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value ,  loss_bcs_value, loss_res_value = self.sess.run([self.loss, self.loss_bcs, self.loss_res] , tf_dict)

 
                self.print('It: %d, Loss: %.3e, Loss_bcs: %.3e, Loss_res: %.3e,Time: %.2f' % (it, loss_value, loss_bcs_value, loss_res_value, elapsed))

            if it % 100 == 0:

                self.adaptive_constant_res_val =  self.relobralo( "loss_res"  ,self.prev_lam_res )  #fres *  np.exp(self.rate * fres)  /norm

                self.adaptive_constant_bc_val =  self.relobralo( "loss_bcs"  ,self.prev_lam_bc )  # adaptive_constant_value * (1.0 - self.beta)+ self.beta * self.adaptive_constant_val

                self.print('adaptive_constant_res_val: %f' % (self.adaptive_constant_res_val))
                self.print('adaptive_constant_bc_val: %f' % (self.adaptive_constant_bc_val))

                self.adpative_constant_bc_log.append(self.adaptive_constant_bc_val)
                self.adpative_constant_res_log.append(self.adaptive_constant_res_val)

                mean_grad_bcs ,  max_grad_res = self.sess.run([self.mean_grad_bcs, self.mean_grad_res] , tf_dict)

                self.mean_grad_bcs_log.append(mean_grad_bcs)
                self.mean_grad_res_log.append(max_grad_res)

                self.prev_lam_bc = self.adaptive_constant_bc_val
                self.prev_lam_res = self.adaptive_constant_res_val
                self.index = it

            start_time = timeit.default_timer()

            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()
 


 # Trains the model by minimizing the MSE loss
    def train(self, bcbatch , fbatch , nIter=10000):
        itValues = [1,100,1000,39999]

        start_time = timeit.default_timer()
        # Fetch boundary mini-batches
        X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], bcbatch)
        X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], bcbatch)
        X_bc3_batch, u_bc3_batch = self.fetch_minibatch(self.bcs_sampler[2], bcbatch)
        X_bc4_batch, u_bc4_batch = self.fetch_minibatch(self.bcs_sampler[3], bcbatch)

        # Fetch residual mini-batch
        X_res_batch, f_res_batch = self.fetch_minibatch(self.res_sampler, fbatch)

        # Define a dictionary for associating placeholders with data
        tf_dict = {self.x1_bc1_tf: X_bc1_batch[:, 0:1], self.x2_bc1_tf: X_bc1_batch[:, 1:2],
                    self.u_bc1_tf: u_bc1_batch,
                    self.x1_bc2_tf: X_bc2_batch[:, 0:1], self.x2_bc2_tf: X_bc2_batch[:, 1:2],
                    self.u_bc2_tf: u_bc2_batch,
                    self.x1_bc3_tf: X_bc3_batch[:, 0:1], self.x2_bc3_tf: X_bc3_batch[:, 1:2],
                    self.u_bc3_tf: u_bc3_batch,
                    self.x1_bc4_tf: X_bc4_batch[:, 0:1], self.x2_bc4_tf: X_bc4_batch[:, 1:2],
                    self.u_bc4_tf: u_bc4_batch,
                    self.x1_r_tf: X_res_batch[:, 0:1], self.x2_r_tf: X_res_batch[:, 1:2], self.r_tf: f_res_batch,
                    self.adaptive_constant_res_tf:  self.adaptive_constant_res_val,
                    self.adaptive_constant_bc_tf:  self.adaptive_constant_bc_val
                    }

        for it in range(1 , nIter):

            # Run the Tensorflow session to minimize the loss
            _ , batch_losses = self.sess.run( [  self.train_op , self.loss_tensor_list ] ,tf_dict)

            for loss_values, key in zip(batch_losses, self.loss_list):
                self.loss_history[key].append(loss_values)
 

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value ,  loss_bcs_value, loss_res_value = self.sess.run([self.loss, self.loss_bcs, self.loss_res] , tf_dict)

 
                self.print('It: %d, Loss: %.3e, Loss_bcs: %.3e, Loss_res: %.3e,Time: %.2f' % (it, loss_value, loss_bcs_value, loss_res_value, elapsed))

            if it % 100 == 0:

                self.adaptive_constant_res_val =  self.relobralo( "loss_res"  ,self.prev_lam_res )  #fres *  np.exp(self.rate * fres)  /norm

                self.adaptive_constant_bc_val =  self.relobralo( "loss_bcs"  ,self.prev_lam_bc )  # adaptive_constant_value * (1.0 - self.beta)+ self.beta * self.adaptive_constant_val

                self.print('adaptive_constant_res_val: %f' % (self.adaptive_constant_res_val))
                self.print('adaptive_constant_bc_val: %f' % (self.adaptive_constant_bc_val))

                self.adpative_constant_bc_log.append(self.adaptive_constant_bc_val)
                self.adpative_constant_res_log.append(self.adaptive_constant_res_val)

                mean_grad_bcs ,  max_grad_res = self.sess.run([self.mean_grad_bcs, self.mean_grad_res] , tf_dict)

                self.mean_grad_bcs_log.append(mean_grad_bcs)
                self.mean_grad_res_log.append(max_grad_res)

                self.prev_lam_bc = self.adaptive_constant_bc_val
                self.prev_lam_res = self.adaptive_constant_res_val
                self.index = it

            start_time = timeit.default_timer()

            if it in itValues:
                    self.plot_layerLoss(tf_dict , it)
                    self.print("Gradients information stored ...")

            sys.stdout.flush()
 
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x1_u_tf: X_star[:, 0:1], self.x2_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x1_r_tf: X_star[:, 0:1], self.x2_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star



  # ###############################################################################################################################################
   # 
   #  
    def plot_layerLoss(self , tf_dict , epoch):
        ## Gradients #
        num_layers = len(self.layers)
        for i in range(num_layers - 1):
            grad_res, grad_bc1    = self.sess.run([ self.grad_res[i],self.grad_bcs[i]], feed_dict=tf_dict)

            # save gradients of loss_r and loss_u
            self.dict_gradients_res_layers['layer_' + str(i + 1)].append(grad_res.flatten())
            self.dict_gradients_bcs_layers['layer_' + str(i + 1)].append(grad_bc1.flatten())

        num_hidden_layers = num_layers -1
        cnt = 1
        fig = plt.figure(4, figsize=(13, 4))
        for j in range(num_hidden_layers):
            ax = plt.subplot(1, num_hidden_layers, cnt)
            ax.set_title('Layer {}'.format(j + 1))
            ax.set_yscale('symlog')
            gradients_res = self.dict_gradients_res_layers['layer_' + str(j + 1)][-1]
            gradients_bc1 = self.dict_gradients_bcs_layers['layer_' + str(j + 1)][-1]

            sns.distplot(gradients_res, hist=False,kde_kws={"shade": False},norm_hist=True,  label=r'$\nabla_\theta \mathcal{L}_r$')

            sns.distplot(gradients_bc1, hist=False,kde_kws={"shade": False},norm_hist=True,   label=r'$\nabla_\theta \mathcal{L}_{u_{bc1}}$')

            #ax.get_legend().remove()
            ax.set_xlim([-1.0, 1.0])
            #ax.set_ylim([0, 150])
            cnt += 1
        handles, labels = ax.get_legend_handles_labels()

        fig.legend(handles, labels, loc="center",  bbox_to_anchor=(0.5, -0.03),borderaxespad=0,bbox_transform=fig.transFigure, ncol=2)
        text = 'layerLoss_epoch' + str(epoch) +'.png'
        plt.savefig(os.path.join(self.dirname,text) , bbox_inches='tight')
        plt.close("all")
    # #########################
    # def make_output_dir(self):
        
    #     if not os.path.exists("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints"):
    #         os.mkdir("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints")
    #     dirname = os.path.join("/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
    #     os.mkdir(dirname)
    #     text = 'output.log'
    #     logpath = os.path.join(dirname, text)
    #     shutil.copyfile('/okyanus/users/afarea/PINN/Adaptive_PINN/IB_PINN/M2.py', os.path.join(dirname, 'M2.py'))

    #     return dirname, logpath
    
    # # ###########################################################
    def make_output_dir(self):
        
        if not os.path.exists("checkpoints"):
            os.mkdir("checkpoints")
        dirname = os.path.join("checkpoints", datetime.now().strftime("%b-%d-%Y_%H-%M-%S-%f_") + self.mode)
        os.mkdir(dirname)
        text = 'output.log'
        logpath = os.path.join(dirname, text)
        shutil.copyfile('M2.ipynb', os.path.join(dirname, 'M2.ipynb'))
        return dirname, logpath
    

    def get_logger(self, logpath):
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.DEBUG)
        sh = logging.StreamHandler()
        sh.setLevel(logging.DEBUG)        
        sh.setFormatter(logging.Formatter('%(message)s'))
        fh = logging.FileHandler(logpath)
        logger.addHandler(sh)
        logger.addHandler(fh)
        return logger


   
    def print(self, *args):
        for word in args:
            if len(args) == 1:
                self.logger.info(word)
            elif word != args[-1]:
                for handler in self.logger.handlers:
                    handler.terminator = ""
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32: 
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)
            else:
                for handler in self.logger.handlers:
                    handler.terminator = "\n"
                if type(word) == float or type(word) == np.float64 or type(word) == np.float32:
                    self.logger.info("%.4e" % (word))
                else:
                    self.logger.info(word)


    def plot_loss_history(self , path):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        for key in self.loss_history:
            self.print("Final loss %s: %e" % (key, self.loss_history[key][-1]))
            ax.semilogy(self.loss_history[key], label=key)
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel("loss", fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        plt.savefig(path)
        plt.close("all" , )
       #######################
    def save_NN(self):

        uv_weights = self.sess.run(self.weights)
        uv_biases = self.sess.run(self.biases)

        with open(os.path.join(self.dirname,'model.pickle'), 'wb') as f:
            pickle.dump([uv_weights, uv_biases], f)
            self.print("Save uv NN parameters successfully in %s ..." , self.dirname)

        # with open(os.path.join(self.dirname,'loss_history_BFS.pickle'), 'wb') as f:
        #     pickle.dump(self.loss_rec, f)
        with open(os.path.join(self.dirname,'loss_history_BFS.png'), 'wb') as f:
            self.plot_loss_history(f)


    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values


    def generate_grad_dict(self):
        num = len(self.layers) - 1
        grad_dict = {}
        for i in range(num):
            grad_dict['layer_{}'.format(i + 1)] = []
        return grad_dict
    
    def assign_batch_losses(self, batch_losses):
        for loss_values, key in zip(batch_losses, self.epoch_loss):
            self.epoch_loss[key] = loss_values
            
    def plt_prediction(self , x1 , x2 , X_star , u_star , u_pred , f_star , f_pred):
        from mpl_toolkits.axes_grid1 import ImageGrid

        ### Plot ###

        # Exact solution & Predicted solution
        # Exact soluton
        U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
        F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

        # Predicted solution
        U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
        F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

        titles = ['Exact $u(x)$' , 'Predicted $u(x)$' , 'Absolute error' , 'Exact $f(x)$' , 'Predicted $f(x)$' , 'Absolute error']
        data = [U_star , U_pred ,  np.abs(U_star - U_pred) , F_star , F_pred ,  np.abs(F_star - F_pred) ]
        

        fig_1 = plt.figure(1, figsize=(13, 5))
        grid = ImageGrid(fig_1, 111, direction="row", nrows_ncols=(2,3), 
                        label_mode="1", axes_pad=1.7, share_all=False, 
                        cbar_mode="each", cbar_location="right", 
                        cbar_size="5%", cbar_pad=0.0)
    # CREATE ARGUMENTS DICT FOR CONTOURPLOTS
        minmax_list = []
        kwargs_list = []
        for d in data:
            # if(local):
            #     minmax_list.append([np.min(d), np.max(d)])
            # else:
            minmax_list.append([np.min(d), np.max(d)])

            kwargs_list.append(dict(levels=np.linspace(minmax_list[-1][0],minmax_list[-1][1], 60),
                cmap="coolwarm", vmin=minmax_list[-1][0], vmax=minmax_list[-1][1]))

        for ax, z, kwargs, minmax, title in zip(grid, data, kwargs_list, minmax_list, titles):
        #pcf = [ax.tricontourf(x, y, z[0,:], **kwargs)]
            #pcfsets.append(pcf)
            # if (timeStp == 0):
                #  print( z[timeStp,:,:])
            pcf = [ax.pcolor(x1, x2, z , cmap='jet')]
            cb = ax.cax.colorbar(pcf[0], ticks=np.linspace(minmax[0],minmax[1],7),  format='%.3e')
            ax.cax.tick_params(labelsize=14.5)
            ax.set_title(title, fontsize=14.5, pad=7)
            ax.set_ylabel("y", labelpad=14.5, fontsize=14.5, rotation="horizontal")
            ax.set_xlabel("x", fontsize=14.5)
            ax.tick_params(labelsize=14.5)
            ax.set_xlim(x1.min(), x1.max())
            ax.set_ylim(x2.min(), x2.max())
            ax.set_aspect("equal")

        fig_1.set_size_inches(15, 10, True)
        fig_1.subplots_adjust(left=0.7, bottom=0, right=2.2, top=0.5, wspace=None, hspace=None)
        plt.tight_layout()
        plt.savefig(os.path.join(self.dirname,"prediction.png"), dpi=300 , bbox_inches='tight')
        plt.close("all" , )


    def plot_lambda(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.adpative_constant_bc_log, label=r'$\lambda_{bc}$')
        ax.semilogy(self.adpative_constant_res_log, label=r'$\lambda_{res}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\lambda$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'lambda_history.png')
        plt.savefig(path)
        plt.close("all" , )





    def plot_grad(self ):

        fig, ax = plt.subplots()
        fig.set_size_inches([15,8])
        ax.semilogy(self.mean_grad_bcs_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{bc}}}$')
        ax.semilogy(self.mean_grad_res_log, label=r'$\bar{\nabla_\theta \mathcal{L}_{u_{res}}}$')
        ax.set_xlabel("epochs", fontsize=15)
        ax.set_ylabel(r'$\bar{\nabla_{\theta} \mathcal{L}}$', fontsize=15)
        ax.tick_params(labelsize=15)
        ax.legend()
        path = os.path.join(self.dirname,'grad_history.png')
        plt.savefig(path)
        plt.close("all" , )

# %%
#test_method(mtd , layers, operator, ics_sampler, bcs_sampler , res_sampler ,lam , mode , stiff_ratio , X_star ,u_star , f_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size)

def test_method(method , layers, operator, ics_sampler, bcs_sampler, res_sampler, lam ,mode , stiff_ratio ,  X_star , u_star , f_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size):


    model = Helmholtz2D(layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, mode, stiff_ratio)

    # Train model
    start_time = time.time()

    if method =="full_batch":
        model.train(nIter  ,bcbatch_size , ubatch_size )
    elif method =="mini_batch":
        model.trainmb(nIter, batch_size=mbbatch_size)
    else:
        print("unknown method!")
    elapsed = time.time() - start_time


    # Predictions
    u_pred = model.predict_u(X_star)
    f_pred = model.predict_r(X_star)

    # Relative error
    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_f: {:.2e}'.format(error_f))

    return [elapsed, error_u , error_f ,  model]

# %%
################################################################################################


nIter =40001
bcbatch_size = 500
ubatch_size = 5000
mbbatch_size = 128

a_1 = 1
a_2 = 4

# Parameter
lam = 1.0

# Domain boundaries
bc1_coords = np.array([[-1.0, -1.0], [1.0, -1.0]])
bc2_coords = np.array([[1.0, -1.0], [1.0, 1.0]])
bc3_coords = np.array([[1.0, 1.0], [-1.0, 1.0]])
bc4_coords = np.array([[-1.0, 1.0], [-1.0, -1.0]])

dom_coords = np.array([[-1.0, -1.0], [1.0, 1.0]])


# Train model

# Test data
nn = 100
x1 = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x2 = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
x1, x2 = np.meshgrid(x1, x2)
X_star = np.hstack((x1.flatten()[:, None], x2.flatten()[:, None]))




# Exact solution
u_star = u(X_star, a_1, a_2)
f_star = f(X_star, a_1, a_2, lam)

# Create initial conditions samplers
ics_sampler = None

# Define model
mode = 'relobralo'            # Method: 'M1', 'M2', 'M3', 'M4'
stiff_ratio = False    # Log the eigenvalues of Hessian of losses

layers = [2, 50, 50, 50, 1]


iterations = 1
methods = ["full_batch"]

result_dict =  dict((mtd, []) for mtd in methods)

for mtd in methods:
    print("Method: ", mtd)
    time_list = []
    error_u_list = []
    error_f_list = []
    
    for index in range(iterations):

        print("Epoch: ", str(index+1))


        # Create boundary conditions samplers
        bc1 = Sampler(2, bc1_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC1')
        bc2 = Sampler(2, bc2_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC2')
        bc3 = Sampler(2, bc3_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC3')
        bc4 = Sampler(2, bc4_coords, lambda x: u(x, a_1, a_2), name='Dirichlet BC4')
        bcs_sampler = [bc1, bc2, bc3, bc4]

        # Create residual sampler
        res_sampler = Sampler(2, dom_coords, lambda x: f(x, a_1, a_2, lam), name='Forcing')

        # [elapsed, error_u , error_f ,  mode] = test_method(mtd , layers, operator, ics_sampler, bcs_sampler , res_sampler ,lam , mode , 
        #                                                                stiff_ratio , X_star ,u_star , f_star , nIter ,bcbatch_size , bcbatch_size , ubatch_size)

#test_method(mtd , layers, operator, ics_sampler, bcs_sampler , res_sampler ,lam , mode , stiff_ratio , X_star ,u_star , f_star , nIter ,mbbatch_size , bcbatch_size , ubatch_size)


        tf.reset_default_graph()
        gpu_options = tf.GPUOptions(visible_device_list="0")
        with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options,allow_soft_placement=False, log_device_placement=False)) as sess:
            model = Helmholtz2D(layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, mode, sess)
 #def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, lam, mode, sess)
            # Train model
            start_time = time.time()

            if mtd =="full_batch":
                model.train(  bcbatch_size , ubatch_size , nIter )
            elif mtd =="mini_batch":
                model.trainmb( mbbatch_size  , nIter)
            else:
                model.print("unknown method!")
            elapsed = time.time() - start_time


            # Predictions
            u_pred = model.predict_u(X_star)
            f_pred = model.predict_r(X_star)

            # Relative error
            error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
            error_f = np.linalg.norm(f_star - f_pred, 2) / np.linalg.norm(f_star, 2)

            model.print('Relative L2 error_u: {:.2e}'.format(error_u))
            model.print('Relative L2 error_f: {:.2e}'.format(error_f))

            model.plot_lambda()
            model.plot_grad()
            model.save_NN()
            model.plt_prediction( x1 , x2 , X_star , u_star , u_pred , f_star , f_pred)

            model.print("average adpative_constant_bc_log : " , np.average(model.adpative_constant_bc_log))
            model.print("average adpative_constant_res_log : " ,  np.average(model.adpative_constant_res_log))
            # sess.close()  

            time_list.append(elapsed)
            error_u_list.append(error_u)
            error_f_list.append(error_f)

    model.print("\n\nMethod: ", mtd)
    model.print("\naverage of time_list:" , sum(time_list) / len(time_list) )
    model.print("average of error_u_list:" , sum(error_u_list) / len(error_u_list) )
    model.print("average of error_v_list:" , sum(error_f_list) / len(error_f_list) )

    result_dict[mtd] = [time_list ,error_u_list ,error_f_list ]
    # scipy.io.savemat("M2_result_"+str(iterations)+"_"+mtd+".mat" , {'time_list':np.array(time_list),'error_u_list':np.array(error_u_list),'error_f_list':np.array(error_f_list)})

    scipy.io.savemat(os.path.join(model.dirname,""+mtd+"_Helmholtz_"+mode+"_result_mb"+str(mbbatch_size)+"_fb"+str(ubatch_size)+"_bc"+str(mbbatch_size)+"_exp"+str(bcbatch_size)+"nIter"+str(nIter)+".mat") , result_dict)
# Out:
# Method:  full_batch
# Epoch:  1
# WARNING:tensorflow:From /tmp/ipykernel_6468/1813897754.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6468/1813897754.py:83: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6468/1813897754.py:84: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6468/1813897754.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2023-12-17 23:29:45.204495: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-17 23:29:45.235358: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2023-12-17 23:29:45.235833: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56343fd008c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-17 23:29:45.235845: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-17 23:29:45.237464: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /tmp/ipykernel_6468/2492806593.py:264: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6468/2492806593.py:123: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6468/2492806593.py:176: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6468/2492806593.py:178: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tmp/ipykernel_6468/2492806593.py:235: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 100, Loss: 6.747e+03, Loss_bcs: 2.069e+01, Loss_res: 6.727e+03,Time: 0.02
# adaptive_constant_res_val: 0.250000
# adaptive_constant_bc_val: 1.750000
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 200, Loss: 2.296e+03, Loss_bcs: 1.449e+01, Loss_res: 2.282e+03,Time: 0.02
# adaptive_constant_res_val: 0.464940
# adaptive_constant_bc_val: 1.535060
# It: 300, Loss: 6.764e+02, Loss_bcs: 2.239e+01, Loss_res: 6.540e+02,Time: 0.02
# adaptive_constant_res_val: 0.314777
# adaptive_constant_bc_val: 1.685223
# It: 400, Loss: 1.467e+02, Loss_bcs: 2.352e+01, Loss_res: 1.231e+02,Time: 0.03
# adaptive_constant_res_val: 0.357385
# adaptive_constant_bc_val: 1.642615
# It: 500, Loss: 5.644e+01, Loss_bcs: 1.781e+01, Loss_res: 3.863e+01,Time: 0.03
# adaptive_constant_res_val: 0.468455
# adaptive_constant_bc_val: 1.531545
# It: 600, Loss: 3.336e+01, Loss_bcs: 1.257e+01, Loss_res: 2.078e+01,Time: 0.02
# adaptive_constant_res_val: 0.570746
# adaptive_constant_bc_val: 1.429254
# It: 700, Loss: 2.418e+01, Loss_bcs: 1.003e+01, Loss_res: 1.415e+01,Time: 0.02
# adaptive_constant_res_val: 0.609697
# adaptive_constant_bc_val: 1.390303
# It: 800, Loss: 1.802e+01, Loss_bcs: 8.156e+00, Loss_res: 9.864e+00,Time: 0.02
# adaptive_constant_res_val: 0.620526
# adaptive_constant_bc_val: 1.379474
# It: 900, Loss: 1.352e+01, Loss_bcs: 6.441e+00, Loss_res: 7.076e+00,Time: 0.02
# adaptive_constant_res_val: 0.635200
# adaptive_constant_bc_val: 1.364800
# It: 1000, Loss: 1.011e+01, Loss_bcs: 4.899e+00, Loss_res: 5.211e+00,Time: 0.02
# adaptive_constant_res_val: 0.651908
# adaptive_constant_bc_val: 1.348092
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 1100, Loss: 7.782e+00, Loss_bcs: 3.767e+00, Loss_res: 4.015e+00,Time: 0.02
# adaptive_constant_res_val: 0.663202
# adaptive_constant_bc_val: 1.336798
# It: 1200, Loss: 6.093e+00, Loss_bcs: 2.909e+00, Loss_res: 3.185e+00,Time: 0.02
# adaptive_constant_res_val: 0.671402
# adaptive_constant_bc_val: 1.328598
# It: 1300, Loss: 4.906e+00, Loss_bcs: 2.244e+00, Loss_res: 2.662e+00,Time: 0.02
# adaptive_constant_res_val: 0.682392
# adaptive_constant_bc_val: 1.317608
# It: 1400, Loss: 3.903e+00, Loss_bcs: 1.746e+00, Loss_res: 2.157e+00,Time: 0.02
# adaptive_constant_res_val: 0.679391
# adaptive_constant_bc_val: 1.320609
# It: 1500, Loss: 3.200e+00, Loss_bcs: 1.363e+00, Loss_res: 1.837e+00,Time: 0.02
# adaptive_constant_res_val: 0.690440
# adaptive_constant_bc_val: 1.309560
# It: 1600, Loss: 2.669e+00, Loss_bcs: 1.075e+00, Loss_res: 1.595e+00,Time: 0.03
# adaptive_constant_res_val: 0.693910
# adaptive_constant_bc_val: 1.306090
# It: 1700, Loss: 2.327e+00, Loss_bcs: 8.629e-01, Loss_res: 1.464e+00,Time: 0.02
# adaptive_constant_res_val: 0.700952
# adaptive_constant_bc_val: 1.299048
# It: 1800, Loss: 1.953e+00, Loss_bcs: 7.115e-01, Loss_res: 1.242e+00,Time: 0.02
# adaptive_constant_res_val: 0.683038
# adaptive_constant_bc_val: 1.316962
# It: 1900, Loss: 1.718e+00, Loss_bcs: 6.012e-01, Loss_res: 1.117e+00,Time: 0.02
# adaptive_constant_res_val: 0.690052
# adaptive_constant_bc_val: 1.309948
# It: 2000, Loss: 1.534e+00, Loss_bcs: 5.218e-01, Loss_res: 1.013e+00,Time: 0.02
# adaptive_constant_res_val: 0.689826
# adaptive_constant_bc_val: 1.310174
# It: 2100, Loss: 1.456e+00, Loss_bcs: 4.629e-01, Loss_res: 9.935e-01,Time: 0.02
# adaptive_constant_res_val: 0.706644
# adaptive_constant_bc_val: 1.293356
# It: 2200, Loss: 1.279e+00, Loss_bcs: 4.210e-01, Loss_res: 8.577e-01,Time: 0.02
# adaptive_constant_res_val: 0.679355
# adaptive_constant_bc_val: 1.320645
# It: 2300, Loss: 1.182e+00, Loss_bcs: 3.872e-01, Loss_res: 7.948e-01,Time: 0.02
# adaptive_constant_res_val: 0.689663
# adaptive_constant_bc_val: 1.310337
# It: 2400, Loss: 1.120e+00, Loss_bcs: 3.620e-01, Loss_res: 7.583e-01,Time: 0.02
# adaptive_constant_res_val: 0.698726
# adaptive_constant_bc_val: 1.301274
# It: 2500, Loss: 1.028e+00, Loss_bcs: 3.415e-01, Loss_res: 6.866e-01,Time: 0.03
# adaptive_constant_res_val: 0.691266
# adaptive_constant_bc_val: 1.308734
# It: 2600, Loss: 9.786e-01, Loss_bcs: 3.248e-01, Loss_res: 6.539e-01,Time: 0.03
# adaptive_constant_res_val: 0.708212
# adaptive_constant_bc_val: 1.291788
# It: 2700, Loss: 9.792e-01, Loss_bcs: 3.131e-01, Loss_res: 6.661e-01,Time: 0.02
# adaptive_constant_res_val: 0.732246
# adaptive_constant_bc_val: 1.267754
# It: 2800, Loss: 8.840e-01, Loss_bcs: 2.985e-01, Loss_res: 5.855e-01,Time: 0.02
# adaptive_constant_res_val: 0.698551
# adaptive_constant_bc_val: 1.301449
# It: 2900, Loss: 8.333e-01, Loss_bcs: 2.892e-01, Loss_res: 5.441e-01,Time: 0.02
# adaptive_constant_res_val: 0.709115
# adaptive_constant_bc_val: 1.290885
# It: 3000, Loss: 9.628e-01, Loss_bcs: 2.774e-01, Loss_res: 6.854e-01,Time: 0.02
# adaptive_constant_res_val: 0.771884
# adaptive_constant_bc_val: 1.228116
# It: 3100, Loss: 7.545e-01, Loss_bcs: 2.718e-01, Loss_res: 4.827e-01,Time: 0.02
# adaptive_constant_res_val: 0.664925
# adaptive_constant_bc_val: 1.335075
# It: 3200, Loss: 7.569e-01, Loss_bcs: 2.650e-01, Loss_res: 4.920e-01,Time: 0.02
# adaptive_constant_res_val: 0.746053
# adaptive_constant_bc_val: 1.253947
# It: 3300, Loss: 6.954e-01, Loss_bcs: 2.578e-01, Loss_res: 4.376e-01,Time: 0.02
# adaptive_constant_res_val: 0.716424
# adaptive_constant_bc_val: 1.283576
# It: 3400, Loss: 6.717e-01, Loss_bcs: 2.519e-01, Loss_res: 4.198e-01,Time: 0.02
# adaptive_constant_res_val: 0.730411
# adaptive_constant_bc_val: 1.269589
# It: 3500, Loss: 6.670e-01, Loss_bcs: 2.460e-01, Loss_res: 4.211e-01,Time: 0.03
# adaptive_constant_res_val: 0.757530
# adaptive_constant_bc_val: 1.242470
# It: 3600, Loss: 6.235e-01, Loss_bcs: 2.405e-01, Loss_res: 3.830e-01,Time: 0.03
# adaptive_constant_res_val: 0.730638
# adaptive_constant_bc_val: 1.269362
# It: 3700, Loss: 6.010e-01, Loss_bcs: 2.353e-01, Loss_res: 3.657e-01,Time: 0.02
# adaptive_constant_res_val: 0.738821
# adaptive_constant_bc_val: 1.261179
# It: 3800, Loss: 7.901e-01, Loss_bcs: 2.319e-01, Loss_res: 5.582e-01,Time: 0.03
# adaptive_constant_res_val: 0.849259
# adaptive_constant_bc_val: 1.150741
# It: 3900, Loss: 5.617e-01, Loss_bcs: 2.254e-01, Loss_res: 3.363e-01,Time: 0.02
# adaptive_constant_res_val: 0.678240
# adaptive_constant_bc_val: 1.321760
# It: 4000, Loss: 5.474e-01, Loss_bcs: 2.210e-01, Loss_res: 3.264e-01,Time: 0.02
# adaptive_constant_res_val: 0.736252
# adaptive_constant_bc_val: 1.263748
# It: 4100, Loss: 5.457e-01, Loss_bcs: 2.158e-01, Loss_res: 3.299e-01,Time: 0.02
# adaptive_constant_res_val: 0.768273
# adaptive_constant_bc_val: 1.231727
# It: 4200, Loss: 6.503e-01, Loss_bcs: 2.121e-01, Loss_res: 4.382e-01,Time: 0.02
# adaptive_constant_res_val: 0.859943
# adaptive_constant_bc_val: 1.140057
# It: 4300, Loss: 4.987e-01, Loss_bcs: 2.072e-01, Loss_res: 2.915e-01,Time: 0.02
# adaptive_constant_res_val: 0.704776
# adaptive_constant_bc_val: 1.295224
# It: 4400, Loss: 5.051e-01, Loss_bcs: 2.025e-01, Loss_res: 3.026e-01,Time: 0.02
# adaptive_constant_res_val: 0.764062
# adaptive_constant_bc_val: 1.235938
# It: 4500, Loss: 5.379e-01, Loss_bcs: 1.982e-01, Loss_res: 3.397e-01,Time: 0.02
# adaptive_constant_res_val: 0.808413
# adaptive_constant_bc_val: 1.191587
# It: 4600, Loss: 4.630e-01, Loss_bcs: 1.944e-01, Loss_res: 2.686e-01,Time: 0.02
# adaptive_constant_res_val: 0.732754
# adaptive_constant_bc_val: 1.267246
# It: 4700, Loss: 6.997e-01, Loss_bcs: 1.906e-01, Loss_res: 5.091e-01,Time: 0.02
# adaptive_constant_res_val: 0.976390
# adaptive_constant_bc_val: 1.023610
# It: 4800, Loss: 8.184e-01, Loss_bcs: 1.846e-01, Loss_res: 6.338e-01,Time: 0.02
# adaptive_constant_res_val: 0.915133
# adaptive_constant_bc_val: 1.084867
# It: 4900, Loss: 4.187e-01, Loss_bcs: 1.823e-01, Loss_res: 2.364e-01,Time: 0.02
# adaptive_constant_res_val: 0.655041
# adaptive_constant_bc_val: 1.344959
# It: 5000, Loss: 4.044e-01, Loss_bcs: 1.783e-01, Loss_res: 2.260e-01,Time: 0.02
# adaptive_constant_res_val: 0.750658
# adaptive_constant_bc_val: 1.249342
# It: 5100, Loss: 4.656e-01, Loss_bcs: 1.753e-01, Loss_res: 2.902e-01,Time: 0.02
# adaptive_constant_res_val: 0.877881
# adaptive_constant_bc_val: 1.122119
# It: 5200, Loss: 4.070e-01, Loss_bcs: 1.706e-01, Loss_res: 2.364e-01,Time: 0.02
# adaptive_constant_res_val: 0.766162
# adaptive_constant_bc_val: 1.233838
# It: 5300, Loss: 3.756e-01, Loss_bcs: 1.671e-01, Loss_res: 2.085e-01,Time: 0.02
# adaptive_constant_res_val: 0.765108
# adaptive_constant_bc_val: 1.234892
# It: 5400, Loss: 3.717e-01, Loss_bcs: 1.637e-01, Loss_res: 2.080e-01,Time: 0.02
# adaptive_constant_res_val: 0.796252
# adaptive_constant_bc_val: 1.203748
# It: 5500, Loss: 5.113e-01, Loss_bcs: 1.593e-01, Loss_res: 3.520e-01,Time: 0.02
# adaptive_constant_res_val: 1.066485
# adaptive_constant_bc_val: 0.933515
# It: 5600, Loss: 3.598e-01, Loss_bcs: 1.570e-01, Loss_res: 2.028e-01,Time: 0.02
# adaptive_constant_res_val: 0.760291
# adaptive_constant_bc_val: 1.239709
# It: 5700, Loss: 3.368e-01, Loss_bcs: 1.534e-01, Loss_res: 1.833e-01,Time: 0.03
# adaptive_constant_res_val: 0.779483
# adaptive_constant_bc_val: 1.220517
# It: 5800, Loss: 3.292e-01, Loss_bcs: 1.503e-01, Loss_res: 1.790e-01,Time: 0.02
# adaptive_constant_res_val: 0.806473
# adaptive_constant_bc_val: 1.193527
# It: 5900, Loss: 3.232e-01, Loss_bcs: 1.471e-01, Loss_res: 1.761e-01,Time: 0.02
# adaptive_constant_res_val: 0.817251
# adaptive_constant_bc_val: 1.182749
# It: 6000, Loss: 4.873e-01, Loss_bcs: 1.438e-01, Loss_res: 3.435e-01,Time: 0.02
# adaptive_constant_res_val: 1.100649
# adaptive_constant_bc_val: 0.899351
# It: 6100, Loss: 3.089e-01, Loss_bcs: 1.410e-01, Loss_res: 1.679e-01,Time: 0.03
# adaptive_constant_res_val: 0.761117
# adaptive_constant_bc_val: 1.238883
# It: 6200, Loss: 3.674e-01, Loss_bcs: 1.383e-01, Loss_res: 2.291e-01,Time: 0.03
# adaptive_constant_res_val: 0.913615
# adaptive_constant_bc_val: 1.086385
# It: 6300, Loss: 2.938e-01, Loss_bcs: 1.350e-01, Loss_res: 1.589e-01,Time: 0.03
# adaptive_constant_res_val: 0.773768
# adaptive_constant_bc_val: 1.226232
# It: 6400, Loss: 3.076e-01, Loss_bcs: 1.324e-01, Loss_res: 1.752e-01,Time: 0.03
# adaptive_constant_res_val: 0.850238
# adaptive_constant_bc_val: 1.149762
# It: 6500, Loss: 2.785e-01, Loss_bcs: 1.293e-01, Loss_res: 1.492e-01,Time: 0.02
# adaptive_constant_res_val: 0.804566
# adaptive_constant_bc_val: 1.195434
# It: 6600, Loss: 2.709e-01, Loss_bcs: 1.267e-01, Loss_res: 1.442e-01,Time: 0.02
# adaptive_constant_res_val: 0.827394
# adaptive_constant_bc_val: 1.172606
# It: 6700, Loss: 2.742e-01, Loss_bcs: 1.240e-01, Loss_res: 1.502e-01,Time: 0.03
# adaptive_constant_res_val: 0.853179
# adaptive_constant_bc_val: 1.146821
# It: 6800, Loss: 2.586e-01, Loss_bcs: 1.215e-01, Loss_res: 1.371e-01,Time: 0.02
# adaptive_constant_res_val: 0.828903
# adaptive_constant_bc_val: 1.171097
# It: 6900, Loss: 2.608e-01, Loss_bcs: 1.188e-01, Loss_res: 1.419e-01,Time: 0.02
# adaptive_constant_res_val: 0.853112
# adaptive_constant_bc_val: 1.146888
# It: 7000, Loss: 2.491e-01, Loss_bcs: 1.165e-01, Loss_res: 1.325e-01,Time: 0.02
# adaptive_constant_res_val: 0.837120
# adaptive_constant_bc_val: 1.162880
# It: 7100, Loss: 3.296e-01, Loss_bcs: 1.136e-01, Loss_res: 2.160e-01,Time: 0.02
# adaptive_constant_res_val: 1.001518
# adaptive_constant_bc_val: 0.998482
# It: 7200, Loss: 2.515e-01, Loss_bcs: 1.119e-01, Loss_res: 1.396e-01,Time: 0.03
# adaptive_constant_res_val: 0.810877
# adaptive_constant_bc_val: 1.189123
# It: 7300, Loss: 2.402e-01, Loss_bcs: 1.096e-01, Loss_res: 1.306e-01,Time: 0.02
# adaptive_constant_res_val: 0.838201
# adaptive_constant_bc_val: 1.161799
# It: 7400, Loss: 2.270e-01, Loss_bcs: 1.073e-01, Loss_res: 1.196e-01,Time: 0.03
# adaptive_constant_res_val: 0.838896
# adaptive_constant_bc_val: 1.161104
# It: 7500, Loss: 2.221e-01, Loss_bcs: 1.051e-01, Loss_res: 1.170e-01,Time: 0.03
# adaptive_constant_res_val: 0.857510
# adaptive_constant_bc_val: 1.142490
# It: 7600, Loss: 2.403e-01, Loss_bcs: 1.027e-01, Loss_res: 1.376e-01,Time: 0.02
# adaptive_constant_res_val: 0.904638
# adaptive_constant_bc_val: 1.095362
# It: 7700, Loss: 2.172e-01, Loss_bcs: 1.007e-01, Loss_res: 1.165e-01,Time: 0.02
# adaptive_constant_res_val: 0.839299
# adaptive_constant_bc_val: 1.160701
# It: 7800, Loss: 2.080e-01, Loss_bcs: 9.873e-02, Loss_res: 1.092e-01,Time: 0.02
# adaptive_constant_res_val: 0.850834
# adaptive_constant_bc_val: 1.149166
# It: 7900, Loss: 2.035e-01, Loss_bcs: 9.668e-02, Loss_res: 1.068e-01,Time: 0.02
# adaptive_constant_res_val: 0.874267
# adaptive_constant_bc_val: 1.125733
# It: 8000, Loss: 2.877e-01, Loss_bcs: 9.532e-02, Loss_res: 1.924e-01,Time: 0.02
# adaptive_constant_res_val: 1.149725
# adaptive_constant_bc_val: 0.850275
# It: 8100, Loss: 2.021e-01, Loss_bcs: 9.272e-02, Loss_res: 1.094e-01,Time: 0.02
# adaptive_constant_res_val: 0.828542
# adaptive_constant_bc_val: 1.171458
# It: 8200, Loss: 1.913e-01, Loss_bcs: 9.101e-02, Loss_res: 1.003e-01,Time: 0.02
# adaptive_constant_res_val: 0.848800
# adaptive_constant_bc_val: 1.151200
# It: 8300, Loss: 1.868e-01, Loss_bcs: 8.916e-02, Loss_res: 9.759e-02,Time: 0.02
# adaptive_constant_res_val: 0.871975
# adaptive_constant_bc_val: 1.128025
# It: 8400, Loss: 1.960e-01, Loss_bcs: 8.770e-02, Loss_res: 1.083e-01,Time: 0.02
# adaptive_constant_res_val: 0.960591
# adaptive_constant_bc_val: 1.039409
# It: 8500, Loss: 1.946e-01, Loss_bcs: 8.591e-02, Loss_res: 1.087e-01,Time: 0.02
# adaptive_constant_res_val: 0.887783
# adaptive_constant_bc_val: 1.112217
# It: 8600, Loss: 2.286e-01, Loss_bcs: 8.359e-02, Loss_res: 1.450e-01,Time: 0.02
# adaptive_constant_res_val: 0.984363
# adaptive_constant_bc_val: 1.015637
# It: 8700, Loss: 2.208e-01, Loss_bcs: 8.281e-02, Loss_res: 1.380e-01,Time: 0.02
# adaptive_constant_res_val: 0.877466
# adaptive_constant_bc_val: 1.122534
# It: 8800, Loss: 1.706e-01, Loss_bcs: 8.071e-02, Loss_res: 8.986e-02,Time: 0.02
# adaptive_constant_res_val: 0.801730
# adaptive_constant_bc_val: 1.198270
# It: 8900, Loss: 1.672e-01, Loss_bcs: 7.906e-02, Loss_res: 8.816e-02,Time: 0.02
# adaptive_constant_res_val: 0.874457
# adaptive_constant_bc_val: 1.125543
# It: 9000, Loss: 1.641e-01, Loss_bcs: 7.756e-02, Loss_res: 8.658e-02,Time: 0.02
# adaptive_constant_res_val: 0.894943
# adaptive_constant_bc_val: 1.105057
# It: 9100, Loss: 1.592e-01, Loss_bcs: 7.600e-02, Loss_res: 8.318e-02,Time: 0.02
# adaptive_constant_res_val: 0.892219
# adaptive_constant_bc_val: 1.107781
# It: 9200, Loss: 1.567e-01, Loss_bcs: 7.455e-02, Loss_res: 8.212e-02,Time: 0.02
# adaptive_constant_res_val: 0.900211
# adaptive_constant_bc_val: 1.099789
# It: 9300, Loss: 1.565e-01, Loss_bcs: 7.301e-02, Loss_res: 8.353e-02,Time: 0.02
# adaptive_constant_res_val: 0.908621
# adaptive_constant_bc_val: 1.091379
# It: 9400, Loss: 1.918e-01, Loss_bcs: 7.168e-02, Loss_res: 1.202e-01,Time: 0.02
# adaptive_constant_res_val: 1.078860
# adaptive_constant_bc_val: 0.921140
# It: 9500, Loss: 1.497e-01, Loss_bcs: 7.027e-02, Loss_res: 7.939e-02,Time: 0.02
# adaptive_constant_res_val: 0.861123
# adaptive_constant_bc_val: 1.138877
# It: 9600, Loss: 1.601e-01, Loss_bcs: 6.896e-02, Loss_res: 9.116e-02,Time: 0.02
# adaptive_constant_res_val: 0.957461
# adaptive_constant_bc_val: 1.042539
# It: 9700, Loss: 1.428e-01, Loss_bcs: 6.771e-02, Loss_res: 7.508e-02,Time: 0.02
# adaptive_constant_res_val: 0.877516
# adaptive_constant_bc_val: 1.122484
# It: 9800, Loss: 1.430e-01, Loss_bcs: 6.655e-02, Loss_res: 7.641e-02,Time: 0.03
# adaptive_constant_res_val: 0.926488
# adaptive_constant_bc_val: 1.073512
# It: 9900, Loss: 1.422e-01, Loss_bcs: 6.530e-02, Loss_res: 7.693e-02,Time: 0.03
# adaptive_constant_res_val: 0.932417
# adaptive_constant_bc_val: 1.067583
# It: 10000, Loss: 1.357e-01, Loss_bcs: 6.394e-02, Loss_res: 7.177e-02,Time: 0.02
# adaptive_constant_res_val: 0.905182
# adaptive_constant_bc_val: 1.094818
# It: 10100, Loss: 1.684e-01, Loss_bcs: 6.282e-02, Loss_res: 1.055e-01,Time: 0.03
# adaptive_constant_res_val: 1.078742
# adaptive_constant_bc_val: 0.921258
# It: 10200, Loss: 1.371e-01, Loss_bcs: 6.169e-02, Loss_res: 7.543e-02,Time: 0.02
# adaptive_constant_res_val: 0.884851
# adaptive_constant_bc_val: 1.115149
# It: 10300, Loss: 1.293e-01, Loss_bcs: 6.052e-02, Loss_res: 6.878e-02,Time: 0.02
# adaptive_constant_res_val: 0.893491
# adaptive_constant_bc_val: 1.106509
# It: 10400, Loss: 1.258e-01, Loss_bcs: 5.948e-02, Loss_res: 6.636e-02,Time: 0.02
# adaptive_constant_res_val: 0.908233
# adaptive_constant_bc_val: 1.091767
# It: 10500, Loss: 1.661e-01, Loss_bcs: 5.875e-02, Loss_res: 1.073e-01,Time: 0.02
# adaptive_constant_res_val: 1.069448
# adaptive_constant_bc_val: 0.930552
# It: 10600, Loss: 1.357e-01, Loss_bcs: 5.722e-02, Loss_res: 7.844e-02,Time: 0.02
# adaptive_constant_res_val: 0.924505
# adaptive_constant_bc_val: 1.075495
# It: 10700, Loss: 1.695e-01, Loss_bcs: 5.614e-02, Loss_res: 1.134e-01,Time: 0.02
# adaptive_constant_res_val: 1.002947
# adaptive_constant_bc_val: 0.997053
# It: 10800, Loss: 1.173e-01, Loss_bcs: 5.545e-02, Loss_res: 6.189e-02,Time: 0.02
# adaptive_constant_res_val: 0.823904
# adaptive_constant_bc_val: 1.176096
# It: 10900, Loss: 1.158e-01, Loss_bcs: 5.453e-02, Loss_res: 6.128e-02,Time: 0.02
# adaptive_constant_res_val: 0.902130
# adaptive_constant_bc_val: 1.097870
# It: 11000, Loss: 1.160e-01, Loss_bcs: 5.356e-02, Loss_res: 6.240e-02,Time: 0.02
# adaptive_constant_res_val: 0.929195
# adaptive_constant_bc_val: 1.070805
# It: 11100, Loss: 1.941e-01, Loss_bcs: 5.276e-02, Loss_res: 1.414e-01,Time: 0.03
# adaptive_constant_res_val: 1.203826
# adaptive_constant_bc_val: 0.796174
# It: 11200, Loss: 1.182e-01, Loss_bcs: 5.196e-02, Loss_res: 6.625e-02,Time: 0.02
# adaptive_constant_res_val: 0.865045
# adaptive_constant_bc_val: 1.134955
# It: 11300, Loss: 1.089e-01, Loss_bcs: 5.106e-02, Loss_res: 5.789e-02,Time: 0.02
# adaptive_constant_res_val: 0.884617
# adaptive_constant_bc_val: 1.115383
# It: 11400, Loss: 1.069e-01, Loss_bcs: 5.025e-02, Loss_res: 5.665e-02,Time: 0.02
# adaptive_constant_res_val: 0.919169
# adaptive_constant_bc_val: 1.080831
# It: 11500, Loss: 1.059e-01, Loss_bcs: 4.938e-02, Loss_res: 5.655e-02,Time: 0.02
# adaptive_constant_res_val: 0.932066
# adaptive_constant_bc_val: 1.067934
# It: 11600, Loss: 1.040e-01, Loss_bcs: 4.863e-02, Loss_res: 5.535e-02,Time: 0.02
# adaptive_constant_res_val: 0.930429
# adaptive_constant_bc_val: 1.069571
# It: 11700, Loss: 1.020e-01, Loss_bcs: 4.793e-02, Loss_res: 5.404e-02,Time: 0.02
# adaptive_constant_res_val: 0.931419
# adaptive_constant_bc_val: 1.068581
# It: 11800, Loss: 1.009e-01, Loss_bcs: 4.722e-02, Loss_res: 5.369e-02,Time: 0.02
# adaptive_constant_res_val: 0.936482
# adaptive_constant_bc_val: 1.063518
# It: 11900, Loss: 9.947e-02, Loss_bcs: 4.649e-02, Loss_res: 5.298e-02,Time: 0.02
# adaptive_constant_res_val: 0.937111
# adaptive_constant_bc_val: 1.062889
# It: 12000, Loss: 9.821e-02, Loss_bcs: 4.584e-02, Loss_res: 5.237e-02,Time: 0.02
# adaptive_constant_res_val: 0.938819
# adaptive_constant_bc_val: 1.061181
# It: 12100, Loss: 9.709e-02, Loss_bcs: 4.510e-02, Loss_res: 5.199e-02,Time: 0.02
# adaptive_constant_res_val: 0.939625
# adaptive_constant_bc_val: 1.060375
# It: 12200, Loss: 9.568e-02, Loss_bcs: 4.451e-02, Loss_res: 5.118e-02,Time: 0.02
# adaptive_constant_res_val: 0.939522
# adaptive_constant_bc_val: 1.060478
# It: 12300, Loss: 9.414e-02, Loss_bcs: 4.388e-02, Loss_res: 5.026e-02,Time: 0.02
# adaptive_constant_res_val: 0.939573
# adaptive_constant_bc_val: 1.060427
# It: 12400, Loss: 1.058e-01, Loss_bcs: 4.311e-02, Loss_res: 6.266e-02,Time: 0.03
# adaptive_constant_res_val: 1.040667
# adaptive_constant_bc_val: 0.959333
# It: 12500, Loss: 9.275e-02, Loss_bcs: 4.257e-02, Loss_res: 5.019e-02,Time: 0.02
# adaptive_constant_res_val: 0.915577
# adaptive_constant_bc_val: 1.084423
# It: 12600, Loss: 9.922e-02, Loss_bcs: 4.194e-02, Loss_res: 5.728e-02,Time: 0.02
# adaptive_constant_res_val: 0.966815
# adaptive_constant_bc_val: 1.033185
# It: 12700, Loss: 1.571e-01, Loss_bcs: 4.171e-02, Loss_res: 1.154e-01,Time: 0.02
# adaptive_constant_res_val: 1.211549
# adaptive_constant_bc_val: 0.788451
# It: 12800, Loss: 8.928e-02, Loss_bcs: 4.092e-02, Loss_res: 4.836e-02,Time: 0.02
# adaptive_constant_res_val: 0.859908
# adaptive_constant_bc_val: 1.140092
# It: 12900, Loss: 1.001e-01, Loss_bcs: 4.013e-02, Loss_res: 5.995e-02,Time: 0.02
# adaptive_constant_res_val: 0.985938
# adaptive_constant_bc_val: 1.014062
# It: 13000, Loss: 8.694e-02, Loss_bcs: 3.973e-02, Loss_res: 4.721e-02,Time: 0.02
# adaptive_constant_res_val: 0.899945
# adaptive_constant_bc_val: 1.100055
# It: 13100, Loss: 8.523e-02, Loss_bcs: 3.928e-02, Loss_res: 4.595e-02,Time: 0.02
# adaptive_constant_res_val: 0.930800
# adaptive_constant_bc_val: 1.069200
# It: 13200, Loss: 1.046e-01, Loss_bcs: 3.887e-02, Loss_res: 6.569e-02,Time: 0.02
# adaptive_constant_res_val: 1.105705
# adaptive_constant_bc_val: 0.894295
# It: 13300, Loss: 9.832e-02, Loss_bcs: 3.841e-02, Loss_res: 5.990e-02,Time: 0.02
# adaptive_constant_res_val: 0.976448
# adaptive_constant_bc_val: 1.023552
# It: 13400, Loss: 8.231e-02, Loss_bcs: 3.777e-02, Loss_res: 4.455e-02,Time: 0.02
# adaptive_constant_res_val: 0.890118
# adaptive_constant_bc_val: 1.109882
# It: 13500, Loss: 8.062e-02, Loss_bcs: 3.723e-02, Loss_res: 4.339e-02,Time: 0.02
# adaptive_constant_res_val: 0.930570
# adaptive_constant_bc_val: 1.069430
# It: 13600, Loss: 7.921e-02, Loss_bcs: 3.677e-02, Loss_res: 4.244e-02,Time: 0.02
# adaptive_constant_res_val: 0.941762
# adaptive_constant_bc_val: 1.058238
# It: 13700, Loss: 7.812e-02, Loss_bcs: 3.632e-02, Loss_res: 4.180e-02,Time: 0.02
# adaptive_constant_res_val: 0.947186
# adaptive_constant_bc_val: 1.052814
# It: 13800, Loss: 7.733e-02, Loss_bcs: 3.589e-02, Loss_res: 4.144e-02,Time: 0.02
# adaptive_constant_res_val: 0.952534
# adaptive_constant_bc_val: 1.047466
# It: 13900, Loss: 7.679e-02, Loss_bcs: 3.545e-02, Loss_res: 4.134e-02,Time: 0.02
# adaptive_constant_res_val: 0.954567
# adaptive_constant_bc_val: 1.045433
# It: 14000, Loss: 7.544e-02, Loss_bcs: 3.500e-02, Loss_res: 4.044e-02,Time: 0.03
# adaptive_constant_res_val: 0.949975
# adaptive_constant_bc_val: 1.050025
# It: 14100, Loss: 7.627e-02, Loss_bcs: 3.453e-02, Loss_res: 4.174e-02,Time: 0.02
# adaptive_constant_res_val: 0.961201
# adaptive_constant_bc_val: 1.038799
# It: 14200, Loss: 7.431e-02, Loss_bcs: 3.416e-02, Loss_res: 4.016e-02,Time: 0.02
# adaptive_constant_res_val: 0.948511
# adaptive_constant_bc_val: 1.051489
# It: 14300, Loss: 8.442e-02, Loss_bcs: 3.382e-02, Loss_res: 5.060e-02,Time: 0.03
# adaptive_constant_res_val: 1.006722
# adaptive_constant_bc_val: 0.993278
# It: 14400, Loss: 8.321e-02, Loss_bcs: 3.350e-02, Loss_res: 4.971e-02,Time: 0.03
# adaptive_constant_res_val: 0.952257
# adaptive_constant_bc_val: 1.047743
# It: 14500, Loss: 7.760e-02, Loss_bcs: 3.301e-02, Loss_res: 4.459e-02,Time: 0.03
# adaptive_constant_res_val: 0.942109
# adaptive_constant_bc_val: 1.057891
# It: 14600, Loss: 7.631e-02, Loss_bcs: 3.251e-02, Loss_res: 4.380e-02,Time: 0.02
# adaptive_constant_res_val: 0.967503
# adaptive_constant_bc_val: 1.032497
# It: 14700, Loss: 7.205e-02, Loss_bcs: 3.225e-02, Loss_res: 3.979e-02,Time: 0.02
# adaptive_constant_res_val: 0.946695
# adaptive_constant_bc_val: 1.053305
# It: 14800, Loss: 7.070e-02, Loss_bcs: 3.189e-02, Loss_res: 3.881e-02,Time: 0.03
# adaptive_constant_res_val: 0.945367
# adaptive_constant_bc_val: 1.054633
# It: 14900, Loss: 6.917e-02, Loss_bcs: 3.154e-02, Loss_res: 3.763e-02,Time: 0.02
# adaptive_constant_res_val: 0.954094
# adaptive_constant_bc_val: 1.045906
# It: 15000, Loss: 6.822e-02, Loss_bcs: 3.117e-02, Loss_res: 3.705e-02,Time: 0.02
# adaptive_constant_res_val: 0.958755
# adaptive_constant_bc_val: 1.041245
# It: 15100, Loss: 6.815e-02, Loss_bcs: 3.081e-02, Loss_res: 3.734e-02,Time: 0.02
# adaptive_constant_res_val: 0.959558
# adaptive_constant_bc_val: 1.040442
# It: 15200, Loss: 6.770e-02, Loss_bcs: 3.051e-02, Loss_res: 3.720e-02,Time: 0.02
# adaptive_constant_res_val: 0.962568
# adaptive_constant_bc_val: 1.037432
# It: 15300, Loss: 8.243e-02, Loss_bcs: 3.025e-02, Loss_res: 5.218e-02,Time: 0.03
# adaptive_constant_res_val: 1.194889
# adaptive_constant_bc_val: 0.805111
# It: 15400, Loss: 6.523e-02, Loss_bcs: 2.979e-02, Loss_res: 3.544e-02,Time: 0.02
# adaptive_constant_res_val: 0.932810
# adaptive_constant_bc_val: 1.067190
# It: 15500, Loss: 7.497e-02, Loss_bcs: 2.947e-02, Loss_res: 4.551e-02,Time: 0.02
# adaptive_constant_res_val: 1.061523
# adaptive_constant_bc_val: 0.938477
# It: 15600, Loss: 6.646e-02, Loss_bcs: 2.913e-02, Loss_res: 3.733e-02,Time: 0.02
# adaptive_constant_res_val: 0.941370
# adaptive_constant_bc_val: 1.058630
# It: 15700, Loss: 6.354e-02, Loss_bcs: 2.882e-02, Loss_res: 3.472e-02,Time: 0.02
# adaptive_constant_res_val: 0.941341
# adaptive_constant_bc_val: 1.058659
# It: 15800, Loss: 6.253e-02, Loss_bcs: 2.856e-02, Loss_res: 3.397e-02,Time: 0.02
# adaptive_constant_res_val: 0.952408
# adaptive_constant_bc_val: 1.047592
# It: 15900, Loss: 6.174e-02, Loss_bcs: 2.824e-02, Loss_res: 3.351e-02,Time: 0.02
# adaptive_constant_res_val: 0.961036
# adaptive_constant_bc_val: 1.038964
# It: 16000, Loss: 6.450e-02, Loss_bcs: 2.792e-02, Loss_res: 3.658e-02,Time: 0.02
# adaptive_constant_res_val: 1.008469
# adaptive_constant_bc_val: 0.991531
# It: 16100, Loss: 6.353e-02, Loss_bcs: 2.773e-02, Loss_res: 3.580e-02,Time: 0.02
# adaptive_constant_res_val: 0.974237
# adaptive_constant_bc_val: 1.025763
# It: 16200, Loss: 6.066e-02, Loss_bcs: 2.737e-02, Loss_res: 3.330e-02,Time: 0.02
# adaptive_constant_res_val: 0.951168
# adaptive_constant_bc_val: 1.048832
# It: 16300, Loss: 5.930e-02, Loss_bcs: 2.710e-02, Loss_res: 3.220e-02,Time: 0.02
# adaptive_constant_res_val: 0.953631
# adaptive_constant_bc_val: 1.046369
# It: 16400, Loss: 5.881e-02, Loss_bcs: 2.683e-02, Loss_res: 3.198e-02,Time: 0.02
# adaptive_constant_res_val: 0.961663
# adaptive_constant_bc_val: 1.038337
# It: 16500, Loss: 5.988e-02, Loss_bcs: 2.661e-02, Loss_res: 3.328e-02,Time: 0.02
# adaptive_constant_res_val: 0.974533
# adaptive_constant_bc_val: 1.025467
# It: 16600, Loss: 8.635e-02, Loss_bcs: 2.635e-02, Loss_res: 6.000e-02,Time: 0.02
# adaptive_constant_res_val: 1.149087
# adaptive_constant_bc_val: 0.850913
# It: 16700, Loss: 5.771e-02, Loss_bcs: 2.603e-02, Loss_res: 3.168e-02,Time: 0.02
# adaptive_constant_res_val: 0.884588
# adaptive_constant_bc_val: 1.115412
# It: 16800, Loss: 5.664e-02, Loss_bcs: 2.578e-02, Loss_res: 3.086e-02,Time: 0.02
# adaptive_constant_res_val: 0.940091
# adaptive_constant_bc_val: 1.059909
# It: 16900, Loss: 5.594e-02, Loss_bcs: 2.552e-02, Loss_res: 3.041e-02,Time: 0.03
# adaptive_constant_res_val: 0.957342
# adaptive_constant_bc_val: 1.042658
# It: 17000, Loss: 5.556e-02, Loss_bcs: 2.527e-02, Loss_res: 3.029e-02,Time: 0.02
# adaptive_constant_res_val: 0.964698
# adaptive_constant_bc_val: 1.035302
# It: 17100, Loss: 5.974e-02, Loss_bcs: 2.497e-02, Loss_res: 3.477e-02,Time: 0.02
# adaptive_constant_res_val: 0.993747
# adaptive_constant_bc_val: 1.006253
# It: 17200, Loss: 5.530e-02, Loss_bcs: 2.482e-02, Loss_res: 3.048e-02,Time: 0.02
# adaptive_constant_res_val: 0.940406
# adaptive_constant_bc_val: 1.059594
# It: 17300, Loss: 5.810e-02, Loss_bcs: 2.451e-02, Loss_res: 3.359e-02,Time: 0.03
# adaptive_constant_res_val: 0.984908
# adaptive_constant_bc_val: 1.015092
# It: 17400, Loss: 5.581e-02, Loss_bcs: 2.431e-02, Loss_res: 3.149e-02,Time: 0.02
# adaptive_constant_res_val: 0.957756
# adaptive_constant_bc_val: 1.042244
# It: 17500, Loss: 5.522e-02, Loss_bcs: 2.406e-02, Loss_res: 3.116e-02,Time: 0.02
# adaptive_constant_res_val: 0.964076
# adaptive_constant_bc_val: 1.035924
# It: 17600, Loss: 5.287e-02, Loss_bcs: 2.389e-02, Loss_res: 2.898e-02,Time: 0.02
# adaptive_constant_res_val: 0.953503
# adaptive_constant_bc_val: 1.046497
# It: 17700, Loss: 5.740e-02, Loss_bcs: 2.371e-02, Loss_res: 3.369e-02,Time: 0.02
# adaptive_constant_res_val: 1.009668
# adaptive_constant_bc_val: 0.990332
# It: 17800, Loss: 6.434e-02, Loss_bcs: 2.333e-02, Loss_res: 4.100e-02,Time: 0.03
# adaptive_constant_res_val: 1.022583
# adaptive_constant_bc_val: 0.977417
# It: 17900, Loss: 5.262e-02, Loss_bcs: 2.323e-02, Loss_res: 2.938e-02,Time: 0.02
# adaptive_constant_res_val: 0.906872
# adaptive_constant_bc_val: 1.093128
# It: 18000, Loss: 5.252e-02, Loss_bcs: 2.303e-02, Loss_res: 2.949e-02,Time: 0.03
# adaptive_constant_res_val: 0.949982
# adaptive_constant_bc_val: 1.050018
# It: 18100, Loss: 5.305e-02, Loss_bcs: 2.281e-02, Loss_res: 3.024e-02,Time: 0.02
# adaptive_constant_res_val: 0.967029
# adaptive_constant_bc_val: 1.032971
# It: 18200, Loss: 5.252e-02, Loss_bcs: 2.264e-02, Loss_res: 2.988e-02,Time: 0.02
# adaptive_constant_res_val: 0.955463
# adaptive_constant_bc_val: 1.044537
# It: 18300, Loss: 5.424e-02, Loss_bcs: 2.235e-02, Loss_res: 3.189e-02,Time: 0.03
# adaptive_constant_res_val: 1.023018
# adaptive_constant_bc_val: 0.976982
# It: 18400, Loss: 5.217e-02, Loss_bcs: 2.223e-02, Loss_res: 2.995e-02,Time: 0.04
# adaptive_constant_res_val: 0.987220
# adaptive_constant_bc_val: 1.012780
# It: 18500, Loss: 4.913e-02, Loss_bcs: 2.196e-02, Loss_res: 2.716e-02,Time: 0.03
# adaptive_constant_res_val: 0.950857
# adaptive_constant_bc_val: 1.049143
# It: 18600, Loss: 4.882e-02, Loss_bcs: 2.178e-02, Loss_res: 2.704e-02,Time: 0.03
# adaptive_constant_res_val: 0.968922
# adaptive_constant_bc_val: 1.031078
# It: 18700, Loss: 4.794e-02, Loss_bcs: 2.159e-02, Loss_res: 2.635e-02,Time: 0.02
# adaptive_constant_res_val: 0.964716
# adaptive_constant_bc_val: 1.035284
# It: 18800, Loss: 4.807e-02, Loss_bcs: 2.142e-02, Loss_res: 2.665e-02,Time: 0.02
# adaptive_constant_res_val: 0.973742
# adaptive_constant_bc_val: 1.026258
# It: 18900, Loss: 4.738e-02, Loss_bcs: 2.120e-02, Loss_res: 2.617e-02,Time: 0.03
# adaptive_constant_res_val: 0.969836
# adaptive_constant_bc_val: 1.030164
# It: 19000, Loss: 6.459e-02, Loss_bcs: 2.117e-02, Loss_res: 4.342e-02,Time: 0.03
# adaptive_constant_res_val: 1.124662
# adaptive_constant_bc_val: 0.875338
# It: 19100, Loss: 6.116e-02, Loss_bcs: 2.085e-02, Loss_res: 4.030e-02,Time: 0.02
# adaptive_constant_res_val: 1.039063
# adaptive_constant_bc_val: 0.960937
# It: 19200, Loss: 5.489e-02, Loss_bcs: 2.078e-02, Loss_res: 3.411e-02,Time: 0.02
# adaptive_constant_res_val: 0.937470
# adaptive_constant_bc_val: 1.062530
# It: 19300, Loss: 5.201e-02, Loss_bcs: 2.049e-02, Loss_res: 3.152e-02,Time: 0.03
# adaptive_constant_res_val: 0.972634
# adaptive_constant_bc_val: 1.027366
# It: 19400, Loss: 4.711e-02, Loss_bcs: 2.030e-02, Loss_res: 2.681e-02,Time: 0.03
# adaptive_constant_res_val: 0.935119
# adaptive_constant_bc_val: 1.064881
# It: 19500, Loss: 4.508e-02, Loss_bcs: 2.017e-02, Loss_res: 2.491e-02,Time: 0.03
# adaptive_constant_res_val: 0.945167
# adaptive_constant_bc_val: 1.054833
# It: 19600, Loss: 4.490e-02, Loss_bcs: 1.999e-02, Loss_res: 2.491e-02,Time: 0.02
# adaptive_constant_res_val: 0.967273
# adaptive_constant_bc_val: 1.032727
# It: 19700, Loss: 4.635e-02, Loss_bcs: 1.985e-02, Loss_res: 2.650e-02,Time: 0.02
# adaptive_constant_res_val: 0.992259
# adaptive_constant_bc_val: 1.007741
# It: 19800, Loss: 4.490e-02, Loss_bcs: 1.963e-02, Loss_res: 2.528e-02,Time: 0.03
# adaptive_constant_res_val: 0.965340
# adaptive_constant_bc_val: 1.034660
# It: 19900, Loss: 5.798e-02, Loss_bcs: 1.946e-02, Loss_res: 3.852e-02,Time: 0.02
# adaptive_constant_res_val: 1.120312
# adaptive_constant_bc_val: 0.879688
# It: 20000, Loss: 4.971e-02, Loss_bcs: 1.931e-02, Loss_res: 3.041e-02,Time: 0.02
# adaptive_constant_res_val: 0.965158
# adaptive_constant_bc_val: 1.034842
# It: 20100, Loss: 4.350e-02, Loss_bcs: 1.916e-02, Loss_res: 2.434e-02,Time: 0.02
# adaptive_constant_res_val: 0.925378
# adaptive_constant_bc_val: 1.074622
# It: 20200, Loss: 4.298e-02, Loss_bcs: 1.900e-02, Loss_res: 2.398e-02,Time: 0.02
# adaptive_constant_res_val: 0.960319
# adaptive_constant_bc_val: 1.039681
# It: 20300, Loss: 4.242e-02, Loss_bcs: 1.886e-02, Loss_res: 2.356e-02,Time: 0.02
# adaptive_constant_res_val: 0.968526
# adaptive_constant_bc_val: 1.031474
# It: 20400, Loss: 4.206e-02, Loss_bcs: 1.873e-02, Loss_res: 2.334e-02,Time: 0.02
# adaptive_constant_res_val: 0.972728
# adaptive_constant_bc_val: 1.027272
# It: 20500, Loss: 4.169e-02, Loss_bcs: 1.856e-02, Loss_res: 2.313e-02,Time: 0.02
# adaptive_constant_res_val: 0.974164
# adaptive_constant_bc_val: 1.025836
# It: 20600, Loss: 4.562e-02, Loss_bcs: 1.847e-02, Loss_res: 2.714e-02,Time: 0.02
# adaptive_constant_res_val: 1.030264
# adaptive_constant_bc_val: 0.969736
# It: 20700, Loss: 4.234e-02, Loss_bcs: 1.830e-02, Loss_res: 2.403e-02,Time: 0.03
# adaptive_constant_res_val: 0.967819
# adaptive_constant_bc_val: 1.032181
# It: 20800, Loss: 4.078e-02, Loss_bcs: 1.813e-02, Loss_res: 2.266e-02,Time: 0.03
# adaptive_constant_res_val: 0.960046
# adaptive_constant_bc_val: 1.039954
# It: 20900, Loss: 4.051e-02, Loss_bcs: 1.798e-02, Loss_res: 2.253e-02,Time: 0.02
# adaptive_constant_res_val: 0.972049
# adaptive_constant_bc_val: 1.027951
# It: 21000, Loss: 4.034e-02, Loss_bcs: 1.784e-02, Loss_res: 2.251e-02,Time: 0.02
# adaptive_constant_res_val: 0.976537
# adaptive_constant_bc_val: 1.023463
# It: 21100, Loss: 4.277e-02, Loss_bcs: 1.771e-02, Loss_res: 2.505e-02,Time: 0.02
# adaptive_constant_res_val: 1.004048
# adaptive_constant_bc_val: 0.995952
# It: 21200, Loss: 4.208e-02, Loss_bcs: 1.761e-02, Loss_res: 2.447e-02,Time: 0.02
# adaptive_constant_res_val: 0.975233
# adaptive_constant_bc_val: 1.024767
# It: 21300, Loss: 4.018e-02, Loss_bcs: 1.742e-02, Loss_res: 2.276e-02,Time: 0.02
# adaptive_constant_res_val: 0.956174
# adaptive_constant_bc_val: 1.043826
# It: 21400, Loss: 3.956e-02, Loss_bcs: 1.728e-02, Loss_res: 2.227e-02,Time: 0.02
# adaptive_constant_res_val: 0.965105
# adaptive_constant_bc_val: 1.034895
# It: 21500, Loss: 4.008e-02, Loss_bcs: 1.716e-02, Loss_res: 2.292e-02,Time: 0.02
# adaptive_constant_res_val: 0.980057
# adaptive_constant_bc_val: 1.019943
# It: 21600, Loss: 4.011e-02, Loss_bcs: 1.703e-02, Loss_res: 2.309e-02,Time: 0.02
# adaptive_constant_res_val: 0.988429
# adaptive_constant_bc_val: 1.011571
# It: 21700, Loss: 5.030e-02, Loss_bcs: 1.692e-02, Loss_res: 3.338e-02,Time: 0.02
# adaptive_constant_res_val: 1.099950
# adaptive_constant_bc_val: 0.900050
# It: 21800, Loss: 3.825e-02, Loss_bcs: 1.677e-02, Loss_res: 2.149e-02,Time: 0.02
# adaptive_constant_res_val: 0.911479
# adaptive_constant_bc_val: 1.088521
# It: 21900, Loss: 3.851e-02, Loss_bcs: 1.665e-02, Loss_res: 2.186e-02,Time: 0.02
# adaptive_constant_res_val: 0.964880
# adaptive_constant_bc_val: 1.035120
# It: 22000, Loss: 3.785e-02, Loss_bcs: 1.651e-02, Loss_res: 2.134e-02,Time: 0.02
# adaptive_constant_res_val: 0.967606
# adaptive_constant_bc_val: 1.032394
# It: 22100, Loss: 3.737e-02, Loss_bcs: 1.641e-02, Loss_res: 2.096e-02,Time: 0.02
# adaptive_constant_res_val: 0.972222
# adaptive_constant_bc_val: 1.027778
# It: 22200, Loss: 3.735e-02, Loss_bcs: 1.629e-02, Loss_res: 2.105e-02,Time: 0.03
# adaptive_constant_res_val: 0.981927
# adaptive_constant_bc_val: 1.018073
# It: 22300, Loss: 3.694e-02, Loss_bcs: 1.617e-02, Loss_res: 2.077e-02,Time: 0.02
# adaptive_constant_res_val: 0.977969
# adaptive_constant_bc_val: 1.022031
# It: 22400, Loss: 3.712e-02, Loss_bcs: 1.605e-02, Loss_res: 2.107e-02,Time: 0.02
# adaptive_constant_res_val: 0.986169
# adaptive_constant_bc_val: 1.013831
# It: 22500, Loss: 3.868e-02, Loss_bcs: 1.593e-02, Loss_res: 2.275e-02,Time: 0.02
# adaptive_constant_res_val: 1.004896
# adaptive_constant_bc_val: 0.995104
# It: 22600, Loss: 3.608e-02, Loss_bcs: 1.581e-02, Loss_res: 2.027e-02,Time: 0.02
# adaptive_constant_res_val: 0.956887
# adaptive_constant_bc_val: 1.043113
# It: 22700, Loss: 3.585e-02, Loss_bcs: 1.570e-02, Loss_res: 2.015e-02,Time: 0.02
# adaptive_constant_res_val: 0.973443
# adaptive_constant_bc_val: 1.026557
# It: 22800, Loss: 4.242e-02, Loss_bcs: 1.561e-02, Loss_res: 2.681e-02,Time: 0.02
# adaptive_constant_res_val: 1.041784
# adaptive_constant_bc_val: 0.958216
# It: 22900, Loss: 3.801e-02, Loss_bcs: 1.551e-02, Loss_res: 2.250e-02,Time: 0.02
# adaptive_constant_res_val: 0.971146
# adaptive_constant_bc_val: 1.028854
# It: 23000, Loss: 3.517e-02, Loss_bcs: 1.536e-02, Loss_res: 1.981e-02,Time: 0.02
# adaptive_constant_res_val: 0.946351
# adaptive_constant_bc_val: 1.053649
# It: 23100, Loss: 3.497e-02, Loss_bcs: 1.525e-02, Loss_res: 1.972e-02,Time: 0.02
# adaptive_constant_res_val: 0.971767
# adaptive_constant_bc_val: 1.028233
# It: 23200, Loss: 3.482e-02, Loss_bcs: 1.515e-02, Loss_res: 1.968e-02,Time: 0.02
# adaptive_constant_res_val: 0.978730
# adaptive_constant_bc_val: 1.021270
# It: 23300, Loss: 3.454e-02, Loss_bcs: 1.503e-02, Loss_res: 1.951e-02,Time: 0.03
# adaptive_constant_res_val: 0.978652
# adaptive_constant_bc_val: 1.021348
# It: 23400, Loss: 3.430e-02, Loss_bcs: 1.493e-02, Loss_res: 1.937e-02,Time: 0.02
# adaptive_constant_res_val: 0.979186
# adaptive_constant_bc_val: 1.020814
# It: 23500, Loss: 3.442e-02, Loss_bcs: 1.483e-02, Loss_res: 1.959e-02,Time: 0.03
# adaptive_constant_res_val: 0.988844
# adaptive_constant_bc_val: 1.011156
# It: 23600, Loss: 3.388e-02, Loss_bcs: 1.472e-02, Loss_res: 1.916e-02,Time: 0.02
# adaptive_constant_res_val: 0.977935
# adaptive_constant_bc_val: 1.022065
# It: 23700, Loss: 3.370e-02, Loss_bcs: 1.462e-02, Loss_res: 1.908e-02,Time: 0.02
# adaptive_constant_res_val: 0.980454
# adaptive_constant_bc_val: 1.019546
# It: 23800, Loss: 3.359e-02, Loss_bcs: 1.451e-02, Loss_res: 1.908e-02,Time: 0.02
# adaptive_constant_res_val: 0.982306
# adaptive_constant_bc_val: 1.017694
# It: 23900, Loss: 3.356e-02, Loss_bcs: 1.441e-02, Loss_res: 1.915e-02,Time: 0.02
# adaptive_constant_res_val: 0.983042
# adaptive_constant_bc_val: 1.016958
# It: 24000, Loss: 3.311e-02, Loss_bcs: 1.431e-02, Loss_res: 1.880e-02,Time: 0.02
# adaptive_constant_res_val: 0.977474
# adaptive_constant_bc_val: 1.022526
# It: 24100, Loss: 3.286e-02, Loss_bcs: 1.421e-02, Loss_res: 1.865e-02,Time: 0.02
# ...
# adaptive_constant_res_val: 0.988687
# adaptive_constant_bc_val: 1.011313
# It: 32000, Loss: 2.196e-02, Loss_bcs: 8.774e-03, Loss_res: 1.319e-02,Time: 0.02
# adaptive_constant_res_val: 0.988205
# adaptive_constant_bc_val: 1.011795
# It: 32100, Loss: 2.189e-02, Loss_bcs: 8.730e-03, Loss_res: 1.316e-02,Time: 0.02
# adaptive_constant_res_val: 0.989066
# adaptive_constant_bc_val: 1.010934
# It: 32200, Loss: 2.179e-02, Loss_bcs: 8.681e-03, Loss_res: 1.311e-02,Time: 0.02
# adaptive_constant_res_val: 0.988562
# adaptive_constant_bc_val: 1.011438
# It: 32300, Loss: 2.171e-02, Loss_bcs: 8.636e-03, Loss_res: 1.307e-02,Time: 0.02
# adaptive_constant_res_val: 0.988606
# adaptive_constant_bc_val: 1.011394
# It: 32400, Loss: 2.160e-02, Loss_bcs: 8.593e-03, Loss_res: 1.300e-02,Time: 0.02
# adaptive_constant_res_val: 0.988183
# adaptive_constant_bc_val: 1.011817
# It: 32500, Loss: 2.151e-02, Loss_bcs: 8.549e-03, Loss_res: 1.296e-02,Time: 0.02
# adaptive_constant_res_val: 0.988676
# adaptive_constant_bc_val: 1.011324
# It: 32600, Loss: 2.144e-02, Loss_bcs: 8.506e-03, Loss_res: 1.293e-02,Time: 0.02
# adaptive_constant_res_val: 0.989248
# adaptive_constant_bc_val: 1.010752
# It: 32700, Loss: 2.134e-02, Loss_bcs: 8.463e-03, Loss_res: 1.287e-02,Time: 0.02
# adaptive_constant_res_val: 0.988695
# adaptive_constant_bc_val: 1.011305
# It: 32800, Loss: 2.125e-02, Loss_bcs: 8.419e-03, Loss_res: 1.283e-02,Time: 0.03
# adaptive_constant_res_val: 0.988748
# adaptive_constant_bc_val: 1.011252
# It: 32900, Loss: 2.165e-02, Loss_bcs: 8.379e-03, Loss_res: 1.327e-02,Time: 0.02
# adaptive_constant_res_val: 0.999605
# adaptive_constant_bc_val: 1.000395
# It: 33000, Loss: 2.111e-02, Loss_bcs: 8.333e-03, Loss_res: 1.278e-02,Time: 0.02
# adaptive_constant_res_val: 0.982173
# adaptive_constant_bc_val: 1.017827
# It: 33100, Loss: 2.123e-02, Loss_bcs: 8.284e-03, Loss_res: 1.295e-02,Time: 0.03
# adaptive_constant_res_val: 0.989758
# adaptive_constant_bc_val: 1.010242
# It: 33200, Loss: 2.096e-02, Loss_bcs: 8.251e-03, Loss_res: 1.271e-02,Time: 0.14
# adaptive_constant_res_val: 0.984247
# adaptive_constant_bc_val: 1.015753
# It: 33300, Loss: 2.081e-02, Loss_bcs: 8.213e-03, Loss_res: 1.260e-02,Time: 0.02
# adaptive_constant_res_val: 0.986574
# adaptive_constant_bc_val: 1.013426
# It: 33400, Loss: 2.074e-02, Loss_bcs: 8.173e-03, Loss_res: 1.257e-02,Time: 0.02
# adaptive_constant_res_val: 0.988766
# adaptive_constant_bc_val: 1.011234
# It: 33500, Loss: 2.070e-02, Loss_bcs: 8.132e-03, Loss_res: 1.257e-02,Time: 0.03
# adaptive_constant_res_val: 0.989904
# adaptive_constant_bc_val: 1.010096
# It: 33600, Loss: 2.066e-02, Loss_bcs: 8.091e-03, Loss_res: 1.257e-02,Time: 0.04
# adaptive_constant_res_val: 0.990955
# adaptive_constant_bc_val: 1.009045
# It: 33700, Loss: 2.049e-02, Loss_bcs: 8.053e-03, Loss_res: 1.244e-02,Time: 0.02
# adaptive_constant_res_val: 0.987824
# adaptive_constant_bc_val: 1.012176
# It: 33800, Loss: 2.041e-02, Loss_bcs: 8.014e-03, Loss_res: 1.239e-02,Time: 0.03
# adaptive_constant_res_val: 0.988960
# adaptive_constant_bc_val: 1.011040
# It: 33900, Loss: 2.033e-02, Loss_bcs: 7.977e-03, Loss_res: 1.235e-02,Time: 0.03
# adaptive_constant_res_val: 0.989518
# adaptive_constant_bc_val: 1.010482
# It: 34000, Loss: 2.027e-02, Loss_bcs: 7.937e-03, Loss_res: 1.234e-02,Time: 0.02
# adaptive_constant_res_val: 0.990309
# adaptive_constant_bc_val: 1.009691
# It: 34100, Loss: 2.017e-02, Loss_bcs: 7.901e-03, Loss_res: 1.227e-02,Time: 0.02
# adaptive_constant_res_val: 0.989297
# adaptive_constant_bc_val: 1.010703
# It: 34200, Loss: 2.011e-02, Loss_bcs: 7.862e-03, Loss_res: 1.225e-02,Time: 0.04
# adaptive_constant_res_val: 0.990463
# adaptive_constant_bc_val: 1.009537
# It: 34300, Loss: 2.004e-02, Loss_bcs: 7.827e-03, Loss_res: 1.222e-02,Time: 0.02
# adaptive_constant_res_val: 0.990123
# adaptive_constant_bc_val: 1.009877
# It: 34400, Loss: 1.997e-02, Loss_bcs: 7.789e-03, Loss_res: 1.218e-02,Time: 0.03
# adaptive_constant_res_val: 0.990188
# adaptive_constant_bc_val: 1.009812
# It: 34500, Loss: 1.986e-02, Loss_bcs: 7.751e-03, Loss_res: 1.211e-02,Time: 0.02
# adaptive_constant_res_val: 0.989178
# adaptive_constant_bc_val: 1.010822
# It: 34600, Loss: 1.979e-02, Loss_bcs: 7.715e-03, Loss_res: 1.208e-02,Time: 0.02
# adaptive_constant_res_val: 0.989733
# adaptive_constant_bc_val: 1.010267
# It: 34700, Loss: 1.974e-02, Loss_bcs: 7.682e-03, Loss_res: 1.206e-02,Time: 0.02
# adaptive_constant_res_val: 0.990325
# adaptive_constant_bc_val: 1.009675
# It: 34800, Loss: 1.964e-02, Loss_bcs: 7.644e-03, Loss_res: 1.199e-02,Time: 0.04
# adaptive_constant_res_val: 0.989500
# adaptive_constant_bc_val: 1.010500
# It: 34900, Loss: 1.956e-02, Loss_bcs: 7.608e-03, Loss_res: 1.195e-02,Time: 0.03
# adaptive_constant_res_val: 0.989900
# adaptive_constant_bc_val: 1.010100
# It: 35000, Loss: 1.949e-02, Loss_bcs: 7.573e-03, Loss_res: 1.192e-02,Time: 0.03
# adaptive_constant_res_val: 0.990047
# adaptive_constant_bc_val: 1.009953
# It: 35100, Loss: 1.942e-02, Loss_bcs: 7.539e-03, Loss_res: 1.188e-02,Time: 0.03
# adaptive_constant_res_val: 0.990043
# adaptive_constant_bc_val: 1.009957
# It: 35200, Loss: 1.936e-02, Loss_bcs: 7.505e-03, Loss_res: 1.186e-02,Time: 0.03
# adaptive_constant_res_val: 0.990488
# adaptive_constant_bc_val: 1.009512
# It: 35300, Loss: 1.953e-02, Loss_bcs: 7.473e-03, Loss_res: 1.205e-02,Time: 0.03
# adaptive_constant_res_val: 0.994602
# adaptive_constant_bc_val: 1.005398
# It: 35400, Loss: 1.920e-02, Loss_bcs: 7.437e-03, Loss_res: 1.176e-02,Time: 0.02
# adaptive_constant_res_val: 0.985710
# adaptive_constant_bc_val: 1.014290
# It: 35500, Loss: 1.913e-02, Loss_bcs: 7.403e-03, Loss_res: 1.173e-02,Time: 0.02
# adaptive_constant_res_val: 0.989160
# adaptive_constant_bc_val: 1.010840
# It: 35600, Loss: 1.909e-02, Loss_bcs: 7.370e-03, Loss_res: 1.172e-02,Time: 0.02
# adaptive_constant_res_val: 0.990694
# adaptive_constant_bc_val: 1.009306
# It: 35700, Loss: 1.899e-02, Loss_bcs: 7.337e-03, Loss_res: 1.166e-02,Time: 0.03
# adaptive_constant_res_val: 0.989781
# adaptive_constant_bc_val: 1.010219
# It: 35800, Loss: 1.892e-02, Loss_bcs: 7.304e-03, Loss_res: 1.162e-02,Time: 0.03
# adaptive_constant_res_val: 0.990222
# adaptive_constant_bc_val: 1.009778
# It: 35900, Loss: 1.891e-02, Loss_bcs: 7.273e-03, Loss_res: 1.164e-02,Time: 0.05
# adaptive_constant_res_val: 0.993019
# adaptive_constant_bc_val: 1.006981
# It: 36000, Loss: 1.879e-02, Loss_bcs: 7.240e-03, Loss_res: 1.155e-02,Time: 0.04
# adaptive_constant_res_val: 0.989903
# adaptive_constant_bc_val: 1.010097
# It: 36100, Loss: 1.872e-02, Loss_bcs: 7.209e-03, Loss_res: 1.151e-02,Time: 0.05
# adaptive_constant_res_val: 0.990394
# adaptive_constant_bc_val: 1.009606
# It: 36200, Loss: 1.872e-02, Loss_bcs: 7.179e-03, Loss_res: 1.154e-02,Time: 0.04
# adaptive_constant_res_val: 0.991655
# adaptive_constant_bc_val: 1.008345
# It: 36300, Loss: 1.859e-02, Loss_bcs: 7.147e-03, Loss_res: 1.144e-02,Time: 0.02
# adaptive_constant_res_val: 0.989626
# adaptive_constant_bc_val: 1.010374
# It: 36400, Loss: 1.872e-02, Loss_bcs: 7.119e-03, Loss_res: 1.160e-02,Time: 0.03
# adaptive_constant_res_val: 0.994594
# adaptive_constant_bc_val: 1.005406
# It: 36500, Loss: 1.850e-02, Loss_bcs: 7.084e-03, Loss_res: 1.142e-02,Time: 0.02
# adaptive_constant_res_val: 0.988932
# adaptive_constant_bc_val: 1.011068
# It: 36600, Loss: 1.844e-02, Loss_bcs: 7.051e-03, Loss_res: 1.139e-02,Time: 0.02
# adaptive_constant_res_val: 0.990753
# adaptive_constant_bc_val: 1.009247
# It: 36700, Loss: 1.849e-02, Loss_bcs: 7.021e-03, Loss_res: 1.147e-02,Time: 0.03
# adaptive_constant_res_val: 0.993142
# adaptive_constant_bc_val: 1.006858
# It: 36800, Loss: 1.859e-02, Loss_bcs: 6.986e-03, Loss_res: 1.160e-02,Time: 0.03
# adaptive_constant_res_val: 0.994187
# adaptive_constant_bc_val: 1.005813
# It: 36900, Loss: 1.820e-02, Loss_bcs: 6.964e-03, Loss_res: 1.124e-02,Time: 0.03
# adaptive_constant_res_val: 0.983628
# adaptive_constant_bc_val: 1.016372
# It: 37000, Loss: 1.815e-02, Loss_bcs: 6.934e-03, Loss_res: 1.122e-02,Time: 0.03
# adaptive_constant_res_val: 0.989394
# adaptive_constant_bc_val: 1.010606
# It: 37100, Loss: 1.828e-02, Loss_bcs: 6.909e-03, Loss_res: 1.137e-02,Time: 0.02
# adaptive_constant_res_val: 0.997628
# adaptive_constant_bc_val: 1.002372
# It: 37200, Loss: 1.802e-02, Loss_bcs: 6.876e-03, Loss_res: 1.114e-02,Time: 0.02
# adaptive_constant_res_val: 0.988042
# adaptive_constant_bc_val: 1.011958
# It: 37300, Loss: 1.796e-02, Loss_bcs: 6.847e-03, Loss_res: 1.111e-02,Time: 0.02
# adaptive_constant_res_val: 0.990346
# adaptive_constant_bc_val: 1.009654
# It: 37400, Loss: 1.789e-02, Loss_bcs: 6.817e-03, Loss_res: 1.108e-02,Time: 0.02
# adaptive_constant_res_val: 0.990792
# adaptive_constant_bc_val: 1.009208
# It: 37500, Loss: 1.783e-02, Loss_bcs: 6.789e-03, Loss_res: 1.104e-02,Time: 0.04
# adaptive_constant_res_val: 0.990957
# adaptive_constant_bc_val: 1.009043
# It: 37600, Loss: 1.780e-02, Loss_bcs: 6.759e-03, Loss_res: 1.104e-02,Time: 0.05
# adaptive_constant_res_val: 0.991456
# adaptive_constant_bc_val: 1.008544
# It: 37700, Loss: 1.771e-02, Loss_bcs: 6.734e-03, Loss_res: 1.098e-02,Time: 0.04
# adaptive_constant_res_val: 0.990450
# adaptive_constant_bc_val: 1.009550
# It: 37800, Loss: 1.765e-02, Loss_bcs: 6.706e-03, Loss_res: 1.095e-02,Time: 0.04
# adaptive_constant_res_val: 0.991029
# adaptive_constant_bc_val: 1.008971
# It: 37900, Loss: 1.779e-02, Loss_bcs: 6.680e-03, Loss_res: 1.111e-02,Time: 0.05
# adaptive_constant_res_val: 0.995199
# adaptive_constant_bc_val: 1.004801
# It: 38000, Loss: 1.756e-02, Loss_bcs: 6.651e-03, Loss_res: 1.090e-02,Time: 0.07
# adaptive_constant_res_val: 0.987968
# adaptive_constant_bc_val: 1.012032
# It: 38100, Loss: 1.748e-02, Loss_bcs: 6.624e-03, Loss_res: 1.085e-02,Time: 0.02
# adaptive_constant_res_val: 0.989987
# adaptive_constant_bc_val: 1.010013
# It: 38200, Loss: 1.742e-02, Loss_bcs: 6.597e-03, Loss_res: 1.082e-02,Time: 0.02
# adaptive_constant_res_val: 0.990983
# adaptive_constant_bc_val: 1.009017
# It: 38300, Loss: 1.736e-02, Loss_bcs: 6.571e-03, Loss_res: 1.079e-02,Time: 0.05
# adaptive_constant_res_val: 0.991273
# adaptive_constant_bc_val: 1.008727
# It: 38400, Loss: 1.730e-02, Loss_bcs: 6.544e-03, Loss_res: 1.076e-02,Time: 0.05
# adaptive_constant_res_val: 0.991432
# adaptive_constant_bc_val: 1.008568
# It: 38500, Loss: 1.725e-02, Loss_bcs: 6.518e-03, Loss_res: 1.073e-02,Time: 0.04
# adaptive_constant_res_val: 0.991465
# adaptive_constant_bc_val: 1.008535
# It: 38600, Loss: 1.720e-02, Loss_bcs: 6.493e-03, Loss_res: 1.071e-02,Time: 0.05
# adaptive_constant_res_val: 0.991817
# adaptive_constant_bc_val: 1.008183
# It: 38700, Loss: 1.722e-02, Loss_bcs: 6.464e-03, Loss_res: 1.076e-02,Time: 0.05
# adaptive_constant_res_val: 0.992888
# adaptive_constant_bc_val: 1.007112
# It: 38800, Loss: 1.713e-02, Loss_bcs: 6.443e-03, Loss_res: 1.069e-02,Time: 0.05
# adaptive_constant_res_val: 0.991445
# adaptive_constant_bc_val: 1.008555
# It: 38900, Loss: 1.705e-02, Loss_bcs: 6.415e-03, Loss_res: 1.064e-02,Time: 0.05
# adaptive_constant_res_val: 0.990981
# adaptive_constant_bc_val: 1.009019
# It: 39000, Loss: 1.697e-02, Loss_bcs: 6.390e-03, Loss_res: 1.058e-02,Time: 0.05
# adaptive_constant_res_val: 0.990726
# adaptive_constant_bc_val: 1.009274
# It: 39100, Loss: 1.692e-02, Loss_bcs: 6.365e-03, Loss_res: 1.055e-02,Time: 0.05
# adaptive_constant_res_val: 0.991491
# adaptive_constant_bc_val: 1.008509
# It: 39200, Loss: 1.686e-02, Loss_bcs: 6.340e-03, Loss_res: 1.052e-02,Time: 0.04
# adaptive_constant_res_val: 0.991613
# adaptive_constant_bc_val: 1.008387
# It: 39300, Loss: 1.681e-02, Loss_bcs: 6.315e-03, Loss_res: 1.050e-02,Time: 0.04
# adaptive_constant_res_val: 0.991719
# adaptive_constant_bc_val: 1.008281
# It: 39400, Loss: 1.676e-02, Loss_bcs: 6.291e-03, Loss_res: 1.047e-02,Time: 0.04
# adaptive_constant_res_val: 0.991741
# adaptive_constant_bc_val: 1.008259
# It: 39500, Loss: 1.673e-02, Loss_bcs: 6.266e-03, Loss_res: 1.047e-02,Time: 0.05
# adaptive_constant_res_val: 0.992418
# adaptive_constant_bc_val: 1.007582
# It: 39600, Loss: 1.673e-02, Loss_bcs: 6.241e-03, Loss_res: 1.049e-02,Time: 0.04
# adaptive_constant_res_val: 0.993504
# adaptive_constant_bc_val: 1.006496
# It: 39700, Loss: 1.683e-02, Loss_bcs: 6.220e-03, Loss_res: 1.061e-02,Time: 0.04
# adaptive_constant_res_val: 0.999419
# adaptive_constant_bc_val: 1.000581
# It: 39800, Loss: 1.655e-02, Loss_bcs: 6.193e-03, Loss_res: 1.036e-02,Time: 0.04
# adaptive_constant_res_val: 0.988054
# adaptive_constant_bc_val: 1.011946
# It: 39900, Loss: 1.650e-02, Loss_bcs: 6.169e-03, Loss_res: 1.033e-02,Time: 0.04
# adaptive_constant_res_val: 0.990732
# adaptive_constant_bc_val: 1.009268
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/afrah2/anaconda3/envs/twoPhase/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Gradients information stored ...
# It: 40000, Loss: 1.644e-02, Loss_bcs: 6.146e-03, Loss_res: 1.030e-02,Time: 0.97
# adaptive_constant_res_val: 0.991396
# adaptive_constant_bc_val: 1.008604
# Relative L2 error_u: 3.01e-02
# Relative L2 error_f: 1.73e-03
# Save uv NN parameters successfully in %s ...checkpoints/Dec-17-2023_23-29-45-237722_relobralo
# Final loss total loss: 1.644491e-02
# Final loss loss_res: 1.029765e-02
# Final loss loss_bcs: 6.147258e-03
# Final loss loss_bc1: 1.407052e-03
# Final loss loss_bc2: 7.703815e-04
# Final loss loss_bc3: 1.156046e-03
# Final loss loss_bc4: 2.813778e-03
# average lambda_bc : 1.0699e+00
# average lambda_res : 1.0
#
#
# Method: full_batch
#
# average of time_list:9.8897e+02
# average of error_u_list:3.0089e-02
# average of error_v_list:1.7294e-03

# %%
Method: mini_batch

average of time_list:2.7972e+02
average of error_u_list:1.4240e-01
average of error_v_list:7.3166e-03
# Out:
#   File "/tmp/ipykernel_28093/1497590327.py", line 3
#     average of time_list:2.7972e+02
#              ^
# SyntaxError: invalid syntax

# %%
model.loss_history
# Out:
# {'total loss': [0,
#   6837.2354,
#   7007.1406,
#   7454.5513,
#   6319.552,
#   6783.9673,
#   7334.4707,
#   7050.1016,
#   6187.1094,
#   7036.614,
#   5874.5605,
#   6618.368,
#   6937.3755,
#   7219.1294,
#   7099.772,
#   6125.392,
#   6735.928,
#   6401.3887,
#   7092.786,
#   7017.5723,
#   7781.6895,
#   7438.0103,
#   7742.739,
#   7142.6064,
#   7664.891,
#   6878.4653,
#   7327.2812,
#   7257.5376,
#   6311.009,
#   6721.8486,
#   7712.5347,
#   7680.7427,
#   7072.624,
#   6979.8364,
#   5573.472,
#   6322.7134,
#   6176.224,
#   7239.36,
#   7936.7607,
#   8020.731,
#   5830.1816,
#   6709.6885,
#   8016.3086,
#   6610.1006,
#   6139.4272,
#   7068.506,
#   7298.9165,
#   7069.425,
#   7903.4688,
#   7141.165,
#   6307.4526,
#   6504.12,
#   6209.652,
#   6289.9307,
#   6624.553,
#   5486.6113,
#   6898.023,
#   6214.5635,
#   5725.3936,
#   6499.5776,
#   6627.588,
#   7278.8633,
#   7669.574,
#   5512.935,
#   8063.378,
#   6745.589,
#   7422.527,
#   8541.348,
#   6321.757,
#   6969.367,
#   6339.0366,
#   7387.566,
#   7699.12,
#   6587.506,
#   6313.7646,
#   7086.5728,
#   6412.5703,
#   6962.434,
#   6666.712,
#   5498.3394,
#   6324.684,
#   6783.741,
#   6418.957,
#   5201.425,
#   7839.14,
#   6252.9966,
#   7290.8203,
#   7928.699,
#   6172.395,
#   6867.5767,
#   7908.3286,
#   5681.918,
#   6942.3774,
#   7968.5293,
#   7233.894,
#   7012.078,
#   6287.2593,
#   7380.471,
#   6251.0854,
#   5985.0044,
#   6514.244,
#   6154.81,
#   6173.5303,
#   8171.205,
#   6470.986,
#   6776.373,
#   6503.6475,
#   6796.3433,
#   6730.601,
#   7070.8647,
#   6407.288,
#   6832.965,
#   7449.904,
#   6861.896,
#   6526.4424,
#   7230.554,
#   6683.4565,
#   7976.8735,
#   7302.5576,
#   7738.3003,
#   7571.305,
#   8056.983,
#   6324.4634,
#   5789.0015,
#   6903.5845,
#   7497.3706,
#   7509.6704,
#   6697.5034,
#   7912.553,
#   6820.9956,
#   7518.5376,
#   7119.607,
#   7359.55,
#   8358.751,
#   7425.1504,
#   7759.7847,
#   6984.5537,
#   6079.5093,
#   5740.83,
#   7072.103,
#   5874.751,
#   6396.0024,
#   7880.611,
#   6795.875,
#   6669.509,
#   8006.0625,
#   7911.6313,
#   6554.966,
#   6670.738,
#   7557.0767,
#   7166.435,
#   6522.6934,
#   8369.08,
#   5921.371,
#   7477.9077,
#   6183.4546,
#   6324.038,
#   5994.154,
#   8025.831,
#   6809.936,
#   7130.404,
#   6530.5747,
#   7895.578,
#   8065.527,
#   6522.935,
#   7116.715,
#   8969.54,
#   5771.222,
#   6674.857,
#   7262.8726,
#   7143.2544,
#   7404.1904,
#   5784.167,
#   7018.394,
#   8020.3115,
#   8100.0527,
#   8202.581,
#   7397.594,
#   7049.6304,
#   6882.379,
#   7209.03,
#   7895.864,
#   7641.106,
#   6443.5566,
#   7249.4907,
#   7744.4595,
#   6737.588,
#   7361.9766,
#   6033.7017,
#   6467.8438,
#   7656.326,
#   7026.795,
#   7195.5283,
#   8115.386,
#   6521.646,
#   6800.9756,
#   7224.905,
#   8253.826,
#   7032.5713,
#   6844.046,
#   7289.5044,
#   5895.869,
#   5689.322,
#   6720.428,
#   6630.6343,
#   4698.1426,
#   6768.5996,
#   6568.8477,
#   7437.94,
#   7291.9614,
#   4498.4727,
#   6503.5786,
#   6305.9478,
#   5982.4526,
#   6241.9517,
#   6635.562,
#   6146.6865,
#   5653.76,
#   6361.71,
#   5548.8794,
#   5321.7163,
#   6437.2017,
#   8062.605,
#   6308.008,
#   6621.872,
#   7013.2173,
#   7268.736,
#   6099.262,
#   6246.0005,
#   7580.0137,
#   7619.8125,
#   4903.738,
#   6016.4253,
#   6142.4775,
#   6867.3228,
#   6283.9126,
#   5991.254,
#   6762.528,
#   4896.168,
#   6451.3853,
#   6710.864,
#   7002.5884,
#   6233.6997,
#   6546.3604,
#   6660.7974,
#   7032.6104,
#   6278.8066,
#   7522.0845,
#   6107.81,
#   7119.492,
#   6132.461,
#   5772.9976,
#   6744.837,
#   6253.491,
#   6375.623,
#   6167.2065,
#   6120.9243,
#   5745.0356,
#   8130.2437,
#   6985.0566,
#   6837.376,
#   4768.21,
#   5694.435,
#   6872.5566,
#   7004.2734,
#   6253.306,
#   6451.461,
#   6256.504,
#   7369.7363,
#   5992.1626,
#   7279.021,
#   5887.712,
#   5733.0674,
#   6303.3843,
#   4868.855,
#   6280.2104,
#   6403.5093,
#   6195.2637,
#   6147.4365,
#   6693.7363,
#   7458.863,
#   6731.5405,
#   6238.757,
#   6526.6206,
#   6052.0137,
#   7010.9033,
#   6376.9673,
#   6938.3174,
#   5667.781,
#   6765.8354,
#   6914.6,
#   6204.0107,
#   6541.3945,
#   6259.2583,
#   6236.3384,
#   6666.815,
#   7198.825,
#   6629.0283,
#   6040.076,
#   6659.8447,
#   6877.7495,
#   5886.7305,
#   5858.1265,
#   5627.8394,
#   5610.0586,
#   5573.4883,
#   5660.823,
#   6660.0317,
#   5327.1074,
#   4882.847,
#   5778.947,
#   4142.1987,
#   5298.0854,
#   5488.5005,
#   6416.1353,
#   5951.728,
#   6052.0996,
#   5757.9536,
#   5263.2456,
#   5419.5303,
#   5129.409,
#   5791.5913,
#   5094.5273,
#   5358.1807,
#   5459.972,
#   5838.109,
#   4911.6187,
#   4698.3013,
#   5233.5596,
#   5148.265,
#   5521.807,
#   4880.848,
#   4880.631,
#   4983.403,
#   5685.92,
#   4804.667,
#   5592.1396,
#   4827.621,
#   5590.078,
#   5609.6567,
#   6198.033,
#   4990.7344,
#   4798.448,
#   4230.8965,
#   4509.1777,
#   6272.072,
#   5745.9575,
#   4318.9844,
#   4911.446,
#   4986.1523,
#   4275.1523,
#   5363.065,
#   4553.273,
#   4159.1562,
#   5428.1836,
#   4790.056,
#   4475.8394,
#   4494.593,
#   5316.4717,
#   4827.998,
#   5050.0557,
#   5228.0737,
#   5546.6294,
#   5125.9204,
#   4842.844,
#   4661.4077,
#   4717.778,
#   4704.6084,
#   5330.6694,
#   4300.3223,
#   5598.1724,
#   4679.3936,
#   4324.9375,
#   5125.9775,
#   5618.6274,
#   4605.6953,
#   4113.9897,
#   4209.4263,
#   4511.2563,
#   4488.1543,
#   4196.4673,
#   5164.96,
#   5053.272,
#   4757.0356,
#   4976.5527,
#   5379.9575,
#   4823.716,
#   5372.2734,
#   3889.1238,
#   4568.843,
#   4329.3804,
#   4752.197,
#   3987.591,
#   4587.9194,
#   4389.9707,
#   4339.5903,
#   4501.307,
#   3901.6277,
#   4581.215,
#   4263.2603,
#   4386.413,
#   3708.4539,
#   4390.438,
#   4380.3306,
#   4689.9365,
#   5118.4956,
#   4404.7554,
#   4228.4727,
#   4183.371,
#   5526.4287,
#   4401.19,
#   4048.8174,
#   4352.764,
#   5541.958,
#   4700.9897,
#   4499.993,
#   4120.6265,
#   5055.5645,
#   4292.2617,
#   4307.599,
#   4844.417,
#   4446.3604,
#   4323.8315,
#   3678.4236,
#   4472.301,
#   4512.619,
#   3925.3313,
#   3832.5103,
#   4466.3086,
#   4225.6245,
#   3810.476,
#   4029.0535,
#   4576.0063,
#   4174.172,
#   5157.843,
#   4309.3765,
#   4168.993,
#   4404.8,
#   4039.0586,
#   5012.677,
#   4500.5845,
#   4320.8804,
#   3938.558,
#   3323.9265,
#   3586.0098,
#   3918.7688,
#   3744.1167,
#   3341.4888,
#   4256.3623,
#   3942.1575,
#   4148.3145,
#   3454.685,
#   4058.7278,
#   4654.301,
#   4966.0366,
#   4825.1504,
#   4027.7268,
#   3944.4863,
#   4865.211,
#   3702.2087,
#   3652.7585,
#   4230.1,
#   3789.3945,
#   4088.8604,
#   3969.9062,
#   4112.775,
#   4904.5273,
#   4666.2734,
#   3282.2434,
#   3690.0486,
#   3690.4724,
#   4282.887,
#   4419.961,
#   4066.8774,
#   3703.211,
#   4367.4067,
#   3585.4917,
#   3669.5938,
#   3493.1543,
#   4034.4968,
#   4075.5264,
#   4780.602,
#   4312.3345,
#   3858.4165,
#   3889.4307,
#   3156.0557,
#   3263.0571,
#   3174.538,
#   3615.2693,
#   3774.9207,
#   3594.8242,
#   4076.7185,
#   3350.8516,
#   3619.4133,
#   3293.4348,
#   3708.4636,
#   2848.1128,
#   4208.3135,
#   4489.399,
#   2994.8137,
#   4670.1187,
#   3766.2324,
#   3386.915,
#   3564.6848,
#   4361.9326,
#   3688.8857,
#   2776.0947,
#   3183.845,
#   3711.903,
#   3458.9026,
#   3407.1494,
#   3737.8376,
#   3188.7124,
#   4089.6885,
#   3468.7747,
#   4078.2925,
#   3191.401,
#   3654.659,
#   2949.927,
#   2846.023,
#   3649.6592,
#   3839.08,
#   3103.8552,
#   3159.7498,
#   3038.0461,
#   3125.1565,
#   3116.9558,
#   2855.1968,
#   3147.117,
#   2381.0105,
#   2839.4512,
#   4293.626,
#   2930.7703,
#   3464.848,
#   2725.8706,
#   3521.5747,
#   2830.6816,
#   2825.38,
#   2491.0042,
#   2139.3918,
#   2421.8894,
#   2170.367,
#   2845.6868,
#   2594.5764,
#   2853.9143,
#   2368.2534,
#   3011.8777,
#   2893.9185,
#   2805.9272,
#   2288.5657,
#   3421.8582,
#   2353.4163,
#   2753.929,
#   2714.3835,
#   2379.6172,
#   3142.102,
#   3128.7046,
#   2731.7253,
#   2648.3489,
#   2938.2107,
#   2435.714,
#   2228.8308,
#   1990.2285,
#   2527.1038,
#   2318.0713,
#   2237.8386,
#   2317.8306,
#   2550.8467,
#   2187.2422,
#   2866.391,
#   1923.2151,
#   1945.8384,
#   1989.1637,
#   2270.0913,
#   2753.331,
#   2125.0435,
#   2247.8538,
#   2282.5488,
#   2280.0286,
#   1780.4869,
#   2155.6,
#   2112.3828,
#   1838.1338,
#   2521.5488,
#   1867.8921,
#   1918.9785,
#   1944.4484,
#   1621.0908,
#   1618.1318,
#   1985.1217,
#   1782.856,
#   2270.1038,
#   1968.345,
#   2065.6729,
#   1999.2266,
#   1584.8646,
#   2658.211,
#   1898.227,
#   1935.2268,
#   1628.2361,
#   1851.3243,
#   1629.3011,
#   1804.852,
#   1413.2415,
#   1353.9519,
#   1589.4438,
#   1559.925,
#   1722.8617,
#   1685.8629,
#   1918.6876,
#   1530.5339,
#   1858.5305,
#   1480.6149,
#   1597.6788,
#   1741.7437,
#   1462.7252,
#   1620.6868,
#   1739.947,
#   1546.2688,
#   1748.18,
#   1262.1927,
#   1514.5234,
#   1573.8356,
#   1515.7739,
#   1438.6141,
#   1225.1034,
#   1343.5376,
#   1534.6249,
#   1410.3145,
#   1469.1462,
#   1515.9392,
#   1433.6768,
#   1626.0315,
#   1849.0488,
#   1229.7504,
#   1377.72,
#   1490.9323,
#   1212.7186,
#   1455.561,
#   1535.6688,
#   1431.4924,
#   1625.0625,
#   1407.3253,
#   1530.8466,
#   1345.8341,
#   1275.0696,
#   1265.6433,
#   1568.1902,
#   1307.2834,
#   1370.0153,
#   1722.506,
#   1363.8583,
#   1506.3754,
#   1366.1768,
#   1657.5298,
#   1104.4692,
#   1169.4417,
#   1259.7555,
#   1395.4001,
#   1204.3813,
#   1390.7161,
#   1425.1307,
#   1080.0537,
#   1215.1072,
#   1265.7272,
#   1016.02386,
#   1395.0446,
#   1419.6671,
#   1097.9226,
#   1450.5831,
#   1260.7786,
#   1288.8682,
#   859.54407,
#   1194.7579,
#   1152.7008,
#   1243.1925,
#   1245.4874,
#   1126.1577,
#   962.8842,
#   1087.4944,
#   932.7767,
#   1071.0413,
#   918.7558,
#   1143.84,
#   1005.6084,
#   1152.907,
#   866.7229,
#   1069.7217,
#   844.99567,
#   1189.1127,
#   923.4462,
#   1008.2408,
#   1004.77905,
#   1170.6377,
#   899.4874,
#   996.12146,
#   910.4805,
#   1248.1652,
#   883.3863,
#   1035.6935,
#   946.9306,
#   773.57306,
#   892.9237,
#   753.2096,
#   946.2837,
#   845.5415,
#   1062.1035,
#   930.3321,
#   901.3364,
#   707.5401,
#   993.77966,
#   933.9757,
#   770.39825,
#   1020.97186,
#   1097.9142,
#   736.9541,
#   838.93994,
#   837.1221,
#   806.56635,
#   1108.8463,
#   747.9597,
#   927.8759,
#   842.08167,
#   941.2638,
#   892.7647,
#   876.4598,
#   935.48694,
#   780.2673,
#   821.9362,
#   1020.6189,
#   763.33527,
#   712.7573,
#   846.13947,
#   675.73834,
#   593.9834,
#   744.1377,
#   739.7707,
#   1033.1383,
#   698.9993,
#   770.3644,
#   635.4104,
#   845.6892,
#   668.4828,
#   682.2329,
#   642.5862,
#   763.97614,
#   742.28076,
#   643.46277,
#   598.7949,
#   683.8814,
#   688.13983,
#   680.7683,
#   577.14435,
#   683.3834,
#   553.5969,
#   766.90265,
#   609.48096,
#   543.73883,
#   532.9688,
#   801.8685,
#   550.16046,
#   541.1233,
#   598.3701,
#   509.11423,
#   551.0906,
#   555.1713,
#   620.97876,
#   476.94513,
#   478.38486,
#   665.6837,
#   448.9945,
#   508.33795,
#   511.17795,
#   509.6935,
#   532.982,
#   533.53314,
#   449.27258,
#   501.71548,
#   548.7342,
#   448.37897,
#   491.5308,
#   498.7201,
#   432.6101,
#   553.2601,
#   614.01196,
#   527.90753,
#   447.58032,
#   482.94522,
#   591.1467,
#   567.4728,
#   460.83353,
#   385.71167,
#   438.9863,
#   518.3973,
#   546.4202,
#   524.04675,
#   564.8479,
#   380.06735,
#   515.5412,
#   474.76523,
#   461.95886,
#   382.37265,
#   463.2822,
#   407.51642,
#   323.21332,
#   394.34778,
#   391.93716,
#   370.17676,
#   413.63095,
#   346.95877,
#   391.6904,
#   434.73135,
#   499.0591,
#   418.9518,
#   519.0155,
#   381.65967,
#   354.9076,
#   304.97937,
#   360.85574,
#   284.25455,
#   354.4277,
#   401.1509,
#   333.605,
#   483.30475,
#   311.7035,
#   381.49274,
#   282.84824,
#   393.80353,
#   309.67682,
#   329.54227,
#   330.99112,
#   389.437,
#   372.7887,
#   366.7969,
#   357.91364,
#   360.1728,
#   308.97516,
#   296.73398,
#   229.8641,
#   301.29916,
#   356.7534,
#   391.73627,
#   314.12997,
#   324.66357,
#   307.42203,
#   496.12125,
#   332.70615,
#   312.81693,
#   253.55115,
#   351.03418,
#   326.25455,
#   257.96313,
#   286.24545,
#   391.69147,
#   362.49146,
#   322.29694,
#   343.8903,
#   249.1988,
#   347.81937,
#   284.55508,
#   309.6614,
#   255.85327,
#   327.79498,
#   329.61407,
#   375.50647,
#   285.2289,
#   283.50708,
#   307.89185,
#   345.7176,
#   292.63382,
#   286.84647,
#   248.93706,
#   288.85095,
#   225.17755,
#   266.1152,
#   272.25928,
#   303.92517,
#   278.23236,
#   273.96463,
#   321.31555,
#   187.3412,
#   289.3091,
#   275.63605,
#   318.1234,
#   285.1653,
#   272.0978,
#   302.0231,
#   309.0957,
#   238.49216,
#   254.31155,
#   307.69785,
#   211.39941,
#   299.14938,
#   204.29984,
#   245.14705,
#   208.52036,
#   208.5886,
#   304.0125,
#   288.18042,
#   279.7145,
#   261.89526,
#   184.83383,
#   265.33615,
#   262.47763,
#   233.95627,
#   220.52203,
#   271.66666,
#   263.0981,
#   266.91248,
#   205.694,
#   190.77467,
#   189.84317,
#   301.89255,
#   210.43947,
#   204.83527,
#   190.54887,
#   268.16922,
#   179.7005,
#   235.7544,
#   229.18001,
#   222.24876,
#   272.68057,
#   228.73604,
#   236.27008,
#   237.0495,
#   225.77786,
#   252.44432,
#   190.01735,
#   180.01633,
#   190.07913,
#   190.21387,
#   217.41846,
#   193.29224,
#   210.64009,
#   182.42175,
#   204.99884,
#   247.24258,
#   209.55272,
#   186.953,
#   220.39331,
#   228.13171,
#   215.71388,
#   222.06366,
#   242.146,
#   221.19577,
#   235.86102,
#   223.67583,
#   201.86522,
#   234.29124,
#   221.27989,
#   206.69772,
#   200.4162,
#   207.3455,
#   240.25043,
#   153.86597,
#   176.5416,
#   185.27295,
#   216.61362,
#   213.13814,
#   229.26764,
#   203.82349,
#   187.24359,
#   202.49695,
#   238.45508,
#   247.17783,
#   230.65735,
#   194.77179,
#   186.70175,
#   251.41406,
#   223.13916,
#   200.77748,
#   218.1617,
#   194.72989,
#   220.80653,
#   191.375,
#   223.6905,
#   251.31259,
#   135.02057,
#   239.79741,
#   176.36844,
#   149.52788,
#   181.10889,
#   185.09686,
#   131.36334,
#   185.97922,
#   177.12656,
#   231.06596,
#   203.05989,
#   159.75865,
#   163.67252,
#   162.01073,
#   186.5517,
#   175.06528,
#   148.70753,
#   187.61098,
#   207.42609,
#   139.31795,
#   189.41124,
#   221.70705,
#   198.79492,
#   ...],
#  'loss_res': [0,
#   6836.659,
#   7006.7354,
#   7454.193,
#   6319.3213,
#   6783.8335,
#   7334.3975,
#   7050.0615,
#   6187.0894,
#   7036.6045,
#   5874.552,
#   6618.3545,
#   6937.3555,
#   7219.101,
#   7099.7393,
#   6125.362,
#   6735.894,
#   6401.351,
#   7092.742,
#   7017.521,
#   7781.638,
#   7437.944,
#   7742.6733,
#   7142.5254,
#   7664.8047,
#   6878.366,
#   7327.171,
#   7257.415,
#   6310.8633,
#   6721.6797,
#   7712.3467,
#   7680.5264,
#   7072.416,
#   6979.6626,
#   5573.326,
#   6322.6006,
#   6176.1387,
#   7239.2876,
#   7936.698,
#   8020.674,
#   5830.129,
#   6709.6255,
#   8016.2427,
#   6610.032,
#   6139.354,
#   7068.429,
#   7298.8237,
#   7069.3286,
#   7903.358,
#   7141.043,
#   6307.3076,
#   6503.9824,
#   6209.501,
#   6289.794,
#   6624.396,
#   5486.4756,
#   6897.8926,
#   6214.461,
#   5725.2783,
#   6499.4717,
#   6627.485,
#   7278.768,
#   7669.4766,
#   5512.8403,
#   8063.2886,
#   6745.513,
#   7422.4414,
#   8541.254,
#   6321.662,
#   6969.273,
#   6338.934,
#   7387.464,
#   7699.007,
#   6587.391,
#   6313.657,
#   7086.46,
#   6412.4565,
#   6962.3076,
#   6666.593,
#   5498.2114,
#   6324.551,
#   6783.587,
#   6418.7827,
#   5201.233,
#   7838.947,
#   6252.8037,
#   7290.62,
#   7928.4854,
#   6172.1426,
#   6867.3203,
#   7908.055,
#   5681.6187,
#   6942.0693,
#   7968.214,
#   7233.624,
#   7011.795,
#   6287.014,
#   7380.2505,
#   6250.8687,
#   5984.7793,
#   6514.0186,
#   6012.1816,
#   6030.447,
#   7981.879,
#   6320.93,
#   6619.2163,
#   6352.8037,
#   6638.699,
#   6574.4263,
#   6906.7754,
#   6258.5415,
#   6674.295,
#   7276.952,
#   6702.5435,
#   6374.8506,
#   7062.711,
#   6528.266,
#   7791.7637,
#   7133.088,
#   7558.763,
#   7395.6543,
#   7870.137,
#   6177.6567,
#   5654.605,
#   6743.3853,
#   7323.3467,
#   7335.3047,
#   6541.915,
#   7728.85,
#   6662.476,
#   7343.8496,
#   6954.132,
#   7188.5576,
#   8164.6123,
#   7252.6777,
#   7579.5576,
#   6822.249,
#   5938.0713,
#   5607.1826,
#   6907.589,
#   5737.866,
#   6247.088,
#   7697.2354,
#   6637.5713,
#   6514.091,
#   7819.581,
#   7727.26,
#   6401.92,
#   6514.8984,
#   7380.837,
#   6998.9336,
#   6370.1123,
#   8173.62,
#   5782.584,
#   7303.09,
#   6038.591,
#   6175.999,
#   5853.5947,
#   7838.4707,
#   6650.4917,
#   6963.5747,
#   6377.4688,
#   7711.035,
#   7876.964,
#   6370.1104,
#   6950.3047,
#   8760.013,
#   5635.803,
#   6518.3755,
#   7092.7075,
#   6975.7427,
#   7230.519,
#   5647.6846,
#   6853.1406,
#   7832.078,
#   7909.9487,
#   8009.7275,
#   7223.7744,
#   6883.472,
#   6720.443,
#   7039.017,
#   7709.72,
#   7460.764,
#   6290.8574,
#   7078.2183,
#   7561.251,
#   6577.3804,
#   7187.455,
#   5890.103,
#   6314.303,
#   7475.3164,
#   6860.0986,
#   7025.005,
#   7923.476,
#   6366.6245,
#   6639.482,
#   7053.5117,
#   8058.653,
#   6865.699,
#   6681.606,
#   7116.916,
#   6339.135,
#   6117.028,
#   7226.5938,
#   7130.051,
#   5050.1636,
#   7278.1846,
#   7063.084,
#   7997.955,
#   7840.7793,
#   4834.564,
#   6992.183,
#   6779.4463,
#   6430.62,
#   6710.1943,
#   7133.0947,
#   6607.3965,
#   6077.157,
#   6838.868,
#   5964.2993,
#   5719.7285,
#   6920.004,
#   8668.913,
#   6781.054,
#   7118.347,
#   7539.4106,
#   7814.14,
#   6555.703,
#   6713.284,
#   8149.0317,
#   8191.475,
#   5269.4414,
#   6466.6377,
#   6602.22,
#   7382.7065,
#   6755.4775,
#   6439.3936,
#   7269.5327,
#   5260.88,
#   6933.797,
#   7213.3345,
#   7526.4644,
#   6699.037,
#   7036.139,
#   7159.0713,
#   7558.9766,
#   6747.737,
#   8086.043,
#   6563.412,
#   7651.902,
#   6590.039,
#   6203.198,
#   7248.5186,
#   6719.784,
#   6851.172,
#   6626.6543,
#   6576.9414,
#   6172.168,
#   8738.748,
#   7506.037,
#   7347.666,
#   5120.8496,
#   6117.3784,
#   7385.834,
#   7527.181,
#   6719.3584,
#   6932.835,
#   6723.716,
#   7921.2925,
#   6438.582,
#   7823.552,
#   6326.034,
#   6159.0244,
#   6772.782,
#   5229.2075,
#   6748.05,
#   6880.324,
#   6656.604,
#   6604.816,
#   7192.855,
#   8016.1104,
#   7232.526,
#   6701.504,
#   7010.5044,
#   6499.0786,
#   7530.672,
#   6847.91,
#   7451.371,
#   6084.1094,
#   7264.8696,
#   7424.424,
#   6658.8857,
#   7022.1914,
#   6717.758,
#   6694.0586,
#   7156.739,
#   7728.259,
#   7116.984,
#   6483.7905,
#   7149.563,
#   7384.6797,
#   6885.0605,
#   6850.6074,
#   6581.203,
#   6559.8584,
#   6517.702,
#   6621.33,
#   7792.855,
#   6230.719,
#   5708.643,
#   6760.203,
#   4840.1753,
#   6195.2466,
#   6419.34,
#   7507.204,
#   6962.472,
#   7080.2666,
#   6733.5835,
#   6154.6914,
#   6338.247,
#   5999.3027,
#   6775.0547,
#   5957.8257,
#   6266.977,
#   6387.2754,
#   6829.6826,
#   5744.895,
#   5494.97,
#   6122.493,
#   6022.009,
#   6459.6924,
#   5708.7188,
#   5709.5957,
#   5830.3677,
#   6653.617,
#   5620.0415,
#   6543.7944,
#   5647.1626,
#   6540.645,
#   6563.709,
#   7254.7114,
#   5837.3623,
#   5611.787,
#   4946.295,
#   5272.6816,
#   7339.9873,
#   6721.865,
#   5048.4976,
#   5744.093,
#   5830.7847,
#   4997.3115,
#   6272.703,
#   5323.3545,
#   4862.6665,
#   6351.3755,
#   5603.9766,
#   5233.9355,
#   5256.834,
#   6220.548,
#   5647.7393,
#   5908.335,
#   6116.0254,
#   6489.0605,
#   5995.8213,
#   5663.5103,
#   5451.1064,
#   5516.519,
#   5500.0605,
#   6235.02,
#   5024.712,
#   6547.7275,
#   5468.2827,
#   5055.138,
#   5993.7188,
#   6571.4346,
#   5386.8516,
#   4812.501,
#   4925.9316,
#   5279.9272,
#   5252.5776,
#   4910.9336,
#   6047.0547,
#   5916.4727,
#   5569.3027,
#   5826.6973,
#   6299.8486,
#   5647.373,
#   6290.8584,
#   4551.1484,
#   5348.0757,
#   5068.132,
#   5563.7686,
#   4666.5635,
#   5371.3145,
#   5138.6313,
#   5078.7627,
#   5268.7188,
#   4564.7935,
#   5362.708,
#   4989.5186,
#   5134.4165,
#   4679.2393,
#   5542.0957,
#   5527.298,
#   5919.3936,
#   6461.4634,
#   5558.304,
#   5335.74,
#   5277.48,
#   6976.5693,
#   5551.0684,
#   5105.274,
#   5487.273,
#   6991.6904,
#   5925.95,
#   5671.748,
#   5188.3154,
#   6370.853,
#   5404.276,
#   5426.6406,
#   6106.052,
#   5605.873,
#   5450.205,
#   4632.52,
#   5639.785,
#   5690.987,
#   4948.216,
#   4830.535,
#   5634.1924,
#   5327.6616,
#   4803.294,
#   5080.288,
#   5769.9155,
#   5261.642,
#   6506.079,
#   5431.5366,
#   5253.1084,
#   5550.9907,
#   5086.333,
#   6318.3955,
#   5669.188,
#   5440.3306,
#   4957.111,
#   4177.524,
#   4510.45,
#   4929.04,
#   4709.802,
#   4201.323,
#   5358.277,
#   4961.262,
#   5223.0444,
#   4345.2007,
#   5110.546,
#   5864.564,
#   6257.6323,
#   6080.874,
#   5073.549,
#   4966.9287,
#   6132.2305,
#   4662.0337,
#   4600.2705,
#   5331.742,
#   4775.145,
#   5155.0654,
#   5004.8335,
#   5187.592,
#   6188.0605,
#   5887.748,
#   4137.598,
#   4653.581,
#   4653.5244,
#   5402.967,
#   5575.8486,
#   5129.745,
#   4670.032,
#   5509.971,
#   4521.1904,
#   4627.455,
#   4403.8955,
#   5087.68,
#   5138.68,
#   6031.2363,
#   5437.664,
#   4864.231,
#   4902.6807,
#   3975.6418,
#   4112.233,
#   3999.635,
#   4556.5293,
#   4759.0005,
#   4529.858,
#   5139.3228,
#   4221.256,
#   4557.872,
#   4146.135,
#   4670.964,
#   3582.1404,
#   5300.6514,
#   5655.2373,
#   3761.9287,
#   5883.2075,
#   5056.8984,
#   4545.998,
#   4788.5244,
#   5863.83,
#   4957.2236,
#   3723.0544,
#   4274.205,
#   4986.933,
#   4647.122,
#   4576.496,
#   5022.0977,
#   4280.183,
#   5498.4106,
#   4659.127,
#   5481.393,
#   4285.5195,
#   4911.819,
#   3960.6191,
#   3817.7434,
#   4903.58,
#   5159.0537,
#   4168.197,
#   4241.8154,
#   4076.6426,
#   4193.0654,
#   4183.6445,
#   3830.0894,
#   4224.1826,
#   3189.7158,
#   3810.2837,
#   5774.304,
#   3932.0005,
#   4657.7363,
#   3657.388,
#   4731.698,
#   3798.2664,
#   3788.9507,
#   3338.4688,
#   2863.587,
#   3243.6328,
#   2903.4602,
#   3814.5696,
#   3475.3647,
#   3824.9673,
#   3168.6519,
#   4038.9412,
#   3879.264,
#   3759.5332,
#   3060.4924,
#   4590.376,
#   3146.4314,
#   3687.8843,
#   3633.3481,
#   3182.2188,
#   4210.1104,
#   4193.092,
#   3656.6804,
#   3542.6125,
#   3935.6733,
#   3258.8174,
#   2978.2761,
#   2656.3406,
#   3383.0583,
#   3098.6787,
#   2990.7803,
#   3098.1094,
#   3410.5295,
#   2921.4077,
#   3834.9417,
#   2563.0286,
#   2591.6184,
#   2650.132,
#   3027.9236,
#   3677.099,
#   2830.7944,
#   2994.5034,
#   3040.032,
#   3041.7747,
#   2363.7227,
#   2871.8933,
#   2811.4932,
#   2444.7927,
#   3365.0757,
#   2482.8813,
#   2551.4485,
#   2586.8423,
#   2151.3652,
#   2147.7837,
#   2646.8708,
#   2371.841,
#   3030.8662,
#   2621.226,
#   2753.7734,
#   2665.8767,
#   2107.2705,
#   3557.0776,
#   2528.8093,
#   2581.4924,
#   2165.084,
#   2468.2063,
#   2292.9683,
#   2544.6274,
#   1987.4731,
#   1900.1581,
#   2237.3074,
#   2196.1934,
#   2425.2417,
#   2373.0374,
#   2707.3413,
#   2150.348,
#   2620.1707,
#   2077.2307,
#   2245.6226,
#   2452.7798,
#   2054.7393,
#   2279.3848,
#   2449.4963,
#   2170.6375,
#   2463.9312,
#   1767.2916,
#   2124.0146,
#   2209.603,
#   2128.3564,
#   2018.1119,
#   1714.6853,
#   1879.3525,
#   2156.677,
#   1978.0638,
#   2061.704,
#   2131.5684,
#   2014.8884,
#   2285.5593,
#   2606.5999,
#   1722.5383,
#   1931.2087,
#   2092.9321,
#   1695.4523,
#   2043.8594,
#   2156.7002,
#   2008.584,
#   2285.0818,
#   1975.9126,
#   2153.6292,
#   1889.9333,
#   1788.9642,
#   1772.7327,
#   2207.4814,
#   1831.0521,
#   1922.7399,
#   2427.5266,
#   1914.7227,
#   2119.1035,
#   1918.274,
#   2335.6626,
#   1545.3774,
#   1635.556,
#   1765.5134,
#   1961.1831,
#   1685.7097,
#   1955.9149,
#   2003.107,
#   1509.0535,
#   1700.07,
#   1772.5745,
#   1414.9229,
#   1957.4899,
#   1990.1963,
#   1533.9503,
#   2037.8279,
#   1766.5107,
#   1808.1777,
#   1195.7395,
#   1675.6716,
#   1614.0383,
#   1742.5417,
#   1744.3728,
#   1574.2971,
#   1342.0776,
#   1519.3595,
#   1296.2769,
#   1493.131,
#   1276.3922,
#   1600.0474,
#   1401.1119,
#   1610.3794,
#   1202.228,
#   1489.1489,
#   1169.3743,
#   1661.7642,
#   1281.7386,
#   1402.2781,
#   1398.3062,
#   1634.7295,
#   1248.1926,
#   1386.9949,
#   1262.1995,
#   1745.5518,
#   1223.3392,
#   1441.8575,
#   1316.4819,
#   1118.3932,
#   1298.1973,
#   1089.0159,
#   1377.2634,
#   1228.2229,
#   1554.7928,
#   1357.0347,
#   1309.1323,
#   1022.85724,
#   1449.1678,
#   1356.6761,
#   1110.7732,
#   1487.7489,
#   1601.675,
#   1057.7571,
#   1213.7444,
#   1211.7107,
#   1164.556,
#   1618.5833,
#   1077.1265,
#   1347.8733,
#   1221.6038,
#   1366.7019,
#   1293.5591,
#   1266.8726,
#   1356.1659,
#   1125.3047,
#   1188.1597,
#   1487.1897,
#   1099.4792,
#   1024.6859,
#   1221.4469,
#   967.12115,
#   846.3959,
#   1069.8643,
#   1060.8019,
#   1505.6858,
#   1001.3317,
#   1107.6855,
#   906.81946,
#   1221.4132,
#   953.5255,
#   972.1139,
#   916.6146,
#   1099.3728,
#   1068.0737,
#   918.46936,
#   853.14844,
#   982.6379,
#   982.8237,
#   977.2936,
#   821.5117,
#   976.63965,
#   784.2977,
#   1104.2607,
#   865.87286,
#   764.86487,
#   756.03235,
#   1156.6589,
#   779.7728,
#   763.1354,
#   854.3722,
#   716.343,
#   780.7175,
#   783.7805,
#   881.3626,
#   668.8321,
#   668.38763,
#   947.5158,
#   626.88855,
#   709.9233,
#   714.2858,
#   714.29407,
#   746.28253,
#   749.02844,
#   625.4365,
#   704.52637,
#   772.8771,
#   620.5946,
#   686.1634,
#   694.5642,
#   595.1389,
#   776.2976,
#   869.88007,
#   740.49567,
#   621.042,
#   671.49,
#   835.1089,
#   801.0167,
#   640.5044,
#   525.49976,
#   607.8796,
#   728.2782,
#   770.0738,
#   737.9554,
#   795.0756,
#   519.9313,
#   719.0362,
#   659.19147,
#   641.6685,
#   538.7065,
#   665.8827,
#   585.8793,
#   449.48108,
#   559.67065,
#   559.54456,
#   525.0398,
#   590.37286,
#   489.22775,
#   557.84534,
#   626.44824,
#   727.8195,
#   598.0258,
#   754.8139,
#   540.5189,
#   503.9799,
#   419.01425,
#   509.52817,
#   387.48566,
#   495.57755,
#   570.5853,
#   467.59845,
#   699.89124,
#   430.1518,
#   538.3843,
#   384.90613,
#   559.2457,
#   422.93323,
#   459.27823,
#   463.72876,
#   553.2642,
#   531.06683,
#   519.8984,
#   503.74445,
#   507.12366,
#   425.4579,
#   405.3245,
#   299.88312,
#   412.51508,
#   499.91974,
#   555.90826,
#   434.0046,
#   451.9567,
#   423.83963,
#   719.8574,
#   463.68042,
#   434.6618,
#   342.3078,
#   492.62637,
#   453.47998,
#   348.6696,
#   391.67108,
#   556.2256,
#   512.8445,
#   448.534,
#   483.51746,
#   336.21768,
#   486.59097,
#   388.96936,
#   427.40344,
#   341.6626,
#   453.56018,
#   459.929,
#   533.037,
#   391.2483,
#   387.07712,
#   424.29932,
#   487.01617,
#   400.36127,
#   388.22375,
#   332.52234,
#   397.62518,
#   296.0594,
#   357.46832,
#   369.13855,
#   421.414,
#   376.57788,
#   376.00464,
#   446.37643,
#   239.54248,
#   396.51294,
#   375.01846,
#   443.13635,
#   389.9818,
#   371.14062,
#   418.18234,
#   427.29822,
#   319.2578,
#   343.29755,
#   426.71884,
#   279.51364,
#   412.86066,
#   266.2694,
#   328.82043,
#   271.9735,
#   271.2713,
#   420.7223,
#   394.93555,
#   383.79474,
#   354.09457,
#   240.56256,
#   374.24042,
#   366.63416,
#   317.71506,
#   299.02023,
#   381.0122,
#   369.35074,
#   374.97696,
#   278.67426,
#   252.46985,
#   253.56293,
#   432.6277,
#   284.64917,
#   275.39084,
#   256.59106,
#   380.61084,
#   237.17053,
#   327.4934,
#   315.24103,
#   299.53418,
#   384.2788,
#   316.37003,
#   327.76703,
#   328.61584,
#   312.3827,
#   351.29376,
#   250.75665,
#   237.40074,
#   252.54443,
#   251.8377,
#   294.89874,
#   255.76068,
#   280.3119,
#   240.01764,
#   278.85663,
#   344.69385,
#   285.35474,
#   248.75919,
#   306.48245,
#   315.30634,
#   293.7044,
#   303.78226,
#   336.9605,
#   301.98956,
#   329.47803,
#   309.47385,
#   273.61304,
#   326.1684,
#   306.0219,
#   284.59772,
#   270.1894,
#   280.63458,
#   334.12695,
#   195.1917,
#   232.0741,
#   245.96136,
#   300.6695,
#   293.22058,
#   320.5183,
#   276.88672,
#   247.6552,
#   275.79742,
#   332.89694,
#   346.24982,
#   322.7379,
#   262.47345,
#   248.57266,
#   355.33276,
#   310.27362,
#   274.49664,
#   299.93402,
#   264.70697,
#   303.95758,
#   259.0704,
#   311.8214,
#   357.5605,
#   165.66873,
#   338.06134,
#   233.81973,
#   191.60083,
#   243.85913,
#   249.44318,
#   161.31287,
#   251.8237,
#   235.48329,
#   324.69647,
#   277.1679,
#   207.52292,
#   216.04121,
#   210.63977,
#   251.67932,
#   233.63383,
#   193.08762,
#   253.28476,
#   285.8996,
#   175.11195,
#   254.44916,
#   307.24585,
#   268.77914,
#   ...],
#  'loss_bcs': [0,
#   0.57605463,
#   0.40509263,
#   0.3584137,
#   0.23033273,
#   0.13364358,
#   0.073298454,
#   0.039864406,
#   0.019853922,
#   0.0092602335,
#   0.008958859,
#   0.013481975,
#   0.020176673,
#   0.028084159,
#   0.032671325,
#   0.030498741,
#   0.034413487,
#   0.03748281,
#   0.043833274,
#   0.051500816,
#   0.051237214,
#   0.066547774,
#   0.06547208,
#   0.08104859,
#   0.08618546,
#   0.09929996,
#   0.11037862,
#   0.12272613,
#   0.14567766,
#   0.1687648,
#   0.18818578,
#   0.2164785,
#   0.20787895,
#   0.17367572,
#   0.14579068,
#   0.11287415,
#   0.08558399,
#   0.07242088,
#   0.062308125,
#   0.057056602,
#   0.05269938,
#   0.063210845,
#   0.066053845,
#   0.06817281,
#   0.073310785,
#   0.07678108,
#   0.09268578,
#   0.09641977,
#   0.11065507,
#   0.121911764,
#   0.14509585,
#   0.13771203,
#   0.15093109,
#   0.13671403,
#   0.15724753,
#   0.1358621,
#   0.13014124,
#   0.10268613,
#   0.11505812,
#   0.10583669,
#   0.103072084,
#   0.09527209,
#   0.097612195,
#   0.0945973,
#   0.089495,
#   0.07551984,
#   0.08565715,
#   0.09379162,
#   0.094908156,
#   0.09435041,
#   0.102401406,
#   0.10192874,
#   0.113379024,
#   0.114646725,
#   0.10758814,
#   0.11279476,
#   0.11375863,
#   0.12663028,
#   0.119116135,
#   0.12782419,
#   0.1331084,
#   0.15410377,
#   0.17429003,
#   0.19179977,
#   0.19337374,
#   0.19291186,
#   0.20034045,
#   0.21404034,
#   0.25255835,
#   0.25630197,
#   0.27331093,
#   0.29927713,
#   0.30824113,
#   0.31554586,
#   0.2700765,
#   0.2834096,
#   0.24519604,
#   0.220589,
#   0.21694125,
#   0.22488686,
#   0.2257421,
#   0.26723006,
#   0.2901331,
#   0.32394004,
#   0.38600728,
#   0.42456985,
#   0.42000002,
#   0.45100945,
#   0.50511986,
#   0.5513461,
#   0.5586062,
#   0.6385983,
#   0.64953697,
#   0.6527686,
#   0.6517352,
#   0.6134429,
#   0.61667544,
#   0.6168389,
#   0.5728351,
#   0.560124,
#   0.53555214,
#   0.49352437,
#   0.5331087,
#   0.50797623,
#   0.5294522,
#   0.62310857,
#   0.68307745,
#   0.693151,
#   0.7018878,
#   0.771398,
#   0.80549186,
#   0.82182056,
#   0.7866246,
#   0.8216374,
#   0.74827814,
#   0.7622741,
#   0.7729539,
#   0.84526193,
#   0.8912911,
#   0.9661614,
#   1.0376117,
#   1.00801,
#   1.1327167,
#   1.154165,
#   1.1931369,
#   1.3466401,
#   1.4248015,
#   1.4843428,
#   1.6052186,
#   1.498084,
#   1.8102301,
#   1.7800399,
#   1.9569342,
#   1.9016443,
#   1.9276528,
#   1.9160377,
#   1.8357656,
#   1.9940504,
#   1.789011,
#   2.0097008,
#   1.9796536,
#   2.1390836,
#   1.9940642,
#   2.0870476,
#   2.0297167,
#   1.872471,
#   2.1429536,
#   2.011722,
#   2.1788065,
#   2.264504,
#   2.3834245,
#   2.5130014,
#   2.8127303,
#   3.0442793,
#   2.8380625,
#   2.8652956,
#   3.2617698,
#   2.828683,
#   3.2353659,
#   2.8644986,
#   3.410425,
#   3.6655545,
#   3.7611406,
#   3.8227377,
#   3.7499628,
#   4.2599998,
#   4.563924,
#   4.428367,
#   4.222173,
#   4.11596,
#   4.092524,
#   4.3528905,
#   4.273527,
#   4.3869925,
#   4.364039,
#   4.3749743,
#   4.473169,
#   4.4510508,
#   4.3974977,
#   4.3230443,
#   4.1596694,
#   4.5390863,
#   4.406588,
#   4.385808,
#   4.3148828,
#   4.65524,
#   4.598963,
#   4.7316947,
#   5.020658,
#   5.101,
#   5.298696,
#   5.310484,
#   5.3736124,
#   6.0008507,
#   5.7099657,
#   6.2755036,
#   5.958327,
#   5.798237,
#   5.8786454,
#   5.7974815,
#   5.9087043,
#   5.963958,
#   6.083791,
#   5.90201,
#   6.2897167,
#   6.3338966,
#   6.5304294,
#   6.5324507,
#   6.809705,
#   6.586458,
#   6.9189954,
#   6.354063,
#   6.468797,
#   6.519547,
#   6.083777,
#   5.596875,
#   6.606242,
#   6.4369144,
#   6.7147064,
#   7.2396197,
#   6.9613175,
#   7.6435776,
#   7.686435,
#   7.1160393,
#   7.298633,
#   7.464469,
#   7.5465837,
#   7.153531,
#   7.824634,
#   7.9553213,
#   7.7374234,
#   7.7659755,
#   8.153387,
#   8.164091,
#   8.194236,
#   8.408718,
#   8.330486,
#   8.5832615,
#   8.643392,
#   8.999114,
#   8.527504,
#   8.744686,
#   8.878404,
#   8.257432,
#   8.595547,
#   8.360577,
#   8.145179,
#   7.5651264,
#   7.859485,
#   8.159236,
#   7.967745,
#   8.290703,
#   8.813191,
#   8.763366,
#   8.695162,
#   8.5859785,
#   8.936576,
#   8.618121,
#   8.8984995,
#   8.739885,
#   8.803903,
#   9.61545,
#   10.268544,
#   10.929433,
#   11.550602,
#   11.757773,
#   12.280669,
#   12.793266,
#   12.859631,
#   13.573587,
#   14.030917,
#   14.807104,
#   14.584381,
#   15.309493,
#   14.47267,
#   14.943123,
#   15.776329,
#   14.156586,
#   13.670927,
#   14.66149,
#   14.109369,
#   13.568723,
#   14.244516,
#   13.760643,
#   14.127213,
#   13.585298,
#   12.685241,
#   12.861863,
#   12.139292,
#   12.95378,
#   12.424125,
#   12.89108,
#   13.20832,
#   12.617351,
#   12.591094,
#   12.68444,
#   12.61795,
#   13.911838,
#   12.984466,
#   12.774989,
#   11.825008,
#   12.4067135,
#   12.249687,
#   12.274075,
#   11.5838995,
#   12.349678,
#   11.086434,
#   10.915705,
#   11.041439,
#   11.383591,
#   11.655114,
#   11.155048,
#   10.31355,
#   10.12625,
#   10.561681,
#   10.6648655,
#   10.448746,
#   10.513567,
#   10.992759,
#   10.9149685,
#   10.157918,
#   11.317582,
#   11.379599,
#   11.326973,
#   11.290935,
#   11.308643,
#   12.165412,
#   12.142395,
#   11.532296,
#   12.213248,
#   11.982491,
#   12.2749605,
#   12.0618305,
#   10.954638,
#   10.55934,
#   9.870282,
#   11.030848,
#   10.357288,
#   10.428761,
#   10.413701,
#   10.271864,
#   11.066968,
#   11.463037,
#   11.371899,
#   11.631676,
#   11.360652,
#   11.874686,
#   12.629367,
#   12.047274,
#   13.555525,
#   12.783463,
#   14.271026,
#   12.395692,
#   12.984528,
#   12.992123,
#   10.558752,
#   8.872964,
#   7.74867,
#   7.717165,
#   7.9089284,
#   7.6004677,
#   7.319118,
#   7.026817,
#   6.8602934,
#   6.883867,
#   6.8223095,
#   6.953481,
#   6.807353,
#   7.129507,
#   7.258292,
#   6.610419,
#   6.7562757,
#   7.1717434,
#   6.613095,
#   7.0223,
#   7.608267,
#   7.3757086,
#   7.8862867,
#   7.1665406,
#   7.409509,
#   7.053889,
#   7.0198984,
#   6.777513,
#   8.095236,
#   7.7378597,
#   7.6834536,
#   8.018455,
#   7.7732973,
#   8.571772,
#   8.203586,
#   9.801566,
#   9.905525,
#   11.470933,
#   11.158137,
#   12.591588,
#   12.596412,
#   14.988258,
#   14.891142,
#   15.708581,
#   13.768121,
#   13.432482,
#   11.31927,
#   11.783048,
#   12.735216,
#   10.595766,
#   10.457322,
#   10.486716,
#   10.678029,
#   9.297839,
#   10.699933,
#   10.269433,
#   9.899731,
#   11.26493,
#   11.320753,
#   11.048121,
#   12.036819,
#   12.618133,
#   12.837273,
#   14.220705,
#   13.726279,
#   14.759446,
#   15.799395,
#   15.6083355,
#   17.099068,
#   16.13319,
#   17.598494,
#   16.52672,
#   16.06018,
#   16.099936,
#   15.870202,
#   15.175948,
#   15.588531,
#   14.653705,
#   14.121178,
#   14.889544,
#   13.9634075,
#   13.209207,
#   14.09082,
#   13.510334,
#   13.105839,
#   12.599161,
#   11.732845,
#   11.242247,
#   10.4611,
#   10.326343,
#   8.9687395,
#   9.516697,
#   8.862537,
#   8.736084,
#   8.576971,
#   8.964698,
#   8.812449,
#   9.120925,
#   8.8389845,
#   8.704423,
#   8.737421,
#   8.682028,
#   8.745524,
#   9.021079,
#   9.567459,
#   10.148752,
#   9.581672,
#   10.475902,
#   10.068005,
#   10.573624,
#   10.286125,
#   9.456161,
#   9.881367,
#   10.198968,
#   9.829744,
#   10.7320595,
#   10.714243,
#   10.769203,
#   12.747867,
#   12.408825,
#   12.4390135,
#   12.937672,
#   14.046163,
#   14.631374,
#   16.69099,
#   15.011219,
#   17.218565,
#   16.420956,
#   14.978456,
#   15.774475,
#   14.408502,
#   15.273823,
#   14.982235,
#   15.216729,
#   14.123826,
#   14.556048,
#   15.133946,
#   15.332363,
#   14.4587,
#   14.904143,
#   15.4153595,
#   14.329411,
#   13.927993,
#   13.6220875,
#   15.125149,
#   14.801888,
#   14.998117,
#   13.797284,
#   14.893756,
#   15.373419,
#   16.089106,
#   15.1166525,
#   15.150257,
#   15.230495,
#   15.149654,
#   14.292866,
#   14.17508,
#   15.237632,
#   12.60413,
#   14.00403,
#   14.159847,
#   14.395381,
#   15.663029,
#   15.026393,
#   15.04989,
#   15.90738,
#   16.200727,
#   16.724083,
#   16.775639,
#   17.143482,
#   17.404947,
#   16.761793,
#   16.98331,
#   17.513119,
#   17.72436,
#   18.073856,
#   18.68863,
#   18.352043,
#   19.017056,
#   18.451212,
#   19.52212,
#   18.890623,
#   19.068495,
#   19.932772,
#   18.98569,
#   17.956528,
#   18.633297,
#   18.462992,
#   17.473282,
#   18.700373,
#   18.433832,
#   18.844103,
#   20.173452,
#   19.047363,
#   21.185408,
#   20.11636,
#   21.269949,
#   21.267666,
#   22.20418,
#   24.217974,
#   22.936943,
#   24.196655,
#   24.976242,
#   21.950672,
#   23.970652,
#   23.034916,
#   24.232338,
#   22.077726,
#   23.635101,
#   23.311775,
#   23.560818,
#   22.974411,
#   22.26424,
#   22.020584,
#   19.975777,
#   21.07853,
#   20.48411,
#   21.732544,
#   21.080715,
#   20.000675,
#   19.426037,
#   19.25877,
#   20.394835,
#   18.79809,
#   19.871975,
#   18.78533,
#   18.999102,
#   18.569891,
#   17.247793,
#   18.642002,
#   18.302013,
#   17.727018,
#   19.765663,
#   19.406685,
#   18.546698,
#   19.79668,
#   19.1959,
#   20.756351,
#   20.160217,
#   19.466545,
#   19.102573,
#   19.684423,
#   19.85195,
#   20.978407,
#   18.415052,
#   19.579933,
#   21.655958,
#   21.208395,
#   20.280901,
#   20.271898,
#   19.367777,
#   21.830088,
#   19.536783,
#   20.060768,
#   20.292448,
#   18.67931,
#   18.209406,
#   20.47193,
#   19.207611,
#   18.715181,
#   20.210283,
#   20.240814,
#   20.194002,
#   19.448166,
#   20.327133,
#   19.92266,
#   19.98362,
#   18.919704,
#   18.271177,
#   17.901608,
#   17.819164,
#   19.305435,
#   18.008356,
#   19.94266,
#   18.842533,
#   18.262354,
#   18.422144,
#   18.032425,
#   18.293875,
#   17.731194,
#   17.711012,
#   19.146406,
#   18.662489,
#   17.675522,
#   19.02534,
#   16.90847,
#   17.977509,
#   18.482983,
#   19.545773,
#   19.4551,
#   19.899626,
#   19.389807,
#   20.724174,
#   18.826254,
#   18.865936,
#   18.912561,
#   18.09075,
#   17.517473,
#   17.026579,
#   17.852104,
#   18.287546,
#   19.067059,
#   18.82691,
#   18.235886,
#   18.658865,
#   19.730556,
#   20.121225,
#   19.649223,
#   18.567225,
#   19.322212,
#   19.979912,
#   19.54658,
#   21.249464,
#   20.51838,
#   20.169926,
#   20.379112,
#   20.719189,
#   20.194494,
#   20.511173,
#   20.007154,
#   19.623758,
#   20.923365,
#   20.491978,
#   21.000135,
#   20.531017,
#   19.741808,
#   20.848194,
#   20.43701,
#   20.267818,
#   20.914206,
#   19.896065,
#   18.992294,
#   19.067194,
#   21.277767,
#   19.103004,
#   20.575123,
#   21.97952,
#   22.278198,
#   21.674114,
#   22.403894,
#   23.70987,
#   22.186245,
#   21.839851,
#   22.506294,
#   22.146736,
#   22.276814,
#   21.807194,
#   20.611656,
#   22.431562,
#   22.637688,
#   23.755621,
#   23.368334,
#   22.412422,
#   22.228966,
#   21.689106,
#   22.629389,
#   22.10171,
#   23.733826,
#   23.127052,
#   22.188223,
#   23.042389,
#   24.299595,
#   21.828308,
#   23.463356,
#   23.7972,
#   23.039392,
#   23.412966,
#   24.4851,
#   25.501293,
#   23.522469,
#   23.163322,
#   22.54512,
#   23.252333,
#   22.41979,
#   21.47393,
#   24.575119,
#   21.811909,
#   22.004082,
#   24.10062,
#   22.955177,
#   22.913595,
#   24.070742,
#   25.280748,
#   21.620094,
#   22.93246,
#   22.640793,
#   24.183886,
#   21.489056,
#   23.578957,
#   22.865973,
#   24.394825,
#   24.947422,
#   23.213385,
#   24.515644,
#   25.391457,
#   23.227352,
#   26.207712,
#   26.15592,
#   25.038336,
#   26.5067,
#   25.54665,
#   24.162224,
#   23.939728,
#   25.020138,
#   25.91378,
#   25.485138,
#   26.675808,
#   26.818233,
#   26.70404,
#   25.465092,
#   25.59489,
#   25.09094,
#   26.384571,
#   25.706062,
#   25.000792,
#   25.29727,
#   26.472507,
#   25.228268,
#   24.572313,
#   24.686626,
#   23.969534,
#   26.003551,
#   25.024006,
#   27.052711,
#   26.400347,
#   25.559105,
#   27.597506,
#   27.229725,
#   23.881641,
#   26.094978,
#   26.535099,
#   24.82176,
#   25.062405,
#   26.262774,
#   24.846567,
#   25.440193,
#   24.797466,
#   24.38321,
#   26.573069,
#   26.351324,
#   26.22002,
#   23.747564,
#   27.028076,
#   25.509861,
#   26.62925,
#   27.349897,
#   26.400017,
#   25.20826,
#   25.944708,
#   26.729973,
#   27.102127,
#   26.809368,
#   26.334904,
#   28.637611,
#   26.137241,
#   25.107662,
#   25.939594,
#   24.146023,
#   24.997208,
#   26.068901,
#   26.13954,
#   26.933193,
#   27.408897,
#   27.86969,
#   27.38114,
#   27.016132,
#   26.385765,
#   26.700657,
#   25.996107,
#   26.552864,
#   25.97082,
#   26.39159,
#   25.425726,
#   25.317684,
#   26.243633,
#   26.449009,
#   25.567406,
#   26.123081,
#   26.203442,
#   25.151598,
#   25.866936,
#   25.278109,
#   24.983929,
#   26.720633,
#   26.151829,
#   26.522026,
#   27.3143,
#   27.544008,
#   25.88373,
#   25.21717,
#   25.574587,
#   26.271896,
#   26.681944,
#   24.974913,
#   26.730135,
#   28.18783,
#   26.530956,
#   25.236286,
#   26.223314,
#   27.420311,
#   26.444912,
#   25.123196,
#   27.33537,
#   24.466877,
#   26.160896,
#   25.004053,
#   26.096786,
#   26.160213,
#   25.338696,
#   26.12399,
#   25.383734,
#   25.245724,
#   26.15556,
#   25.09417,
#   25.410942,
#   25.400349,
#   23.879953,
#   25.637587,
#   24.893633,
#   25.486532,
#   25.312153,
#   25.692884,
#   25.513058,
#   26.009298,
#   25.028097,
#   25.905237,
#   26.09066,
#   24.513777,
#   25.85003,
#   27.106258,
#   25.751673,
#   26.064358,
#   25.08292,
#   25.325047,
#   24.127426,
#   25.059967,
#   23.89631,
#   24.834751,
#   24.887426,
#   24.975842,
#   23.0514,
#   23.712406,
#   23.893517,
#   24.029974,
#   24.756584,
#   26.771479,
#   25.3358,
#   23.929749,
#   24.280754,
#   24.464918,
#   23.573631,
#   25.45541,
#   25.278793,
#   24.019062,
#   24.523098,
#   24.937035,
#   25.350359,
#   25.408978,
#   26.974483,
#   24.588634,
#   23.542583,
#   24.644947,
#   23.929657,
#   23.954924,
#   22.31759,
#   23.968521,
#   24.651215,
#   24.735573,
#   24.418055,
#   24.909966,
#   23.218632,
#   23.354382,
#   23.621897,
#   23.564087,
#   23.165533,
#   22.201973,
#   24.10582,
#   24.445211,
#   24.31455,
#   23.987402,
#   23.888653,
#   23.991425,
#   22.18416,
#   23.003366,
#   22.457333,
#   23.573742,
#   24.659538,
#   23.101206,
#   23.565666,
#   23.901451,
#   22.46953,
#   23.474586,
#   23.85657,
#   22.901356,
#   22.607841,
#   22.43894,
#   23.634024,
#   22.44428,
#   23.747114,
#   22.539377,
#   22.313969,
#   21.830524,
#   23.563793,
#   22.225159,
#   22.981775,
#   22.454924,
#   21.918436,
#   22.30513,
#   22.866653,
#   21.87803,
#   22.78576,
#   21.888443,
#   22.895113,
#   22.732046,
#   21.751394,
#   22.966778,
#   22.357075,
#   22.121716,
#   21.195463,
#   22.405064,
#   22.146347,
#   22.446644,
#   23.186882,
#   22.926754,
#   23.563627,
#   ...],
#  'loss_bc1': [0,
#   0.16271451,
#   0.0955867,
#   0.0702608,
#   0.043053236,
#   0.022652967,
#   0.009951834,
#   0.0034532058,
#   0.00082918844,
#   0.0011679674,
#   0.003875269,
#   0.0077080624,
#   0.012582602,
#   0.01772198,
#   0.020214308,
#   0.018905906,
#   0.021472711,
#   0.023703363,
#   0.027146772,
#   0.028713651,
#   0.023449894,
#   0.030992601,
#   0.030656347,
#   0.03633888,
#   0.03572301,
#   0.035071634,
#   0.037129708,
#   0.036981873,
#   0.05063305,
#   0.051138084,
#   0.05541949,
#   0.06547173,
#   0.05869662,
#   0.04607203,
#   0.041741423,
#   0.030469688,
#   0.022451578,
#   0.019083481,
#   0.0151758995,
#   0.011810157,
#   0.008339096,
#   0.006711093,
#   0.006462774,
#   0.0074918834,
#   0.008541705,
#   0.0080657955,
#   0.00829315,
#   0.0068943296,
#   0.0047311676,
#   0.0028561705,
#   0.0026517743,
#   0.0027576557,
#   0.0023277288,
#   0.0037968233,
#   0.0033270968,
#   0.0021618241,
#   0.0014467179,
#   0.0017436057,
#   0.0019777687,
#   0.0031555742,
#   0.0049595535,
#   0.006819386,
#   0.01016918,
#   0.016513864,
#   0.021395516,
#   0.02428167,
#   0.037192788,
#   0.047347844,
#   0.05478553,
#   0.05801109,
#   0.06397285,
#   0.064047694,
#   0.070307955,
#   0.06676308,
#   0.060946155,
#   0.062542856,
#   0.059040643,
#   0.05993664,
#   0.051044367,
#   0.0526731,
#   0.04429534,
#   0.04832472,
#   0.051049702,
#   0.041431062,
#   0.04127291,
#   0.030658163,
#   0.02883083,
#   0.03273754,
#   0.041104015,
#   0.04247866,
#   0.05267574,
#   0.057095386,
#   0.058888912,
#   0.06660612,
#   0.070112735,
#   0.09073958,
#   0.09276755,
#   0.09924936,
#   0.10333374,
#   0.116723806,
#   0.11790778,
#   0.15688577,
#   0.17234488,
#   0.18796353,
#   0.21908118,
#   0.23787978,
#   0.22787036,
#   0.21480624,
#   0.24107538,
#   0.2702142,
#   0.26749712,
#   0.3304363,
#   0.30565336,
#   0.34109306,
#   0.30167118,
#   0.30548733,
#   0.29016232,
#   0.3086758,
#   0.2815967,
#   0.27866095,
#   0.29508185,
#   0.27583116,
#   0.3282071,
#   0.31530878,
#   0.30459177,
#   0.36029404,
#   0.36298788,
#   0.35227743,
#   0.37413886,
#   0.4124127,
#   0.40716463,
#   0.43323514,
#   0.45807946,
#   0.42939425,
#   0.4578079,
#   0.4997214,
#   0.47730553,
#   0.52070886,
#   0.5077292,
#   0.52881956,
#   0.5670144,
#   0.5219195,
#   0.6371691,
#   0.65787834,
#   0.62978506,
#   0.68800026,
#   0.80363894,
#   0.7782651,
#   0.8739158,
#   0.7778708,
#   0.9924127,
#   0.89381653,
#   1.0461909,
#   0.9284636,
#   1.0267053,
#   1.026489,
#   0.91403353,
#   0.95327216,
#   0.94247395,
#   1.0523527,
#   1.0964934,
#   1.1429901,
#   0.9752628,
#   0.95040125,
#   1.0428672,
#   0.91829664,
#   1.0952549,
#   0.98702717,
#   1.0913932,
#   1.0442429,
#   1.116838,
#   1.1803734,
#   1.3528986,
#   1.4241443,
#   1.3251023,
#   1.2245241,
#   1.3698325,
#   1.1319816,
#   1.2516766,
#   1.2205987,
#   1.397485,
#   1.5215755,
#   1.487534,
#   1.63723,
#   1.6497033,
#   2.0396006,
#   2.3546982,
#   2.0727034,
#   1.9889852,
#   1.9618177,
#   1.7748921,
#   1.9160767,
#   1.8854226,
#   1.8875501,
#   1.7369074,
#   1.7642636,
#   1.6751101,
#   1.4505676,
#   1.654153,
#   1.4718641,
#   1.4026961,
#   1.5800881,
#   1.4557521,
#   1.5157685,
#   1.4803513,
#   1.8204384,
#   1.786248,
#   1.8792772,
#   2.0487313,
#   2.1360261,
#   2.2743607,
#   2.2537694,
#   2.3757997,
#   2.8385053,
#   2.6794,
#   2.864499,
#   2.810809,
#   2.5904396,
#   2.7932446,
#   2.7780366,
#   2.7968752,
#   2.6727276,
#   2.7321672,
#   2.7048013,
#   2.9509506,
#   2.983178,
#   3.455546,
#   3.337163,
#   3.5268047,
#   3.560932,
#   3.9502418,
#   3.3065748,
#   3.3452563,
#   3.3601174,
#   3.0098662,
#   2.825138,
#   3.6462975,
#   3.739078,
#   3.786735,
#   4.2309823,
#   4.2093368,
#   4.4421062,
#   4.31625,
#   4.09291,
#   3.923113,
#   4.09783,
#   4.009325,
#   4.0019546,
#   4.0258017,
#   3.8403628,
#   3.9447002,
#   3.5649705,
#   3.7955394,
#   3.3004289,
#   3.2187395,
#   3.2987595,
#   3.057514,
#   2.7258902,
#   2.771675,
#   2.72967,
#   2.6186461,
#   2.6500838,
#   2.9221122,
#   2.7738547,
#   2.596863,
#   2.784702,
#   2.6369083,
#   2.705795,
#   2.7035108,
#   2.9201636,
#   3.1018622,
#   3.2063422,
#   3.2819927,
#   3.3195405,
#   3.0939176,
#   3.217753,
#   3.4658918,
#   3.3418622,
#   3.5604882,
#   3.3364487,
#   3.2196805,
#   4.0047894,
#   4.410409,
#   4.862565,
#   4.914862,
#   5.484912,
#   5.353283,
#   5.869046,
#   5.9712086,
#   5.758686,
#   6.6228395,
#   7.1224422,
#   6.8570375,
#   6.7917295,
#   6.110178,
#   6.94456,
#   6.9071302,
#   6.241042,
#   6.2503796,
#   6.081254,
#   5.9081817,
#   5.553831,
#   5.987793,
#   4.553133,
#   4.896172,
#   4.455661,
#   4.2684064,
#   3.545033,
#   3.18379,
#   3.1871808,
#   3.240009,
#   2.9353452,
#   2.9635892,
#   2.749897,
#   2.5680487,
#   2.5966382,
#   2.8537579,
#   3.0250945,
#   2.9939337,
#   3.4195118,
#   2.703203,
#   3.4724965,
#   3.5655003,
#   3.6264524,
#   3.6312165,
#   3.649371,
#   4.0675735,
#   3.7950912,
#   4.0673027,
#   4.1848717,
#   4.0365314,
#   4.5033636,
#   4.0383515,
#   3.7413235,
#   3.9271674,
#   4.1673193,
#   3.6738663,
#   3.8719602,
#   3.7683313,
#   3.5673494,
#   3.4435272,
#   3.3537645,
#   3.053451,
#   2.828245,
#   2.627316,
#   3.0283237,
#   2.902413,
#   2.8632658,
#   2.6208944,
#   2.7327616,
#   2.7633083,
#   2.9015388,
#   2.502827,
#   2.3998008,
#   2.45825,
#   2.4135995,
#   2.9571974,
#   2.6324253,
#   3.119038,
#   3.3442059,
#   3.3866382,
#   3.714065,
#   4.330271,
#   4.086938,
#   4.3640585,
#   4.467105,
#   4.2237697,
#   4.647424,
#   4.552825,
#   4.602257,
#   5.182069,
#   5.247521,
#   4.5692754,
#   4.4055758,
#   4.897329,
#   3.2463078,
#   2.678726,
#   2.3062732,
#   2.3986423,
#   1.958955,
#   1.9010527,
#   1.8833616,
#   2.05473,
#   1.9287324,
#   1.939899,
#   2.1844494,
#   1.9581496,
#   2.2788093,
#   2.002684,
#   2.1421797,
#   2.2643871,
#   2.3682024,
#   2.278953,
#   2.0615227,
#   2.4189663,
#   2.2820818,
#   2.206001,
#   2.437078,
#   2.1657488,
#   2.109187,
#   2.2445118,
#   1.9054859,
#   2.0793722,
#   2.1870387,
#   2.0090208,
#   2.1687188,
#   2.5748997,
#   2.2505994,
#   2.5895894,
#   2.5983891,
#   3.0600457,
#   3.3854575,
#   3.4928594,
#   4.288553,
#   4.9450455,
#   4.866059,
#   5.6963835,
#   6.946063,
#   6.5625916,
#   5.4415483,
#   5.4757595,
#   4.86201,
#   5.017179,
#   4.7498775,
#   4.073875,
#   3.8947406,
#   3.7736034,
#   4.0335174,
#   2.7902935,
#   3.6514168,
#   3.5569239,
#   3.4890018,
#   3.249713,
#   4.3693304,
#   3.6612444,
#   4.182238,
#   4.042801,
#   4.153681,
#   4.9504175,
#   4.8452177,
#   5.0993896,
#   5.1558704,
#   5.214085,
#   6.1384983,
#   5.395098,
#   6.307301,
#   5.2907386,
#   5.107003,
#   5.7497296,
#   5.7074304,
#   5.002289,
#   5.1673517,
#   4.9321766,
#   5.1859283,
#   5.691322,
#   4.8098726,
#   5.006217,
#   5.6599092,
#   5.51773,
#   4.726714,
#   4.8695107,
#   4.575706,
#   4.325156,
#   4.183873,
#   3.8670542,
#   3.555015,
#   3.5184174,
#   3.4740958,
#   3.126385,
#   3.1636276,
#   3.1878426,
#   3.2651267,
#   3.009492,
#   3.0994787,
#   2.761653,
#   2.9940195,
#   2.7918856,
#   2.784016,
#   3.020187,
#   3.065961,
#   3.184071,
#   2.954205,
#   2.9645236,
#   2.9157615,
#   2.9541118,
#   2.9161534,
#   3.0543199,
#   2.826757,
#   2.8249645,
#   2.7925937,
#   2.8547027,
#   3.0664563,
#   3.432496,
#   3.99872,
#   3.656006,
#   4.203876,
#   4.677497,
#   4.687167,
#   5.3615866,
#   6.0485086,
#   5.899862,
#   6.4394484,
#   6.407875,
#   5.5676837,
#   5.1803584,
#   4.746787,
#   4.998088,
#   4.6503167,
#   5.1725035,
#   4.365332,
#   4.96574,
#   4.671269,
#   5.0622044,
#   4.3322463,
#   4.8249826,
#   5.1555557,
#   5.0511713,
#   4.582347,
#   3.7814558,
#   4.832579,
#   4.8827343,
#   4.419716,
#   4.481756,
#   4.541833,
#   4.680931,
#   5.225416,
#   4.7454953,
#   4.258094,
#   4.1076584,
#   4.27872,
#   4.268366,
#   3.491556,
#   4.0141983,
#   3.3372738,
#   3.5386138,
#   3.9050522,
#   3.9267657,
#   4.3237247,
#   4.0813274,
#   4.1554804,
#   4.5448217,
#   3.9514835,
#   4.6164103,
#   4.2107625,
#   4.843548,
#   4.7712135,
#   5.113475,
#   4.687912,
#   5.3529143,
#   5.2545652,
#   5.1609564,
#   5.7918425,
#   5.4323044,
#   5.457203,
#   5.273528,
#   5.5919704,
#   4.8234186,
#   5.0637727,
#   4.610095,
#   5.266004,
#   4.4882584,
#   4.6214485,
#   4.608561,
#   4.6536036,
#   4.676408,
#   5.038889,
#   4.9313097,
#   5.670135,
#   5.0008316,
#   5.723212,
#   5.3443584,
#   5.758215,
#   5.744276,
#   7.030615,
#   6.7852936,
#   7.0389185,
#   8.048505,
#   8.033109,
#   6.887685,
#   7.3090296,
#   7.38237,
#   7.0976114,
#   7.6268005,
#   7.3778424,
#   7.6318927,
#   8.1591625,
#   8.00939,
#   7.1802144,
#   6.207061,
#   6.3018446,
#   6.265407,
#   5.897891,
#   5.061222,
#   5.508198,
#   5.3656235,
#   5.0583777,
#   4.857217,
#   4.765236,
#   4.8901687,
#   4.989868,
#   4.176259,
#   4.54939,
#   4.048801,
#   3.77617,
#   4.22528,
#   4.5797863,
#   4.3111973,
#   4.4548454,
#   5.204958,
#   5.194401,
#   5.3631907,
#   5.430765,
#   5.7810245,
#   6.192417,
#   5.4115267,
#   5.453298,
#   5.6146975,
#   5.9515867,
#   5.5722375,
#   5.577527,
#   5.767371,
#   6.847539,
#   6.392042,
#   6.5229635,
#   6.035965,
#   5.8604913,
#   6.1833663,
#   5.6809397,
#   5.394119,
#   5.244994,
#   4.7582903,
#   4.850705,
#   5.3659515,
#   5.153075,
#   5.1656437,
#   5.689488,
#   6.1866984,
#   6.200468,
#   5.5198,
#   4.99023,
#   5.364531,
#   4.299292,
#   4.408968,
#   4.13724,
#   4.0035653,
#   4.4210434,
#   5.130047,
#   4.5966363,
#   5.780148,
#   5.263214,
#   5.668302,
#   5.740965,
#   4.852112,
#   5.537529,
#   5.4158697,
#   4.9514513,
#   4.661055,
#   4.7498693,
#   4.7407875,
#   5.1204357,
#   4.7513514,
#   4.514049,
#   5.278986,
#   5.626426,
#   5.4958453,
#   5.5415087,
#   5.40556,
#   5.7351546,
#   5.038919,
#   4.6086483,
#   5.0917983,
#   3.9822607,
#   3.9014018,
#   4.381974,
#   4.3661003,
#   4.726347,
#   4.49641,
#   4.653511,
#   4.562621,
#   4.929991,
#   5.3285413,
#   5.086996,
#   5.5910378,
#   5.3748274,
#   5.5676517,
#   5.3994083,
#   5.4697814,
#   5.775876,
#   5.985847,
#   6.0020094,
#   5.471241,
#   5.7307863,
#   6.377406,
#   5.4293623,
#   5.002731,
#   6.107048,
#   5.6769037,
#   5.062676,
#   5.688519,
#   5.6731315,
#   5.535174,
#   5.6583443,
#   5.4713135,
#   4.9886327,
#   5.198707,
#   4.815629,
#   5.2693267,
#   5.07441,
#   5.358388,
#   4.8104577,
#   5.8323545,
#   5.623688,
#   6.2360296,
#   5.9901857,
#   6.3389378,
#   6.7476773,
#   6.3131285,
#   7.0687747,
#   6.181821,
#   6.076231,
#   6.0718074,
#   5.834701,
#   5.404589,
#   5.622304,
#   5.8784113,
#   6.1819715,
#   5.5257645,
#   5.7252197,
#   5.5527086,
#   5.5297704,
#   5.886841,
#   5.925181,
#   6.674798,
#   6.026458,
#   5.644972,
#   5.719849,
#   5.9275208,
#   5.3942456,
#   5.71266,
#   6.583202,
#   5.8719597,
#   6.32442,
#   6.191196,
#   6.8938475,
#   6.451339,
#   6.164672,
#   6.0383663,
#   5.906371,
#   5.8450274,
#   5.7791843,
#   5.7177005,
#   6.218553,
#   5.8765283,
#   6.1560645,
#   6.7188287,
#   7.198353,
#   7.5082393,
#   6.887377,
#   6.357765,
#   6.8685904,
#   7.379735,
#   6.6857905,
# ...
#   11.765575,
#   13.027744,
#   12.16506,
#   13.98577,
#   12.222591,
#   13.479187,
#   13.024384,
#   13.498859,
#   13.701493,
#   13.916148,
#   11.044071,
#   12.979301,
#   13.320248,
#   11.864775,
#   12.1008625,
#   12.61115,
#   12.404155,
#   13.189106,
#   11.761213,
#   12.2666445,
#   13.282615,
#   13.386135,
#   13.0787525,
#   11.252512,
#   12.946846,
#   12.029821,
#   13.260953,
#   13.24262,
#   12.69404,
#   11.074242,
#   11.945623,
#   13.514155,
#   12.973804,
#   12.552734,
#   11.750948,
#   13.678507,
#   13.277407,
#   11.968266,
#   10.9109,
#   10.514005,
#   10.338457,
#   11.364456,
#   11.926736,
#   12.893255,
#   12.578831,
#   13.850771,
#   12.880671,
#   12.914249,
#   11.745689,
#   11.991922,
#   12.025178,
#   12.084059,
#   10.893772,
#   12.414131,
#   10.921897,
#   11.073807,
#   11.401807,
#   11.234854,
#   10.488588,
#   11.977955,
#   10.652245,
#   10.886457,
#   10.145108,
#   10.903901,
#   10.221428,
#   10.982516,
#   10.621224,
#   11.524789,
#   11.435924,
#   11.671065,
#   10.6831665,
#   10.583553,
#   11.675394,
#   11.117916,
#   11.54153,
#   9.811602,
#   11.825947,
#   12.28336,
#   10.984338,
#   9.872702,
#   11.416433,
#   11.138086,
#   10.895275,
#   10.904457,
#   12.14592,
#   9.888043,
#   10.729813,
#   10.162629,
#   11.59034,
#   10.93077,
#   10.164854,
#   10.523452,
#   10.145747,
#   10.582865,
#   10.408675,
#   9.592674,
#   10.148005,
#   10.539158,
#   8.8665695,
#   10.434076,
#   9.438465,
#   10.022974,
#   9.087477,
#   9.873381,
#   8.935146,
#   9.351454,
#   9.810781,
#   9.541189,
#   9.789542,
#   8.915745,
#   9.420765,
#   11.257003,
#   9.4070835,
#   10.879519,
#   9.411898,
#   9.43396,
#   9.109886,
#   9.250226,
#   9.319239,
#   8.878421,
#   9.23633,
#   8.724822,
#   7.7714114,
#   8.395188,
#   9.307709,
#   8.73015,
#   8.82685,
#   10.63975,
#   10.321001,
#   8.990406,
#   8.450407,
#   8.580696,
#   8.360341,
#   8.812321,
#   9.016039,
#   8.699804,
#   8.461783,
#   9.234739,
#   9.049887,
#   9.137573,
#   9.220715,
#   8.416504,
#   7.736744,
#   8.378153,
#   8.490337,
#   9.044386,
#   8.059179,
#   8.233652,
#   8.376799,
#   8.377205,
#   7.597026,
#   8.34457,
#   8.004279,
#   7.073932,
#   7.8575687,
#   7.5801105,
#   7.7986226,
#   7.2929273,
#   7.8580337,
#   7.690804,
#   7.6981554,
#   7.239102,
#   7.5133066,
#   7.5388174,
#   7.473998,
#   7.0651093,
#   7.1606283,
#   7.178097,
#   7.3711395,
#   7.2198915,
#   7.6188993,
#   7.206938,
#   7.439164,
#   7.038563,
#   7.3385267,
#   7.2672014,
#   7.052536,
#   6.9130883,
#   8.032591,
#   7.866497,
#   7.118083,
#   7.4166636,
#   6.8826885,
#   7.215232,
#   7.7280855,
#   6.769916,
#   7.256383,
#   7.0896235,
#   7.073298,
#   6.920651,
#   6.5617113,
#   6.5489893,
#   6.5469007,
#   6.6548033,
#   6.3344874,
#   6.6305246,
#   7.409871,
#   6.646647,
#   6.6101856,
#   6.7663627,
#   6.8615046,
#   6.8689,
#   7.313644,
#   6.7334585,
#   6.955339,
#   7.132745,
#   7.626053,
#   ...],
#  'loss_bc4': [0,
#   0.122709125,
#   0.08136185,
#   0.083343595,
#   0.043975554,
#   0.023836851,
#   0.011051843,
#   0.0051153214,
#   0.0022732862,
#   0.00029186325,
#   0.00034465455,
#   0.0010040302,
#   0.0023237676,
#   0.004020308,
#   0.00651937,
#   0.0063029067,
#   0.007947664,
#   0.008624591,
#   0.011150067,
#   0.016921382,
#   0.021291226,
#   0.027436892,
#   0.027271362,
#   0.03718485,
#   0.041931678,
#   0.05364541,
#   0.06113929,
#   0.07286619,
#   0.08097595,
#   0.09811941,
#   0.11038796,
#   0.12425079,
#   0.123224705,
#   0.10748913,
#   0.08866559,
#   0.070133656,
#   0.052790534,
#   0.04168234,
#   0.030265428,
#   0.020611826,
#   0.013611026,
#   0.008645641,
#   0.005513768,
#   0.0037070522,
#   0.0022145999,
#   0.0014346524,
#   0.0009596136,
#   0.0010049823,
#   0.0015221621,
#   0.0029031024,
#   0.0034204996,
#   0.0043091425,
#   0.0054188017,
#   0.0057859803,
#   0.0061767236,
#   0.0049227187,
#   0.004124532,
#   0.002548702,
#   0.0020119203,
#   0.002223305,
#   0.0024603223,
#   0.0023026676,
#   0.0013399045,
#   0.001520106,
#   0.0017400788,
#   0.0025133,
#   0.0025988065,
#   0.0033810246,
#   0.0037198337,
#   0.004832297,
#   0.005585556,
#   0.00624975,
#   0.009057531,
#   0.008117476,
#   0.008742707,
#   0.00985541,
#   0.010709609,
#   0.013449046,
#   0.016447656,
#   0.01684312,
#   0.020781811,
#   0.028315797,
#   0.03846474,
#   0.043254208,
#   0.04565799,
#   0.045926336,
#   0.050387554,
#   0.05384942,
#   0.059955016,
#   0.063269384,
#   0.06581036,
#   0.066638455,
#   0.0691918,
#   0.05918409,
#   0.05106829,
#   0.041130707,
#   0.02961786,
#   0.018934036,
#   0.013277543,
#   0.011512084,
#   0.012438569,
#   0.013363818,
#   0.019813389,
#   0.025244255,
#   0.03108671,
#   0.03955204,
#   0.043591663,
#   0.05171498,
#   0.06460994,
#   0.07393914,
#   0.07399848,
#   0.08832884,
#   0.09605016,
#   0.09563127,
#   0.10099235,
#   0.09027636,
#   0.084802076,
#   0.09243232,
#   0.07690709,
#   0.07212023,
#   0.051877365,
#   0.042076886,
#   0.027237078,
#   0.0225106,
#   0.025209604,
#   0.032605335,
#   0.04682499,
#   0.048713665,
#   0.04652231,
#   0.04880847,
#   0.054747045,
#   0.046467658,
#   0.03770602,
#   0.03885544,
#   0.028104886,
#   0.020950079,
#   0.02222665,
#   0.03594535,
#   0.043683544,
#   0.061105497,
#   0.07309985,
#   0.07322945,
#   0.06308044,
#   0.069186255,
#   0.07516131,
#   0.07731778,
#   0.07554351,
#   0.093778595,
#   0.0919313,
#   0.09069146,
#   0.10732965,
#   0.13280635,
#   0.116320655,
#   0.14522257,
#   0.12787533,
#   0.10279141,
#   0.09466511,
#   0.102590755,
#   0.070744954,
#   0.07132764,
#   0.07332632,
#   0.10038395,
#   0.09500037,
#   0.10898076,
#   0.09701592,
#   0.11478409,
#   0.109740876,
#   0.11040644,
#   0.15165642,
#   0.12273295,
#   0.14996403,
#   0.1584602,
#   0.18846041,
#   0.22100136,
#   0.24383484,
#   0.2798678,
#   0.26175326,
#   0.31671813,
#   0.3129915,
#   0.27448323,
#   0.27797103,
#   0.2829709,
#   0.28458074,
#   0.24876095,
#   0.22328626,
#   0.19013755,
#   0.21614832,
#   0.20211786,
#   0.18266438,
#   0.17323908,
#   0.19649833,
#   0.19419333,
#   0.22917669,
#   0.2311496,
#   0.19370703,
#   0.20333208,
#   0.32637304,
#   0.3544129,
#   0.32442227,
#   0.354396,
#   0.29600564,
#   0.30659944,
#   0.28862408,
#   0.3358791,
#   0.26944065,
#   0.2510324,
#   0.23225574,
#   0.20285755,
#   0.20816258,
#   0.2242668,
#   0.22205754,
#   0.24162257,
#   0.25455952,
#   0.3285303,
#   0.26055902,
#   0.4605804,
#   0.5364767,
#   0.5228686,
#   0.43583632,
#   0.37551335,
#   0.3996331,
#   0.33306777,
#   0.38606462,
#   0.40688407,
#   0.39098287,
#   0.30339515,
#   0.30764395,
#   0.3495597,
#   0.25260842,
#   0.31797034,
#   0.23164889,
#   0.2535355,
#   0.15176833,
#   0.16037892,
#   0.10604043,
#   0.1904403,
#   0.19861989,
#   0.25386536,
#   0.36268875,
#   0.48409334,
#   0.56509054,
#   0.68123055,
#   0.70434844,
#   0.66415143,
#   0.6301705,
#   0.56233513,
#   0.5207866,
#   0.49065313,
#   0.3447974,
#   0.43505296,
#   0.3675075,
#   0.30571944,
#   0.36866152,
#   0.3692127,
#   0.3975187,
#   0.5100545,
#   0.5062623,
#   0.5318022,
#   0.5738374,
#   0.59998643,
#   0.6244631,
#   0.62080294,
#   0.545178,
#   0.50862783,
#   0.56808484,
#   0.53575784,
#   0.53199315,
#   0.4483769,
#   0.46756983,
#   0.46360898,
#   0.32272145,
#   0.40188384,
#   0.3461641,
#   0.30316177,
#   0.2763232,
#   0.2263346,
#   0.20815763,
#   0.21495634,
#   0.16759321,
#   0.20340568,
#   0.14067885,
#   0.13940085,
#   0.21547306,
#   0.17957203,
#   0.23489176,
#   0.27096885,
#   0.38277787,
#   0.41730276,
#   0.5687814,
#   0.61924815,
#   0.6364149,
#   0.8324309,
#   0.91789293,
#   0.94982946,
#   1.0259814,
#   0.94740874,
#   1.0058227,
#   0.8005104,
#   0.85756344,
#   0.8014076,
#   0.72175354,
#   0.6621058,
#   0.4781044,
#   0.44448835,
#   0.3479005,
#   0.26582864,
#   0.26367193,
#   0.27900398,
#   0.30492747,
#   0.30531624,
#   0.33608204,
#   0.35249418,
#   0.43120855,
#   0.4189585,
#   0.39236364,
#   0.5023092,
#   0.37237942,
#   0.34602064,
#   0.35858655,
#   0.33149797,
#   0.3612291,
#   0.38169482,
#   0.5215646,
#   0.5458242,
#   0.6853343,
#   0.7354241,
#   0.87574357,
#   0.7643727,
#   0.79779047,
#   0.9969137,
#   1.0558615,
#   0.821056,
#   0.92480385,
#   0.89275485,
#   0.7272479,
#   0.9379518,
#   0.93454427,
#   0.63352793,
#   0.6664801,
#   0.76087654,
#   0.6040352,
#   0.6809447,
#   0.81289005,
#   0.792447,
#   0.94728374,
#   0.7981303,
#   0.8982,
#   0.9369035,
#   0.94654286,
#   1.1243875,
#   1.0225892,
#   0.95915484,
#   0.904649,
#   0.9503341,
#   0.7862361,
#   0.80326784,
#   0.6288341,
#   0.6235814,
#   0.6193636,
#   0.47336024,
#   0.47641227,
#   0.44543517,
#   0.39769444,
#   0.49710438,
#   0.5531373,
#   0.42920843,
#   0.5513433,
#   0.63597167,
#   0.64264345,
#   0.63937783,
#   0.6536278,
#   0.6795702,
#   0.62687296,
#   0.6864835,
#   0.62191725,
#   0.52750045,
#   0.3967436,
#   0.51176584,
#   0.6303494,
#   0.49505752,
#   0.6637181,
#   0.5967553,
#   0.5687147,
#   0.58651376,
#   0.63107425,
#   0.6665029,
#   0.5882448,
#   0.5754323,
#   0.7005617,
#   0.67755806,
#   0.49705365,
#   0.57551515,
#   0.6332452,
#   0.73793906,
#   0.5711278,
#   0.7018311,
#   0.6208921,
#   0.78431076,
#   0.72392786,
#   0.6977764,
#   0.655585,
#   0.8268051,
#   0.7448093,
#   0.85700554,
#   0.72586083,
#   0.71940684,
#   0.57093406,
#   0.6335708,
#   0.6912875,
#   0.5053505,
#   0.5324913,
#   0.51298,
#   0.50064564,
#   0.62976015,
#   0.6615225,
#   0.8057606,
#   0.89656603,
#   0.9173238,
#   0.7738699,
#   0.69461536,
#   0.8749176,
#   0.7385901,
#   0.642831,
#   0.5687197,
#   0.58960456,
#   0.54438996,
#   0.61967754,
#   0.64987695,
#   0.6131286,
#   0.7747326,
#   0.777438,
#   0.85775524,
#   0.78532684,
#   0.87762594,
#   0.85615826,
#   0.9418875,
#   1.0506907,
#   1.1071205,
#   1.404369,
#   1.4822875,
#   1.4614899,
#   1.6825922,
#   1.6355971,
#   2.2058907,
#   1.9537935,
#   2.090903,
#   2.1934502,
#   1.9916381,
#   1.9786597,
#   1.8464577,
#   1.5340081,
#   1.662713,
#   1.2634964,
#   1.3538432,
#   1.1198046,
#   1.0143852,
#   0.80093265,
#   0.860832,
#   0.68423235,
#   0.5810317,
#   0.52045673,
#   0.45678133,
#   0.40590453,
#   0.305919,
#   0.4202144,
#   0.2833666,
#   0.28925914,
#   0.28651887,
#   0.27908474,
#   0.34871835,
#   0.36032623,
#   0.34770864,
#   0.37902465,
#   0.31301633,
#   0.3149426,
#   0.32249564,
#   0.25832915,
#   0.27551717,
#   0.24285217,
#   0.26062176,
#   0.23562986,
#   0.31739548,
#   0.25847712,
#   0.28948826,
#   0.32966766,
#   0.3136868,
#   0.3220967,
#   0.29481065,
#   0.3548904,
#   0.36127484,
#   0.36792025,
#   0.4499163,
#   0.38618296,
#   0.5213425,
#   0.5688871,
#   0.6614778,
#   0.6486585,
#   0.6803755,
#   0.7245383,
#   0.74874365,
#   0.83326524,
#   0.8235106,
#   0.9461098,
#   0.8414105,
#   0.7476399,
#   0.9401996,
#   0.75459546,
#   0.7789698,
#   0.8322208,
#   0.6603226,
#   0.8284186,
#   0.712698,
#   0.7540282,
#   0.65008646,
#   0.5802336,
#   0.6497266,
#   0.46876293,
#   0.5937348,
#   0.5891607,
#   0.5322261,
#   0.617448,
#   0.6346344,
#   0.76992816,
#   0.68853784,
#   0.6673625,
#   0.7387935,
#   0.6866461,
#   0.66986376,
#   0.6528187,
#   0.696697,
#   0.62713575,
#   0.5459352,
#   0.6199409,
#   0.4700114,
#   0.5746255,
#   0.5360751,
#   0.623546,
#   0.57485616,
#   0.58530843,
#   0.56696963,
#   0.6906003,
#   0.7463044,
#   0.85250455,
#   0.8012879,
#   0.9281603,
#   0.829159,
#   0.96444523,
#   0.93664134,
#   0.97116417,
#   1.113586,
#   1.0870957,
#   1.0005095,
#   1.1884158,
#   1.1820084,
#   1.2055678,
#   1.2228612,
#   1.1210582,
#   1.1368052,
#   1.0782163,
#   1.3007959,
#   1.2209777,
#   1.0944936,
#   1.1159711,
#   0.90714,
#   0.800757,
#   0.8301922,
#   1.0996609,
#   1.0790809,
#   1.0521603,
#   1.018086,
#   1.1473043,
#   1.1749034,
#   1.1977232,
#   1.2681444,
#   1.3326681,
#   1.4240301,
#   1.4267302,
#   1.404125,
#   1.1711661,
#   1.1300614,
#   1.1850739,
#   0.9099163,
#   1.1260058,
#   1.0877883,
#   1.2429278,
#   1.015342,
#   0.937068,
#   0.9766809,
#   0.92843914,
#   1.0285795,
#   0.81480837,
#   0.8660995,
#   0.8440554,
#   0.820428,
#   0.9046411,
#   0.87611175,
#   0.8334327,
#   0.7964417,
#   0.82427925,
#   0.835708,
#   0.87581503,
#   0.768605,
#   0.8723091,
#   0.81561166,
#   0.7606886,
#   0.88978565,
#   0.9897141,
#   0.87803185,
#   0.95149744,
#   0.9533337,
#   0.9411986,
#   0.91561013,
#   0.9703562,
#   0.8785058,
#   0.892517,
#   1.076565,
#   1.0947015,
#   0.9546643,
#   0.90931463,
#   1.0739379,
#   0.98067844,
#   1.1054406,
#   0.8804511,
#   0.99093896,
#   0.8510185,
#   0.7903937,
#   0.86442816,
#   0.8705423,
#   0.76845455,
#   0.8487988,
#   0.8285589,
#   0.7600152,
#   0.65882283,
#   0.6463693,
#   0.707505,
#   0.74239033,
#   0.6423782,
#   0.7320334,
#   0.62930274,
#   0.6202701,
#   0.65948486,
#   0.6067314,
#   0.4990249,
#   0.7474813,
#   0.64690065,
#   0.51845145,
#   0.5324553,
#   0.6147367,
#   0.624701,
#   0.6403922,
#   0.6257038,
#   0.57050693,
#   0.6011815,
#   0.68672705,
#   0.7242843,
#   0.59513336,
#   0.6265696,
#   0.5751511,
#   0.5538627,
#   0.5860647,
#   0.50531024,
#   0.619236,
#   0.5240171,
#   0.6017562,
#   0.6827073,
#   0.7100395,
#   0.6479432,
#   0.6949419,
#   0.67506146,
#   0.6690337,
#   0.74697626,
#   0.90380603,
#   0.66241574,
#   0.71329224,
#   0.748981,
#   0.79391676,
#   0.8312523,
#   0.82221353,
#   1.0029097,
#   0.92381656,
#   0.8475928,
#   0.83878255,
#   0.9067733,
#   0.9518315,
#   0.8416955,
#   0.9349678,
#   0.9942821,
#   1.1085904,
#   0.9965715,
#   1.0566871,
#   1.0826801,
#   1.0410776,
#   1.0516624,
#   1.0942957,
#   1.0889394,
#   1.1350735,
#   1.2749344,
#   1.2587395,
#   1.3618983,
#   1.2214881,
#   1.1835103,
#   1.1885209,
#   1.5259609,
#   1.5576124,
#   1.6812567,
#   1.2878677,
#   1.3013668,
#   1.0881383,
#   1.5862222,
#   1.4733915,
#   1.3340392,
#   1.4952226,
#   1.5177331,
#   1.6394271,
#   1.5791926,
#   1.6236963,
#   1.4526491,
#   1.381302,
#   1.3574381,
#   1.589748,
#   1.5096365,
#   1.6315198,
#   1.6676834,
#   1.762711,
#   1.7890656,
#   1.9588628,
#   1.9756831,
#   1.717136,
#   1.9067509,
#   1.8432131,
#   1.8782444,
#   1.907861,
#   1.7817495,
#   2.3349338,
#   1.9708941,
#   1.904593,
#   1.9854516,
#   1.7925065,
#   2.2099738,
#   1.995426,
#   2.187685,
#   2.213965,
#   2.0498095,
#   2.3039212,
#   2.2475083,
#   2.2305079,
#   2.2195578,
#   2.4152088,
#   2.5090466,
#   2.2427306,
#   2.5122066,
#   2.3121595,
#   2.315772,
#   2.1806133,
#   2.323924,
#   2.7021275,
#   2.226949,
#   2.6704547,
#   2.460455,
#   2.2955475,
#   2.320421,
#   2.807722,
#   2.479413,
#   2.3215418,
#   2.4814982,
#   2.6878161,
#   2.5612786,
#   2.619533,
#   2.8674881,
#   3.085731,
#   2.7872818,
#   2.8511212,
#   3.3557708,
#   3.2799973,
#   3.2897286,
#   3.4520116,
#   3.4699142,
#   3.5139802,
#   3.4886637,
#   3.6836958,
#   3.4885151,
#   3.6548834,
#   3.7256932,
#   3.7921176,
#   3.9309807,
#   3.5406752,
#   3.764937,
#   3.780857,
#   3.6024487,
#   3.598783,
#   3.499331,
#   3.5148358,
#   3.8707218,
#   3.8997169,
#   3.5922766,
#   3.819414,
#   3.6560595,
#   3.8615677,
#   3.816802,
#   3.9553123,
#   3.8185353,
#   3.9005764,
#   3.696152,
#   3.6868916,
#   3.815621,
#   3.6032906,
#   3.51152,
#   3.5622606,
#   3.8965704,
#   3.6580448,
#   3.859871,
#   3.8151438,
#   3.7449913,
#   3.9227922,
#   3.6616833,
#   3.7587695,
#   3.8947084,
#   4.096739,
#   4.1155515,
#   4.185096,
#   4.439314,
#   4.1183615,
#   4.146843,
#   3.9100897,
#   4.1513605,
#   4.210391,
#   4.1081686,
#   4.3449135,
#   4.368594,
#   4.1403275,
#   4.064311,
#   4.2014823,
#   4.1693163,
#   4.1564407,
#   4.1476517,
#   4.3857937,
#   4.263611,
#   4.2103634,
#   4.1985674,
#   4.365519,
#   4.2296114,
#   4.0023413,
#   4.2612505,
#   4.2791424,
#   4.064483,
#   4.0225234,
#   3.9330976,
#   3.9447536,
#   4.0180445,
#   3.836819,
#   4.092198,
#   4.257083,
#   3.9033468,
#   3.9695652,
#   4.261686,
#   4.0028963,
#   4.2886643,
#   4.119794,
#   4.166189,
#   4.096455,
#   3.9171076,
#   4.1933823,
#   4.3271165,
#   4.0720406,
#   4.654095,
#   4.2242603,
#   4.3279715,
#   4.5484834,
#   4.092688,
#   4.257723,
#   4.7854767,
#   4.6656523,
#   4.92107,
#   4.451166,
#   4.61012,
#   4.668373,
#   4.439628,
#   4.2593074,
#   4.0959044,
#   4.4940658,
#   4.488413,
#   4.3605123,
#   4.4784575,
#   4.3832645,
#   4.375285,
#   4.461436,
#   4.264723,
#   4.4403276,
#   4.4976835,
#   4.1738324,
#   4.6582155,
#   4.1631184,
#   4.1186485,
#   4.2302303,
#   4.306307,
#   4.1074343,
#   4.573889,
#   4.411702,
#   4.8793597,
#   4.125112,
#   4.4513435,
#   4.331169,
#   4.2954707,
#   4.1547074,
#   4.356389,
#   4.4916825,
#   3.9950304,
#   4.5165567,
#   4.0752487,
#   4.2077317,
#   4.1380453,
#   4.225191,
#   4.392803,
#   4.0026608,
#   4.1048336,
#   4.2155924,
#   4.104104,
#   4.327982,
#   4.2493014,
#   4.0886383,
#   4.4858346,
#   4.293334,
#   4.49526,
#   4.4444,
#   4.4939637,
#   4.1234407,
#   4.892031,
#   4.6385355,
#   4.4680786,
#   4.204215,
#   4.206292,
#   4.353937,
#   4.603217,
#   4.5724463,
#   4.4403744,
#   4.2238235,
#   4.119644,
#   4.1687975,
#   4.0474267,
#   3.861715,
#   4.0692773,
#   4.293438,
#   4.0687437,
#   4.2551284,
#   3.6814919,
#   3.993289,
#   4.119007,
#   3.8601766,
#   4.005208,
#   4.0878468,
#   4.034608,
#   3.9324565,
#   4.4438815,
#   4.294676,
#   3.8617344,
#   3.963105,
#   4.2613897,
#   3.6509418,
#   4.305392,
#   3.777091,
#   4.170453,
#   3.9768226,
#   3.7232807,
#   4.130147,
#   3.8896189,
#   3.5354822,
#   3.660594,
#   4.1084266,
#   4.040581,
#   4.0055895,
#   3.684723,
#   3.5275471,
#   3.721229,
#   3.780337,
#   3.8151467,
#   3.5315294,
#   3.5363088,
#   3.5603366,
#   3.682828,
#   3.3564663,
#   3.69567,
#   3.59046,
#   3.790389,
#   4.2020373,
#   3.4077437,
#   3.6344163,
#   3.9569366,
#   3.741513,
#   3.1194394,
#   3.6399288,
#   3.6223114,
#   3.7528038,
#   3.545486,
#   3.3054442,
#   3.731392,
#   3.4540815,
#   3.8924942,
#   3.5398517,
#   3.6380377,
#   3.2009053,
#   ...]}

# %%
### Plot ###

# Exact solution & Predicted solution
# Exact soluton
U_star = griddata(X_star, u_star.flatten(), (x1, x2), method='cubic')
F_star = griddata(X_star, f_star.flatten(), (x1, x2), method='cubic')

# Predicted solution
U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')

fig_1 = plt.figure(1, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(x1, x2, U_star, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Exact $u(x)$')

plt.subplot(1, 3, 2)
plt.pcolor(x1, x2, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Predicted $u(x)$')

plt.subplot(1, 3, 3)
plt.pcolor(x1, x2, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# Residual loss & Boundary loss
loss_res = mode.loss_res_log
loss_bcs = mode.loss_bcs_log

fig_2 = plt.figure(2)
ax = fig_2.add_subplot(1, 1, 1)
ax.plot(loss_res, label='$\mathcal{L}_{r}$')
ax.plot(loss_bcs, label='$\mathcal{L}_{u_b}$')
ax.set_yscale('log')
ax.set_xlabel('iterations')
ax.set_ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# Adaptive Constant
adaptive_constant = mode.adpative_constant_log

fig_3 = plt.figure(3)
ax = fig_3.add_subplot(1, 1, 1)
ax.plot(adaptive_constant, label='$\lambda_{u_b}$')
ax.set_xlabel('iterations')
plt.legend()
plt.tight_layout()
plt.show()

# Gradients at the end of training
data_gradients_res = mode.dict_gradients_res_layers
data_gradients_bcs = mode.dict_gradients_bcs_layers

gradients_res_list = []
gradients_bcs_list = []

num_hidden_layers = len(layers) - 1
for j in range(num_hidden_layers):
    gradient_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradient_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]

    gradients_res_list.append(gradient_res)
    gradients_bcs_list.append(gradient_bcs)

cnt = 1
fig_4 = plt.figure(4, figsize=(13, 4))
for j in range(num_hidden_layers):
    ax = plt.subplot(1, 4, cnt)
    ax.set_title('Layer {}'.format(j + 1))
    ax.set_yscale('symlog')
    gradients_res = data_gradients_res['layer_' + str(j + 1)][-1]
    gradients_bcs = data_gradients_bcs['layer_' + str(j + 1)][-1]
    sns.distplot(gradients_bcs, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \lambda_{u_b} \mathcal{L}_{u_b}$')
    sns.distplot(gradients_res, hist=False,
                    kde_kws={"shade": False},
                    norm_hist=True, label=r'$\nabla_\theta \mathcal{L}_r$')
    
    ax.get_legend().remove()
    ax.set_xlim([-3.0, 3.0])
    ax.set_ylim([0,100])
    cnt += 1
handles, labels = ax.get_legend_handles_labels()
fig_4.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.01),
            borderaxespad=0, bbox_transform=fig_4.transFigure, ncol=2)
plt.tight_layout()
plt.show()

# Eigenvalues if applicable
if stiff_ratio:
    eigenvalues_list = mode.eigenvalue_log
    eigenvalues_bcs_list = mode.eigenvalue_bcs_log
    eigenvalues_res_list = mode.eigenvalue_res_log
    eigenvalues_res = eigenvalues_res_list[-1]
    eigenvalues_bcs = eigenvalues_bcs_list[-1]

    fig_5 = plt.figure(5)
    ax = fig_5.add_subplot(1, 1, 1)
    ax.plot(eigenvalues_res, label='$\mathcal{L}_r$')
    ax.plot(eigenvalues_bcs, label='$\mathcal{L}_{u_b}$')
    ax.set_xlabel('index')
    ax.set_ylabel('eigenvalue')
    ax.set_yscale('symlog')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_21548/2533309064.py in <module>
#       7
#       8 # Predicted solution
# ----> 9 U_pred = griddata(X_star, u_pred.flatten(), (x1, x2), method='cubic')
#      10 F_pred = griddata(X_star, f_pred.flatten(), (x1, x2), method='cubic')
#      11
#
# NameError: name 'u_pred' is not defined
